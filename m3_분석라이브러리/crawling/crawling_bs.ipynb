# %% [markdown]
# ## 크롤링(웹 크롤링)
# 크롤링이란
# - 인터넷 상의 웹 페이지 데이터를 자동으로 수집하는 과정.
# - 웹 크롤링은 일반적으로 웹 스크래핑과 연관되며, 둘은 종종 혼용되지만 조금 다른 개념. 웹 크롤링은 웹 페이지를 탐색하고 데이터를 수집하는 반면, 웹 스크래핑은 그 페이지에서 특정 정보를 추출하는 데 중점을 둔다.
# - 크롤링은 스크래핑을 포함할 수 있다. 크롤링 과정에서 각 페이지를 방문할 때, 스크래핑을 통해 필요한 데이터를 추출할 수 있다.
#
# 웹 크롤링에 사용되는 도구
# - BeautifulSoup: Python 라이브러리로, HTML 및 XML 문서를 구문 분석하고 데이터를 추출하는 데 사용.
#
# - Scrapy: 웹 크롤링을 위한 Python 프레임워크로, 효율적이고 확장성이 높은 크롤러를 쉽게 만들 수 있다.
#
# - Selenium: 웹 브라우저 자동화 도구로, JavaScript가 동적으로 로드되는 페이지를 크롤링할 때 유용.
#
# - Requests: Python의 HTTP 라이브러리로, 웹 페이지 요청을 쉽게 할 수 있다.
#
# 웹 크롤링의 기본 과정
# - 크롤러 설정: 크롤러는 특정 웹 페이지를 시작점으로 설정. 이를 '시드(seed)'라고 부르며, 크롤러는 이 시드 URL에서 시작해 다른 페이지로 이동.
#
# - 페이지 요청: 크롤러는 HTTP 요청을 보내 웹 페이지를 요청. 이 과정에서 크롤러는 브라우저처럼 행동하여 웹 서버에서 페이지를 가져온다.
#
# - 데이터 추출: 웹 페이지가 응답되면, 크롤러는 페이지의 HTML을 분석하고 필요한 데이터를 추출. 이 과정에는 BeautifulSoup, lxml, Selenium 같은 라이브러리가 사용될 수 있다.
#
# - 링크 추출 및 큐잉: 크롤러는 현재 페이지에서 다른 페이지로 연결되는 링크를 추출하고, 이 링크들을 큐(queue)에 추가하여 다음 크롤링 대상으로 삼는다.
#
# - 반복: 이 과정은 정해진 규칙이나 종료 조건이 충족될 때까지 반복. 예를 들어, 특정 수의 페이지를 크롤링하거나, 주어진 도메인 내에서만 크롤링하도록 설정할 수 있다.
#
# 웹 크롤링의 주의사항
# 로봇 배제 표준(robots.txt): 많은 웹사이트는 robots.txt 파일을 통해 크롤러가 접근 가능한 부분과 접근을 제한하는 부분을 명시. 크롤러는 이 규칙을 준수해야 한다.
#
# 저작권 및 법적 이슈: 모든 웹사이트의 콘텐츠는 저작권의 보호를 받는다. 따라서 크롤링을 통해 수집한 데이터를 어떻게 사용할지에 대한 법적 문제를 주의해야 한다.
#
# 서버 부하: 지나친 크롤링은 웹 서버에 부하를 줄 수 있다. 크롤링 시에는 서버의 부담을 줄이기 위해 요청 간의 딜레이를 설정하는 것이 좋다.

# %% [markdown]
# 스크래핑 사례
# - 특정 웹페이지에서 유용한 데이터를 추출하는 과정. 주로 특정 정보 추출, 데이터 분석 등에 사용

# %%
import requests
from bs4 import BeautifulSoup

# 예시 네이버 뉴스 페이지 URL
url = 'https://news.naver.com/main/list.naver?mode=LSD&mid=shm&sid1=100'

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')

# 네이버 뉴스 페이지의 뉴스 제목 추출
news_titles = soup.find_all('dt')

for idx, title in enumerate(news_titles):
    print(f"{idx + 1}: {title.get_text().strip()}")
# Out:
# 1:
# 2: 육군, 'AI군수빅데이터융합센터' 만든다…미군 LDAC 벤치마킹
# 3:
# 4: 언론개혁 나서는 거야…김홍일 탄핵 카드 꺼내나
# 5: 동영상기사
# 6: 북한발 오물풍선 수도권·강원서 발견…육지·바다 곳곳 낙하
# 7:
# 8: AI 교과서, 학업성취도 떨어뜨릴까? 교사 출신 백승아 의원 "내년 도입 유보해야"
# 9:
# 10: 대북 방송 재개…“우발적 충돌 누그러뜨릴 수단 있어야”
# 11:
# 12: 민주, 부산 지역위원장 인선 의결… 금정 박인영, 해운대을은 삼파전
# 13:
# 14: 부산시의회, 안성민 의장 연임 카드 부상
# 15:
# 16: 정청래 법사위ㆍ최민희 과방위로 전투력 높인 민주당…“상임위 국정조사도 적극 추진”
# 17:
# 18: 민주당, 이재명 대표 맞춤형 당헌개정 논란
# 19: 동영상기사
# 20: 군, 오늘부터 최전방에서 고정식 대북 확성기 가동
# 21: 동영상기사
# 22: 북 오물풍선 살포 재개에…"대북 확성기 방송 실시"
# 23:
# 24: 결국, 대북확성기 ON
# 25: 동영상기사
# 26: 野 "단독 원 구성에 특검까지"...與 "정권 전복 시도"
# 27:
# 28: 여야, 원 구성 놓고 협상 없이 공방만…10일 야당 단독 처리(종합)
# 29:
# 30: "이병철 양자"라고? 피선거권 또 박탈된 `허본좌`…재등판하려면 84세 돼야
# 31: 동영상기사
# 32: 정부 "총파업 깊은 유감...국민 생명 담보로 불법 집단행동"
# 33:
# 34: [데일리안 오늘뉴스 종합] 의협 "18일 집단 휴진"…정부 "깊은 유감", '대북 확성기' 재설치로 '오물 풍선' 맞대응 등
# 35:
# 36: 충북 영동 야산서도 오물풍선 발견…"위험물질 없어"
# 37: 동영상기사
# 38: [현장영상] '숨겨놨던 스피커가 스르륵' 대북 확성기 훈련 최초 공개…8년 만에 대북 방송 재개
# 39:
# 40: 군, 오늘부터 최전방 여러 곳에서 대북 확성기 가동

# %% [markdown]
# 크롤링 사례
# - 웹페이지를 자동으로 탐색하며 링크를 따라가면서 여러 페이지를 방문하는 과정. 주로 검색 엔진 인덱싱이나 웹사이트 구조 파악에 사용

# %%
# !pip install requests beautifulsoup4 urllib3
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (2.0.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.6.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)

# %%
import requests
from bs4 import BeautifulSoup
from collections import deque
import urllib.robotparser
from urllib.parse import urljoin
import time

# 주어진 URL이 해당 웹사이트의 robots.txt 파일에 의해 접근이 허용되는지를 확인하는 함수
def can_fetch_url(url):
    robot_parser = urllib.robotparser.RobotFileParser()
    robot_parser.set_url('https://example.com/robots.txt')
    robot_parser.read()
    return robot_parser.can_fetch('*', url) # '*'는 모든 사용자 에이전트를 의미. 반환값은 True 또는 False

def get_response_with_retries(url, max_retries=5, backoff_factor=0.3):
    for i in range(max_retries):
        try:
            response = requests.get(url)
            response.raise_for_status()  # HTTP 응답 코드가 200이 아닌 경우 예외 발생
            return response
        except requests.ConnectionError as e: # 네트워크 문제나 서버가 응답하지 않는 경우
            print(f"Connection error: {e}")
        except requests.HTTPError as e: # 클라이언트 오류(4xx) 또는 서버 오류(5xx) 응답 코드
            print(f"HTTP error: {e}")
        except requests.RequestException as e: # 기타 모든 요청 관련 예외(RequestException)를 처리
            print(f"Request failed: {e}")
        time.sleep(backoff_factor * (2 ** i))  # 지수 백오프의 기본 원리는 재시도할 때마다 대기 시간을 두 배로 늘리는 것. 백오프 시간=기본 시간×(2의 n승)
    return None

start_url = 'https://example.com'
# 이미 방문한 URL들을 저장하는 집합
visited = set() # 집합을 사용하여 중복된 URL 방문을 피할 수 있다.
# 방문할 URL들을 저장하는 큐
queue = deque([start_url]) # deque는 양쪽 끝에서 빠르게 추가 및 제거할 수 있는 양방향 큐

max_urls = 10  # 최대 방문할 URL 수
visited_count = 0 # 현재까지 방문한 URL 수

# BFS(Breadth-First Search) 알고리즘을 사용하여 큐를 통해 웹 페이지를 순차적으로 방문. 각 페이지에서 h1 태그를 추출하고, 새로운 링크를 큐에 추가하여 크롤링을 확장
while queue: # 큐에 방문할 URL이 있는 동안 계속 반복
    if visited_count >= max_urls:
        print(f"Reached the limit of {max_urls} URLs. Stopping the crawler.")
        break

    current_url = queue.popleft() # 큐에서 다음 방문할 URL을 꺼내기
    if current_url in visited: # 이미 방문한 URL이면 다음 반복으로 건너뛰기
        continue

    visited.add(current_url) # 현재 URL을 방문한 URL 집합에 추가
    visited_count += 1

    if not can_fetch_url(current_url): # robots.txt 규칙을 확인하여 현재 URL이 접근 가능한지 확인
        print(f"Blocked by robots.txt: {current_url}") # 접근이 차단된 URL이면 메시지를 출력하고 다음 반복으로 건너뛰기
        continue

    response = get_response_with_retries(current_url)
    if response is None: # 응답이 성공적이지 않으면 메시지를 출력하고 다음 반복으로 건너뛰
        print(f"Failed to retrieve {current_url} after retries")
        continue

    soup = BeautifulSoup(response.text, 'html.parser') # 응답 내용을 BeautifulSoup으로 파싱

    titles = soup.find_all('h1') # 페이지 내의 모든 h1 태그를 찾
    for title in titles: # 각 h1 태그의 텍스트를 출력
        print(title.get_text())

    links = soup.find_all('a', href=True) # 페이지 내의 모든 a 태그에서 href 속성이 있는 링크를 찾
    for link in links:
        href = link['href']
        full_url = urljoin(current_url, href)  # 각 링크의 href 속성을 절대 경로로 변환하고, 큐에 추가
        if full_url not in visited and full_url.startswith('http'):
            queue.append(full_url)
# Out:
# Example Domain
# Example Domains
# Internet Assigned Numbers Authority
# Domain Name Services
# Protocol Registries
# Number Resources
# About us
# IANA-managed Reserved Domains
# Reached the limit of 10 URLs. Stopping the crawler.

# %% [markdown]
# Beautiful Soup Documentation <br/>
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %%
html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<div></div>
<p class="title"><b>The Dormouse's story</b></p>
<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html_doc, 'html.parser')
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <div>
#   </div>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
soup.title
# Out:
# <title>The Dormouse's story</title>

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.title.parent
# Out:
# <head><title>The Dormouse's story</title></head>

# %%
soup.title.parent.name
# Out:
# 'head'

# %%
# p태그 첫번째 데이터
soup.p
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
# a태그 첫번째 데이터
soup.a
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
soup.find('a')
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
soup.a['class']
# Out:
# ['sister']

# %%
soup.find_all('a')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.find_all(class_="sister")
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.find(id="link3")
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
soup.p
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
soup.p['class']
# Out:
# ['title']

# %%
soup.find('p')
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
# class는 Python의 예약어이기 때문에 class_를 사용
soup.find(class_='title')
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
soup.find_all('p')
# Out:
# [<p class="title"><b>The Dormouse's story</b></p>,
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  <p class="story">...</p>]

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %%
soup.find_all()
# Out:
# [<html><head><title>The Dormouse's story</title></head>
#  <body>
#  <div></div>
#  <p class="title"><b>The Dormouse's story</b></p>
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>
#  <p class="story">...</p>
#  </body></html>,
#  <head><title>The Dormouse's story</title></head>,
#  <title>The Dormouse's story</title>,
#  <body>
#  <div></div>
#  <p class="title"><b>The Dormouse's story</b></p>
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>
#  <p class="story">...</p>
#  </body>,
#  <div></div>,
#  <p class="title"><b>The Dormouse's story</b></p>,
#  <b>The Dormouse's story</b>,
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>,
#  <p class="story">...</p>]

# %% [markdown]
# #### string vs. get_text() vs. text
# - BeautifulSoup 객체에서 text 속성, get_text() 메서드, string 속성은 모두 HTML 또는 XML 문서에서 텍스트 데이터를 추출하는 데 사용
# - text 속성은 해당 태그에서 모든 텍스트 데이터를 가져오며,
# - get_text() 메서드도 동일한 결과를 반환합니다.
# - string 속성은 해당 태그에서 첫 번째로 발견된 문자열 데이터만 가져옵니다.

# %% [markdown]
# | Method      | 특징                                                                               | 사용 사례                                      |
# |-------------|----------------------------------------------------------------------------------|-----------------------------------------------|
# | `string`    | 자식 텍스트 노드가 하나인 경우에만 해당 텍스트 반환, 여러 노드가 있으면 `None` 반환                | 단일 텍스트 노드만 있는 요소의 텍스트를 추출할 때      |
# | `get_text()`| 요소 및 모든 하위 요소의 텍스트를 모두 포함하여 문자열로 반환, `separator` 및 `strip` 옵션 사용 가능 | 요소 내 모든 텍스트를 추출하고, 구분자 및 공백 처리가 필요한 경우 |
# | `text`      | 요소 및 모든 하위 요소의 텍스트를 모두 포함하여 문자열로 반환, 추가 매개변수 없음                  | 요소 내 모든 텍스트를 단순하게 추출할 때                   |

# %% [markdown]
# string
# - 정의: string 속성은 BeautifulSoup 객체의 자식 노드 중 하나의 텍스트 노드만 반환. 해당 요소의 직접적인 텍스트 콘텐츠가 하나일 때만 유용.
# - 특징:
# 요소가 하나의 자식 텍스트 노드를 가지고 있는 경우에만 그 텍스트를 반환.
# 여러 자식 요소가 있거나 텍스트 노드가 여러 개 있는 경우 None을 반환.

# %%
from bs4 import BeautifulSoup

html = """
<div class="example">
    Single text node
</div>
<div class="example">
    <p>Multiple</p> text <span>nodes</span>
</div>
"""

soup = BeautifulSoup(html, 'html.parser')
single_text_node = soup.find('div', class_='example').string
multiple_text_nodes = soup.find_all('div', class_='example')[1].string

print(single_text_node)  # Output: Single text node
print(multiple_text_nodes)  # Output: None
# Out:
#     Single text node
#
# None

# %% [markdown]
# get_text()
# - 정의: get_text() 메서드는 요소 및 모든 하위 요소의 텍스트를 모두 추출하여 하나의 문자열로 반환.
# - 특징:
# 요소 내의 모든 텍스트를 포함하여 반환.
# 기본적으로 하위 요소 사이에 공백을 추가하지만, separator 매개변수를 사용하여 구분자를 지정할 수 있다.
# strip=True 옵션을 사용하여 앞뒤 공백을 제거할 수 있다.

# %%
from bs4 import BeautifulSoup

html = """
<div class="example">
    Single text node
</div>
<div class="example">
    <p>Multiple</p> text <span>nodes</span>
</div>
"""

soup = BeautifulSoup(html, 'html.parser')

# 기본적으로 `get_text()` 메서드는 공백을 구분자로 사용합니다.
# strip=True 옵션을 사용하여 앞뒤 공백을 제거하고 텍스트를 추출
single_text_node = soup.find('div', class_='example').get_text(strip=True)
multiple_text_nodes = soup.find_all('div', class_='example')[1].get_text(strip=True)

print("Default separator:")
print(single_text_node)  # Output: Single text node
print(multiple_text_nodes)  # Output: Multiple text nodes

# `separator` 매개변수를 사용하여 구분자를 지정합니다.
single_text_node_with_separator = soup.find('div', class_='example').get_text(strip=True)
multiple_text_nodes_with_separator = soup.find_all('div', class_='example')[1].get_text(separator=' | ', strip=True)

print("\nCustom separator (' | '):")
print(single_text_node_with_separator)  # Output: Single text node
print(multiple_text_nodes_with_separator)  # Output: Multiple | text | nodes
# Out:
# Default separator:
# Single text node
# Multipletextnodes
#
# Custom separator (' | '):
# Single text node
# Multiple | text | nodes

# %% [markdown]
# text
# - 정의: text 속성은 요소 및 모든 하위 요소의 텍스트를 모두 포함하는 문자열을 반환. get_text() 메서드와 동일한 기능을 한다.
# - 특징:
# get_text()와 거의 동일한 결과를 제공.
# get_text()와 다르게 추가 매개변수(separator, strip)를 사용할 수 없다.

# %%
from bs4 import BeautifulSoup

html = """
<div class="example">
    Single text node
</div>
<div class="example">
    <p>Multiple</p> text <span>nodes</span>
</div>
"""

soup = BeautifulSoup(html, 'html.parser')
single_text_node = soup.find('div', class_='example').text
multiple_text_nodes = soup.find_all('div', class_='example')[1].text

print(single_text_node)  # Output: Single text node
print(multiple_text_nodes)  # Output: Multiple text nodes
# Out:
#     Single text node
#
#
# Multiple text nodes

# %% [markdown]
# Q. 정규표현식을 사용하여 아래와 같이 출력하세요.
# ```
# Hello,world!
# Hello,world!
# ```

# %%
html = '''
<html>
<body>
<div>
Hello,world!
</div>
<div>
<p>
Hello,<b>world!</b>
</p>
</div>
</body>
</html>
'''
from bs4 import BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')
bs = soup.body.text
print(bs)
# Out:
# Hello,world!
#
#
#
# Hello,world!

# %%
import re
text = re.findall('[^\s]+',bs)
for t in text:
    print(t)
# print(re.findall('[A-Za-z!]+',bs))
# Out:
# Hello,world!
# Hello,world!

# %% [markdown]
# Q. 아래와 같이 출력하세요.
#
# `Hello,world! Hello,world!`

# %%
li = ''
for t in text:
    li += t
    li += ' '
print(li)
# Out:
# Hello,world! Hello,world!

# %%
from bs4 import BeautifulSoup
html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<div></div>
<p class="title"><b>The Dormouse's story</b></p>
<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""
soup = BeautifulSoup(html_doc, 'html.parser')
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <div>
#   </div>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
# BeautifulSoup 객체를 문자열로 변환하여 bs 변수에 저장
# 문자열로 변환하면 정규 표현식이나 다른 문자열 처리 기법을 사용하여 HTML 콘텐츠를 검색하거나 조작할 수 있다.
bs = str(soup)
print(bs,type(bs))
# Out:
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <div></div>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body></html> <class 'str'>

# %%
# 영어 텍스트만 출력
p = re.findall('[a-zA-Z]+',bs) # 정규표현식
m = ' '.join(p)
m
# Out:
# 'html head title The Dormouse s story title head body div div p class title b The Dormouse s story b p p class story Once upon a time there were three little sisters and their names were a class sister href http example com elsie id link Elsie a a class sister href http example com lacie id link Lacie a and a class sister href http example com tillie id link Tillie a and they lived at the bottom of a well p p class story p body html'

# %%
print(type(soup))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
print(soup.get_text())
print(soup.text)
print(type(soup.text))
# Out:
# The Dormouse's story
#
#
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...
#
# The Dormouse's story
#
#
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...
#
# <class 'str'>

# %%
texts = soup.find_all('body')
li = ''
for t in texts:
    li += t.text
print(li)
# Out:
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...

# %%
# 개행을 정규표현식으로 제거
import re
texts = re.findall('[^\s]+', soup.text) # [^\s]는 공백 문자가 아닌 모든 문자를 의미
li =''
for text in texts:
    li += text
    li += ' '
print(li)
# Out:
# The Dormouse's story The Dormouse's story Once upon a time there were three little sisters; and their names were Elsie, Lacie and Tillie; and they lived at the bottom of a well. ...

# %%
print(soup.title.string)
# Out:
# The Dormouse's story

# %% [markdown]
# bs
#
# https://hi-guten-tag.tistory.com/8

# %% [markdown]
# #### html.parser vs. lxml
# - 파이썬에서 HTML 및 XML 문서를 파싱(parsing)하는 라이브러리
# - html.parser는 HTML 문서를 파싱하는 데에 적합한 파서. 파이썬의 기본 라이브러리로 제공되며 파이썬 내부적으로 구현되어 있으며, 외부 종속성이 없으므로 파이썬과 함께 설치되는 패키지만 사용할 수 있습니다.
# - lxml은 C 언어로 작성된 파이썬 외부 라이브러리로서 HTML 및 XML 문서를 파싱하는 데에 적합하며, 파서 성능이 매우 우수합니다.
# - HTML 문서를 파싱하는 경우에는 html.parser를 사용하는 것이 간단하고 편리하며, 대부분의 경우에는 충분한 성능을 제공합니다. 그러나 대용량의 XML 문서나 매우 복잡한 HTML 문서를 파싱해야 하는 경우에는 lxml을 사용하는 것이 더 효율적입니다.

# %% [markdown]
# #### urllib + bs

# %%
# lxml은 파이썬에서 XML과 HTML 문서를 파싱하고 조작하기 위한 빠르고 유연한 라이브러리
# !pip install lxml

# %%
import urllib.request as rq

url = 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100'
# html = rq.urlopen(url).read()
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'lxml')
print(bs)
# Out:
# <!DOCTYPE HTML>
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh"/>
# <meta content="width=1106" name="viewport"/>
# <meta content="정치 : 네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image"/>
# <meta content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="정치 : 네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
# <meta content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공" name="twitter:description"/>
# <title>정치 홈 : 네이버 뉴스	</title>
# <link href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/news.css" rel="stylesheet" type="text/css"/>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jindo.js" type="text/javascript"></script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jquery.js" type="text/javascript"></script>
# <script type="text/javascript">
# var _MAIN_NEWS_MENU_ID='shm';
# var _MAIN_NEWS_SECTION_ID='103';
# var ccsrv='cc.naver.com';
# var g_ssc='news.sec';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness = 3;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
#
# var gnb_timestamp = "Sun Apr 30 10:43:42 KST 2023";
# </script>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.service.js" type="text/javascript"></script>
# <script>
#
#     var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#     if (!isUnderIE10) {
#         var gladSDK = document.createElement("script");
#         gladSDK.async = true;
#         gladSDK.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#         document.head.appendChild(gladSDK);
#     }
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#
#     window.gladsdk.cmd.push(function () {
#         window.gladsdk.setGlobalConfig({enablePersistAd: true});
#         window.gladsdk.setHostMeta('theme', 'system');
#
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newsend',
#             adSlotElementId: 'glad_ad_newsend'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newslist',
#             adSlotElementId: 'glad_ad_newslist'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_sidebox',
#             adSlotElementId: 'glad_ad_sidebox'
#         });
#     })
# </script>
# </head>
# <body>
# <div id="wrap">
# <!-- 광고적용 태그 추가 -->
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
# <li><span class="snb_bdr"></span><a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">스포츠</a></li>
# <li><span class="snb_bdr"></span><a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">날씨</a></li>
# <li><span class="snb_bdr"></span><a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">프리미엄</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_both">
# <div class="lnb_left">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li><a class="nclicks(lnb.pcmedia)" href="/"><span class="tx">언론사별</span> </a></li>
# <li class="on"><a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
# <li><a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a></li>
# <li><a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹</span> </a></li>
# <li><a class="nclicks(lnb.paper)" href="/newspaper/home"><span class="tx">신문보기</span> </a></li>
# <li><a class="nclicks(lnb.opi)" href="/opinion/home"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(lnb.fact)" href="/main/factcheck/main.naver"><span class="tx">팩트체크</span> </a></li>
# </ul>
# </div>
# </div>
# <div class="lnb_right">
# <div class="lnb_extra">
# <div class="lnb_extra_menu">
# <ul class="lnb_extra_menu_list">
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(STA.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb">
# <span class="lnb_date"><strong>04</strong>.<strong>30</strong><span class="day">(일)</span></span>
# <ul class="lnb_side" tabindex="0">
# <li><a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li><a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li><a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# <hr/>
# <table cellpadding="0" cellspacing="0" class="container">
# <caption class="blind">기사목록</caption>
# <colgroup>
# <col class="col_snb"/>
# <col class="col_content"/>
# <col class="col_aside"/>
# </colgroup>
# <tr>
# <td class="snb">
# <div class="snb" id="snb">
# <h2 class="h2"><a class="nclicks(lmn_pol.home)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100">정치</a></h2>
# <ul class="nav">
# <li><a class="snb_s11 nclicks(lmn_pol.mnl,,1)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=264">대통령실 </a></li>
# <li><a class="snb_s12 nclicks(lmn_pol.mnl,,2)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=265">국회/정당 </a></li>
# <li><a class="snb_s13 nclicks(lmn_pol.mnl,,3)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=268">북한 </a></li>
# <li><a class="snb_s14 nclicks(lmn_pol.mnl,,4)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=266">행정 </a></li>
# <li><a class="snb_s15 nclicks(lmn_pol.mnl,,5)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=267">국방/외교 </a></li>
# <li><a class="snb_s16 nclicks(lmn_pol.mnl,,6)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=269">정치일반 </a></li>
# </ul>
# <div class="snb_banner">
# <a class="nclicks(lmn_pol.pmb,,1)" href="https://media.naver.com/channel/setting?back=main"><img alt="언론사 구독하기" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/01/14/142956425_144518244_%2525B8%2525F0%2525B9%2525D9%2525C0%2525CF%2525B8%2525DE%2525C0%2525CE.png" width="71"/></a>
# </div>
# <div class="snb_banner">
# <a class="nclicks(lmn_pol.pmb,,1)" href="https://contents.premium.naver.com/"><img alt="네이버 프리미엄콘텐츠" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71"/></a>
# </div>
# </div>
# </td>
# <td class="content">
# <div class="content" id="main_content">
# <div class="list_body section_index">
# <div class="cluster">
# <div class="cluster_title">
# <span class="cluster_title_inner"><a class="cluster_title_icon_link _news_cluster_layer_btn" href="#biF7L"><i class="cluster_title_icon">안내</i>헤드라인 뉴스</a></span>
# <div class="cluster_title_layer _news_cluster_layer is_hidden">
# <div class="cluster_title_layer_text">
#                             헤드라인 뉴스와 각 기사묶음 타이틀은 <br/> 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.
#                         </div>
# <div class="cluster_title_layer_image"></div>
# <button class="cluster_title_layer_close _news_cluster_layer_close_btn" type="button">닫기</button>
# </div>
# </div>
# </div>
# <div class="_persist">
# <div class="cluster">
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/469/0000736846?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/469/2023/04/29/736846.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/469/0000736846?sid=100">윤 대통령, 5박7일 '국빈 방미' 마치고 귀국길… 30일 오후 도착</a>
# <div class="cluster_text_lede">윤석열 대통령이 29일(현지시간) 5박 7일간의 미국 국빈방문 일정을 마치고 보스턴에서 귀국길에 올랐다. 윤 대통령은 이날 오전 대통령 전용기인 '공군1 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news469,0000736846',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">한국일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004185034',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185034?sid=100">정상회담→상·하원연설→하버드연설…尹 5박7일 국빈 방미 마무리</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news277,0005252668',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">아시아경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005252668?sid=100">尹, 5박7일 미국 국빈방문 종료…귀국길 올라</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011832259',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011832259?sid=100">尹대통령, 美 워싱턴·보스턴 국빈방문 마치고 귀국길…30일 도착</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304292340_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=469&amp;aid=0000736846"><span class="cluster_foot_more_icon_num">23</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054151?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/055/2023/04/29/1054151.jpg?type=ofullfill132_90" width="132"/>
# <strong class="r_ico r_vod_medium">동영상기사</strong>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054151?sid=100">윤 대통령 하버드대 연설…"자유 무시, 결연한 연대 대응"</a>
# <div class="cluster_text_lede">미국을 국빈방문 중인 윤석열 대통령이 하버드대학에서 정책 연설을 했습니다. 윤 대통령은 연설에서 우크라이나 침공과 같이 다른 나라의 자유를 존중하지 않는 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news055,0001054151',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">SBS</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news366,0000897810',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선비즈</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000897810?sid=100">[전문] 尹대통령 美 하버드대 첫 연설 “자유 위협하는 세력에 연대해서 맞서야”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006777756',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006777756?sid=100">尹 하버드대 연설 "北핵협박·힘에의한 현상변경, 국제연대로 대응"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news056,0011475414',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">KBS</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011475414?sid=100">윤 대통령 “자유 무시 결정판이 북한…용기와 연대로 민주주의 지켜야”</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304290540_00000006&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=055&amp;aid=0001054151"><span class="cluster_foot_more_icon_num">48</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/469/0000736760?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/469/2023/04/29/736760.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/469/0000736760?sid=100">MIT석학 만난 윤 대통령 "혁신적 과학기술 협력"</a>
# <div class="cluster_text_lede">윤석열 대통령은 28일(현지시간) 보스턴의 매사추세츠 공과대학(MIT)을 찾았다. 현직 대통령이 MIT를 찾은 건 처음이다. 윤 대통령은 디지털 바이오  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news469,0000736760',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">한국일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news032,0003220473',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">경향신문</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/032/0003220473?sid=100">윤 대통령, MIT 디지털바이오 석학들과 대담</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013911613',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013911613?sid=100">尹, MIT 디지털바이오 석학들과 대담…한국 대통령 최초 방문</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011831673',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011831673?sid=100">尹, 美 MIT 석학 만나 첨단바이오 기술혁신·인재양성 전략 모색</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304290030_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=469&amp;aid=0000736760"><span class="cluster_foot_more_icon_num">39</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/015/0004839034?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/015/2023/04/29/4839034.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/015/0004839034?sid=100">尹 연설에 '피 흘릴 것' 반박한 中…김기현 "지나친 무례"</a>
# <div class="cluster_text_lede">중국 외교부가 윤석열 대통령의 6·25 전쟁 장진호 전투 평가에 대해 거친 표현으로 반박한 가운데, 김기현 국민의힘 대표가 "중국의 지나친 무례함에 깊은 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news015,0004839034',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">한국경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news018,0005475500',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">이데일리</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/018/0005475500?sid=100">국힘 "민주, 중국 도발 언제까지 침묵..北과는 한마음"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news022,0003807760',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">세계일보</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/022/0003807760?sid=100">尹연설 반박 中정부에...김기현 “지나친 무례함”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news082,0001209877',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">부산일보</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/082/0001209877?sid=100">국민의힘, 북·중에 ‘침묵’ 민주당에 “신사대주의” “북한과 찰떡공조”</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304291210_00000006&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=015&amp;aid=0004839034"><span class="cluster_foot_more_icon_num">33</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/008/0004881448?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/008/2023/04/29/4881448.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/008/0004881448?sid=100">尹대통령, 日화이트리스트 복귀에 "이런 식으로 변해가는 것"</a>
# <div class="cluster_text_lede">윤석열 대통령이 한일관계 개선에 대해 일본이 우리나라를 화이트리스트(수출심사우대국)에 복귀시킨 것을 예로 들며 "이런 식으로 변해가는 것"이라고 밝혔다. …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news008,0004881448',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">머니투데이</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003760866?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/023/2023/04/29/3760866.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003760866?sid=100">尹 “한일관계, 많은 변화 있을 것”...日학생 “관계개선 고맙습니다”</a>
# <div class="cluster_text_lede">윤석열 대통령은 28일(현지 시각) 일본 정부가 한국을 수출심사 우대국인 이른바 ‘화이트리스트’로 다시 분류한 데 대해 “이런 식으로 (양국 관계가) 변 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news023,0003760866',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선일보</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304290550_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=008&amp;aid=0004881448"><span class="cluster_foot_more_icon_num">12</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000897801?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/366/2023/04/29/897801.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000897801?sid=100">‘꼼수 탈당 1년 민형배’…'검수완박’ 등 안조위 무력화만 두 번, 與 대책은?</a>
# <div class="cluster_text_lede">민형배, 1년 만에 민주당 복귀 ‘검수완박법’·'학자금 무이자 대출법’ 안조위 무력화 후 복당 국회선진화법 당시 만들어졌지만…유명무실 1년 전 ‘검수완박 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news366,0000897801',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선비즈</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/417/0000917039?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/417/2023/04/29/917039.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/417/0000917039?sid=100">"부끄럽다" vs "환영한다"… 민형배 복당에 민주당 '시끌'</a>
# <div class="cluster_text_lede">민형배 의원의 복당에 대해 민주당 내부에서 의견이 첨예하게 갈리고 있다. 비이재명(비명)계는 "부끄럽다"며 비판의 목소리를 내는 반면 친이재명(친명)계는 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news417,0000917039',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">머니S</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304270700_00000298&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=366&amp;aid=0000897801"><span class="cluster_foot_more_icon_num">5</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/002/0002284275?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/002/2023/04/30/2284275.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/002/0002284275?sid=100">홍준표, 국힘에 "전광훈 끊어라… 못하면 당도 아니다"</a>
# <div class="cluster_text_lede">기독교에는 "이단 규정하라" 홍준표 대구시장이 전광훈 사랑제일교회 목사를 두고 국민의힘에 "더이상 미적 거리지 말고 그 목사의 뜻을 우리당에서 구현하겠다 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news002,0002284275',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">프레시안</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/088/0000811550?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/088/2023/04/29/811550.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/088/0000811550?sid=100">홍준표, 전광훈 두고 "정통기독교는 왜 '이단' 규정 못하나?" 당엔 '손절' 촉구</a>
# <div class="cluster_text_lede">홍준표 대구시장이 '전광훈 리스크'를 강하게 언급하며 국민의힘에 '손절' 조치를 요구했다. 홍준표 시장은 "대통령실로부터 '민주노총(민노총) 세력을 막아 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news088,0000811550',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">매일신문</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304281540_00000420&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=002&amp;aid=0002284275"><span class="cluster_foot_more_icon_num">17</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003760797?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/023/2023/04/29/3760797.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003760797?sid=100">美는 어떤 나라와도 ‘실질적 核공유’ 하지 않는다</a>
# <div class="cluster_text_lede">대통령실 “사실상 핵공유로 느낄 것”… 백악관 “아니다” 윤석열 대통령과 조 바이든 미 대통령이 정상회담에서 핵협의그룹(NCG) 신설 등 한반도 핵우산( …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news023,0003760797',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/018/0005475379?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/018/2023/04/29/5475379.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/018/0005475379?sid=100">美 전략자산 끌고 온 尹대통령[통실호외]</a>
# <div class="cluster_text_lede">윤석열 대통령과 조 바이든 미국 대통령이 ‘워싱턴 선언’을 채택했다. 워싱턴 선언은 북핵 위협의 확장억제를 강화하는 것을 골자로 한다. 핵심은 미 전략자 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news018,0005475379',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">이데일리</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304261910_00000003&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=023&amp;aid=0003760797"><span class="cluster_foot_more_icon_num">7</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879061?sid=100">외교부, 중국에 "한미 정상 성명, 특정국 겨냥 아냐"</a>
# <div class="cluster_text_lede">정부가 최근 한미 정상회담 공동성명 내용과 관련해 특정국을 겨냥한 것이 아니라는 입장을 중국 측에 전달했습니다. 외교부에 따르면 강상욱 주중대사관 정무공사는 그제(27일) 류진쑹 중국 외교부 아시아 담당 국 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879061',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/448/0000406930?sid=100">외교부 "한미 정상 공동성명, 특정국 겨냥 아냐"</a>
# <div class="cluster_text_lede">정부는 한미정상회담 공동성명 내용이 "양국의 미래지향적 협력 확대를 위한 것으로서 특정국을 겨냥한 것이 아니다"라는 입장을 중국 측에 설명했다. 29일 외교부에 따르면 강상욱 주중 대사관 정무공사는 지난 2 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news448,0000406930',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">TV조선</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304271640_00000008&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=052&amp;aid=0001879061"><span class="cluster_foot_more_icon_num">6</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054192?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/055/2023/04/29/1054192.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054192?sid=100">'아메리칸 파이' 뒷이야기…바이든 즉석 요청, 윤 대통령 '깜짝' 열창</a>
# <div class="cluster_text_lede">윤석열 대통령이 지난 26일(현지시간) 백악관 국빈만찬에서 미 포크록 가수 돈 맥클린의 '아메리칸 파이'(American Pie)를 '깜짝' 열창한 것을 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news055,0001054192',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">SBS</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/057/0001739016?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/057/2023/04/29/1739016.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/057/0001739016?sid=100">'아메리칸 파이' 열창한 윤 대통령 뒷이야기..."바이든이 요청했다"</a>
# <div class="cluster_text_lede">방미 중인 윤석열 대통령이 지난 26일(현지시간) 백악관 국빈만찬에서 돈 맥클린의 '아메리칸 파이'(American Pie)를 열창한 가운데, 대통령실이 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news057,0001739016',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">MBN</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304271400_00000046&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=055&amp;aid=0001054192"><span class="cluster_foot_more_icon_num">25</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005252617?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/277/2023/04/29/5252617.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005252617?sid=100">통일부, 北 김여정에 "허둥지둥 억지주장 보니 초조한가"</a>
# <div class="cluster_text_lede">정부는 김여정 북한 노동당 부부장이 한미 정상회담에 맹비난을 쏟아낸 데 대해 "적반하장"이라는 입장으로 일축했다. 통일부 당국자는 29일 출입기자단에 밝 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news277,0005252617',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">아시아경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/021/0002569298?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/021/2023/04/29/2569298.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/021/0002569298?sid=100">통일부, “北, 허둥지둥 억지 주장…무례한 언어, 저급한 수준 국제사회 웃음거리”</a>
# <div class="cluster_text_lede">통일부, 29일 ‘김여정 부부장 입장 발표에 대한 입장’ 尹 향해 ‘못난 인간’, 바이든에 ‘미래 없는 늙은이’ 발언 김여정에 “무례한 언어로 한미 양국 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news021,0002569298',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">문화일보</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304290630_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=277&amp;aid=0005252617"><span class="cluster_foot_more_icon_num">84</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054153?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/055/2023/04/29/1054153.jpg?type=ofullfill132_90" width="132"/>
# <strong class="r_ico r_vod_medium">동영상기사</strong>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054153?sid=100">대통령실, '핵공유 논란'에 "용어에 집착할 필요 없어"</a>
# <div class="cluster_text_lede">대통령실은 이번 한미정상회담에서 채택된 '워싱턴 선언'을 두고 '핵공유 논란'이 이는 데 대해서 "용어에 너무 집착할 필요가 없다"고 밝혔습니다. 방미  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news055,0001054153',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">SBS</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013911601?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2023/04/29/13911601.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013911601?sid=100">대통령실, '핵공유 논란'에 "용어에 집착할 필요 없어"</a>
# <div class="cluster_text_lede">보스턴 현지 브리핑…"美당국자 말한 핵공유는 나토식" "'워싱턴 선언', 나토식 핵공유 아냐…한미 양자간이어서 더 실효적" 대통령실은 28일(현지시간)  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013911601',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304282030_00001231&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=055&amp;aid=0001054153"><span class="cluster_foot_more_icon_num">32</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000897945?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/366/2023/04/30/897945.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000897945?sid=100">與, 내일 윤리위 첫 회의…김재원 ‘5·18 망언’ 징계 무게</a>
# <div class="cluster_text_lede">‘4·3, 김구 발언 논란’ 태영호 징계 논의도 예상 국민의힘 중앙당 윤리위원회가 내달 1일 첫 회의를 열고 활동을 시작한다. 당내에서는 윤리위가 잇따른 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news366,0000897945',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선비즈</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879007?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/052/2023/04/29/1879007.jpg?type=ofullfill132_90" width="132"/>
# <strong class="r_ico r_vod_medium">동영상기사</strong>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879007?sid=100">與 윤리위, 오는 1일 첫 회의...김재원·태영호 징계 논의 주목</a>
# <div class="cluster_text_lede">최근 지도부의 잇단 설화로 비판받은 국민의힘이 당 윤리위원회 구성을 마무리하고 내부 기강 잡기에 본격 돌입합니다. 오는 1일 첫 회의를 여는데, 김재원· …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879007',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304281030_00001855&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=366&amp;aid=0000897945"><span class="cluster_foot_more_icon_num">9</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269674?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/214/2023/04/29/1269674.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269674?sid=100">민주 "한미정상회담으로 원전 수출 사실상 어려워질 것‥구체적 이익 밝히라"</a>
# <div class="cluster_text_lede">더불어민주당이 한미정상회담 결과로 인해 "윤석열 정부의 원전 수출이 사실상 어려워질 것"이라고 주장했습니다. 더불어민주당 강선우 대변인은 서면 논평을 통 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news214,0001269674',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">MBC</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/022/0003807804?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/022/2023/04/30/3807804.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/022/0003807804?sid=100">민주, 韓美공동성명에 “원전 수출 사실상 어려워져. 족쇄만 찬 꼴”</a>
# <div class="cluster_text_lede">“정부는 양국이 원전 협력에 의기투합했다고 홍보하고 있으니 기가 막혀” 윤석열 대통령과 조 바이든 미국 대통령이 26일(현지시간) 워싱턴DC 백악관 로즈 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news022,0003807804',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">세계일보</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304260940_00000006&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=214&amp;aid=0001269674"><span class="cluster_foot_more_icon_num">4</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002136923?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/016/2023/04/29/2136923.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002136923?sid=100">대통령실 “‘워싱턴 선언’, 방미 최고성과…제2 한미상호방위조약”</a>
# <div class="cluster_text_lede">대통령실은 28일(현지시간) 한미정상회담에서 채택한 '워싱턴 선언'에 대해 “윤석열 대통령의 국빈 방미 가장 중요한 성과”라며 “제2의 한미상호방위조약” …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news016,0002136923',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">헤럴드경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269608?sid=100">
# ...
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/659/2023/04/30/11121.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/659/0000011121?ntype=RANKING&amp;sid=001">"간식에서 화장품 맛나요".. 거짓 구매 후기 쓴 주부 ' …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=659"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/659/2022/01/19/logo_659_56_20220119141438.png" width="16"/></span>전주MBC</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/666/0000010040?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/666/2023/04/29/10040.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/666/0000010040?ntype=RANKING&amp;sid=001">전세사기 대책위 설명회…피해자들 ‘보증금 일부라도 반환을’</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=666"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/666/2023/01/03/logo_666_56_20230103174615.png" width="16"/></span>경기일보</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/665/0000000874?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/665/2023/04/29/874.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/665/0000000874?ntype=RANKING&amp;sid=001">구글, 애플… '쥐꼬리 이익률' 속 탐욕과 농락 [視리즈]</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=665"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/665/2022/12/08/logo_665_56_20221208184224.png" width="16"/></span>더스쿠프</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/353/0000044809?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/353/2023/04/29/44809.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/353/0000044809?ntype=RANKING&amp;sid=001">4년 만에 만나는 황매산 철쭉</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=353"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/353/2018/09/20/logo_353_56_20180920154420.png" width="16"/></span>중앙SUNDAY</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018620?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/145/2023/04/29/18620.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018620?ntype=RANKING&amp;sid=001">가족이 함께 하면 더 좋은 유럽 여행지 4곳</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=145"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/145/2020/12/09/logo_145_56_20201209180915.png" width="16"/></span>레이디경향</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <button class="refresh_button nclicks('rig.renws2new') _refreshButton" type="button">더보기</button>
# </div>
# <script type="text/javascript">
#     var OfficeTopRankingManager = jindo.$Class({
#         $static: {
#             RANKING_INFO_BUTTON_SELECTOR: '._rankingInfoButton',
#             RANKING_INFO_LAYER_SELECTOR : '._rankingInfoLayer',
#             RANKING_INFO_BUTTON_CLOSE_SELECTOR : '._rankingInfoCloseButton',
#             REFRESH_BUTTON_SELECTOR : '._refreshButton',
#             RANKING_LIST_SELECTOR : '._rankingList'
#         },
#
#         $init: function(base) {
#             this._welBase = jindo.$Element(base);
#             this._rankingInfoLayer = jindo.$Element(this._welBase.query(this.constructor.RANKING_INFO_LAYER_SELECTOR));
#             this._rankingListArray = jindo.$ElementList(this._welBase.queryAll(this.constructor.RANKING_LIST_SELECTOR));
#
#             this._initEvent();
#         },
#
#         _initEvent: function() {
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_SELECTOR, jindo.$Fn(this._showRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_CLOSE_SELECTOR, jindo.$Fn(this._closeRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.REFRESH_BUTTON_SELECTOR, jindo.$Fn(this._refreshRankingList, this).bind());
#         },
#
#         _showRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.toggle();
#         },
#
#         _closeRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.hide();
#         },
#
#         _refreshRankingList: function(event) {
#             event.stopDefault();
#
#             for (var i=0 ; i<this._rankingListArray.length() ; i++) {
#                 var rankingList = this._rankingListArray.get(i);
#
#                 if (rankingList.visible() === true) {
#                     var nextIndex = i + 1;
#
#                     if (nextIndex === this._rankingListArray.length()) {
#                         nextIndex = 0;
#                     }
#
#                     var nextRankingList = this._rankingListArray.get(nextIndex);
#
#                     rankingList.hide();
#                     nextRankingList.show();
#
#                     break;
#                 }
#             }
#         }
#     });
#
#     window.addEventListener("load", function() {
#         var officeTopRanking = jindo.$$.getSingle("._officeTopRanking1087473");
#         if (officeTopRanking) {
#             new OfficeTopRankingManager(officeTopRanking);
#         }
#     });
# </script>
# <div class="side_ad" id="glad_ad_sidebox"></div>
# <div class="section" id="right_dailyList" style="margin-bottom:20px; white-space:nowrap;">
# <h4>분야별 주요뉴스</h4>
# <div class="classfy sd" style="display:block">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/032/0003220507?sid=100" title="북한 “한·미, 핵전쟁 기정사실화…비싼 대가 치를 것”">북한 “한·미, 핵전쟁 기정사실화…비싼 대가 치를 것”</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/011/0004185034?sid=100" title="정상회담→상·하원연설→하버드연설…尹 5박7일 국빈 방미 마무리">정상회담→상·하원연설→하버드연설…尹 5박7일 국빈 방미 마무리</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/119/0002708057?sid=100" title='홍준표 "전광훈, 급기야 대통령실 물고들어가…미적거리지 말고 끊어라"'>홍준표 "전광훈, 급기야 대통령실 물고들어가…미적거리지 말고 끊어라"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/001/0013912466?sid=104" title='바이든 "한미동맹, 민주주의·자유·안보에서 탄생…무엇보다 자유"'>바이든 "한미동맹, 민주주의·자유·안보에서 탄생…무엇보다 자유"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/018/0005475714?sid=104" title="퍼스트리퍼블릭 인수 은행 곧 나온다…JP모건·PNC 물망">퍼스트리퍼블릭 인수 은행 곧 나온다…JP모건·PNC 물망</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/215/0001098634?sid=101" title='이창양 장관, 한미 로봇협력 상징 찾아…"첨단로봇 지원"'>이창양 장관, 한미 로봇협력 상징 찾아…"첨단로봇 지원"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/421/0006778550?sid=101" title='"30대 다시 집 산다"…1분기 전국아파트 거래 비중 40대도 추월'>"30대 다시 집 산다"…1분기 전국아파트 거래 비중 40대도 추월</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/018/0005475742?sid=101" title="美 법인 찾은 HD현대 정기선, 참전용사 가족 만나…“희생에 감사”">美 법인 찾은 HD현대 정기선, 참전용사 가족 만나…“희생에 감사”</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/018/0005475759?sid=105" title="“환경미화원 대신 자율주행 청소차&quot;…LG U+, '26년 실증">“환경미화원 대신 자율주행 청소차"…LG U+, '26년 실증</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/648/0000015954?sid=105" title='KT, 감염병 대비 차세대 방역기술 개발…"빌게이츠 지원"'>KT, 감염병 대비 차세대 방역기술 개발…"빌게이츠 지원"</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/025/0003276799?sid=102" title="&quot;살인·성범죄·피싱 다 엮였다&quot;…'마약 전쟁' 이끄는 김연실 검사">"살인·성범죄·피싱 다 엮였다"…'마약 전쟁' 이끄는 김연실 검사</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/025/0003276793?sid=102" title="&quot;넌 좋아 보인다&quot; 스토킹 신고 당하자 살해…2심도 '징역 30년'">"넌 좋아 보인다" 스토킹 신고 당하자 살해…2심도 '징역 30년'</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/025/0003276794?sid=102" title="교육부 ‘동결’ 요청했지만…결국 4년제 대학 17곳 등록금 인상">교육부 ‘동결’ 요청했지만…결국 4년제 대학 17곳 등록금 인상</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/417/0000917141?sid=103" title="[내일 날씨] 전국 대체로 '맑음'… 중부지방은 구름 많음">[내일 날씨] 전국 대체로 '맑음'… 중부지방은 구름 많음</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/011/0004185002?sid=103" title="5월은 전주국제영화제와 함께 맞아볼까…영화제 이모저모">5월은 전주국제영화제와 함께 맞아볼까…영화제 이모저모</a> </li>
# </ul>
# </ul>
# </ul>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://media.naver.com/channel/settings"> <img alt="네이버 메인에서 바로 보는 언론사 편집뉴스 지금 바로 구독해보세요!" src="https://imgnews.pstatic.net/image/upload/item/2018/11/27/174854048_PC_%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA_%25B1%25B8%25B5%25B6%25C8%25B0%25BC%25BA%25C8%25AD.png" width="300"/> </a>
# </div>
# </div>
# <div class="section">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/assembly/index.naver" target="_blank"> <img alt="내일을 여는 국민의 국회" border="0" class="banner" height="60" src="https://imgnews.pstatic.net/image/upload/item/2021/01/08/173235779_%25B1%25B9%25C8%25B8%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA.png" width="300"/> </a>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" target="_blank"> <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/183951086_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300"/> </a>
# </div>
# </div>
# <div class="section">
# <h4> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"> 서비스 안내 </a> </h4>
# <ul class="list_txt">
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb"> 고침 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb"> 정정·반론·추후 보도 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb"> 불공정 선거 보도 기사 모음 </a> </li>
# </ul>
# <a class="more_link nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"><span class="blind">서비스 안내</span>더보기</a>
# </div>
# <script>
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#
#         adSlot.setCustomParam("calp", 'shome');
#         window.gladsdk.displayAd(adSlot);
#     });
# </script>
# </div>
# </td>
# </tr>
# </table>
# </div>
# <hr/>
# <div class="index">
# <div class="index_inner">
# <div class="floating_btn">
# <div class="floating_inner">
# <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
# <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
# </div>
# </div>
# <div class="index_tab" id="index.press_category">
# <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content is_hidden" id="index.press.area"></div>
# <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content02 is_hidden" id="index.category.area"></div>
# </div>
# </div>
# </div>
# <hr/>
# <div id="footer">
# <ul>
# <li class="first"><a class="nclicks(fot.agreement)" href="http://www.naver.com/rules/service.html">이용약관</a></li>
# <li><a class="nclicks(fot.guide)" href="/main/ombudsman/index.naver">서비스 안내</a></li>
# <li><a class="nclicks(fot.editor)" href="/main/ombudsman/edit.naver?mid=omb">기사배열 원칙 책임자 : 유봉석</a></li>
# <li>청소년 보호 책임자 : 이희만</li>
# <li><strong><a class="nclicks(fot.privacy)" href="http://www.naver.com/rules/privacy.html">개인정보처리방침</a></strong></li>
# <li><a class="nclicks(fot.disclaimer)" href="http://www.naver.com/rules/disclaimer.html">책임의 한계와 법적고지</a></li>
# <li><a class="nclicks(fot.help)" href="#" onclick="news.external.OPS.helpNews(); return false;" title="새창">뉴스 고객센터</a></li>
# </ul>
# <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
# <address class="address_nhn">
# <a class="logo nclicks(fot.naver)" href="https://www.navercorp.com/" target="_blank"><span class="blind">NAVER</span></a>
# <em>Copyright ©</em>
# <a class="nclicks(fot.navercorp)" href="https://www.navercorp.com/" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# <!-- -->
# </div>
# <script type="text/javascript">
#
#
#
#
#
#
#
# var index_tab = new news.index.TabController('index.press_category');
# index_tab.add(new news.index.Tab('index.press.btn','stit','index.press.area','/main/ajax/bottomIndex/press.naver'));
# index_tab.add(new news.index.Tab('index.category.btn','stit2','index.category.area','/main/ajax/bottomIndex/category.naver'));
# jindo.$Fn(index_tab.toggle, index_tab).attach(index_tab.tabs.keys(), 'click');
#
#
# (function() {
# 	news.right.RightSideFloatingManager.init();
# })();
#
#
#
#     (function() {
#         news.right.TopDownFloatingManager.init();
#     })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ;(function(){
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jindo.$Fn(function(){
#
#
# 	lcs_do();
#
#     }).attach(window, eventType);
# })();
#
#
#
#
#
#
#
#
# news.startup();
#
#
# jindo.$Fn(function(){
#     var welSkip = jindo.$Element("u_skip");
#     if (welSkip === null) {
#         return;
#     }
#     welSkip.delegate("click", "a", function(weEvent){
#         weEvent.stopDefault();
#         var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#         oWebAccessibilityUtil.moveFocus(elTarget);
#     });
# }).attach(window, "load");
#
#
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
# </body>
# </html>

# %%
text1 = bs.find('p')
print(text1,'\n')
text2 = bs.find('p').string
print(text2,'\n')
text3 = bs.find('p').get_text()
print(text3)
# Out:
# <p class="airs_info_inner"><i class="airs_info_icon_airs">AiRS</i><span class="airs_info_text"><b>추천</b>으로 구성된 뉴스를 제공합니다.</span></p>
#
# None
#
# AiRS추천으로 구성된 뉴스를 제공합니다.

# %%
texts = bs.find_all('p')
for t in texts:
    print(t.text)
# Out:
# AiRS추천으로 구성된 뉴스를 제공합니다.
# 오전 9시~오전 10시까지 집계한 결과입니다.
# 본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.

# %% [markdown]
# bs4에서 headers는
# - HTTP 요청을 보낼 때 요청 헤더를 설정하는 데 사용됩니다.
# - 일반적으로 웹 사이트에서 데이터를 스크래핑하려면, 해당 웹 사이트에서 HTTP 요청을 받을 때 자신이 웹 브라우저인 것처럼 보이도록 요청 헤더를 설정해야 합니다.
# - 이를 통해 웹 사이트는 봇이나 크롤러와 같은 자동화된 스크래핑 도구에서 요청을 보내는 것으로 인식하는 것을 방지할 수 있습니다.

# %% [markdown]
#  #### 인코딩 에러를 해결
#  chardet.detect(response.content)['encoding']은 response.content의 인코딩 방식을 자동으로 감지하여 반환하며
#  이 값을 encoding 변수에 저장한 후, response.content를 이 encoding 방식으로 디코딩하여 html 변수에 저장하고 출력

# %%
import requests
import chardet

# HTTP 요청에서 사용될 헤더 정보를 설정합니다.
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}

# 웹사이트에서 스크래핑할 URL을 지정합니다.
url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100'

# 지정된 url에 HTTP GET 요청을 전달
response = requests.get(url, headers=headers)

# HTTP 요청이 성공적으로 전달되었다면, 웹사이트의 HTML 코드를 출력합니다.
if response.status_code == 200:
    encoding = chardet.detect(response.content)['encoding']
    # print(response.content.decode(encoding)) # 웹사이트의 HTML 코드를 포함하는 이진(binary) 데이터를 반환
    print(response.text) # 웹사이트의 HTML 코드를 문자열 형태로 반환
else:
    print("HTTP request failed.")
# Out:
# <!doctype html>
# <html lang="ko" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36">
# 	<head>
# 		<meta charset="utf-8">
# 		<meta http-equiv="X-UA-Compatible" content="IE=edge">
# 		<meta name="referrer" contents="always">
# 		<meta http-equiv="refresh" content="600">
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" />
# 		<meta property="og:title" content="정치 : 네이버 뉴스">
# 		<meta property="og:type" content="website">
# 		<meta property="og:url" content="https://news.naver.com/section/100">
# 		<meta property="og:image" content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png">
# 		<meta property="og:description" content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공">
# 		<meta property="og:article:author" content="네이버">
# 		<meta name="twitter:card" content="summary">
# 		<meta name="twitter:title" content="정치 : 네이버 뉴스">
# 		<meta name="twitter:site" content="네이버 뉴스">
# 		<meta name="twitter:creator" content="네이버 뉴스">
# 		<meta name="twitter:image" content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png">
# 		<meta name="twitter:description" content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공">
# 		<title>정치 : 네이버 뉴스</title>
# 			<link rel="stylesheet" href="https://static-nnews.pstatic.net/css/min/20240214/news.css">
# 			<link rel="shortcut icon" type="image/x-icon" href="https://ssl.pstatic.net/static.news/image/news/m/2023/08/21/favicon.ico" />
# 			<link rel="apple-touch-icon-precomposed" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />
# 			<link rel="apple-touch-icon-precomposed" size="72x72" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" />
# 			<link rel="apple-touch-icon-precomposed" size="96x96" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" />
# 			<link rel="apple-touch-icon-precomposed" size="144x144" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" />
# 			<link rel="apple-touch-icon-precomposed" size="192x192" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />
# 					<script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script>
# 				<script>
# 			var g_ssc = nsc = "news.v3_sec";
# 			var g_default_area = "pol";
#
# 			var svr = "one-service-r-20240214-240214-160707-7b4b8d6fd-5mqbx";
# 			var nelo = {
# 				sampleNumber : 100,
# 				maxCount : 100,
# 				maxSendMessage : "로그 전송 최대치 도달"
# 			};
# 			var isGreendot = document.cookie.indexOf("MM_NEW=1") > -1;
# 			var isNewGreendot = document.cookie.indexOf("MM_NEW=2") > -1;
# 			var domain = "https://n.news.naver.com";
# 			var ajaxDomain = "";
# 			var newsDomain = "";
# 			var layoutName = "section_home";
# 			var layoutType = "section";
# 			var isAvailableDarkMode = false;
#
# 			var article = {
#
# 				officeId: "",
# 				articleId: "",
# 				sectionId : "",
# 				gdid: "",
# 				type: "",
# 				sectionInfo: {
# 					firstSection: "",
# 					secondSection: "",
# 					thirdSection: ""
# 				},
# 				title: document.title
# 			};
#
#
#
# 			var office = {
# 				isChannel: false,
# 				isPressHome: false,
# 				name : "",
# 				category : ""
# 			};
#
# 			var searchQuery = (function() {
# 				var referrerLink = document.createElement("a");
# 				var emptySearch = "";
#
# 				referrerLink.href = document.referrer || "";
#
# 				if (referrerLink.host.indexOf("search.naver.com") === -1) {
# 					return emptySearch;
# 				}
#
# 				return decodeURIComponent(
# 					(
# 						referrerLink.search.match(/(?:\?|&)query\=([^&]+)/) || [ null, emptySearch ]
# 					)[1].replace(/\+/g, " ")
# 				);
# 			})();
#
# 			var divIds = [];
# 			var syncDivIds = [];
# 			var syncDivIdsForNonArticle = [];
#
# 			var unitIds = [];
# 			var syncUnitIds = [];
# 			var syncUnitIdsForNonArticle = [];
#
# 			window.gladsdk = window.gladsdk || { cmd: [] };
# 			gladsdk.cmd.push(function() {
# 				gladsdk.setGlobalConfig({ enablePersistAd: true });
#
# 				var adInfoList = [];
#
# 				adInfoList.push({
# 					seq: 1,
# 					unitId: "p_news_newslist",
# 					sync: false,
# 					mobileOnly: false,
# 					article: false,
# 					directSalesPct: "",
# 					calp: false,
# 					hasSid1: true
# 				});
# 				adInfoList.push({
# 					seq: 2,
# 					unitId: "p_news_sidebox",
# 					sync: false,
# 					mobileOnly: false,
# 					article: false,
# 					directSalesPct: "",
# 					calp: true,
# 					hasSid1: false
# 				});
#
# 				var userAgent = navigator.userAgent.toLowerCase();
#
# 				for (var i = 0; i < adInfoList.length; i++) {
# 					var adInfo = adInfoList[i];
#
# 					var divId = "nmap_c_" + article.officeId + "_" + article.articleId + "_" + article.sectionId + "_" + adInfo.seq;
#
# 					var unitId = adInfo.unitId;
# 					var mobileOnly = adInfo.mobileOnly;
# 					var sync = adInfo.sync;
# 					var isArticle = adInfo.article;
# 					var directSalesPct = adInfo.directSalesPct;
# 					var calp = adInfo.calp;
# 					var hasSid1 = adInfo.hasSid1;
#
# 					if (mobileOnly == true) {
# 						if (/iphone|android|ipod/.test(userAgent) == false) {
# 							continue;
# 						}
# 					}
#
# 					var customParam = {
# 						sid1: article.sectionId,
# 						oid: article.officeId,
# 						gdid: article.gdid,
# 						pk: searchQuery,
# 						directSalesPct: directSalesPct
# 					};
#
# 					if (calp == true) {
# 						customParam.calp = "shome";
# 					}
# 					if (hasSid1 == true) {
# 						customParam.sid1 = "100";
# 					}
#
# 					var adUnit = {
# 						adUnitId: unitId,
# 						adSlotElementId: divId,
# 						customParam: customParam
# 					};
#
# 					if (sync == true) {
# 						syncUnitIds.push(unitId);
# 						syncDivIds.push(divId);
#
# 						if (isArticle == false) {
# 							syncUnitIdsForNonArticle.push(unitId);
# 							syncDivIdsForNonArticle.push(divId);
# 						}
# 					} else {
# 						unitIds.push(unitId);
# 						divIds.push(divId);
# 					}
#
# 					gladsdk.defineAdSlot(adUnit);
# 				}
#
# 			});
# 			window.__htExternalUrl = window.__htExternalUrl || {};
# 		</script>
# 		<script src="https://static-nnews.pstatic.net/js/min/20240214/common.min.js"></script>
# 	</head>
# 	<body class="n_news_mnews fs1 as_mp_layout as_section_home">
# 		<div class="end_container">
# 		<div class="u_skip"><a href="#ct">본문 바로가기</a></div>
# 		<header role="banner" class="as_gnb_mnews as_type_section">
# 	<div class="header_inner">
# 		<div class="Ngnb">
# 			<div class="Ngnb_inner">
# 				<div class="Ngnb_both">
# 					<div class="Ngnb_left">
# 						<span class="Ngnb_logo"><a href="https://m.naver.com/" class="Nlogo_link _LINK" data-clk="gnb.naver" data-url="https://m.naver.com/" data-pc-url="https://www.naver.com/"><span class="Nicon_logo">NAVER</span></a></span>
# 						<div class="Ngnb_service">
# 							<h1 class="Nservice_item"><a href="https://m.news.naver.com" class="_LINK" data-clk="gnb.news" data-url="https://m.news.naver.com" data-pc-url="https://news.naver.com/"><span class="Nicon_service">뉴스</span></a></h1>
# 							<span class="Nservice_subitem">
# 								<a href="https://m.entertain.naver.com" class="_LINK" data-clk="gnb.entertain" data-url="https://m.entertain.naver.com" data-pc-url="https://entertain.naver.com/home">
# 									<span class="Nicon_family Nicon_entertain">연예</span>
# 								</a>
# 							</span>
# 							<span class="Nservice_subitem">
# 								<a href="https://m.sports.naver.com" class="_LINK" data-clk="gnb.sports" data-url="https://m.sports.naver.com" data-pc-url="https://sports.news.naver.com/index">
# 									<span class="Nicon_family Nicon_sports">스포츠</span>
# 								</a>
# 							</span>
# 							<span class="Nservice_subitem">
# 								<a href="https://weather.naver.com" data-clk="gnb.weather">
# 									<span class="Nicon_family Nicon_weather">날씨</span>
# 								</a>
# 							</span>
# 							<span class="Nservice_subitem">
# 								<a href="https://contents.premium.naver.com" data-clk="gnb.premium">
# 									<span class="Nicon_family Nicon_premium">프리미엄</span>
# 								</a>
# 							</span>
# 						</div>
# 					</div>
# 					<div class="Ngnb_right">
# 						<div class="Ngnb_group">
# 							<div id="gnb" class="gnb_dark_type2"></div>
# 						</div>
# 						<div class="Ngnb_search _SEARCH_WRAP is_hidden"></div>
# 						<div class="Ngnb_tool">
# 							<a href="javascript:;" class="Ntool_button _SEARCH_CONTENT_TOGGLE_BUTTON" data-clk="gnb.scho"><span class="Nicon_search">검색</span></a>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 		<div id="_LNB_PARENT_WRAP" class="Nlnb" style="z-index:3000;" data-scroll-fixed="true">
# 		<div id="_LNB_WRAP" class="Nlnb_menu Ntype_scroll ">
# 			<div id="_LNB" class="Nlnb_menu_inner">
# 				<ul class="Nlnb_menu_list" role="tablist">
# 					<li class="Nlist_item _LNB_ITEM" role="tab">
# 						<a href="https://news.naver.com/" class="Nitem_link" data-clk="lnb.press"><span class="Nitem_link_menu">언론사별</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM is_active" role="tab">
# 						<a href="https://news.naver.com/main/main.naver?mode&#x3D;LSD&amp;mid&#x3D;shm&amp;sid1&#x3D;100" class="Nitem_link" data-clk="lnb.pol"><span class="Nitem_link_menu">정치</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="tab">
# 						<a href="https://news.naver.com/main/main.naver?mode&#x3D;LSD&amp;mid&#x3D;shm&amp;sid1&#x3D;101" class="Nitem_link" data-clk="lnb.eco"><span class="Nitem_link_menu">경제</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="tab">
# 						<a href="https://news.naver.com/main/main.naver?mode&#x3D;LSD&amp;mid&#x3D;shm&amp;sid1&#x3D;102" class="Nitem_link" data-clk="lnb.soc"><span class="Nitem_link_menu">사회</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="tab">
# 						<a href="https://news.naver.com/main/main.naver?mode&#x3D;LSD&amp;mid&#x3D;shm&amp;sid1&#x3D;103" class="Nitem_link" data-clk="lnb.lif"><span class="Nitem_link_menu">생활/문화</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="tab">
# 						<a href="https://news.naver.com/main/main.naver?mode&#x3D;LSD&amp;mid&#x3D;shm&amp;sid1&#x3D;105" class="Nitem_link" data-clk="lnb.it"><span class="Nitem_link_menu">IT/과학</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="tab">
# 						<a href="https://news.naver.com/main/main.naver?mode&#x3D;LSD&amp;mid&#x3D;shm&amp;sid1&#x3D;104" class="Nitem_link" data-clk="lnb.wor"><span class="Nitem_link_menu">세계</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="tab">
# 						<a href="https://news.naver.com/main/ranking/popularDay.naver?mid&#x3D;etc&amp;sid1&#x3D;111" class="Nitem_link" data-clk="lnb.rank"><span class="Nitem_link_menu">랭킹</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="tab">
# 						<a href="https://news.naver.com/newspaper/home" class="Nitem_link" data-clk="lnb.paper"><span class="Nitem_link_menu">신문보기</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="tab">
# 						<a href="https://news.naver.com/main/opinion/home.naver" class="Nitem_link" data-clk="lnb.opi"><span class="Nitem_link_menu">오피니언</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="tab">
# 						<a href="https://news.naver.com/main/tv/index.naver?mid&#x3D;tvh" class="Nitem_link" data-clk="lnb.tv"><span class="Nitem_link_menu">TV</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="tab">
# 						<a href="https://news.naver.com/main/factcheck/main.naver" class="Nitem_link" data-clk="lnb.fact"><span class="Nitem_link_menu">팩트체크</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="tab">
# 						<a href="https://media.naver.com/algorithm" class="Nitem_link" data-clk="lnb.algo"><span class="Nitem_link_menu">알고리즘 안내</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="tab">
# 						<a href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid&#x3D;omb" class="Nitem_link" data-clk="lnb.correct"><span class="Nitem_link_menu">정정보도 모음</span></a>
# 					</li>
# 				</ul>
# 			</div>
# 		</div>
# 		</div>
# 	</div>
# </header>
# <hr>
# <script>
# 	var svt = "20240214164709.573";
# 	var timestamp = svt.substr(0, 8);
# 	var isLogin = false;
# 	var uhv = "";
#
# 	var service = {
# 		news: false,
# 		entertain: false,
# 		sports: false,
# 		mnews: true,
# 		newsType: true
# 	};
# 	var serviceName = "mnews";
#
# 	var envPhase = "production";
# 	var isProduction = true;
#
# 	var gnb_service = "news";
# 	var gnb_logout = encodeURIComponent(location.href);
# 	var gnb_template = "gnb_utf8";
# 	var gnb_brightness = 3;
# 	var gnb_item_hide_option = 128;
# </script>
# <div id="ct_wrap" class="ct_wrap">
# 	<div class="ct_lnb">
# 		<div class="ct_lnb_inner">
# 			<strong class="ct_lnb_date">02.14(수)</strong>
# 			<ul class="ct_lnb_side">
# 				<li class="ct_lnb_side_item">
# 					<a href="https://news.naver.com/main/officeList.naver" class="ct_lnb_side_link" data-clk="slb.allmedia">전체 언론사</a>
# 				</li>
# 				<li class="ct_lnb_side_item">
# 					<a href="https://newsstand.naver.com/" class="ct_lnb_side_link" target="_blank" data-clk="slb.newsstand">뉴스스탠드</a>
# 				</li>
# 				<li class="ct_lnb_side_item">
# 					<a href="https://newslibrary.naver.com/search/searchByDate.nhn" class="ct_lnb_side_link" target="_blank" data-clk="slb.library">라이브러리</a>
# 				</li>
# 			</ul>
# 		</div>
# 	</div>
# 	<div class="ct_scroll_wrapper">
# 		<div class="column0">
# 			<div class="ct_snb">
# 				<h2 class="ct_snb_h2">
# 					<a href="https://news.naver.com/main/main.naver?mode&#x3D;LSD&amp;mid&#x3D;shm&amp;sid1&#x3D;100" class="ct_snb_h2_a" data-clk="lmn_pol.home">정치</a>
# 				</h2>
# 				<ul class="ct_snb_nav">
# 					<li class="ct_snb_nav_item">
# 						<a href="/breakingnews/section/100/264" class="ct_snb_nav_item_link" data-clk="lmn_pol.mnl" data-rank="1">대통령실</a>
# 					</li>
# 					<li class="ct_snb_nav_item">
# 						<a href="/breakingnews/section/100/265" class="ct_snb_nav_item_link" data-clk="lmn_pol.mnl" data-rank="2">국회/정당</a>
# 					</li>
# 					<li class="ct_snb_nav_item">
# 						<a href="/breakingnews/section/100/268" class="ct_snb_nav_item_link" data-clk="lmn_pol.mnl" data-rank="3">북한</a>
# 					</li>
# 					<li class="ct_snb_nav_item">
# 						<a href="/breakingnews/section/100/266" class="ct_snb_nav_item_link" data-clk="lmn_pol.mnl" data-rank="4">행정</a>
# 					</li>
# 					<li class="ct_snb_nav_item">
# 						<a href="/breakingnews/section/100/267" class="ct_snb_nav_item_link" data-clk="lmn_pol.mnl" data-rank="5">국방/외교</a>
# 					</li>
# 					<li class="ct_snb_nav_item">
# 						<a href="/breakingnews/section/100/269" class="ct_snb_nav_item_link" data-clk="lmn_pol.mnl" data-rank="6">정치일반</a>
# 					</li>
# 				</ul>
# 				<div class="ct_snb_banner">
# 					<a href="https://media.naver.com/algorithm" data-clk="lmn_pol.pmb" data-rank="1">
# 						<img data-src="https://imgnews.pstatic.net/image/upload/item/2023/07/10/184436024_banner_left.png" width="71" height="74" class="_LAZY_LOADING">
# 					</a>
# 				</div>
# 				<div class="ct_snb_banner">
# 					<a href="https://contents.premium.naver.com/" data-clk="lmn_pol.pmb" data-rank="2">
# 						<img data-src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71" height="74" class="_LAZY_LOADING">
# 					</a>
# 				</div>
# 			</div>
# 		</div>
# 		<div id="newsct" class="newsct_wrapper _GRID_TEMPLATE_COLUMN _STICKY_CONTENT" role="main"><div class="section_component as_section_headline _PERSIST_CONTENT" data-persist="2_sectionHeadline">
# <div class="section_article as_headline _TEMPLATE" data-template-id="SECTION_HEADLINE">
# 	<div class="sa_head">
# 		<span class="sa_head_inner">
# 			<a href="#" class="sa_head_link _TOGGLE" data-classValue="is_hidden" data-target="_SECTION_HEADLINE_INFO_8paew" data-clk="guide">헤드라인 뉴스 <i class="sa_head_icon">안내</i></a>
# 		</span>
# 		<div id="_SECTION_HEADLINE_INFO_8paew" class="sa_head_layer is_hidden">
# 			<p class="sa_head_layer_p">각 헤드라인의 기사와 배열 순서는 개인화를 반영해 자동 추천되어 제공됩니다. 기사 수량이 표기된 기사 우측 하단의 파란색 아이콘을 클릭하면 기사묶음을 확인할 수 있고 기사묶음과 기사묶음 타이틀도 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.</p>
# 			<a href="https://media.naver.com/algorithm" class="sa_head_layer_go">알고리즘 자세히 보기</a>
# 			<div class="sa_head_layer_close">
# 				<button type="button" class="_TOGGLE" data-classValue="is_hidden" data-target="_SECTION_HEADLINE_INFO_8paew">닫기</button>
# 			</div>
# 		</div>
# 	</div>
# 	<ul id="_SECTION_HEADLINE_LIST_8paew" class="sa_list">
# 		<li class="sa_item _SECTION_HEADLINE">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/001/0014504759" class="sa_thumb_link" data-clk="clart">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/001/2024/02/14/14504759.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING" width="110" height="75" alt="">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/001/0014504759" class="sa_text_title" data-clk="clart">
# 							<strong class="sa_text_strong">오세훈 &quot;작은공 세워 수십년 권세&quot;…정치권에 &quot;참새와 봉황&quot;</strong>
# 						</a>
# 						<div class="sa_text_lede">안중근 사형선고일에 &quot;이런분이 독립운동가…정쟁 급하다고 쉽게 올리지마라&quot; 오세훈 서울시장은 &#x27;밸런타인데이&#x27;이자 독립운동가 안중근 의사에게 일제가 사형을 언도한 날인 14일 안 의사의 활동을 소재로 현 정국을 에둘러 </div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">연합뉴스</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/001/0014504759" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news001,0014504759" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202402141510_00000011/section/100?oid&#x3D;001&amp;aid&#x3D;0014504759" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">9</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _SECTION_HEADLINE">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/052/0001997715" class="sa_text_title" data-clk="clart">
# 							<strong class="sa_text_strong">불법 도박사이트 제작해 한국 범죄 조직에 팔아넘긴 北 외화벌이 조직 적발</strong>
# 						</a>
# 						<div class="sa_text_lede">불법 도박 사이트 수천 개를 제작해 한국 범죄 조직에 팔아넘긴 북한 외화벌이 조직이 국가정보원에 적발됐습니다. 국정원은 불법 외화벌이 조직은 노동당 39호실 산하 조직으로 중국 단둥에서 활동 중인 &#x27;경흥정보기술교류사</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">YTN</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/052/0001997715" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news052,0001997715" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202402141100_00000026/section/100?oid&#x3D;052&amp;aid&#x3D;0001997715" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">33</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _SECTION_HEADLINE">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/009/0005258006" class="sa_text_title" data-clk="clart">
# 							<strong class="sa_text_strong">尹 &quot;기업 출산지원 稅혜택 확대&quot;</strong>
# 						</a>
# 						<div class="sa_text_lede">부영이 최근 자녀 1인당 1억원이라는 파격적인 출산장려금을 내놓은 가운데 윤석열 대통령이 저출생 극복에 힘을 보태는 기업들을 지원하기 위한 세제 지원책을 마련하라고 관계 부처에 지시했다. 13일 대통령실에 따르면 윤</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">매일경제</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/009/0005258006" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news009,0005258006" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202402121440_00000001/section/100?oid&#x3D;009&amp;aid&#x3D;0005258006" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">42</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _SECTION_HEADLINE">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/366/0000970328" class="sa_thumb_link" data-clk="clart">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/366/2024/02/14/970328.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING" width="110" height="75" alt="">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/366/0000970328" class="sa_text_title" data-clk="clart">
# 							<strong class="sa_text_strong">‘尹 40년 지기’ 석동현도 컷오프… 與 단수공천에 대통령실 출신 ‘0명’</strong>
# 						</a>
# 						<div class="sa_text_lede">한강벨트 6곳 등 서울 승부처 19곳 후보 확정 국민의힘 공천관리위원회가 처음 발표한 4·10 총선 서울 지역 ‘단수 공천’ 명단에 용산 대통령실 출신이 단 한 명도 이름을 올리지 못했다. 14일 국민의힘 공관위는 </div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">조선비즈</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/366/0000970328" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news366,0000970328" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202402141040_00000002/section/100?oid&#x3D;366&amp;aid&#x3D;0000970328" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">80</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _SECTION_HEADLINE">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/016/0002266225" class="sa_thumb_link" data-clk="clart">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/016/2024/02/14/2266225.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING" width="110" height="75" alt="">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/016/0002266225" class="sa_text_title" data-clk="clart">
# 							<strong class="sa_text_strong">5·18 묘역 찾은 조국 “尹 정권 빨리 종식시켜야”</strong>
# 						</a>
# 						<div class="sa_text_lede">신당 창당을 선언한 조국 전 법무부장관이 14일 “광주의 역사는 제 삶의 가장 중요한 이정표 중 하나다. 그 역사가, 오늘 아침 저에게 조금은 다르게 다가온다”고 했다. 조 전 장관은 이날 오전 광주 5·18 망월묘</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">헤럴드경제</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/016/0002266225" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news016,0002266225" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202402141020_00000006/section/100?oid&#x3D;016&amp;aid&#x3D;0002266225" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">26</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _SECTION_HEADLINE is_blind">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/448/0000447800" class="sa_thumb_link" data-clk="clart">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/448/2024/02/14/447800.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING" width="110" height="75" alt="">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/448/0000447800" class="sa_text_title" data-clk="clart">
# 							<strong class="sa_text_strong">尹, 외국인 투자기업에 &quot;사업에 유리한 제도·규제 환경 제공…세제 지원도&quot;</strong>
# 						</a>
# 						<div class="sa_text_lede">윤석열 대통령이 14일 외국인 투자기업인들을 만나 &quot;글로벌 스탠더드보다 더 유리한 제도와 규제 환경을 제공하고, 여러 가지 세제와 지원을 여러분에게 아끼지 않아야 될 것 같다&quot;고 말했다. 윤 대통령은 이날 서울 중구</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">TV조선</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/448/0000447800" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news448,0000447800" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202402141330_00000007/section/100?oid&#x3D;448&amp;aid&#x3D;0000447800" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">30</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _SECTION_HEADLINE is_blind">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/014/0005142018" class="sa_thumb_link" data-clk="clart">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/014/2024/02/14/5142018.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING" width="110" height="75" alt="">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/014/0005142018" class="sa_text_title" data-clk="clart">
# 							<strong class="sa_text_strong">한동훈, &#x27;부정선거 음모론자&#x27; 비판에 &quot;선거 관리 엄정해야&quot;</strong>
# 						</a>
# 						<div class="sa_text_lede">한동훈 국민의힘 비상대책위원장이 14일 &#x27;부정선거 음모론자&#x27;라는 비판에 대해 &quot;선거 관리를 엄정하게 하자는 주장은 절대로 폄하될 수 없다&quot;고 목소리를 높였다. 한 위원장은 이날 서울 여의도 국민의힘 당사 출근길에 기</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">파이낸셜뉴스</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/014/0005142018" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news014,0005142018" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202402131020_00000076/section/100?oid&#x3D;014&amp;aid&#x3D;0005142018" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">23</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _SECTION_HEADLINE is_blind">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/277/0005379720" class="sa_thumb_link" data-clk="clart">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/277/2024/02/14/5379720.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING" width="110" height="75" alt="">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/277/0005379720" class="sa_text_title" data-clk="clart">
# 							<strong class="sa_text_strong">尹, 다음주 독일·덴마크 순방 순연키로</strong>
# 						</a>
# 						<div class="sa_text_lede">윤석열 대통령이 다음 주 출국을 목표로 했던 독일·덴마크 순방을 순연하기로 한 것으로 14일 알려졌다. 윤 대통령과 대통령실은 여러 요인을 검토하고 독일과 덴마크 측에 양해를 구한 것으로 전해졌다. 윤 대통령은 20</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">아시아경제</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/277/0005379720" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news277,0005379720" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202402141440_00000001/section/100?oid&#x3D;277&amp;aid&#x3D;0005379720" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">31</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _SECTION_HEADLINE is_blind">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/016/0002266329" class="sa_thumb_link" data-clk="clart">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/016/2024/02/14/2266329.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING" width="110" height="75" alt="">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/016/0002266329" class="sa_text_title" data-clk="clart">
# 							<strong class="sa_text_strong">유동규 출사표 &quot;이재명 방탄조끼 입는 꼴 더는 못 보겠다&quot;</strong>
# 						</a>
# 						<div class="sa_text_lede">대장동 사건으로 기소된 유동규 전 성남도시개발공사 기획본부장이 14일 자유통일당에 입당과 함께 앙숙이 된 이재명 더불어민주당 대표의 지역구 인천 계양을에 출마하겠다고 선언했다. 자유통일당은 광화문 태극기 집회를 주도</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">헤럴드경제</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/016/0002266329" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news016,0002266329" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202402141010_00000471/section/100?oid&#x3D;016&amp;aid&#x3D;0002266329" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">41</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _SECTION_HEADLINE is_blind">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/421/0007350337" class="sa_thumb_link" data-clk="clart">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/421/2024/02/14/7350337.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING" width="110" height="75" alt="">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/421/0007350337" class="sa_text_title" data-clk="clart">
# 							<strong class="sa_text_strong">국힘, 위성정당 &#x27;국민의미래&#x27; 창당대회 23일로 순연</strong>
# 						</a>
# 						<div class="sa_text_lede">국민의힘 총선용 위성정당인 &#x27;국민의미래(가칭)&#x27; 출범이 23일로 순연됐다. 14일 국민의힘에 따르면 국민의미래 창당대회는 당내 사정을 이유로 당초 알려진 15일에서 8일 늦어진 23일 개최될 예정이다. 이는 당 지도</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">뉴스1</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/421/0007350337" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news421,0007350337" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202402141200_00000365/section/100?oid&#x3D;421&amp;aid&#x3D;0007350337" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">13</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 	</ul>
# </div>
# <div class="section_more _SECTION_HEADLINE_MORE_BUTTON_WRAP">
# 	<a href="#" class="section_more_inner _SECTION_HEADLINE_MORE_BUTTON" data-target="_SECTION_HEADLINE_LIST_8paew" data-clk="clsmore">헤드라인 더보기</a>
# </div>
# </div>
# <div class="section_component as_section_series _PERSIST_CONTENT" data-persist="3_sectionSeries">
# <div class="section_series _TEMPLATE" data-template-id="SECTION_SERIES">
# 	<div class="ss_head">
# 		<div class="ss_head_inner">
# 			<a href="https://news.naver.com/hotissue/main?sid1&#x3D;163&amp;cid&#x3D;2000862" class="ss_head_link" data-clk="sert">
# 				<span class="ss_head_go">연재보기</span>
# 				<h2 class="ss_head_topic">띵동 정국배달</h2>
# 			</a>
# 		</div>
# 	</div>
# 	<div class="ss_body">
# 		<ul class="ss_list">
# 			<li class="ss_item _LAZY_LOADING_WRAP">
# 				<div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# 					<div class="ss_thumb_inner">
# 						<a href="https://n.news.naver.com/mnews/hotissue/article/052/0001997552?type&#x3D;series&amp;cid&#x3D;2000862" class="ss_thumb_link" data-clk="sera">
# 							<img data-src="https://mimgnews.pstatic.net/image/origin/052/2024/02/14/1997552.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="" style="display:none;">
# 							<span class="ss_thumb_play">
# 								<em class="blind">동영상뉴스</em>
# 							</span>
# 						</a>
# 					</div>
# 				</div>
# 				<div class="ss_text">
# 					<a href="https://n.news.naver.com/mnews/hotissue/article/052/0001997552?type&#x3D;series&amp;cid&#x3D;2000862" class="ss_text_headline" data-clk="sera">조국 신당 변수는? / &quot;의원 한 명 더!&quot;...개혁신당 바쁜 이유</a>
# 					<div class="ss_text_lede">조국 전 법무부장관이 신당 창당을 공식 선언했습니다. 조 전 장관은 총선에서 검찰 독재를 종식하겠다고 강조했는데요. 고향인 부산에서 가진 기자회견을 함께 보시죠. [조 국 / 전 법무부 장관 : 4월 10일은 무도하</div>
# 					<div class="ss_text_info">
# 						<div class="ss_text_press">YTN</div>
# 						<a href="https://n.news.naver.com/mnews/article/comment/052/0001997552" class="ss_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news052,0001997552" data-zero-allow="false" data-clk="sercmtcount"></a>
# 					</div>
# 				</div>
# 			</li>
# 			<li class="ss_item _LAZY_LOADING_WRAP">
# 				<div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# 					<div class="ss_thumb_inner">
# 						<a href="https://n.news.naver.com/mnews/hotissue/article/052/0001997043?type&#x3D;series&amp;cid&#x3D;2000862" class="ss_thumb_link" data-clk="sera">
# 							<img data-src="https://mimgnews.pstatic.net/image/origin/052/2024/02/13/1997043.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="" style="display:none;">
# 							<span class="ss_thumb_play">
# 								<em class="blind">동영상뉴스</em>
# 							</span>
# 						</a>
# 					</div>
# 				</div>
# 				<div class="ss_text">
# 					<a href="https://n.news.naver.com/mnews/hotissue/article/052/0001997043?type&#x3D;series&amp;cid&#x3D;2000862" class="ss_text_headline" data-clk="sera">이재명, 폭풍트윗에 쓴 말 / &#x27;건국전쟁&#x27; 본 한동훈 &quot;결단 곱씹어야&quot;</a>
# 					<div class="ss_text_lede">설 연휴 더불어민주당 이재명 대표는 폭풍 트윗을 날렸습니다. 연휴 첫날밤부터 자신의 SNS에 잇따라 글을 남겼는데요. 단결만이 답이라며 친명, 비명 나누지 말라는 내용의 글을 공유하고, 리트윗 한 번, 댓글 한 개,</div>
# 					<div class="ss_text_info">
# 						<div class="ss_text_press">YTN</div>
# 						<a href="https://n.news.naver.com/mnews/article/comment/052/0001997043" class="ss_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news052,0001997043" data-zero-allow="false" data-clk="sercmtcount"></a>
# 					</div>
# 				</div>
# 			</li>
# 			<li class="ss_item _LAZY_LOADING_WRAP">
# 				<div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# 					<div class="ss_thumb_inner">
# 						<a href="https://n.news.naver.com/mnews/hotissue/article/052/0001995729?type&#x3D;series&amp;cid&#x3D;2000862" class="ss_thumb_link" data-clk="sera">
# 							<img data-src="https://mimgnews.pstatic.net/image/origin/052/2024/02/08/1995729.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="" style="display:none;">
# 							<span class="ss_thumb_play">
# 								<em class="blind">동영상뉴스</em>
# 							</span>
# 						</a>
# 					</div>
# 				</div>
# 				<div class="ss_text">
# 					<a href="https://n.news.naver.com/mnews/hotissue/article/052/0001995729?type&#x3D;series&amp;cid&#x3D;2000862" class="ss_text_headline" data-clk="sera">&quot;낙동강 벨트 사수&quot; 영남 중진 차출 / 민주, 조국·송영길 신당도 연대?</a>
# 					<div class="ss_text_lede">총선을 앞두고 국민의힘에서는 영남 중진 의원들에 대한 희생을 요구가 이어지고 있습니다. 부산 5선 서병수, 경남 3선 김태호 의원에 이어 역시 3선인 조해진 의원에게도 험지 출마를 요청한 겁니다. 모두 민주당 의원들</div>
# 					<div class="ss_text_info">
# 						<div class="ss_text_press">YTN</div>
# 						<a href="https://n.news.naver.com/mnews/article/comment/052/0001995729" class="ss_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news052,0001995729" data-zero-allow="false" data-clk="sercmtcount"></a>
# 					</div>
# 				</div>
# 			</li>
# 			<li class="ss_item _LAZY_LOADING_WRAP">
# 				<div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# 					<div class="ss_thumb_inner">
# 						<a href="https://n.news.naver.com/mnews/hotissue/article/052/0001995252?type&#x3D;series&amp;cid&#x3D;2000862" class="ss_thumb_link" data-clk="sera">
# 							<img data-src="https://mimgnews.pstatic.net/image/origin/052/2024/02/07/1995252.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="" style="display:none;">
# 							<span class="ss_thumb_play">
# 								<em class="blind">동영상뉴스</em>
# 							</span>
# 						</a>
# 					</div>
# 				</div>
# 				<div class="ss_text">
# 					<a href="https://n.news.naver.com/mnews/hotissue/article/052/0001995252?type&#x3D;series&amp;cid&#x3D;2000862" class="ss_text_headline" data-clk="sera">이낙연, 오늘 광주로...제3지대 통합공관위 합류?</a>
# 					<div class="ss_text_lede">새로운 미래와의 공동창당을 준비하다 이탈한 이원욱, 조응천 의원이 제3지대 대통합을 위한 통합공천관리위원회를 구성하자고 제안했습니다. 이준석 대표가 이끄는 개혁신당, 이낙연 대표의 새로운미래, 금태섭 전 의원이 추진</div>
# 					<div class="ss_text_info">
# 						<div class="ss_text_press">YTN</div>
# 						<a href="https://n.news.naver.com/mnews/article/comment/052/0001995252" class="ss_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news052,0001995252" data-zero-allow="false" data-clk="sercmtcount"></a>
# 					</div>
# 				</div>
# 			</li>
# 		</ul>
# 	</div>
# </div>
# </div>
# 		<div class="r_group_comp ad_box _da_banner _PERSIST_HEIGHT is_border_none" data-persist="1_ad">
# 			<div id="nmap_c____1" class="ad_area _AD_WRAP" data-unitid="p_news_newslist" data-mobileonly="false" data-sync="false" data-article="false"></div>
# 		</div>
# <div class="section_latest">
# <div class="section_component as_section_article_list _PERSIST_CONTENT" data-persist="SECTION_ARTICLE_LIST">
# <div class="section_latest_article _CONTENT_LIST _PERSIST_META" data-sid="100" data-sid2="" data-cluid="" data-has-next="true" data-cursor-name="next" data-cursor="20240214143501" data-page-no="1" data-date="" data-template="SECTION_ARTICLE_LIST" data-nclk="airscont" data-persist="SECTION_ARTICLE_LIST_META" data-persist-meta-restore="true">
# <div class="section_article _TEMPLATE" data-template-id="SECTION_ARTICLE_LIST">
# 	<ul class="sa_list">
# 		<li class="sa_item _LAZY_LOADING_WRAP">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/001/0014505306" class="sa_thumb_link" data-clk="airscont" data-extra="{&quot;lk&quot;:{&quot;r&quot;:1,&quot;g&quot;:&quot;880000D8_000000000000000014505306&quot;},&quot;md&quot;:{&quot;v&quot;:&quot;news_sec_v2.0&quot;,&quot;s&quot;:&quot;MpYUQDbw3QSvJTDX&quot;}}" data-rank="1" data-gdid="880000D8_000000000000000014505306">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/001/2024/02/14/14505306.jpg?type&#x3D;ofullfill220_150" class="_LAZY_LOADING" width="110" height="75" alt="" onerror="this.outerHTML='<span class=&quot;noimage&quot;></span>'">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/001/0014505306" class="sa_text_title" data-clk="airscont" data-extra="{&quot;lk&quot;:{&quot;r&quot;:1,&quot;g&quot;:&quot;880000D8_000000000000000014505306&quot;},&quot;md&quot;:{&quot;v&quot;:&quot;news_sec_v2.0&quot;,&quot;s&quot;:&quot;MpYUQDbw3QSvJTDX&quot;}}" data-rank="1" data-gdid="880000D8_000000000000000014505306">
# 							<strong class="sa_text_strong">탈환이냐 수성이냐…&#x27;121석&#x27; 걸린 수도권 공천대전 스타트</strong>
# 						</a>
# 						<div class="sa_text_lede">與, 서울 19곳 &#x27;한강벨트 방점&#x27; 단수공천 발표…나머지 재배치·전략공천 주목 野, 일부 중진에 불출마 권유하며 &#x27;물갈이&#x27; 시동…이재명 &quot;새 술은 새 부대에&quot; 여야, 컷오프 인사 제3지대行 경계…개혁신당, 서울 종로</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">연합뉴스</div>
# 								<div class="sa_text_datetime is_recent">
# 									<b>9분전</b>
# 								</div>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="https://n.news.naver.com/mnews/article/comment/001/0014505306" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news001,0014505306" data-zero-allow="false"></a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _LAZY_LOADING_WRAP">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/018/0005673290" class="sa_thumb_link" data-clk="airscont" data-extra="{&quot;lk&quot;:{&quot;r&quot;:2,&quot;g&quot;:&quot;880000E7_000000000000000005673290&quot;},&quot;md&quot;:{&quot;v&quot;:&quot;news_sec_v2.0&quot;,&quot;s&quot;:&quot;MpYUQDbw3QSvJTDX&quot;}}" data-rank="2" data-gdid="880000E7_000000000000000005673290">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/018/2024/02/14/5673290.jpg?type&#x3D;ofullfill220_150" class="_LAZY_LOADING" width="110" height="75" alt="" onerror="this.outerHTML='<span class=&quot;noimage&quot;></span>'">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/018/0005673290" class="sa_text_title" data-clk="airscont" data-extra="{&quot;lk&quot;:{&quot;r&quot;:2,&quot;g&quot;:&quot;880000E7_000000000000000005673290&quot;},&quot;md&quot;:{&quot;v&quot;:&quot;news_sec_v2.0&quot;,&quot;s&quot;:&quot;MpYUQDbw3QSvJTDX&quot;}}" data-rank="2" data-gdid="880000E7_000000000000000005673290">
# 							<strong class="sa_text_strong">민주당 영입인재들, 지역구 찾아 삼만리</strong>
# 						</a>
# 						<div class="sa_text_lede">더불어민주당 영입인재들이 ‘험지’도 마다하지 않고 야심 차게 여의도 입성을 노리고 있다. 다만 일부 인재들은 당에서 지역구를 확정지어 주지 않아 답답한 상황이다. 지난 2일 민주당 콘서트 ‘사람과미래’에 참석한 이재</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">이데일리</div>
# 								<div class="sa_text_datetime is_recent">
# 									<b>13분전</b>
# 								</div>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="https://n.news.naver.com/mnews/article/comment/018/0005673290" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news018,0005673290" data-zero-allow="false"></a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _LAZY_LOADING_WRAP">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/047/0002422181" class="sa_thumb_link" data-clk="airscont" data-extra="{&quot;lk&quot;:{&quot;r&quot;:3,&quot;g&quot;:&quot;880000E3_000000000000000002422181&quot;},&quot;md&quot;:{&quot;v&quot;:&quot;news_sec_v2.0&quot;,&quot;s&quot;:&quot;MpYUQDbw3QSvJTDX&quot;}}" data-rank="3" data-gdid="880000E3_000000000000000002422181">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/047/2024/02/14/2422181.jpg?type&#x3D;ofullfill220_150" class="_LAZY_LOADING" width="110" height="75" alt="" onerror="this.outerHTML='<span class=&quot;noimage&quot;></span>'">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/047/0002422181" class="sa_text_title" data-clk="airscont" data-extra="{&quot;lk&quot;:{&quot;r&quot;:3,&quot;g&quot;:&quot;880000E3_000000000000000002422181&quot;},&quot;md&quot;:{&quot;v&quot;:&quot;news_sec_v2.0&quot;,&quot;s&quot;:&quot;MpYUQDbw3QSvJTDX&quot;}}" data-rank="3" data-gdid="880000E3_000000000000000002422181">
# 							<strong class="sa_text_strong">한동훈 &quot;과일을 홍익표가 먹었나? 이재명, 왜 정치하나?&quot;</strong>
# 						</a>
# 						<div class="sa_text_lede">백현동 로비 및 법인카드 유용 의혹 두고 맹공... 조국 향해 &quot;2심 실형 받고 민주당 2중대 호소&quot; ▲ 한동훈 국민의힘 비상대책위원장이 13일 서울 오전 서울 여의도 국민의힘 중앙당사에서 열린 비상대책위원회의에 참</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">오마이뉴스</div>
# 								<div class="sa_text_datetime is_recent">
# 									<b>21분전</b>
# 								</div>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="https://n.news.naver.com/mnews/article/comment/047/0002422181" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news047,0002422181" data-zero-allow="false"></a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _LAZY_LOADING_WRAP">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/422/0000644713" class="sa_thumb_link" data-clk="airscont" data-extra="{&quot;lk&quot;:{&quot;r&quot;:4,&quot;g&quot;:&quot;08138262_000000000000000000644713&quot;},&quot;md&quot;:{&quot;v&quot;:&quot;news_sec_v2.0&quot;,&quot;s&quot;:&quot;MpYUQDbw3QSvJTDX&quot;}}" data-rank="4" data-gdid="08138262_000000000000000000644713">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/422/2024/02/14/644713.jpg?type&#x3D;ofullfill220_150" class="_LAZY_LOADING" width="110" height="75" alt="" onerror="this.outerHTML='<span class=&quot;noimage&quot;></span>'">
# 								<span class="sa_thumb_play">
# 									<em class="blind">동영상뉴스</em>
# 								</span>
# 								<span class="sa_thumb_playtime">
# 									<em class="blind">재생시간</em>
# 									<span class="sa_thumb_playtime_text">44:05</span>
# 								</span>
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/422/0000644713" class="sa_text_title" data-clk="airscont" data-extra="{&quot;lk&quot;:{&quot;r&quot;:4,&quot;g&quot;:&quot;08138262_000000000000000000644713&quot;},&quot;md&quot;:{&quot;v&quot;:&quot;news_sec_v2.0&quot;,&quot;s&quot;:&quot;MpYUQDbw3QSvJTDX&quot;}}" data-rank="4" data-gdid="08138262_000000000000000000644713">
# 							<strong class="sa_text_strong">[뉴스1번지] 여, 25명 단수공천…민주, 하위 20% 통보 지연</strong>
# 						</a>
# 						<div class="sa_text_lede">오늘 정치권 이슈들은 서정욱, 조현삼 변호사와 자세히 짚어 보겠습니다. 어서 오세요. &lt;질문 1&gt; 국민의힘 공천관리위원회가 경선을 치르지 않는 단수 공천 대상자 25명을 발표했습니다. 정영환 공관위원장은 단수 공천 </div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">연합뉴스TV</div>
# 								<div class="sa_text_datetime is_recent">
# 									<b>22분전</b>
# 								</div>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="https://n.news.naver.com/mnews/article/comment/422/0000644713" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news422,0000644713" data-zero-allow="false"></a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _LAZY_LOADING_WRAP">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# ...
# 			</div>
# 		</a>
# 	</div>
# </div>
# <div class="col2_banner mobile_hidden is_hidden _LAZY_LOADING_WRAP" data-grid-template-column-aside="true">
# 	<div class="col2_banner_inner _LAZY_LOADING_ERROR_HIDE">
# 		<a href="http://news.naver.com/main/assembly/index.naver" class="col2_banner_link" data-clk="asidebanner2">
# 			<img data-src="https://imgnews.pstatic.net/image/upload/item/2021/01/08/173235779_%25B1%25B9%25C8%25B8%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA.png" alt="" width="300" height="80" class="_LAZY_LOADING">
# 			<div class="blind">
# 				<strong>내일을 여는 국민의 국회</strong>
# 				<p></p>
# 			</div>
# 		</a>
# 	</div>
# </div>
# <div class="col2_banner mobile_hidden is_hidden _LAZY_LOADING_WRAP" data-grid-template-column-aside="true">
# 	<div class="col2_banner_inner _LAZY_LOADING_ERROR_HIDE">
# 		<a href="https://media.naver.com/algorithm" class="col2_banner_link" data-clk="asidebanner3">
# 			<img data-src="https://imgnews.pstatic.net/image/upload/item/2023/07/06/183901500_banner_AI.png" alt="" width="300" height="80" class="_LAZY_LOADING">
# 			<div class="blind">
# 				<strong>알고리즘 안내</strong>
# 				<p></p>
# 			</div>
# 		</a>
# 	</div>
# </div>
# <div class="col2_banner mobile_hidden is_hidden _LAZY_LOADING_WRAP" data-grid-template-column-aside="true">
# 	<div class="col2_banner_inner _LAZY_LOADING_ERROR_HIDE">
# 		<a href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid&#x3D;omb" class="col2_banner_link" data-clk="asidebanner4">
# 			<img data-src="https://imgnews.pstatic.net/image/upload/item/2023/06/23/195350239_banner_24hours.png" alt="" width="300" height="80" class="_LAZY_LOADING">
# 			<div class="blind">
# 				<strong>뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요</strong>
# 				<p></p>
# 			</div>
# 		</a>
# 	</div>
# </div>
# 	<div class="rankingnews as_type_flat mobile_hidden is_hidden _FLICKING_WRAP _OFFICE_RANKING_ALL _PERSIST_META" data-persist="10_officeRankingAll" data-aggregation-start="" data-aggregation-end="" data-count="1" data-flicking-nclk="true" data-nclk-prefix="rig" data-flicking-disable="true" data-flicking-init-tab-index="" data-grid-template-column-aside="true">
# 		<div class="ra_head">
# 			<strong class="ra_title"><em class="ra_highlight"></em> 서비스 안내</strong>
# 			<a href="https://news.naver.com/main/ombudsman/index.naver" class="media_more" data-clk="rig.more"><span class="blind">더보기</span></a>
# 		</div>
#
# 		<div class="ra_area">
# 			<div class="flick" style="height:90px;">
# 				<div class="flick-container _FLICKING" style="height:90px; opacity:0;">
# 						<div class="flick-panel">
# 								<ul class="ranking_list _FLICKING_CONTENT" data-index="0" style="margin-top: 0;">
# 										<li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# 											<div class="rl_link_end">
# 												<div class="rl_content">
# 													<p class="rl_txt">고침 기사 모음</p>
# 												</div>
# 												<a href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid&#x3D;omb" class="rl_coverlink" data-clk="rig.text">
# 													<span class="blind">더보기</span>
# 												</a>
# 											</div>
# 										</li>
# 										<li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# 											<div class="rl_link_end">
# 												<div class="rl_content">
# 													<p class="rl_txt">정정·반론·추후 보도 기사 모음</p>
# 												</div>
# 												<a href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid&#x3D;omb" class="rl_coverlink" data-clk="rig.text">
# 													<span class="blind">더보기</span>
# 												</a>
# 											</div>
# 										</li>
# 										<li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# 											<div class="rl_link_end">
# 												<div class="rl_content">
# 													<p class="rl_txt">불공정 선거 보도 기사 모음</p>
# 												</div>
# 												<a href="https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid&#x3D;omb" class="rl_coverlink" data-clk="rig.text">
# 													<span class="blind">더보기</span>
# 												</a>
# 											</div>
# 										</li>
# 								</ul>
# 						</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# </div>
# 		<div class="outside_area _OUTSIDE_AREA">
# 			<div class="outside_area_inner _GRID_TEMPLATE_COLUMN_ASIDE _OUTSIDE_AREA_INNER"></div>
# 		</div>
# 		<aside class="main_aside _MAIN_ASIDE">
# 			<div class="main_aside_inner _MAIN_ASIDE_INNER">
# 			<h3 class="blind">구독</h3>
# 			<script type="x-tmpl-mustache" class="_LAZY_LOADING_IFRAME">
# 			<iframe class="_aside _GRID_TEMPLATE_ASIDE_IFRAME" src="https://news.naver.com/aside" data-allow-domain="https://news.naver.com" style="visibility: hidden;" frameborder="no" scrolling="no" width="100%"></iframe>
# 			</script>
# 			</div>
# 		</aside>
# 	</div>
# </div>
# <div class="media_end_tts_ticker _FADE_LAYER" id="_media_end_tts_ticker" style="display: none;">
# 	<p class="media_end_tts_ticker_text" style="display: block;">본문 듣기를 <em class="media_end_tts_ticker_point">종료</em>하였습니다.</p>
# </div>
# <div class="tomain_ticker _TOMAIN_RECOMMAND_LAYER _FADE_LAYER" style="display: none;">이 기사를 <em class="tomain_ticker_point">추천</em>했습니다.
# </div>
# <div class="tomain_ticker _TOMAIN_CANCEL_LAYER _FADE_LAYER" style="display: none;">추천을 <em class="tomain_ticker_point">취소</em>했습니다.
# </div><hr>
# 	<div class="u_ft _STICKY_FOOTER">
# 		<div class="u_ft_inner">
# 		<footer role="contentinfo">
# 			<p id="u_ftlkw" class="u_ftlkw">
# 					<a href="https://nid.naver.com/nidlogin.login?svctype=262144" class="u_ftlk _LINK" data-url="https://nid.naver.com/nidlogin.login?svctype=262144" data-pc-url="https://nid.naver.com/nidlogin.login" data-clk="fot.login">로그인</a>
# 				<a href="https://m.naver.com/services.html?f=svc.news" class="u_ftlk _LINK" data-url="https://m.naver.com/services.html?f=svc.news" data-pc-url="https://www.naver.com/more.html" data-clk="fot.sitemap">전체서비스</a>
# 			</p>
# 			<p class="u_cr">
# 				<span class="u_ftm">
# 					<span class="u_cri u_cri_v1"><a href="https://m.news.naver.com/ombudsman/index" class="u_cra _LINK" data-url="https://m.news.naver.com/ombudsman/index" data-pc-url="https://news.naver.com/main/ombudsman/index.naver">서비스안내</a></span>
# 					<span class="u_cri u_cri_v1"><a href="https://help.naver.com/alias/news/news_007.naver" class="u_cra" data-clk="fot.help">뉴스도움말</a></span>
# 					<span class="u_cri u_cri_v1"><a href="https://help.naver.com/alias/news/news_001.naver" class="u_cra" data-clk="fot.report">오류신고</a></span>
# 				</span>
# 				<span class="u_charge">
# 						<a href="https://m.news.naver.com/ombudsman/index?mode=rule&open=edit" class="u_charge_item _LINK" data-clk="fot.editor" data-url="https://m.news.naver.com/ombudsman/index?mode=rule&open=edit" data-pc-url="https://news.naver.com/main/ombudsman/edit.naver?mid=omb">기사배열 책임자 : 유봉석</a>
# 					<span class="u_charge_item">청소년 보호 책임자 : 이정규</span>
# 				</span>
# 				<span class="u_copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며, 이를 무단 <br>이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</span>
# 				<span class="u_cri"><span class="copymark">ⓒ</span> <a href="https://www.navercorp.com" class="u_cra_v1" data-clk="fot.navercorp">NAVER Corp.</a></span>
# 			</p>
# 		</footer>
# 		</div>
# 	</div>
# <a href="#" class="r_pg_top show _MOVE_TOP" id="goTop" data-clk="fot.top" style="display:none;">맨위로</a>
# <div id="_MY_FEED_CANCEL_MODAL" class="subscribe_dimmed is_hidden" style="display:none;">
# 	<div class="subscribe_alert">
# 		<p class="subscribe_alert_p _message _MY_FFED_CANCEL_MODAL_MESSAGE">
# 		</p>
# 		<div class="subscribe_alert_btns">
# 			<a href="#" class="subscribe_alert_btn _CANCEL_YES_BTN _TOGGLE" data-target="_MY_FEED_CANCEL_MODAL" data-classValue="is_hidden">예</a>
# 			<a href="#" class="subscribe_alert_btn _TOGGLE" data-target="_MY_FEED_CANCEL_MODAL" data-classValue="is_hidden">아니오</a>
# 		</div>
# 	</div>
# </div>
# <script type="x-tmpl-mustache" class="_MY_FEED_CANCEL_MODAL_TEMPLATE">
# 			{{#series}}
# 			<span class="subscribe_alert_p_ellipsis">{{value}}</span><br>연재 구독을 취소하시겠습니까? <span class="subscribe_alert_p_dsc">해당 연재는 <em>구독</em>에서 제외됩니다.</span>
# 			{{/series}}
# 			{{#journalist}}
# 			{{value}} 기자의 기사<br> 구독을 취소하시겠습니까? <span class="subscribe_alert_p_dsc"><em>구독</em>에서 해당 기자의 기사가 제외됩니다.</span>
# 			{{/journalist}}
# </script>
# <div id="_MODAL_LAYER_FOR_NOTIFICATION" class="modal is_hidden"></div>
# <div id="_MODAL_LAYER_FOR_NOTIFICATION_ALL" class="modal is_hidden"></div>
# <div id="_MODAL_LAYER_FOR_NOTIFICATION_OS" class="modal is_hidden"></div>
# <script type="x-tmpl-mustache" class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION">
# <div class="m_dimmed"></div>
# <div class="m_notification is_single">
# 	<strong class="mn_ok">구독완료</strong>
# 	{{#officeInfos}}
# 	<div class="mn_text">
# 		<h4 class="mn_h">{{officeName}} 뉴스를 <br> <span class="m_em">알림</span>으로 받아 보시겠습니까?</h4>
# 		<p class="mn_p">언론사의 주요 콘텐츠를 <br> 네이버에서 빠르게 확인할 수 있습니다.</p>
# 	</div>
# 	{{/officeInfos}}
# 	<div class="mn_btns">
# 		<button type="button" class="mn_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}no">닫기</button>
# 		<button type="button" class="mn_btn as_em _MODAL_LAYER_POSITIVE" data-clk="{{nclk}}yes">알림받기</button>
# 	</div>
# </div>
# </script>
# <script type="x-tmpl-mustache" class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION_ALL">
# <div class="m_dimmed"></div>
# <div class="m_notification">
# 	<strong class="mn_ok">구독완료</strong>
# 	<div class="mn_text">
# 		<h4 class="mn_h">언론사의 주요 뉴스를 <br> <span class="m_em">알림</span>으로 받아 보시겠습니까?</h4>
# 		<ul class="mn_list">
# 			{{#officeInfos}}
# 			<li class="mn_item">
# 				<div class="mn_head">
# 					<div class="mn_img">
# 						<img src="{{logo}}" alt="" onerror="this.outerHTML='<span class=&quot;no_image&quot;></span>'">
# 					</div>
# 					<div class="mn_name">{{officeName}}</div>
# 				</div>
# 				<div class="mn_body">
# 					<button type="button" class="mn_noti _ALL_OFFICES_NOTIFICATION_ITEM" data-oid="{{officeId}}" data-clk-add="notchnon" data-clk-remove="notchnoff">알림받기 사용함</button>
# 				</div>
# 			</li>
# 			{{/officeInfos}}
# 		</ul>
# 	</div>
# 	<div class="mn_btns">
# 		<button type="button" class="mn_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}no">닫기</button>
# 		<button type="button" class="mn_btn as_em _MODAL_LAYER_POSITIVE _CHANNEL_BANNER_ITEM_NOTICE_COMPLETE" data-clk="{{nclk}}yes">완료</button>
# 	</div>
# </div>
# </script>
# <script type="x-tmpl-mustache" class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION_OS">
# <div class="m_dimmed"></div>
# <div class="napp_notify_notice">
# 	<div class="napp_notify_info_area">
# 		<strong class="napp_notify_title">네이버 앱 푸시알림이 꺼져있어요.</strong>
# 		<div class="napp_notify_desc_box">
# 			<p class="napp_notify_desc1">네이버 앱 알림켜기 &gt; 알림탭 &gt; 알림허용</p>
# 			<p class="napp_notify_desc2">버튼을 눌러 앱 알림 설정을 켜주세요.</p>
# 		</div>
# 	</div>
# 	<div class="napp_notify_button_area">
# 		<button type="button" class="napp_notify_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}.osnotoff">닫기</button>
# 		<button type="button" class="napp_notify_btn highlight _MODAL_LAYER_POSITIVE _NAPP_NOTIFY_COMPLETE" data-clk="{{nclk}}.osnoton">네이버 앱 알림 켜기</button>
# 	</div>
# </div>
# </div>
# </script>
# <div id="_MODAL_COMMENT_FOLLOW_TUTORIAL" style="display: none;"></div>
# <script type="x-tmpl-mustache" class="_MODAL_COMMENT_FOLLOW_TUTORIAL_TEMPLATE">
# <div class="comment_follow_tutorial" role="dialog" aria-modal="true">
# 	<div class="comment_follow_tutorial_layer">
# 		<div class="comment_follow_tutorial_layer_dimmed"></div>
# 		<div class="comment_follow_tutorial_layer_container">
# 			<div class="comment_follow_tutorial_layer_content">
# 				<div class="comment_follow_tutorial_layer_item">
# 					<p class="{{className}}">{{text}}</p>
# 					<i class="comment_follow_tutorial_layer_closeicon"></i>
# 					<button type="button" class="comment_follow_tutorial_layer_close _MODAL_COMMENT_FOLLOW_TUTORIAL_CLOSE" data-clk="{{nclkPrefix}}tutclose">닫기</button>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# </div>
# </script>
# <div id="_TICKER_LAYER_FOR_NOTIFICATION" class="ticker" style="display: none;"></div>
# <script type="x-tmpl-mustache" class="_TICKER_LAYER_TEMPLATE_FOR_NOTIFICATION">
# {{#officeInfos}}
# <p class="t_inner"><em class="t_point">{{officeName}}</em> 언론사 알림이 설정되었습니다.</p>
# {{/officeInfos}}
# </script>
# <script src="https://static-nnews.pstatic.net/js/min/20240214/library.min.js"></script>
# <script src="https://static-nnews.pstatic.net/js/min/20240214/read.min.js"></script>
# <script>
# 	window.ntm = window.ntm || [];
# 	var ntmOption = {};
#
# 	if (ntmOption) {
#
# 		var section = {};
# 		var redirectSection = {"id":"100","name":"정치"};
#
# 		ntmOption["channelId"] = article.officeId;
#
# 		// 기타 또는 주요 섹션 이름
# 		var nilSendSectionName = "기타";
# 		var nilSendSectionId = "";
# 		if (/100|101|102|103|104|105|106|107/.test(section.id)) {
# 			nilSendSectionName = section.name;
# 			nilSendSectionId = section.id;
# 		}
#
# 		// 기사 타입
# 		var htArticleTypeName = { "0": "text", "1": "photo", "2": "tv" };
# 		var articleTypeName = htArticleTypeName[article.type] || "";
#
# 		ntmOption["hitType"] = "cv";
# 		ntmOption["eventCategory"] = "post_view";
# 		ntmOption["uri"] = "";
# 		ntmOption["gdid"] = article.gdid;
# 		ntmOption["dimension1"] = encodeURIComponent(nilSendSectionName);
# 		ntmOption["dimension4"] = articleTypeName;
# 		ntmOption["optional2"] = nilSendSectionId;
#
# 		var journalistIdList = [];
#
# 		// 기자 목록
# 		$("._JOURNALIST_CARD ._JOURNALIST_ID").each(function (index, object) {
# 			var $this = $(object);
# 			var journalistId = $this.attr("data-journalistId");
#
# 			if (journalistId && journalistIdList.indexOf(journalistId) === -1) {
# 				journalistIdList.push(journalistId);
# 			}
# 		});
#
# 		if (journalistIdList.length > 0) {
# 			ntmOption["dimension3"] = journalistIdList.join("___");
# 		}
#
# 		if (location.href.match(/ntype=RANKING/)) {
# 			ntmOption["dimension5"] = "y";
# 		}
#
# 		if (service.sports || service.newsType) {
# 			ntmOption["dimension2"] = article.sectionInfo.secondSection + "." + article.sectionInfo.thirdSection;
# 		}
#
# 		var seriesComponentId = $("._VALID_SERIES").attr("data-component-id");
# 		ntmOption["dimension6"] = seriesComponentId;
#
# 		if (/[?|&]type=breakingnews(&|$)/.test(location.href) === true) {
# 			if (/(m\.naver\.com)|(media\.naver\.com)|(news\.naver\.com\/?$)|(www\.naver\.com)/.test(document.referrer) === true) {
# 				ntmOption["dimension7"] = "breaking";
# 			}
# 		}
#
# 		var ntmLeaveOption = $.extend({}, ntmOption);
# 		ntmLeaveOption["hitType"] = "event";
# 		ntmLeaveOption["eventCategory"] = "action";
# 		ntmLeaveOption["eventAction"] = "leave";
#
# 		if (/\/article\/comment\//.test(location.href) == false) {
# 			if (window.addEventListener) {
# 				window.addEventListener("load", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 				}, false);
# 				window.addEventListener("onpagehide" in window ? "pagehide" : "beforeunload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 				}, false);
# 			} else if (window.attachEvent) {
# 				window.attachEvent("onload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 				});
# 				window.attachEvent("onpagehide" in window ? "onpagehide" : "onbeforeunload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 				});
# 			} else {
# 				var onUnloadEventName = "onpagehide" in window ? "onpagehide" : "onbeforeunload";
# 				var fnOnUnload = window[onUnloadEventName];
# 				window[onUnloadEventName] = function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 					if (fnOnUnload) {
# 						fnOnUnload();
# 					}
# 				};
#
# 				var fnOnload = window.onload;
# 				window.onload = function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 					if (fnOnload) {
# 						fnOnload();
# 					}
# 				};
# 			}
# 		}
# 	}
# </script>
# 		</div>
# 		<script>
# 			var eventType = "onpageshow" in window ? "pageshow" : "load";
# 			$(window).on(eventType, function() {
# 				lcs_do({ "sti": "news" });
#
# 				// ma 로그 전송
# 				var data = {
# 					"service": "news",
# 					"baseInfo": {
# 						"category": "섹션홈"
# 					},
# 					"extraInfo": {
# 						"sectionId": "100"
# 					}
# 				};
#
# 				if (typeof ma !== "undefined") {
# 					ma.init({
# 						api: "https://ma.news.naver.com/l",
# 						data: data
# 					});
# 				}
#
# 				if (window.matchMedia("(prefers-color-scheme)").media === "not all") {
# 					$("html").removeClass("DARK_THEME");
# 				}
# 			});
# 		</script>
# 	</body>
# </html>

# %%
# 한글만 출력
import re
texts = response.text
result = re.findall('[가-힣]+',texts)
' '.join(result)
# Out:
# '정치 네이버 뉴스 국회 행정 국방 외교 등 정치 분야 뉴스 제공 네이버 정치 네이버 뉴스 네이버 뉴스 네이버 뉴스 국회 행정 국방 외교 등 정치 분야 뉴스 제공 정치 홈 네이버 뉴스 광고적용 태그 추가 메인 메뉴로 바로가기 본문으로 바로가기 검색 뉴스 연예 스포츠 날씨 프리미엄 언론사별 정치 선택됨 경제 사회 생활 문화 과학 세계 랭킹 신문보기 오피니언 팩트체크 전체 언론사 전체 언론사 뉴스스탠드 뉴스스탠드 라이브러리 라이브러리 일 전체 언론사 전체 언론사 뉴스스탠드 뉴스스탠드 라이브러리 라이브러리 기사목록 정치 대통령실 국회 정당 북한 행정 국방 외교 정치일반 언론사 구독하기 네이버 프리미엄콘텐츠 안내 헤드라인 뉴스 헤드라인 뉴스와 각 기사묶음 타이틀은 기사 내용을 기반으로 자동 추출 됩니다 닫기 한미 정상 부부 가슴 울린 아이들 초 아리랑 앵콜곡 요청까지 분 미만으로 예정됐던 한미 정상 부부와 합창단 아이들 간 조우가 분을 넘어섰습니다 이들의 초 아리랑 을 감상한 조 바이든은 아이들이 너무 헤럴드경제 백악관에 또 와라 초 아리랑 으로 감동 전한 아이들 연합뉴스 초 행사가 분으로 한미정상 부부에 감동전한 한인 아이들 동아일보 백악관 또 와달라 한미정상 부부 멈추게한 아이들의 아리랑 개의 관련뉴스 더보기 동영상기사 년 성취 무너져 허망 발언 빠져 다큐 문재인입니다 보니 년간 이룬 성취가 무너졌다 는 취지의 문재인 전 대통령 발언은 빠졌고 그의 평산마을 전원 생활이 부각됐다 문 전 대통령의 퇴임 후 일상을 보여주는 중앙일보 서울신문 다큐 문재인입니다 첫 공개 년 간 성취 발언 빠진 이유는 다큐 문재인입니다 공개 문재인이라는 인간 탐구에 초점 조선일보 년 성취 무너져 허망 다큐 발언 실제 공개땐 빠졌다 개의 관련뉴스 더보기 워싱턴 선언 핵 공유 논란 대국민 사기극 성과 딴지 김태효 차장 사실상 핵 공유 핵 공유 아냐 온도 차 강선우 온도 차가 아니라 비교체험 극과 극 장동혁 과 더불어민주당이 찰떡 세계일보 국민의힘 북한 민주당 찰떡공조로 방미성과 깎아내리고 딴지 걸어 문화일보 방미 일정 마지막 날 한미군사동맹 핵동맹 전기 마련 빈손 외교 공방 매일경제 방미성과 두고 여야 공방 핵공유 정신승리 한미동맹 이간질 개의 관련뉴스 더보기 김여정 바이든에 늙은이 망언 에 못난 인간 워싱턴 선언 반발 북한 김정은 국무위원장의 친동생 김여정 노동당 부부장이 확장억제 강화 방안을 담은 한미 정상의 워싱턴 선언 채택에 강하게 반발하며 한미 정상을 싸잡아 헤럴드경제 김여정 막말 바이든 늙은이 망언 못난 인간 조선비즈 속보 김여정 바이든 정권 종말 발언에 늙은이의 망언 쉽게 넘길 수 없다 아시아경제 김여정 워싱턴 선언 에 미래없는 늙은이의 망언 개의 관련뉴스 더보기 아메리칸 파이 열창 후일담 바이든이 깜짝 요청 윤석열 대통령이 미국 백악관 국빈만찬에서 년대 빌보드 히트곡 아메리칸 파이 를 열창한 후일담이 공개됐다 이도운 대통령실 대변인은 일 현지시 국민일보 박지원 바이든 과 아메리칸 파이 듀엣 준비했다더라 후렴 불렀어야 박지원 전 국정원장은 윤석열 대통령과 조 바이든 미국 대통령이 전세계가 지켜보는 가운데 듀엣 으로 노래를 부르는 장면을 연출할 뻔했다고 주장했다 정치 뉴스 개의 관련뉴스 더보기 김기현 술 마시면 운전 못하게 음주운전 방지장치 의무화법 대표 발의 대표 취임 후 첫 대표발의 법안 의원 명 공동 발의로 참여 위반자 장치부착 조건부 운전면허 발급 김기현 국민의힘 대표는 일 음주운전 위반 전 매일경제 스쿨존 음주 인명사고 가해자 신상공개 줄줄이 법안 발의 어린이보호구역에서 음주 운전으로 인명 사고를 낸 경우 가해자의 신상을 공개하는 것을 주요 내용으로 한 법안이 잇따라 발의됐습니다 국민의힘 서정숙 의원은 오늘 일 스쿨존에서 음주 사망 사고를 낸 피의 개의 관련뉴스 더보기 이재명 박광온과 변화 통합 반드시 이룰 것 기사내용 요약 박광온 취임발언 인용하며 포부 전해 이재명 더불어민주당 대표는 일 박광온 원내대표와 함께 담대한 변화와 견고한 통합을 반드시 이뤄내겠 뉴시스 이재명 박광온과 총선 승리 는 역사적 소명 차이 크지 않아 이재명 더불어민주당 대표는 온건파 친이낙연계 로 분류되는 박광온 신임 원내대표 당선과 관련 박 원내대표와 함께 담대한 변화와 견고한 통합을 반드시 문화일보 개의 관련뉴스 더보기 박지원 바이든 과 듀엣 부르려했는데 바보 대통령실 박지원 전 국가정보원장이 윤석열 대통령과 조 바이든 미국 대통령이 전 세계가 지켜보는 가운데 듀엣 으로 노래를 부르는 장면을 연출할 수 있었는데 우리 헤럴드경제 박지원 바이든 과 듀엣 부르려 했다 바보 대통령실 비난 박지원 전 국가정보원장이 윤석열 대통령과 조 바이든 미국 대통령이 전 세계가 지켜보는 가운데 듀엣 으로 노래를 부르는 장면을 연출할 뻔했는데 우리 대 문화일보 개의 관련뉴스 더보기 한미 북핵대표 미사일 위협 대응 논의 이달에만 세 차례 김건 한반도평화교섭본부장이 지난 일 국제 학술 행사 참석을 위해 방한한 성 김 미국 대북특별대표와 한미 북핵수석대표 협의를 가졌다고 외교부가 일 뉴스 김건 본부장 성김과 학술행사 계기 서울서 한미북핵대표협의 이달에만 차례 대면 유선 협의 김건 외교부 한반도평화교섭본부장이 성김 미국 대북특별대표를 만나 한미 북핵수석대표 협의를 진행했다고 외교부가 일 밝혔 연합뉴스 개의 관련뉴스 더보기 하버드서 힘에 의한 현상 변경 결연한 연대로 대응해야 하버드대 연설 미국을 국빈 방문 중인 윤석열 대통령은 일 현지시각 다른 나라의 자유를 무시하는 힘에 의한 현상 변경 시도 에 국제사회는 용기 있 조선일보 하버드서 힘에 의한 현상 변경 시도 결연한 연대로 대응 전문 윤석열 대통령은 일 현지시간 다른 나라의 자유를 무시하는 힘에 의한 현상 변경 시도 에 국제사회는 용기 있고 결연한 연대로서 대응해야 한다 고 헤럴드경제 개의 관련뉴스 더보기 윤 대통령 미국서 귀국 기내 기자간담회는 또 안 해 윤석열 대통령이 박 일 동안의 미국 국빈 방문 일정을 마무리하고 일 오후 경기 성남 서울공항으로 귀국했다 윤 대통령과 김건희 여사가 탄 공군 호 한겨레 동영상기사 윤대통령 박 일 미국 국빈 방문 마치고 귀국 현장연결 윤석열 대통령이 박 일 간의 미국 국빈 방문 일정을 마치고 귀국했습니다 조금 전 서울공항 도착 영상이 들어와있는데요 현장 모습 함께 보시겠습니다 연합뉴스 개의 관련뉴스 더보기 이영 장관 보스턴 바이오클러스터에서 협력방안 논의 이영 중소벤처기업부 장관은 일 현지시간 한 미 클러스터 라운드 테이블 에 참석해 클러스터 혁신방안을 논의했다 이날 라운드 테이블에는 데이빗 브라 전자신문 보스턴 클러스터 핵심은 머니플로우 제도 정비해야 종합 기사내용 요약 과학기술 제조생산 양국에 윈 윈 전문가들 바이오테크 자본조달 중요해 서울 뉴윤석열 대통령은 일 현지시간 미국 보스 뉴시스 개의 관련뉴스 더보기 경계 중 이상 육군 사단 과학화 경계작전 기사내용 요약 년 과학화 경계시스템 도입 육군은 최전방 경계를 담당하고 있는 사단에서 과학화 경계시스템을 적용해 경계 작전을 펼치고 뉴시스 동영상기사 최전방 이상 무 과학화 시스템으로 철통 경계 남북이 가장 가깝게 총구를 맞대고 있는 곳 최북단 철책에는 시간 경계를 펴고 있는 최전방 사단이 있습니다 과학화 경계시스템으로 보다 정밀한 임무를 개의 관련뉴스 더보기 민주 핵 공유 대국민 사기극 아전인수식 정신 승리 더불어민주당은 한미 정상회담에서 불거진 핵 공유 논란 과 관련해 대통령실은 대국민 사기극을 벌인 데 대해 사죄하라 며 비판했습니다 민주당 강선우 대 민주 핵 공유 논란 에 대통령실 대국민 사기극 사죄하라 종합 기사내용 요약 없는 말 지어내 국민 혼란만 커져 눈 가리고 아웅 하는 데도 정도 있어 서울 뉴더불어민주당은 일 한미정상회담에서 채택된 워싱 뉴시스 개의 관련뉴스 더보기 국힘 간호법 등 강행처리 규탄 이번에도 거부권 지난 일 야당이 본회의에서 간호법 제정안과 방송법 개정안 쌍특검 억 클럽 특검 김건희 여사 특검 패스트트랙 신속처리안건 지정 안건 등을 강행 머니 동영상기사 간호법 특검법 여야 대치 귀국 후 거부권 주목 오늘 윤석열 대통령이 방미 일정을 마치고 복귀한 뒤 야당 주도로 통과된 간호법에 대한 어떤 입장을 내놓을지 주목됩니다 양곡관리법 개정 ...

# %%
import requests as rq
from bs4 import BeautifulSoup
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100'
r = rq.get(url,headers=headers)
# print(r)
html = r.text
bs = BeautifulSoup(html, 'lxml')
print(bs.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="정치 : 네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/section/100" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image"/>
# <meta content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="정치 : 네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
# <meta content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공" name="twitter:description"/>
# <title>정치 : 네이버 뉴스</title>
# <link href="https://static-nnews.pstatic.net/css/min/20240214/news.css" rel="stylesheet"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2023/08/21/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" rel="apple-touch-icon-precomposed" size="72x72"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" rel="apple-touch-icon-precomposed" size="96x96"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" rel="apple-touch-icon-precomposed" size="144x144"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" rel="apple-touch-icon-precomposed" size="192x192"/>
# <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script>
# <script>
# 			var g_ssc = nsc = "news.v3_sec";
# 			var g_default_area = "pol";
#
# 			var svr = "one-service-r-20240214-240214-160707-7b4b8d6fd-rfhvh";
# 			var nelo = {
# 				sampleNumber : 100,
# 				maxCount : 100,
# 				maxSendMessage : "로그 전송 최대치 도달"
# 			};
# 			var isGreendot = document.cookie.indexOf("MM_NEW=1") > -1;
# 			var isNewGreendot = document.cookie.indexOf("MM_NEW=2") > -1;
# 			var domain = "https://n.news.naver.com";
# 			var ajaxDomain = "";
# 			var newsDomain = "";
# 			var layoutName = "section_home";
# 			var layoutType = "section";
# 			var isAvailableDarkMode = false;
#
# 			var article = {
#
# 				officeId: "",
# 				articleId: "",
# 				sectionId : "",
# 				gdid: "",
# 				type: "",
# 				sectionInfo: {
# 					firstSection: "",
# 					secondSection: "",
# 					thirdSection: ""
# 				},
# 				title: document.title
# 			};
#
#
#
# 			var office = {
# 				isChannel: false,
# 				isPressHome: false,
# 				name : "",
# 				category : ""
# 			};
#
# 			var searchQuery = (function() {
# 				var referrerLink = document.createElement("a");
# 				var emptySearch = "";
#
# 				referrerLink.href = document.referrer || "";
#
# 				if (referrerLink.host.indexOf("search.naver.com") === -1) {
# 					return emptySearch;
# 				}
#
# 				return decodeURIComponent(
# 					(
# 						referrerLink.search.match(/(?:\?|&)query\=([^&]+)/) || [ null, emptySearch ]
# 					)[1].replace(/\+/g, " ")
# 				);
# 			})();
#
# 			var divIds = [];
# 			var syncDivIds = [];
# 			var syncDivIdsForNonArticle = [];
#
# 			var unitIds = [];
# 			var syncUnitIds = [];
# 			var syncUnitIdsForNonArticle = [];
#
# 			window.gladsdk = window.gladsdk || { cmd: [] };
# 			gladsdk.cmd.push(function() {
# 				gladsdk.setGlobalConfig({ enablePersistAd: true });
#
# 				var adInfoList = [];
#
# 				adInfoList.push({
# 					seq: 1,
# 					unitId: "p_news_newslist",
# 					sync: false,
# 					mobileOnly: false,
# 					article: false,
# 					directSalesPct: "",
# 					calp: false,
# 					hasSid1: true
# 				});
# 				adInfoList.push({
# 					seq: 2,
# 					unitId: "p_news_sidebox",
# 					sync: false,
# 					mobileOnly: false,
# 					article: false,
# 					directSalesPct: "",
# 					calp: true,
# 					hasSid1: false
# 				});
#
# 				var userAgent = navigator.userAgent.toLowerCase();
#
# 				for (var i = 0; i < adInfoList.length; i++) {
# 					var adInfo = adInfoList[i];
#
# 					var divId = "nmap_c_" + article.officeId + "_" + article.articleId + "_" + article.sectionId + "_" + adInfo.seq;
#
# 					var unitId = adInfo.unitId;
# 					var mobileOnly = adInfo.mobileOnly;
# 					var sync = adInfo.sync;
# 					var isArticle = adInfo.article;
# 					var directSalesPct = adInfo.directSalesPct;
# 					var calp = adInfo.calp;
# 					var hasSid1 = adInfo.hasSid1;
#
# 					if (mobileOnly == true) {
# 						if (/iphone|android|ipod/.test(userAgent) == false) {
# 							continue;
# 						}
# 					}
#
# 					var customParam = {
# 						sid1: article.sectionId,
# 						oid: article.officeId,
# 						gdid: article.gdid,
# 						pk: searchQuery,
# 						directSalesPct: directSalesPct
# 					};
#
# 					if (calp == true) {
# 						customParam.calp = "shome";
# 					}
# 					if (hasSid1 == true) {
# 						customParam.sid1 = "100";
# 					}
#
# 					var adUnit = {
# 						adUnitId: unitId,
# 						adSlotElementId: divId,
# 						customParam: customParam
# 					};
#
# 					if (sync == true) {
# 						syncUnitIds.push(unitId);
# 						syncDivIds.push(divId);
#
# 						if (isArticle == false) {
# 							syncUnitIdsForNonArticle.push(unitId);
# 							syncDivIdsForNonArticle.push(divId);
# 						}
# 					} else {
# 						unitIds.push(unitId);
# 						divIds.push(divId);
# 					}
#
# 					gladsdk.defineAdSlot(adUnit);
# 				}
#
# 			});
# 			window.__htExternalUrl = window.__htExternalUrl || {};
# 		</script>
# <script src="https://static-nnews.pstatic.net/js/min/20240214/common.min.js"></script>
# </head>
# <body class="n_news_mnews fs1 as_mp_layout as_section_home">
# <div class="end_container">
# <div class="u_skip"><a href="#ct">본문 바로가기</a></div>
# <header class="as_gnb_mnews as_type_section" role="banner">
# <div class="header_inner">
# <div class="Ngnb">
# <div class="Ngnb_inner">
# <div class="Ngnb_both">
# <div class="Ngnb_left">
# <span class="Ngnb_logo"><a class="Nlogo_link _LINK" data-clk="gnb.naver" data-pc-url="https://www.naver.com/" data-url="https://m.naver.com/" href="https://m.naver.com/"><span class="Nicon_logo">NAVER</span></a></span>
# <div class="Ngnb_service">
# <h1 class="Nservice_item"><a class="_LINK" data-clk="gnb.news" data-pc-url="https://news.naver.com/" data-url="https://m.news.naver.com" href="https://m.news.naver.com"><span class="Nicon_service">뉴스</span></a></h1>
# <span class="Nservice_subitem">
# <a class="_LINK" data-clk="gnb.entertain" data-pc-url="https://entertain.naver.com/home" data-url="https://m.entertain.naver.com" href="https://m.entertain.naver.com">
# <span class="Nicon_family Nicon_entertain">연예</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a class="_LINK" data-clk="gnb.sports" data-pc-url="https://sports.news.naver.com/index" data-url="https://m.sports.naver.com" href="https://m.sports.naver.com">
# <span class="Nicon_family Nicon_sports">스포츠</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a data-clk="gnb.weather" href="https://weather.naver.com">
# <span class="Nicon_family Nicon_weather">날씨</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a data-clk="gnb.premium" href="https://contents.premium.naver.com">
# <span class="Nicon_family Nicon_premium">프리미엄</span>
# </a>
# </span>
# </div>
# </div>
# <div class="Ngnb_right">
# <div class="Ngnb_group">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="Ngnb_search _SEARCH_WRAP is_hidden"></div>
# <div class="Ngnb_tool">
# <a class="Ntool_button _SEARCH_CONTENT_TOGGLE_BUTTON" data-clk="gnb.scho" href="javascript:;"><span class="Nicon_search">검색</span></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="Nlnb" data-scroll-fixed="true" id="_LNB_PARENT_WRAP" style="z-index:3000;">
# <div class="Nlnb_menu Ntype_scroll" id="_LNB_WRAP">
# <div class="Nlnb_menu_inner" id="_LNB">
# <ul class="Nlnb_menu_list" role="tablist">
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.press" href="https://news.naver.com/"><span class="Nitem_link_menu">언론사별</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM is_active" role="tab">
# <a class="Nitem_link" data-clk="lnb.pol" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="Nitem_link_menu">정치</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.eco" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="Nitem_link_menu">경제</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.soc" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="Nitem_link_menu">사회</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.lif" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="Nitem_link_menu">생활/문화</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.it" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="Nitem_link_menu">IT/과학</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.wor" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="Nitem_link_menu">세계</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.rank" href="https://news.naver.com/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="Nitem_link_menu">랭킹</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.paper" href="https://news.naver.com/newspaper/home"><span class="Nitem_link_menu">신문보기</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.opi" href="https://news.naver.com/main/opinion/home.naver"><span class="Nitem_link_menu">오피니언</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.tv" href="https://news.naver.com/main/tv/index.naver?mid=tvh"><span class="Nitem_link_menu">TV</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.fact" href="https://news.naver.com/main/factcheck/main.naver"><span class="Nitem_link_menu">팩트체크</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.algo" href="https://media.naver.com/algorithm"><span class="Nitem_link_menu">알고리즘 안내</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.correct" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb"><span class="Nitem_link_menu">정정보도 모음</span></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </header>
# <hr/>
# <script>
# 	var svt = "20240214165227.186";
# 	var timestamp = svt.substr(0, 8);
# 	var isLogin = false;
# 	var uhv = "";
#
# 	var service = {
# 		news: false,
# 		entertain: false,
# 		sports: false,
# 		mnews: true,
# 		newsType: true
# 	};
# 	var serviceName = "mnews";
#
# 	var envPhase = "production";
# 	var isProduction = true;
#
# 	var gnb_service = "news";
# 	var gnb_logout = encodeURIComponent(location.href);
# 	var gnb_template = "gnb_utf8";
# 	var gnb_brightness = 3;
# 	var gnb_item_hide_option = 128;
# </script>
# <div class="ct_wrap" id="ct_wrap">
# <div class="ct_lnb">
# <div class="ct_lnb_inner">
# <strong class="ct_lnb_date">02.14(수)</strong>
# <ul class="ct_lnb_side">
# <li class="ct_lnb_side_item">
# <a class="ct_lnb_side_link" data-clk="slb.allmedia" href="https://news.naver.com/main/officeList.naver">전체 언론사</a>
# </li>
# <li class="ct_lnb_side_item">
# <a class="ct_lnb_side_link" data-clk="slb.newsstand" href="https://newsstand.naver.com/" target="_blank">뉴스스탠드</a>
# </li>
# <li class="ct_lnb_side_item">
# <a class="ct_lnb_side_link" data-clk="slb.library" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank">라이브러리</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="ct_scroll_wrapper">
# <div class="column0">
# <div class="ct_snb">
# <h2 class="ct_snb_h2">
# <a class="ct_snb_h2_a" data-clk="lmn_pol.home" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100">정치</a>
# </h2>
# <ul class="ct_snb_nav">
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_pol.mnl" data-rank="1" href="/breakingnews/section/100/264">대통령실</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_pol.mnl" data-rank="2" href="/breakingnews/section/100/265">국회/정당</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_pol.mnl" data-rank="3" href="/breakingnews/section/100/268">북한</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_pol.mnl" data-rank="4" href="/breakingnews/section/100/266">행정</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_pol.mnl" data-rank="5" href="/breakingnews/section/100/267">국방/외교</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_pol.mnl" data-rank="6" href="/breakingnews/section/100/269">정치일반</a>
# </li>
# </ul>
# <div class="ct_snb_banner">
# <a data-clk="lmn_pol.pmb" data-rank="1" href="https://media.naver.com/algorithm">
# <img class="_LAZY_LOADING" data-src="https://imgnews.pstatic.net/image/upload/item/2023/07/10/184436024_banner_left.png" height="74" width="71"/>
# </a>
# </div>
# <div class="ct_snb_banner">
# <a data-clk="lmn_pol.pmb" data-rank="2" href="https://contents.premium.naver.com/">
# <img class="_LAZY_LOADING" data-src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" height="74" width="71"/>
# </a>
# </div>
# </div>
# </div>
# <div class="newsct_wrapper _GRID_TEMPLATE_COLUMN _STICKY_CONTENT" id="newsct" role="main"><div class="section_component as_section_headline _PERSIST_CONTENT" data-persist="2_sectionHeadline">
# <div class="section_article as_headline _TEMPLATE" data-template-id="SECTION_HEADLINE">
# <div class="sa_head">
# <span class="sa_head_inner">
# <a class="sa_head_link _TOGGLE" data-classvalue="is_hidden" data-clk="guide" data-target="_SECTION_HEADLINE_INFO_pwc6d" href="#">헤드라인 뉴스 <i class="sa_head_icon">안내</i></a>
# </span>
# <div class="sa_head_layer is_hidden" id="_SECTION_HEADLINE_INFO_pwc6d">
# <p class="sa_head_layer_p">각 헤드라인의 기사와 배열 순서는 개인화를 반영해 자동 추천되어 제공됩니다. 기사 수량이 표기된 기사 우측 하단의 파란색 아이콘을 클릭하면 기사묶음을 확인할 수 있고 기사묶음과 기사묶음 타이틀도 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.</p>
# <a class="sa_head_layer_go" href="https://media.naver.com/algorithm">알고리즘 자세히 보기</a>
# <div class="sa_head_layer_close">
# <button class="_TOGGLE" data-classvalue="is_hidden" data-target="_SECTION_HEADLINE_INFO_pwc6d" type="button">닫기</button>
# </div>
# </div>
# </div>
# <ul class="sa_list" id="_SECTION_HEADLINE_LIST_pwc6d">
# <li class="sa_item _SECTION_HEADLINE">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link" data-clk="clart" href="https://n.news.naver.com/mnews/article/437/0000379647">
# <img alt="" class="_LAZY_LOADING" data-src="https://mimgnews.pstatic.net/image/origin/437/2024/02/14/379647.jpg?type=nf220_150" height="75" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title" data-clk="clart" href="https://n.news.naver.com/mnews/article/437/0000379647">
# <strong class="sa_text_strong">윤 대통령 "외투기업, 우리 경제에 엄청난 기여...글로벌 스탠다드보다 유리한 환경 제공"</strong>
# </a>
# <div class="sa_text_lede">윤석열 대통령이 외국인 투자기업 대표들을 만난 자리에서 "글로벌 스탠더드보다 더 유리한 제도와 규제 환경을 제공하고, 여러 가지 세제와 지원을 여러분에게 아끼지 않아야 될 것 같다"고 말했습니다. 윤 대통령은 오늘(</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">JTBC</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news437,0000379647" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/437/0000379647" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202402141330_00000007/section/100?oid=437&amp;aid=0000379647">
# <span class="sa_text_cluster_num">31</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link" data-clk="clart" href="https://n.news.naver.com/mnews/article/057/0001799102">
# <img alt="" class="_LAZY_LOADING" data-src="https://mimgnews.pstatic.net/image/origin/057/2024/02/14/1799102.jpg?type=nf220_150" height="75" width="110"/>
# <span class="sa_thumb_play">
# <em class="blind">동영상뉴스</em>
# </span>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title" data-clk="clart" href="https://n.news.naver.com/mnews/article/057/0001799102">
# <strong class="sa_text_strong"> 99% 경선 / 이재명 전화 / 현역 확보전[뉴스 돋보기]</strong>
# </a>
# <div class="sa_text_lede">총선을 50여 일 앞두고 여야의 공천 작업이 본격화되는 모양새입니다. 정치부 유호정 기자와 더 이야기 나눠보겠습니다. 【 질문1 】 공천 면접이 진행되고 있는 국민의힘부터 짚어보죠. 면접 첫날부터 신경전이 팽팽한 지</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">MBN</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news057,0001799102" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/057/0001799102" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202402141040_00000002/section/100?oid=057&amp;aid=0001799102">
# <span class="sa_text_cluster_num">81</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link" data-clk="clart" href="https://n.news.naver.com/mnews/article/031/0000812247">
# <img alt="" class="_LAZY_LOADING" data-src="https://mimgnews.pstatic.net/image/origin/031/2024/02/13/812247.jpg?type=nf220_150" height="75" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title" data-clk="clart" href="https://n.news.naver.com/mnews/article/031/0000812247">
# <strong class="sa_text_strong">국힘 조해진 "경남 김해을 출마…당 '험지' 요청 수용"</strong>
# </a>
# <div class="sa_text_lede">조해진 국민의힘 의원(경남 밀양의령함안창녕)이 13일 여당 총선 험지인 경남 김해을 출마를 선언했다. 조 의원은 이날 국회 소통관에서 기자회견을 열고 "당(국민의힘)이 제가 김해을에 출마해 현역 더불어민주당 의원을 </div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">아이뉴스24</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news031,0000812247" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/031/0000812247" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202402120720_00000442/section/100?oid=031&amp;aid=0000812247">
# <span class="sa_text_cluster_num">26</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link" data-clk="clart" href="https://n.news.naver.com/mnews/article/008/0004998637">
# <img alt="" class="_LAZY_LOADING" data-src="https://mimgnews.pstatic.net/image/origin/008/2024/02/14/4998637.jpg?type=nf220_150" height="75" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title" data-clk="clart" href="https://n.news.naver.com/mnews/article/008/0004998637">
# <strong class="sa_text_strong">민주당 "정책자금 2배 늘려 이자 부담 낮출 것"…총선 공약 발표</strong>
# </a>
# <div class="sa_text_lede">더불어민주당이 총선을 앞두고 정책지원자금 확대와 에너지바우처 제도 신설 등 소상공인 맞춤형 공약을 내놨다. 고금리에 시름하는 영세 소상공인의 부담은 줄여주고 지역화폐와 온누리상품권 발행을 늘려 매출을 지원하겠다는 것</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">머니투데이</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news008,0004998637" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/008/0004998637" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202402140010_00000390/section/100?oid=008&amp;aid=0004998637">
# <span class="sa_text_cluster_num">20</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link" data-clk="clart" href="https://n.news.naver.com/mnews/article/032/0003278914">
# <img alt="" class="_LAZY_LOADING" data-src="https://mimgnews.pstatic.net/image/origin/032/2024/02/14/3278914.jpg?type=nf220_150" height="75" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title" data-clk="clart" href="https://n.news.naver.com/mnews/article/032/0003278914">
# <strong class="sa_text_strong">녹색정의당, 민주당 주도 비례정당 합류 찬반 갈등…배진교 원내대표 사퇴</strong>
# </a>
# <div class="sa_text_lede">더불어민주당이 주도하는 준위성정당(통합비례정당) 참여 여부를 놓고 녹색정의당 내부의 찬반 갈등이 커지고 있다. 배진교 녹색정의당 의원은 통합비례정당 참여를 촉구하며 14일 원내대표직을 사임했다. 배 의원은 이날 국회</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">경향신문</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news032,0003278914" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/032/0003278914" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202402141030_00000004/section/100?oid=032&amp;aid=0003278914">
# <span class="sa_text_cluster_num">23</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE is_blind">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link" data-clk="clart" href="https://n.news.naver.com/mnews/article/437/0000379545">
# <img alt="" class="_LAZY_LOADING" data-src="https://mimgnews.pstatic.net/image/origin/437/2024/02/14/379545.jpg?type=nf220_150" height="75" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title" data-clk="clart" href="https://n.news.naver.com/mnews/article/437/0000379545">
# <strong class="sa_text_strong">한미 국방부, 핵협의그룹 프레임워크 서명</strong>
# </a>
# <div class="sa_text_lede">한미 국방부가 핵협의그룹(NCG) 프레임 워크 문서에 서명했습니다. 오늘(14일) 국방부는 보도자료를 통해 NCG 공동대표인 조창래 국방부 국방정책실장과 비핀 나랑 미 국방부 우주정책 수석부차관보가 12일(현지시간)</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">JTBC</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news437,0000379545" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/437/0000379545" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202402140750_00000002/section/100?oid=437&amp;aid=0000379545">
# <span class="sa_text_cluster_num">27</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE is_blind">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link" data-clk="clart" href="https://n.news.naver.com/mnews/article/025/0003341238">
# <img alt="" class="_LAZY_LOADING" data-src="https://mimgnews.pstatic.net/image/origin/025/2024/02/14/3341238.jpg?type=nf220_150" height="75" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title" data-clk="clart" href="https://n.news.naver.com/mnews/article/025/0003341238">
# <strong class="sa_text_strong">[속보] 합참 "북한 순항미사일 여러발 동해서 포착"</strong>
# </a>
# <div class="sa_text_lede">북한이 14일 오전 동해상으로 순항미사일을 여러 발 발사했다고 합동참모본부가 밝혔다. 합참은 "우리 군은 오전 9시쯤 (강원도) 원산 동북방 해상에서 미상 순항미사일 수 발을 포착했으며, 한미 정보당국이 정밀분석 중</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">중앙일보</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news025,0003341238" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/025/0003341238" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202402141050_00000001/section/100?oid=025&amp;aid=0003341238">
# <span class="sa_text_cluster_num">47</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE is_blind">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link" data-clk="clart" href="https://n.news.naver.com/mnews/article/021/0002621261">
# <img alt="" class="_LAZY_LOADING" data-src="https://mimgnews.pstatic.net/image/origin/021/2024/02/14/2621261.jpg?type=nf220_150" height="75" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title" data-clk="clart" href="https://n.news.naver.com/mnews/article/021/0002621261">
# <strong class="sa_text_strong">총선 군산 출마 김의겸, 채이배와 후보 단일화…金 “공약 이어받을 것”</strong>
# </a>
# <div class="sa_text_lede">전북 군산시 선거구에 출마를 선언한 김의겸 더불어민주당 의원과 채이배 전 의원이 14일 단일화를 발표했다. 채 전 의원은 이날 김 의원과 전북특별자치도의회에서 기자회견을 열고 "김 의원과 단일화하겠다"며 "김 의원은</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">문화일보</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news021,0002621261" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/021/0002621261" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202402141150_00000026/section/100?oid=021&amp;aid=0002621261">
# <span class="sa_text_cluster_num">15</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE is_blind">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link" data-clk="clart" href="https://n.news.naver.com/mnews/article/023/0003816575">
# <img alt="" class="_LAZY_LOADING" data-src="https://mimgnews.pstatic.net/image/origin/023/2024/02/14/3816575.jpg?type=nf220_150" height="75" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title" data-clk="clart" href="https://n.news.naver.com/mnews/article/023/0003816575">
# <strong class="sa_text_strong">北, 불법 도박사이트 수천개 제작...한국 범죄 조직에 팔았다</strong>
# </a>
# <div class="sa_text_lede">불법 도박 사이트 수천 개를 제작해 한국의 범죄 조직에 팔아 넘긴 북한의 외화벌이 조직이 국가정보원에 적발됐다. 이들은 도박사이트를 제작해준 후 악성코드를 심어 회원정보 등을 탈취하기도 했다. 국정원은 14일 “15</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">조선일보</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news023,0003816575" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/023/0003816575" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202402141100_00000026/section/100?oid=023&amp;aid=0003816575">
# <span class="sa_text_cluster_num">33</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _SECTION_HEADLINE is_blind">
# <div class="sa_item_inner">
# <div class="sa_item_flex _LAZY_LOADING_WRAP">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link" data-clk="clart" href="https://n.news.naver.com/mnews/article/421/0007350191">
# <img alt="" class="_LAZY_LOADING" data-src="https://mimgnews.pstatic.net/image/origin/421/2024/02/14/7350191.jpg?type=nf220_150" height="75" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title" data-clk="clart" href="https://n.news.naver.com/mnews/article/421/0007350191">
# <strong class="sa_text_strong">"'북한판 지하드' 대비해야…테러·교란 주도 가능성"</strong>
# </a>
# <div class="sa_text_lede">김정은 북한 노동당 총비서가 남북관계를 '교전 중인 두 국가관계'라고 선언함에 따라 북한의 고정간첩이나 북한 동조세력이 남한 내 테러·교란을 주도하는 '북한판 지하드'(성전) 가능성에 대비해야 한다는 제언이 나왔다.</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">뉴스1</div>
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news421,0007350191" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/421/0007350191" style="display: none;"></a>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cluster" data-clk="clcou" href="/cluster/c_202402141040_00000620/section/100?oid=421&amp;aid=0007350191">
# <span class="sa_text_cluster_num">13</span>
# <span class="blind">개의 관련뉴스 더보기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="section_more _SECTION_HEADLINE_MORE_BUTTON_WRAP">
# <a class="section_more_inner _SECTION_HEADLINE_MORE_BUTTON" data-clk="clsmore" data-target="_SECTION_HEADLINE_LIST_pwc6d" href="#">헤드라인 더보기</a>
# </div>
# </div>
# <div class="section_component as_section_series _PERSIST_CONTENT" data-persist="3_sectionSeries">
# <div class="section_series _TEMPLATE" data-template-id="SECTION_SERIES">
# <div class="ss_head">
# <div class="ss_head_inner">
# <a class="ss_head_link" data-clk="sert" href="https://news.naver.com/hotissue/main?sid1=163&amp;cid=2000791">
# <span class="ss_head_go">연재보기</span>
# <h2 class="ss_head_topic">여론조사 동향</h2>
# </a>
# </div>
# </div>
# <div class="ss_body">
# <ul class="ss_list">
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link" data-clk="sera" href="https://n.news.naver.com/mnews/hotissue/article/002/0002319325?type=series&amp;cid=2000791">
# <img alt="" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/002/2024/02/14/2319325.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline" data-clk="sera" href="https://n.news.naver.com/mnews/hotissue/article/002/0002319325?type=series&amp;cid=2000791">"아쉽다"는 尹 입장 표명 '적절치 않다' 67% vs. '적절하다' 27%</a>
# <div class="ss_text_lede">윤석열 대통령이 김건희 영부인의 명품백 수수 논란에 대해 "아쉽다"는 입장을 표명한 것을 두고 '적절치 않았다'고 보는 국민이 3명 중 2명 꼴이라는 여론조사 결과가 나왔다. 13일 JTBC가 새로 편성한 &lt;여기(여</div>
# <div class="ss_text_info">
# <div class="ss_text_press">프레시안</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news002,0002319325" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/002/0002319325" style="display: none;"></a>
# </div>
# </div>
# </li>
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link" data-clk="sera" href="https://n.news.naver.com/mnews/hotissue/article/002/0002319094?type=series&amp;cid=2000791">
# <img alt="" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/002/2024/02/10/2319094.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline" data-clk="sera" href="https://n.news.naver.com/mnews/hotissue/article/002/0002319094?type=series&amp;cid=2000791">올해 총선에서 '정부 견제론 55%, '정부 지원론' 40%</a>
# <div class="ss_text_lede">4월 총선에서 '정부 견제론'이 정부 지원론'보다 더 높은 여론 지지를 받는 것으로 조사됐다. 9일 MBC가 코리아리서치에 의뢰한 여론조사 결과에 따르면 정부 견제를 위해 야당 후보가 많이 당선돼야 한다는 응답은 5</div>
# <div class="ss_text_info">
# <div class="ss_text_press">프레시안</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news002,0002319094" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/002/0002319094" style="display: none;"></a>
# </div>
# </div>
# </li>
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link" data-clk="sera" href="https://n.news.naver.com/mnews/hotissue/article/002/0002319018?type=series&amp;cid=2000791">
# <img alt="" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/002/2024/02/08/2319018.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline" data-clk="sera" href="https://n.news.naver.com/mnews/hotissue/article/002/0002319018?type=series&amp;cid=2000791">당정 지지도 동반상승…尹 국정 지지도, 6%P 오른 37%</a>
# <div class="ss_text_lede">국민의힘 37% vs 민주당 30%…정부·여당 지원 47% vs 견제 44% 윤석열 대통령의 국정 지지도가 2주 사이 6%P(포인트) 올랐다는 여론조사가 나왔다. 국민의힘 정당 지지율, 4.10 총선에서의 정부 지원</div>
# <div class="ss_text_info">
# <div class="ss_text_press">프레시안</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news002,0002319018" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/002/0002319018" style="display: none;"></a>
# </div>
# </div>
# </li>
# <li class="ss_item _LAZY_LOADING_WRAP">
# <div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ss_thumb_inner">
# <a class="ss_thumb_link" data-clk="sera" href="https://n.news.naver.com/mnews/hotissue/article/002/0002318743?type=series&amp;cid=2000791">
# <img alt="" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/002/2024/02/07/2318743.jpg?type=nf220_150" height="75" style="display:none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="ss_text">
# <a class="ss_text_headline" data-clk="sera" href="https://n.news.naver.com/mnews/hotissue/article/002/0002318743?type=series&amp;cid=2000791">'김건희 스캔들은 몰카 공작' 19% 불과…'대통령 해명·영부인 사과' 요구 70% 넘어</a>
# <div class="ss_text_lede">설 연휴를 앞두고 실시된 여론조사에서 '김건희 명품백 스캔들'과 관련해 윤석열 대통령의 해명과 김건희 영부인 사과가 필요하다는 여론이 70%를 넘어선 것으로 나타났다. 의뢰로 여론조사업체 엠브레인퍼블릭이 지난 4~5</div>
# <div class="ss_text_info">
# <div class="ss_text_press">프레시안</div>
# <a class="ss_text_cmt _COMMENT_COUNT_LIST" data-clk="sercmtcount" data-object-id="news002,0002318743" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/002/0002318743" style="display: none;"></a>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="r_group_comp ad_box _da_banner _PERSIST_HEIGHT is_border_none" data-persist="1_ad">
# <div class="ad_area _AD_WRAP" data-article="false" data-mobileonly="false" data-sync="false" data-unitid="p_news_newslist" id="nmap_c____1"></div>
# </div>
# <div class="section_latest">
# <div class="section_component as_section_article_list _PERSIST_CONTENT" data-persist="SECTION_ARTICLE_LIST">
# <div class="section_latest_article _CONTENT_LIST _PERSIST_META" data-cluid="" data-cursor="20240214143501" data-cursor-name="next" data-date="" data-has-next="true" data-nclk="airscont" data-page-no="1" data-persist="SECTION_ARTICLE_LIST_META" data-persist-meta-restore="true" data-sid="100" data-sid2="" data-template="SECTION_ARTICLE_LIST">
# <div class="section_article _TEMPLATE" data-template-id="SECTION_ARTICLE_LIST">
# <ul class="sa_list">
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link" data-clk="airscont" data-extra='{"lk":{"r":1,"g":"880000D8_000000000000000014505306"},"md":{"v":"news_sec_v2.0","s":"hdCTVlR9GbXdobYU"}}' data-gdid="880000D8_000000000000000014505306" data-rank="1" href="https://n.news.naver.com/mnews/article/001/0014505306">
# <img alt="" class="_LAZY_LOADING" data-src="https://mimgnews.pstatic.net/image/origin/001/2024/02/14/14505306.jpg?type=ofullfill220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title" data-clk="airscont" data-extra='{"lk":{"r":1,"g":"880000D8_000000000000000014505306"},"md":{"v":"news_sec_v2.0","s":"hdCTVlR9GbXdobYU"}}' data-gdid="880000D8_000000000000000014505306" data-rank="1" href="https://n.news.naver.com/mnews/article/001/0014505306">
# <strong class="sa_text_strong">탈환이냐 수성이냐…'121석' 걸린 수도권 공천대전 스타트</strong>
# </a>
# <div class="sa_text_lede">與, 서울 19곳 '한강벨트 방점' 단수공천 발표…나머지 재배치·전략공천 주목 野, 일부 중진에 불출마 권유하며 '물갈이' 시동…이재명 "새 술은 새 부대에" 여야, 컷오프 인사 제3지대行 경계…개혁신당, 서울 종로</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">연합뉴스</div>
# <div class="sa_text_datetime is_recent">
# <b>15분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news001,0014505306" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/001/0014505306" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link" data-clk="airscont" data-extra='{"lk":{"r":2,"g":"880000E7_000000000000000005673290"},"md":{"v":"news_sec_v2.0","s":"hdCTVlR9GbXdobYU"}}' data-gdid="880000E7_000000000000000005673290" data-rank="2" href="https://n.news.naver.com/mnews/article/018/0005673290">
# <img alt="" class="_LAZY_LOADING" data-src="https://mimgnews.pstatic.net/image/origin/018/2024/02/14/5673290.jpg?type=ofullfill220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title" data-clk="airscont" data-extra='{"lk":{"r":2,"g":"880000E7_000000000000000005673290"},"md":{"v":"news_sec_v2.0","s":"hdCTVlR9GbXdobYU"}}' data-gdid="880000E7_000000000000000005673290" data-rank="2" href="https://n.news.naver.com/mnews/article/018/0005673290">
# <strong class="sa_text_strong">민주당 영입인재들, 지역구 찾아 삼만리</strong>
# </a>
# <div class="sa_text_lede">더불어민주당 영입인재들이 ‘험지’도 마다하지 않고 야심 차게 여의도 입성을 노리고 있다. 다만 일부 인재들은 당에서 지역구를 확정지어 주지 않아 답답한 상황이다. 지난 2일 민주당 콘서트 ‘사람과미래’에 참석한 이재</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">이데일리</div>
# <div class="sa_text_datetime is_recent">
# <b>19분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news018,0005673290" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/018/0005673290" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link" data-clk="airscont" data-extra='{"lk":{"r":3,"g":"880000E3_000000000000000002422181"},"md":{"v":"news_sec_v2.0","s":"hdCTVlR9GbXdobYU"}}' data-gdid="880000E3_000000000000000002422181" data-rank="3" href="https://n.news.naver.com/mnews/article/047/0002422181">
# <img alt="" class="_LAZY_LOADING" data-src="https://mimgnews.pstatic.net/image/origin/047/2024/02/14/2422181.jpg?type=ofullfill220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title" data-clk="airscont" data-extra='{"lk":{"r":3,"g":"880000E3_000000000000000002422181"},"md":{"v":"news_sec_v2.0","s":"hdCTVlR9GbXdobYU"}}' data-gdid="880000E3_000000000000000002422181" data-rank="3" href="https://n.news.naver.com/mnews/article/047/0002422181">
# <strong class="sa_text_strong">한동훈 "과일을 홍익표가 먹었나? 이재명, 왜 정치하나?"</strong>
# </a>
# <div class="sa_text_lede">백현동 로비 및 법인카드 유용 의혹 두고 맹공... 조국 향해 "2심 실형 받고 민주당 2중대 호소" ▲ 한동훈 국민의힘 비상대책위원장이 13일 서울 오전 서울 여의도 국민의힘 중앙당사에서 열린 비상대책위원회의에 참</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">오마이뉴스</div>
# <div class="sa_text_datetime is_recent">
# <b>26분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news047,0002422181" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/047/0002422181" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link" data-clk="airscont" data-extra='{"lk":{"r":4,"g":"08138262_000000000000000000644713"},"md":{"v":"news_sec_v2.0","s":"hdCTVlR9GbXdobYU"}}' data-gdid="08138262_000000000000000000644713" data-rank="4" href="https://n.news.naver.com/mnews/article/422/0000644713">
# <img alt="" class="_LAZY_LOADING" data-src="https://mimgnews.pstatic.net/image/origin/422/2024/02/14/644713.jpg?type=ofullfill220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" width="110"/>
# <span class="sa_thumb_play">
# <em class="blind">동영상뉴스</em>
# </span>
# <span class="sa_thumb_playtime">
# <em class="blind">재생시간</em>
# <span class="sa_thumb_playtime_text">44:05</span>
# </span>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title" data-clk="airscont" data-extra='{"lk":{"r":4,"g":"08138262_000000000000000000644713"},"md":{"v":"news_sec_v2.0","s":"hdCTVlR9GbXdobYU"}}' data-gdid="08138262_000000000000000000644713" data-rank="4" href="https://n.news.naver.com/mnews/article/422/0000644713">
# <strong class="sa_text_strong">[뉴스1번지] 여, 25명 단수공천…민주, 하위 20% 통보 지연</strong>
# </a>
# <div class="sa_text_lede">오늘 정치권 이슈들은 서정욱, 조현삼 변호사와 자세히 짚어 보겠습니다. 어서 오세요. &lt;질문 1&gt; 국민의힘 공천관리위원회가 경선을 치르지 않는 단수 공천 대상자 25명을 발표했습니다. 정영환 공관위원장은 단수 공천 </div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">연합뉴스TV</div>
# <div class="sa_text_datetime is_recent">
# <b>27분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news422,0000644713" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/422/0000644713" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link" data-clk="airscont" data-extra='{"lk":{"r":5,"g":"880000E3_000000000000000002422180"},"md":{"v":"news_sec_v2.0","s":"hdCTVlR9GbXdobYU"}}' data-gdid="880000E3_000000000000000002422180" data-rank="5" href="https://n.news.naver.com/mnews/article/047/0002422180">
# <img alt="" class="_LAZY_LOADING" data-src="https://mimgnews.pstatic.net/image/origin/047/2024/02/14/2422180.jpg?type=ofullfill220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title" data-clk="airscont" data-extra='{"lk":{"r":5,"g":"880000E3_000000000000000002422180"},"md":{"v":"news_sec_v2.0","s":"hdCTVlR9GbXdobYU"}}' data-gdid="880000E3_000000000000000002422180" data-rank="5" href="https://n.news.naver.com/mnews/article/047/0002422180">
# <strong class="sa_text_strong">"지역도 모르면서..." 조해진 김해을 출마에 거센 반발</strong>
# </a>
# <div class="sa_text_lede">당원 반대로 김해시청 기자회견 못 열어... 국힘 예비후보들 "공정 경선", 민주당 "김해 무시" ▲ 국민의힘 조해진 의원이 13일 국회에서 22대 총선 김해(을) 출마 선언 기자회견 후 인사하고 있다. ⓒ 연합뉴스</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">오마이뉴스</div>
# <div class="sa_text_datetime is_recent">
# <b>29분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news047,0002422180" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/047/0002422180" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link" data-clk="airscont" data-extra='{"lk":{"r":6,"g":"88221sgg_000000000000000000066024"},"md":{"v":"news_sec_v2.0","s":"hdCTVlR9GbXdobYU"}}' data-gdid="88221sgg_000000000000000000066024" data-rank="6" href="https://n.news.naver.com/mnews/article/658/0000066024">
# <img alt="" class="_LAZY_LOADING" data-src="https://mimgnews.pstatic.net/image/origin/658/2024/02/14/66024.jpg?type=ofullfill220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title" data-clk="airscont" data-extra='{"lk":{"r":6,"g":"88221sgg_000000000000000000066024"},"md":{"v":"news_sec_v2.0","s":"hdCTVlR9GbXdobYU"}}' data-gdid="88221sgg_000000000000000000066024" data-rank="6" href="https://n.news.naver.com/mnews/article/658/0000066024">
# <strong class="sa_text_strong">낙동강 중진 차출 빈 자리 3곳 누가 채울까</strong>
# </a>
# <div class="sa_text_lede">국민의힘 중진들의 낙동강벨트 차출로 빠진 자리에 누구를 채울지 정치권의 관심이 집중되고 있다. 현역 국회의원 불출마 지역은 우선추천(전략공천) 조건이 된다는 점에서 당 안팎에서는 용산 출신이나 검사 출신 친윤 인사들</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">국제신문</div>
# <div class="sa_text_datetime is_recent">
# <b>29분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news658,0000066024" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/658/0000066024" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="section_article _TEMPLATE" data-template-id="SECTION_ARTICLE_LIST">
# <ul class="sa_list">
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link" data-clk="airscont" data-extra='{"lk":{"r":7,"g":"08138263_000000000000000007351265"},"md":{"v":"news_sec_v2.0","s":"hdCTVlR9GbXdobYU"}}' data-gdid="08138263_000000000000000007351265" data-rank="7" href="https://n.news.naver.com/mnews/article/421/0007351265">
# <img alt="" class="_LAZY_LOADING" data-src="https://mimgnews.pstatic.net/image/origin/421/2024/02/14/7351265.jpg?type=ofullfill220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title" data-clk="airscont" data-extra='{"lk":{"r":7,"g":"08138263_000000000000000007351265"},"md":{"v":"news_sec_v2.0","s":"hdCTVlR9GbXdobYU"}}' data-gdid="08138263_000000000000000007351265" data-rank="7" href="https://n.news.naver.com/mnews/article/421/0007351265">
# <strong class="sa_text_strong">'단수공천 제외' 현역 최재형·박성중·유경준 지역구 경선가나</strong>
# </a>
# <div class="sa_text_lede">국민의힘 서울 현역의원 중에는 권영세·배현진·조은희·태영호 의원이 단수 추천 후보자로 선정된 가운데 다른 서울 현역 의원들의 공천 여부에 관심이 쏠리고 있다. 공천관리위원회는 14일 오전 브리핑을 통해 면접이 진행된</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">뉴스1</div>
# <div class="sa_text_datetime is_recent">
# <b>31분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# ...
# <div class="col2_banner mobile_hidden is_hidden _LAZY_LOADING_WRAP" data-grid-template-column-aside="true">
# <div class="col2_banner_inner _LAZY_LOADING_ERROR_HIDE">
# <a class="col2_banner_link" data-clk="asidebanner1" href="https://media.naver.com/channel/settings">
# <img alt="" class="_LAZY_LOADING" data-src="https://imgnews.pstatic.net/image/upload/item/2018/11/27/174854048_PC_%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA_%25B1%25B8%25B5%25B6%25C8%25B0%25BC%25BA%25C8%25AD.png" height="80" width="300"/>
# <div class="blind">
# <strong>네이버 메인에서 바로 보는 언론사 편집뉴스 지금 바로 구독해보세요!</strong>
# <p></p>
# </div>
# </a>
# </div>
# </div>
# <div class="col2_banner mobile_hidden is_hidden _LAZY_LOADING_WRAP" data-grid-template-column-aside="true">
# <div class="col2_banner_inner _LAZY_LOADING_ERROR_HIDE">
# <a class="col2_banner_link" data-clk="asidebanner2" href="http://news.naver.com/main/assembly/index.naver">
# <img alt="" class="_LAZY_LOADING" data-src="https://imgnews.pstatic.net/image/upload/item/2021/01/08/173235779_%25B1%25B9%25C8%25B8%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA.png" height="80" width="300"/>
# <div class="blind">
# <strong>내일을 여는 국민의 국회</strong>
# <p></p>
# </div>
# </a>
# </div>
# </div>
# <div class="col2_banner mobile_hidden is_hidden _LAZY_LOADING_WRAP" data-grid-template-column-aside="true">
# <div class="col2_banner_inner _LAZY_LOADING_ERROR_HIDE">
# <a class="col2_banner_link" data-clk="asidebanner3" href="https://media.naver.com/algorithm">
# <img alt="" class="_LAZY_LOADING" data-src="https://imgnews.pstatic.net/image/upload/item/2023/07/06/183901500_banner_AI.png" height="80" width="300"/>
# <div class="blind">
# <strong>알고리즘 안내</strong>
# <p></p>
# </div>
# </a>
# </div>
# </div>
# <div class="col2_banner mobile_hidden is_hidden _LAZY_LOADING_WRAP" data-grid-template-column-aside="true">
# <div class="col2_banner_inner _LAZY_LOADING_ERROR_HIDE">
# <a class="col2_banner_link" data-clk="asidebanner4" href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb">
# <img alt="" class="_LAZY_LOADING" data-src="https://imgnews.pstatic.net/image/upload/item/2023/06/23/195350239_banner_24hours.png" height="80" width="300"/>
# <div class="blind">
# <strong>뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요</strong>
# <p></p>
# </div>
# </a>
# </div>
# </div>
# <div class="rankingnews as_type_flat mobile_hidden is_hidden _FLICKING_WRAP _OFFICE_RANKING_ALL _PERSIST_META" data-aggregation-end="" data-aggregation-start="" data-count="1" data-flicking-disable="true" data-flicking-init-tab-index="" data-flicking-nclk="true" data-grid-template-column-aside="true" data-nclk-prefix="rig" data-persist="10_officeRankingAll">
# <div class="ra_head">
# <strong class="ra_title"><em class="ra_highlight"></em> 서비스 안내</strong>
# <a class="media_more" data-clk="rig.more" href="https://news.naver.com/main/ombudsman/index.naver"><span class="blind">더보기</span></a>
# </div>
# <div class="ra_area">
# <div class="flick" style="height:90px;">
# <div class="flick-container _FLICKING" style="height:90px; opacity:0;">
# <div class="flick-panel">
# <ul class="ranking_list _FLICKING_CONTENT" data-index="0" style="margin-top: 0;">
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <div class="rl_link_end">
# <div class="rl_content">
# <p class="rl_txt">고침 기사 모음</p>
# </div>
# <a class="rl_coverlink" data-clk="rig.text" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb">
# <span class="blind">더보기</span>
# </a>
# </div>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <div class="rl_link_end">
# <div class="rl_content">
# <p class="rl_txt">정정·반론·추후 보도 기사 모음</p>
# </div>
# <a class="rl_coverlink" data-clk="rig.text" href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb">
# <span class="blind">더보기</span>
# </a>
# </div>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <div class="rl_link_end">
# <div class="rl_content">
# <p class="rl_txt">불공정 선거 보도 기사 모음</p>
# </div>
# <a class="rl_coverlink" data-clk="rig.text" href="https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb">
# <span class="blind">더보기</span>
# </a>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="outside_area _OUTSIDE_AREA">
# <div class="outside_area_inner _GRID_TEMPLATE_COLUMN_ASIDE _OUTSIDE_AREA_INNER"></div>
# </div>
# <aside class="main_aside _MAIN_ASIDE">
# <div class="main_aside_inner _MAIN_ASIDE_INNER">
# <h3 class="blind">구독</h3>
# <script class="_LAZY_LOADING_IFRAME" type="x-tmpl-mustache">
# 			<iframe class="_aside _GRID_TEMPLATE_ASIDE_IFRAME" src="https://news.naver.com/aside" data-allow-domain="https://news.naver.com" style="visibility: hidden;" frameborder="no" scrolling="no" width="100%"></iframe>
# 			</script>
# </div>
# </aside>
# </div>
# </div>
# <div class="media_end_tts_ticker _FADE_LAYER" id="_media_end_tts_ticker" style="display: none;">
# <p class="media_end_tts_ticker_text" style="display: block;">본문 듣기를 <em class="media_end_tts_ticker_point">종료</em>하였습니다.</p>
# </div>
# <div class="tomain_ticker _TOMAIN_RECOMMAND_LAYER _FADE_LAYER" style="display: none;">이 기사를 <em class="tomain_ticker_point">추천</em>했습니다.
# </div>
# <div class="tomain_ticker _TOMAIN_CANCEL_LAYER _FADE_LAYER" style="display: none;">추천을 <em class="tomain_ticker_point">취소</em>했습니다.
# </div><hr/>
# <div class="u_ft _STICKY_FOOTER">
# <div class="u_ft_inner">
# <footer role="contentinfo">
# <p class="u_ftlkw" id="u_ftlkw">
# <a class="u_ftlk _LINK" data-clk="fot.login" data-pc-url="https://nid.naver.com/nidlogin.login" data-url="https://nid.naver.com/nidlogin.login?svctype=262144" href="https://nid.naver.com/nidlogin.login?svctype=262144">로그인</a>
# <a class="u_ftlk _LINK" data-clk="fot.sitemap" data-pc-url="https://www.naver.com/more.html" data-url="https://m.naver.com/services.html?f=svc.news" href="https://m.naver.com/services.html?f=svc.news">전체서비스</a>
# </p>
# <p class="u_cr">
# <span class="u_ftm">
# <span class="u_cri u_cri_v1"><a class="u_cra _LINK" data-pc-url="https://news.naver.com/main/ombudsman/index.naver" data-url="https://m.news.naver.com/ombudsman/index" href="https://m.news.naver.com/ombudsman/index">서비스안내</a></span>
# <span class="u_cri u_cri_v1"><a class="u_cra" data-clk="fot.help" href="https://help.naver.com/alias/news/news_007.naver">뉴스도움말</a></span>
# <span class="u_cri u_cri_v1"><a class="u_cra" data-clk="fot.report" href="https://help.naver.com/alias/news/news_001.naver">오류신고</a></span>
# </span>
# <span class="u_charge">
# <a class="u_charge_item _LINK" data-clk="fot.editor" data-pc-url="https://news.naver.com/main/ombudsman/edit.naver?mid=omb" data-url="https://m.news.naver.com/ombudsman/index?mode=rule&amp;open=edit" href="https://m.news.naver.com/ombudsman/index?mode=rule&amp;open=edit">기사배열 책임자 : 유봉석</a>
# <span class="u_charge_item">청소년 보호 책임자 : 이정규</span>
# </span>
# <span class="u_copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며, 이를 무단 <br/>이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</span>
# <span class="u_cri"><span class="copymark">ⓒ</span> <a class="u_cra_v1" data-clk="fot.navercorp" href="https://www.navercorp.com">NAVER Corp.</a></span>
# </p>
# </footer>
# </div>
# </div>
# <a class="r_pg_top show _MOVE_TOP" data-clk="fot.top" href="#" id="goTop" style="display:none;">맨위로</a>
# <div class="subscribe_dimmed is_hidden" id="_MY_FEED_CANCEL_MODAL" style="display:none;">
# <div class="subscribe_alert">
# <p class="subscribe_alert_p _message _MY_FFED_CANCEL_MODAL_MESSAGE">
# </p>
# <div class="subscribe_alert_btns">
# <a class="subscribe_alert_btn _CANCEL_YES_BTN _TOGGLE" data-classvalue="is_hidden" data-target="_MY_FEED_CANCEL_MODAL" href="#">예</a>
# <a class="subscribe_alert_btn _TOGGLE" data-classvalue="is_hidden" data-target="_MY_FEED_CANCEL_MODAL" href="#">아니오</a>
# </div>
# </div>
# </div>
# <script class="_MY_FEED_CANCEL_MODAL_TEMPLATE" type="x-tmpl-mustache">
# 			{{#series}}
# 			<span class="subscribe_alert_p_ellipsis">{{value}}</span><br>연재 구독을 취소하시겠습니까? <span class="subscribe_alert_p_dsc">해당 연재는 <em>구독</em>에서 제외됩니다.</span>
# 			{{/series}}
# 			{{#journalist}}
# 			{{value}} 기자의 기사<br> 구독을 취소하시겠습니까? <span class="subscribe_alert_p_dsc"><em>구독</em>에서 해당 기자의 기사가 제외됩니다.</span>
# 			{{/journalist}}
# </script>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION"></div>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION_ALL"></div>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION_OS"></div>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="m_notification is_single">
# 	<strong class="mn_ok">구독완료</strong>
# 	{{#officeInfos}}
# 	<div class="mn_text">
# 		<h4 class="mn_h">{{officeName}} 뉴스를 <br> <span class="m_em">알림</span>으로 받아 보시겠습니까?</h4>
# 		<p class="mn_p">언론사의 주요 콘텐츠를 <br> 네이버에서 빠르게 확인할 수 있습니다.</p>
# 	</div>
# 	{{/officeInfos}}
# 	<div class="mn_btns">
# 		<button type="button" class="mn_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}no">닫기</button>
# 		<button type="button" class="mn_btn as_em _MODAL_LAYER_POSITIVE" data-clk="{{nclk}}yes">알림받기</button>
# 	</div>
# </div>
# </script>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION_ALL" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="m_notification">
# 	<strong class="mn_ok">구독완료</strong>
# 	<div class="mn_text">
# 		<h4 class="mn_h">언론사의 주요 뉴스를 <br> <span class="m_em">알림</span>으로 받아 보시겠습니까?</h4>
# 		<ul class="mn_list">
# 			{{#officeInfos}}
# 			<li class="mn_item">
# 				<div class="mn_head">
# 					<div class="mn_img">
# 						<img src="{{logo}}" alt="" onerror="this.outerHTML='<span class=&quot;no_image&quot;></span>'">
# 					</div>
# 					<div class="mn_name">{{officeName}}</div>
# 				</div>
# 				<div class="mn_body">
# 					<button type="button" class="mn_noti _ALL_OFFICES_NOTIFICATION_ITEM" data-oid="{{officeId}}" data-clk-add="notchnon" data-clk-remove="notchnoff">알림받기 사용함</button>
# 				</div>
# 			</li>
# 			{{/officeInfos}}
# 		</ul>
# 	</div>
# 	<div class="mn_btns">
# 		<button type="button" class="mn_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}no">닫기</button>
# 		<button type="button" class="mn_btn as_em _MODAL_LAYER_POSITIVE _CHANNEL_BANNER_ITEM_NOTICE_COMPLETE" data-clk="{{nclk}}yes">완료</button>
# 	</div>
# </div>
# </script>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION_OS" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="napp_notify_notice">
# 	<div class="napp_notify_info_area">
# 		<strong class="napp_notify_title">네이버 앱 푸시알림이 꺼져있어요.</strong>
# 		<div class="napp_notify_desc_box">
# 			<p class="napp_notify_desc1">네이버 앱 알림켜기 &gt; 알림탭 &gt; 알림허용</p>
# 			<p class="napp_notify_desc2">버튼을 눌러 앱 알림 설정을 켜주세요.</p>
# 		</div>
# 	</div>
# 	<div class="napp_notify_button_area">
# 		<button type="button" class="napp_notify_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}.osnotoff">닫기</button>
# 		<button type="button" class="napp_notify_btn highlight _MODAL_LAYER_POSITIVE _NAPP_NOTIFY_COMPLETE" data-clk="{{nclk}}.osnoton">네이버 앱 알림 켜기</button>
# 	</div>
# </div>
# </div>
# </script>
# <div id="_MODAL_COMMENT_FOLLOW_TUTORIAL" style="display: none;"></div>
# <script class="_MODAL_COMMENT_FOLLOW_TUTORIAL_TEMPLATE" type="x-tmpl-mustache">
# <div class="comment_follow_tutorial" role="dialog" aria-modal="true">
# 	<div class="comment_follow_tutorial_layer">
# 		<div class="comment_follow_tutorial_layer_dimmed"></div>
# 		<div class="comment_follow_tutorial_layer_container">
# 			<div class="comment_follow_tutorial_layer_content">
# 				<div class="comment_follow_tutorial_layer_item">
# 					<p class="{{className}}">{{text}}</p>
# 					<i class="comment_follow_tutorial_layer_closeicon"></i>
# 					<button type="button" class="comment_follow_tutorial_layer_close _MODAL_COMMENT_FOLLOW_TUTORIAL_CLOSE" data-clk="{{nclkPrefix}}tutclose">닫기</button>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# </div>
# </script>
# <div class="ticker" id="_TICKER_LAYER_FOR_NOTIFICATION" style="display: none;"></div>
# <script class="_TICKER_LAYER_TEMPLATE_FOR_NOTIFICATION" type="x-tmpl-mustache">
# {{#officeInfos}}
# <p class="t_inner"><em class="t_point">{{officeName}}</em> 언론사 알림이 설정되었습니다.</p>
# {{/officeInfos}}
# </script>
# <script src="https://static-nnews.pstatic.net/js/min/20240214/library.min.js"></script>
# <script src="https://static-nnews.pstatic.net/js/min/20240214/read.min.js"></script>
# <script>
# 	window.ntm = window.ntm || [];
# 	var ntmOption = {};
#
# 	if (ntmOption) {
#
# 		var section = {};
# 		var redirectSection = {"id":"100","name":"정치"};
#
# 		ntmOption["channelId"] = article.officeId;
#
# 		// 기타 또는 주요 섹션 이름
# 		var nilSendSectionName = "기타";
# 		var nilSendSectionId = "";
# 		if (/100|101|102|103|104|105|106|107/.test(section.id)) {
# 			nilSendSectionName = section.name;
# 			nilSendSectionId = section.id;
# 		}
#
# 		// 기사 타입
# 		var htArticleTypeName = { "0": "text", "1": "photo", "2": "tv" };
# 		var articleTypeName = htArticleTypeName[article.type] || "";
#
# 		ntmOption["hitType"] = "cv";
# 		ntmOption["eventCategory"] = "post_view";
# 		ntmOption["uri"] = "";
# 		ntmOption["gdid"] = article.gdid;
# 		ntmOption["dimension1"] = encodeURIComponent(nilSendSectionName);
# 		ntmOption["dimension4"] = articleTypeName;
# 		ntmOption["optional2"] = nilSendSectionId;
#
# 		var journalistIdList = [];
#
# 		// 기자 목록
# 		$("._JOURNALIST_CARD ._JOURNALIST_ID").each(function (index, object) {
# 			var $this = $(object);
# 			var journalistId = $this.attr("data-journalistId");
#
# 			if (journalistId && journalistIdList.indexOf(journalistId) === -1) {
# 				journalistIdList.push(journalistId);
# 			}
# 		});
#
# 		if (journalistIdList.length > 0) {
# 			ntmOption["dimension3"] = journalistIdList.join("___");
# 		}
#
# 		if (location.href.match(/ntype=RANKING/)) {
# 			ntmOption["dimension5"] = "y";
# 		}
#
# 		if (service.sports || service.newsType) {
# 			ntmOption["dimension2"] = article.sectionInfo.secondSection + "." + article.sectionInfo.thirdSection;
# 		}
#
# 		var seriesComponentId = $("._VALID_SERIES").attr("data-component-id");
# 		ntmOption["dimension6"] = seriesComponentId;
#
# 		if (/[?|&]type=breakingnews(&|$)/.test(location.href) === true) {
# 			if (/(m\.naver\.com)|(media\.naver\.com)|(news\.naver\.com\/?$)|(www\.naver\.com)/.test(document.referrer) === true) {
# 				ntmOption["dimension7"] = "breaking";
# 			}
# 		}
#
# 		var ntmLeaveOption = $.extend({}, ntmOption);
# 		ntmLeaveOption["hitType"] = "event";
# 		ntmLeaveOption["eventCategory"] = "action";
# 		ntmLeaveOption["eventAction"] = "leave";
#
# 		if (/\/article\/comment\//.test(location.href) == false) {
# 			if (window.addEventListener) {
# 				window.addEventListener("load", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 				}, false);
# 				window.addEventListener("onpagehide" in window ? "pagehide" : "beforeunload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 				}, false);
# 			} else if (window.attachEvent) {
# 				window.attachEvent("onload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 				});
# 				window.attachEvent("onpagehide" in window ? "onpagehide" : "onbeforeunload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 				});
# 			} else {
# 				var onUnloadEventName = "onpagehide" in window ? "onpagehide" : "onbeforeunload";
# 				var fnOnUnload = window[onUnloadEventName];
# 				window[onUnloadEventName] = function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 					if (fnOnUnload) {
# 						fnOnUnload();
# 					}
# 				};
#
# 				var fnOnload = window.onload;
# 				window.onload = function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 					if (fnOnload) {
# 						fnOnload();
# 					}
# 				};
# 			}
# 		}
# 	}
# </script>
# </div>
# <script>
# 			var eventType = "onpageshow" in window ? "pageshow" : "load";
# 			$(window).on(eventType, function() {
# 				lcs_do({ "sti": "news" });
#
# 				// ma 로그 전송
# 				var data = {
# 					"service": "news",
# 					"baseInfo": {
# 						"category": "섹션홈"
# 					},
# 					"extraInfo": {
# 						"sectionId": "100"
# 					}
# 				};
#
# 				if (typeof ma !== "undefined") {
# 					ma.init({
# 						api: "https://ma.news.naver.com/l",
# 						data: data
# 					});
# 				}
#
# 				if (window.matchMedia("(prefers-color-scheme)").media === "not all") {
# 					$("html").removeClass("DARK_THEME");
# 				}
# 			});
# 		</script>
# </body>
# </html>
# >

# %%
# bs.find('div')
# bs.find('div',id=True)
bs.find('div', id='header')

# %%
import requests as rq
from bs4 import BeautifulSoup
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100'
r = rq.get(url,headers=headers)
# print(r)
html = r.text
bs = BeautifulSoup(html, 'lxml')
# print(bs.find('div',id=True))
bs.find('div',id=True).find('a').text
# Out:
# '메인 메뉴로 바로가기'

# %%
lists = bs.find('div',id=True).find_all('a')
for i in lists:
    print(i.text)
# Out:
# 메인 메뉴로 바로가기
# 본문으로 바로가기
# 검색
# NAVER
# 뉴스
# TV연예
# 스포츠
# 날씨
# 프리미엄
# 언론사별
# 정치 선택됨
# 경제
# 사회
# 생활/문화
# IT/과학
# 세계
# 랭킹
# 신문보기
# 오피니언
# TV
# 팩트체크
# 전체 언론사
# 뉴스스탠드
# 라이브러리
# 전체 언론사
# 뉴스스탠드
# 라이브러리
# 정치
# 대통령실
# 국회/정당
# 북한
# 행정
# 국방/외교
# 정치일반
#
#
# 안내헤드라인 뉴스
#
#
#
# 김기현, '음주운전 방지 장치 부착 의무화' 법안 내일 대표 발의
# '후~' 불어야 시동…김기현 '음주운전 방지장치' 법안 내일 발의
# 3번째 음주운전…중앙선 넘어 트럭 들이받았지만 '집행유예'
# '스쿨존 음주운전' 엄벌…"안전시설 설치부터"
# 40개의 관련뉴스 더보기
#
#
#
# 민주당 "尹대통령 방미, 대국민 사기 외교"
# 민주당 “尹 방미, 대국민 사기 외교…텅빈 쇼핑백”
# 민주 "尹 방미, '빈손' 넘어 '사기' 외교…경제 사안 해결 없어"
# "무한·영원한 번영" "텅 빈 쇼핑백"‥여야, 국빈방미 극과극 평가
# 24개의 관련뉴스 더보기
#
#
#
# 한·미정상회담 끝나자 ‘비싼대가 치를 것’ 위협한 북한, 군사 행동 수위 높이나?
# 北, ‘워싱턴 선언’에 핵 선제타격 위협…대형도발 강행하나
# 北, 연일 ‘워싱턴 선언’ 비난하며 도발 명분 쌓기…“군사억제력 강화 당연”
# 北김여정, 한미 비난하며 '결정적 행동' 위협…도발 명분쌓기
# 8개의 관련뉴스 더보기
#
#
#
# 민주당 "있지도 않은 핵공유 말 지어내" 정부·여당 비판한 이유는?
# 민주 “핵 공유? 대국민 사기극…아전인수식 정신 승리”
# 민주당, '사실상 핵 공유'에 "대통령실·與, 정신승리 끈 놓지 못해"
# 민주, '사실상 핵공유' 논란에 "대국민 사기극…정신승리 하자는 것"
# 31개의 관련뉴스 더보기
#
#
#
# 김여정, '정권종말' 바이든에 "미래없는 늙은이의 망언"
#
#
#
# [속보] 北김여정, 바이든 ‘정권 종말’ 발언에 “늙은이의 망언, 쉽게 넘길 수 없다”
# 85개의 관련뉴스 더보기
#
#
# 동영상기사
#
# '방미' 윤대통령, MIT 석학 만나…'디지털 바이오' 논의
#
#
#
# MIT 찾은 尹 대통령 “한국 과학기술 인력들, 보스턴 보내 배우게 할 것”
# 17개의 관련뉴스 더보기
#
#
#
# 이영, 보스턴서 '클러스터 협력안' 논의…MOU 4건 체결
#
#
#
#  보스턴 클러스터 업계 한자리에…尹 "핵심은 자본투자"(종합2보)[尹국빈방미]
# 23개의 관련뉴스 더보기
#
#
#
# 이서진이 왜 거기서 나와?…尹 대통령 "어떻게 오셨냐"
#
#
#
# 尹, 보자마자 "어떻게 오셨냐"…美국빈행사 나타난 이서진 왜
# 8개의 관련뉴스 더보기
#
#
#
# '민형배 복당' 與野 모두 비판? 속사정 들여다보니
#
#
#
# ‘꼼수 탈당 1년 민형배’…'검수완박’ 등 안조위 무력화만 두 번, 與 대책은?
# 4개의 관련뉴스 더보기
#
#
#
# 보훈처장, 美필라델피아 리틀극장 방문…'제1차 한인회의' 재현
# 박민식 보훈처장, 미국서 태극기 들고 '제1차 한인회의' 재현
# 6개의 관련뉴스 더보기
#
#
# 동영상기사
#
# 윤 대통령, 미국 국빈 방문 마치고 귀국길
#
#
#
# 尹대통령, 5박7일 '국빈 방미' 마치고 귀국길…오늘 오후 도착
# 56개의 관련뉴스 더보기
#
#
#
# 北, 연일 '워싱턴 선언' 비판…"반드시 비싼 대가 치를 것"
#
#
#
# 북한 "한미 핵전쟁 책동…상응한 군사적 억제력 키울 것"
# 24개의 관련뉴스 더보기
#
#
#
# 尹, 하버드 대담서 “워싱턴선언, 나토 다자약정보다 실효성 있다”
#
#
#
# "재학생이라면 A학점"…하버드대 교수 웃게 한 尹 답변 보니
# 13개의 관련뉴스 더보기
#
#
# 동영상기사
#
#  윤대통령 하버드대 연설…'자유 향한 여정' 주제[현장연결]
#
#
#
# 尹, 하버드서 “힘에 의한 현상 변경, 결연한 연대로 대응해야”
# 49개의 관련뉴스 더보기
#
#
#
# 홍준표 "전광훈, 급기야 대통령실 물고들어가…미적거리지 말고 끊어라"
#
#
#
# 홍준표 "`하나님도 나한테 맞는다`는 전광훈…목사인가"
# 23개의 관련뉴스 더보기
#
#
# 동영상기사
#
# 민주 새 원내대표 ‘비명’ 박광온…“이기는 통합의 길”
#
#
#
# 압도적 표 얻었지만...‘개딸’은 불신하는 박광온?
# 19개의 관련뉴스 더보기
# 헤드라인 더보기
#
# 연재보기
# 세종만사(世宗萬事)
#
#
#
#
# [세종만사]추경호 부총리, 15년만에 G7재무장관회의 참석
# [세종만사]블랙홀 된 전기·가스요금, 에너지정책 '진통'
# [세종만사]호흡곤란 '김포골드라인' 원-오 회동에도 산너머 산
# [세종만사]누리호 3차 발사 초읽기에 들어간 과기정통부
#
#
#
# 동영상기사
#
# 北 "반드시 비싼 대가 치를 것...군사적 억제력 강화"
# YTN
#
#
#
# [단독] 중학 교사 “2찍남은 멍청, 尹 술마시며 일해”. …
# 조선일보
#
#
#
# 40도 폭염에 말 죽고…바다 온도 관측 이래 최고
# KBS
#
#
#
# “가수 송민호도 타보더니 감탄” 한국인이 가장 많이 사는  …
# 헤럴드경제
#
#
#
# 남자친구와 타이완 여행 30대 숨진 채 발견…경찰, 타살  …
# SBS
#
#
#
# 과외누나 남자친구 살해한 고교생..신촌대학생 살인사건[그해 …
# 이데일리
#
#
#
# 미 언론 “한국 청년들은 ‘아메리칸 파이’보다 일자리 부족 …
# 한겨레
#
#
#
# "부끄럽지 않나" 비난에도... 11개월 '주부'가 된 남 …
# 오마이뉴스
#
#
#
# "벨라루스 국민은 러시아의 우크라 침공에 단호히 반대"
# 시사저널
#
#
#
# 역대급 카메라라던 ‘갤럭시S23 울트라’… 성능 평가는 중 …
# 조선비즈
#
#
#
# “손자가 성폭행을 했습니다”...피해자는 극단선택, 가해자 …
# 매일경제
#
#
#
# [단독] "빛·소음 때문에 짜증"…드라마 촬영장에 벽돌 투 …
# TV조선
#
#
#
# 사상 초유 '4연속 하한가'…1주일새 시총 '8조' 증발  …
# 서울경제
#
#
#
# [단독] 정부, 6월 로또 추첨장에 참관 원하는 국민 전원 …
# 국민일보
#
#
#
# 여신도 나체 석고상이라니…JMS 엽기행각 충격
# 아시아경제
#
#
#
# “납득 안 되는 딸의 죽음…왜 잊으라고만 하나요”
# 경향신문
#
#
# 동영상기사
#
# 호랑이 마주친 사슴처럼 '펄쩍'‥나흘간 잠복한 결과는?
# MBC
#
#
#
# 대만 호텔서 숨진채 발견된 30대 한국 여성.. 남자친구  …
# 파이낸셜뉴스
#
#
#
# 다큐 '문재인입니다' 첫 상영…"5년 성취 허망" 발언 빠 …
# 매일신문
#
#
#
# 소름, 전화기 넘어 그 목소리 분명 내 딸이었는데...[누 …
# 뉴시스
#
#
#
# 한효주, BTS, 성훈 트레이너가 무일푼에서 논현동 헬스장 …
# 동아일보
#
#
#
# '강남 1시간 거리'도 안통한다…광교·의정부 아파트값 40 …
# 머니투데이
#
#
#
# 샴푸 떨어졌다... 바디워시로 머리 감으면 어떻게 될까?
# 헬스조선
#
#
#
# 임창정도 당한 '주가조작', 한탕이면 46억 원 챙겨
# 한국일보
#
#
#
# 이용식 "바로 윗선배 오니 활짝 웃네"…서세원에 마지막 인 …
# 중앙일보
#
#
# 동영상기사
#
# 폭락 사태 늑장대응…커지는 금융당국 책임론
# 연합뉴스TV
#
#
#
# "4인 가족 삼겹살 외식하면 10만원"…가정의 달 앞두고  …
# JTBC
#
#
#
# 故서세원, 현지 화장 뒤 국내서 장례식…유족 “억측·루머  …
# 서울신문
#
#
#
# 45초 행사가 12분으로…한미정상 부부에 감동전한 한인 아 …
# 연합뉴스
#
#
#
# 쉰 목소리에 검사했다가 '깜짝'…이혜영 "2주간 말 못 해 …
# 한국경제
#
#
#
# 230년 된 조각상에 파란 낙서가...英 박물관에 무슨 일 …
# MBN
#
#
#
# 윤석열 대통령, 5박 7일 미국 국빈방문 마치고 귀국
# kbc광주방송
#
#
#
# 직장인 괴롭히는 '3대 갑질'은? 1위는 '직장 내 괴롭힘 …
# 노컷뉴스
#
#
#
# [알고보니] 청첩장 다 돌렸는데 갑작스레 파혼 통보…법적  …
# 뉴스1
#
#
#
# 황금연휴 여기 모르면 '낭패'…서울 곳곳이 '대변신'
# 한국경제TV
#
#
#
# 故 서세원 유해, 사망 열흘 만에 고국으로…한국서 장례식  …
# 부산일보
#
#
#
# 이창양 장관, 현대차그룹 로봇 개발 거점 '보스턴 다이내믹 …
# 데일리안
#
#
#
# 간호법 지지 나선 한의사협회 “의사들 파업하면 우리가 공백 …
# 세계일보
#
#
#
# “바이든, 尹과 듀엣하려 했다” 박지원 비난에 대통령실 “ …
# 문화일보
#
#
#
# 민주당 “尹 방미, 대국민 사기 외교…텅빈 쇼핑백”
# 채널A
#
#
#
# 1억5천만 원짜리 '바나나 작품'  먹어 치운 서울대생.. …
# 디지털데일리
#
#
#
# 트위터 기사 건당 요금낸다...머스크 "월 구독 과금체계  …
# ZDNet Korea
#
#
#
# '지금 아니면 영원히 내 집 없다'…이젠 30대가 '큰 손 …
# SBS Biz
#
#
#
# ‘죽음’에 대해 말하자 ‘자살’ 단어 내민 챗봇 [평범한  …
# 시사IN
#
#
#
# 애플페이 질주에 낙동강 오리알 된 오픈페이
# 전자신문
#
#
#
# [세금줍줍] 법인차량을 직원들이 썼는데요
# 비즈워치
#
#
#
# 대만여행 간 30대 한국 여성 숨져…동행한 남자친구 혐의  …
# 디지털타임스
#
#
#
# [속보]윤 대통령, 5박 7일 미국 국빈 방문 마치고 귀국
# 강원일보
#
#
#
# "검사 때 해외연수?" 尹 영어연설 띄우기 진심이었던 언론 …
# 미디어오늘
#
#
#
# 저는 SKY, 사수는 그냥 ‘인서울’...학벌 알고 나니  …
# 매경이코노미
#
#
#
# 박지원 "바보 대통령실? 尹이 한소절 더 안했으면 바이든이 …
# 프레시안
#
#
#
# 30대 퇴직금 평균 1180만원…50대가 퇴직금 '최고'
# 아이뉴스24
#
#
#
# 민주 "尹 방미, 빈손 외교 넘어 대국민 사기 외교...냉 …
# 강원도민일보
#
#
#
# [One with Nature] Immerse yourse …
# 코리아헤럴드
#
#
#
# “정치는 직업 아닌 소명…” 송영길 발언이 위험한 이유
# 한겨레21
#
#
#
# 은행권 정기예금 금리 최고 연 3.75%...저축은행 최고 …
# 조세일보
#
#
#
# ‘1억짜리 바나나’ 먹어치운 서울대생,  리움미술관이 용서 …
# 이코노미스트
#
#
#
# 로또 1065회 당첨번호 1등 18억, '이거 실화? 또  …
# 더팩트
#
#
#
# "김건희가 대통령이냐" 방명록 논란…김정숙, 김혜경은 어땠 …
# 주간조선
#
#
#
# “윤석열은 큰 그릇, 이익 위해 남 희생시키지 않아” [+ …
# 신동아
#
#
#
# "尹 대통령 방미만으로 증시 훈풍 글쎄…없는 것보단 나아"
# 블로터
#
#
#
# “세금으로 백신 만들어 놓곤…” 모더나 CEO 스톡옵션으로 …
# 국제신문
#
#
#
# [CEO포커스]스마게 권혁빈, 세기의 이혼… 5조원대 재산 …
# 머니S
#
#
#
# 어디 '학폭' 뿐이랴.. '직장내 괴롭힘'에 신고조차 못해 …
# JIBS
#
#
#
# ‘탈레반 리튬’ 잡아라! 아프간 1300조 리튬 눈독 들이 …
# 주간동아
#
#
#
# 체중 줄이고 혈당 천천히 낮게 올리는 음식은?
# 코메디닷컴
#
#
#
# Gaming in Korea is a real career …
# 코리아중앙데일리
#
#
#
# "간식에서 화장품 맛나요".. 거짓 구매 후기 쓴 주부 ' …
# 전주MBC
#
#
#
# HD한국조선해양, 유럽서 220억 투자…차세대 기술 선점
# 한경비즈니스
#
#
#
# 꿀 먹으며 꽃가루 옮겨…꽃과 상부상조하는 초식 개구리
# 동아사이언스
#
#
#
# 야외활동 후 ‘사마귀’가 생겼다면? ‘이것’ 주의
# 농민신문
#
#
#
# 다큐 '문재인입니다', 전주국제영화제서 첫 공개
# 대전일보
#
#
#
# 네이버 뉴스서 'URL·QR코드·언론사사이트' 이동 가능해 …
# 기자협회보
#
#
#
# “순둥이 아들의 찢어진 셔츠…죽음에 대한 예의도 없었다”
# 주간경향
#
#
#
# 30대 다문화여성 4살 아들 살해하고 경찰에 자수
# CJB청주방송
#
#
#
# [만나보니] 국가인권위원회가 제시하는 이슬람 사원 갈등 해 …
# 대구MBC
#
#
#
# 성별에 대해 우리가 갖는 ‘두려움’
# 일다
#
#
#
# 토핑 추가하면 4만원… 외면받는 金피자 [인포로 본 세상]
# 더스쿠프
#
#
#
# “물극필반 아닌 사필귀정”... 與, 송영길 전 대표 비판
# 경기일보
#
#
#
# 4년 만에 만나는 황매산 철쭉
# 중앙SUNDAY
#
#
#
# 성별에 대해 우리가 갖는 ‘두려움’
# 일다
#
#
#
# 토핑 추가하면 4만원… 외면받는 金피자 [인포로 본 세상]
# 더스쿠프
#
#
#
# “물극필반 아닌 사필귀정”... 與, 송영길 전 대표 비판
# 경기일보
#
#
#
# 4년 만에 만나는 황매산 철쭉
# 중앙SUNDAY
#
#
#
# ‘당근 마니아’ 모여! ‘영양 빵빵 접는 김밥’[주말&]
# 레이디경향
# [뉴스1 PICK]윤석열 대통령, 미국 국빈 방문 마치고 귀국
# 엇갈린 '방미 성과' 평가... "사기 외교" vs. "프랑스와 동급"
# 이재명 "박광온과 '총선승리' 역사적 소명…우리 안 차이 안 커"
# "日기시다, 5월 7∼8일 방한"...尹 '결단' 답례로 '선물' 내놓을까
# 대만 호텔방서 무슨 일이… 한국인 여성, 숨진 채 발견
# 이창양 장관, 현대차그룹 로봇 개발 거점 '보스턴 다이내믹스' 방문
# 정의선·박재욱·노홍철…한국판 '버핏과의 점심' 첫 타자로
# 尹대통령, 안보·경제 두마리 토끼 받았다[국빈방문 결산]
# 구글·MS에 다 빼앗길라.. 정부, AI 학습용 데이터 대거 개방
# 울산과기원, “AI-탄소중립-반도체 삼각편대로 20년 데스밸리 뛰어넘는다”
# 의사·간호조무사 "총파업 강행" 예고…의료대란 현실화할까(종합)
# 검찰 "청소년 마약 범죄, 사형... 공급망 뿌리 뽑겠다"
# “죄송해요”…생후 40일 아들 학대 숨지게 한 친모 영장 심사
# 문체부 “넷플릭스 투자 등 윤 대통령 방미 성공적”
# [날씨] 중부 곳곳 비…강원영동 대기 건조, 강풍까지
#
#
#
#  서비스 안내
#  고침 기사 모음
#  정정·반론·추후 보도 기사 모음
#  불공정 선거 보도 기사 모음
# 서비스 안내더보기

# %%
import urllib.request as rq

url = 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100'
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'lxml')
texts = bs.find_all('p')
print(texts)
# Out:
# [<p class="airs_info_inner"><i class="airs_info_icon_airs">AiRS</i><span class="airs_info_text"><b>추천</b>으로 구성된 뉴스를 제공합니다.</span></p>, <p class="section_sub_txt">오후 3시~오후 4시까지 집계한 결과입니다.</p>, <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>]

# %%
for t in texts:
    t = t.get_text()
    print(t,'\n')
# Out:
# AiRS추천으로 구성된 뉴스를 제공합니다.
#
# 오후 3시~오후 4시까지 집계한 결과입니다.
#
# 본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.

# %%
import urllib.request as rq
url = 'https://news.naver.com'
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'lxml')
print(bs.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <title id="browserTitleArea">
#    네이버 뉴스
#   </title>
#   <script>
#    function isMobileDevice() {
# 		return /^.*(iPhone|iPod|iPad|Android).*/.test(navigator.userAgent);
# 	}
#   </script>
#   <script>
#    (function () {
# 		try {
# 			if (isMobileDevice() && isAbleApplyPrefersColorScheme()) {
#
# 				document.querySelector("html").classList.add("DARK_THEME");
# 			}
# 		} catch(e) {}
#
# 		function isAbleApplyPrefersColorScheme() {
#
# 			if (window.matchMedia("(prefers-color-scheme)").matches === false) {
# 				return false;
# 			}
#
# 			var userAgent = navigator.userAgent;
#
# 			if (userAgent.indexOf("NAVER") > -1) {
#
# 				if (/.*NAVER\([a-zA-Z]*;\s[a-zA-Z]*;\s([0-9]*);/.test(userAgent)) {
# 					return Number(RegExp.$1) >= 1000;
# 				}
# 			} else {
#
# 				return document.cookie.indexOf("NSCS=1") > -1;
# 			}
#
# 			return false;
# 		}
# 	})();
#   </script>
#   <script>
#    var g_ssc = 'news.v3_media' || null;
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width,initial-scale=1.0,maximum-scale=1.0,minimum-scale=1.0,user-scalable=no,target-densitydpi=medium-dpi" name="viewport"/>
#   <link href="https://ssl.pstatic.net/static.news/mnews/resources/20230420_005654/css/generated/newshome.css" rel="stylesheet" type="text/css"/>
#   <link href="https://mimgnews.pstatic.net/image/news/m/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <script>
#    (function(){
# 		var userAgent = navigator.userAgent;
# 		var result = [];
#
# 		if(userAgent.indexOf('Android') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="72x72" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="96x96" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="144x144" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="192x192" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />'
# 			];
# 		}else if(userAgent.indexOf('iPhone') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="120X120" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPhone_2x_120X120.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="180x180" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPhone_3x_180X180.png" />'
# 			];
# 		}else if(userAgent.indexOf('iPad') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="167x167" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPadPro_2x_167X167.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="152x152" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPad_2x_152X152.png" />'
# 			];
# 		}
# 		document.write(result.join('\n'));
# 	})();
#   </script>
#   <script src="https://ssl.pstatic.net/static.news/mnews/resources/20230420_005654/js/generated/statistics_jquery.js" type="text/javascript">
#   </script>
#   <script>
#    document.documentElement.setAttribute('data-useragent',navigator.userAgent);
#   </script>
#   <script>
#    document.documentElement.setAttribute('data-useragent', navigator.userAgent);
#
#
# function showNoImage(elImg, type) {
#     switch (type) {
#
#         case "remove":
#             try {
#                 elImg.parentNode.removeChild(elImg);
#             } catch(e) {}
#             break;
#
#
#         case "removeParent":
#             try {
#                 elImg.parentNode.outerHTML = '';
#             } catch(e) {}
#             break;
#
#
#         case "alt":
#             elImg.outerHTML = ('<span class="noimage_text {imgClassName}">' + (elImg.alt || "") + '</span>')
#
#                 .replace('{imgClassName}', elImg.className);
#             break;
#
#
# 		case "class" :
# 			var outerHTMLSource = Number(elImg.getAttribute("height")) > 0?
#
# 				'<span class="noimage_wrap {imgClassName}" style="height:' + elImg.getAttribute("height") + 'px;"><span class="noimage"></span></span>':
# 				'<span class="noimage_wrap {imgClassName}"><span class="noimage"></span></span>';
# 			elImg.outerHTML = outerHTMLSource.replace('{imgClassName}', elImg.className);
# 			break;
#
#
#         default:
#
#             elImg.outerHTML = Number(elImg.getAttribute("height")) > 0?
#
#                 '<span class="noimage_wrap" style="height:' + elImg.getAttribute("height") + 'px;"><span class="noimage"></span></span>':
#                 '<span class="noimage_wrap"><span class="noimage"></span></span>';
#     }
# }
#
#
# function doAfterLoadEnd(callback, callbackOnPersisted) {
#     var eventName = "onpageshow" in window ? "pageshow" : "load";
#
#     callback = callback || function(){};
#     callbackOnPersisted = callbackOnPersisted || function(){};
#
#     window.addEventListener(eventName, function(e) {
#         try{
#             if(Boolean(e.persisted)){
#                 callbackOnPersisted();
#                 return;
#             }
#         }catch(e){}
#
#         callback();
#     });
# }
#   </script>
#   <meta content="네이버 뉴스" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://news.naver.com/main/home.naver" property="og:url"/>
#   <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image"/>
#   <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" property="og:description"/>
#   <meta content="네이버" property="og:article:author"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="네이버 뉴스" name="twitter:title"/>
#   <meta content="네이버 뉴스" name="twitter:site"/>
#   <meta content="네이버 뉴스" name="twitter:creator"/>
#   <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
#   <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" name="twitter:description"/>
#   <script>
#    (function () {
#         var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#         if (!isUnderIE10) {
#             var script = document.createElement("script");
#             script.async = true;
#             script.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#             document.head.appendChild(script);
#         }
#     })();
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#     window.gladsdk.cmd.push(function () {
#
#         window.gladsdk.setGlobalConfig({
#             enablePersistAd: true
#         });
#
#
#         var adUnits = [];
#
#         adUnits.push({
#             adUnitId: "p_news_sidebox",
#             adSlotElementId: "glad_ad_sidebox",
#             customParam: {
#                 calp: "home"
#             }
#         });
#
#         for (let i = 0; i < adUnits.length; i++) {
#             window.gladsdk.defineAdSlot(adUnits[i]);
#         }
#
#
#         var htmlClass = document.querySelector("html").getAttribute("class");
#         if (htmlClass && htmlClass.indexOf("DARK_THEME") > -1) {
#             window.gladsdk.setHostMeta("theme", "system");
#         }
#     });
#   </script>
#  </head>
#  <body class="as_mp_layout">
#   <div class="u_skip">
#    <a href="#ct">
#     본문 바로가기
#    </a>
#   </div>
#   <!-- Menu 구분  -->
#   <section class="news_header">
#    <header class="nh_header" role="banner">
#     <div class="Ngnb">
#      <div class="Ngnb_inner">
#       <div class="Ngnb_both">
#        <div class="Ngnb_left">
#         <span class="Ngnb_logo">
#          <a class="Nlogo_link" href="https://www.naver.com" onclick="nclk(event,'gnb.naver','','');">
#           <span class="Nicon_logo">
#            NAVER
#           </span>
#          </a>
#         </span>
#         <div class="Ngnb_service">
#          <h1 class="Nservice_item">
#           <a href="https://news.naver.com" onclick="nclk(event,'gnb.news','','');">
#            <span class="Nicon_service">
#             뉴스
#            </span>
#           </a>
#          </h1>
#          <span class="Nservice_subitem">
#           <a href="https://entertain.naver.com/home" onclick="nclk(event,'gnb.enter','','');">
#            <span class="Nicon_family Nicon_entertain">
#             연예
#            </span>
#           </a>
#          </span>
#          <span class="Nservice_subitem">
#           <a href="https://sports.news.naver.com/index" onclick="nclk(event,'gnb.sports','','');">
#            <span class="Nicon_family Nicon_sports">
#             스포츠
#            </span>
#           </a>
#          </span>
#          <span class="Nservice_subitem">
#           <a href="https://weather.naver.com/" onclick="nclk(event,'gnb.weather','','');">
#            <span class="Nicon_family Nicon_weather">
#             날씨
#            </span>
#           </a>
#          </span>
#          <span class="Nservice_subitem">
#           <a href="https://contents.premium.naver.com/" onclick="nclk(event,'gnb.premium','','');">
#            <span class="Nicon_family Nicon_premium">
#             프리미엄
#            </span>
#           </a>
#          </span>
#         </div>
#        </div>
#        <div class="Ngnb_right">
#         <div class="Ngnb_group">
#          <div class="gnb_dark_type2" id="gnb">
#          </div>
#         </div>
#         <div class="Ngnb_search is_hidden _search_content">
#         </div>
#         <div class="Ngnb_tool">
#          <a class="Ntool_button _search_content_toggle_btn" href="javascript:;" onclick="nclk(event,'gnb.sch','','');">
#           <span class="Nicon_search">
#            검색
#           </span>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="Nlnb _float_lnb">
#      <div class="Nlnb_inner">
#       <div class="Nlnb_both">
#        <div class="Nlnb_left _lnb_scroll">
#         <div class="Nlnb_menu Ntype_scroll">
#          <div class="Nlnb_menu_inner _scroll">
#           <ul class="Nlnb_menu_list" role="menu">
#            <li class="Nlist_item is_active">
#             <a aria-selected="true" class="Nitem_link" href="https://news.naver.com/?viewType=pc" onclick="nclk(event,'lnb.pcmedia','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               언론사별
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100" onclick="nclk(event,'lnb.pol','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               정치
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101" onclick="nclk(event,'lnb.eco','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               경제
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102" onclick="nclk(event,'lnb.soc','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               사회
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103" onclick="nclk(event,'lnb.lif','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               생활/문화
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105" onclick="nclk(event,'lnb.sci','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               IT/과학
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104" onclick="nclk(event,'lnb.wor','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               세계
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item _isNew">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/ranking/popularDay.naver" onclick="nclk(event,'lnb.rank','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               랭킹
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item _isNew">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/newspaper/home?viewType=pc" onclick="nclk(event,'lnb.paper','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               신문보기
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/opinion/home" onclick="nclk(event,'lnb.opi','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               오피니언
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/tv/index.naver?mid=tvh" onclick="nclk(event,'lnb.tv','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               TV
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/factcheck/main.naver" onclick="nclk(event,'lnb.fact','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               팩트체크
#              </span>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#        <div class="Nlnb_right">
#         <div class="lnb_extra" id="">
#          <div class="lnb_extra_menu">
#           <ul class="lnb_extra_menu_list">
#            <li class="lnb_extra_menu_item">
#             <a class="lnb_extra_menu_link" href="https://news.naver.com/main/officeList.naver" onclick="nclk(event,'slb.allmedia','','');">
#              전체 언론사
#             </a>
#            </li>
#            <li class="lnb_extra_menu_item">
#             <a class="lnb_extra_menu_link" href="https://newsstand.naver.com/" onclick="nclk(event,'slb.newsstand','','');" target="_blank">
#              뉴스스탠드
#             </a>
#            </li>
#            <li class="lnb_extra_menu_item">
#             <a class="lnb_extra_menu_link" href="https://newslibrary.naver.com/search/searchByDate.naver" onclick="nclk(event,'slb.library','','');" target="_blank">
#              라이브러리
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </header>
#   </section>
#   <hr/>
#   <div class="main_wrap" id="ct" role="main">
#    <div class="main_container">
#     <section class="main_content">
#      <h3 class="blind">
#       콘텐츠
#      </h3>
#      <div class="main_sublnb">
#       <div class="main_sublnb_date">
#        <strong>
#         4
#        </strong>
#        .
#        <strong>
#         30
#        </strong>
#        <span>
#         (일)
#        </span>
#       </div>
#       <ul class="main_sublnb_menu">
#        <li class="main_sublnb_item">
#         <a class="main_sublnb_link" href="https://news.naver.com/main/officeList.naver " onclick="nclk(event, 'slb.allmedia', '', '')">
#          전체 언론사
#         </a>
#        </li>
#        <li class="main_sublnb_item">
#         <a class="main_sublnb_link" href="https://newsstand.naver.com/" onclick="nclk(event, 'slb.newsstand', '', '')" target="_blank">
#          뉴스스탠드
#         </a>
#        </li>
#        <li class="main_sublnb_item">
#         <a class="main_sublnb_link" href="https://newslibrary.naver.com/search/searchByDate.naver" onclick="nclk(event, 'slb.library', '', '')" target="_blank">
#          라이브러리
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="main_brick">
#       <!-- BRICK HOUSE -->
#       <div class="grid1_wrap brick-house _brick_gid_wrapper">
#        <div class="brick-vowel _brick_column">
#         <div class="main_brick_item _press_main_status_wrapper">
#          <div class="comp_journal_subscribe">
#           <div class="cjs_title_wrap">
#            <h3 class="cjs_edit_title">
#             <span class="cjs_main">
#              언론사편집
#             </span>
#             <a class="cjs_subscribe_a" href="#feedJournalistCard" onclick="nclk(event, 'home.editassetting1', '', '')">
#              <span class="subs_text">
#               기자
#              </span>
#             </a>
#             <a class="cjs_subscribe_a" href="#feedSeriesCard" onclick="nclk(event, 'home.editassetting2', '', '')">
#              <span class="subs_text">
#               연재
#              </span>
#             </a>
#            </h3>
#            <a class="cjs_more_link" href="https://media.naver.com/channel/settings" onclick="nclk(event, 'home.editsetting', '', '')">
#             구독설정
#             <span class="ico_more">
#             </span>
#            </a>
#           </div>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_news_preview_wrapper" data-max-page="16">
#          <div class="comp_journal_subscribe _preview_card_page" style="">
#           <div class="cjs_channel_card">
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/123" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img height="28" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/123/2018/10/02/logo_123_56_20181002190002.png?type=nf76_76_q90" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                조세일보
#                <span class="datetime">
#                 04월 30일 15:17
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="123" data-office_name="조세일보" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/123/0002304027" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/origin/123/2023/04/30/2304027.jpg?type=nf264_176&amp;ut=20230430111001" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                "빚 만드는 외상결제'...서비스업체, 연체율 급증에 건전성 우려
#               </div>
#               <p class="cjs_d">
#                물건을 먼저 구입하고 나중에 결제하는 '선구매 후불결제(BNPL)' 서비스의 연체율이 높아지면서 건전성에 대한 우려도 커지고 있다. 30일 국회 정무위원회 소속 최승재 국민의힘 의원이 금융감독원으로부터 받은 네이버파
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/119" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img height="28" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/119/2023/03/17/logo_119_56_20230317161040.jpg?type=nf76_76_q90" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                데일리안
#                <span class="datetime">
#                 04월 30일 17:13
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="119" data-office_name="데일리안" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/119/0002708038" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/origin/119/2023/04/30/2708038.jpg?type=nf264_176&amp;ut=20230430070101" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                "어디서 들어본 것 같지 않나요?"…반복되는 표절 의혹에 멍드는 케이팝 [기자수첩-연예]
#               </div>
#               <p class="cjs_d">
#                'K팝 사상 최단 기간 빌보드 입성', '중소의 기적' 등의 영광스러운 수식어를 지닌 피프티피프티 활약에 제동이 걸렸다. 튀르계 가수 Evrencan Gündüz가 피프티피프티의 데뷔곡 '큐피드'가
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/055" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img height="28" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/055/2020/10/07/logo_055_56_20201007141807.jpg?type=nf76_76_q90" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                SBS
#                <span class="datetime">
#                 04월 30일 16:43
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="055" data-office_name="SBS" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/055/0001054288" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/origin/055/2023/04/30/1054288.jpg?type=nf264_176&amp;ut=20230430164101" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                '형용사: 특출난, 유일무이한'…펠레, 포르투갈어 사전 등재
#               </div>
#               <p class="cjs_d">
#                '축구 황제' 펠레의 이름이 '뛰어난, 비교할 수 없는, 유일무이한' 사람을 의미하는 형용사로 브라질 사전에 영원히 남게 됐습니다. 현지 시간으로 지난 27일 CNN, BBC 등 외신들은 '펠레'가 포르투갈어 사전에
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/016" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img height="28" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/016/2020/11/03/logo_016_56_20201103113832.jpg?type=nf76_76_q90" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                헤럴드경제
#                <span class="datetime">
#                 04월 30일 15:39
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="016" data-office_name="헤럴드경제" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/016/0002137070" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/origin/016/2023/04/30/2137070.jpg?type=nf264_176&amp;ut=20230430070204" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                “가수 송민호도 타보더니 감탄” 한국인이 가장 많이 사는 독일 중고차 1위는?[머니뭐니]
#               </div>
#               <p class="cjs_d">
#                “한국인이 없어서 못타는 ‘독일차’…가수 위너도 반했다” 중고차 거래 플랫폼 KB차차차가 지난 1년간 한국인이 가장 많이 찾는 독일 3사(벤츠·BMW·아우디) 중고차 모델을 분석한 결과 벤츠 E클래스가 1위를 기록한
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/469" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img height="28" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/469/2023/02/07/logo_469_56_20230207160012.png?type=nf76_76_q90" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                한국일보
#                <span class="datetime">
#                 04월 30일 17:05
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="469" data-office_name="한국일보" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/469/0000736876" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/origin/469/2023/04/30/736876.jpg?type=nf264_176&amp;ut=20230430143304" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                "5년 성취 무너져 허망" 발언 빠져… '문재인입니다' 다큐 어떤 내용?
#               </div>
#               <p class="cjs_d">
#                29일 오후 7시 무렵 전북 전주시 전북대 삼성문화회관은 사람들로 붐볐다. 제24회 전주국제영화제에서 첫 공개되는 다큐멘터리영화 ‘문재인입니다’를 보려는 이들이 대부분이었다. 일부 관객은 로비에 설치된 대형 영화 포
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_info">
#             <button card_type="preview" class="cjs_btn_refresh _refresh_btn" data-max-page="" data-page="0" onclick="nclk(event, 'home.editnfnew', '', '')" size="5" type="button">
#              새로보기
#             </button>
#            </div>
#           </div>
#          </div>
#          <div class="comp_journal_subscribe _preview_card_page" style="display:none">
#           <div class="cjs_channel_card">
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/214" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/214/2020/06/30/logo_214_56_20200630111130.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                MBC
#                <span class="datetime">
#                 04월 30일 16:32
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="214" data-office_name="MBC" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/214/0001269736" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/214/2023/04/30/1269736.jpg?type=nf264_176&amp;ut=20230430113501" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#               <span class="comp_ico_movie">
#                동영상
#               </span>
#               <span class="comp_playtime">
#                <span class="time">
#                 <span class="blind">
#                  재생시간
#                 </span>
#                 01:54
#                </span>
#               </span>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                호랑이 마주친 사슴처럼 '펄쩍'‥나흘간 잠복한 결과는?
#               </div>
#               <p class="cjs_d">
#                지난달 경기도 포천의 한 주택가 골목. 늦은 밤, 남성 세 명이 계속 주변을 두리번거리며 골목을 서성입니다. 다른 날에도 이 골목엔 같은 남성들이 찾아와 누군가를 기다리는 듯 한참을 서 있다 떠났습니다. 다음날인 2
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/296" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/296/2021/08/31/logo_296_56_20210831152430.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                코메디닷컴
#                <span class="datetime">
#                 04월 30일 16:43
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="296" data-office_name="코메디닷컴" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/296/0000065431" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/296/2023/04/30/65431.jpg?type=nf264_176&amp;ut=20230430164801" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                간호조무사협회장, '간호법 반대 단식'에 병원행
#               </div>
#               <p class="cjs_d">
#                간호법 제정 반대를 위해 단식 시위 중이던 곽지연 대한간호조무사협회장이 병원으로 이송됐다. 30일 오후 국회 앞에서 단식 농성을 벌이던 곽 회장은 보건복지부 조규홍 장관과 현장 의사의 권유로 병원에 응급 이송됐다.
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/607" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/607/2018/10/02/logo_607_56_20181002184602.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                뉴스타파
#                <span class="datetime">
#                 04월 28일 13:40
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="607" data-office_name="뉴스타파" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/607/0000001506" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/607/2023/04/28/1506.jpg?type=nf264_176&amp;ut=20230428134001" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                [현장에서]아직도 ‘4대강은 대운하가 아니다’라는 그들에게
#               </div>
#               <p class="cjs_d">
#                요즘 4대강 사업의 주역들이 부쩍 대중 앞에 자주 등장하고 있다. 이명박 전 대통령(이하 존칭 생략)은 며칠 전 측근 유인촌의 연극을 관람했고 앞으로 4대강도 방문할 예정이라고 한다. 4대강 추진본부장이었던 심명필은
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/052" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/052/2021/10/01/logo_052_56_20211001183149.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                YTN
#                <span class="datetime">
#                 04월 30일 16:11
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="052" data-office_name="YTN" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/052/0001879280" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/052/2023/04/30/1879280.jpg?type=nf264_176&amp;ut=20230430135301" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#               <span class="comp_ico_movie">
#                동영상
#               </span>
#               <span class="comp_playtime">
#                <span class="time">
#                 <span class="blind">
#                  재생시간
#                 </span>
#                 01:47
#                </span>
#               </span>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                "최전방 이상 무!"...과학화 시스템으로 철통 경계
#               </div>
#               <p class="cjs_d">
#                남북이 가장 가깝게 총구를 맞대고 있는 곳, 최북단 철책에는 24시간 경계를 펴고 있는 최전방 사단이 있습니다. 과학화 경계시스템으로 보다 정밀한 임무를 수행하는 7사단 GOP 장병들의 모습을 임성재 기자가 보도합니
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/640" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/640/2020/05/06/logo_640_56_20200506111106.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                코리아중앙데일리
#                <span class="datetime">
#                 04월 30일 13:34
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="640" data-office_name="코리아중앙데일리" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/640/0000037870" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/640/2023/04/30/37870.jpg?type=nf264_176&amp;ut=20230430070103" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                Gaming in Korea is a real career path, not for the short of temper
#               </div>
#               <p class="cjs_d">
#                There's a certain phrase that goes, “No matter how good you are at gaming, there’s always a Korean better than you.” And
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_info">
#             <button card_type="preview" class="cjs_btn_refresh _refresh_btn" data-max-page="" data-page="0" onclick="nclk(event, 'home.editnfnew', '', '')" size="5" type="button">
#              새로보기
#             </button>
#            </div>
#           </div>
#          </div>
#          <div class="comp_journal_subscribe _preview_card_page" style="display:none">
#           <div class="cjs_channel_card">
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/422" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/422/2019/11/29/logo_422_56_20191129165529.jpg?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                연합뉴스TV
#                <span class="datetime">
#                 04월 30일 17:14
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="422" data-office_name="연합뉴스TV" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/422/0000596371" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/422/2023/04/30/596371.jpg?type=nf264_176&amp;ut=20230430154803" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#               <span class="comp_ico_movie">
#                동영상
#               </span>
#               <span class="comp_playtime">
#                <span class="time">
#                 <span class="blind">
#                  재생시간
#                 </span>
#                 00:30
#                </span>
#               </span>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                직장갑질119 "제보자 61％ 직장 내 괴롭힘 호소"
#               </div>
#               <p class="cjs_d">
#                시민단체 직장갑질119는 올해 지난 26일까지 받은 이메일 제보 중 직장 내 괴롭힘 피해 호소가 전체의 61.3%에 달했다고 밝혔습니다. 구체적 유형으로는 따돌림과 차별·보복이 절반을 넘었고, 이어 폭행·폭언, 부당
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/003" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/003/2022/02/21/logo_003_56_20220221152351.jpg?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                뉴시스
#                <span class="datetime">
#                 04월 30일 17:08
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="003" data-office_name="뉴시스" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/003/0011832820" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/003/2023/04/30/11832820.jpg?type=nf264_176&amp;ut=20230430164501" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                아이돌 'B.A.P' 출신 힘찬, 강제추행 혐의로 실형 확정
#               </div>
#               <p class="cjs_d">
#                기사내용 요약 펜션서 20대 여성 강제추행한 혐의 대법 유죄 판단…징역 10개월 확정 [서울=뉴시스] 류인선 기자 = 펜션에서 여성을 강제추행한 혐의로 재판에 넘겨진 그룹 '비에이피'(B.A.P) 출신 멤버 힘찬(김
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/057" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/057/2019/11/25/logo_057_56_20191125103925.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                MBN
#                <span class="datetime">
#                 04월 30일 17:12
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="057" data-office_name="MBN" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/057/0001739158" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/057/2023/04/30/1739158.jpg?type=nf264_176&amp;ut=20230430160401" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                음주운전 방지장치 의무화...김기현, 내일 법안 대표 발의
#               </div>
#               <p class="cjs_d">
#                국민의힘 김기현 대표는 음주운전으로 적발된 적이 있는 운전자의 차량에 '방지 장치를 의무적으로 부착'하도록 하는 도로교통법 개정안을 내일(오는 1일) 대표 발의한다고 오늘(30일) 밝혔습니다. 이 법안은 김 대표가
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/417" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/417/2021/01/25/logo_417_56_20210125161624.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                머니S
#                <span class="datetime">
#                 04월 30일 16:00
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="417" data-office_name="머니S" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/417/0000917175" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/417/2023/04/30/917175.jpg?type=nf264_176&amp;ut=20230430153801" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                루이비통, 국내 첫 프리폴 패션쇼 성료… 1600여명 몰려
#               </div>
#               <p class="cjs_d">
#                프랑스 명품 브랜드 루이비통이 서울 잠수교에서 개최한 국내 첫 패션쇼가 성황리에 마무리됐다. 루이비통은 지난 29일 오후 8시 서울 잠수교에서 프리폴(Prefall) 패션쇼를 열었다. 정규 가을·겨울(F/W) 컬렉션
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/024" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/024/2020/12/23/logo_024_56_20201223182820.jpg?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                매경이코노미
#                <span class="datetime">
#                 04월 30일 13:25
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="024" data-office_name="매경이코노미" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/024/0000081718" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/024/2023/04/30/81718.jpg?type=nf264_176&amp;ut=20230430092401" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                백스윙 때 오른발 뒤꿈치 밟고 스윙 때 떼라
#               </div>
#               <p class="cjs_d">
#                (410) 김상현의 정교한 샷 한국프로골프(KPGA) 코리안투어가 개막하는 매년 4월, 주목받는 한 선수가 있습니다. 전년도 스릭슨투어 상금왕 김상현입니다. 2부 투어지만 지난해 정규투어에서 2번의 우승을 포함해 1
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_info">
#             <button card_type="preview" class="cjs_btn_refresh _refresh_btn" data-max-page="" data-page="0" onclick="nclk(event, 'home.editnfnew', '', '')" size="5" type="button">
#              새로보기
#             </button>
#            </div>
#           </div>
#          </div>
#          <div class="comp_journal_subscribe _preview_card_page" style="display:none">
#           <div class="cjs_channel_card">
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/215" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/215/2020/08/12/logo_215_56_20200812134433.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
# ...
#              <div class="cjs_channel_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/661/2022/01/19/logo_661_56_20220119142145.png" loading="lazy" onerror="showNoImage(this)"/>
#              </div>
#              <div class="cjs_channel_name">
#               JIBS
#              </div>
#             </a>
#            </li>
#            <li class="cjs_channel_item">
#             <a aria-checked="false" class="cjs_channel_a _item" data-office_id="658" href="javascript:;" role="checkbox">
#              <div class="cjs_channel_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/658/2022/01/20/logo_658_56_20220120164828.png" loading="lazy" onerror="showNoImage(this)"/>
#              </div>
#              <div class="cjs_channel_name">
#               국제신문
#              </div>
#             </a>
#            </li>
#            <li class="cjs_channel_item">
#             <a aria-checked="false" class="cjs_channel_a _item" data-office_id="654" href="javascript:;" role="checkbox">
#              <div class="cjs_channel_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/654/2022/01/14/logo_654_56_20220114111216.png" loading="lazy" onerror="showNoImage(this)"/>
#              </div>
#              <div class="cjs_channel_name">
#               강원도민일보
#              </div>
#             </a>
#            </li>
#            <li class="cjs_channel_item">
#             <a aria-checked="false" class="cjs_channel_a _item" data-office_id="655" href="javascript:;" role="checkbox">
#              <div class="cjs_channel_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/655/2022/01/20/logo_655_56_20220120164501.png" loading="lazy" onerror="showNoImage(this)"/>
#              </div>
#              <div class="cjs_channel_name">
#               CJB청주방송
#              </div>
#             </a>
#            </li>
#            <li class="cjs_channel_item">
#             <a aria-checked="false" class="cjs_channel_a _item" data-office_id="088" href="javascript:;" role="checkbox">
#              <div class="cjs_channel_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/088/2019/08/22/logo_088_56_20190822111422.png" loading="lazy" onerror="showNoImage(this)"/>
#              </div>
#              <div class="cjs_channel_name">
#               매일신문
#              </div>
#             </a>
#            </li>
#            <li class="cjs_channel_item">
#             <a aria-checked="false" class="cjs_channel_a _item" data-office_id="087" href="javascript:;" role="checkbox">
#              <div class="cjs_channel_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/087/2019/08/22/logo_087_56_20190822110222.png" loading="lazy" onerror="showNoImage(this)"/>
#              </div>
#              <div class="cjs_channel_name">
#               강원일보
#              </div>
#             </a>
#            </li>
#            <li class="cjs_channel_item">
#             <a aria-checked="false" class="cjs_channel_a _item" data-office_id="666" href="javascript:;" role="checkbox">
#              <div class="cjs_channel_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/666/2023/01/03/logo_666_56_20230103174615.png" loading="lazy" onerror="showNoImage(this)"/>
#              </div>
#              <div class="cjs_channel_name">
#               경기일보
#              </div>
#             </a>
#            </li>
#           </ul>
#           <div class="cjs_info">
#            <button class="cjs_btn_refresh _refresh_btn" onclick="nclk(event, 'home.edittnew', '', '')" type="button">
#             새로보기
#            </button>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="brick-vowel _brick_column">
#        </div>
#        <div class="brick-vowel _brick_column">
#        </div>
#       </div>
#      </div>
#     </section>
#     <section class="main_aside _aside_wrapper">
#      <div class="main_aside_inner _aside_content">
#       <h3 class="blind">
#        구독
#       </h3>
#       <div class="_aside">
#       </div>
#       <script>
#        doAfterLoadEnd(loadAside);
#
#
# function loadAside() {
#     var forcePcVersion = "";
#
#     if (isMobileDevice() && !forcePcVersion) {
#         return;
#     }
#     var iframe = append();
#     var asideFixed;
#
#     window.addEventListener('message', function(event) {
#         var data = event.data;
#
#         if (event.origin !== "https://news.naver.com") {
#             return;
#         }
#
#         if (data.type === "setIframeSize" && data.height) {
#             iframe.style.height = data.height + 'px';
#             iframe.style.visibility = "";
#
#             try {
#                 asideFixed.deactivate(); // event 중복 적용되지 않게
#             } catch(e) {}
#
#             asideFixed = AsideFixed({
#                 "wrapper" : document.querySelector("._aside_wrapper")
#
#             });
#         }
#     });
#
#
#     function append() {
#         var iframe = document.createElement('iframe');
#
#         iframe.width = "100%";
#         iframe.height = "0";
#         iframe.style.visibility = "hidden";
#         iframe.setAttribute("frameborder", "no");
#         iframe.setAttribute("scrolling", "no");
#         iframe.src = "https://news.naver.com/aside?oid=";
#
#         document.querySelector("._aside").appendChild(iframe);
#
#         return iframe;
#     }
# }
#       </script>
#      </div>
#     </section>
#     <div class="layer_toast" style="display: none">
#     </div>
#     <div class="layer_toast_journal_subscribe _subscribe_toast_layer" style="display: none">
#      <button class="lt_btn_set _subscribe_toast_btn" onclick="nclk(event, 'home.edittallchk', '', '')" type="button">
#      </button>
#     </div>
#    </div>
#   </div>
#   <!-- //ct -->
#   <hr/>
#   <div class="mp_footer">
#    <div class="f_subinfo">
#     <div class="f_subinfoinner">
#      <div class="f_notice">
#       <h5 class="f_notice_badge">
#        공지
#       </h5>
#       <a class="f_notice_link" data-mpurl='{"m":"https://m.news.naver.com/ombudsman/noticeread?notiId=715","p":"https://news.naver.com/main/ombudsman/readView.naver?notiId=715"}' href="https://m.news.naver.com/ombudsman/noticeread?notiId=715" onclick="nclk(event, 'fot.noticetext', '', '');">
#        <p class="f_notice_text">
#         기자·연재 카드 개선 안내
#        </p>
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="f_maininfo">
#     <div class="f_maininfoinner">
#      <a class="r_pg_top _go_top" href="javascript:;" id="goTop" onclick="nclk(event, 'fot.pctop', '', '');">
#       맨위로
#      </a>
#      <footer role="contentinfo">
#       <p class="u_ftlkw _footer_login" id="u_ftlkw">
#        <a class="u_ftlk" data-mpurl='{"m":"https://m.naver.com/services.html","p":"https://www.naver.com/more.html"}' href="https://m.naver.com/services.html" onclick="nclk(event,'fot.serviceall','','');">
#         전체서비스
#        </a>
#       </p>
#       <p class="u_cr">
#        <span class="u_ftm">
#         <span class="u_cri u_cri_v1">
#          <a class="u_cra" data-mpurl='{"m":"https://policy.naver.com/policy-mobile/term.html?type=1?type=1","p":"https://policy.naver.com/rules/service.html"}' href="https://policy.naver.com/policy-mobile/term.html?type=1?type=1" onclick="nclk(event,'fot.agreement','','');">
#           이용약관
#          </a>
#         </span>
#         <span class="u_cri u_cri_v1">
#          <a class="u_cra" data-mpurl='{"m":"https://policy.naver.com/policy-mobile/privacy.html","p":"https://policy.naver.com/rules/privacy.html"}' href="https://policy.naver.com/policy-mobile/privacy.html" onclick="nclk(event,'fot.privacy','','');">
#           <strong>
#            개인정보처리방침
#           </strong>
#          </a>
#         </span>
#         <span class="u_cri u_cri_v1">
#          청소년 보호 책임자 : 이희만
#         </span>
#         <span class="u_cri u_cri_v1">
#          <a class="u_cra" data-mpurl='{"m":"https://m.news.naver.com/ombudsman/index","p":"https://news.naver.com/main/ombudsman/index.naver"}' href="https://m.news.naver.com/ombudsman/index" onclick="nclk(event,'fot.guide','','');">
#           서비스안내
#          </a>
#         </span>
#        </span>
#        <span class="u_cri">
#         각 언론사가 직접 콘텐츠를 편집합니다.
#        </span>
#       </p>
#      </footer>
#     </div>
#    </div>
#   </div>
#   <script src="https://ssl.pstatic.net/static.news/mnews/resources/20230420_005654/js/generated/news.mobile.js" type="text/javascript">
#   </script>
#   <script src="https://ssl.pstatic.net/static.news/mnews/resources/20230420_005654/js/generated/pressmain.dependency.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /**
#  * 이 파일은 모바일 뉴스 서비스 전체 페이지에 적용되는 스크립트로써,
#  * 코드 추가 시 Front-End 성능 관점에서 주의를 요합니다.
#  */
# jQuery(window).on('load', function(){
#     setTimeout(onload, 10);
#
#     function onload(){
#         var oLnb = new news.Lnb('._lnb_scroll');
#         new news.ImageLazyLoader().load("img[data-src]");
#         new news.MoveTopButton("._go_top");
#
#
#         new news.HistoryManager().init("naver_mobile_news_history", "");
#
#         // iframe lazy-loading
#         (function(){
#             try {
#                 Array.prototype.slice.apply(document.querySelectorAll('iframe[data-src]'))
#                     .forEach(function(iframeEl) {
#                         var originSrc = iframeEl.getAttribute('data-src');
#                         if(originSrc) {
#                             iframeEl.setAttribute('src', originSrc);
#                         }
#                     });
#             }catch(e) {}
#         })();
#
#         if(typeof init === "function"){
#             init();
#         }
#
#         var cookie = news.Cookie.getInstance();
#         var isShownNewLnb = cookie.getItem("isShownNewLnb");
#         if(isShownNewLnb == null) {
#             isShownNewLnb = "Y";
#             cookie.setItem("isShownNewLnb", isShownNewLnb, 3650, "", "/");
#             $("._isNew").addClass("is_new");
#         }
#
#         {
#             var footerLogin = jQuery(document).find('._footer_login');
#             if(footerLogin <= 0) {
#                 return;
#             }
#
#             // 디바이스에 따라 로그인, 로그아웃 URL 분기
#             var loginUrl = "https://nid.naver.com/nidlogin.login";
#             var logoutUrl = "https://nid.naver.com/nidlogin.logout?";
#             if (news.Util.getAgentInfo().bMobileOrTablet) {
#                 loginUrl = "https://nid.naver.com/nidlogin.login?svctype=262144";
#                 logoutUrl = "https://nid.naver.com/nidlogin.logout?svctype=262144&";
#             }
#
#             if(news.LoginAssistor.isLoginUser()) {
#                 footerLogin.prepend('<a href="javascript:news.Util.logout(\''+logoutUrl+'url=\'+encodeURIComponent(location.href));" class="u_ftlk" id="news_logout" onclick="nclk(event,\'fot.logout\',\'\',\'\');" >로그아웃</a>')
#             }else {
#                 footerLogin.prepend('<a href="'+loginUrl+'" class="u_ftlk" id="news_login" onclick="nclk(event,\'fot.login\',\'\',\'\');" >로그인</a>')
#             }
#         }
#     }
# });
#   </script>
#   <script id="feedRefreshButtonTemplate" type="text/x-handlebars-template">
#    {{buttonText}}
#     <span class="paging">
#         <span class="blind">현재</span>{{currentPage}}
#         <em class="total"> / <span class="blind">전체</span>{{totalPage}}</em>
#     </span>
#   </script>
#   <script type="text/javascript">
#    FeedCard($('._journalist_feed_card_wrapper'), 'journalist', 'https://m.news.naver.com');
#     FeedCard($('._series_feed_card_wrapper'), 'series', 'https://m.news.naver.com');
#     BrickGridForEditByPress($("._brick_gid_wrapper"));
#     PressMainStatusCard($('._press_main_status_wrapper'));
#     NewsFlashCard($('._newsflash_wrapper'));
#
#
#
#
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#         adSlot.setCustomParam("calp", 'home');
#         window.gladsdk.displayAd(adSlot);
#
#
#         window.gladsdk.addEventListener(window.gladsdk.event.ERROR, function (ad, error) {
#             $("._card_ad").hide();
#         });
#     });
#
#     $('._channel_news_card_wrapper').each(function () {
#         var wrapper = $(this);
#         ChannelNewsCard(wrapper, 'https://m.news.naver.com');
#     })
#
#     ChannelNewsPreviewCard($('._channel_news_preview_wrapper'), 'https://m.news.naver.com');
#     SubscribeBannerShortCard($('._short_subscribe_banner_card_wrapper'), 'https://m.news.naver.com');
#     SubscribeBannerLongCard($('._long_subscribe_banner_card_wrapper'), 'https://m.news.naver.com');
#
#     WeeklySpecialReportCard($('._weekly_special_report_card_wrapper'));
#
#     $('._horizontal_card_wrapper').each(function () {
#         var wrapper = $(this);
#         HorizontalTypeCard(wrapper, 'https://m.news.naver.com');
#     });
#
#     SpecialReportCard($('._special_report_card_wrapper'), 'https://m.news.naver.com');
#
#     ArticleLinkParamsAppender('news_media_pc');
#   </script>
#   <script>
#    var gnb_service = 'news';
#     var gnb_logout = encodeURIComponent(location.href);
#     var gnb_template = 'gnb_utf8';
#     var gnb_brightness = 3;
#
#     doAfterLoadEnd(function () {
#         try {
#             GlobalMPUrlManager.init();
#         } catch (e) {}
#     });
#
#     doAfterLoadEnd(function() {
#         if (!document.querySelector('#gnb') || isMobileDevice() === true) {
#             return;
#         }
#
#         var gnb_src = "https://ssl.pstatic.net/static.gn/templates/gnb_utf8?2023043017";
#
#         // GnbHelper를 이용하여 GNB Layer를 닫을 수 있도록 지원한다.
#         if (window.jindo) {
#             jindo.LazyLoading.load(
#                 gnb_src,
#                 function() {
#                     try {
#                         getGNB();
#                     } catch(e) {}
#                 },
#                 'utf-8'
#             );
#
#             jindo.$Fn(function (oEvent) {
#
#                 GnbHelper.attachClick(oEvent.$value().target);
#             }).attach(document, 'click');
#         } else if (window.jQuery) {
#             new news.JsLoader().
#                 load(
#                     [gnb_src],
#                     function() {
#                         try {
#                             getGNB();
#                         } catch(e) {}
#                     }
#                 );
#
#             $(document).on("click", function(event) {
#                 GnbHelper.attachClick(event.target);
#             });
#         }
#     });
#   </script>
#   <script>
#    doAfterLoadEnd(function() {
#         if (!document.querySelector('.news_header')){
#             return;
#         }
#
#         try {
#             GnbFloatingManager.init();
#         } catch (e) { }
#     });
#   </script>
#   <script>
#    doAfterLoadEnd(function() {
#     try {
#         new SearchAutoComplete({
#             content: document.querySelector("._search_content"),
#             contentToggleBtn: document.querySelector("._search_content_toggle_btn"),
#             isMobile: isMobileDevice(),
#             nClickType: "newsM"
#         });
#     } catch(e) {}
# });
#   </script>
#   <!-- LCS -->
#   <script type="text/javascript">
#    function initMa(){
#     var data = {
#         "service": "news",
#         "baseInfo": {
#             "category": (function(){
#
#                 var result = "언론사별(신규)";
#
#                 if(result !== ""){
#                     return result;
#                 }
#                 try{
#
#                     return document.querySelector('meta[property="og:title"]')
#                         .getAttribute('content')
#                         .replace(/[\s]*:+[\s]*네이버[\s]*뉴스/, '');
#                 }catch(e){
#                     return "";
#                 }
#             })()
#         },
#         "extraInfo": {}
#     };
#
#
#
#     try{
#         ma.init({
#             api: "https://ma.news.naver.com/l",
#             data: data
#         });
#     }catch(e){}
# }
#   </script>
#   <script type="text/javascript">
#    var eventType = "onpageshow" in window ? "pageshow" : "load";
# jQuery(window).on(eventType, function() {
#
#
#
# lcs_do();
#
#
#     try{
#         initMa();
#     }catch(e){}
# });
#   </script>
#   <!-- //LCS -->
#   <div id="videoWrap">
#   </div>
#  </body>
# </html>

# %%
# bs.find_all
texts = bs.find_all('p')
for t in texts:
    print(t.string)
# Out:
# 물건을 먼저 구입하고 나중에 결제하는 '선구매 후불결제(BNPL)' 서비스의 연체율이 높아지면서 건전성에 대한 우려도 커지고 있다. 30일 국회 정무위원회 소속 최승재 국민의힘 의원이 금융감독원으로부터 받은 네이버파
# 'K팝 사상 최단 기간 빌보드 입성', '중소의 기적' 등의 영광스러운 수식어를 지닌 피프티피프티 활약에 제동이 걸렸다. 튀르계 가수 Evrencan Gündüz가 피프티피프티의 데뷔곡 '큐피드'가
# '축구 황제' 펠레의 이름이 '뛰어난, 비교할 수 없는, 유일무이한' 사람을 의미하는 형용사로 브라질 사전에 영원히 남게 됐습니다. 현지 시간으로 지난 27일 CNN, BBC 등 외신들은 '펠레'가 포르투갈어 사전에
# “한국인이 없어서 못타는 ‘독일차’…가수 위너도 반했다” 중고차 거래 플랫폼 KB차차차가 지난 1년간 한국인이 가장 많이 찾는 독일 3사(벤츠·BMW·아우디) 중고차 모델을 분석한 결과 벤츠 E클래스가 1위를 기록한
# 29일 오후 7시 무렵 전북 전주시 전북대 삼성문화회관은 사람들로 붐볐다. 제24회 전주국제영화제에서 첫 공개되는 다큐멘터리영화 ‘문재인입니다’를 보려는 이들이 대부분이었다. 일부 관객은 로비에 설치된 대형 영화 포
# 지난달 경기도 포천의 한 주택가 골목. 늦은 밤, 남성 세 명이 계속 주변을 두리번거리며 골목을 서성입니다. 다른 날에도 이 골목엔 같은 남성들이 찾아와 누군가를 기다리는 듯 한참을 서 있다 떠났습니다. 다음날인 2
# 간호법 제정 반대를 위해 단식 시위 중이던 곽지연 대한간호조무사협회장이 병원으로 이송됐다. 30일 오후 국회 앞에서 단식 농성을 벌이던 곽 회장은 보건복지부 조규홍 장관과 현장 의사의 권유로 병원에 응급 이송됐다.
# 요즘 4대강 사업의 주역들이 부쩍 대중 앞에 자주 등장하고 있다. 이명박 전 대통령(이하 존칭 생략)은 며칠 전 측근 유인촌의 연극을 관람했고 앞으로 4대강도 방문할 예정이라고 한다. 4대강 추진본부장이었던 심명필은
# 남북이 가장 가깝게 총구를 맞대고 있는 곳, 최북단 철책에는 24시간 경계를 펴고 있는 최전방 사단이 있습니다. 과학화 경계시스템으로 보다 정밀한 임무를 수행하는 7사단 GOP 장병들의 모습을 임성재 기자가 보도합니
# There's a certain phrase that goes, “No matter how good you are at gaming, there’s always a Korean better than you.” And
# 시민단체 직장갑질119는 올해 지난 26일까지 받은 이메일 제보 중 직장 내 괴롭힘 피해 호소가 전체의 61.3%에 달했다고 밝혔습니다. 구체적 유형으로는 따돌림과 차별·보복이 절반을 넘었고, 이어 폭행·폭언, 부당
# 기사내용 요약 펜션서 20대 여성 강제추행한 혐의 대법 유죄 판단…징역 10개월 확정 [서울=뉴시스] 류인선 기자 = 펜션에서 여성을 강제추행한 혐의로 재판에 넘겨진 그룹 '비에이피'(B.A.P) 출신 멤버 힘찬(김
# 국민의힘 김기현 대표는 음주운전으로 적발된 적이 있는 운전자의 차량에 '방지 장치를 의무적으로 부착'하도록 하는 도로교통법 개정안을 내일(오는 1일) 대표 발의한다고 오늘(30일) 밝혔습니다. 이 법안은 김 대표가
# 프랑스 명품 브랜드 루이비통이 서울 잠수교에서 개최한 국내 첫 패션쇼가 성황리에 마무리됐다. 루이비통은 지난 29일 오후 8시 서울 잠수교에서 프리폴(Prefall) 패션쇼를 열었다. 정규 가을·겨울(F/W) 컬렉션
# (410) 김상현의 정교한 샷 한국프로골프(KPGA) 코리안투어가 개막하는 매년 4월, 주목받는 한 선수가 있습니다. 전년도 스릭슨투어 상금왕 김상현입니다. 2부 투어지만 지난해 정규투어에서 2번의 우승을 포함해 1
# 의사와 간호조무사 등이 간호법 제정안과 의료법 개정안(의사면허취소법)의 국회 본회의 통과에 반발, 총파업을 예고했다. 30일 의료계 등에 따르면 의사와 간호조무사 단체 등 13개 보건의료단체가 참여하는 보건복지의료연
# 지속적 정자 기증으로 전 세계에 550명의 자녀를 둔 것으로 알려진 40대 네덜란드 남성에게 '정자 기증 금지령'이 내려졌다. 지난 28일(현지시간) 영국 BBC, 가디언 등은 네덜란드 국적의 조너선 제이컵 메이어르
# 5월부터 행정안전부가 운영하는 ‘안전신문고’ 누리집과 어플리케이션(앱)에서 불법 숙박업소를 신고할 수 있다. 숙박업소는 업종에 따라 여러 부처에서 관할하고 있다. 보건복지부가 모텔 등 일반숙박업과 생활숙박업, 농림축
# 조 바이든 미국 대통령이 30일(현지 시간) 트위터에 “한미동맹은 공동의 국경선이 아니라 공통의 신념에서 탄생했다”며 “그것은 민주주의, 자유, 안보(democracy, liberty, security)이고 무엇보다
# 코미디언 겸 사업가 고(故) 서세원씨의 한국 장례식이 30일인 오늘부터 한국코미디언협회장으로 치러지고 있다. 동료 코미디언 이용식씨와 엄영수씨(개명 전 엄용수) 등이 빈소를 찾아 고인을 애도했다. 30일 뉴스1에 따
# Similar to South Korea, North Korea is grappling with tumbling childbirths. The cause, however, is starkly different: fa
# 애플워치가 향후 아이폰 뿐 아니라 아이패드, 맥 등 다른 애플 기기와도 연동될 수 있다는 소식이 나왔다. IT매체 폰아레나는 27일(현지시간) 트위터 이용자 @Analyst941를 인용해 애플이 애플워치를 아이패드,
# 러시아 전투기가 미군 전투기의 조종석 화면에 보입니다. 이후 날개를 움직여 기체 방향을 틀기도 합니다. 이 전투기는 빠르게 이동하며 결국 시야에서 사라집니다. 현지시간 지난 18일 시리아 상공에서 미군 전투기에 목격
# '강직한 검사'는 어떻게 '가해자'를 변호하게 됐는가 한국 사회에서 보통 검사는 옷을 벗으면 '전관 변호사'가 된다. 엊그제 범죄자를 잡아 넣던 검사는 오늘 범죄자를 변호한다. 이상한 모습이지만 자연스러운 모습니다.
# 벨기에에서 30대 남성이 인공지능(AI) 챗봇의 부추김을 받아 스스로 목숨을 끊었다고 3월28일 벨기에 일간지 〈라리브르(La Libre)〉가 보도했다. 여러 언론의 추가 보도를 종합해 사건을 재구성하면 이렇다. 피
# 생후 40일 아이를 떨어뜨리고도 방치해 숨지게 한 혐의를 받는 20대 중증 지적장애인 친모 A씨가 30일 오후 구속 전 피의자 심문(영장실질심사)을 받기 위해 인
# 대구시 북구 대현동 이슬람 사원 건축공사 논란이 3년째 계속되고 있습니다. 주민 반대를 넘어 사회적 갈등으로 확산하고 있는데요, 이슬람 사원 건축을 놓고 지역 주민들이 대구 북구청에 탄원서를 제출하면서 2021년 2
# 활동 무대 옮겨가며 미성년자 성 착취하는 ‘유사 N번방’ 기승 “◯◯팸 옵챗(오픈채팅) 들어가지마셈.” 온라인 커뮤니티 디시인사이드의 ‘우울증 갤러리’에는 최근 이 같은 내용의 게시물이 여러 건
# 산불 여파로 관광객 감소를 우려했던 것과 달리 황금연휴를 맞아 관광객들이 강릉지역에 대거 방문해 지역사회가 안도하고 있다. 근로자의 날(1일)까지 이어지는 황금연휴를 맞아 주말동안(29~30일) 강릉지역 유명 관광지
# 대만에서 한국인 여성 관광객이 현지 호텔에서 숨진 채 발견된 가운데, 현지 수사당국은 이 여성과 동행했던 한국인 남자친구를 긴급 체포했다. 30일(현지시간) 대만연합보는 지난 24일 낮 12시30분쯤 남부 가오슝 첸
# 강제추행 혐의로 기소된 남성그룹 B.A.P 출신 김힘찬(활동명 힘찬·33)씨가 대법원에서 실형을 확정했다. 30일 법조계에 따르면 대법원 3부(주심 대법관 오석준)는 최근 김씨의 상고를 기각하고 징역 10개월을 선고
# 미국의 한 여성이 놀이공원에서 롤러코스터를 탄 후 신장결석이 제거됐다고 주장해 관심을 모으고 있다. 이 여성은 롤러코스터 탑승이 신장결석 배출에 도움이 된다는 연구결과를 보고 이 같은 행동을 한 것으로 전해졌다. 지
# 김영민 교수 책 <인생의 허무를 어떻게 할 것인가> 벚꽃이 만개해 세상이 연분홍빛으로 뒤덮였다. 비가 내리자 벚꽃나무 가지만 남았다. 오랜만에 해가 떠 있는 시간에 퇴근하니 회사 앞에 안 보이던 철쭉들이 진분홍 길을
# 네이버가 불공정 논란이 일었던 뉴스콘텐츠제휴 약관을 전면 수정해 재공지했다. 네이버는 28일 오후 뉴스콘텐츠제휴 언론사들에 이메일을 보내 “(기존 약관 대신) 추가 수정한 개정 약관으로 재동의를 구하고자 한다”며 “
# 윤석열 대통령은 이번 미국 국빈 방문 기간 ‘1호 영업사원’으로서 경제 부문 성과를 위해 바쁘게 움직였다. 윤 대통령은 첨단 산업·에너지 분야 등 50건의 양해각서(MOU)를 체결했고, 59억 달러(한화 약 7조 9
# 지난 27일 출시한 모바일 MMORPG '나이트크로우'가 출시 4일 만에 구글플레이 스토어 매출 순위 2위를 기록했다. 그간 글로벌 지역을 중심으로 블록체인과 관련 기술을 탑재한 게임 플랫폼을 운영해온 위메이드는 나
# 곤충이나 무척추동물이 주식인 개구리는 육식성 동물로 알려져 있다. 하지만 어떤 개구리는 식물의 열매나 꿀을 맛있게 먹는 초식성 식습관을 가졌다는 연구 결과가 나왔다. 열매를 먹는 과정에서 꽃가루를 옮기며 식물의 수분
# 박지원 전 국가정보원장이 30일 대통령 안보실 김태효 1차장이 물러나야 윤석열 정부 외교가 살 수 있다고 주장했다. 이와 함께 윤석열 대통령이 '아메리칸 파이' 열창 시 한 소절만 부르고 말았다면 조 바이든 대통령과
# "통정매매 가담…처벌대상 될 수 있어" 가수 임창정 씨가 연일 화제의 중심에 서있다. 최근 외국계 증권사 소시에테제네랄(SG) 증권발(發) 주가 하락 사태와 관련해 수십억 원의 손해를 본 것으로 알려지면서다. 현재
# 직장인 익명 커뮤니티 블라인드에 삼성전자 신입 사원이 남긴 패기 넘치는 글이 화제다. "이재용 회장에게 사내 메신저로 '뽑아주셔서 감사하다'는 인사를 보내도 되냐"는 내용인데, 정작 이 글보다 이에 대한 베댓(베스트
# 영국 일각에서 ‘미·영 관계 소홀’ 비판 바이든 대통령 아일랜드계인 것이 영향? 역대 美대통령 중 참석 전무 조 바이든 미국 대통령의 영국 찰스 3세 국왕 대관식 불참 때문에 논쟁이 이어지고 있다고 29일(현지시간)
# ■ 4월인데 40도…폭염에 가뭄까지 폭염이 스페인을 덮쳤다. 26일 남부 세비야는 오후 5시에도 섭씨 40도까지 치솟았고, 27일 코르도바는 38.8도를 기록했다. 관측 이래 4월 최고 기온, 평년보다 10~15도
# 부산에 본사를 둔 중앙정부 산하 공공기관 절반이 지난해 영업적자를 낸 것으로 나타났다. 코로나19 장기화와 원자재 가격 상승 등으로 경영이 악화됐기 때문이다. 이 때문에 지역 공공기관 상당수는 기관장 연봉을 삭감했다
# "그건 안 돼요. 원점회귀해야 됩니다." "왜요?" "반려견은 케이지 없이 지하철 못 타요." "아." 우리의 대화는 대체로 이랬다. 쳇바퀴 돌 듯 어려움과 이해가 거듭됐다. 반려견을 동반해 움직인다는 것에 무지한
# 대만에서 여행중이던 30대 한국인 여성이 호텔에서 사망하면서 현지 수사당국이 조사에 나섰습니다. 대만 검찰은 여성과 동행한 남성을 유력 용의자로 보고 긴급체포했습니다. 대만 현지 보도 등을 종합하면 현지시각으로 지난
# 여성들의 말과 글이 세상에 더 많이 퍼지고 새겨져야 한다고 믿으며, 서점에서 퍼뜨리고 싶은 여자들의 책을 고른다. ‘살롱드마고’의 신간 책장에서 마음에 새겨지는 책을 한 권씩 밑줄 그으며 꼭꼭 씹어 독자들과 맛있게
# "아무도 없어서 외로웠는데 바로 윗선배가 나타나니까 활짝 웃네" 코미디언 이용식씨가 최근 캄보디아에서 숨진 방송인 출신 사업가 고(故) 서세원씨의 빈소를 찾아 후배에게 마지막 작별 인사를 했다. 이씨는 30일 서울
# 하이브 직원들이 글로벌 아티스트 방탄소년단(BTS)의 단체활동 중단 전 내부 정보를 활용해 주식을 매매한 혐의로 수사를 받고 있는 것으로 알려졌다. 30일 조선일보 보도 등에 따르면 수사당국은 하이브 직원 일부에 대
# 다음 달 10일 개봉…"5년간 이룬 성취 무너져 허무" 발언은 빠져 문재인 전 대통령의 퇴임 후 일상을 보여주는 이창재 감독의 다큐멘터리 영화 '문재인입니다'가 29일 전주국제영화제에서 공개됐다. 이 영화는 이날 저
# 남자친구와 대만 여행 중이던 30대 한국 여성이 호텔에서 숨진 채 발견돼 현지 경찰이 조사에 나섰다. 30일 대만 자유시보 등 현지 매체에 따르면 지난 24일 오후 1시 30분께 가오슝의 한 호텔에서 A(31) 씨가
# 박지원 “尹, 한 소절 더 했으면 바이든과 듀엣” 대통령실 “바이든 노력 알기에 한 소절 부른 것” 대통령실은 30일 윤석열 대통령이 지난 26일(현지 시각) 백악관 국빈 만찬에서 ‘아메리칸 파이’를 부른 것과 관련
# 조 바이든 미국 대통령이 내년 대선에 출마하겠다고 공식적으로 선언했다고 AP 등 외신이 4월 25일(현지 시간) 보도했다. 보도에 따르면 바이든 대통령은 이날 온라인에 공개한 선거 운동 영상에서 “일을 마무리 짓겠다
# 30대 다문화여성이 4살 아들을 살해하고 경찰에 자수했습니다. 충북 청주 흥덕경찰서는 우즈베키스탄 국적의 30대 여성 A씨를 살인혐의로 붙잡아 조사하고 있습니다. A씨는 29일 오전 3시 40분쯤 청주시 흥덕구 자택
# 이번 주 금융시장이 가장 주목할 국내 경제지표는 통계청이 내놓는 4월 소비자물가지수(CPI)다. 올해 들어 물가 상승세가 둔화하고 있는 가운데, 이같은 추세가 이어졌는지가 관건이다. 통화당국의 기준금리 방향성도 결국
# 윤석열 대통령이 30일 5박 7일 간의 미국 국빈 방문을 마치고 귀국했다. 윤 대통령과 부인 김건희 여사는 이날 오후 전용기인 공군 1호기 편으로 서울공항에 도착해 미리 나와 있던 환영객들과 인사했다. 윤 대통령은
# 미국을 국빈 방문한 윤석열 대통령이 참석한 행사에 배우 이서진이 모습을 나타냈다. 윤 대통령은 지난 27일(현지시간) 워싱턴DC 미국영화협회(MPA) 건물에서 개최된 ‘글로벌 영상콘텐츠 리더십 포럼’에 참석했다. 이
# # 때만 되면 포털 뉴스란에 심심찮게 등장하는 단어가 있습니다. 수상택시입니다. 그 옆에는 늘 함께 붙어다니는 말이 있습니다. 서울시입니다. # 서울시는 2005년부터 서울의 교통혼잡을 완화하기 위한 대안으로 수상택
# 코로나19 백신 개발로 급성장한 미국 제약사 모더나의 스테판 방셀 최고경영자(CEO)가 지난해 스톡옵션(주식매수청구권)으로 거액을 번 사실을 드러나 논란이 일고 있습니다. 미국 워싱턴포스트(WP)는 방셀 CEO가 지
# 민생 드라이브로 '돈봉투' 국면전환 모색…정책 제안으로 정부 비판 효과도 더불어민주당 이재명 대표가 최근 부쩍 자주 현장을 찾고 있다. 이 대표는 지난주에는 전세 사기 피해자 간담회(24일), 이른바 '지옥철'로 불
# 지난 20일 캄보디아에서 갑작스레 별세한 방송인 서세원 씨의 빈소가 마련된 서울아산병원 장례식장에 조문의 발걸음이 이어지고 있다. 빈소에는 가수 김흥국과 설운도, 각 방송사와 엔터테인먼트사, 고인과 인연이 있던 각계
# 80~90년대 ‘생활영어’로 명성을 얻은 ‘1세대 영어 강사’ 오성식 씨가 윤석열 대통령의 미 의회 연설에 대해서 “윤 대통령이 영어에도, 스피치에도 일가견이 있더라”며 “이번 스피치는 정말 만점이었다”고 평가했다.
# 159명의 청년이 목숨을 잃은 이태원 참사가 6개월을 맞았다. 반년의 시간이 흘러 봄이 왔지만, 유족들에게 치유의 시간은 아직 허락되지 않고 있다. 유족이 애타게 알고 싶은 ‘그날의 진실’이 여전히 베일에 싸여 있기
# 이종호 JW그룹 명예회장이 30일 오전 향년 90세로 별세했다. 고인은 ‘제약구세’(製藥救世)의 일념으로 약다운 약을 만들어 국민 건강을 지키는 제약보국 실현에 앞장서왔다. JW그룹에 따르면 세브란스병원에서 입원 중
# 미국을 국빈 방문 중인 윤석열 대통령은 28일(현지시간) 오후 보스턴 하버드대 케네디스쿨에서 진행한 연설 이후 조지프 나이 하버드대 석좌교수와의 토론 및 학생 질의응답에서 "대한민국은 핵무장을 하겠다고 마음을 먹으면
# 중국이 우리나라 반도체 산업에 대한 압박에 나섰다. 원산지 점검과 통관 검사 강화 조치에 이어 우리 기업의 중국 수출 계약 취소 사례까지 등장, 미-중 갈등으로 인해 국내 기업 피해가 가시화되는 것이 아니냐는 우려가
# '더불어민주당 2021년 전당대회 돈봉투 살포 의혹'과 관련한 검찰의 압수수색을 '물극필반(物極必反·사물의 전개가 극에 달하면 반드시 반전한다)'이라고 주장한 민주당 송영길 전 대표를 향해 국민의힘은 '사필귀정(事必
# 금기어 깨트린 윤 대통에게 러시아․중국 강하게 반발 상황에 따라 각기 입장 달리하는 英․ 佛․獨 태도 되새겨야 윤석열 대통령이 러시아와 중국의 적대적 행위에 엄중한 경고를 보냈다. 로
# 이태원 참사 희생자 분향소 운영을 두고 서울시와 유족의 갈등이 3개월째 이어지고 있다. 앞서 서울시는 이태원 참사 유가족협의회(유가협)와 시민대책회의에 2023년 2월4일부터 4월6일까지 무단점유한 서울광장 72㎡에
# ◀ 앵커 ▶ 석달 앞으로 다가온 세계잼버리를 앞두고, 지구촌 50여 개국 스카우트 대표단이 부안 새만금 현장을 찾아 막바지 점검을 진행했습니다. 만일의 사고를 대비하고 개선 사항을 점검하기 위한 시범캠프를 방문한 건
# 다큐멘터리 <문재인입니다>가 지난 29일 오후 전주국제영화제에서 처음 공개됐다. 영화를 연출한 이창재 감독은 이날 전북대 삼성문화회관에서 열린 상영회 무대에 올라 “영화가 이번주에 만들어졌다(완성됐다)”며 “제가 1
# 넷플릭스 코리아 '성+인물' 신동엽, 성시경 진행 맡아 일본 AV 배우·호스트 인터뷰 국내 불법인 AV 성 산업 조명 여성 배우 성착취 문제 언급 없어 넷플릭스 코리아가 제작한 예능 '성+인물 : 일본편'이 공개된
# 제주자치도청 여성 공무원도 남성 공무원과 똑같이 밤낮 구분 없는 당직근무에 투입됩니다. 제주자치도는 5월인 내일(1일)부터 여성 공무원도 일직·숙직 구분 없이 당직근무 대상자로 근무명령을 내렸다고 밝혔습니다. 양성통
# 윤석열 대통령이 30일 5박7일 간의 미국 국빈 방문을 마치고 귀국했다. 윤 대통령과 부인 김건희 여사는 이날 오후 전용기인 공군 1호기 편으로 서울공항에 도착해 미리 나와 있던 환영객들과 인사했다. 지난 24일 출
# 윤석열 대통령의 5박7일 국빈 방미 일정이 끝난 가운데 일부 언론이 외교 성과를 냉정히 짚기보다 지난 28일 대통령의 미 의회 '영어' 연설을 지나치게 띄워줘 일련의 보도 행태가 전두환 5공 시절을 떠올리게 한다는
# 영화 제작사 “정치적으로 해석될 수 있는 부분은 가급적 뺐다” 문재인 전 대통령이 지난 27일 오후 경남 양산시 하북면 평산책방에서 오픈 기념 강연(정지아 작가와의 만남)에서 인사말하고 있다. 양산=연합뉴스 “5년
# 정부가 우리 농업의 미래와 식량주권 확보를 위해 '가루쌀' 보급·육성에 사활을 걸고 있습니다. 농림축산식품부(장관 정황근)는 '2024년도 가루쌀 전문 재배단지 육성사업' 지원 대상자를 모집한다고 30일 밝혔습니다.
# 이철규 국민의힘 사무총장 ● “대선 경선 치르며 처음 인연 맺었다” ● 당 사무총장, 살림하고 책임지는 자리 ● 공천 1순위는 주민 위해 봉사할 인물 ● 尹, 쓴소리에 귀 닫지 않는 열린 마음 소유자 ● 검사 많다고
# 문재인 전 대통령의 퇴임 후 일상을 다룬 다큐멘터리 영화 '문재인입니다(5월 10일 개봉)'가 지난 29일 전주국제영화제에서 처음 상영됐다. 개봉 전 선공개 당시 "5년간 이룬 성취가 무너졌다"는 문 전 대통령 발언
# 간호법 제정안 저지를 위해 지난 25일부터 국회 앞 단식을 이어 온 곽지연 대한간호조무사협회장이 30일 건강 악화로 병원에 후송됐다. 지난 27일 간호법 및 의사면허 취소법이 더불어민주당 주도로 국회 본회의에서 강행
# 캔을 뚜껑째 열어 맥주잔처럼 마실 수 있는 일본 ‘아사히 수퍼드라이 생맥주’ 제품이 5월 국내에 한정 출시되는 가운데 며칠 앞서 코스트코에 입고된 상품을 사기 위한 ‘오픈런’ 경쟁이 치열한 것으로 나타났다. 일본에서
# 윤석열 대통령은 역대 대통령들과 다른 별종의 지도자인 것 같다. 박정희 정권 이래 지난 60여년간 대한민국의 대통령은 보수, 진보를 막론하고 자신의 기질과 상관없이 대외정책에서 한반도 정세의 안정을 기하는 방향에서
# 대만에 여행 간 한국인 여성 관광객이 현지 호텔에서 숨진 채 발견됐다. 이 사건과 관련해 현지 수사당국은 여성과 동행한 한국인 남성을 체포했다. 30일(현지시간) 대만연합보는 지난 24일 낮 1시 30분께 대만 남부
# None
# [클린룸]“취임 후 한국으로부터 1000억 달러 유치”...더욱 선명해진 바이든의 속내
# “그 ×은 여자친구 엄마 불러 그 앞에서 딸을 살해했다”…목숨 걸고 이별 통보?[전국부 사건창고]
# [법안 톺아보기] 제동 걸린 ‘北 도발 생존 장병 특별법’, 원인은 또 ‘형평성’ 논란
# [뉴스 즉설]시치미 뚝 송영길, 동문서답 이재명, '돈봉투 민주당' 뭐가 중한디?
# [픽&톡]"마스크 벗었다고 코로나 끝난 게 아니다"
# [뉴스 즉설]영길이 형 아웃, 7인회 해체, 이재명 퇴진… 돈봉투 후폭풍 어디까지
# [줌인] 충청 인구감소 가속화
# 대통령실 “핵공유 용어 집착 필요 없다, 나토보다 더 실효적”
# ‘빈털터리 외교’ 비판에…대통령실 “한국기업 부담 최소화” 진화
# 윤 대통령, 하버드서도 ‘자유’…“민주로 위장한 이들 경계해야”
# 윤 대통령, 테슬라 공장 유치? 업계선 “굳이 한국 올 이유가…”
# "20대 대학생도, 노인도 쓴다"…자고 나면 신고가 찍는 이 종목 [윤현주의 主食이 주식]
# "너도 물렸어? 나도"…'46만원→20만원' 반토막에 개미들 비명 [윤현주의 主食이 주식]
# "급락 위험" 전문가 경고에도…개미들 우르르 몰려간 곳 [박의명의 불개미 구조대]
# '무더기 주가 폭락' 사태 주범 CFD, 신규 가입·매매 막는다
# SK하이닉스가 HBM에 진심인 이유 <2> [강해령의 하이엔드 테크]
# 금도끼 줄까 은도끼 줄까…아님 구리? [코주부]
# 반도체 기업 엔비디아, AI '헛소리' 해결 나선 이유는?[AI토피아]
# “위기를 기회로” 美 제재에 반도체 투자 쏟아내는 中[뒷북 글로벌]
# “석열아, 먼저 손 내밀고 더 많이 들어라” [+영상]
# “尹, 술 마실 땐 ‘통 큰 사람’… 정치는 통 크게 못했다” [+영상]
# ‘길복순’ 전도연 “집에선 아이에게 쩔쩔매는 엄마예요”
# [+영상]‘살아있는 천사’ 트로트가수 허송이 7번 아이언으로 일군 기적
# [스타트UP] 태블릿 하나로 매장관리 끝… 클라우드 POS ‘페이히어’
# [스타트UP] “세상은 무대, 모두는 플레이어”… 체험 콘텐츠 대명사 된 ‘유니크굿컴퍼니’
# [스타트UP] “덕질 편하게 하세요”… 크리에이터·팬 연결 플랫폼 ‘팬심’
# [스타트UP] 도우미·청소·이사… 200여개 홈서비스를 한번에
# [월드리포트] 확장억제 성과 논란…'말의 성찬'이 부른 후과
# '워싱턴 선언' 잘 모르는 국방부…한미 협의 잘 된 건가 [취재파일]
# [사실은] 윤 대통령 '일본 무릎' 발언, 워싱턴포스트에 직접 물었습니다
# [월드리포트] 일본 남성 아이돌 대부 '성착취' 의혹…주류 언론 나서나
# 가족모임 많은 5월, "외식비 부담돼요"…치킨·삼겹살 등 줄인상
# [남궁창성의 용산리포트] 16. 김건희 여사의 국빈방미 내조 외교
# 1분기 전국 아파트 거래 4명중 1명은 30대…2019년 이후 최대
# [최동열의 산썰(山說)] 6.산에서 어명을 받은 소나무들
# 외신 "美, 韓 핵무장론 달래기 시도…핵잠 기항 동북아 불안정 키울 것"
# 워싱턴선언 '동상이몽'? 대통령실 "사실상 핵공유" 美당국자 "핵공유 아냐"
# 尹대통령 '워싱턴선언' 후속행보, 한미 '핵공유' 온도차
# '자체 핵무장' 주장 태영호 "尹대통령에 영업왕 칭호까지 줘야겠다"
# 모두가 “나도 피해자” 호소…SG사태, 주범은 어디에
# 임창정 측 “주가조작단 ‘1조 파티’, 초대손님일 뿐 내용 몰랐다”
# SG사태 임창정이 피해자? “공범이냐 아니냐를 논해야”
# 아쉬움 많지만, 가상자산 제도화 성과…A- 학점
# 갈등으로 정책 공백, 범부처 통합논의장은 '긍정적'...C학점
# 플랫폼 '지원vs규제' 놓고 정부-국회 엇박자...B학점
# 식민지 조선 위해 싸운 두 일본인.. '5월의 독립운동가'되다
# 어디 '학폭' 뿐이랴.. '직장내 괴롭힘'에 신고조차 못해 "출근길이  지옥"
# "5년 성취 무너져" 발언 빠져.. 영화 '문재인입니다' 공개
# '4.3' 발언 등 막말 콤비에, 국힘 윤리위 '칼' 빼들까?.. 민주 "징계로 품격 되찾길"
# 정통 워맨스, 그런데 킬힐 못 벗은 언니들의 '퀸메이커'
# 한국 여성작가 100인, 프랑스 파리서 새로운 'K아트' 가능성을 열다
# 피해자 보호 관점 실종된 '나는 신이다' 열풍
# 60대에 '별의 순간' 양자경...트랜스젠더 연기로 8세에 은곰상
# [효자 車보험]㊤아픈 손가락은 옛말
# [효자 車보험]㊥돈 냄새 맡은 중소 손보사들
# [효자 車보험]㊦치솟는 한방 진료비 논란
# "尹 연설, 홈런 쳤다"…김연아·MB 영어과외 美선생님 놀란 장면
# 尹방미 경제 성적표는…NSTC·SMR동맹 '윈윈' IRA·반도체법 '아직'
# "편한 복장에 배낭 메고"…尹 하버드 연설회장에 참석한 박영선
# "바이든의 요청, 거절할 수 없어 한소절"…尹열창 뒷이야기
# [PK 총선 일타강의] 재선 여부 ‘부산 여성 정치’ 변곡점… 가장 큰 과제는 ‘공천’
# 국내외 복합리조트 ‘러시’… 부산만 발 묶였다
# [단독] 부산공동어시장 현대화사업, 좌초 위기 갈등 끝 가까스로 봉합
# [단독] “밑그림 부실”… 급제동 걸린 거제 국가정원 사업
# 윤 대통령 "마음 먹으면 1년 이내 핵무장 가능하지만..."
# 윤 대통령 "전체주의가 민주주의 위협, 민주세력으로 위장"
# '사실상 핵공유'는 성과 부풀리기? 대통령실 "용어 집착할 필요 없어"
# 5년 전과 정반대, 미국만 바라보는 한국 대통령 [김종성의 '히, 스토리']
# 원빈·이나영 절반씩 매입한 빌딩이 5년 만에 300억대로[누구집]
# 산 속 '단독주택 라이프' 김대호 아나운서 집은 어디?[누구집]
# '눈누난나' 히트 가수 제시, 한강뷰 집은 어디?[누구집]
# 박명수 아내, 낡은 빌라 '스벅 모시기'로 100억 재테크[누구집]
# 5대 동맹 강화로 미래 70년 초석 다졌다
# [韓美 정상회담] 반도체·양자 협력 강화… 尹·바이든, 기술동맹 `의기투합`
# [韓美 정상회담] 尹, 국빈 만찬 건배사… "강철같은 동맹을 위하여!"
# [전문]尹대통령, 美의회서 30여분간 영어 연설…자유 46회 언급, 박수 60여 차례 받아
# “극초음속도 막는다”… 미사일 위협 키우는 북한, 한국 ‘하늘의 방패’ 세운다 [박수찬의 軍]
# 등록 반려묘 수 1%에 그쳐… 강제성·처벌 규정 없어 ‘헛바퀴’ [이슈 속으로]
# “직항·비자·인력 개선해줄게”…중국 관광객에 내민 3국 3색 [박종현의 아세안 코너]
# 누워도 괜찮아… 지친 말들의 낙원 [밀착취재]
# 반도체냐 배터리냐 그것이 문제로다
# 배터리 리사이클링 부각한 유럽판 IRA ‘핵심원자재법’
# 애플페이 상륙으로 불붙은 ‘간편결제 大戰’
# 월 소득 4000만 원으로 주담대 먼저 갚으세요
# 호텔뷔페 18만원·한우갈비 11만원 …"비싸도 팔려" 배짱영업
# 외식물가 30년만에 최고…양파·무 관세 낮춰 공급 확대
# 서민메뉴 떡볶이마저 30% 뛰었다
# 韓 상륙 수제버거 美보다 20% 비싸
# "진료비 많이 주면 비대면도 오케이" 의사의 태세전환 이유
# 국회에 법안 4개 발의됐지만…여야 막론 약사·의사 의원들 반대
# 초진 허용두고 전세계도 갈렸다… 플랫폼 vs 의료계 피터지는 이유
# 24년 묵히다 다시 '시계 제로'…결국 中에도 밀린 韓 비대면 진료
# [네팔, 나를 찾아가는 먼길]묘하게 잊히지 않아…세 번째 찾아간 ‘신들의 땅’
# '기시다, 5월 7∼8일 윤 대통령과 한국서 정상회담 추진' 日보도에 대통령실, "결정된 바 없다"
# “자격증 따러 왕복 6시간” … 강원도 취준생의 한숨
# [르포]괭이로 고사리 싹쓸이…임산물 불법 채취 기승
# 美연준, SVB사태 책임 인정…"당국 감독 실패"
# 美육군, 잇따른 충돌 사고에 "모든 항공기 운항 중단"
# "美, 대반격 앞둔 우크라에 '핵전쟁 감시망' 구축"
# 무섭게 큰 위안화, 달러 추격 중...'통화 패권' 이동하나
# [뉴스야?! 단독] 단호해진 김기현?
# [따져보니] '조작 의혹'에 대폭락…CFD가 뭐기에
# [포커스] '가짜뉴스' 몸살 앓는 지구…곳곳서 '전쟁'
# [따져보니] 주가조작 피해자인가 공범인가
# 교대가 등록금 인상 앞장선 이유는?
# 살아남는 배터리가 강하다, LFP는 강하다
# 1년 뒤 총선, “모욕 정치”·“분열 정치” 이대로 괜찮나 [창+]
# 명동의 봄은 이제 시작…다음 주까지 ‘명동 페스티벌’ [주말엔]
# [THINK ENGLISH] 이르면 올해 거리에서 배달 로봇 보게 될 듯
# [THINK ENGLISH] 윤 대통령, 전세사기 매물 경매 중단 지시
# [THINK ENGLISH] 조선 회화사의 공백 채울 걸작들의 귀환
# 한국의 금융 산업을 이끄는 30인은 누구인가 [2023 파워 금융인 30]
# 세계 최초의 자율 주행차를 누가 죽였나…한국 금융산업을 옥죄고 있는 그 무엇[EDITOR's LETTER]
# 윤종규 KB금융그룹 회장, 비은행 포트폴리오 다각화 결실...“넘버원 금융 플랫폼으로 진화” [2023 파워 금융인 30]
# 호텔에 ‘헬로 카봇’ 떴다? 아빠는 또 지갑을 열었다 [언박싱]
# [인터뷰] “신형 코나는 전기차가 원조”…악동+미래지향적 디자인 ‘매력’
# “핵 보장 첫걸음” “경제성과 아쉬워”…한미정상회담 엇갈린 평가[국빈방미 결산]
# "뉴스서 본 그 해열제·김, 우리 애도 먹였는데"…불량식품 급증 '이것' 때문? [채상우의 미담:味談]
# [개미가 궁금해] '무더기 하한가' 예고된 재앙…CFD 거래 허점 '화 불렀다'
# [개미가 궁금해] '매도는 예술' 몸소 증명한 김익래 회장…SG증권 폭락 사태 알았을까?
# [개미가 궁금해] 가상자산 투자자 보호 '첫발'…불공정거래시 손해배상.과징금 부과
# 도대체 바닥은 어디일까...제주 아파트값 3억씩 ‘뚝뚝’ [김경민의 부동산NOW]
# “이러다 20억 다시 찍으려나”...마포 집값 슬금슬금 오른다 [김경민의 부동산NOW]
# 용인 반도체 클러스터 수혜지 어디?...이천·동탄 등 경기 남부 ‘반세권’ 뜬다[김경민의 부동산NOW]
# 아파트 이름만 무려 25글자?...“길고 어려운 아파트명 쉽게 바꾸자”
# 경기도, 내년 ‘인구인지예산’ 편성…저출생·고령화 대응 나선다
# 직장갑질119, "괴롭힘·야근·징계해고 '3대 갑질' 만연"
# 산재보험도 ‘부익부빈익빈’… 소규모 업체 가입 외면 [경기도 근로자 재해실태 보고서_15]
# '간호법' 통과...의사, 간호조무사 "4일 부분 파업", 전망과 쟁점은?
# '워싱턴 선언' 연일 설전...與 "흠집내기 골몰" 野 "정신승리"
# 尹 "우크라 전황 예의주시...다양한 옵션 있을 수도"
# 尹 "자유와 민주주의 지키려면 용기와 연대 필요"
# 5박 7일 국빈 방미 공식일정 마무리...성과와 과제는?
# '시장이 지금 아닌 하반기를 보는 이유'…주도권 잡을 삼성 반도체
# 2Q부터 감산효과…삼성 반도체 '봄날' 기다린다
# K반도체 '새우등 터질라'…정부역할론 절실
# 토요일밤 루이비통 모델들의 런웨이된 한강 잠수교
# ‘전세사기 공포’에 100만원 넘는 오피스텔 월세 급증
# “김정은처럼 변해가는 몸, 되돌리는 비결은…”[이용권 기자의 Health 이용권]
# 크림반도서 연료탱크 폭발...우크라선 러 폭격으로 어린이 등 26명 사망
# 질병청 “피해조사전문위원장 마취심사 없었다”…'부실조사' 의혹 무슨 일이?
# 2년 전 피해 아직 진행형…“개인 아닌 사회적 재난” 호소
# 해운대구도 터지나…전세사기 의심 대거 발견돼 당국 조사
# 정부, 전세사기 피해자에 우선 매수권 등 특례 부여
# [정승조의 아트홀릭] 미술관이 가장 잘하는 걸 안 볼 이유는 없다
# [아무튼, 자수] 꽃보다 그녀 ‘세월을 수놓다’
# ‘우주 최초 수달 공무원’ 충주씨의 귀한 실물 사진 보러오세요
# [명품 컷] 비 오는 날의 수채화처럼 청아한 각원사의 봄풍경
# [와글와글] '실내 흡연 피해' 호소했더니 "나 건달이야"
# [와글와글] "으악" 카드 사진 올렸더니‥10분 만에 1천2백만 원 결제
# [와글와글] "외상 주문 거절했는데 마음에 걸려요"
# [와글와글] 종이 쇼핑백 같은데?‥알고 보니 300만 원 명품 백
# 406개 판결문으로 본 ‘법원으로 간 학폭’
# 학교폭력 그 이후, ‘생기부 빨간 줄’보다 중요한 것들이 있다
# 드라마보다 더 잔인한 현실, ‘학폭’ 판결문 406개 분석 [금요시사회]
# [약손+] 아이들도 힘들다, '새 학기 증후군' ⑨ADHD라는 오해
# [영상+] "내 꼬리는 빨개" 가창 부채꼬리바위딱새
# [뉴스+] 죽음의 과속 방지턱···사고 잇따르는 이유는?
# [들어보니] 우리는 보통 사람입니다 | 빅벙커
# ‘윤석열 특수활동비’ 6월 23일 공개된다
# [주간 뉴스타파] 1,243일만의 승소... '검사' 윤석열, 검증의 시간
# 확정판결 검찰예산 신속히 공개 안 하면, '간접강제' 신청한다
# 검찰의 방패를 뚫고, 정보공개 최종 판결을 받아내기까지
# 위기의 네카오… 정부, 메스 들었다
# 편집권 내려놓은 포털, 여전한 공정성 시비에 '진땀'
# 디지털 재난 관리에 온플법까지… 규제 늪에 빠진 네카오
# 야외활동 후 ‘사마귀’가 생겼다면? ‘이것’ 주의
# 우리 아이에게 ‘다크서클’ 생겼다면? ‘이것’ 의심하세요
# 부모가 ‘OO’이면 자녀의 ‘천식’ 위험 4~5배↑
# 삶을 망치는 ‘만성기침’의 원인 4가지
# 가속을 멈춰라, 달팽이처럼 기어서 가자
# 인류가 탈 나지 않는 탈성장
# “제 일터가 기후 악당” 노동자·홈리스·엄마들 파업에 나서다
# “‘1.5도 라이프스타일’이란 합의가 필요하다”
# 미 의회서 43분 영어 연설…펜타곤 군사지휘센터 최초 방문
# 연설도중 23번 기립박수…"저는 몰라도 BTS는 아실 것"
# 한미 정상, '워싱턴 선언' 발표…"핵공격 시 핵 대응"
# Yoon fetes new nuclear accord as allies take harder line on NK
# Samsung eyeing 25% cut in chip production: analysts
# [Herald Interview] Winds of change in Korea's labor movement
# 與, 국토위서 전세사기특별법 상정…野 주장 '보증금 채권 매입' 제외
# 이원석 검찰총장 "전세사기, 법정 최고형 선고되도록 수사"
# "집주인 잡혀도 고통 여전, 정부 대책도 무소용"…계속되는 전세사기 피해
# [단독] 폭락 전날에도 "지금이 매수 기회"…폭락 후엔 "다시 불려줄게"
# [단독] "만져본 적도 없는 돈이 빚으로"…투자자 울린 주가조작의 덫
# [단독] 주가조작단, 1조 넘게 주무르며 '조조 파티'…"임창정도 왔다"
# [단독] '조 단위 자금' 가능했던 배경엔…회장님들의 '통 큰' 투자
# "조국 1심 선고, 재판 지연 하이라이트" 조선일보 보도 맞나
# 노조 간부 방벽 넘어 몸싸움 불법? 언론에 가린 진실
# '공영방송 정치 독립법' 국회 본회의 올랐다
# "나는 신이다" 성공 이면 틈바구니 속 윤리를 집어넣는다면
# [세계를 가다]물가 뛴다고…이집트 정부, 닭발 먹기 캠페인
# [아는기자]순방 외교서 ‘한일·한미일’ 이야기 많이 나온 이유는?
# [아는기자]‘주가조작 의혹’ 8개는 어떤 종목인가?
# [아는기자]“나의 친구”…윤석열-바이든, 36시간 동안 4개 일정
# [오늘과학] 남성 육아휴직, 가족 구성원 성평등 의식 높인다
# [오늘과학] 북미서 발견된 5000만년 전 고추 화석
# [오늘과학] 하얗게 세어버린 머리카락 되돌리는 법
# [오늘과학] 코로나 백신 부작용 '혈전' 피하는 단백질, 곰한테 있었네
# 따뜻한 날씨에 늘어난 호흡기감염병…예방·관리수칙은?
# 무심코 먹은 감자튀김이 정신건강을 위협한다?
# '스마트폰'이 '뇌종양'에 미치는 안타까운 영향
# 취침 시간 34분 늦추면 고혈압 위험 ↑
# [국빈방미 결산] ① '동맹 청사진' 주력한 5박7일…'워싱턴 선언' 전면에
# [국빈방미 결산] ② '첨단기술동맹' 협력 틀 구축…한미 시너지 본격화
# [국빈방미 결산] ③ 5차례 대면한 尹-바이든 '밀착'…손 맞잡고 어깨동무
# 떡볶이에 진심인 이 나라… 요즘은 ‘맵단짠’이 최고!
# [컨슈머리포트] 다시 붉어지는 입술… 부드럽고 조화로운 립스틱은?
# [컨슈머리포트] 두툼한 도우·토핑 듬뿍 시카고피자 인기는 ‘쭉’
# [RSAC2023] 한-미 사이버동맹, ‘파이브아이즈’ 수준으로 강화
# [RSAC2023] 전시회 성황리 개막··· 보안 리더 기업 대부분 참여
# [RSAC2023] SIEM 시대 종말? 팔마 트렐릭스 CEO “SecOps 혁명 이뤄야”
# [RSAC2023] “사이버보안에 AI 기술 활용코자 하는 움직임 확인”
# 가산금리가 마이너스?… 인뱅 주담대・전세대출 두드려볼까 [내돈내산]
# 추첨물량 늘었는데 청약통장 깨지 말까요?…활용법 A to Z [내돈내산]
# 카드 쓰면 돌려받던 20만 원, 감액?... "두드리면 열려요" [내돈내산]
# 근로시간 69시간… 구로의 불편한 등대 [視리즈]
# 냉면, 비빔밥… 1만원으로 먹을 게 없는 야속한 시절
# 기승전-반도체‧중국, 한미 정상회담이 낳은 변수 [마켓톡톡]
# 문 닫는 도봉고등학교 가보니… 사라질 공간에 남은 흔적들
# [尹국빈방미]尹, 美의회서 "두 기술강국 협력, 커다란 시너지"
# [尹국빈방미]해외정상 최초 美DARPA 방문 尹 “첨단과기, 경제·안보 중심”
# [尹국빈방미]尹, 美 상·하원 합동의회 연설[전문]
# [尹국빈방미]尹 '압도' 바이든 '종말'…'워싱턴 선언'에 담긴 對北 경고
# [법정B컷]"전세사기요? 전 심부름만"…'빌라왕' 재판 판사의 분노
# SSBN 부산에 기항…'비핵화 선언'과 모순 아니라고?[안보열전]
# [그래?픽!]"저도 선생님 XX까요" 교권 추락…학생인권 때문이라고?
# [딥뉴스]리버버스는 '골병라인'을 구할 수 있을까
# ‘거래 재개’ KG모빌리티, 주가 ‘오프로드’ 달리나
# [특징주] KG모빌리티, 2년4개월만 거래재개 첫날 급등
# 거래소, KG모빌리티 상장유지 결정…내일부터 거래가능
# KG 모빌리티, 에디슨모터스 '역인수'…우선협상 대상자 선정
# [영상] 현장은 '우회전 옥신각신'이지만…길 건너던 보행자 사고 줄이려면?- 취[재]중진담
# [부동산 핵심클릭] 주택 공급에 '적신호'가 켜졌다
# [진료는 의사에게] 간에 무리주는 민간요법 '주의'…나도 모르는 E형 간염
# [뉴스추적] 기존 주가조작과 다른 점…피해자냐? 공범이냐?
# 비대면 진료 초진 허용, 서로 물러설 수 없는 이유 [보건의료 리포트]
# 바이오헬스 인재 양성 나선 정부, 빠른 변화와 소통 필요하다 [보건의료 리포트]
# 바이오헬스 성장 위한 정부 '선물보따리'…'오답노트' 반복하나 [보건의료 리포트]
# [보건의료 리포트] 길 잃은 ‘혁신형 제약기업’, 변신의 갈림길 서다
# "5000원이면 한끼 든든" 점심시간 편의점으로 우르르 [도시락 전성시대①]
# 세입자 모시기 '별따기'...전월세 4건 중 1건 하락거래 '역대 최고'[역전세난 확산]①
# "용산공원 개방 계기로 국민소통 강화되길"[용산시대 1년]
# 소름, 전화기 넘어 그 목소리 분명 내 딸이었는데...[누구냐 넌 下]
# 15억 ‘할마·할빠’ 경제 급성장… 미국 조부모, 연 340만원 쓴다
# F1 마이애미 그랑프리 입장권 가격, 최고 870만원
# ‘메리 포핀스’ 속 뱅크런, 아이울음에서 촉발된 예금 인출러시 [Biz&Cinema]
# AI가 패션 디자이너를 대체할 수 있을까요 [Biz&Consulting]
# 체중 줄이고 혈당 천천히 낮게 올리는 음식은?
# 같이 먹으면...살빼기에 좋은 음식 콤비 11
# 치매 유발하는 뇌 건강에 '못된 음식' Best 3는?
# 윤 대통령, 국빈 방미 마치고 서울공항 도착
# 일 언론 “기시다, 5월7~8일 방한해 정상회담 추진”···대통령실 “결정된 바 없어”
# 윤 대통령 ‘아메리칸 파이’···백악관의 ‘치밀한 빌드업’ 있었다
# 김여정, ‘정권 종말’ 바이든에 “늙은이 망언”···윤 대통령엔 “그 못난 인간”
# 尹대통령, 5박 7일 美 국빈방문 마치고 귀국
# “백악관 또 와달라” 한미정상 부부 멈추게한 아이들의 ‘아리랑’
# 바이든, 尹열창 영상에 “재능 많은 남자”… 돈 매클레인 “尹과 노래 희망”
# [사설]백악관 “핵 공유 아냐”… 괜히 부풀리다 또 머쓱해진 대통령실
# 윤석열, '5박 7일간 국빈 방미' 마치고 귀국 [TF사진관]
# 서울 밤하늘에 펼쳐진 '화려한 드론 쇼' [TF사진관]
# '방배본동' 모자 쓴 전성수 서초구청장 [TF사진관]
# 원희룡 "전세사기, 사회적재난 아냐...피해금 국가 대납 안돼" [TF사진관]
# 엉터리 아파트 추첨, "어? 5백 명이 빠졌네?"
# "형도 친부도 계모도 살해하고".. 자신도 극단 선택
# 지역특화비자 취업박람회.."외국인 300명 운집"
# 농촌 살리는 '활력 사업'..지속 추진은 과제
# 尹대통령, 안보·경제 두마리 토끼 받았다[국빈방문 결산]
# [尹 방미결산] 與 "한미동맹 역사적 전환점" vs 野 "대국민 사기외교" 혹평
# [국빈방미 결산]윤대통령, 넷플릭스 등 59억달러 투자유치 '경제외교'
# 尹, 美국빈 방문 마치고 귀국..한미동맹 확실히 강화했다
# [과학을읽다]'中 한번에 성공, 日 실패'…달 착륙 그렇게 어려웠나?
# [과학을읽다]사상 최대 '슈뢰딩거의 고양이'가 나타났다
# [과학을읽다]美-러, 땅에선 원수·우주에선 단짝(?)
# [과학을읽다]로켓 발사 주변 '쑥대밭'…스타십, 결국 조사 받는다
# [작전이 판친다]임창정도 30억?…연예인·골퍼·의사 엮인 주가조작판
# [작전이 판친다] 세력 손털기 도와주는 '하따'…유튜버도 부채질
# [작전이 판친다]'수십억' CFD 반대매매 청구서, 어떻게 '깡통계좌' 되나
# 자금모집·투자자관리 '철저한 분업'…3년에 걸쳐 진행된 주가조작 전모
# '돈봉투 파문' 민주당은 여유 왜? '이정도 스캔들 별 문제 없어' 안일한 인식 탓" [촌철살인]
# 尹 대통령 방미 성과 "100% 만족하기 어려워도 너무 폄하할 필요는 없어" [촌철살인]
# '구하라·박수홍' 변호인 "권경애, 변호사의 수치..법, 정의 실현하는지 의문"[여의도초대석]
# 장예찬 "송영길은 꼬리, 몸통은 이재명..연결고리 '키맨'은 바로 '이사람'"[여의도초대석]
# 구독하신 기자가 최근 48시간 이내 작성한 기사가 제공됩니다. 전체 구독 리스트는 구독 설정에서 확인하세요.
# 기자별 기사를 자동 추천해 드립니다. 기자를 구독하시면 해당 기자의 최신 기사를 언론사별에서 확인할 수 있습니다.
# 구독한 연재 중 최근 48시간 이내 작성된 기사가 제공됩니다. 전체 구독 리스트는 구독 설정에서 확인하세요.
# 다양한 연재 기사를 자동 추천해 드립니다. 연재를 구독하시면 해당 연재의 최신 기사를 언론사별에서 확인할 수 있습니다.
# 기자·연재 카드 개선 안내
# None
# None

# %%
url = 'https://news.naver.com'
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'lxml')

import re
texts = bs.text
result = re.findall('[가-힣]+',texts)
' '.join(result)
# Out:
# '네이버 뉴스 본문 바로가기 뉴스 연예 스포츠 날씨 프리미엄 검색 언론사별 정치 경제 사회 생활 문화 과학 세계 랭킹 신문보기 오피니언 팩트체크 전체 언론사 뉴스스탠드 라이브러리 콘텐츠 일 전체 언론사 뉴스스탠드 라이브러리 언론사편집 기자 연재 구독설정 블로터 월 일 구독 나이트크로우 위메이드 캐시카우로 자리잡을까 오 컬쳐 지난 일 출시한 모바일 나이트크로우 가 출시 일 만에 구글플레이 스토어 매출 순위 위를 기록했다 그간 글로벌 지역을 중심으로 블록체인과 관련 기술을 탑재한 게임 플랫폼을 운영해온 위메이드는 나 국민일보 월 일 구독 강제추행 출신 힘찬 대법서 징역 개월 확정 강제추행 혐의로 기소된 남성그룹 출신 김힘찬 활동명 힘찬 씨가 대법원에서 실형을 확정했다 일 법조계에 따르면 대법원 부 주심 대법관 오석준 는 최근 김씨의 상고를 기각하고 징역 개월을 선고 코리아헤럴드 월 일 구독 주간동아 월 일 구독 우울증 갤러리 엔 아직도 여성 회원에 만나자는 글 수십 건 활동 무대 옮겨가며 미성년자 성 착취하는 유사 번방 기승 팸 옵챗 오픈채팅 들어가지마셈 온라인 커뮤니티 디시인사이드의 우울증 갤러리 에는 최근 이 같은 내용의 게시물이 여러 건 디지털타임스 월 일 구독 속보 대통령 박 일 국빈 방미 마치고 귀국 윤석열 대통령이 일 박 일 간의 미국 국빈 방문을 마치고 귀국했다 윤 대통령과 부인 김건희 여사는 이날 오후 전용기인 공군 호기 편으로 서울공항에 도착해 미리 나와 있던 환영객들과 인사했다 지난 일 출 새로보기 조세일보 월 일 구독 빚 만드는 외상결제 서비스업체 연체율 급증에 건전성 우려 물건을 먼저 구입하고 나중에 결제하는 선구매 후불결제 서비스의 연체율이 높아지면서 건전성에 대한 우려도 커지고 있다 일 국회 정무위원회 소속 최승재 국민의힘 의원이 금융감독원으로부터 받은 네이버파 매경이코노미 월 일 구독 백스윙 때 오른발 뒤꿈치 밟고 스윙 때 떼라 김상현의 정교한 샷 한국프로골프 코리안투어가 개막하는 매년 월 주목받는 한 선수가 있습니다 전년도 스릭슨투어 상금왕 김상현입니다 부 투어지만 지난해 정규투어에서 번의 우승을 포함해 시사저널 월 일 구독 경제가 안보 인 시대 커지는 러시아와 중국 리스크 권상집의 논전 금기어 깨트린 윤 대통에게 러시아 중국 강하게 반발 상황에 따라 각기 입장 달리하는 태도 되새겨야 윤석열 대통령이 러시아와 중국의 적대적 행위에 엄중한 경고를 보냈다 로 파이낸셜뉴스 월 일 구독 대만 호텔서 숨진채 발견된 대 한국 여성 남자친구 긴급 체포 대만에 여행 간 한국인 여성 관광객이 현지 호텔에서 숨진 채 발견됐다 이 사건과 관련해 현지 수사당국은 여성과 동행한 한국인 남성을 체포했다 일 현지시간 대만연합보는 지난 일 낮 시 분께 대만 남부 한국일보 월 일 구독 년 성취 무너져 허망 발언 빠져 문재인입니다 다큐 어떤 내용 일 오후 시 무렵 전북 전주시 전북대 삼성문화회관은 사람들로 붐볐다 제 회 전주국제영화제에서 첫 공개되는 다큐멘터리영화 문재인입니다 를 보려는 이들이 대부분이었다 일부 관객은 로비에 설치된 대형 영화 포 새로보기 동아일보 월 일 구독 바이든 한미동맹 공통 신념서 탄생 방미 장면 동영상 올려 조 바이든 미국 대통령이 일 현지 시간 트위터에 한미동맹은 공동의 국경선이 아니라 공통의 신념에서 탄생했다 며 그것은 민주주의 자유 안보 이고 무엇보다 더스쿠프 월 일 구독 김포골드라인 리버버스 실패작 수상택시 년 만의 오버랩 리즈 때만 되면 포털 뉴스란에 심심찮게 등장하는 단어가 있습니다 수상택시입니다 그 옆에는 늘 함께 붙어다니는 말이 있습니다 서울시입니다 서울시는 년부터 서울의 교통혼잡을 완화하기 위한 대안으로 수상택 대구 월 일 구독 만나보니 국가인권위원회가 제시하는 이슬람 사원 갈등 해법은 대구시 북구 대현동 이슬람 사원 건축공사 논란이 년째 계속되고 있습니다 주민 반대를 넘어 사회적 갈등으로 확산하고 있는데요 이슬람 사원 건축을 놓고 지역 주민들이 대구 북구청에 탄원서를 제출하면서 년 월 일 구독 동영상 재생시간 최전방 이상 무 과학화 시스템으로 철통 경계 남북이 가장 가깝게 총구를 맞대고 있는 곳 최북단 철책에는 시간 경계를 펴고 있는 최전방 사단이 있습니다 과학화 경계시스템으로 보다 정밀한 임무를 수행하는 사단 장병들의 모습을 임성재 기자가 보도합니 서울신문 월 일 구독 간호법 반대 단식 조무사협회장 건강 악화로 병원 이송 간호법 제정안 저지를 위해 지난 일부터 국회 앞 단식을 이어 온 곽지연 대한간호조무사협회장이 일 건강 악화로 병원에 후송됐다 지난 일 간호법 및 의사면허 취소법이 더불어민주당 주도로 국회 본회의에서 강행 새로보기 뉴스타파 월 일 구독 현장에서 아직도 대강은 대운하가 아니다 라는 그들에게 요즘 대강 사업의 주역들이 부쩍 대중 앞에 자주 등장하고 있다 이명박 전 대통령 이하 존칭 생략 은 며칠 전 측근 유인촌의 연극을 관람했고 앞으로 대강도 방문할 예정이라고 한다 대강 추진본부장이었던 심명필은 한국경제 월 일 구독 자녀 명 둔 남자 또 정자 기증하면 벌금 억 만원 지속적 정자 기증으로 전 세계에 명의 자녀를 둔 것으로 알려진 대 네덜란드 남성에게 정자 기증 금지령 이 내려졌다 지난 일 현지시간 영국 가디언 등은 네덜란드 국적의 조너선 제이컵 메이어르 문화일보 월 일 구독 바이든 찰스 세 대관식 불참 두고 갑론을박 아일랜드계라서 영국 일각에서 미 영 관계 소홀 비판 바이든 대통령 아일랜드계인 것이 영향 역대 대통령 중 참석 전무 조 바이든 미국 대통령의 영국 찰스 세 국왕 대관식 불참 때문에 논쟁이 이어지고 있다고 일 현지시간 부산일보 월 일 구독 대만 여행 중이던 대 여성 사망 동행한 남성 긴급체포 남자친구와 대만 여행 중이던 대 한국 여성이 호텔에서 숨진 채 발견돼 현지 경찰이 조사에 나섰다 일 대만 자유시보 등 현지 매체에 따르면 지난 일 오후 시 분께 가오슝의 한 호텔에서 씨가 국제신문 월 일 구독 부산 공공기관 밑빠진 독 물붓기 에 기관장 연봉 감축 부산에 본사를 둔 중앙정부 산하 공공기관 절반이 지난해 영업적자를 낸 것으로 나타났다 코로나 장기화와 원자재 가격 상승 등으로 경영이 악화됐기 때문이다 이 때문에 지역 공공기관 상당수는 기관장 연봉을 삭감했다 새로보기 디지털데일리 월 일 구독 이재용 회장께 메신저해도 될까요 삼성 신입사원의 패기 주위 반응은 라이프 직장인 익명 커뮤니티 블라인드에 삼성전자 신입 사원이 남긴 패기 넘치는 글이 화제다 이재용 회장에게 사내 메신저로 뽑아주셔서 감사하다 는 인사를 보내도 되냐 는 내용인데 정작 이 글보다 이에 대한 베댓 베스트 데일리안 월 일 구독 어디서 들어본 것 같지 않나요 반복되는 표절 의혹에 멍드는 케이팝 기자수첩 연예 팝 사상 최단 기간 빌보드 입성 중소의 기적 등의 영광스러운 수식어를 지닌 피프티피프티 활약에 제동이 걸렸다 튀르계 가수 가 피프티피프티의 데뷔곡 큐피드 가 신동아 월 일 구독 윤석열은 큰 그릇 이익 위해 남 희생시키지 않아 영상 이철규 국민의힘 사무총장 대선 경선 치르며 처음 인연 맺었다 당 사무총장 살림하고 책임지는 자리 공천 순위는 주민 위해 봉사할 인물 쓴소리에 귀 닫지 않는 열린 마음 소유자 검사 많다고 매일신문 월 일 구독 다큐 문재인입니다 첫 상영 년 성취 허망 발언 빠지고 텃밭 생활 부각 문재인 전 대통령의 퇴임 후 일상을 다룬 다큐멘터리 영화 문재인입니다 월 일 개봉 가 지난 일 전주국제영화제에서 처음 상영됐다 개봉 전 선공개 당시 년간 이룬 성취가 무너졌다 는 문 전 대통령 발언 한국경제 월 일 구독 또 의료대란 간호법 반발 일 부분파업 돌입 의사와 간호조무사 등이 간호법 제정안과 의료법 개정안 의사면허취소법 의 국회 본회의 통과에 반발 총파업을 예고했다 일 의료계 등에 따르면 의사와 간호조무사 단체 등 개 보건의료단체가 참여하는 보건복지의료연 새로보기 조선비즈 월 일 구독 대통령실 박지원 조율된 아메리칸 파이 주장에 근거 없는 모함 반국가적 작태 박지원 한 소절 더 했으면 바이든과 듀엣 대통령실 바이든 노력 알기에 한 소절 부른 것 대통령실은 일 윤석열 대통령이 지난 일 현지 시각 백악관 국빈 만찬에서 아메리칸 파이 를 부른 것과 관련 머니투데이 월 일 구독 조문객 많지 않아 서세원  ...

# %% [markdown]
# #### requests + bs

# %%
from bs4 import BeautifulSoup
import requests as rq
url = 'https://news.naver.com/'
r = rq.get(url)
html = r.text
bs = BeautifulSoup(html, 'lxml')
print(bs)
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <title id="browserTitleArea">네이버 뉴스</title>
# <script>
# 	function isMobileDevice() {
# 		return /^.*(iPhone|iPod|iPad|Android).*/.test(navigator.userAgent);
# 	}
# </script>
# <script>
# 	(function () {
# 		try {
# 			if (isMobileDevice() && isAbleApplyPrefersColorScheme()) {
#
# 				document.querySelector("html").classList.add("DARK_THEME");
# 			}
# 		} catch(e) {}
#
# 		function isAbleApplyPrefersColorScheme() {
#
# 			if (window.matchMedia("(prefers-color-scheme)").matches === false) {
# 				return false;
# 			}
#
# 			var userAgent = navigator.userAgent;
#
# 			if (userAgent.indexOf("NAVER") > -1) {
#
# 				if (/.*NAVER\([a-zA-Z]*;\s[a-zA-Z]*;\s([0-9]*);/.test(userAgent)) {
# 					return Number(RegExp.$1) >= 1000;
# 				}
# 			} else {
#
# 				return document.cookie.indexOf("NSCS=1") > -1;
# 			}
#
# 			return false;
# 		}
# 	})();
# </script>
# <script>
# 		var g_ssc = 'news.v3_media' || null;
# 		</script>
# <meta charset="utf-8"/>
# <meta content="width=device-width,initial-scale=1.0,maximum-scale=1.0,minimum-scale=1.0,user-scalable=no,target-densitydpi=medium-dpi" name="viewport"/>
# <link href="https://ssl.pstatic.net/static.news/mnews/resources/20230420_005654/css/generated/newshome.css" rel="stylesheet" type="text/css"/>
# <link href="https://mimgnews.pstatic.net/image/news/m/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <script>
# 	(function(){
# 		var userAgent = navigator.userAgent;
# 		var result = [];
#
# 		if(userAgent.indexOf('Android') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="72x72" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="96x96" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="144x144" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="192x192" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />'
# 			];
# 		}else if(userAgent.indexOf('iPhone') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="120X120" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPhone_2x_120X120.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="180x180" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPhone_3x_180X180.png" />'
# 			];
# 		}else if(userAgent.indexOf('iPad') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="167x167" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPadPro_2x_167X167.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="152x152" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPad_2x_152X152.png" />'
# 			];
# 		}
# 		document.write(result.join('\n'));
# 	})();
# </script>
# <script src="https://ssl.pstatic.net/static.news/mnews/resources/20230420_005654/js/generated/statistics_jquery.js" type="text/javascript"></script>
# <script>
#     document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
# <script>
#
# document.documentElement.setAttribute('data-useragent', navigator.userAgent);
#
#
# function showNoImage(elImg, type) {
#     switch (type) {
#
#         case "remove":
#             try {
#                 elImg.parentNode.removeChild(elImg);
#             } catch(e) {}
#             break;
#
#
#         case "removeParent":
#             try {
#                 elImg.parentNode.outerHTML = '';
#             } catch(e) {}
#             break;
#
#
#         case "alt":
#             elImg.outerHTML = ('<span class="noimage_text {imgClassName}">' + (elImg.alt || "") + '</span>')
#
#                 .replace('{imgClassName}', elImg.className);
#             break;
#
#
# 		case "class" :
# 			var outerHTMLSource = Number(elImg.getAttribute("height")) > 0?
#
# 				'<span class="noimage_wrap {imgClassName}" style="height:' + elImg.getAttribute("height") + 'px;"><span class="noimage"></span></span>':
# 				'<span class="noimage_wrap {imgClassName}"><span class="noimage"></span></span>';
# 			elImg.outerHTML = outerHTMLSource.replace('{imgClassName}', elImg.className);
# 			break;
#
#
#         default:
#
#             elImg.outerHTML = Number(elImg.getAttribute("height")) > 0?
#
#                 '<span class="noimage_wrap" style="height:' + elImg.getAttribute("height") + 'px;"><span class="noimage"></span></span>':
#                 '<span class="noimage_wrap"><span class="noimage"></span></span>';
#     }
# }
#
#
# function doAfterLoadEnd(callback, callbackOnPersisted) {
#     var eventName = "onpageshow" in window ? "pageshow" : "load";
#
#     callback = callback || function(){};
#     callbackOnPersisted = callbackOnPersisted || function(){};
#
#     window.addEventListener(eventName, function(e) {
#         try{
#             if(Boolean(e.persisted)){
#                 callbackOnPersisted();
#                 return;
#             }
#         }catch(e){}
#
#         callback();
#     });
# }
# </script>
# <meta content="네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/main/home.naver" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image"/>
# <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
# <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" name="twitter:description"/>
# <script>
#
#     (function () {
#         var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#         if (!isUnderIE10) {
#             var script = document.createElement("script");
#             script.async = true;
#             script.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#             document.head.appendChild(script);
#         }
#     })();
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#     window.gladsdk.cmd.push(function () {
#
#         window.gladsdk.setGlobalConfig({
#             enablePersistAd: true
#         });
#
#
#         var adUnits = [];
#
#         adUnits.push({
#             adUnitId: "p_news_sidebox",
#             adSlotElementId: "glad_ad_sidebox",
#             customParam: {
#                 calp: "home"
#             }
#         });
#
#         for (let i = 0; i < adUnits.length; i++) {
#             window.gladsdk.defineAdSlot(adUnits[i]);
#         }
#
#
#         var htmlClass = document.querySelector("html").getAttribute("class");
#         if (htmlClass && htmlClass.indexOf("DARK_THEME") > -1) {
#             window.gladsdk.setHostMeta("theme", "system");
#         }
#     });
# </script>
# </head>
# <body class="as_mp_layout">
# <div class="u_skip"><a href="#ct">본문 바로가기</a></div>
# <!-- Menu 구분  -->
# <section class="news_header">
# <header class="nh_header" role="banner">
# <div class="Ngnb">
# <div class="Ngnb_inner">
# <div class="Ngnb_both">
# <div class="Ngnb_left">
# <span class="Ngnb_logo"><a class="Nlogo_link" href="https://www.naver.com" onclick="nclk(event,'gnb.naver','','');"><span class="Nicon_logo">NAVER</span></a></span>
# <div class="Ngnb_service">
# <h1 class="Nservice_item"><a href="https://news.naver.com" onclick="nclk(event,'gnb.news','','');"><span class="Nicon_service">뉴스</span></a></h1>
# <span class="Nservice_subitem">
# <a href="https://entertain.naver.com/home" onclick="nclk(event,'gnb.enter','','');">
# <span class="Nicon_family Nicon_entertain">연예</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a href="https://sports.news.naver.com/index" onclick="nclk(event,'gnb.sports','','');">
# <span class="Nicon_family Nicon_sports">스포츠</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a href="https://weather.naver.com/" onclick="nclk(event,'gnb.weather','','');">
# <span class="Nicon_family Nicon_weather">날씨</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a href="https://contents.premium.naver.com/" onclick="nclk(event,'gnb.premium','','');">
# <span class="Nicon_family Nicon_premium">프리미엄</span>
# </a>
# </span>
# </div>
# </div>
# <div class="Ngnb_right">
# <div class="Ngnb_group">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="Ngnb_search is_hidden _search_content"></div>
# <div class="Ngnb_tool">
# <a class="Ntool_button _search_content_toggle_btn" href="javascript:;" onclick="nclk(event,'gnb.sch','','');"><span class="Nicon_search">검색</span></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="Nlnb _float_lnb">
# <div class="Nlnb_inner">
# <div class="Nlnb_both">
# <div class="Nlnb_left _lnb_scroll">
# <div class="Nlnb_menu Ntype_scroll">
# <div class="Nlnb_menu_inner _scroll">
# <ul class="Nlnb_menu_list" role="menu">
# <li class="Nlist_item is_active"><a aria-selected="true" class="Nitem_link" href="https://news.naver.com/?viewType=pc" onclick="nclk(event,'lnb.pcmedia','','');" role="menuitem"><span class="Nitem_link_menu">언론사별</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100" onclick="nclk(event,'lnb.pol','','');" role="menuitem"><span class="Nitem_link_menu">정치</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101" onclick="nclk(event,'lnb.eco','','');" role="menuitem"><span class="Nitem_link_menu">경제</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102" onclick="nclk(event,'lnb.soc','','');" role="menuitem"><span class="Nitem_link_menu">사회</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103" onclick="nclk(event,'lnb.lif','','');" role="menuitem"><span class="Nitem_link_menu">생활/문화</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105" onclick="nclk(event,'lnb.sci','','');" role="menuitem"><span class="Nitem_link_menu">IT/과학</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104" onclick="nclk(event,'lnb.wor','','');" role="menuitem"><span class="Nitem_link_menu">세계</span></a></li>
# <li class="Nlist_item _isNew"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/ranking/popularDay.naver" onclick="nclk(event,'lnb.rank','','');" role="menuitem"><span class="Nitem_link_menu">랭킹</span></a></li>
# <li class="Nlist_item _isNew"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/newspaper/home?viewType=pc" onclick="nclk(event,'lnb.paper','','');" role="menuitem"><span class="Nitem_link_menu">신문보기</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/opinion/home" onclick="nclk(event,'lnb.opi','','');" role="menuitem"><span class="Nitem_link_menu">오피니언</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/tv/index.naver?mid=tvh" onclick="nclk(event,'lnb.tv','','');" role="menuitem"><span class="Nitem_link_menu">TV</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/factcheck/main.naver" onclick="nclk(event,'lnb.fact','','');" role="menuitem"><span class="Nitem_link_menu">팩트체크</span></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="Nlnb_right">
# <div class="lnb_extra" id="">
# <div class="lnb_extra_menu">
# <ul class="lnb_extra_menu_list">
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link" href="https://news.naver.com/main/officeList.naver" onclick="nclk(event,'slb.allmedia','','');">전체 언론사</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link" href="https://newsstand.naver.com/" onclick="nclk(event,'slb.newsstand','','');" target="_blank">뉴스스탠드</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link" href="https://newslibrary.naver.com/search/searchByDate.naver" onclick="nclk(event,'slb.library','','');" target="_blank">라이브러리</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </header>
# </section>
# <hr/>
# <div class="main_wrap" id="ct" role="main">
# <div class="main_container">
# <section class="main_content">
# <h3 class="blind">콘텐츠</h3>
# <div class="main_sublnb">
# <div class="main_sublnb_date">
# <strong>4</strong>.<strong>30</strong><span>(일)</span>
# </div>
# <ul class="main_sublnb_menu">
# <li class="main_sublnb_item"><a class="main_sublnb_link" href="https://news.naver.com/main/officeList.naver " onclick="nclk(event, 'slb.allmedia', '', '')">전체 언론사</a></li>
# <li class="main_sublnb_item"><a class="main_sublnb_link" href="https://newsstand.naver.com/" onclick="nclk(event, 'slb.newsstand', '', '')" target="_blank">뉴스스탠드</a></li>
# <li class="main_sublnb_item"><a class="main_sublnb_link" href="https://newslibrary.naver.com/search/searchByDate.naver" onclick="nclk(event, 'slb.library', '', '')" target="_blank">라이브러리</a></li>
# </ul>
# </div>
# <div class="main_brick">
# <!-- BRICK HOUSE -->
# <div class="grid1_wrap brick-house _brick_gid_wrapper">
# <div class="brick-vowel _brick_column">
# <div class="main_brick_item _press_main_status_wrapper">
# <div class="comp_journal_subscribe">
# <div class="cjs_title_wrap">
# <h3 class="cjs_edit_title">
# <span class="cjs_main">언론사편집</span>
# <a class="cjs_subscribe_a" href="#feedJournalistCard" onclick="nclk(event, 'home.editassetting1', '', '')">
# <span class="subs_text">기자
#
#                     </span>
# </a>
# <a class="cjs_subscribe_a" href="#feedSeriesCard" onclick="nclk(event, 'home.editassetting2', '', '')">
# <span class="subs_text">연재
#
#                     </span>
# </a>
# </h3>
# <a class="cjs_more_link" href="https://media.naver.com/channel/settings" onclick="nclk(event, 'home.editsetting', '', '')">
#                 구독설정
#
#                 <span class="ico_more"></span>
# </a>
# </div>
# </div>
# </div>
# <div class="main_brick_item _channel_news_preview_wrapper" data-max-page="16">
# <div class="comp_journal_subscribe _preview_card_page" style="">
# <div class="cjs_channel_card">
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/123" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img height="28" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/123/2018/10/02/logo_123_56_20181002190002.png?type=nf76_76_q90" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">조세일보<span class="datetime">04월 30일 15:17</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="123" data-office_name="조세일보" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/123/0002304027" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/origin/123/2023/04/30/2304027.jpg?type=nf264_176&amp;ut=20230430111001" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">"빚 만드는 외상결제'...서비스업체, 연체율 급증에 건전성 우려</div>
# <p class="cjs_d">물건을 먼저 구입하고 나중에 결제하는 '선구매 후불결제(BNPL)' 서비스의 연체율이 높아지면서 건전성에 대한 우려도 커지고 있다. 30일 국회 정무위원회 소속 최승재 국민의힘 의원이 금융감독원으로부터 받은 네이버파</p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/640" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img height="28" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/640/2020/05/06/logo_640_56_20200506111106.png?type=nf76_76_q90" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">코리아중앙데일리<span class="datetime">04월 30일 13:34</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="640" data-office_name="코리아중앙데일리" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/640/0000037870" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/origin/640/2023/04/30/37870.jpg?type=nf264_176&amp;ut=20230430070103" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">Gaming in Korea is a real career path, not for the short of temper</div>
# <p class="cjs_d">There's a certain phrase that goes, “No matter how good you are at gaming, there’s always a Korean better than you.” And</p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/037" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img height="28" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/037/2022/07/13/logo_037_56_20220713135804.png?type=nf76_76_q90" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">주간동아<span class="datetime">04월 30일 10:06</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="037" data-office_name="주간동아" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/037/0000032459" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/origin/037/2023/04/30/32459.jpg?type=nf264_176&amp;ut=20230430100201" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">‘우울증 갤러리’엔 아직도 여성 회원에 만나자는 글 수십 건</div>
# <p class="cjs_d">활동 무대 옮겨가며 미성년자 성 착취하는 ‘유사 N번방’ 기승 “◯◯팸 옵챗(오픈채팅) 들어가지마셈.” 온라인 커뮤니티 디시인사이드의 ‘우울증 갤러리’에는 최근 이 같은 내용의 게시물이 여러 건</p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/029" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img height="28" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/029/2022/09/01/logo_029_56_20220901154918.jpg?type=nf76_76_q90" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">디지털타임스<span class="datetime">04월 30일 16:03</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="029" data-office_name="디지털타임스" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/029/0002797811" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/origin/029/2023/04/30/2797811.jpg?type=nf264_176&amp;ut=20230430153301" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">[속보] 尹대통령, 5박7일 국빈 방미 마치고 귀국</div>
# <p class="cjs_d">윤석열 대통령이 30일 5박7일 간의 미국 국빈 방문을 마치고 귀국했다. 윤 대통령과 부인 김건희 여사는 이날 오후 전용기인 공군 1호기 편으로 서울공항에 도착해 미리 나와 있던 환영객들과 인사했다. 지난 24일 출</p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/658" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img height="28" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/658/2022/01/20/logo_658_56_20220120164828.png?type=nf76_76_q90" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">국제신문<span class="datetime">04월 30일 17:12</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="658" data-office_name="국제신문" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/658/0000039614" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/origin/658/2023/04/30/39614.jpg?type=nf264_176&amp;ut=20230430171001" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">부산 공공기관 '밑빠진 독 물붓기'에 기관장 연봉 20% 감축</div>
# <p class="cjs_d">부산에 본사를 둔 중앙정부 산하 공공기관 절반이 지난해 영업적자를 낸 것으로 나타났다. 코로나19 장기화와 원자재 가격 상승 등으로 경영이 악화됐기 때문이다. 이 때문에 지역 공공기관 상당수는 기관장 연봉을 삭감했다</p>
# </div>
# </a>
# </div>
# <div class="cjs_info">
# <button card_type="preview" class="cjs_btn_refresh _refresh_btn" data-max-page="" data-page="0" onclick="nclk(event, 'home.editnfnew', '', '')" size="5" type="button">새로보기</button>
# </div>
# </div>
# </div>
# <div class="comp_journal_subscribe _preview_card_page" style="display:none">
# <div class="cjs_channel_card">
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/366" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/366/2020/12/23/logo_366_56_20201223182636.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">조선비즈<span class="datetime">04월 30일 17:18</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="366" data-office_name="조선비즈" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/366/0000897999" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/366/2023/04/30/897999.jpg?type=nf264_176&amp;ut=20230430171601" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">대통령실, 박지원 “조율된 아메리칸 파이” 주장에 “근거 없는 모함…반국가적 작태”</div>
# <p class="cjs_d">박지원 “尹, 한 소절 더 했으면 바이든과 듀엣” 대통령실 “바이든 노력 알기에 한 소절 부른 것” 대통령실은 30일 윤석열 대통령이 지난 26일(현지 시각) 백악관 국빈 만찬에서 ‘아메리칸 파이’를 부른 것과 관련</p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/044" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/044/2018/10/02/logo_044_56_20181002183002.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">코리아헤럴드<span class="datetime">04월 30일 16:28</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="044" data-office_name="코리아헤럴드" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/044/0000245774" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/044/2023/04/30/245774.jpg?type=nf264_176&amp;ut=20230430143301" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">Falling births a concern for North Korea, too</div>
# <p class="cjs_d">Similar to South Korea, North Korea is grappling with tumbling childbirths. The cause, however, is starkly different: fa</p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/417" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/417/2021/01/25/logo_417_56_20210125161624.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">머니S<span class="datetime">04월 30일 16:00</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="417" data-office_name="머니S" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/417/0000917175" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/417/2023/04/30/917175.jpg?type=nf264_176&amp;ut=20230430153801" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">루이비통, 국내 첫 프리폴 패션쇼 성료… 1600여명 몰려</div>
# <p class="cjs_d">프랑스 명품 브랜드 루이비통이 서울 잠수교에서 개최한 국내 첫 패션쇼가 성황리에 마무리됐다. 루이비통은 지난 29일 오후 8시 서울 잠수교에서 프리폴(Prefall) 패션쇼를 열었다. 정규 가을·겨울(F/W) 컬렉션</p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/055" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/055/2020/10/07/logo_055_56_20201007141807.jpg?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">SBS<span class="datetime">04월 30일 16:43</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="055" data-office_name="SBS" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/055/0001054288" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/055/2023/04/30/1054288.jpg?type=nf264_176&amp;ut=20230430164101" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">'형용사: 특출난, 유일무이한'…펠레, 포르투갈어 사전 등재</div>
# <p class="cjs_d">'축구 황제' 펠레의 이름이 '뛰어난, 비교할 수 없는, 유일무이한' 사람을 의미하는 형용사로 브라질 사전에 영원히 남게 됐습니다. 현지 시간으로 지난 27일 CNN, BBC 등 외신들은 '펠레'가 포르투갈어 사전에</p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/006" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/006/2018/07/18/logo_006_56_20180718152218.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">미디어오늘<span class="datetime">04월 30일 14:37</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="006" data-office_name="미디어오늘" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/006/0000117879" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/006/2023/04/30/117879.jpg?type=nf264_176&amp;ut=20230430151401" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">"검사 때 해외연수?" 尹 영어연설 띄우기 진심이었던 언론 </div>
# <p class="cjs_d">윤석열 대통령의 5박7일 국빈 방미 일정이 끝난 가운데 일부 언론이 외교 성과를 냉정히 짚기보다 지난 28일 대통령의 미 의회 '영어' 연설을 지나치게 띄워줘 일련의 보도 행태가 전두환 5공 시절을 떠올리게 한다는 </p>
# </div>
# </a>
# </div>
# <div class="cjs_info">
# <button card_type="preview" class="cjs_btn_refresh _refresh_btn" data-max-page="" data-page="0" onclick="nclk(event, 'home.editnfnew', '', '')" size="5" type="button">새로보기</button>
# </div>
# </div>
# </div>
# <div class="comp_journal_subscribe _preview_card_page" style="display:none">
# <div class="cjs_channel_card">
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/346" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/346/2023/02/24/logo_346_56_20230224143254.jpg?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">헬스조선<span class="datetime">04월 30일 16:02</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="346" data-office_name="헬스조선" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/346/0000060552" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/346/2023/04/30/60552.jpg?type=nf264_176&amp;ut=20230430160101" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">롤러코스터 탄 뒤 신장결석 없어졌다? 황당 주장 같지만…</div>
# <p class="cjs_d">미국의 한 여성이 놀이공원에서 롤러코스터를 탄 후 신장결석이 제거됐다고 주장해 관심을 모으고 있다. 이 여성은 롤러코스터 탑승이 신장결석 배출에 도움이 된다는 연구결과를 보고 이 같은 행동을 한 것으로 전해졌다. 지</p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/138" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/138/2018/07/18/logo_138_56_20180718153118.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">디지털데일리<span class="datetime">04월 30일 14:21</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="138" data-office_name="디지털데일리" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/138/0002147515" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/138/2023/04/29/2147515.jpg?type=nf264_176&amp;ut=20230429072801" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">"이재용 회장께 메신저해도 될까요?" 삼성 신입사원의 패기... 주위 반응은? [e라이프]</div>
# <p class="cjs_d">직장인 익명 커뮤니티 블라인드에 삼성전자 신입 사원이 남긴 패기 넘치는 글이 화제다. "이재용 회장에게 사내 메신저로 '뽑아주셔서 감사하다'는 인사를 보내도 되냐"는 내용인데, 정작 이 글보다 이에 대한 베댓(베스트</p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/243" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/243/2023/01/12/logo_243_56_20230112142411.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">이코노미스트<span class="datetime">04월 30일 17:05</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="243" data-office_name="이코노미스트" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/243/0000044181" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/243/2023/04/30/44181.jpg?type=nf264_176&amp;ut=20230430164801" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">‘약다운 약’ 만들어 제약보국 실현…한국 제약계 ‘큰 별’ 지다</div>
# <p class="cjs_d">이종호 JW그룹 명예회장이 30일 오전 향년 90세로 별세했다. 고인은 ‘제약구세’(製藥救世)의 일념으로 약다운 약을 만들어 국민 건강을 지키는 제약보국 실현에 앞장서왔다. JW그룹에 따르면 세브란스병원에서 입원 중</p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/656" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/656/2022/01/19/logo_656_56_20220119134936.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">대전일보<span class="datetime">04월 30일 16:51</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="656" data-office_name="대전일보" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/656/0000049547" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/656/2023/04/30/49547.jpg?type=nf264_176&amp;ut=20230430120401" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">다큐 '문재인입니다', 전주국제영화제서 첫 공개</div>
# <p class="cjs_d">다음 달 10일 개봉…"5년간 이룬 성취 무너져 허무" 발언은 빠져 문재인 전 대통령의 퇴임 후 일상을 보여주는 이창재 감독의 다큐멘터리 영화 '문재인입니다'가 29일 전주국제영화제에서 공개됐다. 이 영화는 이날 저</p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/666" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/666/2023/01/03/logo_666_56_20230103174615.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">경기일보<span class="datetime">04월 30일 17:21</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="666" data-office_name="경기일보" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/666/0000010072" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/666/2023/04/30/10072.jpg?type=nf264_176&amp;ut=20230430161201" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">“죄송해요”…생후 40일 아들 학대 숨지게 한 친모 영장 심사</div>
# <p class="cjs_d">생후 40일 아이를 떨어뜨리고도 방치해 숨지게 한 혐의를 받는 20대 중증 지적장애인 친모 A씨가 30일 오후 구속 전 피의자 심문(영장실질심사)을 받기 위해 인</p>
# </div>
# </a>
# </div>
# <div class="cjs_info">
# <button card_type="preview" class="cjs_btn_refresh _refresh_btn" data-max-page="" data-page="0" onclick="nclk(event, 'home.editnfnew', '', '')" size="5" type="button">새로보기</button>
# </div>
# </div>
# </div>
# <div class="comp_journal_subscribe _preview_card_page" style="display:none">
# <div class="cjs_channel_card">
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/586" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/586/2018/09/20/logo_586_56_20180920154020.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">시사저널<span class="datetime">04월 30일 16:10</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="586" data-office_name="시사저널" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/586/0000056902" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/586/2023/04/30/56902.jpg?type=nf264_176&amp;ut=20230430160901" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">'경제가 안보'인 시대, 커지는 러시아와 중국 리스크 [권상집의 논전(論戰)]</div>
# <p class="cjs_d">금기어 깨트린 윤 대통에게 러시아․중국 강하게 반발 상황에 따라 각기 입장 달리하는 英․ 佛․獨 태도 되새겨야 윤석열 대통령이 러시아와 중국의 적대적 행위에 엄중한 경고를 보냈다. 로</p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/215" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/215/2020/08/12/logo_215_56_20200812134433.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">한국경제TV<span class="datetime">04월 30일 17:10</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="215" data-office_name="한국경제TV" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/215/0001098635" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/215/2023/04/30/1098635.jpg?type=nf264_176&amp;ut=20230430105301" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">또 의료대란?…간호법 반발 "4일 부분파업 돌입"</div>
# <p class="cjs_d">의사와 간호조무사 등이 간호법 제정안과 의료법 개정안(의사면허취소법)의 국회 본회의 통과에 반발, 총파업을 예고했다. 30일 의료계 등에 따르면 의사와 간호조무사 단체 등 13개 보건의료단체가 참여하는 보건복지의료연</p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/127" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/127/2020/04/02/logo_127_56_20200402162102.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">기자협회보<span class="datetime">04월 28일 17:49</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="127" data-office_name="기자협회보" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/127/0000034004" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/127/2023/04/28/34004.jpg?type=nf264_176&amp;ut=20230428174801" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">네이버 뉴스서 'URL·QR코드·언론사사이트' 이동 가능해진다</div>
# <p class="cjs_d">네이버가 불공정 논란이 일었던 뉴스콘텐츠제휴 약관을 전면 수정해 재공지했다. 네이버는 28일 오후 뉴스콘텐츠제휴 언론사들에 이메일을 보내 “(기존 약관 대신) 추가 수정한 개정 약관으로 재동의를 구하고자 한다”며 “</p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/437" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/437/2020/08/25/logo_437_56_20200825135552.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">JTBC<span class="datetime">04월 30일 17:12</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="437" data-office_name="JTBC" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/437/0000341231" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/437/2023/04/30/341231.jpg?type=nf264_176&amp;ut=20230430155301" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">[영상] 러 전투기, 미 전투기 600m까지 접근해 '아찔'…미군 영상 공개</div>
# <p class="cjs_d">러시아 전투기가 미군 전투기의 조종석 화면에 보입니다. 이후 날개를 움직여 기체 방향을 틀기도 합니다. 이 전투기는 빠르게 이동하며 결국 시야에서 사라집니다. 현지시간 지난 18일 시리아 상공에서 미군 전투기에 목격</p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/662" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/662/2023/01/05/logo_662_56_20230105140724.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">농민신문<span class="datetime">04월 30일 14:40</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="662" data-office_name="농민신문" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/662/0000019176" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/662/2023/04/30/19176.jpg?type=nf264_176&amp;ut=20230430120201" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">‘불법 숙박업소’ 안전신문고에서 신고하세요</div>
# <p class="cjs_d">5월부터 행정안전부가 운영하는 ‘안전신문고’ 누리집과 어플리케이션(앱)에서 불법 숙박업소를 신고할 수 있다. 숙박업소는 업종에 따라 여러 부처에서 관할하고 있다. 보건복지부가 모텔 등 일반숙박업과 생활숙박업, 농림축</p>
# </div>
# </a>
# </div>
# <div class="cjs_info">
# <button card_type="preview" class="cjs_btn_refresh _refresh_btn" data-max-page="" data-page="0" onclick="nclk(event, 'home.editnfnew', '', '')" size="5" type="button">새로보기</button>
# </div>
# </div>
# </div>
# <div class="comp_journal_subscribe _preview_card_page" style="display:none">
# <div class="cjs_channel_card">
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/449" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/449/2020/06/26/logo_449_56_20200626104826.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">채널A<span class="datetime">04월 30일 17:05</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="449" data-office_name="채널A" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/449/0000248681" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/449/2023/04/30/248681.jpg?type=nf264_176&amp;ut=20230430161201" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">대만 여행하던 30대 한국 여성 사망…동행 남성 긴급 체포</div>
# <p class="cjs_d">대만에서 여행중이던 30대 한국인 여성이 호텔에서 사망하면서 현지 수사당국이 조사에 나섰습니다. 대만 검찰은 여성과 동행한 남성을 유력 용의자로 보고 긴급체포했습니다. 대만 현지 보도 등을 종합하면 현지시각으로 지난</p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/008" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/008/2018/09/13/logo_008_56_20180913140213.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">머니투데이<span class="datetime">04월 30일 16:09</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="008" data-office_name="머니투데이" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/008/0004881657" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/008/2023/04/30/4881657.jpg?type=nf264_176&amp;ut=20230430155201" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">"조문객 많지 않아"…故서세원 한국 빈소는 '조용'</div>
# <p class="cjs_d">코미디언 겸 사업가 고(故) 서세원씨의 한국 장례식이 30일인 오늘부터 한국코미디언협회장으로 치러지고 있다. 동료 코미디언 이용식씨와 엄영수씨(개명 전 엄용수) 등이 빈소를 찾아 고인을 애도했다. 30일 뉴스1에 따</p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/011" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/011/2022/07/29/logo_011_56_20220729150242.jpg?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">서울경제<span class="datetime">04월 30일 17:14</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="011" data-office_name="서울경제" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/011/0004185101" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/011/2023/04/30/4185101.jpg?type=nf264_176&amp;ut=20230430153101" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">'코스트코 오픈런' 아사히 왕뚜껑 맥주…"문 열자마자 가도 못 사"</div>
# <p class="cjs_d">캔을 뚜껑째 열어 맥주잔처럼 마실 수 있는 일본 ‘아사히 수퍼드라이 생맥주’ 제품이 5월 국내에 한정 출시되는 가운데 며칠 앞서 코스트코에 입고된 상품을 사기 위한 ‘오픈런’ 경쟁이 치열한 것으로 나타났다. 일본에서</p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/293" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# ...
# <div class="cjs_channel_name">TV조선</div>
# </a>
# </li>
# </ul>
# <div class="cjs_channel_title _category_title_b" style="display: none">종합지</div>
# <ul class="cjs_channel_list _category_list_wrapper_b" style="display: none">
# <li class="cjs_channel_item">
# <a aria-checked="false" class="cjs_channel_a _item" data-office_id="469" href="javascript:;" role="checkbox">
# <div class="cjs_channel_mw"><img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/469/2023/02/07/logo_469_56_20230207160012.png" loading="lazy" onerror="showNoImage(this)"/></div>
# <div class="cjs_channel_name">한국일보</div>
# </a>
# </li>
# <li class="cjs_channel_item">
# <a aria-checked="false" class="cjs_channel_a _item" data-office_id="022" href="javascript:;" role="checkbox">
# <div class="cjs_channel_mw"><img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/022/2018/07/18/logo_022_56_20180718152618.png" loading="lazy" onerror="showNoImage(this)"/></div>
# <div class="cjs_channel_name">세계일보</div>
# </a>
# </li>
# <li class="cjs_channel_item">
# <a aria-checked="false" class="cjs_channel_a _item" data-office_id="032" href="javascript:;" role="checkbox">
# <div class="cjs_channel_mw"><img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/032/2022/12/05/logo_032_56_20221205150153.png" loading="lazy" onerror="showNoImage(this)"/></div>
# <div class="cjs_channel_name">경향신문</div>
# </a>
# </li>
# <li class="cjs_channel_item">
# <a aria-checked="false" class="cjs_channel_a _item" data-office_id="021" href="javascript:;" role="checkbox">
# <div class="cjs_channel_mw"><img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/021/2022/08/04/logo_021_56_20220804125306.png" loading="lazy" onerror="showNoImage(this)"/></div>
# <div class="cjs_channel_name">문화일보</div>
# </a>
# </li>
# <li class="cjs_channel_item">
# <a aria-checked="false" class="cjs_channel_a _item" data-office_id="081" href="javascript:;" role="checkbox">
# <div class="cjs_channel_mw"><img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/081/2022/01/05/logo_081_56_20220105195830.png" loading="lazy" onerror="showNoImage(this)"/></div>
# <div class="cjs_channel_name">서울신문</div>
# </a>
# </li>
# <li class="cjs_channel_item">
# <a aria-checked="false" class="cjs_channel_a _item" data-office_id="028" href="javascript:;" role="checkbox">
# <div class="cjs_channel_mw"><img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/028/2018/08/01/logo_028_56_20180801163801.png" loading="lazy" onerror="showNoImage(this)"/></div>
# <div class="cjs_channel_name">한겨레</div>
# </a>
# </li>
# <li class="cjs_channel_item">
# <a aria-checked="false" class="cjs_channel_a _item" data-office_id="020" href="javascript:;" role="checkbox">
# <div class="cjs_channel_mw"><img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/020/2020/09/17/logo_020_56_20200917112548.jpg" loading="lazy" onerror="showNoImage(this)"/></div>
# <div class="cjs_channel_name">동아일보</div>
# </a>
# </li>
# <li class="cjs_channel_item">
# <a aria-checked="false" class="cjs_channel_a _item" data-office_id="005" href="javascript:;" role="checkbox">
# <div class="cjs_channel_mw"><img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/005/2018/07/18/logo_005_56_20180718152218.png" loading="lazy" onerror="showNoImage(this)"/></div>
# <div class="cjs_channel_name">국민일보</div>
# </a>
# </li>
# <li class="cjs_channel_item">
# <a aria-checked="false" class="cjs_channel_a _item" data-office_id="023" href="javascript:;" role="checkbox">
# <div class="cjs_channel_mw"><img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/023/2020/04/29/logo_023_56_20200429140429.png" loading="lazy" onerror="showNoImage(this)"/></div>
# <div class="cjs_channel_name">조선일보</div>
# </a>
# </li>
# <li class="cjs_channel_item">
# <a aria-checked="false" class="cjs_channel_a _item" data-office_id="025" href="javascript:;" role="checkbox">
# <div class="cjs_channel_mw"><img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/025/2021/08/20/logo_025_56_20210820165911.png" loading="lazy" onerror="showNoImage(this)"/></div>
# <div class="cjs_channel_name">중앙일보</div>
# </a>
# </li>
# </ul>
# <div class="cjs_info">
# <button class="cjs_btn_refresh _refresh_btn" onclick="nclk(event, 'home.edittnew', '', '')" type="button">새로보기</button>
# </div>
# </div>
# </div>
# </div>
# <div class="brick-vowel _brick_column">
# </div>
# <div class="brick-vowel _brick_column">
# </div>
# </div>
# </div>
# </section>
# <section class="main_aside _aside_wrapper">
# <div class="main_aside_inner _aside_content">
# <h3 class="blind">구독</h3>
# <div class="_aside"></div>
# <script>
# doAfterLoadEnd(loadAside);
#
#
# function loadAside() {
#     var forcePcVersion = "";
#
#     if (isMobileDevice() && !forcePcVersion) {
#         return;
#     }
#     var iframe = append();
#     var asideFixed;
#
#     window.addEventListener('message', function(event) {
#         var data = event.data;
#
#         if (event.origin !== "https://news.naver.com") {
#             return;
#         }
#
#         if (data.type === "setIframeSize" && data.height) {
#             iframe.style.height = data.height + 'px';
#             iframe.style.visibility = "";
#
#             try {
#                 asideFixed.deactivate(); // event 중복 적용되지 않게
#             } catch(e) {}
#
#             asideFixed = AsideFixed({
#                 "wrapper" : document.querySelector("._aside_wrapper")
#
#             });
#         }
#     });
#
#
#     function append() {
#         var iframe = document.createElement('iframe');
#
#         iframe.width = "100%";
#         iframe.height = "0";
#         iframe.style.visibility = "hidden";
#         iframe.setAttribute("frameborder", "no");
#         iframe.setAttribute("scrolling", "no");
#         iframe.src = "https://news.naver.com/aside?oid=";
#
#         document.querySelector("._aside").appendChild(iframe);
#
#         return iframe;
#     }
# }
# </script>
# </div>
# </section>
# <div class="layer_toast" style="display: none"></div>
# <div class="layer_toast_journal_subscribe _subscribe_toast_layer" style="display: none">
# <button class="lt_btn_set _subscribe_toast_btn" onclick="nclk(event, 'home.edittallchk', '', '')" type="button"></button>
# </div>
# </div>
# </div>
# <!-- //ct -->
# <hr/>
# <div class="mp_footer">
# <div class="f_subinfo">
# <div class="f_subinfoinner">
# <div class="f_notice">
# <h5 class="f_notice_badge">공지</h5>
# <a class="f_notice_link" data-mpurl='{"m":"https://m.news.naver.com/ombudsman/noticeread?notiId=715","p":"https://news.naver.com/main/ombudsman/readView.naver?notiId=715"}' href="https://m.news.naver.com/ombudsman/noticeread?notiId=715" onclick="nclk(event, 'fot.noticetext', '', '');">
# <p class="f_notice_text">기자·연재 카드 개선 안내</p>
# </a>
# </div>
# </div>
# </div>
# <div class="f_maininfo">
# <div class="f_maininfoinner">
# <a class="r_pg_top _go_top" href="javascript:;" id="goTop" onclick="nclk(event, 'fot.pctop', '', '');">맨위로</a>
# <footer role="contentinfo">
# <p class="u_ftlkw _footer_login" id="u_ftlkw">
# <a class="u_ftlk" data-mpurl='{"m":"https://m.naver.com/services.html","p":"https://www.naver.com/more.html"}' href="https://m.naver.com/services.html" onclick="nclk(event,'fot.serviceall','','');">전체서비스</a>
# </p>
# <p class="u_cr">
# <span class="u_ftm">
# <span class="u_cri u_cri_v1"><a class="u_cra" data-mpurl='{"m":"https://policy.naver.com/policy-mobile/term.html?type=1?type=1","p":"https://policy.naver.com/rules/service.html"}' href="https://policy.naver.com/policy-mobile/term.html?type=1?type=1" onclick="nclk(event,'fot.agreement','','');">이용약관</a></span>
# <span class="u_cri u_cri_v1"><a class="u_cra" data-mpurl='{"m":"https://policy.naver.com/policy-mobile/privacy.html","p":"https://policy.naver.com/rules/privacy.html"}' href="https://policy.naver.com/policy-mobile/privacy.html" onclick="nclk(event,'fot.privacy','','');"><strong>개인정보처리방침</strong></a></span>
# <span class="u_cri u_cri_v1">청소년 보호 책임자 : 이희만</span>
# <span class="u_cri u_cri_v1"><a class="u_cra" data-mpurl='{"m":"https://m.news.naver.com/ombudsman/index","p":"https://news.naver.com/main/ombudsman/index.naver"}' href="https://m.news.naver.com/ombudsman/index" onclick="nclk(event,'fot.guide','','');">서비스안내</a></span>
# </span>
# <span class="u_cri">각 언론사가 직접 콘텐츠를 편집합니다.</span>
# </p>
# </footer>
# </div>
# </div>
# </div>
# <script src="https://ssl.pstatic.net/static.news/mnews/resources/20230420_005654/js/generated/news.mobile.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/static.news/mnews/resources/20230420_005654/js/generated/pressmain.dependency.js" type="text/javascript"></script>
# <script type="text/javascript">
# /**
#  * 이 파일은 모바일 뉴스 서비스 전체 페이지에 적용되는 스크립트로써,
#  * 코드 추가 시 Front-End 성능 관점에서 주의를 요합니다.
#  */
# jQuery(window).on('load', function(){
#     setTimeout(onload, 10);
#
#     function onload(){
#         var oLnb = new news.Lnb('._lnb_scroll');
#         new news.ImageLazyLoader().load("img[data-src]");
#         new news.MoveTopButton("._go_top");
#
#
#         new news.HistoryManager().init("naver_mobile_news_history", "");
#
#         // iframe lazy-loading
#         (function(){
#             try {
#                 Array.prototype.slice.apply(document.querySelectorAll('iframe[data-src]'))
#                     .forEach(function(iframeEl) {
#                         var originSrc = iframeEl.getAttribute('data-src');
#                         if(originSrc) {
#                             iframeEl.setAttribute('src', originSrc);
#                         }
#                     });
#             }catch(e) {}
#         })();
#
#         if(typeof init === "function"){
#             init();
#         }
#
#         var cookie = news.Cookie.getInstance();
#         var isShownNewLnb = cookie.getItem("isShownNewLnb");
#         if(isShownNewLnb == null) {
#             isShownNewLnb = "Y";
#             cookie.setItem("isShownNewLnb", isShownNewLnb, 3650, "", "/");
#             $("._isNew").addClass("is_new");
#         }
#
#         {
#             var footerLogin = jQuery(document).find('._footer_login');
#             if(footerLogin <= 0) {
#                 return;
#             }
#
#             // 디바이스에 따라 로그인, 로그아웃 URL 분기
#             var loginUrl = "https://nid.naver.com/nidlogin.login";
#             var logoutUrl = "https://nid.naver.com/nidlogin.logout?";
#             if (news.Util.getAgentInfo().bMobileOrTablet) {
#                 loginUrl = "https://nid.naver.com/nidlogin.login?svctype=262144";
#                 logoutUrl = "https://nid.naver.com/nidlogin.logout?svctype=262144&";
#             }
#
#             if(news.LoginAssistor.isLoginUser()) {
#                 footerLogin.prepend('<a href="javascript:news.Util.logout(\''+logoutUrl+'url=\'+encodeURIComponent(location.href));" class="u_ftlk" id="news_logout" onclick="nclk(event,\'fot.logout\',\'\',\'\');" >로그아웃</a>')
#             }else {
#                 footerLogin.prepend('<a href="'+loginUrl+'" class="u_ftlk" id="news_login" onclick="nclk(event,\'fot.login\',\'\',\'\');" >로그인</a>')
#             }
#         }
#     }
# });
# </script>
# <script id="feedRefreshButtonTemplate" type="text/x-handlebars-template">
#     {{buttonText}}
#     <span class="paging">
#         <span class="blind">현재</span>{{currentPage}}
#         <em class="total"> / <span class="blind">전체</span>{{totalPage}}</em>
#     </span>
# </script>
# <script type="text/javascript">
#     FeedCard($('._journalist_feed_card_wrapper'), 'journalist', 'https://m.news.naver.com');
#     FeedCard($('._series_feed_card_wrapper'), 'series', 'https://m.news.naver.com');
#     BrickGridForEditByPress($("._brick_gid_wrapper"));
#     PressMainStatusCard($('._press_main_status_wrapper'));
#     NewsFlashCard($('._newsflash_wrapper'));
#
#
#
#
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#         adSlot.setCustomParam("calp", 'home');
#         window.gladsdk.displayAd(adSlot);
#
#
#         window.gladsdk.addEventListener(window.gladsdk.event.ERROR, function (ad, error) {
#             $("._card_ad").hide();
#         });
#     });
#
#     $('._channel_news_card_wrapper').each(function () {
#         var wrapper = $(this);
#         ChannelNewsCard(wrapper, 'https://m.news.naver.com');
#     })
#
#     ChannelNewsPreviewCard($('._channel_news_preview_wrapper'), 'https://m.news.naver.com');
#     SubscribeBannerShortCard($('._short_subscribe_banner_card_wrapper'), 'https://m.news.naver.com');
#     SubscribeBannerLongCard($('._long_subscribe_banner_card_wrapper'), 'https://m.news.naver.com');
#
#     WeeklySpecialReportCard($('._weekly_special_report_card_wrapper'));
#
#     $('._horizontal_card_wrapper').each(function () {
#         var wrapper = $(this);
#         HorizontalTypeCard(wrapper, 'https://m.news.naver.com');
#     });
#
#     SpecialReportCard($('._special_report_card_wrapper'), 'https://m.news.naver.com');
#
#     ArticleLinkParamsAppender('news_media_pc');
# </script>
# <script>
#     var gnb_service = 'news';
#     var gnb_logout = encodeURIComponent(location.href);
#     var gnb_template = 'gnb_utf8';
#     var gnb_brightness = 3;
#
#     doAfterLoadEnd(function () {
#         try {
#             GlobalMPUrlManager.init();
#         } catch (e) {}
#     });
#
#     doAfterLoadEnd(function() {
#         if (!document.querySelector('#gnb') || isMobileDevice() === true) {
#             return;
#         }
#
#         var gnb_src = "https://ssl.pstatic.net/static.gn/templates/gnb_utf8?2023043017";
#
#         // GnbHelper를 이용하여 GNB Layer를 닫을 수 있도록 지원한다.
#         if (window.jindo) {
#             jindo.LazyLoading.load(
#                 gnb_src,
#                 function() {
#                     try {
#                         getGNB();
#                     } catch(e) {}
#                 },
#                 'utf-8'
#             );
#
#             jindo.$Fn(function (oEvent) {
#
#                 GnbHelper.attachClick(oEvent.$value().target);
#             }).attach(document, 'click');
#         } else if (window.jQuery) {
#             new news.JsLoader().
#                 load(
#                     [gnb_src],
#                     function() {
#                         try {
#                             getGNB();
#                         } catch(e) {}
#                     }
#                 );
#
#             $(document).on("click", function(event) {
#                 GnbHelper.attachClick(event.target);
#             });
#         }
#     });
# </script>
# <script>
#     doAfterLoadEnd(function() {
#         if (!document.querySelector('.news_header')){
#             return;
#         }
#
#         try {
#             GnbFloatingManager.init();
#         } catch (e) { }
#     });
# </script>
# <script>
# doAfterLoadEnd(function() {
#     try {
#         new SearchAutoComplete({
#             content: document.querySelector("._search_content"),
#             contentToggleBtn: document.querySelector("._search_content_toggle_btn"),
#             isMobile: isMobileDevice(),
#             nClickType: "newsM"
#         });
#     } catch(e) {}
# });
# </script>
# <!-- LCS -->
# <script type="text/javascript">
#
# function initMa(){
#     var data = {
#         "service": "news",
#         "baseInfo": {
#             "category": (function(){
#
#                 var result = "언론사별(신규)";
#
#                 if(result !== ""){
#                     return result;
#                 }
#                 try{
#
#                     return document.querySelector('meta[property="og:title"]')
#                         .getAttribute('content')
#                         .replace(/[\s]*:+[\s]*네이버[\s]*뉴스/, '');
#                 }catch(e){
#                     return "";
#                 }
#             })()
#         },
#         "extraInfo": {}
#     };
#
#
#
#     try{
#         ma.init({
#             api: "https://ma.news.naver.com/l",
#             data: data
#         });
#     }catch(e){}
# }
# </script>
# <script type="text/javascript">
#
#
#
# var eventType = "onpageshow" in window ? "pageshow" : "load";
# jQuery(window).on(eventType, function() {
#
#
#
# lcs_do();
#
#
#     try{
#         initMa();
#     }catch(e){}
# });
# </script>
# <!-- //LCS -->
# <div id="videoWrap"></div>
# </body>
# </html>

# %%
bs.find('title').get_text()
# Out:
# '네이버 뉴스'

# %%
bs.find('title').text
# Out:
# '네이버 뉴스'

# %%
bs.find('title').string
# Out:
# '네이버 뉴스'

# %%
# 기상청 데이터
# urlopen() 과 BeautifulSoup 조합
from bs4 import BeautifulSoup
import urllib.request as req
url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"
# urlopen()으로 데이터 가져오기
res = req.urlopen(url)
# BeautifulSoup으로 분석하기
soup = BeautifulSoup(res, "html.parser")
print(soup)
# Out:
# <?xml version="1.0" encoding="utf-8" ?>
# <rss version="2.0">
# <channel>
# <title>기상청 육상 중기예보</title>
# <link/>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp
# <description>기상청 날씨 웹서비스</description>
# <language>ko</language>
# <generator>기상청</generator>
# <pubdate>2023년 04월 30일 (일)요일 06:00</pubdate>
# <item>
# <author>기상청</author>
# <category>육상중기예보</category>
# <title>전국 육상 중기예보 - 2023년 04월 30일 (일)요일 06:00 발표</title>
# <link/>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp
# <guid>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp</guid>
# <description>
# <header>
# <title>전국 육상중기예보</title>
# <tm>202304300600</tm>
# <wf><![CDATA[○ (강수) 5월 4일(목)은 전남권과 경남권, 제주도에 비가 오겠습니다.<br />○ (기온) 이번 예보기간 아침 기온은 8~18도로 평년(최저기온 9~14도)과 비슷하거나 조금 높겠고, 낮 기온은 18~25도로 평년(최고기온 20~25도)과 비슷하겠습니다.<br />○ (해상) 5월 4일(목)~6일(토)은 전해상에서 물결이 1.0~3.0m로 높게 일겠습니다.<br /><br />* 이번 예보기간에는 기압골의 발달 정도와 이동 속도에 따라 강수시점과 구역이 변경될 가능성이 있으니, 앞으로 발표되는 최신 예보를 참고하기 바랍니다.]]></wf>
# </header>
# <body>
# <location wl_ver="3">
# <province>서울ㆍ인천ㆍ경기도</province>
# <city>서울</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>14</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>14</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>맑음</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>서울ㆍ인천ㆍ경기도</province>
# <city>인천</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>18</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>맑음</wf>
# <tmn>13</tmn>
# <tmx>18</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>18</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>서울ㆍ인천ㆍ경기도</province>
# <city>수원</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>12</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>12</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>맑음</wf>
# <tmn>13</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>서울ㆍ인천ㆍ경기도</province>
# <city>파주</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>9</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>9</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>11</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>8</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>8</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>서울ㆍ인천ㆍ경기도</province>
# <city>이천</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>11</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>11</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>서울ㆍ인천ㆍ경기도</province>
# <city>평택</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>12</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>12</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>맑음</wf>
# <tmn>13</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>강원도영서</province>
# <city>춘천</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>10</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>10</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>11</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>11</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>11</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>11</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>강원도영서</province>
# <city>원주</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>12</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>12</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>13</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>13</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>강원도영동</province>
# <city>강릉</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>16</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>16</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>15</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>18</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>12</tmn>
# <tmx>18</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>13</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>대전ㆍ세종ㆍ충청남도</province>
# <city>대전</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>12</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>12</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>13</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>대전ㆍ세종ㆍ충청남도</province>
# <city>세종</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>11</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>11</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>14</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>8</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>대전ㆍ세종ㆍ충청남도</province>
# <city>홍성</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>11</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>11</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>12</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>충청북도</province>
# <city>청주</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>13</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>13</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>14</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>13</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>충청북도</province>
# <city>충주</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>10</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>10</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>11</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>11</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>12</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>8</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>충청북도</province>
# <city>영동</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>8</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>8</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>10</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>10</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>11</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>11</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>7</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>8</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>광주ㆍ전라남도</province>
# <city>광주</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>15</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>80</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>15</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>80</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>18</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>18</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>13</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>12</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>광주ㆍ전라남도</province>
# <city>목포</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>15</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>80</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>15</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>80</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>12</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>광주ㆍ전라남도</province>
# <city>여수</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>15</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>80</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>15</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>80</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>13</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>13</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>광주ㆍ전라남도</province>
# <city>순천</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>11</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>흐림</wf>
# <tmn>11</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>14</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>80</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>14</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>80</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>12</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>광주ㆍ전라남도</province>
# <city>광양</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>14</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>80</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>14</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>80</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>13</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>11</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>광주ㆍ전라남도</province>
# <city>나주</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>11</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>흐림</wf>
# <tmn>11</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>80</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>80</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>10</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>전라북도</province>
# <city>전주</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>13</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>14</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>전라북도</province>
# <city>군산</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>11</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>흐림</wf>
# <tmn>11</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>13</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>전라북도</province>
# <city>정읍</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>12</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>18</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>18</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>14</tmn>
# ...
# <tmn>12</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>대구ㆍ경상북도</province>
# <city>대구</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>12</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>12</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>대구ㆍ경상북도</province>
# <city>안동</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>10</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>10</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>11</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>11</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>대구ㆍ경상북도</province>
# <city>포항</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>14</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>14</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>18</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>18</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>18</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>18</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>13</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>13</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>13</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>대구ㆍ경상북도</province>
# <city>경주</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>9</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>9</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>11</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>11</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>9</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>대구ㆍ경상북도</province>
# <city>울진</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>13</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>13</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>18</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>18</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>11</tmn>
# <tmx>17</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>흐림</wf>
# <tmn>11</tmn>
# <tmx>17</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>11</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>10</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>대구ㆍ경상북도</province>
# <city>울릉도</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>14</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>14</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐림</wf>
# <tmn>13</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>17</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>17</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>17</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>14</tmn>
# <tmx>17</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>17</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>흐림</wf>
# <tmn>12</tmn>
# <tmx>17</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>17</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>13</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>맑음</wf>
# <tmn>12</tmn>
# <tmx>17</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>제주도</province>
# <city>제주</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>17</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>90</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>17</tmn>
# <tmx>23</tmx>
# <reliability></reliability>
# <rnst>90</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>19</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>19</tmn>
# <tmx>24</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>15</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>14</tmn>
# <tmx>19</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>15</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>제주도</province>
# <city>서귀포</city>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-03 12:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>20</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 00:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>17</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>90</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-04 12:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>17</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>90</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 00:00</tmef>
# <wf>흐림</wf>
# <tmn>18</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-05 12:00</tmef>
# <wf>흐림</wf>
# <tmn>18</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 00:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-06 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 00:00</tmef>
# <wf>흐림</wf>
# <tmn>16</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2023-05-07 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>16</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-08 00:00</tmef>
# <wf>맑음</wf>
# <tmn>15</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-09 00:00</tmef>
# <wf>맑음</wf>
# <tmn>14</tmn>
# <tmx>21</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2023-05-10 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>14</tmn>
# <tmx>22</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# </location>
# </body>
# </description>
# </item>
# </channel>
# </rss>

# %%
# 원하는 데이터 추출하기
title = soup.find("title").text
print(title)
# Out:
# 기상청 육상 중기예보

# %%
wf = soup.find("wf").text
print(wf)
# Out:
# ○ (강수) 5월 4일(목)은 전남권과 경남권, 제주도에 비가 오겠습니다.<br />○ (기온) 이번 예보기간 아침 기온은 8~18도로 평년(최저기온 9~14도)과 비슷하거나 조금 높겠고, 낮 기온은 18~25도로 평년(최고기온 20~25도)과 비슷하겠습니다.<br />○ (해상) 5월 4일(목)~6일(토)은 전해상에서 물결이 1.0~3.0m로 높게 일겠습니다.<br /><br />* 이번 예보기간에는 기압골의 발달 정도와 이동 속도에 따라 강수시점과 구역이 변경될 가능성이 있으니, 앞으로 발표되는 최신 예보를 참고하기 바랍니다.

# %%
# 한글과 숫자만 출력
result = re.findall('[가-힣0-9]+',wf)
' '.join(result)
# Out:
# '강수 5월 4일 목 은 전남권과 경남권 제주도에 비가 오겠습니다 기온 이번 예보기간 아침 기온은 8 18도로 평년 최저기온 9 14도 과 비슷하거나 조금 높겠고 낮 기온은 18 25도로 평년 최고기온 20 25도 과 비슷하겠습니다 해상 5월 4일 목 6일 토 은 전해상에서 물결이 1 0 3 0 로 높게 일겠습니다 이번 예보기간에는 기압골의 발달 정도와 이동 속도에 따라 강수시점과 구역이 변경될 가능성이 있으니 앞으로 발표되는 최신 예보를 참고하기 바랍니다'

# %%
wf = soup.find("wf").text
wf = re.sub('<.+?>','',wf)
print(wf)
wf = ''.join(re.findall('[^A-Z0-9]?[0-9가-힣]+[^A-Z0-9]?',wf))
# wf = ''.join(re.findall('\w*\s',wf))
wf
# Out:
# ○ (강수) 5월 4일(목)은 전남권과 경남권, 제주도에 비가 오겠습니다.○ (기온) 이번 예보기간 아침 기온은 8~18도로 평년(최저기온 9~14도)과 비슷하거나 조금 높겠고, 낮 기온은 18~25도로 평년(최고기온 20~25도)과 비슷하겠습니다.○ (해상) 5월 4일(목)~6일(토)은 전해상에서 물결이 1.0~3.0m로 높게 일겠습니다.* 이번 예보기간에는 기압골의 발달 정도와 이동 속도에 따라 강수시점과 구역이 변경될 가능성이 있으니, 앞으로 발표되는 최신 예보를 참고하기 바랍니다.
# '(강수) 5월 4일(목)은 전남권과 경남권, 제주도에 비가 오겠습니다.(기온) 이번 예보기간 아침 기온은 8~18도로 평년(최저기온 9~14도)과 비슷하거나 조금 높겠고, 낮 기온은 18~25도로 평년(최고기온 20~25도)과 비슷하겠습니다.(해상) 5월 4일(목)~6일(토)은 전해상에서 물결이 1.0~3.0m로 높게 일겠습니다. 이번 예보기간에는 기압골의 발달 정도와 이동 속도에 따라 강수시점과 구역이 변경될 가능성이 있으니, 앞으로 발표되는 최신 예보를 참고하기 바랍니다.'

# %%
wf = soup.find('wf').get_text()
wf = re.sub('<.+?>','',wf) # wf 문자열에서 모든 HTML 태그를 제거하여 반환
wf = re.finditer('\w',wf)
print(title,'\n')
for i in wf:
    print(i.group(), end='')
# Out:
# 기상청 육상 중기예보
#
# 강수5월4일목은전남권과경남권제주도에비가오겠습니다기온이번예보기간아침기온은818도로평년최저기온914도과비슷하거나조금높겠고낮기온은1825도로평년최고기온2025도과비슷하겠습니다해상5월4일목6일토은전해상에서물결이1030m로높게일겠습니다이번예보기간에는기압골의발달정도와이동속도에따라강수시점과구역이변경될가능성이있으니앞으로발표되는최신예보를참고하기바랍니다

# %% [markdown]
# #### [과제] 기상청 육상 정보에서 강원도의 지역번호는 105이다. 강원도의 날씨예보를 출력하세요.
# url = 'https://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=105'

# %%
# requests
from bs4 import BeautifulSoup
import requests
import re
url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=105"
res = requests.get(url).text
soup = BeautifulSoup(res,'html.parser')
wf = soup.find('wf').text
text = ''.join(re.findall('[^A-Z0-9]?[0-9가-힣]+[^A-Z0-9]?',wf))
text
# Out:
# '(하늘상태) 이번 예보기간은 대체로 흐린 날이 많겠으나, 5월 8일(월)~10일(수)은 대체로 맑겠습니다.(기온) 이번 예보기간 아침 기온은 5~16도, 낮 기온은 14~26도로 평년(최저기온 6~12도, 최고기온 17~25도)과 비슷하거나 조금 높겠습니다.(해상) 동해중부해상의 물결은 5월 5일(금)~6일(토)은 1.0~3.0m로 높게 일겠습니다. 이번 예보기간에는 기압골의 발달 정도와 이동 속도에 따라 강수시점과 구역이 변경될 가능성이 있으니, 앞으로 발표되는 최신 예보를 참고하기 바랍니다.'

# %%
# urllib
import re
from bs4 import BeautifulSoup
import urllib.request
import urllib.parse

API = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"
# 매개변수를 URL 인코딩합니다.
values = {
    'stnId': '105'
}
params = urllib.parse.urlencode(values)
# 요청 전용 URL을 생성합니다.
url = API + "?" + params
print("url=", url)

res = urllib.request.urlopen(url)
soup = BeautifulSoup(res,'html.parser')
wf = soup.find('wf').string
text = ''.join(re.findall('[^A-Z0-9]?[0-9가-힣]+[^A-Z0-9]?',wf))
text
# Out:
# url= http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=105
# '(하늘상태) 이번 예보기간은 대체로 흐린 날이 많겠으나, 5월 8일(월)~10일(수)은 대체로 맑겠습니다.(기온) 이번 예보기간 아침 기온은 5~16도, 낮 기온은 14~26도로 평년(최저기온 6~12도, 최고기온 17~25도)과 비슷하거나 조금 높겠습니다.(해상) 동해중부해상의 물결은 5월 5일(금)~6일(토)은 1.0~3.0m로 높게 일겠습니다. 이번 예보기간에는 기압골의 발달 정도와 이동 속도에 따라 강수시점과 구역이 변경될 가능성이 있으니, 앞으로 발표되는 최신 예보를 참고하기 바랍니다.'

# %% [markdown]
# #### 연습 : urllib

# %% [markdown]
# #### Q. "http://www.naver.com" 사이트에서 span 태그에 연결된 한글만을 불필요한 공백을 제거한 후 출력하세요.

# %%
import urllib.request as rq
import re
url = "http://www.naver.com"
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'lxml')
print(bs.prettify())
# Out:
# <!DOCTYPE html>
# <html data-dark="false" lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    NAVER
#   </title>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=1190" name="viewport"/>
#   <meta content="NAVER" name="apple-mobile-web-app-title"/>
#   <meta content="index,nofollow" name="robots"/>
#   <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description"/>
#   <meta content="네이버" property="og:title"/>
#   <meta content="https://www.naver.com/" property="og:url"/>
#   <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/>
#   <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="" name="twitter:title"/>
#   <meta content="https://www.naver.com/" name="twitter:url"/>
#   <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" name="twitter:image"/>
#   <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="twitter:description"/>
#   <link href="https://pm.pstatic.net/dist/css/nmain.20230302.css" rel="stylesheet"/>
#   <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_220526.css" rel="stylesheet"/>
#   <link href="/favicon.ico?1" rel="shortcut icon" type="image/x-icon"/>
#   <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png" rel="apple-touch-icon"/>
#   <script>
#    window.nmain=window.nmain||{},window.nmain.supportFlicking=!1;var nsc="navertop.v4",ua=navigator.userAgent,useIeJSFlag="1";window.nmain.isIE="0"===useIeJSFlag,document.getElementsByTagName("html")[0].setAttribute("data-useragent",ua),window.nmain.isIE&&(Object.create=function(n){function e(){}return e.prototype=n,new e})
#   </script>
#   <script>
#    var darkmode= false;window.naver_corp_da=window.naver_corp_da||{main:{}},window.naver_corp_da.main=window.naver_corp_da.main||{},window.naver_corp_da.main.darkmode=darkmode,window.gladsdk=window.gladsdk||{cmd:[]},window.gladsdk.cmd.push((function(){window.gladsdk.setHostMeta("theme",darkmode?"dark":"light")})),window.ndpsdk=window.ndpsdk||{cmd:[],polyfill:{cmd:[]}},window.ndpsdk.cmd.push((function(){window.ndpsdk.setHostMeta("theme",darkmode?"dark":"light")}))
#   </script>
#   <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js">
#   </script>
#   <script async="" src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js">
#   </script>
#   <script>
#    window.nmain.gv = {  isLogin: false,
# useId: null,   daInfo: {"BEAUTY":{"menu":"BEAUTY","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000163","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_1","tb":"BEAUTY_1","unit":"SU10595","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000164","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_2","tb":"BEAUTY_1","unit":"SU10596","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVING":{"menu":"LIVING","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000183","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_1","tb":"LIVING_1","unit":"SU10597","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000184","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_2","tb":"LIVING_1","unit":"SU10606","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVINGHOME":{"menu":"LIVINGHOME","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000185","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_livinghome_1","tb":"LIVINGHOME_1","unit":"SU10571","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000186","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_livinghome_2","tb":"LIVINGHOME_1","unit":"SU10572","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]}},
# svt: 20230430174706,
# };
#   </script>
#   <script>
#    window.nmain.newsstand = {
# rcode: '09440127',
# newsCastSubsInfo: '',
# newsStandSubsInfo: ''
# };
# window.etc = {  };
# window.svr = "<!--cweb14-->";
#   </script>
#   <script defer="defer" src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js">
#   </script>
#   <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/external.2961eaa5.js?o=www" type="text/javascript">
#   </script>
#   <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/preload.5fe99fda.js?o=www" type="text/javascript">
#   </script>
#   <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/polyfill.f3c68d2d.js?o=www" type="text/javascript">
#   </script>
#   <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/vendors~more~nmain~notice~search~sidebar_notice.40da85e0.js?o=www" type="text/javascript">
#   </script>
#   <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/search.c0c3b1c5.js?o=www" type="text/javascript">
#   </script>
#   <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/vendors~more~nmain~sidebar_notice.7aad5e27.js?o=www" type="text/javascript">
#   </script>
#   <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/nmain.e31af4db.js?o=www" type="text/javascript">
#   </script>
#   <style>
#    :root{color-scheme:light}#_nx_kbd .setkorhelp a{display:none}
#   </style>
#  </head>
#  <body>
#   <div id="u_skip">
#    <a href="#newsstand">
#     <span>
#      뉴스스탠드 바로가기
#     </span>
#    </a>
#    <a href="#themecast">
#     <span>
#      주제별캐스트 바로가기
#     </span>
#    </a>
#    <a href="#timesquare">
#     <span>
#      타임스퀘어 바로가기
#     </span>
#    </a>
#    <a href="#shopcast">
#     <span>
#      쇼핑캐스트 바로가기
#     </span>
#    </a>
#    <a href="#account">
#     <span>
#      로그인 바로가기
#     </span>
#    </a>
#   </div>
#   <div id="wrap">
#    <style>
#     ._1syGnXOL{padding-right:18px;font-size:14px;line-height:0;letter-spacing:-.25px;color:#000}._1syGnXOL span,._1syGnXOL strong{line-height:49px}._1syGnXOL:before{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20220527@2x.png);background-repeat:no-repeat;background-size:141px 112px;width:18px;height:18px;margin:16px 8px 0 0;background-position:-98px 0}[data-useragent*="MSIE 8"] ._1syGnXOL:before{background-image:url(https://static-whale.pstatic.net/main/sprite-20220527.png)}._1syGnXOL._3dsvmZg2:before{background-position:-47px -85px}._1syGnXOL._1NBFx1WK:before{width:20px;height:20px;margin:15px 8px 0 0;background-position:-21px -89px}._1syGnXOL._2mcQEKCd:before{width:22px;height:22px;margin:14px 7px 0 0;background-position:-47px -63px}._1syGnXOL._36slsKuJ:before{width:21px;height:49px;margin:0 14px 0 0;background-position:0 -63px}._1syGnXOL._3qlJVWzR:before{width:24px;height:49px;margin:0 10px 0 0;background-position:-117px 0}._1syGnXOL._3VkgqBXB:before{width:26px;height:49px;margin:0 10px 0 0;background-position:-116px -54px}._1syGnXOL._3di88A4c{padding-right:12px;font-size:17px}._1syGnXOL._3di88A4c:before{content:none}._1syGnXOL ._19K4X1CD{text-decoration:underline}._2aeXMlrb{display:inline-block;position:relative;font-size:12px;height:49px;width:78px;text-decoration:none;color:#fff;font-weight:700;letter-spacing:-.5px;vertical-align:top}._2aeXMlrb span{text-align:center;margin:9px 0;height:31px;display:block;line-height:31px;border-radius:15px}._2aeXMlrb span:before{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20220527@2x.png);background-repeat:no-repeat;background-size:141px 112px}[data-useragent*="MSIE 8"] ._2aeXMlrb span:before{background-image:url(https://static-whale.pstatic.net/main/sprite-20220527.png)}._2aeXMlrb.BMgpjddw{font-size:11px;width:94px}._2aeXMlrb.BMgpjddw span:before{margin:9px 3px 0 0;width:17px;height:13px;background-position:-89px -63px}._3h-N8T9V{position:absolute;top:0;left:0;right:0;bottom:0;background:rgba(0,0,0,0)}._1KncATpM{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20220527@2x.png);background-repeat:no-repeat;background-size:141px 112px;margin-top:14px;float:left;width:98px;height:21px;background-position:0 -21px}[data-useragent*="MSIE 8"] ._1KncATpM{background-image:url(https://static-whale.pstatic.net/main/sprite-20220527.png)}._1KncATpM._2v3uxv2x{background-position:0 0}._1KncATpM._1yl_Ow6o{background-position:0 -42px}._20PYt6lT{font-size:11px;height:49px;cursor:pointer;position:absolute;top:0;right:0;color:#666;opacity:.7}._20PYt6lT:after{width:15px;height:15px;margin-left:4px;background-position:-98px -33px;display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20220527@2x.png);background-repeat:no-repeat;background-size:141px 112px}[data-useragent*="MSIE 8"] ._20PYt6lT:after{background-image:url(https://static-whale.pstatic.net/main/sprite-20220527.png)}._20PYt6lT._39oMCV2N:after{background-position:-98px -18px}._20PYt6lT._3MOWOORv{color:#c3c2c2}._20PYt6lT._3MOWOORv:after{background-position:-80px -85px}._20PYt6lT._3wm5EzmJ{color:#fff}._20PYt6lT._3wm5EzmJ:after{background-position:-65px -85px}._1hiMWemA{height:49px}._1hiMWemA .tY_u8r23{position:relative;width:1130px;margin:0 auto}._1hiMWemA .tY_u8r23 a{text-decoration:none}._1hiMWemA._23U_6TM_{position:relative}._1hiMWemA._23U_6TM_:after{position:absolute;z-index:1;content:"";display:block;width:100%;height:1px;bottom:0;background-color:rgba(0,0,0,.050980392156862744)}
#    </style>
#    <div class="_1hiMWemA" data-clk-prefix="top" id="NM_TOP_BANNER" style="background-color: #fff7e1">
#     <div class="tY_u8r23">
#      <a class="_3h-N8T9V" data-clk="dropbanner1a" href="https://whale.naver.com/ko/details/security/&amp;wpid=RydDy7">
#      </a>
#      <span class="_1syGnXOL _3VkgqBXB" data-clk="dropbanner1a" style="padding-right: 20px; font-size: 17px; color: black">
#       <span>
#        매일 쓰는 브라우저 보안이 걱정된다면,
#       </span>
#       <strong>
#        안전하고 빠른 최신 브라우저 웨일로 업데이트 하세요.
#       </strong>
#      </span>
#      <a class="_2aeXMlrb BMgpjddw" data-clk="dropdownload1a" href="https://installer-whale.pstatic.net/downloads/banner/RydDy7/WhaleSetup.exe" id="NM_whale_download_btn">
#       <span style="background-color: #0436c7">
#        다운로드
#       </span>
#      </a>
#      <button class="_20PYt6lT _39oMCV2N" data-clk="dropclose1a" data-ui-cookie-exp-days="3" data-ui-cookie-key="NM_TOP_PROMOTION" data-ui-cookie-value="1" data-ui-hide-target="#NM_TOP_BANNER" type="button">
#       3일 동안 보지 않기
#      </button>
#     </div>
#    </div>
#    <div id="header" role="banner">
#     <div class="special_bg">
#      <div class="group_flex">
#       <div class="logo_area">
#        <h1 class="logo_default">
#         <a class="logo_naver" data-clk="top.logo" href="/">
#          <span class="blind">
#           네이버
#          </span>
#         </a>
#        </h1>
#       </div>
#       <div class="service_area">
#        <a class="link_set" data-clk="top.mkhome" href="https://help.naver.com/support/welcomePage/guide.help" id="NM_set_home_btn">
#         네이버를 시작페이지로
#        </a>
#        <i class="sa_bar">
#        </i>
#        <a class="link_jrnaver" data-clk="top.jrnaver" href="https://jr.naver.com">
#         <i class="ico_jrnaver">
#         </i>
#         <span class="blind">
#          쥬니어네이버
#         </span>
#        </a>
#        <a class="link_happybin" data-clk="top.happybean" href="https://happybean.naver.com">
#         <i class="ico_happybin">
#         </i>
#         <span class="blind">
#          해피빈
#         </span>
#        </a>
#       </div>
#       <div class="search_area" data-clk-prefix="sch" id="search">
#        <form action="https://search.naver.com/search.naver" id="sform" method="get" name="sform" role="search">
#         <fieldset>
#          <legend class="blind">
#           검색
#          </legend>
#          <input name="where" type="hidden" value="nexearch"/>
#          <input id="sm" name="sm" type="hidden" value="top_hty"/>
#          <input id="fbm" name="fbm" type="hidden" value="0"/>
#          <input disabled="disabled" id="acr" name="acr" type="hidden" value=""/>
#          <input disabled="disabled" id="acq" name="acq" type="hidden" value=""/>
#          <input disabled="disabled" id="qdt" name="qdt" type="hidden" value=""/>
#          <input id="ie" name="ie" type="hidden" value="utf8"/>
#          <input disabled="disabled" id="acir" name="acir" type="hidden" value=""/>
#          <input disabled="disabled" id="os" name="os" type="hidden" value=""/>
#          <input disabled="disabled" id="bid" name="bid" type="hidden" value=""/>
#          <input disabled="disabled" id="pkid" name="pkid" type="hidden" value=""/>
#          <input disabled="disabled" id="eid" name="eid" type="hidden" value=""/>
#          <input disabled="disabled" id="mra" name="mra" type="hidden" value=""/>
#          <div class="green_window" style="">
#           <!-- [AU] data-atcmp-element 에 해당하는 attribute를 추가해주세요. -->
#           <input accesskey="s" autocomplete="off" class="input_text" data-atcmp-element="" id="query" maxlength="255" name="query" onclick="document.getElementById('fbm').value=1;" placeholder="검색어를 입력해 주세요." style="ime-mode:active;" tabindex="1" title="검색어 입력" type="search" value=""/>
#          </div>
#          <button class="btn_submit" id="search_btn" onclick="window.nclick(this,'sch.action','','',event);" style="" tabindex="3" title="검색" type="submit">
#           <span class="blind">
#            검색
#           </span>
#           <span class="ico_search_submit">
#           </span>
#          </button>
#         </fieldset>
#        </form>
#        <!-- 한글입력기 -->
#        <a class="btn_keyboard" href="#" id="ke_kbd_btn" onclick="return false;" role="button">
#         <span class="blind">
#          한글 입력기
#         </span>
#         <span class="ico_keyboard">
#         </span>
#        </a>
#        <div id="_nx_kbd" style="display:none;">
#        </div>
#        <div class="autocomplete">
#         <!-- 자동완성 열린 경우 fold 클래스 추가, 딤드인 경우 dim 추가 -->
#         <a aria-pressed="false" class="btn_arw _btn_arw fold" data-atcmp-element="" href="#" id="nautocomplete" role="button" tabindex="2">
#          <span class="blind">
#           자동완성 레이어
#          </span>
#          <span class="ico_arr">
#          </span>
#         </a>
#        </div>
#        <!-- 자동완성레이어 -->
#        <div class="reatcmp" id="autoFrame" style="display: none;">
#         <!-- [AU] data-atcmp-element attribute를 추가해주세요. -->
#         <div class="ly_atcmp" data-atcmp-element="">
#          <div class="api_atcmp_wrap">
#           <!-- 최근검색어 -->
#           <!-- [AU] _recent_layer 클래스를 추가해주세요. -->
#           <div class="atcmp_fixer _recent_layer" style="display:none;">
#            <!-- [AU] _recent_header 클래스를 추가해주세요. -->
#            <div class="atcmp_header _recent_header">
#             <strong class="tit">
#              최근검색어
#             </strong>
#             <div class="option">
#              <!-- [AU] _delAll 클래스를 추가해주세요. -->
#              <a aria-pressed="false" class="item _delAll" href="#" role="button">
#               전체삭제
#              </a>
#             </div>
#            </div>
#            <div class="atcmp_container">
#             <!-- [AU] _recent 클래스를 추가해주세요. -->
#             <ul class="kwd_lst _recent">
#              <!-- 최근검색어 템플릿 -->
#              <!-- [AU] _item 클래스를 추가해주세요. -->
#              <!-- [AU] data-template-type="history" data-keyword="@in_txt@" attribute를 추가해주세요. -->
#              <li class="item _item" data-keyword="@in_txt@" data-rank="@rank@" data-template-type="history">
#               <a class="kwd" href="#">
#                <span class="fix">
#                 <span class="common_ico_kwd">
#                  <i class="imsc ico_search">
#                  </i>
#                 </span>
#                 <span>
#                  @txt@
#                 </span>
#                </span>
#               </a>
#               <span class="etc">
#                <em class="date">
#                 @date@.
#                </em>
#                <!-- [AU] _del 클래스를 추가해주세요. -->
#                <a aria-pressed="false" class="bt_item _del" href="#" role="button">
#                 <i class="imsc ico_del">
#                  삭제
#                 </i>
#                </a>
#               </span>
#              </li>
#             </ul>
#             <!-- [D] 검색어 저장 꺼진 경우 atcmp_fixer에 type_off 추가 -->
#             <!-- [AU] _offMsg 클래스를 추가해주세요. -->
#             <div class="kwd_info kwd_off _offMsg" style="display: none;">
#              검색어 저장 기능이 꺼져 있습니다.
#              <br/>
#              <span class="kwd_dsc">
#               설정이 초기화 된다면
#               <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/support/alias/search/word/word_29.naver" target="_blank">
#                도움말
#               </a>
#               을 확인해주세요.
#              </span>
#             </div>
#             <!-- [D] 검색어 내역 없는 경우 atcmp_fixer에 type_off 추가 -->
#             <!-- [AU] _recentNone 클래스를 추가해주세요. -->
#             <div class="kwd_info kwd_none _recentNone" style="display: none;">
#              최근 검색어 내역이 없습니다.
#              <br/>
#              <span class="kwd_dsc">
#               설정이 초기화 된다면
#               <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/support/alias/search/word/word_29.naver" target="_blank">
#                도움말
#               </a>
#               을 확인해주세요.
#              </span>
#             </div>
#            </div>
#            <div class="atcmp_footer">
#             <span class="side_opt_area">
#              <span class="opt_item">
#               <a data-clk="sly.help" href="https://help.naver.com/support/service/main.help?serviceNo=605&amp;categoryNo=1991" target="_blank">
#                도움말
#               </a>
#              </span>
#             </span>
#             <span class="rside_opt_area">
#              <span class="opt_item">
#               <!-- [AU] _keywordOnOff 클래스를 추가해주세요. -->
#               <a class="close _keywordOnOff" href="#">
#                자동저장 끄기
#               </a>
#              </span>
#             </span>
#            </div>
#           </div>
#           <!-- 자동완성 -->
#           <!-- [AU] _atcmp_layer 클래스를 추가해주세요. -->
#           <div class="atcmp_fixer _atcmp_layer" style="display:none;">
#            <!-- [AU] _words 클래스를 추가해주세요. -->
#            <div class="atcmp_container _words">
#             <!-- 정답형 템플릿 : 로또당첨번호 -->
#             <!-- [AU] _answer 클래스를 추가해주세요. -->
#             <!-- [AU] data-template-type="answer_3" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
#             <div class="atcmp_correct type_lotto _answer" data-code="@code@" data-keyword="@1@" data-template-type="answer_3">
#              <a class="link_item" href="#">
#               <span class="common_ico_kwd">
#                <i class="imsc ico_search">
#                </i>
#               </span>
#               <div class="dsc_area">
#                <span class="tit">
#                 @5@회 로또당첨번호
#                </span>
#                <span class="dsc">
#                 <span class="item">
#                  동행복권 제공
#                 </span>
#                </span>
#               </div>
#               <span class="etc_area">
#                <span class="etc lotto">
#                 <em class="n@6@">
#                  @6@
#                 </em>
#                 <em class="n@7@">
#                  @7@
#                 </em>
#                 <em class="n@8@">
#                  @8@
#                 </em>
#                 <em class="n@9@">
#                  @9@
#                 </em>
#                 <em class="n@10@">
#                  @10@
#                 </em>
#                 <em class="n@11@">
#                  @11@
#                 </em>
#                 <em class="imsc_bf bonus n@12@">
#                  @12@
#                 </em>
#                </span>
#               </span>
#              </a>
#             </div>
#             <!-- 정답형 템플릿 : 환율 -->
#             <!-- [AU] _answer 클래스를 추가해주세요. -->
#             <!-- [AU] data-template-type="answer_9" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
#             <div class="atcmp_correct type_exchange _answer" data-code="@code@" data-keyword="@1@" data-template-type="answer_9">
#              <!-- [D] 상승 up, 하락 down 추가 -->
#              <a class="link_item @11@" href="#">
#               <!-- [D] 국가별 class 가나다순
# ZAR 남아프리카 공화국
# NPR 네팔
# NOK 노르웨이
# NZD 뉴질랜드
# TWD 대만
# DKK 덴마크
# RUB 러시아
# MOP 마카오
# MYR 말레이시아
# MXN 멕시코
# MNT 몽골
# USD 미국
# BHD 바레인
# BDT 방글라데시
# VND 베트남
# BRL 브라질
# SAR 사우디아라비아
# SEK 스웨덴
# CHF 스위스
# SGD 싱가포르
# AED 아랍에미리트
# GBP 영국
# EUR 유럽연합
# ILS 이스라엘
# EGP 이집트
# INR 인도
# IDR 인도네시아
# JPY 일본
# CNY 중국
# CZK 체코
# CLP 칠레
# KZT 카자흐스탄
# QAR 카타르
# CAD 캐나다
# KWD 쿠웨이트
# THB 태국
# TRY 터키
# PKR 파키스탄
# PLN 폴란드
# PHP 필리핀
# HUF 헝가리
# AUD 호주
# HKD 홍콩
# -->
#               <span class="common_ico_kwd">
#                <i class="imsc ico @12@">
#                 @14@
#                </i>
#               </span>
#               <div class="dsc_area">
#                <span class="tit">
#                 @txt@
#                 <span class="sub">
#                  @currency@
#                 </span>
#                </span>
#                <span class="dsc">
#                 <span class="item">
#                  <i class="imsc ico_arr">
#                  </i>
#                  @8@(@9@%)
#                 </span>
#                </span>
#               </div>
#               <span class="etc_area">
#                <span class="etc">
#                 <em class="num">
#                  @6@
#                 </em>
#                 원
#                </span>
#               </span>
#              </a>
#             </div>
#             <!-- 정답형 템플릿 : 날씨(국내11, 해외12) -->
#             <!-- [AU] _answer 클래스를 추가해주세요. -->
#             <!-- [AU] data-template-type="answer_11" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
#             <div class="atcmp_correct type_weather _answer" data-code="@code@" data-keyword="@1@" data-template-type="answer_11">
#              <!-- [D] 상승 up, 하락 down 추가 -->
#              <a class="link_item @12@" href="#">
#               <span class="common_ico_kwd">
#                <i class="imsc ico_search">
#                </i>
#               </span>
#               <div class="dsc_area">
#                <span class="tit">
#                 @txt@
#                </span>
#                <span class="dsc">
#                 <span class="item">
#                  @7@, @message@
#                 </span>
#                </span>
#               </div>
#               <span class="etc_area">
#                <span class="etc">
#                 <!-- [D] 날씨별 class
# ico1 맑음(낮)
# ico2 맑음(밤)
# ico3 구름조금(낮)
# ico4 구름조금(밤)
# ico5 구름많음(낮)
# ico6 구름많음(밤)
# ico7 흐림
# ico8 약한비
# ico9 비
# ico10 강한비
# ico11 약한눈
# ico12 눈
# ico13 강한눈
# ico14 진눈깨비
# ico15 소나기
# ico16 안개
# ico17 소낙눈
# ico18 번개뇌우
# ico19 우박
# ico20 황사
# ico21 비또는눈
# ico22 가끔비
# ico23 가끔눈
# ico24 가끔비또는눈
# ico25 흐린후갬
# ico26 뇌우후갬
# ico27 비후갬
# ico28 눈후갬
# ico29 흐려져비
# ico30 흐려져눈
# -->
#                 <span class="ico_weather">
#                  <i class="imsc ico ico@iconNo@">
#                   @7@
#                  </i>
#                 </span>
#                 <em class="degree">
#                  @8@
#                  <sup class="celsius">
#                   °
#                  </sup>
#                 </em>
#                </span>
#               </span>
#              </a>
#             </div>
#             <!-- 정답형 템플릿 : 사이트 바로가기 -->
#             <!-- [AU] _answer 클래스를 추가해주세요. -->
#             <!-- [AU] data-template-type="answer_17" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
#             <div class="atcmp_correct type_site _answer" data-code="@code@" data-keyword="@1@" data-template-type="answer_17">
#              <a class="link_item" href="@5@" target="_blank">
#               <span class="common_ico_kwd">
#                <i class="imsc ico_url">
#                </i>
#               </span>
#               <div class="dsc_area">
#                <span class="tit">
#                 @txt@
#                </span>
#                <span class="dsc">
#                 <span class="item">
#                  @5@
#                 </span>
#                </span>
#               </div>
#               <span class="etc_area">
#                <span class="etc">
#                 바로가기
#                </span>
#               </span>
#              </a>
#             </div>
#             <!-- [AU] _kwd_list 클래스를 추가해주세요. -->
#             <ul class="kwd_lst _kwd_list">
#              <!-- [AU] 자동완성 검색어 템플릿 -->
#              <!-- [AU] _item 클래스를 추가해주세요. -->
#              <!-- [AU] data-rank="@rank@" data-template-type="suggestion" data-keyword="@in_txt@" attribute를 추가해주세요. -->
#              <li class="item _item" data-keyword="@in_txt@" data-rank="@rank@" data-template-type="suggestion">
#               <a class="kwd" href="#">
#                <span class="fix">
#                 <span class="common_ico_kwd">
#                  <i class="imsc ico_search">
#                  </i>
#                 </span>
#                 @txt@
#                </span>
#               </a>
#               <span class="etc">
#                <a aria-pressed="false" class="bt_item _add" href="#" role="button">
#                 <i class="imsc ico_insert">
#                  추가
#                 </i>
#                </a>
#               </span>
#              </li>
#              <!-- [AU] 최근검색어 템플릿 -->
#              <!-- [AU] _item 클래스를 추가해주세요. -->
#              <!-- [AU] data-rank="@rank@" data-template-type="history" data-keyword="@in_txt@" attribute를 추가해주세요. -->
#              <li class="item has_correct _item" data-keyword="@in_txt@" data-rank="@rank@" data-template-type="history">
#               <a class="kwd" href="#">
#                <span class="fix">
#                 <span class="common_ico_kwd">
#                  <i class="imsc ico_search">
#                  </i>
#                 </span>
#                 @txt@
#                </span>
#               </a>
#               <span class="etc">
#                <!-- 최근검색어 있으면 날짜 표시 -->
#                <em class="date">
#                 @date@.
#                </em>
#                <a aria-pressed="false" class="bt_item _add" href="#" role="button">
#                 <i class="imsc ico_insert">
#                  추가
#                 </i>
#                </a>
#               </span>
#              </li>
#             </ul>
#             <!-- [AU] 문맥검색 템플릿 -->
#             <!-- [AU] _item 클래스를 추가해주세요. -->
#             <!-- [AU] data-rank="@rank@" data-template-type="intend" data-keyword="@transQuery@" attribute를 추가해주세요. -->
#             <li class="item has_correct _item" data-intend-rank="@intendRank@" data-keyword="@transQuery@" data-rank="@rank@" data-template-type="intend">
#              <a class="kwd" href="#">
#               <span class="fix">
#                <span class="common_ico_kwd">
#                 <i class="imsc ico_search">
#                 </i>
#                </span>
#                @query@
#                <span class="context">
#                 @intend@
#                </span>
#               </span>
#              </a>
#              <span class="etc">
#               <a aria-pressed="false" class="bt_item _add" href="#" role="button">
#                <i class="imsc ico_insert">
#                 추가
#                </i>
#               </a>
#              </span>
#             </li>
#             <!-- [D] 선거안내문구 -->
#             <!-- [AU] _alert 클래스를 추가해주세요. -->
#             <div class="atcmp_alert _alert">
#              <div class="dsc_election">
#               <p class="dsc">
#                <i class="imsc ico_election">
#                </i>
#                <span class="_alert_passage">
#                </span>
#               </p>
#               <span class="dsc_inner">
#                <!-- [AU] _alert_passage2 클래스를 추가해주세요. -->
#                <span class="_alert_passage2">
#                </span>
#                <!-- [AU] _alert_link 클래스를 추가해주세요. -->
#                <a class="link _alert_link" href="#" target="_blank">
#                 자세히보기
#                </a>
#               </span>
#              </div>
#             </div>
#             <!-- [AU] _plus 클래스를 추가해주세요. -->
#             <div class="atcmp_plus _plus">
#              <div class="dsc_plus">
#               <a class="link_dsc" data-clk="sug.cxhelp" href="https://help.naver.com/support/alias/search/word/word_16.naver" target="_blank">
#                관심사를 반영한 컨텍스트 자동완성
#                <i class="imsc ico_help">
#                 도움말
#                </i>
#               </a>
#              </div>
#              <div class="switch">
#               <!-- [D] 선택시 aria-pressed="ture/false" -->
#               <!-- [AU] _plus_btn 클래스를 추가해주세요. -->
#               <a aria-pressed="false" class="bt_switch active _plus_btn" href="#" role="button">
#                <i class="imsc ico_option">
#                 컨텍스트 자동완성
#                </i>
#               </a>
#              </div>
#              <!-- [AU] _plus_layer 클래스를 추가해주세요. -->
#              <div class="layer_plus _plus_layer">
#               <strong class="tit">
#                컨텍스트 자동완성
#               </strong>
#               <!-- [AU] _plus_layer_isloggedin 클래스를 추가해주세요. -->
#               <!-- [AU] style="display:none" 추가해주세요. -->
#               <div class="_plus_layer_isloggedin" style="display:none">
#                <p class="dsc">
#                 ON/OFF 설정은
#                 <br/>
#                 해당기기(브라우저)에 저장됩니다.
#                </p>
#                <div class="btn_area">
#                 <a class="btn btn_view" data-clk="sug.cxlink" href="https://help.naver.com/support/alias/search/word/word_16.naver" target="_blank">
#                  자세히
#                 </a>
#                </div>
#               </div>
#               <!-- [AU] _plus_layer_isnotloggedin 클래스를 추가해주세요. -->
#               <!-- [AU] style="display:none" 추가해주세요. -->
#               <div class="_plus_layer_isnotloggedin" style="display:none">
#                <p class="dsc">
#                 <em class="txt">
#                  동일한 시간대/연령/남녀별
#                 </em>
#                 사용자 그룹의
#                 <br/>
#                 관심사에 맞춰 자동완성을 제공합니다.
#                </p>
#                <div class="btn_area">
#                 <a class="btn btn_login" data-clk="sug.cxlogin" href="https://nid.naver.com/nidlogin.login">
#                  로그인
#                 </a>
#                 <a class="btn btn_view" data-clk="sug.cxlink" href="https://help.naver.com/support/alias/search/word/word_16.naver" target="_blank">
#                  자세히
#                 </a>
#                </div>
#               </div>
#               <!-- [AU] _plus_layer_close 클래스를 추가해주세요. -->
#               <a class="btn_close _plus_layer_close" href="#" role="button">
#                <i class="imsc ico_close">
#                 컨텍스트 자동완성 레이어 닫기
#                </i>
#               </a>
#              </div>
#             </div>
#            </div>
#            <div class="atcmp_footer">
#             <span class="side_opt_area">
#              <span class="opt_item">
#               <a data-clk="sug.help" href="https://help.naver.com/alias/search/word/word_17.naver" target="_blank">
#                도움말
#               </a>
#              </span>
#              <span class="opt_item">
#               <a class="report" data-clk="sug.report" href="https://help.naver.com/support/contents/contents.help?serviceNo=605&amp;categoryNo=18215" target="_blank">
#                신고
#               </a>
#              </span>
#             </span>
#             <span class="rside_opt_area">
#              <span class="opt_item">
#               <!-- [AU] _suggestOnOff 클래스를 추가해주세요. -->
#               <a class="close _suggestOnOff" href="#">
#                자동완성 끄기
#               </a>
#              </span>
#             </span>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <!--EMPTY-->
#     <div id="gnb" role="navigation">
#      <div class="gnb_inner" id="NM_FAVORITE">
#       <div class="group_nav">
#        <ul class="list_nav type_fix">
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.mail" href="https://mail.naver.com/">
#           <i class="ico_mail">
#           </i>
#           메일
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.cafe" href="https://section.cafe.naver.com/">
#           카페
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.blog" href="https://section.blog.naver.com/">
#           블로그
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.kin" href="https://kin.naver.com/">
#           지식iN
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav shop" data-clk="svc.shopping" href="https://shopping.naver.com/">
#           <span class="blind">
#            쇼핑
#           </span>
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav shoplive" data-clk="svc.shoppinglive" href="https://shoppinglive.naver.com/home">
#           <span class="blind">
#            쇼핑LIVE
#           </span>
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.pay" href="https://order.pay.naver.com/home">
#           Pay
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.tvcast" href="https://tv.naver.com/">
#           <i class="ico_tv">
#           </i>
#           TV
#          </a>
#         </li>
#        </ul>
#        <ul class="list_nav NM_FAVORITE_LIST">
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.dic" href="https://dict.naver.com/">
#           사전
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.news" href="https://news.naver.com/">
#           뉴스
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.stock" href="https://finance.naver.com/">
#           증권
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.land" href="https://land.naver.com/">
#           부동산
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.map" href="https://map.naver.com/">
#           지도
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.vibe" href="https://vibe.naver.com/?from=naver_main&amp;utm_source=naver_main&amp;utm_medium=naver_main_pcweb&amp;utm_campaign=naver_main_redirect">
#           VIBE
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.book" href="https://search.shopping.naver.com/book/home">
#           도서
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.webtoon" href="https://comic.naver.com/">
#           웹툰
#          </a>
#         </li>
#        </ul>
#        <ul class="list_nav type_empty" style="display: none;">
#        </ul>
#        <a class="btn_more" data-clk="svc.more" href="#" role="button">
#         더보기
#        </a>
#        <div class="ly_btn_area">
#         <a class="btn NM_FAVORITE_ALL" data-clk="map.svcmore" href="more.html">
#          서비스 전체보기
#         </a>
#         <a class="btn btn_set" data-clk="map.edit" href="#" role="button">
#          메뉴설정
#         </a>
#         <a class="btn btn_reset" data-clk="edt.reset" href="#" role="button">
#          초기화
#         </a>
#         <a class="btn btn_save" data-clk="edt.save" href="#" role="button">
#          저장
#         </a>
#        </div>
#       </div>
#       <div class="group_weather" id="NM_WEATHER">
#        <div>
#         <a class="weather_area ico_w05" data-clk="squ.weat" href="https://weather.naver.com/today/09440127?cpName=KMA">
#          <div class="current_box">
#           <strong aria-label="현재기온" class="current">
#            15.3°
#           </strong>
#           <strong class="state">
#            구름많음
#           </strong>
#          </div>
#          <div class="degree_box">
#           <span aria-label="최저기온" class="min">
#            8.0°
#           </span>
#           <span aria-label="최고기온" class="max">
#            18.0°
#           </span>
#          </div>
#          <span class="location">
#           상암동
#          </span>
#         </a>
#        </div>
#        <div>
#         <a class="air_area" data-clk="squ.dust" href="https://weather.naver.com/today/09440127?cpName=KMA">
#          <ul class="list_air">
#           <li class="air_item">
#            미세
#            <strong class="state state_normal">
#             보통
#            </strong>
#           </li>
#           <li class="air_item">
#            초미세
#            <strong class="state state_good">
#             좋음
#            </strong>
#           </li>
#          </ul>
#          <span class="location">
#           상암동
#          </span>
#         </a>
#        </div>
#       </div>
#      </div>
#      <div class="ly_service">
#       <div class="group_service NM_FAVORITE_ALL_LY">
#       </div>
#       <div class="group_service NM_FAVORITE_EDIT_LY" style="display: none;">
#       </div>
#      </div>
#     </div>
#    </div>
#    <div id="container" role="main">
#     <div style="position:relative;width:1130px;margin:0 auto;z-index:11">
#      <div id="da_top">
#      </div>
#      <div id="da_expwide">
#      </div>
#     </div>
#     <div class="column_left" id="NM_INT_LEFT">
#      <div id="veta_top">
#       <div id="veta_top_inner" style="height:135px">
#       </div>
#       <span class="veta_bd_t">
#       </span>
#       <span class="veta_bd_b">
#       </span>
#       <span class="veta_bd_l">
#       </span>
#       <span class="veta_bd_r">
#       </span>
#      </div>
#      <div class="sc_newscast" id="newsstand">
#       <h2 class="blind">
#        뉴스스탠드
#       </h2>
#       <div class="group_issue" data-clk-prefix="ncy" id="NM_NEWSSTAND_HEADER">
#        <div class="issue_area">
#         <a class="link_media" data-clk="newsflash" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y">
#          연합뉴스
#         </a>
#         <div class="list_issue" data-nm-ui="rolling" id="NM_ONELINE_ROLLING">
#          <div>
#           <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013913044">
#            尹대통령, 5박7일 국빈 방미 마치고 귀국
#           </a>
#          </div>
#          <div>
#           <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013912693">
#            尹대통령, 방미 후속책 마련·홍보전 주력…간호법 대응도 고심
#           </a>
#          </div>
#          <div>
#           <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013913300">
#            대통령실, 박지원에 "반국가적 작태"…'아메리칸 파이'후문 일축
#           </a>
#          </div>
#          <div>
#           <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013913163">
#            '한계채무자 만나고 지옥철 타고'…현장 부쩍 자주 찾는 이재명
#           </a>
#          </div>
#          <div>
#           <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013913043">
#            간호조무사협회장, '간호법 반대' 단식 중 병원 이송
#           </a>
#          </div>
#          <div>
#           <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013912765">
#            생후 40일 아들 떨어뜨리고 방치해 사망…친모 "죄송하다"
#           </a>
#          </div>
#          <div>
#           <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013912547">
#            기시다, 내달 초순 방한 '가닥'…식민지배 사죄·반성 언급할까
#           </a>
#          </div>
#          <div>
#           <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013913215">
#            與, 내일 윤리위 첫 회의…김재원 '5·18 이전 징계' 무게
#           </a>
#          </div>
#          <div>
#           <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013913023">
#            故 서세원 빈소에 원로 코미디언들 추모…이철우 지사도 조문
#           </a>
#          </div>
#          <div>
#           <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013912419">
#            칼 빼든 검찰 "청소년에 마약 공급하면 최고 사형 구형"
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="direct_area">
#         <a class="link_news" data-clk="newshome" href="http://news.naver.com/">
#          뉴스홈
#         </a>
#         <a class="link_direct" data-clk="entertainment" href="http://entertain.naver.com/home">
#          연예
#         </a>
#         <a class="link_direct" data-clk="sports" href="http://sports.news.naver.com/">
#          스포츠
#         </a>
#         <a class="link_direct" data-clk="economy" href="http://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101">
#          경제
#         </a>
#        </div>
#       </div>
#       <div class="group_title" data-clk-prefix="nsd" id="NM_NEWSSTAND_TITLE">
#        <a class="link_newsstand" data-clk="title" href="http://newsstand.naver.com/" target="_blank">
#         뉴스스탠드
#        </a>
#        <div class="sort_area" id="NM_NEWSSTAND_data_buttons" role="tablist">
#         <a aria-controls="NM_NEWSSTAND_MY_LIST" aria-selected="false" class="btn_sort" data-clk="my" data-type="my" href="#" role="tab">
#          구독한 언론사
#         </a>
#         <a aria-controls="NM_NEWSSTAND_DEFAULT_THUMB" aria-selected="true" class="btn_sort" data-clk="all" data-type="all" href="#" role="tab">
#          전체언론사
#         </a>
#        </div>
#        <div class="set_area" id="NM_NEWSSTAND_view_buttons" role="tablist">
#         <a aria-controls="NM_NEWSSTAND_DEFAULT_LIST" aria-selected="false" class="btn_set" data-clk="articleview" data-type="list" href="#" role="tab">
#          <i class="ico_list">
#           <span class="blind">
#            리스트형
#           </span>
#          </i>
#         </a>
#         <a aria-controls="NM_NEWSSTAND_DEFAULT_THUMB" aria-selected="true" class="btn_set" data-clk="pressview" data-type="thumb" href="#" role="tab">
#          <i class="ico_tile">
#           <span class="blind">
#            썸네일형
#           </span>
#          </i>
#         </a>
#         <a class="btn_set" data-clk="set" href="http://newsstand.naver.com/config.html" target="_blank">
#          <i class="ico_set">
#           <span class="blind">
#            설정
#           </span>
#          </i>
#         </a>
#        </div>
#       </div>
#       <div id="NM_NEWSSTAND_VIEW_CONTAINER" style="position:relative">
#        <div class="group_news" data-clk-prefix="nsd_all" id="NM_NEWSSTAND_DEFAULT_LIST" role="tabpanel" style="display:none">
#         <a class="pm_btn_prev_l _NM_NEWSSTAND_LIST_prev_btn" data-clk-custom="prev" href="#" role="button">
#          <i class="ico_btn">
#           <span class="blind">
#            이전
#           </span>
#          </i>
#         </a>
#         <a class="pm_btn_next_l _NM_NEWSSTAND_LIST_next_btn" data-clk-custom="next" href="#" role="button">
#          <i class="ico_btn">
#           <span class="blind">
#            다음
#           </span>
#          </i>
#         </a>
#         <div class="list_view">
#          <div class="option_area">
#           <div class="list_option_wrap">
#            <ul class="list_option">
#             <li class="option_item" data-cateid="ct2">
#              <a class="option" data-clk="daei" href="#">
#               종합/경제
#              </a>
#             </li>
#             <li class="option_item" data-cateid="ct3">
#              <a class="option" data-clk="dtvcom" href="#">
#               방송/통신
#              </a>
#             </li>
#             <li class="option_item" data-cateid="ct4">
#              <a class="option" data-clk="dit" href="#">
#               IT
#              </a>
#             </li>
#             <li class="option_item" data-cateid="ct5">
#              <a class="option" data-clk="deng" href="#">
#               영자지
#              </a>
#             </li>
#             <li class="option_item" data-cateid="ct6">
#              <a class="option" data-clk="dsporent" href="#">
#               스포츠/연예
#              </a>
#             </li>
#             <li class="option_item" data-cateid="ct7">
#              <a class="option" data-clk="dmagtec" href="#">
#               매거진/전문지
#              </a>
#             </li>
#             <li class="option_item" data-cateid="ct8">
#              <a class="option" data-clk="dloc" href="#">
#               지역
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#          <div class="_NM_NEWSSTAND_ARTICLE_CONTAINER" data-clk-sub="*a">
#          </div>
#         </div>
#         <div class="ly_popup NM_NEWSSTAND_POPUP NM_NEWSSTAND_invalid" data-clk-sub="*a" style="display:none">
#          <a class="btn_close NM_NEWSSTAND_POPUP_CLOSE" href="#" role="button">
#           <i class="ico_close">
#           </i>
#           <span class="blind">
#            닫기
#           </span>
#          </a>
#          <p class="popup_msg">
#           해당 언론사 사정으로 접근이 제한됩니다.
#          </p>
#          <div class="popup_btn">
#           <a class="btn_confirm NM_NEWSSTAND_POPUP_CLOSE" href="#" role="button">
#            확인
#           </a>
#          </div>
#         </div>
#         <div class="ly_popup NM_NEWSSTAND_POPUP NM_NEWSSTAND_undescribe_confirm" data-clk-sub="*a" style="display:none">
#          <a class="btn_close NM_NEWSSTAND_POPUP_CLOSE" data-clk="usclose" href="#" role="button">
#           <i class="ico_close">
#           </i>
#           <span class="blind">
#            닫기
#           </span>
#          </a>
#          <p class="popup_msg">
#           <strong class="NM_NEWSSTAND_POPUP_PNAME">
#           </strong>
#           을(를)
#           <br/>
#           구독해지 하시겠습니까?
#          </p>
#          <div class="popup_btn">
#           <a class="btn_confirm NM_NEWSSTAND_POPUP_CONFIRM" data-clk="usdone" href="#" role="button">
#            확인
#           </a>
#           <a class="btn_confirm NM_NEWSSTAND_POPUP_CLOSE" data-clk="uscancel" href="#" role="button">
#            취소
#           </a>
#          </div>
#         </div>
#         <div class="ly_toast NM_NEWSSTAND_TOAST" style="display:none">
#          <p class="toast_msg">
#           구독한 언론사에 추가되었습니다.
#          </p>
#         </div>
#        </div>
#        <div class="group_news" data-clk-prefix="nsd_all" id="NM_NEWSSTAND_DEFAULT_THUMB" role="tabpanel" style="display:block">
#         <a class="pm_btn_prev_l _NM_UI_PAGE_PREV" data-clk-custom="prev" href="#" role="button">
#          <i class="ico_btn">
#           <span class="blind">
#            이전
#           </span>
#          </i>
#         </a>
#         <a class="pm_btn_next_l _NM_UI_PAGE_NEXT" data-clk-custom="next" href="#" role="button">
#          <i class="ico_btn">
#           <span class="blind">
#            다음
#           </span>
#          </i>
#         </a>
#         <div class="_NM_UI_PAGE_CONTAINER" data-clk-sub="*p" style="height:100%;overflow:hidden">
#          <div style="width: 750px; float: left;">
#           <div class="tile_view">
#            <div class="frame_area">
#             <i class="line to_right1">
#             </i>
#             <i class="line to_right2">
#             </i>
#             <i class="line to_right3">
#             </i>
#             <i class="line to_bottom1">
#             </i>
#             <i class="line to_bottom2">
#             </i>
#             <i class="line to_bottom3">
#             </i>
#             <i class="line to_bottom4">
#             </i>
#             <i class="line to_bottom5">
#             </i>
#            </div>
#            <div class="thumb_area">
# ...
#             <div class="media_thumb">
#              <img alt="" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Ftvcast.phinf%2F20230429_108%2Fr0F0b_1682772693912FKf3b_JPEG%2F20230429_214130_643_1.jpg%22&amp;type=nf464_260" height="130" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" width="232"/>
#              <span class="thumb_dim">
#              </span>
#              <span class="thumb_bd">
#              </span>
#              <i class="pm_ico_play">
#               <span class="blind">
#                재생
#               </span>
#              </i>
#              <span class="theme_runtime">
#               <span class="runtime_bg">
#                재생시간
#               </span>
#               <em class="time">
#                1:48
#               </em>
#              </span>
#             </div>
#             <div class="media_info">
#              <div class="info_box">
#               <em class="theme_category">
#                TV 드라마
#               </em>
#               <strong class="title">
#                명세빈과 실랑이하다, 환자(=살인범)를 놓치고 만 엄정화💥 | JTBC 230429 방송
#               </strong>
#               <div class="source_wrap">
#                <span class="date">
#                 18시간 전
#                </span>
#                <span class="source">
#                 <span class="source_inner">
#                  닥터 차정숙
#                 </span>
#                </span>
#               </div>
#              </div>
#             </div>
#            </a>
#            <a class="media_area" data-clk="tcc_tvc.list3cont7" data-da-position="true" data-gdid="PC-THEME-ENTER-RANKING-2[materials][6]" href="https://tv.naver.com/v/35452388" target="_blank">
#             <div class="media_thumb">
#              <img alt="" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Ftvcast.phinf%2F20230429_214%2Fdlz8N_1682772393419vziQt_JPEG%2F20230429_213644_098_1.jpg%22&amp;type=nf464_260" height="130" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" width="232"/>
#              <span class="thumb_dim">
#              </span>
#              <span class="thumb_bd">
#              </span>
#              <i class="pm_ico_play">
#               <span class="blind">
#                재생
#               </span>
#              </i>
#              <span class="theme_runtime">
#               <span class="runtime_bg">
#                재생시간
#               </span>
#               <em class="time">
#                1:37
#               </em>
#              </span>
#             </div>
#             <div class="media_info">
#              <div class="info_box">
#               <em class="theme_category">
#                TV 드라마
#               </em>
#               <strong class="title">
#                김병철-민우혁, 웃는 얼굴😃로 묘한 '신경전' 펼치는 중⚡ | JTBC 230429 방송
#               </strong>
#               <div class="source_wrap">
#                <span class="date">
#                 18시간 전
#                </span>
#                <span class="source">
#                 <span class="source_inner">
#                  닥터 차정숙
#                 </span>
#                </span>
#               </div>
#              </div>
#             </div>
#            </a>
#            <a class="media_area" data-clk="tcc_tvc.list3cont8" data-da-position="true" data-gdid="PC-THEME-ENTER-RANKING-2[materials][7]" href="https://tv.naver.com/v/35464392" target="_blank">
#             <div class="media_thumb">
#              <img alt="" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Ftvcast.phinf%2F20230430_151%2FxXmKo_1682835387067s5dFe_JPEG%2Fclip_20230430144228_0.jpg%22&amp;type=nf464_260" height="130" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" width="232"/>
#              <span class="thumb_dim">
#              </span>
#              <span class="thumb_bd">
#              </span>
#              <i class="pm_ico_play">
#               <span class="blind">
#                재생
#               </span>
#              </i>
#              <span class="theme_runtime">
#               <span class="runtime_bg">
#                재생시간
#               </span>
#               <em class="time">
#                17:54
#               </em>
#              </span>
#             </div>
#             <div class="media_info">
#              <div class="info_box">
#               <em class="theme_category">
#                TV 예능
#               </em>
#               <strong class="title">
#                [엠뚜루마뚜루] 나래 로망 실현 시켜주고 결국에는 울린 다정하고 로맨틱한 코쿤 the love💚 | #박나래 #코드쿤스트 #데이트 MBC230428방송
#               </strong>
#               <div class="source_wrap">
#                <span class="date">
#                 2시간 전
#                </span>
#                <span class="source">
#                 <span class="source_inner">
#                  나 혼자 산다
#                 </span>
#                </span>
#               </div>
#              </div>
#             </div>
#            </a>
#            <a class="media_area" data-clk="tcc_tvc.list3cont9" data-da-position="true" data-gdid="PC-THEME-ENTER-RANKING-2[materials][8]" href="https://tv.naver.com/v/35429451" target="_blank">
#             <div class="media_thumb">
#              <img alt="" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Ftvcast.phinf%2F20230428_201%2F1Kxgk_1682685690283MsRSr_JPEG%2F00000215149020230428190026453.jpg%22&amp;type=nf464_260" height="130" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" width="232"/>
#              <span class="thumb_dim">
#              </span>
#              <span class="thumb_bd">
#              </span>
#              <i class="pm_ico_play">
#               <span class="blind">
#                재생
#               </span>
#              </i>
#              <span class="theme_runtime">
#               <span class="runtime_bg">
#                재생시간
#               </span>
#               <em class="time">
#                0:50
#               </em>
#              </span>
#             </div>
#             <div class="media_info">
#              <div class="info_box">
#               <em class="theme_category">
#                TV 예능
#               </em>
#               <strong class="title">
#                [예고] 제대로 화난 오 박사♨ 유치원에 가지 못하는 영어 천재 6세 아들의 문제는 무엇일
#               </strong>
#               <div class="source_wrap">
#                <span class="date">
#                 어제
#                </span>
#                <span class="source">
#                 <span class="source_inner">
#                  요즘 육아 금쪽같은 내새끼
#                 </span>
#                </span>
#               </div>
#              </div>
#             </div>
#            </a>
#           </div>
#          </div>
#         </div>
#         <div class="btn_more_wrap">
#          <button class="btn_more" data-clk-custom="tcc_tvc.more" data-next-page="2" type="button">
#           <i class="ico_more">
#           </i>
#           새로운 글 더보기
#          </button>
#         </div>
#         <div class="NM_THEME_META" data-panel-code="ENTER" data-parent-code="" style="display: none">
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="column_right" id="NM_INT_RIGHT">
#      <div class="column_fix_wrap">
#       <div id="da_brand">
#       </div>
#       <div class="sc_login" id="account">
#        <h2 class="blind">
#         Sign in
#        </h2>
#        <p class="login_msg">
#         Connect with people
#        </p>
#        <a class="link_login" data-clk="log_off.login" href="https://nid.naver.com/nidlogin.login?mode=form&amp;url=https%3A%2F%2Fwww.naver.com">
#         <i class="ico_naver">
#          <span class="blind">
#           NAVER
#          </span>
#         </i>
#         Sign in
#        </a>
#        <div class="sub_area">
#         <div class="look_box">
#          <a class="link_look" data-clk="log_off.searchid" href="https://nid.naver.com/user/help.nhn?todo=idinquiry">
#           Forgot Username
#          </a>
#          <a class="link_look" data-clk="log_off.searchpass" href="https://nid.naver.com/nidreminder.form">
#           Password
#          </a>
#         </div>
#         <a class="link_join" data-clk="log_off.registration" href="https://nid.naver.com/nidregister.form?url=https%3A%2F%2Fwww.naver.com">
#          Sign up
#         </a>
#        </div>
#       </div>
#       <div class="sc_timesquare" id="timesquare">
#        <h2 class="blind">
#         타임스퀘어
#        </h2>
#        <div class="card_wrap">
#         <div class="card_nav">
#          <a class="btn_nav btn_prev" data-clk="squ.pre" href="#" role="button">
#           <span class="blind">
#            이전
#           </span>
#          </a>
#          <a class="btn_nav btn_next" data-clk="squ.next" href="#" role="button">
#           <span class="blind">
#            다음
#           </span>
#          </a>
#         </div>
#         <div id="NM_TS_ROLLING_WRAP" style="height: 100%;">
#          <div>
#           <a class="card_news" data-clk="squ.line3" href="https://search.naver.com/search.naver?sm=top_hty&amp;fbm=0&amp;ie=utf8&amp;query=%EC%BD%94%EB%A1%9C%EB%82%9819">
#            <i class="news_badge">
#             이슈
#            </i>
#            <span class="news">
#             코로나바이러스감염증-19 현황
#            </span>
#           </a>
#          </div>
#         </div>
#        </div>
#        <!-- EMPTY -->
#       </div>
#       <div id="veta_branding">
#        <span class="blind">
#         <script id="veta_service_check">
#         </script>
#        </span>
#        <div id="veta_branding_inner" style="width:350px;height:200px">
#        </div>
#        <span class="veta_bd_t">
#        </span>
#        <span class="veta_bd_b">
#        </span>
#        <span class="veta_bd_l">
#        </span>
#        <span class="veta_bd_r">
#        </span>
#       </div>
#       <div class="sc_shopcast" id="shopcast">
#        <iframe data-iframe-src="/shoppingbox/shoppingboxnew/main.nhn?mode=plusdeal&amp;domain=N" frameborder="0" height="1809" id="shopcast_iframe" marginheight="0" marginwidth="0" scrolling="no" title="쇼핑캐스트" width="350">
#        </iframe>
#       </div>
#      </div>
#     </div>
#     <a class="content_top" href="#wrap" id="NM_scroll_top_btn">
#      <span class="blind">
#       TOP
#      </span>
#     </a>
#     <button aria-pressed="false" class="btn_theme" id="NM_darkmode_btn" role="button" type="button">
#      <span class="blind">
#       라이트 모드로 보기
#      </span>
#     </button>
#    </div>
#    <div id="footer" role="contentinfo">
#     <div class="footer_inner">
#      <div class="banner_area" id="NM-FOOTER-AD">
#       <div class="da_box_wrap">
#        <div id="da_public_left">
#        </div>
#        <div id="da_public_right">
#        </div>
#        <div id="veta_time2">
#        </div>
#       </div>
#      </div>
#      <div class="notice_area" data-clk-prefix="ntc">
#       <div class="notice_box">
#        <h3 class="title">
#         <a href="https://www.naver.com/NOTICE">
#          공지사항
#         </a>
#        </h3>
#        <!-- EMPTY -->
#       </div>
#       <a class="link_all" data-clk="svcmap" href="more.html">
#        서비스 전체보기
#       </a>
#      </div>
#      <div class="aside_area">
#       <div class="partner_box_wrap">
#        <div class="partner_box" data-clk-prefix="crt">
#         <h3 class="title">
#          Creators
#         </h3>
#         <a class="link_partner" data-clk="creator" href="https://www.navercorp.com/service/creators">
#          크리에이터
#         </a>
#         <a class="link_partner" data-clk="smbusiness" href="https://www.navercorp.com/service/business">
#          스몰비즈니스
#         </a>
#        </div>
#        <div class="partner_box" data-clk-prefix="crt">
#         <h3 class="title">
#          Partners
#         </h3>
#         <a class="link_partner" data-clk="sme" href="https://campaign.naver.com/smefullcare/online/">
#          SME 풀케어 시스템
#         </a>
#         <a class="link_partner" data-clk="service" href="https://business.naver.com/service.html">
#          비즈니스 · 광고
#         </a>
#         <a class="link_partner" data-clk="store" href="https://sell.storefarm.naver.com/#/home/about">
#          스토어 개설
#         </a>
#         <a class="link_partner" data-clk="place" href="https://smartplace.naver.com">
#          지역업체 등록
#         </a>
#         <a class="link_partner" data-clk="expert" href="https://expert.naver.com/expert/introduction?tab=guide#join">
#          엑스퍼트 등록
#         </a>
#        </div>
#        <div class="partner_box" data-clk-prefix="crt">
#         <h3 class="title">
#          Developers
#         </h3>
#         <a class="link_partner" data-clk="center" href="https://developers.naver.com">
#          네이버 개발자 센터
#         </a>
#         <a class="link_partner" data-clk="openapi" href="https://developers.naver.com/docs/common/openapiguide/#/apilist.md">
#          오픈 API
#         </a>
#         <a class="link_partner" data-clk="opensource" href="https://naver.github.io">
#          오픈소스
#         </a>
#         <a class="link_partner" data-clk="d2" href="https://d2.naver.com">
#          네이버 D2
#         </a>
#         <a class="link_partner" data-clk="naverD2SF" href="http://d2startup.com">
#          네이버 D2SF
#         </a>
#         <a class="link_partner" data-clk="labs" href="https://www.naverlabs.com">
#          네이버 랩스
#         </a>
#        </div>
#       </div>
#       <div class="service_box_wrap">
#        <div class="service_box" data-clk-prefix="wbd">
#         <a class="service_logo" data-clk="bt" href="http://whale.naver.com/">
#          <img alt="웨일" height="48" src="data:image/png;base64,..." width="48"/>
#         </a>
#         <div class="service_info">
#          <strong class="title">
#           웨일 브라우저
#          </strong>
#          <a class="dsc" data-clk="bt" href="http://whale.naver.com/">
#           다운받기
#          </a>
#         </div>
#        </div>
#        <div class="service_box" data-clk-prefix="prj">
#         <a class="service_logo" data-clk="link" href="https://search.naver.com/search.naver?where=nexearch&amp;sm=top_hty&amp;fbm=1&amp;ie=utf8&amp;query=%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%EA%BD%83">
#          <img alt="꽃" height="50" src="data:image/png;base64,..." width="47"/>
#         </a>
#         <div class="service_info">
#          <strong class="title">
#           프로젝트 꽃
#          </strong>
#          <a class="dsc" data-clk="link" href="https://search.naver.com/search.naver?where=nexearch&amp;sm=top_hty&amp;fbm=1&amp;ie=utf8&amp;query=%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%EA%BD%83">
#           바로가기
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="corp_area" data-clk-prefix="plc">
#       <h3 class="blind">
#        네이버 정책 및 약관
#       </h3>
#       <ul class="list_corp">
#        <li class="corp_item">
#         <a data-clk="intronhn" href="https://www.navercorp.com">
#          회사소개
#         </a>
#        </li>
#        <li class="corp_item">
#         <a data-clk="recruit" href="https://recruit.navercorp.com/">
#          인재채용
#         </a>
#        </li>
#        <li class="corp_item">
#         <a data-clk="contact" href="https://www.navercorp.com/naver/proposalGuide">
#          제휴제안
#         </a>
#        </li>
#        <li class="corp_item">
#         <a data-clk="service" href="/policy/service.html">
#          이용약관
#         </a>
#        </li>
#        <li class="corp_item">
#         <a data-clk="privacy" href="/policy/privacy.html">
#          <strong>
#           개인정보처리방침
#          </strong>
#         </a>
#        </li>
#        <li class="corp_item">
#         <a data-clk="youth" href="/policy/youthpolicy.html">
#          청소년보호정책
#         </a>
#        </li>
#        <li class="corp_item">
#         <a data-clk="policy" href="https://policy.naver.com/policy/service_group.html">
#          네이버 정책
#         </a>
#        </li>
#        <li class="corp_item">
#         <a data-clk="helpcenter" href="https://help.naver.com/">
#          고객센터
#         </a>
#        </li>
#       </ul>
#       <address class="addr">
#        <a data-clk="nhn" href="https://www.navercorp.com" target="_blank">
#         ⓒ NAVER Corp.
#        </a>
#       </address>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div id="adscript" style="display:none">
#   </div>
#  </body>
# </html>

# %%
text = bs.find('div')
print(text)
# Out:
# <div id="u_skip"> <a href="#newsstand"><span>뉴스스탠드 바로가기</span></a> <a href="#themecast"><span>주제별캐스트 바로가기</span></a> <a href="#timesquare"><span>타임스퀘어 바로가기</span></a> <a href="#shopcast"><span>쇼핑캐스트 바로가기</span></a> <a href="#account"><span>로그인 바로가기</span></a> </div>

# %%
text = bs.find('span')
text.string
# Out:
# '뉴스스탠드 바로가기'

# %%
print(bs.find('div').string)
print(bs.find('div').find('span').string)
print(bs.find('div').get_text())
print(bs.find('div').text)
# Out:
# None
# 뉴스스탠드 바로가기
#  뉴스스탠드 바로가기 주제별캐스트 바로가기 타임스퀘어 바로가기 쇼핑캐스트 바로가기 로그인 바로가기
#  뉴스스탠드 바로가기 주제별캐스트 바로가기 타임스퀘어 바로가기 쇼핑캐스트 바로가기 로그인 바로가기

# %%
texts = bs.find_all('span')
texts
# Out:
# [<span>뉴스스탠드 바로가기</span>,
#  <span>주제별캐스트 바로가기</span>,
#  <span>타임스퀘어 바로가기</span>,
#  <span>쇼핑캐스트 바로가기</span>,
#  <span>로그인 바로가기</span>,
#  <span class="_1syGnXOL _3VkgqBXB" data-clk="dropbanner1a" style="padding-right: 20px; font-size: 17px; color: black"><span>매일 쓰는 브라우저 보안이 걱정된다면, </span><strong>안전하고 빠른 최신 브라우저 웨일로 업데이트 하세요.</strong></span>,
#  <span>매일 쓰는 브라우저 보안이 걱정된다면, </span>,
#  <span style="background-color: #0436c7">다운로드</span>,
#  <span class="blind">네이버</span>,
#  <span class="blind">쥬니어네이버</span>,
#  <span class="blind">해피빈</span>,
#  <span class="blind">검색</span>,
#  <span class="ico_search_submit"></span>,
#  <span class="blind">한글 입력기</span>,
#  <span class="ico_keyboard"></span>,
#  <span class="blind">자동완성 레이어</span>,
#  <span class="ico_arr"></span>,
#  <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span><span>@txt@</span></span>,
#  <span class="common_ico_kwd"><i class="imsc ico_search"></i></span>,
#  <span>@txt@</span>,
#  <span class="etc">
#  <em class="date">@date@.</em>
#  <!-- [AU] _del 클래스를 추가해주세요. -->
#  <a aria-pressed="false" class="bt_item _del" href="#" role="button"><i class="imsc ico_del">삭제</i></a>
#  </span>,
#  <span class="kwd_dsc">설정이 초기화 된다면 <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/support/alias/search/word/word_29.naver" target="_blank">도움말</a>을 확인해주세요.</span>,
#  <span class="kwd_dsc">설정이 초기화 된다면 <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/support/alias/search/word/word_29.naver" target="_blank">도움말</a>을 확인해주세요.</span>,
#  <span class="side_opt_area">
#  <span class="opt_item"><a data-clk="sly.help" href="https://help.naver.com/support/service/main.help?serviceNo=605&amp;categoryNo=1991" target="_blank">도움말</a></span>
#  </span>,
#  <span class="opt_item"><a data-clk="sly.help" href="https://help.naver.com/support/service/main.help?serviceNo=605&amp;categoryNo=1991" target="_blank">도움말</a></span>,
#  <span class="rside_opt_area">
#  <span class="opt_item">
#  <!-- [AU] _keywordOnOff 클래스를 추가해주세요. -->
#  <a class="close _keywordOnOff" href="#">자동저장 끄기</a>
#  </span>
#  </span>,
#  <span class="opt_item">
#  <!-- [AU] _keywordOnOff 클래스를 추가해주세요. -->
#  <a class="close _keywordOnOff" href="#">자동저장 끄기</a>
#  </span>,
#  <span class="common_ico_kwd"><i class="imsc ico_search"></i></span>,
#  <span class="tit">@5@회 로또당첨번호</span>,
#  <span class="dsc">
#  <span class="item">동행복권 제공</span>
#  </span>,
#  <span class="item">동행복권 제공</span>,
#  <span class="etc_area">
#  <span class="etc lotto">
#  <em class="n@6@">@6@</em><em class="n@7@">@7@</em><em class="n@8@">@8@</em><em class="n@9@">@9@</em><em class="n@10@">@10@</em><em class="n@11@">@11@</em><em class="imsc_bf bonus n@12@">@12@</em>
#  </span>
#  </span>,
#  <span class="etc lotto">
#  <em class="n@6@">@6@</em><em class="n@7@">@7@</em><em class="n@8@">@8@</em><em class="n@9@">@9@</em><em class="n@10@">@10@</em><em class="n@11@">@11@</em><em class="imsc_bf bonus n@12@">@12@</em>
#  </span>,
#  <span class="common_ico_kwd"><i class="imsc ico @12@">@14@</i></span>,
#  <span class="tit">@txt@<span class="sub">@currency@</span></span>,
#  <span class="sub">@currency@</span>,
#  <span class="dsc">
#  <span class="item"><i class="imsc ico_arr"></i>@8@(@9@%)</span>
#  </span>,
#  <span class="item"><i class="imsc ico_arr"></i>@8@(@9@%)</span>,
#  <span class="etc_area">
#  <span class="etc"><em class="num">@6@</em>원</span>
#  </span>,
#  <span class="etc"><em class="num">@6@</em>원</span>,
#  <span class="common_ico_kwd"><i class="imsc ico_search"></i></span>,
#  <span class="tit">@txt@</span>,
#  <span class="dsc">
#  <span class="item">@7@, @message@</span>
#  </span>,
#  <span class="item">@7@, @message@</span>,
#  <span class="etc_area">
#  <span class="etc">
#  <!-- [D] 날씨별 class
#  ico1 맑음(낮)
#  ico2 맑음(밤)
#  ico3 구름조금(낮)
#  ico4 구름조금(밤)
#  ico5 구름많음(낮)
#  ico6 구름많음(밤)
#  ico7 흐림
#  ico8 약한비
#  ico9 비
#  ico10 강한비
#  ico11 약한눈
#  ico12 눈
#  ico13 강한눈
#  ico14 진눈깨비
#  ico15 소나기
#  ico16 안개
#  ico17 소낙눈
#  ico18 번개뇌우
#  ico19 우박
#  ico20 황사
#  ico21 비또는눈
#  ico22 가끔비
#  ico23 가끔눈
#  ico24 가끔비또는눈
#  ico25 흐린후갬
#  ico26 뇌우후갬
#  ico27 비후갬
#  ico28 눈후갬
#  ico29 흐려져비
#  ico30 흐려져눈
#  -->
#  <span class="ico_weather"><i class="imsc ico ico@iconNo@">@7@</i></span>
#  <em class="degree">@8@<sup class="celsius">°</sup></em>
#  </span>
#  </span>,
#  <span class="etc">
#  <!-- [D] 날씨별 class
#  ico1 맑음(낮)
#  ico2 맑음(밤)
#  ico3 구름조금(낮)
#  ico4 구름조금(밤)
#  ico5 구름많음(낮)
#  ico6 구름많음(밤)
#  ico7 흐림
#  ico8 약한비
#  ico9 비
#  ico10 강한비
#  ico11 약한눈
#  ico12 눈
#  ico13 강한눈
#  ico14 진눈깨비
#  ico15 소나기
#  ico16 안개
#  ico17 소낙눈
#  ico18 번개뇌우
#  ico19 우박
#  ico20 황사
#  ico21 비또는눈
#  ico22 가끔비
#  ico23 가끔눈
#  ico24 가끔비또는눈
#  ico25 흐린후갬
#  ico26 뇌우후갬
#  ico27 비후갬
#  ico28 눈후갬
#  ico29 흐려져비
#  ico30 흐려져눈
#  -->
#  <span class="ico_weather"><i class="imsc ico ico@iconNo@">@7@</i></span>
#  <em class="degree">@8@<sup class="celsius">°</sup></em>
#  </span>,
#  <span class="ico_weather"><i class="imsc ico ico@iconNo@">@7@</i></span>,
#  <span class="common_ico_kwd"><i class="imsc ico_url"></i></span>,
#  <span class="tit">@txt@</span>,
#  <span class="dsc">
#  <span class="item">@5@</span>
#  </span>,
#  <span class="item">@5@</span>,
#  <span class="etc_area">
#  <span class="etc">바로가기</span>
#  </span>,
#  <span class="etc">바로가기</span>,
#  <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span>@txt@</span>,
#  <span class="common_ico_kwd"><i class="imsc ico_search"></i></span>,
#  <span class="etc">
#  <a aria-pressed="false" class="bt_item _add" href="#" role="button"><i class="imsc ico_insert">추가</i></a>
#  </span>,
#  <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span>@txt@</span>,
#  <span class="common_ico_kwd"><i class="imsc ico_search"></i></span>,
#  <span class="etc">
#  <!-- 최근검색어 있으면 날짜 표시 -->
#  <em class="date">@date@.</em>
#  <a aria-pressed="false" class="bt_item _add" href="#" role="button"><i class="imsc ico_insert">추가</i></a>
#  </span>,
#  <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span>@query@ <span class="context">@intend@</span></span>,
#  <span class="common_ico_kwd"><i class="imsc ico_search"></i></span>,
#  <span class="context">@intend@</span>,
#  <span class="etc">
#  <a aria-pressed="false" class="bt_item _add" href="#" role="button"><i class="imsc ico_insert">추가</i></a>
#  </span>,
#  <span class="_alert_passage"></span>,
#  <span class="dsc_inner">
#  <!-- [AU] _alert_passage2 클래스를 추가해주세요. -->
#  <span class="_alert_passage2"></span>
#  <!-- [AU] _alert_link 클래스를 추가해주세요. -->
#  <a class="link _alert_link" href="#" target="_blank">자세히보기</a>
#  </span>,
#  <span class="_alert_passage2"></span>,
#  <span class="side_opt_area">
#  <span class="opt_item"><a data-clk="sug.help" href="https://help.naver.com/alias/search/word/word_17.naver" target="_blank">도움말</a></span>
#  <span class="opt_item"><a class="report" data-clk="sug.report" href="https://help.naver.com/support/contents/contents.help?serviceNo=605&amp;categoryNo=18215" target="_blank">신고</a></span>
#  </span>,
#  <span class="opt_item"><a data-clk="sug.help" href="https://help.naver.com/alias/search/word/word_17.naver" target="_blank">도움말</a></span>,
#  <span class="opt_item"><a class="report" data-clk="sug.report" href="https://help.naver.com/support/contents/contents.help?serviceNo=605&amp;categoryNo=18215" target="_blank">신고</a></span>,
#  <span class="rside_opt_area">
#  <span class="opt_item">
#  <!-- [AU] _suggestOnOff 클래스를 추가해주세요. -->
#  <a class="close _suggestOnOff" href="#">자동완성 끄기</a>
#  </span>
#  </span>,
#  <span class="opt_item">
#  <!-- [AU] _suggestOnOff 클래스를 추가해주세요. -->
#  <a class="close _suggestOnOff" href="#">자동완성 끄기</a>
#  </span>,
#  <span class="blind">쇼핑</span>,
#  <span class="blind">쇼핑LIVE</span>,
#  <span aria-label="최저기온" class="min">8.0°</span>,
#  <span aria-label="최고기온" class="max">18.0°</span>,
#  <span class="location">상암동</span>,
#  <span class="location">상암동</span>,
#  <span class="veta_bd_t"></span>,
#  <span class="veta_bd_b"></span>,
#  <span class="veta_bd_l"></span>,
#  <span class="veta_bd_r"></span>,
#  <span class="blind">리스트형</span>,
#  <span class="blind">썸네일형</span>,
#  <span class="blind">설정</span>,
#  <span class="blind">이전</span>,
#  <span class="blind">다음</span>,
#  <span class="blind">닫기</span>,
#  <span class="blind">닫기</span>,
#  <span class="blind">이전</span>,
#  <span class="blind">다음</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="blind">닫기</span>,
#  <span class="blind">닫기</span>,
#  <span class="blind">이전</span>,
#  <span class="blind">다음</span>,
#  <span class="blind">다음</span>,
#  <span class="blind">닫기</span>,
#  <span class="blind">닫기</span>,
#  <span class="blind">이전</span>,
#  <span class="blind">다음</span>,
#  <span class="blind">닫기</span>,
#  <span class="blind">닫기</span>,
#  <span class="dsc">주제별로 분류된 다양한 글 모음</span>,
#  <span class="info"><strong class="new">641</strong> 개의 글</span>,
#  <span class="blind">이전</span>,
#  <span class="blind">다음</span>,
#  <span class="ico_middot"></span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">9:25</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">어제</span>,
#  <span class="source">
#  <span class="source_inner">제59회 백상예술대상</span>
#  </span>,
#  <span class="source_inner">제59회 백상예술대상</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">1:49</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">18시간 전</span>,
#  <span class="source">
#  <span class="source_inner">닥터 차정숙</span>
#  </span>,
#  <span class="source_inner">닥터 차정숙</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">2:37</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">17시간 전</span>,
#  <span class="source">
#  <span class="source_inner">닥터 차정숙</span>
#  </span>,
#  <span class="source_inner">닥터 차정숙</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">1:19</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">8시간 전</span>,
#  <span class="source">
#  <span class="source_inner">닥터 차정숙</span>
#  </span>,
#  <span class="source_inner">닥터 차정숙</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">3:52</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">1개월 전</span>,
#  <span class="source">
#  <span class="source_inner">불타는 트롯맨</span>
#  </span>,
#  <span class="source_inner">불타는 트롯맨</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">1:47</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">18시간 전</span>,
#  <span class="source">
#  <span class="source_inner">닥터 차정숙</span>
#  </span>,
#  <span class="source_inner">닥터 차정숙</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">3:58</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">어제</span>,
#  <span class="source">
#  <span class="source_inner">서진이네</span>
#  </span>,
#  <span class="source_inner">서진이네</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">0:57</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">어제</span>,
#  <span class="source">
#  <span class="source_inner">제59회 백상예술대상</span>
#  </span>,
#  <span class="source_inner">제59회 백상예술대상</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">4:08</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">8시간 전</span>,
#  <span class="source">
#  <span class="source_inner">뭉쳐야 찬다2</span>
#  </span>,
#  <span class="source_inner">뭉쳐야 찬다2</span>,
#  <span class="dsc">오전 2시 업데이트</span>,
#  <span class="blind">위</span>,
#  <span class="thumb_bd"></span>,
#  <span class="dsc">
#  <a data-clk="tcc_tvc.mranksinger1" href="https://vibe.naver.com/artist/2303512" target="_blank">임재현</a>
#  </span>,
#  <span class="dsc"><a data-clk="tcc_tvc.mrankalbum1" href="https://vibe.naver.com/album/9554582" target="_blank">시작은 첫키스 OST Part 1</a></span>,
#  <span class="blind">재생</span>,
#  <span class="blind">가사</span>,
#  <span class="blind">위</span>,
#  <span class="thumb_bd"></span>,
#  <span class="dsc">
#  <a data-clk="tcc_tvc.mranksinger2" href="https://vibe.naver.com/artist/143192" target="_blank">허각</a>
#  </span>,
#  <span class="dsc"><a data-clk="tcc_tvc.mrankalbum2" href="https://vibe.naver.com/album/9613552" target="_blank">물론</a></span>,
#  <span class="blind">재생</span>,
#  <span class="blind">가사</span>,
#  <span class="blind">위</span>,
#  <span class="thumb_bd"></span>,
#  <span class="dsc">
#  <a data-clk="tcc_tvc.mranksinger3" href="https://vibe.naver.com/artist/294000" target="_blank">박재정</a>
#  </span>,
#  <span class="dsc"><a data-clk="tcc_tvc.mrankalbum3" href="https://vibe.naver.com/album/9494325" target="_blank">1집 Alone</a></span>,
#  <span class="blind">재생</span>,
#  <span class="blind">가사</span>,
#  <span class="blind">위</span>,
#  <span class="blind">상승</span>,
#  <span class="thumb_bd"></span>,
#  <span class="dsc">
#  <a data-clk="tcc_tvc.mranksinger4" href="https://vibe.naver.com/artist/215754" target="_blank">손승연</a>
#  </span>,
#  <span class="dsc"><a data-clk="tcc_tvc.mrankalbum4" href="https://vibe.naver.com/album/9555354" target="_blank">꽃선비 열애사 OST Part 6</a></span>,
#  <span class="blind">재생</span>,
#  <span class="blind">가사</span>,
#  <span class="blind">위</span>,
#  <span class="blind">하락</span>,
#  <span class="thumb_bd"></span>,
#  <span class="dsc">
#  <a data-clk="tcc_tvc.mranksinger5" href="https://vibe.naver.com/artist/1749697" target="_blank">윤지영</a>
#  </span>,
#  <span class="dsc"><a data-clk="tcc_tvc.mrankalbum5" href="https://vibe.naver.com/album/9501627" target="_blank">나의 정원에서</a></span>,
#  <span class="blind">재생</span>,
#  <span class="blind">가사</span>,
#  <span class="blind">위</span>,
#  <span class="thumb_bd"></span>,
#  <span class="dsc">
#  <a data-clk="tcc_tvc.mranksinger6" href="https://vibe.naver.com/artist/36433" target="_blank">노리플라이(no reply)</a>
#  </span>,
#  <span class="dsc"><a data-clk="tcc_tvc.mrankalbum6" href="https://vibe.naver.com/album/9500098" target="_blank">랑데뷰 (Rendezvous)</a></span>,
#  <span class="blind">재생</span>,
#  <span class="blind">가사</span>,
#  <span class="blind">위</span>,
#  <span class="thumb_bd"></span>,
#  <span class="dsc">
#  <a data-clk="tcc_tvc.mranksinger7" href="https://vibe.naver.com/artist/362264" target="_blank">볼빨간사춘기</a>
#  </span>,
#  <span class="dsc"><a data-clk="tcc_tvc.mrankalbum7" href="https://vibe.naver.com/album/9486305" target="_blank">사랑.zip</a></span>,
#  <span class="blind">재생</span>,
#  <span class="blind">가사</span>,
#  <span class="blind">위</span>,
#  <span class="thumb_bd"></span>,
#  <span class="dsc">
#  <a data-clk="tcc_tvc.mranksinger8" href="https://vibe.naver.com/artist/226344" target="_blank">진수영</a>,
#
#                  <a data-clk="tcc_tvc.mranksinger8" href="https://vibe.naver.com/artist/335695" target="_blank">홍이삭</a>
#  </span>,
#  <span class="dsc"><a data-clk="tcc_tvc.mrankalbum8" href="https://vibe.naver.com/album/9582971" target="_blank">everland</a></span>,
#  <span class="blind">재생</span>,
#  <span class="blind">가사</span>,
#  <span class="blind">위</span>,
#  <span class="thumb_bd"></span>,
#  <span class="dsc">
#  <a data-clk="tcc_tvc.mranksinger9" href="https://vibe.naver.com/artist/294021" target="_blank">박시환</a>
#  </span>,
#  <span class="dsc"><a data-clk="tcc_tvc.mrankalbum9" href="https://vibe.naver.com/album/9499903" target="_blank">Fall in LOVE</a></span>,
#  <span class="blind">재생</span>,
#  <span class="blind">가사</span>,
#  <span class="blind">위</span>,
#  <span class="blind">상승</span>,
#  <span class="thumb_bd"></span>,
#  <span class="dsc">
#  <a data-clk="tcc_tvc.mranksinger10" href="https://vibe.naver.com/artist/101695" target="_blank">박재범</a>
#  </span>,
#  <span class="dsc"><a data-clk="tcc_tvc.mrankalbum10" href="https://vibe.naver.com/album/9506813" target="_blank">Sunday Night Drive</a></span>,
#  <span class="blind">재생</span>,
#  <span class="blind">가사</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">23:31</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">17시간 전</span>,
#  <span class="source">
#  <span class="source_inner">낭만닥터 김사부 3</span>
#  </span>,
#  <span class="source_inner">낭만닥터 김사부 3</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">2:59</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">어제</span>,
#  <span class="source">
#  <span class="source_inner">제59회 백상예술대상</span>
#  </span>,
#  <span class="source_inner">제59회 백상예술대상</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">2:14</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">18시간 전</span>,
#  <span class="source">
#  <span class="source_inner">닥터 차정숙</span>
#  </span>,
#  <span class="source_inner">닥터 차정숙</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">1:05</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">18시간 전</span>,
#  <span class="source">
#  <span class="source_inner">닥터 차정숙</span>
#  </span>,
#  <span class="source_inner">닥터 차정숙</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">19:27</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">6시간 전</span>,
#  <span class="source">
#  <span class="source_inner">낭만닥터 김사부 3</span>
#  </span>,
#  <span class="source_inner">낭만닥터 김사부 3</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">4:42</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">어제</span>,
#  <span class="source">
#  <span class="source_inner">요즘 육아 금쪽같은 내새끼</span>
#  </span>,
#  <span class="source_inner">요즘 육아 금쪽같은 내새끼</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">0:26</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">17시간 전</span>,
#  <span class="source">
#  <span class="source_inner">닥터 차정숙</span>
#  </span>,
#  <span class="source_inner">닥터 차정숙</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">1:05</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">5일 전</span>,
#  <span class="source">
#  <span class="source_inner">장사천재 백사장</span>
#  </span>,
#  <span class="source_inner">장사천재 백사장</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">15:32</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">6시간 전</span>,
#  <span class="source">
#  <span class="source_inner">전지적 참견 시점</span>
#  </span>,
#  <span class="source_inner">전지적 참견 시점</span>,
#  <span class="blind">이전</span>,
#  <span class="blind">다음</span>,
#  <span class="thumb_bd"></span>,
#  <span class="dsc">2023.04.26</span>,
#  <span class="thumb_bd"></span>,
#  <span class="dsc">2023.04.26</span>,
#  <span class="thumb_bd"></span>,
#  <span class="dsc">2023.04.25</span>,
#  <span class="thumb_bd"></span>,
#  <span class="dsc">2023.04.24</span>,
#  <span class="thumb_bd"></span>,
#  <span class="dsc">2023.04.18</span>,
#  <span class="thumb_bd"></span>,
#  <span class="dsc">2023.04.18</span>,
#  <span class="thumb_bd"></span>,
#  <span class="dsc">2023.04.17</span>,
#  <span class="thumb_bd"></span>,
#  <span class="dsc">2023.04.14</span>,
#  <span class="thumb_bd"></span>,
#  <span class="dsc">2023.04.11</span>,
#  <span class="thumb_bd"></span>,
#  <span class="dsc">2023.04.10</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">3:23</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">어제</span>,
#  <span class="source">
#  <span class="source_inner">요즘 육아 금쪽같은 내새끼</span>
#  </span>,
#  <span class="source_inner">요즘 육아 금쪽같은 내새끼</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">1:09</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">9시간 전</span>,
#  <span class="source">
#  <span class="source_inner">판도라: 조작된 낙원</span>
#  </span>,
#  <span class="source_inner">판도라: 조작된 낙원</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">6:59</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">어제</span>,
#  <span class="source">
#  <span class="source_inner">서진이네</span>
#  </span>,
#  <span class="source_inner">서진이네</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">3:01</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">어제</span>,
#  <span class="source">
#  <span class="source_inner">닥터 차정숙</span>
#  </span>,
#  <span class="source_inner">닥터 차정숙</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">4:14</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">어제</span>,
#  <span class="source">
#  <span class="source_inner">요즘 육아 금쪽같은 내새끼</span>
#  </span>,
#  <span class="source_inner">요즘 육아 금쪽같은 내새끼</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">1:48</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">18시간 전</span>,
#  <span class="source">
#  <span class="source_inner">닥터 차정숙</span>
#  </span>,
#  <span class="source_inner">닥터 차정숙</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">1:37</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">18시간 전</span>,
#  <span class="source">
#  <span class="source_inner">닥터 차정숙</span>
#  </span>,
#  <span class="source_inner">닥터 차정숙</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">17:54</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">2시간 전</span>,
#  <span class="source">
#  <span class="source_inner">나 혼자 산다</span>
#  </span>,
#  <span class="source_inner">나 혼자 산다</span>,
#  <span class="thumb_dim"></span>,
#  <span class="thumb_bd"></span>,
#  <span class="blind">재생</span>,
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">0:50</em></span>,
#  <span class="runtime_bg">재생시간</span>,
#  <span class="date">어제</span>,
#  <span class="source">
#  <span class="source_inner">요즘 육아 금쪽같은 내새끼</span>
#  </span>,
#  <span class="source_inner">요즘 육아 금쪽같은 내새끼</span>,
#  <span class="blind">NAVER</span>,
#  <span class="blind">이전</span>,
#  <span class="blind">다음</span>,
#  <span class="news">코로나바이러스감염증-19 현황</span>,
#  <span class="blind"> <script id="veta_service_check"></script> </span>,
#  <span class="veta_bd_t"></span>,
#  <span class="veta_bd_b"></span>,
#  <span class="veta_bd_l"></span>,
#  <span class="veta_bd_r"></span>,
#  <span class="blind">TOP</span>,
#  <span class="blind">라이트 모드로 보기</span>]

# %%
# texts = str(texts)
texts = bs.find_all('span')
lt = ''
for t in texts:
    t = t.get_text()
    lt += t
print(lt)
# Out:
# 뉴스스탠드 바로가기주제별캐스트 바로가기타임스퀘어 바로가기쇼핑캐스트 바로가기로그인 바로가기매일 쓰는 브라우저 보안이 걱정된다면, 안전하고 빠른 최신 브라우저 웨일로 업데이트 하세요.매일 쓰는 브라우저 보안이 걱정된다면, 다운로드네이버쥬니어네이버해피빈검색한글 입력기자동완성 레이어@txt@@txt@
# @date@.
#
# 삭제
# 설정이 초기화 된다면 도움말을 확인해주세요.설정이 초기화 된다면 도움말을 확인해주세요.
# 도움말
# 도움말
#
#
# 자동저장 끄기
#
#
#
# 자동저장 끄기
# @5@회 로또당첨번호
# 동행복권 제공
# 동행복권 제공
#
# @6@@7@@8@@9@@10@@11@@12@
#
#
# @6@@7@@8@@9@@10@@11@@12@
# @14@@txt@@currency@@currency@
# @8@(@9@%)
# @8@(@9@%)
# @6@원
# @6@원@txt@
# @7@, @message@
# @7@, @message@
#
#
# @7@
# @8@°
#
#
#
# @7@
# @8@°
# @7@@txt@
# @5@
# @5@
# 바로가기
# 바로가기@txt@
# 추가
# @txt@
#
# @date@.
# 추가
# @query@ @intend@@intend@
# 추가
#
#
#
#
# 자세히보기
#
# 도움말
# 신고
# 도움말신고
#
#
# 자동완성 끄기
#
#
#
# 자동완성 끄기
# 쇼핑쇼핑LIVE8.0°18.0°상암동상암동리스트형썸네일형설정이전다음닫기닫기이전다음닫기닫기이전다음다음닫기닫기이전다음닫기닫기주제별로 분류된 다양한 글 모음641 개의 글이전다음재생재생시간9:25재생시간어제
# 제59회 백상예술대상
# 제59회 백상예술대상재생재생시간1:49재생시간18시간 전
# 닥터 차정숙
# 닥터 차정숙재생재생시간2:37재생시간17시간 전
# 닥터 차정숙
# 닥터 차정숙재생재생시간1:19재생시간8시간 전
# 닥터 차정숙
# 닥터 차정숙재생재생시간3:52재생시간1개월 전
# 불타는 트롯맨
# 불타는 트롯맨재생재생시간1:47재생시간18시간 전
# 닥터 차정숙
# 닥터 차정숙재생재생시간3:58재생시간어제
# 서진이네
# 서진이네재생재생시간0:57재생시간어제
# 제59회 백상예술대상
# 제59회 백상예술대상재생재생시간4:08재생시간8시간 전
# 뭉쳐야 찬다2
# 뭉쳐야 찬다2오전 2시 업데이트위
# 임재현
# 시작은 첫키스 OST Part 1재생가사위
# 허각
# 물론재생가사위
# 박재정
# 1집 Alone재생가사위상승
# 손승연
# 꽃선비 열애사 OST Part 6재생가사위하락
# 윤지영
# 나의 정원에서재생가사위
# 노리플라이(no reply)
# 랑데뷰 (Rendezvous)재생가사위
# 볼빨간사춘기
# 사랑.zip재생가사위
# 진수영,
#
#                 홍이삭
# everland재생가사위
# 박시환
# Fall in LOVE재생가사위상승
# 박재범
# Sunday Night Drive재생가사재생재생시간23:31재생시간17시간 전
# 낭만닥터 김사부 3
# 낭만닥터 김사부 3재생재생시간2:59재생시간어제
# 제59회 백상예술대상
# 제59회 백상예술대상재생재생시간2:14재생시간18시간 전
# 닥터 차정숙
# 닥터 차정숙재생재생시간1:05재생시간18시간 전
# 닥터 차정숙
# 닥터 차정숙재생재생시간19:27재생시간6시간 전
# 낭만닥터 김사부 3
# 낭만닥터 김사부 3재생재생시간4:42재생시간어제
# 요즘 육아 금쪽같은 내새끼
# 요즘 육아 금쪽같은 내새끼재생재생시간0:26재생시간17시간 전
# 닥터 차정숙
# 닥터 차정숙재생재생시간1:05재생시간5일 전
# 장사천재 백사장
# 장사천재 백사장재생재생시간15:32재생시간6시간 전
# 전지적 참견 시점
# 전지적 참견 시점이전다음2023.04.262023.04.262023.04.252023.04.242023.04.182023.04.182023.04.172023.04.142023.04.112023.04.10재생재생시간3:23재생시간어제
# 요즘 육아 금쪽같은 내새끼
# 요즘 육아 금쪽같은 내새끼재생재생시간1:09재생시간9시간 전
# 판도라: 조작된 낙원
# 판도라: 조작된 낙원재생재생시간6:59재생시간어제
# 서진이네
# 서진이네재생재생시간3:01재생시간어제
# 닥터 차정숙
# 닥터 차정숙재생재생시간4:14재생시간어제
# 요즘 육아 금쪽같은 내새끼
# 요즘 육아 금쪽같은 내새끼재생재생시간1:48재생시간18시간 전
# 닥터 차정숙
# 닥터 차정숙재생재생시간1:37재생시간18시간 전
# 닥터 차정숙
# 닥터 차정숙재생재생시간17:54재생시간2시간 전
# 나 혼자 산다
# 나 혼자 산다재생재생시간0:50재생시간어제
# 요즘 육아 금쪽같은 내새끼
# 요즘 육아 금쪽같은 내새끼NAVER이전다음코로나바이러스감염증-19 현황  TOP라이트 모드로 보기

# %%
lt = str(lt)
lt = re.findall('[가-힣]+',lt)
lt = ' '.join(lt)
lt
# Out:
# '뉴스스탠드 바로가기주제별캐스트 바로가기타임스퀘어 바로가기쇼핑캐스트 바로가기로그인 바로가기매일 쓰는 브라우저 보안이 걱정된다면 안전하고 빠른 최신 브라우저 웨일로 업데이트 하세요 매일 쓰는 브라우저 보안이 걱정된다면 다운로드네이버쥬니어네이버해피빈검색한글 입력기자동완성 레이어 삭제 설정이 초기화 된다면 도움말을 확인해주세요 설정이 초기화 된다면 도움말을 확인해주세요 도움말 도움말 자동저장 끄기 자동저장 끄기 회 로또당첨번호 동행복권 제공 동행복권 제공 원 원 바로가기 바로가기 추가 추가 추가 자세히보기 도움말 신고 도움말신고 자동완성 끄기 자동완성 끄기 쇼핑쇼핑 상암동상암동리스트형썸네일형설정이전다음닫기닫기이전다음닫기닫기이전다음다음닫기닫기이전다음닫기닫기주제별로 분류된 다양한 글 모음 개의 글이전다음재생재생시간 재생시간어제 제 회 백상예술대상 제 회 백상예술대상재생재생시간 재생시간 시간 전 닥터 차정숙 닥터 차정숙재생재생시간 재생시간 시간 전 닥터 차정숙 닥터 차정숙재생재생시간 재생시간 시간 전 닥터 차정숙 닥터 차정숙재생재생시간 재생시간 개월 전 불타는 트롯맨 불타는 트롯맨재생재생시간 재생시간 시간 전 닥터 차정숙 닥터 차정숙재생재생시간 재생시간어제 서진이네 서진이네재생재생시간 재생시간어제 제 회 백상예술대상 제 회 백상예술대상재생재생시간 재생시간 시간 전 뭉쳐야 찬다 뭉쳐야 찬다 오전 시 업데이트위 임재현 시작은 첫키스 재생가사위 허각 물론재생가사위 박재정 집 재생가사위상승 손승연 꽃선비 열애사 재생가사위하락 윤지영 나의 정원에서재생가사위 노리플라이 랑데뷰 재생가사위 볼빨간사춘기 사랑 재생가사위 진수영 홍이삭 재생가사위 박시환 재생가사위상승 박재범 재생가사재생재생시간 재생시간 시간 전 낭만닥터 김사부 낭만닥터 김사부 재생재생시간 재생시간어제 제 회 백상예술대상 제 회 백상예술대상재생재생시간 재생시간 시간 전 닥터 차정숙 닥터 차정숙재생재생시간 재생시간 시간 전 닥터 차정숙 닥터 차정숙재생재생시간 재생시간 시간 전 낭만닥터 김사부 낭만닥터 김사부 재생재생시간 재생시간어제 요즘 육아 금쪽같은 내새끼 요즘 육아 금쪽같은 내새끼재생재생시간 재생시간 시간 전 닥터 차정숙 닥터 차정숙재생재생시간 재생시간 일 전 장사천재 백사장 장사천재 백사장재생재생시간 재생시간 시간 전 전지적 참견 시점 전지적 참견 시점이전다음 재생재생시간 재생시간어제 요즘 육아 금쪽같은 내새끼 요즘 육아 금쪽같은 내새끼재생재생시간 재생시간 시간 전 판도라 조작된 낙원 판도라 조작된 낙원재생재생시간 재생시간어제 서진이네 서진이네재생재생시간 재생시간어제 닥터 차정숙 닥터 차정숙재생재생시간 재생시간어제 요즘 육아 금쪽같은 내새끼 요즘 육아 금쪽같은 내새끼재생재생시간 재생시간 시간 전 닥터 차정숙 닥터 차정숙재생재생시간 재생시간 시간 전 닥터 차정숙 닥터 차정숙재생재생시간 재생시간 시간 전 나 혼자 산다 나 혼자 산다재생재생시간 재생시간어제 요즘 육아 금쪽같은 내새끼 요즘 육아 금쪽같은 내새끼 이전다음코로나바이러스감염증 현황 라이트 모드로 보기'

# %% [markdown]
# #### Q. "http://www.naver.com" 사이트에서 span 태그에 연결된 문자 + 숫자를 불필요한 공백을 제거한 후 출력하세요.

# %%
import urllib.request as rq
import re
url = "http://www.naver.com"
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'lxml')
texts = bs.find_all('span')
for t in texts:
    print(t.text)
# Out:
# 뉴스스탠드 바로가기
# 주제별캐스트 바로가기
# 타임스퀘어 바로가기
# 쇼핑캐스트 바로가기
# 로그인 바로가기
# 매일 쓰는 브라우저 보안이 걱정된다면, 안전하고 빠른 최신 브라우저 웨일로 업데이트 하세요.
# 매일 쓰는 브라우저 보안이 걱정된다면,
# 다운로드
# 네이버
# 쥬니어네이버
# 해피빈
# 검색
#
# 한글 입력기
#
# 자동완성 레이어
#
# @txt@
#
# @txt@
#
# @date@.
#
# 삭제
#
# 설정이 초기화 된다면 도움말을 확인해주세요.
# 설정이 초기화 된다면 도움말을 확인해주세요.
#
# 도움말
#
# 도움말
#
#
#
# 자동저장 끄기
#
#
#
#
# 자동저장 끄기
#
#
# @5@회 로또당첨번호
#
# 동행복권 제공
#
# 동행복권 제공
#
#
# @6@@7@@8@@9@@10@@11@@12@
#
#
#
# @6@@7@@8@@9@@10@@11@@12@
#
# @14@
# @txt@@currency@
# @currency@
#
# @8@(@9@%)
#
# @8@(@9@%)
#
# @6@원
#
# @6@원
#
# @txt@
#
# @7@, @message@
#
# @7@, @message@
#
#
#
# @7@
# @8@°
#
#
#
#
# @7@
# @8@°
#
# @7@
#
# @txt@
#
# @5@
#
# @5@
#
# 바로가기
#
# 바로가기
# @txt@
#
#
# 추가
#
# @txt@
#
#
#
# @date@.
# 추가
#
# @query@ @intend@
#
# @intend@
#
# 추가
#
#
#
#
#
#
# 자세히보기
#
#
#
# 도움말
# 신고
#
# 도움말
# 신고
#
#
#
# 자동완성 끄기
#
#
#
#
# 자동완성 끄기
#
# 쇼핑
# 쇼핑LIVE
# 8.0°
# 18.0°
# 상암동
# 상암동
#
#
#
#
# 리스트형
# 썸네일형
# 설정
# 이전
# 다음
# 닫기
# 닫기
# 이전
# 다음
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 닫기
# 닫기
# 이전
# 다음
# 다음
# 닫기
# 닫기
# 이전
# 다음
# 닫기
# 닫기
# 주제별로 분류된 다양한 글 모음
# 641 개의 글
# 이전
# 다음
#
#
# 4일 전
#
# 경제만랩
#
# 경제만랩
#
# 2일 전
#
# KT 에스테이트
#
# KT 에스테이트
#
# 5일 전
#
# 부동산R114
#
# 부동산R114
#
# 5일 전
#
# 비즈한국
#
# 비즈한국
#
# 어제
#
# 뉴스1
#
# 뉴스1
#
#
# 재생
# 재생시간
# 재생시간
# 1주일 전
#
#
# 머니투데이
#
#
# 머니투데이
#
#
# 재생
# 재생시간
# 재생시간
# 1주일 전
#
#
# 한국경제TV - 신속한 경제/증권 채널
#
#
# 한국경제TV - 신속한 경제/증권 채널
#
#
# 재생
# 재생시간
# 재생시간
# 1개월 전
#
#
# 머니투데이
#
#
# 머니투데이
#
# 23시간 전
#
# 한국경제
#
# 한국경제
#
# 6일 전
#
# 집코노미
#
# 집코노미
#
# 2일 전
#
# 아시아경제
#
# 아시아경제
#
# 2일 전
#
# RealCast
#
# RealCast
#
# 2일 전
#
# 데이트저스트
#
# 데이트저스트
#
#
# 재생
# 재생시간
# 재생시간
# 1주일 전
#
#
# 머니투데이
#
#
# 머니투데이
#
#
# 재생
# 재생시간
# 재생시간
# 3일 전
#
#
# 머니투데이
#
#
# 머니투데이
#
#
# 재생
# 재생시간
# 재생시간
# 4주일 전
#
#
# 후랭이TV
#
#
# 후랭이TV
#
# 2일 전
#
# 국민일보
#
# 국민일보
#
# 어제
#
# 월급쟁이부자들
#
# 월급쟁이부자들
#
# 2일 전
#
# 데이트저스트
#
# 데이트저스트
#
# 2일 전
#
# 뉴스웨이
#
# 뉴스웨이
#
# 2일 전
#
# 서울경제신문
#
# 서울경제신문
#
#
# 재생
# 재생시간
# 재생시간
# 2주일 전
#
#
#  한경 글로벌마켓
#
#
#  한경 글로벌마켓
#
#
# 재생
# 재생시간
# 재생시간
# 1개월 전
#
#
# 후랭이TV
#
#
# 후랭이TV
#
#
# 재생
# 재생시간
# 재생시간
# 3개월 전
#
#
# 주슨생tv
#
#
# 주슨생tv
#
# 2주일 전
#
# 전국투자자교육협의회
#
# 전국투자자교육협의회
#
# 2일 전
#
# 바삭한경제
#
# 바삭한경제
#
# 2일 전
#
# 조선비즈
#
# 조선비즈
#
# 2일 전
#
# 부자동
#
# 부자동
#
# 어제
#
# 부자비즈
#
# 부자비즈
#
#
# 재생
# 재생시간
# 재생시간
# 4주일 전
#
#
# 후랭이TV
#
#
# 후랭이TV
#
#
# 재생
# 재생시간
# 재생시간
# 1개월 전
#
#
# 후랭이TV
#
#
# 후랭이TV
#
#
# 재생
# 재생시간
# 재생시간
# 3일 전
#
#
# 서울경제 어썸머니
#
#
# 서울경제 어썸머니
#
# 2일 전
#
# 더스쿠프
#
# 더스쿠프
#
# 어제
#
# 한국경제
#
# 한국경제
#
# 6일 전
#
# 파이낸셜뉴스
#
# 파이낸셜뉴스
#
# 2일 전
#
# 뉴스1
#
# 뉴스1
#
# 2일 전
#
# 한국경제
#
# 한국경제
#
#
# 재생
# 재생시간
# 재생시간
# 1개월 전
#
#
# 후랭이TV
#
#
# 후랭이TV
#
#
# 재생
# 재생시간
# 재생시간
# 4주일 전
#
#
# 머니투데이
#
#
# 머니투데이
#
#
# 재생
# 재생시간
# 재생시간
# 4개월 전
#
#
# 머니투데이
#
#
# 머니투데이
#
# 2일 전
#
# 전성기
#
# 전성기
#
# 2일 전
#
# 월급쟁이 재테크 연구
#
# 월급쟁이 재테크 연구
#
# 2일 전
#
# 리얼투데이
#
# 리얼투데이
#
# 2일 전
#
# 대한경제
#
# 대한경제
#
# 2일 전
#
# RealCast
#
# RealCast
#
#
# 재생
# 재생시간
# 재생시간
# 5일 전
#
#
# 머니투데이
#
#
# 머니투데이
#
#
# 재생
# 재생시간
# 재생시간
# 3일 전
#
#
# 집코노미TV
#
#
# 집코노미TV
#
#
# 재생
# 재생시간
# 재생시간
# 5일 전
#
#
# 사이다경제
#
#
# 사이다경제
#
# 어제
#
# 사이다경제
#
# 사이다경제
#
# 2일 전
#
# e분양
#
# e분양
#
# 6일 전
#
# 브릿지경제
#
# 브릿지경제
#
# 6일 전
#
# 한국경제
#
# 한국경제
#
# 6일 전
#
# 블라블라
#
# 블라블라
#
#
# 재생
# 재생시간
# 재생시간
# 1주일 전
#
#
# 한국경제TV - 신속한 경제/증권 채널
#
#
# 한국경제TV - 신속한 경제/증권 채널
#
#
# 재생
# 재생시간
# 재생시간
# 1주일 전
#
#
# 전국투자자교육협의회
#
#
# 전국투자자교육협의회
#
#
# 재생
# 재생시간
# 재생시간
# 1주일 전
#
#
# 피셔인베스트
#
#
# 피셔인베스트
#
# 2일 전
#
# 리멤버
#
# 리멤버
#
# 3일 전
#
# 투벤저스
#
# 투벤저스
#
# 23시간 전
#
# 북극성주
#
# 북극성주
#
# 어제
#
# 메트로신문
#
# 메트로신문
#
# 6일 전
#
# 투벤저스
#
# 투벤저스
#
# 어제
#
# 뉴스핌
#
# 뉴스핌
#
# 6일 전
#
# 직방
#
# 직방
#
# 2일 전
#
# 한경BUSINESS
#
# 한경BUSINESS
#
# 2일 전
#
# 머니투데이
#
# 머니투데이
#
# 어제
#
# 아시아경제
#
# 아시아경제
#
# 2일 전
#
# KB부동산
#
# KB부동산
#
# 어제
#
# Master Your Space
#
# Master Your Space
#
# 3일 전
#
# 하나은행
#
# 하나은행
#
# 2일 전
#
# 트렌드DA
#
# 트렌드DA
#
# 5일 전
#
# 트렌드DA
#
# 트렌드DA
#
# 1주일 전
#
# RealCast
#
# RealCast
#
# 2일 전
#
# 토스
#
# 토스
#
# 어제
#
# 한국경제
#
# 한국경제
#
# 4일 전
#
# 조던
#
# 조던
#
# 5일 전
#
# 하나은행
#
# 하나은행
#
# 5일 전
#
# 파이낸셜뉴스
#
# 파이낸셜뉴스
#
# 6일 전
#
# 머니플러스
#
# 머니플러스
#
# 3일 전
#
# 중앙일보
#
# 중앙일보
#
# 2일 전
#
# 우리은행
#
# 우리은행
#
# 1주일 전
#
# 요기요사장님포털
#
# 요기요사장님포털
# NAVER
# 이전
# 다음
# 코로나바이러스감염증-19 현황
#
#
#
#
#
# TOP
# 라이트 모드로 보기

# %%
result = ''
for t in texts:
    t = t.text
    result += t

r = str(result)
r = re.findall('[가-힣]+',r)
print(' '.join(r))
# Out:
# 뉴스스탠드 바로가기주제별캐스트 바로가기타임스퀘어 바로가기쇼핑캐스트 바로가기로그인 바로가기매일 쓰는 브라우저 보안이 걱정된다면 안전하고 빠른 최신 브라우저 웨일로 업데이트 하세요 매일 쓰는 브라우저 보안이 걱정된다면 다운로드네이버쥬니어네이버해피빈검색한글 입력기자동완성 레이어 삭제 설정이 초기화 된다면 도움말을 확인해주세요 설정이 초기화 된다면 도움말을 확인해주세요 도움말 도움말 자동저장 끄기 자동저장 끄기 회 로또당첨번호 동행복권 제공 동행복권 제공 원 원 바로가기 바로가기 추가 추가 추가 자세히보기 도움말 신고 도움말신고 자동완성 끄기 자동완성 끄기 쇼핑쇼핑 상암동상암동리스트형썸네일형설정이전다음닫기닫기이전다음닫기닫기이전다음다음닫기닫기이전다음닫기닫기주제별로 분류된 다양한 글 모음 개의 글이전다음 일 전 경제만랩 경제만랩 일 전 에스테이트 에스테이트 일 전 부동산 부동산 일 전 비즈한국 비즈한국어제 뉴스 뉴스 재생재생시간재생시간 주일 전 머니투데이 머니투데이재생재생시간재생시간 주일 전 한국경제 신속한 경제 증권 채널 한국경제 신속한 경제 증권 채널재생재생시간재생시간 개월 전 머니투데이 머니투데이 시간 전 한국경제 한국경제 일 전 집코노미 집코노미 일 전 아시아경제 아시아경제 일 전 일 전 데이트저스트 데이트저스트재생재생시간재생시간 주일 전 머니투데이 머니투데이재생재생시간재생시간 일 전 머니투데이 머니투데이재생재생시간재생시간 주일 전 후랭이 후랭이 일 전 국민일보 국민일보어제 월급쟁이부자들 월급쟁이부자들 일 전 데이트저스트 데이트저스트 일 전 뉴스웨이 뉴스웨이 일 전 서울경제신문 서울경제신문재생재생시간재생시간 주일 전 한경 글로벌마켓 한경 글로벌마켓재생재생시간재생시간 개월 전 후랭이 후랭이 재생재생시간재생시간 개월 전 주슨생 주슨생 주일 전 전국투자자교육협의회 전국투자자교육협의회 일 전 바삭한경제 바삭한경제 일 전 조선비즈 조선비즈 일 전 부자동 부자동어제 부자비즈 부자비즈재생재생시간재생시간 주일 전 후랭이 후랭이 재생재생시간재생시간 개월 전 후랭이 후랭이 재생재생시간재생시간 일 전 서울경제 어썸머니 서울경제 어썸머니 일 전 더스쿠프 더스쿠프어제 한국경제 한국경제 일 전 파이낸셜뉴스 파이낸셜뉴스 일 전 뉴스 뉴스 일 전 한국경제 한국경제재생재생시간재생시간 개월 전 후랭이 후랭이 재생재생시간재생시간 주일 전 머니투데이 머니투데이재생재생시간재생시간 개월 전 머니투데이 머니투데이 일 전 전성기 전성기 일 전 월급쟁이 재테크 연구 월급쟁이 재테크 연구 일 전 리얼투데이 리얼투데이 일 전 대한경제 대한경제 일 전 재생재생시간재생시간 일 전 머니투데이 머니투데이재생재생시간재생시간 일 전 집코노미 집코노미 재생재생시간재생시간 일 전 사이다경제 사이다경제어제 사이다경제 사이다경제 일 전 분양 분양 일 전 브릿지경제 브릿지경제 일 전 한국경제 한국경제 일 전 블라블라 블라블라재생재생시간재생시간 주일 전 한국경제 신속한 경제 증권 채널 한국경제 신속한 경제 증권 채널재생재생시간재생시간 주일 전 전국투자자교육협의회 전국투자자교육협의회재생재생시간재생시간 주일 전 피셔인베스트 피셔인베스트 일 전 리멤버 리멤버 일 전 투벤저스 투벤저스 시간 전 북극성주 북극성주어제 메트로신문 메트로신문 일 전 투벤저스 투벤저스어제 뉴스핌 뉴스핌 일 전 직방 직방 일 전 한경 한경 일 전 머니투데이 머니투데이어제 아시아경제 아시아경제 일 전 부동산 부동산어제 일 전 하나은행 하나은행 일 전 트렌드 트렌드 일 전 트렌드 트렌드 주일 전 일 전 토스 토스어제 한국경제 한국경제 일 전 조던 조던 일 전 하나은행 하나은행 일 전 파이낸셜뉴스 파이낸셜뉴스 일 전 머니플러스 머니플러스 일 전 중앙일보 중앙일보 일 전 우리은행 우리은행 주일 전 요기요사장님포털 요기요사장님포털 이전다음코로나바이러스감염증 현황 라이트 모드로 보기

# %%
import urllib.request as rq
import re
url = "http://www.naver.com"
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'lxml')
texts = bs.find_all('span')

lt = ''
for t in texts:
    t = t.get_text()
    lt += t
# print(lt)

lt = str(lt)
lt = re.findall('[^\W]+',lt) # 문자 + 숫자와 매치
lt = ' '.join(lt)
lt
# Out:
# '뉴스스탠드 바로가기주제별캐스트 바로가기타임스퀘어 바로가기쇼핑캐스트 바로가기로그인 바로가기매일 쓰는 브라우저 보안이 걱정된다면 안전하고 빠른 최신 브라우저 웨일로 업데이트 하세요 매일 쓰는 브라우저 보안이 걱정된다면 다운로드네이버쥬니어네이버해피빈검색한글 입력기자동완성 레이어 txt txt date 삭제 설정이 초기화 된다면 도움말을 확인해주세요 설정이 초기화 된다면 도움말을 확인해주세요 도움말 도움말 자동저장 끄기 자동저장 끄기 5 회차 당첨번호 추첨 13 지급기한 1년 추첨 13 지급기한 1년 6 7 8 9 10 11 12 6 7 8 9 10 11 12 14 txt currency currency 8 9 8 9 6 원 6 원 txt 7 message 7 message 7 8 7 8 7 txt 5 5 바로가기 바로가기 txt 추가 txt date 추가 query intend intend 추가 자세히보기 도움말 신고 도움말신고 자동완성 끄기 자동완성 끄기 쇼핑쇼핑LIVE23 0 30 0 서초동서초동리스트형썸네일형설정이전다음닫기닫기이전다음닫기닫기이전다음다음닫기닫기이전다음닫기닫기주제별로 분류된 다양한 글 모음671 개의 글이전다음아백아백요일별 웹툰요일별 웹툰랑데뷰랑데뷰투신전생기투신전생기위유지 박태준 만화회사 김정현 스튜디오 137화 참아내야만 했다위유지 자까 시즌2 84화 어서 와 우리 집은 처음이지위상승 박태준만화회사 김숭늉 광산 9화_감시위유지 청담 56화위하락 이혜 101화위유지 서패스 김진석 200화위유지 웹툰 작가 18 몽유병 bunny 작가위상승 생일기분 56화위하락 박태준 만화회사 38화 허 접 ㅋ위유지 티바 여슬기 88화위유지 로유진 1화 무료위하락 린더 50화 무료위하락 비가 25화 무료위유지 파추 115화 무료위상승 글망쟁이 1화 무료위유지 전혁 1화 무료위유지 왕위 1화 무료위유지 글라딘 1화 무료위유지 우각 1화 무료위유지 windfall 1화 무료위유지 MAKOTO RAIKU 1화 무료위하락 박태준 김정현 141화 무료위유지 EIICHIRO ODA 5화 무료위하락 청담 56화 무료위유지 Joji Morikawa 위상승 이석준 간짜장 오리보리 40화 무료위하락 성소작 LICO 38화 무료위하락 이상규 343화 무료위하락 혀노 136화 무료위하락 전극진 박진환 7화 무료위유지 플아다 팻녹 총 129회위유지 이흰 강수인 총 258회위상승 알파타르트 치런 총 251회위하락 빵양이 라바니즈 총 102회위유지 클레오빡도라 Hosyo 총 162회위유지 주황연 톷추 총 93회위유지 성하 진단 총 76회위유지 하윤미 정이나 총 33회위유지 이윤아 마끼 총 137회위유지 노승아 JYUN 총 67회일요웹툰유계진유계진매일 웹툰정석현 강지영정석현 강지영수요웹툰웹툰 작가웹툰 작가매일 웹툰pompom매일 웹툰파랑파랑매일 웹툰떡구이 이지떡구이 이지매일 웹툰전지구 커피콩전지구 커피콩매일 웹툰호야호야매일 웹툰조 베넷 앨 유잉조 베넷 앨 유잉이전다음1위위25화 무료2위위25화 무료3위위25화 무료4위위25화 무료5위위4화 무료6위위50화 무료7위위25화 무료8위위25화 무료9위위25화 무료10위위5화 무료이전다음1위위웹툰 작가2위위웹툰작가고등단편 zip 작가 작품3위위모죠모죠의 일지 작가 작품4위위고일고일 달비트청소년유해매체물5위위혜니 성혜림힙한남자 작가 작품6위위티아이 김두루미 한중월야나노마신 작가 작품7위위자까독립일기 작가 작품8위위홍치열불 로맨스 작가 작품9위위GRIMZO10위위우지금이전다음1위위7화 무료2위위3화 무료3위위4화 무료4위위59화 무료5위위21화 무료6위위7위위3화 무료8위위9위위20화 무료10위위20화 무료이전다음1위위이동건2주 연속 1위2위위모죠25주 연속 TOP103위위퀀퀀 파란드TOP10 진입 4위위조석28주 연속 TOP105위위자까24주 연속 TOP106위위전선욱 박태준2주 연속 TOP107위위남수9주 연속 TOP108위위반지TOP10 재진입9위위홍필 김칸비3주 연속 TOP1010위위오성대6주 연속 TOP10이전다음로맨스해이서로맨스재이니아로판노란매화현판돈주신로판오간세현판마음설현판반구십노인로맨스단오날로맨스이는봄무협관마새NAVER이전다음코로나바이러스감염증 19 현황 TOP라이트 모드로 보기'

# %% [markdown]
# #### Q. "http://www.naver.com" 사이트에서 a 태그에 id가 있는 경우에 대하여 연결된 문자 + 숫자를 아래와 같이 출력하세요.
# - 해당되는 조건에 맞게 모두 출력
# - 한글만 열방향으로 출력
# - 불필요한 공백을 제거한 후 한글만 한줄에 출력

# %%
# A.
import urllib.request as rq
import re
url = "http://www.naver.com"
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'html.parser')
texts = bs.find_all('a',id=True)
texts
# Out:
# [<a class="_2aeXMlrb BMgpjddw" data-clk="dropdownload1b" href="https://installer-whale.pstatic.net/downloads/banner/RydDy7/WhaleSetup.exe" id="NM_whale_download_btn"><span style="background-color: #0436c7">다운로드</span></a>,
#  <a class="link_set" data-clk="top.mkhome" href="https://help.naver.com/support/welcomePage/guide.help" id="NM_set_home_btn">네이버를 시작페이지로</a>,
#  <a class="btn_keyboard" href="#" id="ke_kbd_btn" onclick="return false;" role="button"><span class="blind">한글 입력기</span><span class="ico_keyboard"></span></a>,
#  <a aria-pressed="false" class="btn_arw _btn_arw fold" data-atcmp-element="" href="#" id="nautocomplete" role="button" tabindex="2"><span class="blind">자동완성 레이어</span><span class="ico_arr"></span></a>,
#  <a class="btn_set" data-clk="tca.like" href="#" id="NM_THEME_EDIT_SET" role="button">관심주제 설정</a>,
#  <a class="content_top" href="#wrap" id="NM_scroll_top_btn"><span class="blind">TOP</span></a>]

# %%
# A.
import urllib.request as rq
import re
url = "http://www.naver.com"
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'html.parser')
texts = bs.find_all('a',id=True)
for t in texts:
    t = t.get_text()
    print(t)
# Out:
# 다운로드
# 네이버를 시작페이지로
# 한글 입력기
# 자동완성 레이어
# 관심주제 설정
# TOP

# %%
# A.
url = "http://www.naver.com"
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'html.parser')
texts = bs.find_all('a',id=True)
texts = str(texts)
p = re.findall('[가-힣]+',texts)
# p = re.findall('[^\W]+',texts)
m = ' '.join(p)
m
# Out:
# '다운로드 네이버를 시작페이지로 한글 입력기 자동완성 레이어 관심주제 설정'

# %%
# A.
import urllib.request as rq
import re
url = "http://www.naver.com"
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'html.parser')
texts = bs.find_all('a',id=True)
lt = ''
for t in texts:
    t = t.get_text()
    lt += t
lt = str(lt)
lt = re.findall('[^\W]+', lt)
lt = ' '.join(lt)
print(lt)
# Out:
# 다운로드네이버를 시작페이지로한글 입력기자동완성 레이어관심주제 설정TOP

# %%
import urllib.request as rq
import re
url = "http://www.naver.com"
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'lxml')
text = bs.find('div').get_text()
text
# Out:
# ' 뉴스스탠드 바로가기 주제별캐스트 바로가기 타임스퀘어 바로가기 쇼핑캐스트 바로가기 로그인 바로가기 '

# %%
from bs4 import BeautifulSoup
import urllib.request as rq
url = 'https://news.naver.com/'
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'lxml')
print(bs.find_all('p'))
# Out:
# [<p class="cjs_d">(410) 김상현의 정교한 샷 한국프로골프(KPGA) 코리안투어가 개막하는 매년 4월, 주목받는 한 선수가 있습니다. 전년도 스릭슨투어 상금왕 김상현입니다. 2부 투어지만 지난해 정규투어에서 2번의 우승을 포함해 1</p>, <p class="cjs_d">넷플릭스 코리아 '성+인물' 신동엽, 성시경 진행 맡아 일본 AV 배우·호스트 인터뷰 국내 불법인 AV 성 산업 조명 여성 배우 성착취 문제 언급 없어 넷플릭스 코리아가 제작한 예능 '성+인물 : 일본편'이 공개된 </p>, <p class="cjs_d">이태원 참사 희생자 분향소 운영을 두고 서울시와 유족의 갈등이 3개월째 이어지고 있다. 앞서 서울시는 이태원 참사 유가족협의회(유가협)와 시민대책회의에 2023년 2월4일부터 4월6일까지 무단점유한 서울광장 72㎡에</p>, <p class="cjs_d">박지원 “尹, 한 소절 더 했으면 바이든과 듀엣” 대통령실 “바이든 노력 알기에 한 소절 부른 것” 대통령실은 30일 윤석열 대통령이 지난 26일(현지 시각) 백악관 국빈 만찬에서 ‘아메리칸 파이’를 부른 것과 관련</p>, <p class="cjs_d">정부가 우리 농업의 미래와 식량주권 확보를 위해 '가루쌀' 보급·육성에 사활을 걸고 있습니다. 농림축산식품부(장관 정황근)는 '2024년도 가루쌀 전문 재배단지 육성사업' 지원 대상자를 모집한다고 30일 밝혔습니다.</p>, <p class="cjs_d">“한국인이 없어서 못타는 ‘독일차’…가수 위너도 반했다” 중고차 거래 플랫폼 KB차차차가 지난 1년간 한국인이 가장 많이 찾는 독일 3사(벤츠·BMW·아우디) 중고차 모델을 분석한 결과 벤츠 E클래스가 1위를 기록한</p>, <p class="cjs_d">개봉을 앞둔 디즈니 영화 '인어공주'의 타이틀롤을 맡은 미국 배우 할리 베일리(23)가 동물 학대를 부추겼다는 논란에 휩싸였다. 29일(현지시간) 영국 매체 미러에 따르면, 베일리는 지난 19일 자신의 인스타그램을 </p>, <p class="cjs_d">간호법 제정안 저지를 위해 지난 25일부터 국회 앞 단식을 이어 온 곽지연 대한간호조무사협회장이 30일 건강 악화로 병원에 후송됐다. 지난 27일 간호법 및 의사면허 취소법이 더불어민주당 주도로 국회 본회의에서 강행</p>, <p class="cjs_d">윤석열 대통령은 역대 대통령들과 다른 별종의 지도자인 것 같다. 박정희 정권 이래 지난 60여년간 대한민국의 대통령은 보수, 진보를 막론하고 자신의 기질과 상관없이 대외정책에서 한반도 정세의 안정을 기하는 방향에서 </p>, <p class="cjs_d">야유회에서 술을 마시고 옥상에서 떨어져 수술 받다 숨진 군인을 보훈대상자로 인정하기 어렵다는 대법원의 판단이 나왔습니다. 대법원 1부는 지난 2003년 7월 간부 숙소 옥상에서 추락해 군 병원에서 수술을 받다 숨진 </p>, <p class="cjs_d">내일(1일)까지 이어지는 황금 연휴에 나들이 떠나 부담없이 여유를 즐기는 건 좋지만 이럴 때 일수록 음주운전은 금물이라는 거 알고 계시죠? 경찰이 오늘 대낮 음주 단속을 단행했는데, 그 현장을 이해선 기자가 동행 취</p>, <p class="cjs_d">남북이 가장 가깝게 총구를 맞대고 있는 곳, 최북단 철책에는 24시간 경계를 펴고 있는 최전방 사단이 있습니다. 과학화 경계시스템으로 보다 정밀한 임무를 수행하는 7사단 GOP 장병들의 모습을 임성재 기자가 보도합니</p>, <p class="cjs_d">"그건 안 돼요. 원점회귀해야 됩니다." "왜요?" "반려견은 케이지 없이 지하철 못 타요." "아." 우리의 대화는 대체로 이랬다. 쳇바퀴 돌 듯 어려움과 이해가 거듭됐다. 반려견을 동반해 움직인다는 것에 무지한 </p>, <p class="cjs_d">문재인 전 대통령의 퇴임 후 일상을 보여주는 다큐멘터리 영화 '문재인입니다'가 최근 전주국제영화제에서 공개됐다. 선공개 영상에 포함됐던] '5년간 성취가 정권 교체 후 무너졌다'는 취지의 문 전 대통령 발언은 이날 </p>, <p class="cjs_d">캔을 뚜껑째 열어 맥주잔처럼 마실 수 있는 일본 ‘아사히 수퍼드라이 생맥주’ 제품이 5월 국내에 한정 출시되는 가운데 며칠 앞서 코스트코에 입고된 상품을 사기 위한 ‘오픈런’ 경쟁이 치열한 것으로 나타났다. 일본에서</p>, <p class="cjs_d">물건을 먼저 구입하고 나중에 결제하는 '선구매 후불결제(BNPL)' 서비스의 연체율이 높아지면서 건전성에 대한 우려도 커지고 있다. 30일 국회 정무위원회 소속 최승재 국민의힘 의원이 금융감독원으로부터 받은 네이버파</p>, <p class="cjs_d">"주차장에서 차 빼라고 전화가 와서"라든지 "택시가 안 잡혀서 어쩔 수 없이"라는 말들, 경찰의 음주운전 단속에 적발된 운전자들의 흔한 변명입니다. 심지어 "내가 신분증 내밀면 알 만한 사람인데" 또는 "내가 너 죽</p>, <p class="cjs_d">윤석열 대통령이 30일 5박 7일 간의 미국 국빈 방문 일정을 모두 마무리하고 귀국했다. 윤 대통령은 지난 24일 출국 후 미국 워싱턴 D.C.에서 한미정상회담과 국빈 만찬, 미 상·하원 합동회의 연설, 미 국방부인</p>, <p class="cjs_d">30일 오후 4시 29분쯤 정선군 화암면 화암 약수제 행사장에서 텐트가 강풍에 의해 무너지는 사고가 발생했다. 이 사고로 텐트 주변에 있던 7명이 다쳐 병원으로 옮겨졌다. 이날 정선지역에는 강풍주의보가 내려진 상태다</p>, <p class="cjs_d">이재명 더불어민주당 대표는 30일 "저와 박광온 원내대표에게는 함께 힘을 합쳐 총선에서 반드시 승리해 우리 사회의 추락을 저지해야 할 역사적 소명이 주어져 있다"고 밝혔다. 이 대표는 이날 페이스북에 "박 대표님 손</p>, <p class="cjs_d">하이브 직원들이 글로벌 아티스트 방탄소년단(BTS)의 단체활동 중단 전 내부 정보를 활용해 주식을 매매한 혐의로 수사를 받고 있는 것으로 알려졌다. 30일 조선일보 보도 등에 따르면 수사당국은 하이브 직원 일부에 대</p>, <p class="cjs_d">'축구 황제' 펠레의 이름이 '뛰어난, 비교할 수 없는, 유일무이한' 사람을 의미하는 형용사로 브라질 사전에 영원히 남게 됐습니다. 현지 시간으로 지난 27일 CNN, BBC 등 외신들은 '펠레'가 포르투갈어 사전에</p>, <p class="cjs_d">코로나19 백신 개발로 급성장한 미국 제약사 모더나의 스테판 방셀 최고경영자(CEO)가 지난해 스톡옵션(주식매수청구권)으로 거액을 번 사실을 드러나 논란이 일고 있습니다. 미국 워싱턴포스트(WP)는 방셀 CEO가 지</p>, <p class="cjs_d">5박7일 일정 마무리…與, '워싱턴선언' 최대 성과 지목 12년 만의 국빈 방문에 '최초' 기록도 여럿 '빈손' IRA‧반도체법‧'핵 공유' 논란 등 찜찜한 뒷맛 윤석열 대통령과 김건희 여사는 </p>, <p class="cjs_d">윤석열 대통령이 미국 국빈 방문 일정을 마치고 30일 오후 귀국했다. 여야는 윤 대통령의 귀국에 맞춰 이번 국빈 방문을 두고 엇갈린 해석을 내놓았다. 여당은 ‘워싱턴 선언’ 등 지난 5박 7일간 윤 대통령의 국빈 방</p>, <p class="cjs_d"># 때만 되면 포털 뉴스란에 심심찮게 등장하는 단어가 있습니다. 수상택시입니다. 그 옆에는 늘 함께 붙어다니는 말이 있습니다. 서울시입니다. # 서울시는 2005년부터 서울의 교통혼잡을 완화하기 위한 대안으로 수상택</p>, <p class="cjs_d">윤석열 대통령이 30일 5박 7일 간의 미국 국빈 방문을 마치고 귀국했다. 윤 대통령과 부인 김건희 여사는 이날 오후 전용기인 공군 1호기 편으로 서울공항에 도착해 미리 나와 있던 환영객들과 인사했다. 윤 대통령은 </p>, <p class="cjs_d">29일 오후 7시 무렵 전북 전주시 전북대 삼성문화회관은 사람들로 붐볐다. 제24회 전주국제영화제에서 첫 공개되는 다큐멘터리영화 ‘문재인입니다’를 보려는 이들이 대부분이었다. 일부 관객은 로비에 설치된 대형 영화 포</p>, <p clas ...
#
#
#                                 오늘 언론사가 발행한<br/>종이신문에 실린 뉴스 1면<br/>기사가 제공됩니다.
#
#
#
#                     </p>, <p class="cjs_dept_desc">[클린룸]“취임 후 한국으로부터 1000억 달러 유치”...더욱 선명해진 바이든의 속내</p>, <p class="cjs_dept_desc">“그 ×은 여자친구 엄마 불러 그 앞에서 딸을 살해했다”…목숨 걸고 이별 통보?[전국부 사건창고]</p>, <p class="cjs_dept_desc">[법안 톺아보기] 제동 걸린 ‘北 도발 생존 장병 특별법’, 원인은 또 ‘형평성’ 논란</p>, <p class="cjs_dept_desc">5대 동맹 강화로 미래 70년 초석 다졌다</p>, <p class="cjs_dept_desc">[韓美 정상회담] 반도체·양자 협력 강화… 尹·바이든, 기술동맹 `의기투합`</p>, <p class="cjs_dept_desc">[韓美 정상회담] 尹, 국빈 만찬 건배사… "강철같은 동맹을 위하여!"</p>, <p class="cjs_dept_desc">[전문]尹대통령, 美의회서 30여분간 영어 연설…자유 46회 언급, 박수 60여 차례 받아</p>, <p class="cjs_dept_desc">경기도, 내년 ‘인구인지예산’ 편성…저출생·고령화 대응 나선다</p>, <p class="cjs_dept_desc">직장갑질119, "괴롭힘·야근·징계해고 '3대 갑질' 만연"</p>, <p class="cjs_dept_desc">산재보험도 ‘부익부빈익빈’… 소규모 업체 가입 외면 [경기도 근로자 재해실태 보고서_15]</p>, <p class="cjs_dept_desc">'간호법' 통과...의사, 간호조무사 "4일 부분 파업", 전망과 쟁점은?</p>, <p class="cjs_dept_desc">[법정B컷]"전세사기요? 전 심부름만"…'빌라왕' 재판 판사의 분노</p>, <p class="cjs_dept_desc">SSBN 부산에 기항…'비핵화 선언'과 모순 아니라고?[안보열전]</p>, <p class="cjs_dept_desc">[그래?픽!]"저도 선생님 XX까요" 교권 추락…학생인권 때문이라고?</p>, <p class="cjs_dept_desc">[딥뉴스]리버버스는 '골병라인'을 구할 수 있을까</p>, <p class="cjs_dept_desc">호텔에 ‘헬로 카봇’ 떴다? 아빠는 또 지갑을 열었다 [언박싱]</p>, <p class="cjs_dept_desc">[인터뷰] “신형 코나는 전기차가 원조”…악동+미래지향적 디자인 ‘매력’</p>, <p class="cjs_dept_desc">“핵 보장 첫걸음” “경제성과 아쉬워”…한미정상회담 엇갈린 평가[국빈방미 결산]</p>, <p class="cjs_dept_desc">"뉴스서 본 그 해열제·김, 우리 애도 먹였는데"…불량식품 급증 '이것' 때문? [채상우의 미담:味談]</p>, <p class="cjs_dept_desc">홍준표 "전광훈, 급기야 대통령실 물고들어가…미적거리지 말고 끊어라"</p>, <p class="cjs_dept_desc">"중국 혼밥, 김정은에 아부가 그립느냐"…홍준표, '尹 흠집 올인' 세력에 일갈</p>, <p class="cjs_dept_desc">"입 닫겠다"던 홍준표 "이러다 제3지대 당 탄생"</p>, <p class="cjs_dept_desc">홍준표, 전광훈 '국힘 결별' 예고에 "손절해야 할 사람에 손절 당해…치욕스러워"</p>, <p class="cjs_dept_desc">[오늘과학] 남성 육아휴직, 가족 구성원 성평등 의식 높인다</p>, <p class="cjs_dept_desc">[오늘과학] 북미서 발견된 5000만년 전 고추 화석</p>, <p class="cjs_dept_desc">[오늘과학] 하얗게 세어버린 머리카락 되돌리는 법</p>, <p class="cjs_dept_desc">[오늘과학] 코로나 백신 부작용 '혈전' 피하는 단백질, 곰한테 있었네</p>, <p class="cjs_dept_desc">[작전이 판친다]임창정도 30억?…연예인·골퍼·의사 엮인 주가조작판</p>, <p class="cjs_dept_desc">[작전이 판친다] 세력 손털기 도와주는 '하따'…유튜버도 부채질</p>, <p class="cjs_dept_desc">[작전이 판친다]'수십억' CFD 반대매매 청구서, 어떻게 '깡통계좌' 되나</p>, <p class="cjs_dept_desc">자금모집·투자자관리 '철저한 분업'…3년에 걸쳐 진행된 주가조작 전모</p>, <p class="cjs_dept_desc">‘치킨집 3만 시대’ 월 매출 ‘1억’vs 폐업…‘K-치킨’에 목매는 이유 있었네</p>, <p class="cjs_dept_desc">‘4인 가족 삼겹살 파티’ 10만원 훌쩍…‘5월 가정의 달’ 치솟는 물가 어쩌나</p>, <p class="cjs_dept_desc">돌아온 ‘망빙’의 계절…한 그릇에 ‘12만6000원’, 최고가 특급호텔은</p>, <p class="cjs_dept_desc">[영상] 현장은 '우회전 옥신각신'이지만…길 건너던 보행자 사고 줄이려면?- 취[재]중진담</p>, <p class="cjs_dept_desc">[부동산 핵심클릭] 주택 공급에 '적신호'가 켜졌다</p>, <p class="cjs_dept_desc">[진료는 의사에게] 간에 무리주는 민간요법 '주의'…나도 모르는 E형 간염</p>, <p class="cjs_dept_desc">[뉴스추적] 기존 주가조작과 다른 점…피해자냐? 공범이냐?</p>, <p class="cjs_dept_desc">[정승조의 아트홀릭] 미술관이 가장 잘하는 걸 안 볼 이유는 없다</p>, <p class="cjs_dept_desc">[아무튼, 자수] 꽃보다 그녀 ‘세월을 수놓다’</p>, <p class="cjs_dept_desc">‘우주 최초 수달 공무원’ 충주씨의 귀한 실물 사진 보러오세요</p>, <p class="cjs_dept_desc">[명품 컷] 비 오는 날의 수채화처럼 청아한 각원사의 봄풍경</p>, <p class="cjs_dept_desc">도대체 바닥은 어디일까...제주 아파트값 3억씩 ‘뚝뚝’ [김경민의 부동산NOW]</p>, <p class="cjs_dept_desc">“이러다 20억 다시 찍으려나”...마포 집값 슬금슬금 오른다 [김경민의 부동산NOW]</p>, <p class="cjs_dept_desc">용인 반도체 클러스터 수혜지 어디?...이천·동탄 등 경기 남부 ‘반세권’ 뜬다[김경민의 부동산NOW]</p>, <p class="cjs_dept_desc">아파트 이름만 무려 25글자?...“길고 어려운 아파트명 쉽게 바꾸자”</p>, <p class="cjs_dept_desc">[RSAC2023] 한-미 사이버동맹, ‘파이브아이즈’ 수준으로 강화</p>, <p class="cjs_dept_desc">[RSAC2023] 전시회 성황리 개막··· 보안 리더 기업 대부분 참여</p>, <p class="cjs_dept_desc">[RSAC2023] SIEM 시대 종말? 팔마 트렐릭스 CEO “SecOps 혁명 이뤄야”</p>, <p class="cjs_dept_desc">[RSAC2023] “사이버보안에 AI 기술 활용코자 하는 움직임 확인”</p>, <p class="cjs_dept_desc">[THINK ENGLISH] 이르면 올해 거리에서 배달 로봇 보게 될 듯</p>, <p class="cjs_dept_desc">[THINK ENGLISH] 윤 대통령, 전세사기 매물 경매 중단 지시</p>, <p class="cjs_dept_desc">[THINK ENGLISH] 조선 회화사의 공백 채울 걸작들의 귀환</p>, <p class="cjs_dept_desc">정통 워맨스, 그런데 킬힐 못 벗은 언니들의 '퀸메이커'</p>, <p class="cjs_dept_desc">한국 여성작가 100인, 프랑스 파리서 새로운 'K아트' 가능성을 열다</p>, <p class="cjs_dept_desc">피해자 보호 관점 실종된 '나는 신이다' 열풍</p>, <p class="cjs_dept_desc">60대에 '별의 순간' 양자경...트랜스젠더  ...
# <a class="u_ftlk" data-mpurl='{"m":"https://m.naver.com/services.html","p":"https://www.naver.com/more.html"}' href="https://m.naver.com/services.html" onclick="nclk(event,'fot.serviceall','','');">전체서비스</a>
# </p>, <p class="u_cr">
# <span class="u_ftm">
# <span class="u_cri u_cri_v1"><a class="u_cra" data-mpurl='{"m":"https://policy.naver.com/policy-mobile/term.html?type=1?type=1","p":"https://policy.naver.com/rules/service.html"}' href="https://policy.naver.com/policy-mobile/term.html?type=1?type=1" onclick="nclk(event,'fot.agreement','','');">이용약관</a></span>
# <span class="u_cri u_cri_v1"><a class="u_cra" data-mpurl='{"m":"https://policy.naver.com/policy-mobile/privacy.html","p":"https://policy.naver.com/rules/privacy.html"}' href="https://policy.naver.com/policy-mobile/privacy.html" onclick="nclk(event,'fot.privacy','','');"><strong>개인정보처리방침</strong></a></span>
# <span class="u_cri u_cri_v1">청소년 보호 책임자 : 이희만</span>
# <span class="u_cri u_cri_v1"><a class="u_cra" data-mpurl='{"m":"https://m.news.naver.com/ombudsman/index","p":"https://news.naver.com/main/ombudsman/index.naver"}' href="https://m.news.naver.com/ombudsman/index" onclick="nclk(event,'fot.guide','','');">서비스안내</a></span>
# </span>
# <span class="u_cri">각 언론사가 직접 콘텐츠를 편집합니다.</span>
# </p>]

# %%
# find() : 하나의 요소만 가져 옴
print(bs.find('p'))
# Out:
# <p class="cjs_d">(410) 김상현의 정교한 샷 한국프로골프(KPGA) 코리안투어가 개막하는 매년 4월, 주목받는 한 선수가 있습니다. 전년도 스릭슨투어 상금왕 김상현입니다. 2부 투어지만 지난해 정규투어에서 2번의 우승을 포함해 1</p>

# %%
# limit : 태그의 양을 제한
print(bs.find_all('p', limit=1),'\n')
print(bs.find_all('p', limit=3))
# Out:
# [<p class="cjs_d">(410) 김상현의 정교한 샷 한국프로골프(KPGA) 코리안투어가 개막하는 매년 4월, 주목받는 한 선수가 있습니다. 전년도 스릭슨투어 상금왕 김상현입니다. 2부 투어지만 지난해 정규투어에서 2번의 우승을 포함해 1</p>]
#
# [<p class="cjs_d">(410) 김상현의 정교한 샷 한국프로골프(KPGA) 코리안투어가 개막하는 매년 4월, 주목받는 한 선수가 있습니다. 전년도 스릭슨투어 상금왕 김상현입니다. 2부 투어지만 지난해 정규투어에서 2번의 우승을 포함해 1</p>, <p class="cjs_d">넷플릭스 코리아 '성+인물' 신동엽, 성시경 진행 맡아 일본 AV 배우·호스트 인터뷰 국내 불법인 AV 성 산업 조명 여성 배우 성착취 문제 언급 없어 넷플릭스 코리아가 제작한 예능 '성+인물 : 일본편'이 공개된 </p>, <p class="cjs_d">이태원 참사 희생자 분향소 운영을 두고 서울시와 유족의 갈등이 3개월째 이어지고 있다. 앞서 서울시는 이태원 참사 유가족협의회(유가협)와 시민대책회의에 2023년 2월4일부터 4월6일까지 무단점유한 서울광장 72㎡에</p>]

# %% [markdown]
# url = 'https://news.naver.com/' 사이트 p태크에서 class가 cjs_ht인 데이터를 출력하세요.

# %%
from bs4 import BeautifulSoup
import requests as rq
url = 'https://news.naver.com/'
r = rq.get(url)
html = r.text
bs = BeautifulSoup(html, 'lxml')

print(bs.find('p', class_="cjs_ht"))
print(bs.find_all('p', {'class':"cjs_d"}))
# Out:
# <p class="cjs_ht">
#
#
#                                 오늘 언론사가 발행한<br/>종이신문에 실린 뉴스 1면<br/>기사가 제공됩니다.
#
#
#
#                     </p>
# [<p class="cjs_d">정부가 우리 농업의 미래와 식량주권 확보를 위해 '가루쌀' 보급·육성에 사활을 걸고 있습니다. 농림축산식품부(장관 정황근)는 '2024년도 가루쌀 전문 재배단지 육성사업' 지원 대상자를 모집한다고 30일 밝혔습니다.</p>, <p class="cjs_d">미국을 국빈 방문 중인 윤석열 대통령은 28일(현지시간) 오후 보스턴 하버드대 케네디스쿨에서 진행한 연설 이후 조지프 나이 하버드대 석좌교수와의 토론 및 학생 질의응답에서 "대한민국은 핵무장을 하겠다고 마음을 먹으면</p>, <p class="cjs_d">돈 한 푼 안들이고 시간, 장소 제약 없이 할 수 있는 최고의 운동, 바로 '계단 걷기'입니다. 그런데 막상 하려니 무릎 관절이 걱정이신 분들, 이 두 가지만 명심하십시오. '올라갈 땐 숙이고, 내려갈 땐 세우라' </p>, <p class="cjs_d">코미디언 겸 사업가 고(故) 서세원씨의 한국 장례식이 30일인 오늘부터 한국코미디언협회장으로 치러지고 있다. 동료 코미디언 이용식씨와 엄영수씨(개명 전 엄용수) 등이 빈소를 찾아 고인을 애도했다. 30일 뉴스1에 따</p>, <p class="cjs_d">5박7일 일정 마무리…與, '워싱턴선언' 최대 성과 지목 12년 만의 국빈 방문에 '최초' 기록도 여럿 '빈손' IRA‧반도체법‧'핵 공유' 논란 등 찜찜한 뒷맛 윤석열 대통령과 김건희 여사는 </p>, <p class="cjs_d">대만에서 한국인 여성 관광객이 현지 호텔에서 숨진 채 발견된 가운데, 현지 수사당국은 이 여성과 동행했던 한국인 남자친구를 긴급 체포했다. 30일(현지시간) 대만연합보는 지난 24일 낮 12시30분쯤 남부 가오슝 첸</p>, <p class="cjs_d">대만에 여행 간 한국인 여성 관광객이 현지 호텔에서 숨진 채 발견됐다. 이 사건과 관련해 현지 수사당국은 여성과 동행한 한국인 남성을 체포했다. 30일(현지시간) 대만연합보는 지난 24일 낮 1시 30분께 대만 남부</p>, <p class="cjs_d">159명의 청년이 목숨을 잃은 이태원 참사가 6개월을 맞았다. 반년의 시간이 흘러 봄이 왔지만, 유족들에게 치유의 시간은 아직 허락되지 않고 있다. 유족이 애타게 알고 싶은 ‘그날의 진실’이 여전히 베일에 싸여 있기</p>, <p class="cjs_d">이태원 참사 희생자 분향소 운영을 두고 서울시와 유족의 갈등이 3개월째 이어지고 있다. 앞서 서울시는 이태원 참사 유가족협의회(유가협)와 시민대책회의에 2023년 2월4일부터 4월6일까지 무단점유한 서울광장 72㎡에</p>, <p class="cjs_d">5월 첫째주 공모주 일정을 알아볼게요. 이번주에는 근로자의 날과 어린이날 휴일이 끼어 있는데도 수요예측 일정이 빼곡해요. 앞서 증권신고서 정정으로 일정을 미룬 기업들의 공모일정이 겹쳤기 때문인데요. 기업인수목적회사인</p>, <p class="cjs_d">조 바이든 미국 대통령이 내년 대선에 출마하겠다고 공식적으로 선언했다고 AP 등 외신이 4월 25일(현지 시간) 보도했다. 보도에 따르면 바이든 대통령은 이날 온라인에 공개한 선거 운동 영상에서 “일을 마무리 짓겠다</p>, <p class="cjs_d">반려견과 산책하다 다쳐 응급실을 찾는 사람들이 미국에서 매년 평균 2만 명 이상 발생한다는 연구 결과가 나왔다. 미국 존스홉킨스대의대와 보건대학원 공동 연구팀은 2001~2020년 미국 소비자제품안전위원회 '국가 상</p>, <p class="cjs_d">지난 27일 출시한 모바일 MMORPG '나이트크로우'가 출시 4일 만에 구글플레이 스토어 매출 순위 2위를 기록했다. 그간 글로벌 지역을 중심으로 블록체인과 관련 기술을 탑재한 게임 플랫폼을 운영해온 위메이드는 나</p>, <p class="cjs_d">인도 북부의 한 공장 지대에서 유독 가스가 누출돼 11명이 목숨을 잃고 9명이 다친 것으로 파악됐다. 30일(현지시각) 로이터통신에 따르면 이날 오전 북부 펀자브주 루디아나 지역의 공장 지대에서 유독 가스 누출 사고</p>, <p class="cjs_d">◀ 앵커 ▶ 석달 앞으로 다가온 세계잼버리를 앞두고, 지구촌 50여 개국 스카우트 대표단이 부안 새만금 현장을 찾아 막바지 점검을 진행했습니다. 만일의 사고를 대비하고 개선 사항을 점검하기 위한 시범캠프를 방문한 건</p>, <p class="cjs_d">윤석열 대통령이 조 바이든 미국 대통령과의 정상회담을 통해 일궈 낸 ‘워싱턴 선언’에 대해 한국 내에서는 북한의 핵무기에 대비한 실질적인 확장억제 방편이라는 평가가 있지만, 실속이 없다는 비판도 존재한다. 한국 내에</p>, <p class="cjs_d">간호법 제정안 저지를 위해 지난 25일부터 국회 앞 단식을 이어 온 곽지연 대한간호조무사협회장이 30일 건강 악화로 병원에 후송됐다. 지난 27일 간호법 및 의사면허 취소법이 더불어민주당 주도로 국회 본회의에서 강행</p>, <p class="cjs_d">활동 무대 옮겨가며 미성년자 성 착취하는 ‘유사 N번방’ 기승 “◯◯팸 옵챗(오픈채팅) 들어가지마셈.” 온라인 커뮤니티 디시인사이드의 ‘우울증 갤러리’에는 최근 이 같은 내용의 게시물이 여러 건</p>, <p class="cjs_d">文 전 대통령 부부의 목가적 전원생활 그려 풍산개 송강·곰이 파양 문제 비중 있게 다뤄 정치적 메시지는 이전 정부 인사의 발언 빌려 文 전 대통령 당시 검찰총장 임기보장 원칙 고수엔 전 정부 인사들 “결국 정권 뺏겼</p>, <p class="cjs_d">올해 1분기 러시아인 난민 신청이 지난해 1년치보다 많은 것으로 집계됐습니다. 법무부는 올해 들어 3월까지 접수된 난민 신청 건수가 4,057건이며 이 중 러시아인 신청이 가장 많은 1,056건으로 전체의 26%를 </p>, <p class="cjs_d">코로나19 백신 개발로 급성장한 미국 제약사 모더나의 스테판 방셀 최고경영자(CEO)가 지난해 스톡옵션(주식매수청구권)으로 거액을 번 사실을 드러나 논란이 일고 있습니다. 미국 워싱턴포스트(WP)는 방셀 CEO가 지</p>, <p class="cjs_d">30대 다문화여성이 4살 아들을 살해하고 경찰에 자수했습니다. 충북 청주 흥덕경찰서는 우즈베키스탄 국적의 30대 여성 A씨를 살인혐의로 붙잡아 조사하고 있습니다. A씨는 29일 오전 3시 40분쯤 청주시 흥덕구 자택</p>, <p class="cjs_d">하이브 직원들이 글로벌 아티스트 방탄소년단(BTS)의 단체활동 중단 전 내부 정보를 활용해 주식을 매매한 혐의로 수사를 받고 있는 것으로 알려졌다. 30일 조선일보 보도 등에 따르면 수사당국은 하이브 직원 일부에 대</p>, <p class="cjs_d">물건을 먼저 구입하고 나중에 결제하는 '선구매 후불결제(BNPL)' 서비스의 연체율이 높아지면서 건전성에 대한 우려도 커지고 있다. 30일 국회 정무위원회 소속 최승재 국민의힘 의원이 금융감독원으로부터 받은 네이버파</p>, <p class="cjs_d">윤석열 대통령이 30일 5박 7일 간의 미국 국빈 방문 일정을 모두 마무리하고 귀국했다. 윤 대통령은 지난 24일 출국 후 미국 워싱턴 D.C.에서 한미정상회담과 국빈 만찬, 미 상·하원 합동회의 연설, 미 국방부인</p>, <p class="cjs_d">요즘 4대강 사업의 주역들이 부쩍 대중 앞에 자주 등장하고 있다. 이명박 전 대통령(이하 존칭 생략)은 며칠 전 측근 유인촌의 연극을 관람했고 앞으로 4대강도 방문할 예정이라고 한다. 4대강 추진본부장이었던 심명필은</p>, <p class="cjs_d">“한국인이 없어서 못타는 ‘독일차’…가수 위너도 반했다” 중고차 거래 플랫폼 KB차차차가 지난 1년간 한국인이 가장 많이 찾는 독일 3사(벤츠·BMW·아우디) 중고차 모델을 분석한 결과 벤츠 E클래스가 1위를 기록한</p>, <p class="cjs_d">"아무도 없어서 외로웠는데 바로 윗선배가 나타나니까 활짝 웃네" 코미디언 이용식씨가 최근 캄보디아에서 숨진 방송인 출신 사업가 고(故) 서세원씨의 빈소를 찾아 후배에게 마지막 작별 인사를 했다. 이씨는 30일 서울 </p>, <p class="cjs_d">지난 ...

# %%
texts = bs.find_all('p', {'class':"cjs_d"})
for t in texts:
    t = str(t)
    t = re.findall('[가-힣]+',t)
    t = ' '.join(t)
    print(t,'\n')
# Out:
# 정부가 우리 농업의 미래와 식량주권 확보를 위해 가루쌀 보급 육성에 사활을 걸고 있습니다 농림축산식품부 장관 정황근 는 년도 가루쌀 전문 재배단지 육성사업 지원 대상자를 모집한다고 일 밝혔습니다
#
# 미국을 국빈 방문 중인 윤석열 대통령은 일 현지시간 오후 보스턴 하버드대 케네디스쿨에서 진행한 연설 이후 조지프 나이 하버드대 석좌교수와의 토론 및 학생 질의응답에서 대한민국은 핵무장을 하겠다고 마음을 먹으면
#
# 돈 한 푼 안들이고 시간 장소 제약 없이 할 수 있는 최고의 운동 바로 계단 걷기 입니다 그런데 막상 하려니 무릎 관절이 걱정이신 분들 이 두 가지만 명심하십시오 올라갈 땐 숙이고 내려갈 땐 세우라
#
# 코미디언 겸 사업가 고 서세원씨의 한국 장례식이 일인 오늘부터 한국코미디언협회장으로 치러지고 있다 동료 코미디언 이용식씨와 엄영수씨 개명 전 엄용수 등이 빈소를 찾아 고인을 애도했다 일 뉴스 에 따
#
# 박 일 일정 마무리 워싱턴선언 최대 성과 지목 년 만의 국빈 방문에 최초 기록도 여럿 빈손 반도체법 핵 공유 논란 등 찜찜한 뒷맛 윤석열 대통령과 김건희 여사는
#
# 대만에서 한국인 여성 관광객이 현지 호텔에서 숨진 채 발견된 가운데 현지 수사당국은 이 여성과 동행했던 한국인 남자친구를 긴급 체포했다 일 현지시간 대만연합보는 지난 일 낮 시 분쯤 남부 가오슝 첸
#
# 대만에 여행 간 한국인 여성 관광객이 현지 호텔에서 숨진 채 발견됐다 이 사건과 관련해 현지 수사당국은 여성과 동행한 한국인 남성을 체포했다 일 현지시간 대만연합보는 지난 일 낮 시 분께 대만 남부
#
# 명의 청년이 목숨을 잃은 이태원 참사가 개월을 맞았다 반년의 시간이 흘러 봄이 왔지만 유족들에게 치유의 시간은 아직 허락되지 않고 있다 유족이 애타게 알고 싶은 그날의 진실 이 여전히 베일에 싸여 있기
#
# 이태원 참사 희생자 분향소 운영을 두고 서울시와 유족의 갈등이 개월째 이어지고 있다 앞서 서울시는 이태원 참사 유가족협의회 유가협 와 시민대책회의에 년 월 일부터 월 일까지 무단점유한 서울광장 에
#
# 월 첫째주 공모주 일정을 알아볼게요 이번주에는 근로자의 날과 어린이날 휴일이 끼어 있는데도 수요예측 일정이 빼곡해요 앞서 증권신고서 정정으로 일정을 미룬 기업들의 공모일정이 겹쳤기 때문인데요 기업인수목적회사인
#
# 조 바이든 미국 대통령이 내년 대선에 출마하겠다고 공식적으로 선언했다고 등 외신이 월 일 현지 시간 보도했다 보도에 따르면 바이든 대통령은 이날 온라인에 공개한 선거 운동 영상에서 일을 마무리 짓겠다
#
# 반려견과 산책하다 다쳐 응급실을 찾는 사람들이 미국에서 매년 평균 만 명 이상 발생한다는 연구 결과가 나왔다 미국 존스홉킨스대의대와 보건대학원 공동 연구팀은 년 미국 소비자제품안전위원회 국가 상
#
# 지난 일 출시한 모바일 나이트크로우 가 출시 일 만에 구글플레이 스토어 매출 순위 위를 기록했다 그간 글로벌 지역을 중심으로 블록체인과 관련 기술을 탑재한 게임 플랫폼을 운영해온 위메이드는 나
#
# 인도 북부의 한 공장 지대에서 유독 가스가 누출돼 명이 목숨을 잃고 명이 다친 것으로 파악됐다 일 현지시각 로이터통신에 따르면 이날 오전 북부 펀자브주 루디아나 지역의 공장 지대에서 유독 가스 누출 사고
#
# 앵커 석달 앞으로 다가온 세계잼버리를 앞두고 지구촌 여 개국 스카우트 대표단이 부안 새만금 현장을 찾아 막바지 점검을 진행했습니다 만일의 사고를 대비하고 개선 사항을 점검하기 위한 시범캠프를 방문한 건
#
# 윤석열 대통령이 조 바이든 미국 대통령과의 정상회담을 통해 일궈 낸 워싱턴 선언 에 대해 한국 내에서는 북한의 핵무기에 대비한 실질적인 확장억제 방편이라는 평가가 있지만 실속이 없다는 비판도 존재한다 한국 내에
#
# 간호법 제정안 저지를 위해 지난 일부터 국회 앞 단식을 이어 온 곽지연 대한간호조무사협회장이 일 건강 악화로 병원에 후송됐다 지난 일 간호법 및 의사면허 취소법이 더불어민주당 주도로 국회 본회의에서 강행
#
# 활동 무대 옮겨가며 미성년자 성 착취하는 유사 번방 기승 팸 옵챗 오픈채팅 들어가지마셈 온라인 커뮤니티 디시인사이드의 우울증 갤러리 에는 최근 이 같은 내용의 게시물이 여러 건
#
# 전 대통령 부부의 목가적 전원생활 그려 풍산개 송강 곰이 파양 문제 비중 있게 다뤄 정치적 메시지는 이전 정부 인사의 발언 빌려 전 대통령 당시 검찰총장 임기보장 원칙 고수엔 전 정부 인사들 결국 정권 뺏겼
#
# 올해 분기 러시아인 난민 신청이 지난해 년치보다 많은 것으로 집계됐습니다 법무부는 올해 들어 월까지 접수된 난민 신청 건수가 건이며 이 중 러시아인 신청이 가장 많은 건으로 전체의 를
#
# 코로나 백신 개발로 급성장한 미국 제약사 모더나의 스테판 방셀 최고경영자 가 지난해 스톡옵션 주식매수청구권 으로 거액을 번 사실을 드러나 논란이 일고 있습니다 미국 워싱턴포스트 는 방셀 가 지
#
# 대 다문화여성이 살 아들을 살해하고 경찰에 자수했습니다 충북 청주 흥덕경찰서는 우즈베키스탄 국적의 대 여성 씨를 살인혐의로 붙잡아 조사하고 있습니다 씨는 일 오전 시 분쯤 청주시 흥덕구 자택
#
# 하이브 직원들이 글로벌 아티스트 방탄소년단 의 단체활동 중단 전 내부 정보를 활용해 주식을 매매한 혐의로 수사를 받고 있는 것으로 알려졌다 일 조선일보 보도 등에 따르면 수사당국은 하이브 직원 일부에 대
#
# 물건을 먼저 구입하고 나중에 결제하는 선구매 후불결제 서비스의 연체율이 높아지면서 건전성에 대한 우려도 커지고 있다 일 국회 정무위원회 소속 최승재 국민의힘 의원이 금융감독원으로부터 받은 네이버파
#
# 윤석열 대통령이 일 박 일 간의 미국 국빈 방문 일정을 모두 마무리하고 귀국했다 윤 대통령은 지난 일 출국 후 미국 워싱턴 에서 한미정상회담과 국빈 만찬 미 상 하원 합동회의 연설 미 국방부인
#
# 요즘 대강 사업의 주역들이 부쩍 대중 앞에 자주 등장하고 있다 이명박 전 대통령 이하 존칭 생략 은 며칠 전 측근 유인촌의 연극을 관람했고 앞으로 대강도 방문할 예정이라고 한다 대강 추진본부장이었던 심명필은
#
# 한국인이 없어서 못타는 독일차 가수 위너도 반했다 중고차 거래 플랫폼 차차차가 지난 년간 한국인이 가장 많이 찾는 독일 사 벤츠 아우디 중고차 모델을 분석한 결과 벤츠 클래스가 위를 기록한
#
# 아무도 없어서 외로웠는데 바로 윗선배가 나타나니까 활짝 웃네 코미디언 이용식씨가 최근 캄보디아에서 숨진 방송인 출신 사업가 고 서세원씨의 빈소를 찾아 후배에게 마지막 작별 인사를 했다 이씨는 일 서울
#
# 지난해부터 사회관계망서비스 에 자주 등장하는 디저트로 전통 과자류인 약과를 빼놓을 수 없다 제사상이나 차례상에서 주로 접하던 약과가 케이 디저트 로 각광받으며 이제는 오픈런 과 완판행진 을 불러일으
#
# 영업 시작과 함께 고객들의 발길이 이어집니다 중국 노동절 연휴를 맞아 제주를 찾은 개별 관광객들입니다 정기편으로 찾은 태국 단체 관광객까지 몰려 연휴 분위기는 더합니다 개별 씀씀이가 아주 크진 않아도 지난해 초
#
# 그건 안 돼요 원점회귀해야 됩니다 왜요 반려견은 케이지 없이 지하철 못 타요 아 우리의 대화는 대체로 이랬다 쳇바퀴 돌 듯 어려움과 이해가 거듭됐다 반려견을 동반해 움직인다는 것에 무지한
#
# 배우 원빈과 이나영이 지난 년 서울 강남구 청담동에 매입한 건물이 억원을 호가하는 것으로 알려져 주목을 받고 있다 일 부동산 업계에 따르면 원빈과 이나영은 년 월 서울 강남구 청담동 지하철
#
# 야유회에서 술을 마시고 옥상에서 떨어져 수술 받다 숨진 군인을 보훈대상자로 인정하기 어렵다는 대법원의 판단이 나왔습니다 대법원 부는 지난 년 월 간부 숙소 옥상에서 추락해 군 병원에서 수술을 받다 숨진
#
#
#
# 남북이 가장 가깝게 총구를 맞대고 있는 곳 최북단 철책에는 시간 경계를 펴고 있는 최전방 사단이 있습니다 과학화 경계시스템으로 보다 정밀한 임무를 수행하는 사단 장병들의 모습을 임성재 기자가 보도합니
#
# 때만 되면 포털 뉴스란에 심심찮게 등장하는 단어가 있습니다 수상택시입니다 그 옆에는 늘 함께 붙어다니는 말이 있습니다 서울시입니다 서울시는 년부터 서울의 교통혼잡을 완화하기 위한 대안으로 수상택
#
# 김상현의 정교한 샷 한국프로골프 코리안투어가 개막하는 매년 월 주목받는 한 선수가 있습니다 전년도 스릭슨투어 상금왕 김상현입니다 부 투어지만 지난해 정규투어에서 번의 우승을 포함해
#
# 김익래 다우키움그룹 회장의 다우데이타 주식 고점 매도 후 주가 폭락 은 이번이 처음이 아닌 것으로 확인됐다 년 전 김 회장은 보유 중이던 다우데이타 주식 를 폭락 직전 매도해 억 만원을 확보
#
# 포장된 상자 안에 살아있는 오리가 고개를 내밀고 있는 사진이 온라인상에서 확산하며 화제가 되고 있습니다 지난 일 온라인 커뮤니티 에펨코리아 등에는 현직 택배기사인데 이거 뭐냐 라는 제목의 글이 게재됐습니다
#
# 중국이 우리나라 반도체 산업에 대한 압박에 나섰다 원산지 점검과 통관 검사 강화 조치에 이어 우리 기업의 중국 수출 계약 취소 사례까지 등장 미 중 갈등으로 인해 국내 기업 피해가 가시화되는 것이 아니냐는 우려가
#
# 개봉을 앞둔 디즈니 영화 인어공주 의 타이틀롤을 맡은 미국 배우 할리 베일리 가 동물 학대를 부추겼다는 논란에 휩싸였다 일 현지시간 영국 매체 미러에 따르면 베일리는 지난 일 자신의 인스타그램을
#
# 문재인 전 대통령의 퇴임 후 일상을 보여주는 다큐멘터리 영화 문재인입니다 가 최근 전주국제영화제에서 공개됐다 선공개 영상에 포함됐던 년간 성취가 정권 교체 후 무너졌다 는 취지의 문 전 대통령 발언은 이날
#
# 이재명 더불어민주당 대표는 일 저와 박광온 원내대표에게는 함께 힘을 합쳐 총선에서 반드시 승리해 우리 사회의 추락을 저지해야 할 역사적 소명이 주어져 있다 고 밝혔다 이 대표는 이날 페이스북에 박 대표님 손
#
# 통정매매 가담 처벌대상 될 수 있어 가수 임창정 씨가 연일 화제의 중심에 서있다 최근 외국계 증권사 소시에테제네랄 증권발 주가 하락 사태와 관련해 수십억 원의 손해를 본 것으로 알려지면서다 현재
#
# 축구 황제 펠레의 이름이 뛰어난 비교할 수 없는 유일무이한 사람을 의미하는 형용사로 브라질 사전에 영원히 남게 됐습니다 현지 시간으로 지난 일 등 외신들은 펠레 가 포르투갈어 사전에
#
# 캔을 뚜껑째 열어 맥주잔처럼 마실 수 있는 일본 아사히 수퍼드라이 생맥주 제품이 월 국내에 한정 출시되는 가운데 며칠 앞서 코스트코에 입고된 상품을 사기 위한 오픈런 경쟁이 치열한 것으로 나타났다 일본에서
#
# 윤석열 대통령은 미국 상 하원 합동 연설에서 자유 란 단어를 회나 사용했다 취임 후 가장 많이 썼다 그러면서 윤 대통려은 한미동맹을 자유와 평화를 지키는 글로벌 동맹 으로 규정했다 이와 대조적으로 러시아
#
# 강직한 검사 는 어떻게 가해자 를 변호하게 됐는가 한국 사회에서 보통 검사는 옷을 벗으면 전관 변호사 가 된다 엊그제 범죄자를 잡아 넣던 검사는 오늘 범죄자를 변호한다 이상한 모습이지만 자연스러운 모습니다
#
# 여성들의 말과 글이 세상에 더 많이 퍼지고 새겨져야 한다고 믿으며 서점에서 퍼뜨리고 싶은 여자들의 책을 고른다 살롱드마고 의 신간 책장에서 마음에 새겨지는 책을 한 권씩 밑줄 그으며 꼭꼭 씹어 독자들과 맛있게
#
# 주차장에서 차 빼라고 전화가 와서 라든지 택시가 안 잡혀서 어쩔 수 없이 라는 말들 경찰의 음주운전 단속에 적발된 운전자들의 흔한 변명입니다 심지어 내가 신분증 내밀면 알 만한 사람인데 또는 내가 너 죽
#
# 대만으로 여행을 떠난 대 한국 여성이 쓰러진 채 발견돼 병원으로 이송됐지만 결국 숨졌습니다 현지 수사당국은 최초 신고자인 남자친구를 유력한 용의자로 보고 체포했습니다 황예린 기자입니다 기자 대만 가오슝에
#
# 모빌리티 옛 쌍용차 가 년 개월 만의 거래 재개 첫날 양호한 흐름을 보였다 다만 단기 차익실현 매물과 내달 의무보유해제 물량 등의 악재로 당분간 변동성을 키울 것이라는 관측이 나오고 있다 일 한국거래소
#
# 일 오후 시 무렵 전북 전주시 전북대 삼성문화회관은 사람들로 붐볐다 제 회 전주국제영화제에서 첫 공개되는 다큐멘터리영화 문재인입니다 를 보려는 이들이 대부분이었다 일부 관객은 로비에 설치된 대형 영화 포
#
# 가수 겸 배우 임창정이 외국계 증권사 소시에테제네랄 증권발 주가 폭락 사태와 관련해 피해를 호소한 가운데 일각에서 불거진 압구정 수백억원 빌딩설 에 대해 해명했다 업계에 따르면 최근 한 온라인 커뮤니티에
#
# 윤석열 대통령이 미국 국빈 방문 일정을 마치고 일 오후 귀국했다 여야는 윤 대통령의 귀국에 맞춰 이번 국빈 방문을 두고 엇갈린 해석을 내놓았다 여당은 워싱턴 선언 등 지난 박 일간 윤 대통령의 국빈 방
#
# 대통령실은 일 백악관 만찬에서 윤석열 대통령이 부른 아메리칸 파이 와 관련한 박지원 전 국가정보원장의 주장에 대해 반국가적 작태 라고 일축했다 대통령실 핵심 관계자는 이날 언론을 통해 근거 없는 박 전 원장
#
# 직장인 익명 커뮤니티 블라인드에 삼성전자 신입 사원이 남긴 패기 넘치는 글이 화제다 이재용 회장에게 사내 메신저로 뽑아주셔서 감사하다 는 인사를 보내도 되냐 는 내용인데 정작 이 글보다 이에 대한 베댓 베스트
#
# 기사내용 요약 펜션서 대 여성 강제추행한 혐의 대법 유죄 판단 징역 개월 확정 서울 뉴시스 류인선 기자 펜션에서 여성을 강제추행한 혐의로 재판에 넘겨진 그룹 비에이피 출신 멤버 힘찬 김
#
# 이철규 국민의힘 사무총장 대선 경선 치르며 처음 인연 맺었다 당 사무총장 살림하고 책임지는 자리 공천 순위는 주민 위해 봉사할 인물 쓴소리에 귀 닫지 않는 열린 마음 소유자 검사 많다고
#
# 대구시 북구 대현동 이슬람 사원 건축공사 논란이 년째 계속되고 있습니다 주민 반대를 넘어 사회적 갈등으로 확산하고 있는데요 이슬람 사원 건축을 놓고 지역 주민들이 대구 북구청에 탄원서를 제출하면서 년
#
# 박지원 한 소절 더 했으면 바이든과 듀엣 대통령실 바이든 노력 알기에 한 소절 부른 것 대통령실은 일 윤석열 대통령이 지난 일 현지 시각 백악관 국빈 만찬에서 아메리칸 파이 를 부른 것과 관련
#
# 민생 드라이브로 돈봉투 국면전환 모색 정책 제안으로 정부 비판 효과도 더불어민주당 이재명 대표가 최근 부쩍 자주 현장을 찾고 있다 이 대표는 지난주에는 전세 사기 피해자 간담회 일 이른바 지옥철 로 불
#
#
#
# 부산에 본사를 둔 중앙정부 산하 공공기관 절반이 지난해 영업적자를 낸 것으로 나타났다 코로나 장기화와 원자재 가격 상승 등으로 경영이 악화됐기 때문이다 이 때문에 지역 공공기관 상당수는 기관장 연봉을 삭감했다
#
# 한낮의 공원에 약 마리의 반려견들이 모였다 이들은 서울시로부터 정식 순찰대로 임명받은 반려견 순찰대다 월의 마지막 날인 일 서울 여의도 한강공원은 온통 개 짖는 소리로 가득했다 이곳에선 이날
#
# 네이버가 불공정 논란이 일었던 뉴스콘텐츠제휴 약관을 전면 수정해 재공지했다 네이버는 일 오후 뉴스콘텐츠제휴 언론사들에 이메일을 보내 기존 약관 대신 추가 수정한 개정 약관으로 재동의를 구하고자 한다 며
#
# 간호법 제정 반대를 위해 단식 시위 중이던 곽지연 대한간호조무사협회장이 병원으로 이송됐다 일 오후 국회 앞에서 단식 농성을 벌이던 곽 회장은 보건복지부 조규홍 장관과 현장 의사의 권유로 병원에 응급 이송됐다
#
# 김영민 교수 책 인생의 허무를 어떻게 할 것인가 벚꽃이 만개해 세상이 연분홍빛으로 뒤덮였다 비가 내리자 벚꽃나무 가지만 남았다 오랜만에 해가 떠 있는 시간에 퇴근하니 회사 앞에 안 보이던 철쭉들이 진분홍 길을
#
# 의사와 간호조무사 등이 간호법 제정안과 의료법 개정안 의사면허취소법 의 국회 본회의 통과에 반발 총파업을 예고했다 일 의료계 등에 따르면 의사와 간호조무사 단체 등 개 보건의료단체가 참여하는 보건복지의료연
#
# 윤석열 대통령의 박 일 국빈 방미 일정이 끝난 가운데 일부 언론이 외교 성과를 냉정히 짚기보다 지난 일 대통령의 미 의회 영어 연설을 지나치게 띄워줘 일련의 보도 행태가 전두환 공 시절을 떠올리게 한다는
#
# 곤충이나 무척추동물이 주식인 개구리는 육식성 동물로 알려져 있다 하지만 어떤 개구리는 식물의 열매나 꿀을 맛있게 먹는 초식성 식습관을 가졌다는 연구 결과가 나왔다 열매를 먹는 과정에서 꽃가루를 옮기며 식물의 수분
#
# 박지원 전 국가정보원장이 일 대통령 안보실 김태효 차장이 물러나야 윤석열 정부 외교가 살 수 있다고 주장했다 이와 함께 윤석열 대통령이 아메리칸 파이 열창 시 한 소절만 부르고 말았다면 조 바이든 대통령과
#
# 애플워치가 향후 아이폰 뿐 아니라 아이패드 맥 등 다른 애플 기기와도 연동될 수 있다는 소식이 나왔다 매체 폰아레나는 일 현지시간 트위터 이용자 를 인용해 애플이 애플워치를 아이패드
#
# 윤석열 대통령 부부가 일 박 일 간의 미국 국빈 방문을 마치고 귀국했다 윤 대통령과 김건희 여사는 이날 오후 전용기인 공군 호기 편으로 서울공항에 도착했다 이날 공항에는 김대기 대통령비서실장 김기현 국민
#
# 생후 일 아이를 떨어뜨리고도 방치해 숨지게 한 혐의를 받는 대 중증 지적장애인 친모 씨가 일 오후 구속 전 피의자 심문 영장실질심사 을 받기 위해 인
#
# 윤석열 대통령이 일 박 일 간의 미국 국빈 방문을 마치고 귀국했다 윤 대통령과 부인 김건희 여사는 이날 오후 전용기인 공군 호기 편으로 서울공항에 도착해 미리 나와 있던 환영객들과 인사했다 윤 대통령은
#
# 미국을 국빈 방문한 윤석열 대통령이 참석한 행사에 배우 이서진이 모습을 나타냈다 윤 대통령은 지난 일 현지시간 워싱턴 미국영화협회 건물에서 개최된 글로벌 영상콘텐츠 리더십 포럼 에 참석했다 이
#
# 윤석열 대통령은 역대 대통령들과 다른 별종의 지도자인 것 같다 박정희 정권 이래 지난 여년간 대한민국의 대통령은 보수 진보를 막론하고 자신의 기질과 상관없이 대외정책에서 한반도 정세의 안정을 기하는 방향에서
#
# 일 오후 시 분쯤 정선군 화암면 화암 약수제 행사장에서 텐트가 강풍에 의해 무너지는 사고가 발생했다 이 사고로 텐트 주변에 있던 명이 다쳐 병원으로 옮겨졌다 이날 정선지역에는 강풍주의보가 내려진 상태다
#
# 벨기에에서 대 남성이 인공지능 챗봇의 부추김을 받아 스스로 목숨을 끊었다고 월 일 벨기에 일간지 라리브르 가 보도했다 여러 언론의 추가 보도를 종합해 사건을 재구성하면 이렇다 피
#
# 넷플릭스 코리아 성 인물 신동엽 성시경 진행 맡아 일본 배우 호스트 인터뷰 국내 불법인 성 산업 조명 여성 배우 성착취 문제 언급 없어 넷플릭스 코리아가 제작한 예능 성 인물 일본편 이 공개된
#
# 년대 생활영어 로 명성을 얻은 세대 영어 강사 오성식 씨가 윤석열 대통령의 미 의회 연설에 대해서 윤 대통령이 영어에도 스피치에도 일가견이 있더라 며 이번 스피치는 정말 만점이었다 고 평가했다

# %%
# A.
import requests as rq
from bs4 import BeautifulSoup

url = 'https://news.daum.net/politics'

r = rq.get(url)
html = r.text
bs = BeautifulSoup(html,'html.parser')
title = bs.find('h2',id='mainContent').text
title
# Out:
# '정치'

# %%
# 점검
# Q. 네이버 영화 랭킹 조회순 첫번째 영화제목을 출력하세요.

# %%
import requests
from bs4 import BeautifulSoup

url = "https://serieson.naver.com/v3/movie/ranking/realtime"

# HTTP GET 요청을 보냅니다.
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
import requests
from bs4 import BeautifulSoup

url = "https://serieson.naver.com/v3/movie/ranking/realtime"

# HTTP GET 요청을 보냅니다.
response = requests.get(url)

# HTTP 요청이 성공적으로 전달되었다면, 웹사이트의 HTML 코드를 가져옵니다.
if response.status_code == 200:
    # HTML 코드를 파싱합니다.
    soup = BeautifulSoup(response.text, "html.parser")
# print(soup)
soup.find("span", class_="Title_title__s9o0D").text
# Out:
# '던전 앤 드래곤: 도적들의 명예'

# %%
<span class="Title_title__s9o0D">던전 앤 드래곤: 도적들의 명예</span>

# %%
import requests
from bs4 import BeautifulSoup
req = requests.get("https://serieson.naver.com/v3/movie/ranking/realtime")
html = req.content.decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')
list = soup.find_all("span", class_="Title_title__s9o0D")
for i, l in enumerate(list[:10]):
    print(f'{i+1}: {l.text}')
# Out:
# 1: 던전 앤 드래곤: 도적들의 명예
# 2: 존 윅
# 3: 존 윅 3: 파라벨룸
# 4: 앤트맨과 와스프: 퀀텀매니아
# 5: 아바타: 물의 길(부가영상 제공)
# 6: 존 윅 - 리로드
# 7: 소중한 날의 꿈
# 8: 앤트맨과 와스프: 퀀텀매니아(세트: 1~3편)
# 9: 에브리씽 에브리웨어 올 앳 원스
# 10: 극장판 짱구는 못말려: 수수께끼! 꽃피는 천하떡잎학교

# %%
# 점검
# Q. 네이버 영화 랭킹 가져와서 조회순 첫번째 영화제목을 출력하세요.
import requests
from bs4 import BeautifulSoup
req = requests.get("https://serieson.naver.com/v3/movie/ranking/realtime")
html = req.content.decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')
#container > div.RankingPage_ranking_wrap__GB855 > ol > li:nth-child(1) > a > div.Poster_info_area__HGRo_.Poster_margin_left__sLY0L > span
# print(soup)
movie = soup.select_one('#container > div > ol > li > a > div > span')
print('1위:', movie.get_text().strip())
# Out:
# 1위: 던전 앤 드래곤: 도적들의 명예

# %%
from bs4 import BeautifulSoup
import re # 정규 표현식을 사용할 때
html = """
<ul>
  <li><a href="hoge.html">hoge</li>
  <li><a href="https://example.com/fuga">fuga*</li>
  <li><a href="https://example.com/foo">foo*</li>
  <li><a href="http://example.com/aaa">aaa</li>
</ul>
"""
soup = BeautifulSoup(html, "html.parser")
# 정규 표현식으로 href에서 https인 것 추출하기
li = soup.find_all(href=re.compile(r"^https://"))
for e in li: print(e.attrs['href'])
# Out:
# https://example.com/fuga
# https://example.com/foo

# %% [markdown]
# ### CSS 선택자
# - 원하는 정보만 선별하여 수집하고 싶을 때 css선택자를 활용할 수 있음
# - (CSS 선택자 설명 추가)
# - F12 >> 수집하고 싶은 부분 클릭 >> 태그 선택 >> copy Selector
# - BeautifulSoup의 select_one, select 활용

# %%
# select()
import requests as rq
from bs4 import BeautifulSoup

url = 'https://news.daum.net/politics#1'
r = rq.get(url)
html = r.text
bs = BeautifulSoup(html,'lxml')
# lines = bs.select('body > div > main > section > div.main-sub > div > ul > li:nth-child(1) > strong > a')
lines = bs.select('body > div > main > section > div.main-sub > div > ul > li > strong > a')
body = '\n'.join([line.text for line in lines])
print(body)
body
# Out:
# 금융위기 때 부실 금융사도 지원했으면서…피해 세입자는 왜?
# 여야, 엇갈린 방미 평가...'전세 사기 특별법' 본격 논의
# 내일 윤리위 첫 회의, 김재원 '5·18 이전 징계' 무게  [시사스페셜]
# 30대 퇴직금 평균 1180만원…전체 평균의 79% 수준
# 박광온 `통합` 내세웠지만… 민주당 계파결집 갈수록 심화
# 적과 아군 뿐인 ‘치명적’ 윤석열 외교…북·중·러 반발 거세진다
# 檢, 송영길 금품살포 공범 영장 적시…"지시 여부 확인할 것"
# 돈봉투·쇄신·개딸… 野 새 원내사령탑 과제 산적
# 북한, 연일 '워싱턴 선언' 비난…릴레이 도발 나서나
# 與, 윤리위·노동개혁특위 본격 가동
# '금융위기 때 부실 금융사도 지원했으면서…피해 세입자는 왜?\n여야, 엇갈린 방미 평가...\'전세 사기 특별법\' 본격 논의\n내일 윤리위 첫 회의, 김재원 \'5·18 이전 징계\' 무게  [시사스페셜]\n30대 퇴직금 평균 1180만원…전체 평균의 79% 수준\n박광온 `통합` 내세웠지만… 민주당 계파결집 갈수록 심화\n적과 아군 뿐인 ‘치명적’ 윤석열 외교…북·중·러 반발 거세진다\n檢, 송영길 금품살포 공범 영장 적시…"지시 여부 확인할 것"\n돈봉투·쇄신·개딸… 野 새 원내사령탑 과제 산적\n북한, 연일 \'워싱턴 선언\' 비난…릴레이 도발 나서나\n與, 윤리위·노동개혁특위 본격 가동'

# %%
texts = re.findall('[가-힣0-9]+',body)
print(' '.join(texts))
# Out:
# 금융위기 때 부실 금융사도 지원했으면서 피해 세입자는 왜 여야 엇갈린 방미 평가 전세 사기 특별법 본격 논의 내일 윤리위 첫 회의 김재원 5 18 이전 징계 무게 시사스페셜 30대 퇴직금 평균 1180만원 전체 평균의 79 수준 박광온 통합 내세웠지만 민주당 계파결집 갈수록 심화 적과 아군 뿐인 치명적 윤석열 외교 북 중 러 반발 거세진다 송영길 금품살포 공범 영장 적시 지시 여부 확인할 것 돈봉투 쇄신 개딸 새 원내사령탑 과제 산적 북한 연일 워싱턴 선언 비난 릴레이 도발 나서나 윤리위 노동개혁특위 본격 가동

# %%
import requests as rq
from bs4 import BeautifulSoup

url = 'https://news.daum.net/politics#1'
r = rq.get(url)
html = r.text
bs = BeautifulSoup(html,'lxml')
lines = bs.select('body > div > main > section > div > div > ul > li > strong > a')
for line in lines:
    print(line.text)
# Out:
# 금융위기 때 부실 금융사도 지원했으면서…피해 세입자는 왜?
# 여야, 엇갈린 방미 평가...'전세 사기 특별법' 본격 논의
# 내일 윤리위 첫 회의, 김재원 '5·18 이전 징계' 무게  [시사스페셜]
# 30대 퇴직금 평균 1180만원…전체 평균의 79% 수준
# 박광온 `통합` 내세웠지만… 민주당 계파결집 갈수록 심화
# 적과 아군 뿐인 ‘치명적’ 윤석열 외교…북·중·러 반발 거세진다
# 檢, 송영길 금품살포 공범 영장 적시…"지시 여부 확인할 것"
# 돈봉투·쇄신·개딸… 野 새 원내사령탑 과제 산적
# 북한, 연일 '워싱턴 선언' 비난…릴레이 도발 나서나
# 與, 윤리위·노동개혁특위 본격 가동

# %% [markdown]
# #### 크롤링) 접속 차단되었을때 User-Agent지정(header)
# https://m.blog.naver.com/PostView.naver?isHttpsRedirect=true&blogId=kiddwannabe&logNo=221185808375

# %%
from bs4 import BeautifulSoup
import requests

headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
url = "https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=102" # 네이버 뉴스 사회면 메인 페이지
req = requests.get(url, headers=headers)   # GET방식으로 서비스 호출
soup = BeautifulSoup(req.content, "html.parser")
print(soup)
# Out:
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh">
# <meta content="width=1106" name="viewport">
# <meta content="사회 : 네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image">
# <meta content="교육, 언론, 의료, 인물, 사건사고 등 사회 분야 뉴스 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author">
# <meta content="summary" name="twitter:card"/>
# <meta content="사회 : 네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
# <meta content="교육, 언론, 의료, 인물, 사건사고 등 사회 분야 뉴스 제공" name="twitter:description"/>
# <title>사회 홈 : 네이버 뉴스	</title>
# <link href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/news.css" rel="stylesheet" type="text/css"/>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jindo.js" type="text/javascript"></script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jquery.js" type="text/javascript"></script>
# <script type="text/javascript">
# var _MAIN_NEWS_MENU_ID='shm';
# var _MAIN_NEWS_SECTION_ID='103';
# var ccsrv='cc.naver.com';
# var g_ssc='news.sec';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness = 3;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
#
# var gnb_timestamp = "Sun Apr 30 19:45:47 KST 2023";
# </script>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.service.js" type="text/javascript"></script>
# <script>
#
#     var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#     if (!isUnderIE10) {
#         var gladSDK = document.createElement("script");
#         gladSDK.async = true;
#         gladSDK.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#         document.head.appendChild(gladSDK);
#     }
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#
#     window.gladsdk.cmd.push(function () {
#         window.gladsdk.setGlobalConfig({enablePersistAd: true});
#         window.gladsdk.setHostMeta('theme', 'system');
#
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newsend',
#             adSlotElementId: 'glad_ad_newsend'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newslist',
#             adSlotElementId: 'glad_ad_newslist'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_sidebox',
#             adSlotElementId: 'glad_ad_sidebox'
#         });
#     })
# </script>
# </meta></meta></meta></meta></head>
# <body>
# <div id="wrap">
# <!-- 광고적용 태그 추가 -->
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
# <li><span class="snb_bdr"></span><a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">스포츠</a></li>
# <li><span class="snb_bdr"></span><a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">날씨</a></li>
# <li><span class="snb_bdr"></span><a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">프리미엄</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_both">
# <div class="lnb_left">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li><a class="nclicks(lnb.pcmedia)" href="/"><span class="tx">언론사별</span> </a></li>
# <li><a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> </a></li>
# <li><a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
# <li class="on"><a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹</span> </a></li>
# <li><a class="nclicks(lnb.paper)" href="/newspaper/home"><span class="tx">신문보기</span> </a></li>
# <li><a class="nclicks(lnb.opi)" href="/opinion/home"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(lnb.fact)" href="/main/factcheck/main.naver"><span class="tx">팩트체크</span> </a></li>
# </ul>
# </div>
# </div>
# <div class="lnb_right">
# <div class="lnb_extra">
# <div class="lnb_extra_menu">
# <ul class="lnb_extra_menu_list">
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(STA.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb">
# <span class="lnb_date"><strong>04</strong>.<strong>30</strong><span class="day">(일)</span></span>
# <ul class="lnb_side" tabindex="0">
# <li><a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li><a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li><a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# <hr/>
# <table cellpadding="0" cellspacing="0" class="container">
# <caption class="blind">기사목록</caption>
# <colgroup>
# <col class="col_snb"/>
# <col class="col_content"/>
# <col class="col_aside"/>
# </colgroup>
# <tr>
# <td class="snb">
# <div class="snb" id="snb">
# <h2 class="h4"><a class="nclicks(lmn_soc.home)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102">사회</a></h2>
# <ul class="nav">
# <li><a class="snb_s26 nclicks(lmn_soc.mnl,,1)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=249">사건사고 </a></li>
# <li><a class="snb_s27 nclicks(lmn_soc.mnl,,2)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=250">교육 </a></li>
# <li><a class="snb_s28 nclicks(lmn_soc.mnl,,3)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=251">노동 </a></li>
# <li><a class="snb_s29 nclicks(lmn_soc.mnl,,4)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=254">언론 </a></li>
# <li><a class="snb_s30 nclicks(lmn_soc.mnl,,5)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=252">환경 </a></li>
# <li><a class="snb_s31 nclicks(lmn_soc.mnl,,6)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=59b">인권/복지 </a></li>
# <li><a class="snb_s32 nclicks(lmn_soc.mnl,,7)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=255">식품/의료 </a></li>
# <li><a class="snb_s90 nclicks(lmn_soc.mnl,,8)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=256">지역 </a></li>
# <li><a class="snb_s104 nclicks(lmn_soc.mnl,,9)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=276">인물 </a></li>
# <li><a class="snb_s33 nclicks(lmn_soc.mnl,,10)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=257">사회 일반 </a></li>
# </ul>
# <div class="snb_banner">
# <a class="nclicks(lmn_soc.pmb,,1)" href="https://media.naver.com/channel/setting?back=main"><img alt="언론사 구독하기" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/01/14/142956425_144518244_%2525B8%2525F0%2525B9%2525D9%2525C0%2525CF%2525B8%2525DE%2525C0%2525CE.png" width="71"/></a>
# </div>
# <div class="snb_banner">
# <a class="nclicks(lmn_soc.pmb,,1)" href="https://contents.premium.naver.com/"><img alt="네이버 프리미엄콘텐츠" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71"/></a>
# </div>
# </div>
# </td>
# <td class="content">
# <div class="content" id="main_content">
# <div class="list_body section_index">
# <div class="cluster">
# <div class="cluster_title">
# <span class="cluster_title_inner"><a class="cluster_title_icon_link _news_cluster_layer_btn" href="#biF7L"><i class="cluster_title_icon">안내</i>헤드라인 뉴스</a></span>
# <div class="cluster_title_layer _news_cluster_layer is_hidden">
# <div class="cluster_title_layer_text">
#                             헤드라인 뉴스와 각 기사묶음 타이틀은 <br/> 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.
#                         </div>
# <div class="cluster_title_layer_image"></div>
# <button class="cluster_title_layer_close _news_cluster_layer_close_btn" type="button">닫기</button>
# </div>
# </div>
# </div>
# <div class="_persist">
# <div class="cluster">
# <div class="cluster_group _cluster_content">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202304300910_00000006&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=025&amp;aid=0003276844"><span class="cluster_head_more_icon_num">39</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202304300910_00000006&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=025&amp;aid=0003276844">
# <span class="cluster_head_sub_topic">4년제 대학 평균등록금 679만5200원 </span><span class="cluster_head_sub_topic">올해 17곳 인상 </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/025/0003276844?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/025/2023/04/30/3276844.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/025/0003276844?sid=102">등록금 인상 17곳 중 8곳이 ‘교대’…정원 감축에 “더 오를수도”</a>
# <div class="cluster_text_lede">올해 등록금을 올린 4년제 대학 17곳 중에 8곳이 교육대학인 것으로 나타났다. 전국 10개 교대 중 서울·공주교대를 제외하고 모두 등록금을 올렸다. 정 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news025,0003276844',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">중앙일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news119,0002708072',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">데일리안</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/119/0002708072?sid=102">전국 4년제 대학 17개교 등록금 인상…평균 680만원</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news014,0005004987',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">파이낸셜뉴스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/014/0005004987?sid=102">4년제 대학 평균 등록금 679만원… 91% 동결·인하</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news079,0003764975',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">노컷뉴스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/079/0003764975?sid=102">4년제 대학 17곳 올해 등록금 인상…전문대 18곳도 인상</a>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202304300910_00000010&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=009&amp;aid=0005123843"><span class="cluster_head_more_icon_num">24</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202304300910_00000010&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=009&amp;aid=0005123843">
# <span class="cluster_head_sub_topic">대법 보훈대상자 아냐 </span><span class="cluster_head_sub_topic">軍병원 수술중 숨진 군인 </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/009/0005123843?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/009/2023/04/30/5123843.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/009/0005123843?sid=102">軍병원서 수술하다 죽은 군인…대법 “보훈대상자 아냐” 왜?</a>
# <div class="cluster_text_lede">군병원에서 수술을 받고 회복하던 중 사망한 군인에 대해 보훈보상 대상자로 인정할 수 없다는 대법원 판단이 나와 관심이 쏠린다. 대법원 1부(주심 노태악  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news009,0005123843',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">매일경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news214,0001269764',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">MBC</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269764?sid=102">대법 "군 병원에서 수술받다 숨진 군인, 보훈 대상자 인정 안돼"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011832377',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/003/0011832377?sid=102">軍야유회 숙소 복귀하다 추락→수술 중 사망…대법 "보훈대상자 아냐"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006778436',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/421/0006778436?sid=102">귀가 중 추락해 치료 받다 숨진 군인…대법 "보훈보상대상 아냐"</a>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202304301010_00000004&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=003&amp;aid=0011832432"><span class="cluster_head_more_icon_num">11</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202304301010_00000004&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=003&amp;aid=0011832432">
# <span class="cluster_head_sub_topic">민원 처리 불만 </span><span class="cluster_head_sub_topic">안되자 몸에 휘발유 붓고 공무원 위협한 60대 집행유예 </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/003/0011832432?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/04/30/11832432.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/003/0011832432?sid=102">민원 처리 안되자 공무원 앞서 분신시도한 사슴농장주 집유</a>
# <div class="cluster_text_lede">기사내용 요약 재판부 '특수공무집행방해치상'→'특수공무집행방해' 판단 "사안 중대하지만 당사자 잘못 반성, 피해자 6명 중 4명이 처벌 불원" [청주=뉴 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011832432',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news655,0000009594',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">CJB청주방송</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/655/0000009594?sid=102">민원처리 안되자 몸에 휘발유 붓고 공무원 위협한 60대 집행유예</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news015,0004839223',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">한국경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/015/0004839223?sid=102">"공무원이 내 말 안 들어"…휘발유 끼얹고 '분신 시도'한 60대</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news629,0000214525',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">더팩트</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/629/0000214525?sid=102">공무원 민원 처리에 불만 품고 분신 시도한 60대 '집행유예 2년'</a>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202304271550_00000069&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=119&amp;aid=0002707991"><span class="cluster_head_more_icon_num">16</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202304271550_00000069&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=119&amp;aid=0002707991">
# <span class="cluster_head_sub_topic">이태원 참사 6개월 </span><span class="cluster_head_sub_topic">"정쟁 멈추고 특별법 제정하라" </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/119/0002707991?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/119/2023/04/29/2707991.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/119/0002707991?sid=102">이태원참사 6개월…유족 "국회는 정쟁 멈추고 특별법 제정해야"</a>
# <div class="cluster_text_lede">이태원 참사가 발생한 지 6개월 되는 날인 29일 유족과 시민단체가 진상규명을 위한 특별법 제정을 거듭 촉구했다. 복수의 언론보도에 따르면 10·29 이 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news119,0002707991',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">데일리안</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news629,0000214445',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">더팩트</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/629/0000214445?sid=102">이태원 참사 유가족들, 빗속 1인 시위 "특별법 제정 촉구"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011831967',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/003/0011831967?sid=102">이태원 참사 유가족들, 빗속 1인 시위…"정쟁 멈추고 특별법 제정을"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news032,0003220587',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">경향신문</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/032/0003220587?sid=102">이태원 참사 6개월, 책임지고 물러난 고위공직자는 없었다</a>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202304291640_00000016&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=001&amp;aid=0013912186"><span class="cluster_head_more_icon_num">58</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202304291640_00000016&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=001&amp;aid=0013912186">
# <span class="cluster_head_sub_topic">"간호법 반대" 단식 6일째 간호조무사협회장 </span><span class="cluster_head_sub_topic">의사·간호조무사 "총파업 강행" </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/001/0013912186?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2023/04/29/13912186.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/001/0013912186?sid=102">돌봄종사자 만난 복지장관 "간호법은 최적 대안 아냐"</a>
# <div class="cluster_text_lede">조규홍 보건복지부 장관이 간호법의 국회 본회의 통과 후 서비스 점검차 장기요양 시설을 방문한 자리에서 "간호법이 최적의 대안이 아니다"고 재차 강조했다. …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013912186',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/003/0011832816?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/04/30/11832816.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/003/0011832816?sid=102">'간호법 반발' 간호조무사 협회장, 단식 탈진…119 후송</a>
# <div class="cluster_text_lede">기사내용 요약 단식 농성장 찾은 복지부 장관 설득에 병원가서 검사 받기로 [서울=뉴간호법 국회 본회의 통과에 반발해 단식 투쟁에 들어간 곽지연 대한간호조 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011832816',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202304291350_00000200&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=008&amp;aid=0004881588"><span class="cluster_head_more_icon_num">68</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202304291350_00000200&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=008&amp;aid=0004881588">
# <span class="cluster_head_sub_topic">최고 사형 구형 </span><span class="cluster_head_sub_topic">청소년 대상 마약범죄 엄단 </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/008/0004881588?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/008/2023/04/30/4881588.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/008/0004881588?sid=102">"숙소 제공" 가출 여학생 유혹…마약 덫 놓는 어른들 "최대 사형 구형"</a>
# <div class="cluster_text_lede">#15세 A양은 친구의 아버지인 40대 남성이 준 아이스크림을 먹고 잠이들었다. 아이스크림에는 졸피뎀이 들어있었다. 남성은 잠든 A양을 성폭행하고 사진을 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news008,0004881588',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">머니투데이</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/057/0001739181?sid=102">※검찰 "청소년에게 마약 공급하면 최고 사형 구형"</a>
# <div class="cluster_text_lede">최근 학원가에서 마약이 든 음료수를 학생들에게 주는 사건이 벌어지는 등 청소년에게까지 마약이 침투하자 검찰이 강경 대응을 예고했습니다. 대검찰청은 "청소년에 대한 마약공급이나 청소년을 이용한 마약유통, 청소 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news057,0001739181',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">MBN</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202304301540_00000006&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=003&amp;aid=0011832820"><span class="cluster_head_more_icon_num">25</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202304301540_00000006&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=003&amp;aid=0011832820">
# <span class="cluster_head_sub_topic">"징역 10개월" 확정 </span><span class="cluster_head_sub_topic">강제추행 B.A.P 힘찬 </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/003/0011832820?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/04/30/11832820.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/003/0011832820?sid=102">아이돌 'B.A.P' 출신 힘찬, 강제추행 혐의로 실형 확정</a>
# <div class="cluster_text_lede">기사내용 요약 펜션서 20대 여성 강제추행한 혐의 대법 유죄 판단…징역 10개월 확정 [서울=뉴펜션에서 여성을 강제추행한 혐의로 재판에 넘겨진 그룹 '비 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011832820',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/422/0000596395?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/422/2023/04/30/596395.jpg?type=nf132_90" width="132"/>
# <strong class="r_ico r_vod_medium">동영상기사</strong>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/422/0000596395?sid=102">'강제추행' B.A.P 힘찬, 징역 10개월 확정</a>
# <div class="cluster_text_lede">강제추행 혐의로 기소된 아이돌그룹 비에이피(B.A.P) 출신의 힘찬에 대한 실형이 확정됐습니다. 힘찬 측은 징역 10개월과 함께 법정구속한 2심 재판부의 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news422,0000596395',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스TV</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202304300830_00000008&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=003&amp;aid=0011832446"><span class="cluster_head_more_icon_num">13</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202304300830_00000008&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=003&amp;aid=0011832446">
# <span class="cluster_head_sub_topic">러시아인 난민신청 1분기에만 1056건 </span><span class="cluster_head_sub_topic">지난해 1년치 넘겨 </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/003/0011832446?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/04/30/11832446.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/003/0011832446?sid=102">올해 1분기 러시아인 난민 신청 지난해 전체건수 넘어</a>
# <div class="cluster_text_lede">기사내용 요약 1~3월 러시아인 난민 신청 1056명으로 전체 26% 총 불법체류자 41만명…전체 체류 외국인 17% [서울=뉴2023년 상반기 러시아인 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011832446',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/422/0000596382?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/422/2023/04/30/596382.jpg?type=nf132_90" width="132"/>
# <strong class="r_ico r_vod_medium">동영상기사</strong>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/422/0000596382?sid=102">러시아인 난민 신청 1분기 1,056건…1년치 넘어</a>
# <div class="cluster_text_lede">올해 1분기 러시아인 난민 신청이 지난해 1년치보다 많은 것으로 집계됐습니다. 법무부는 올해 들어 3월까지 접수된 난민 신청 건수가 4,057건이며 이  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news422,0000596382',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스TV</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202304301210_00000020&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=009&amp;aid=0005123831"><span class="cluster_head_more_icon_num">23</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202304301210_00000020&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=009&amp;aid=0005123831">
# <span class="cluster_head_sub_topic">직장인 "3대 갑질" 괴롭힘·야근·징계 </span><span class="cluster_head_sub_topic">제보자 61% 차지 </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/009/0005123831?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/009/2023/04/30/5123831.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/009/0005123831?sid=102">“직장 다니는게 지옥”...괴롭힘 신고해도 돌아오는건 괴롭힘뿐</a>
# <div class="cluster_text_lede">직장갑질119, 제보 607건 분석 신고해도 무시하거나 보복하기도 “노동법 위반 특별근로감독해야” 5월1일 노동절 133주년을 앞두고 직장인들이 여전히  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news009,0005123831',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">매일경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/422/0000596371?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/422/2023/04/30/596371.jpg?type=nf132_90" width="132"/>
# <strong class="r_ico r_vod_medium">동영상기사</strong>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/422/0000596371?sid=102">직장갑질119 "제보자 61％ 직장 내 괴롭힘 호소"</a>
# <div class="cluster_text_lede">시민단체 직장갑질119는 올해 지난 26일까지 받은 이메일 제보 중 직장 내 괴롭힘 피해 호소가 전체의 61.3%에 달했다고 밝혔습니다. 구체적 유형으로 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news422,0000596371',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스TV</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202304241500_00000441&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=018&amp;aid=0005475921"><span class="cluster_head_more_icon_num">33</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202304241500_00000441&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=018&amp;aid=0005475921">
# <span class="cluster_head_sub_topic">故 서세원 유해 </span><span class="cluster_head_sub_topic">故서세원 영결식 사회는 김학래 </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/018/0005475921?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/018/2023/04/30/5475921.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/018/0005475921?sid=102">이철우 경북지사, 故 서세원 아산병원 빈소 방문 “안타깝다”</a>
# <div class="cluster_text_lede">코미디언 고(故) 서세원씨(왼쪽)와 이철우 경북도지사 (사진=이철우 경북도지사 페이스북) 이철우 경북도지사가 30일 서울 송파구 아산병원에 마련된 코미디 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news018,0005475921',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">이데일리</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879312?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/052/2023/04/30/1879312.jpg?type=nf132_90" width="132"/>
# <strong class="r_ico r_vod_medium">동영상기사</strong>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879312?sid=102">故 서세원 국내 빈소 마련...코미디언협회장으로 엄수</a>
# <div class="cluster_text_lede">최근 캄보디아에서 세상을 떠난 방송인 서세원 씨의 유골이 한국으로 송환돼 오늘(30일)부터 국내 장례 절차가 시작됐습니다. 서 씨의 빈소는 서울아산병원  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879312',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202304291040_00000008&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=052&amp;aid=0001879263"><span class="cluster_head_more_icon_num">102</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202304291040_00000008&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=052&amp;aid=0001879263">
# <span class="cluster_head_sub_topic">검찰 "돈봉투 의혹" 송영길 압수수색 </span><span class="cluster_head_sub_topic">檢 宋 직접 자금 조달 가능성 수사 </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879263?sid=102">검찰 "송영길 후원조직, 캠프 자금 조달·보관 의심"</a>
# <div class="cluster_text_lede">더불어민주당의 재작년 전당대회 돈 봉투 의혹을 수사하는 검찰은 송영길 전 대표의 후원조직이 캠프 자금 조달 창구 역할을 했던 것으로 의심하고 압수물 분석에 주력하고 있습니다. 서울중앙지검 반부패수사2부는 송 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879263',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269686?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/214/2023/04/29/1269686.jpg?type=nf132_90" width="132"/>
# <strong class="r_ico r_vod_medium">동영상기사</strong>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269686?sid=102">돈봉투 의혹 송영길 압수수색‥당대표 일정·회계자료 확보</a>
# <div class="cluster_text_lede">◀ 앵커 ▶ 더불어민주당 전당대회 돈봉투 의혹을 수사하고 있는 검찰이 오늘 의혹의 정점에 있는 송영길 전 대표를 전격 압수수색했습니다. 송 전 대표가 프 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news214,0001269686',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">MBC</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202304260510_00001305&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=056&amp;aid=0011475530"><span class="cluster_head_more_icon_num">12</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202304260510_00001305&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=056&amp;aid=0011475530">
# <span class="cluster_head_sub_topic">지난해보다 4.25% 하락 </span><span class="cluster_head_sub_topic">인천시 개별주택 가격 공시 </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/056/0011475530?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/056/2023/04/29/11475530.jpg?type=nf132_90" width="132"/>
# <strong class="r_ico r_vod_medium">동영상기사</strong>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/056/0011475530?sid=102">경남 개별주택 공시가격 평균 4% 내려…거제 5.4%↓</a>
# <div class="cluster_text_lede">경남의 올해 개별주택 공시가격이 지난해보다 평균 4.01% 내린 것으로 나타났습니다. 지역별로는 거제가 5.44%가 떨어져 경남에서 하락 폭이 가장 크고 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news056,0011475530',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">KBS</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/003/0011832398?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/04/30/11832398.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/003/0011832398?sid=102">인천시, 개별주택 가격 공시…지난해보다 4.25% 하락</a>
# <div class="cluster_text_lede">인천시는 개별주택 가격을 군·구별로 결정·공시한다고 30일 밝혔다. ‘개별주택가격’은 재산세·종합부동산세 등 각종 국세 및 지방세의 과세표준으로 활용되는 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011832398',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202304301120_00000002&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=029&amp;aid=0002797766"><span class="cluster_head_more_icon_num">12</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202304301120_00000002&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=029&amp;aid=0002797766">
# <span class="cluster_head_sub_topic">서울시 청년월세 대상자 모집 </span><span class="cluster_head_sub_topic">"매월 최대 20만원 지원" </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/029/0002797766?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/029/2023/04/30/2797766.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/029/0002797766?sid=102">서울시 "월 20만원 `청년월세` 지원 받으세요"</a>
# <div class="cluster_text_lede">5월 3일~16일 접수 서울시는 오는 3일부터 16일까지 청년들의 주거비 부담을 줄이기 위한 '청년월세 지원사업' 신청자를 접수 받는다고 30일 밝혔다. …</div>
# ...
# </div>
# </div>
# </div>
# </li>
# </ul>
# <ul class="section_list_ranking_press _rankingList" id="_rankingList75" style="display: none">
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/659/0000011132?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/659/2023/04/30/11132.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/659/0000011132?ntype=RANKING&amp;sid=001">새만금잼버리 현장 점검.."텐트 치기 부적합"</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=659"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/659/2022/01/19/logo_659_56_20220119141438.png" width="16"/></span>전주MBC</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/655/0000009592?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/655/2023/04/30/9592.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/655/0000009592?ntype=RANKING&amp;sid=001">30대 다문화여성 4살 아들 살해하고 경찰에 자수</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=655"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/655/2022/01/20/logo_655_56_20220120164501.png" width="16"/></span>CJB청주방송</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/665/0000000878?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/665/2023/04/30/878.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/665/0000000878?ntype=RANKING&amp;sid=001">김포골드라인 리버버스, 실패작 수상택시 16년 만의 오버랩 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=665"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/665/2022/12/08/logo_665_56_20221208184224.png" width="16"/></span>더스쿠프</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/353/0000044809?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/353/2023/04/29/44809.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/353/0000044809?ntype=RANKING&amp;sid=001">4년 만에 만나는 황매산 철쭉</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=353"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/353/2018/09/20/logo_353_56_20180920154420.png" width="16"/></span>중앙SUNDAY</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018622?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/145/2023/04/30/18622.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018622?ntype=RANKING&amp;sid=001">순천만국가정원, 미디어아트 더한다</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=145"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/145/2020/12/09/logo_145_56_20201209180915.png" width="16"/></span>레이디경향</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <button class="refresh_button nclicks('rig.renws2new') _refreshButton" type="button">더보기</button>
# </div>
# <script type="text/javascript">
#     var OfficeTopRankingManager = jindo.$Class({
#         $static: {
#             RANKING_INFO_BUTTON_SELECTOR: '._rankingInfoButton',
#             RANKING_INFO_LAYER_SELECTOR : '._rankingInfoLayer',
#             RANKING_INFO_BUTTON_CLOSE_SELECTOR : '._rankingInfoCloseButton',
#             REFRESH_BUTTON_SELECTOR : '._refreshButton',
#             RANKING_LIST_SELECTOR : '._rankingList'
#         },
#
#         $init: function(base) {
#             this._welBase = jindo.$Element(base);
#             this._rankingInfoLayer = jindo.$Element(this._welBase.query(this.constructor.RANKING_INFO_LAYER_SELECTOR));
#             this._rankingListArray = jindo.$ElementList(this._welBase.queryAll(this.constructor.RANKING_LIST_SELECTOR));
#
#             this._initEvent();
#         },
#
#         _initEvent: function() {
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_SELECTOR, jindo.$Fn(this._showRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_CLOSE_SELECTOR, jindo.$Fn(this._closeRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.REFRESH_BUTTON_SELECTOR, jindo.$Fn(this._refreshRankingList, this).bind());
#         },
#
#         _showRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.toggle();
#         },
#
#         _closeRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.hide();
#         },
#
#         _refreshRankingList: function(event) {
#             event.stopDefault();
#
#             for (var i=0 ; i<this._rankingListArray.length() ; i++) {
#                 var rankingList = this._rankingListArray.get(i);
#
#                 if (rankingList.visible() === true) {
#                     var nextIndex = i + 1;
#
#                     if (nextIndex === this._rankingListArray.length()) {
#                         nextIndex = 0;
#                     }
#
#                     var nextRankingList = this._rankingListArray.get(nextIndex);
#
#                     rankingList.hide();
#                     nextRankingList.show();
#
#                     break;
#                 }
#             }
#         }
#     });
#
#     window.addEventListener("load", function() {
#         var officeTopRanking = jindo.$$.getSingle("._officeTopRanking1087475");
#         if (officeTopRanking) {
#             new OfficeTopRankingManager(officeTopRanking);
#         }
#     });
# </script>
# <div class="side_ad" id="glad_ad_sidebox"></div>
# <div class="section" id="right_dailyList" style="margin-bottom:20px; white-space:nowrap;">
# <h4>분야별 주요뉴스</h4>
# <div class="classfy sd" style="display:block">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/079/0003765061?sid=100" title="김건희 여사 귀국길 기내서 기자단과 '깜짝인사', '셀카'도">김건희 여사 귀국길 기내서 기자단과 '깜짝인사', '셀카'도</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/119/0002708124?sid=100" title="개딸들 망동…이재명이 박광온 직접 감싸도 안 통한다">개딸들 망동…이재명이 박광온 직접 감싸도 안 통한다</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/032/0003220593?sid=100" title="박지원 “바이든 ‘아메리칸 파이’ 듀엣 준비”···대통령실 “반국가적 작태”">박지원 “바이든 ‘아메리칸 파이’ 듀엣 준비”···대통령실 “반국가적 작태”</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/025/0003276849?sid=104" title="'2라운드' 접어든 尹 가치외교…&quot;기시다 답방이 3국 공조 초석&quot;">'2라운드' 접어든 尹 가치외교…"기시다 답방이 3국 공조 초석"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/025/0003276867?sid=104" title='"바이든, 왕실 무시한다" 찰스 대관식 앞둔 英 발끈한 이유'>"바이든, 왕실 무시한다" 찰스 대관식 앞둔 英 발끈한 이유</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/422/0000596394?sid=101" title="'한국판 버핏과의 점심' 1호는 정의선 현대차 회장">'한국판 버핏과의 점심' 1호는 정의선 현대차 회장</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/092/0002290711?sid=101" title='"약 다운 약을 우리 손으로”…이종호 JW그룹 명예회장 별세'>"약 다운 약을 우리 손으로”…이종호 JW그룹 명예회장 별세</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011833040?sid=101" title="'첨단기술동맹' 확대·8조 세일즈외교…반도체·IRA 해법 과제 [尹방미 결산]">'첨단기술동맹' 확대·8조 세일즈외교…반도체·IRA 해법 과제 [尹방미 결산]</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/014/0005004887?sid=105" title="과기정통부, NIA와 AI 학습용 데이터 개방한다">과기정통부, NIA와 AI 학습용 데이터 개방한다</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/018/0005475735?sid=105" title="“기지국 데이터로 감염병 관리”…KT, 게이츠재단 연구성과 공개">“기지국 데이터로 감염병 관리”…KT, 게이츠재단 연구성과 공개</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/028/0002637947?sid=102" title="의사·간호조무사 ‘총파업’으로 윤 대통령 압박한다지만…“글쎄”">의사·간호조무사 ‘총파업’으로 윤 대통령 압박한다지만…“글쎄”</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/448/0000407019?sid=102" title='검찰 "청소년에 마약 공급하면 최고 사형 구형"'>검찰 "청소년에 마약 공급하면 최고 사형 구형"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/001/0013913364?sid=102" title="생후 40일 아들 떨어뜨리고 방치해 사망…20대 친모 구속">생후 40일 아들 떨어뜨리고 방치해 사망…20대 친모 구속</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/277/0005252829?sid=103" title="문체부 '한미 문화동맹 TF' 구성…&quot;정상외교 키워드는 'K-컬처'&quot;">문체부 '한미 문화동맹 TF' 구성…"정상외교 키워드는 'K-컬처'"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011833007?sid=103" title="노동절 낮 최고 24도 포근…큰 일교차 주의[내일날씨]">노동절 낮 최고 24도 포근…큰 일교차 주의[내일날씨]</a> </li>
# </ul>
# </ul>
# </ul>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://media.naver.com/channel/settings"> <img alt="네이버 메인에서 바로 보는 언론사 편집뉴스 지금 바로 구독해보세요!" src="https://imgnews.pstatic.net/image/upload/item/2018/11/27/175025584_PC_%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA_%25B1%25B8%25B5%25B6%25C8%25B0%25BC%25BA%25C8%25AD.png" width="300"> </img></a>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" target="_blank"> <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/183254054_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300"> </img></a>
# </div>
# </div>
# <div class="section">
# <h4> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"> 서비스 안내 </a> </h4>
# <ul class="list_txt">
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb"> 고침 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb"> 정정·반론·추후 보도 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb"> 불공정 선거 보도 기사 모음 </a> </li>
# </ul>
# <a class="more_link nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"><span class="blind">서비스 안내</span>더보기</a>
# </div>
# <script>
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#
#         adSlot.setCustomParam("calp", 'shome');
#         window.gladsdk.displayAd(adSlot);
#     });
# </script>
# </div>
# </td>
# </tr>
# </table>
# </div>
# <hr/>
# <div class="index">
# <div class="index_inner">
# <div class="floating_btn">
# <div class="floating_inner">
# <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
# <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
# </div>
# </div>
# <div class="index_tab" id="index.press_category">
# <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content is_hidden" id="index.press.area"></div>
# <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content02 is_hidden" id="index.category.area"></div>
# </div>
# </div>
# </div>
# <hr/>
# <div id="footer">
# <ul>
# <li class="first"><a class="nclicks(fot.agreement)" href="http://www.naver.com/rules/service.html">이용약관</a></li>
# <li><a class="nclicks(fot.guide)" href="/main/ombudsman/index.naver">서비스 안내</a></li>
# <li><a class="nclicks(fot.editor)" href="/main/ombudsman/edit.naver?mid=omb">기사배열 원칙 책임자 : 유봉석</a></li>
# <li>청소년 보호 책임자 : 이희만</li>
# <li><strong><a class="nclicks(fot.privacy)" href="http://www.naver.com/rules/privacy.html">개인정보처리방침</a></strong></li>
# <li><a class="nclicks(fot.disclaimer)" href="http://www.naver.com/rules/disclaimer.html">책임의 한계와 법적고지</a></li>
# <li><a class="nclicks(fot.help)" href="#" onclick="news.external.OPS.helpNews(); return false;" title="새창">뉴스 고객센터</a></li>
# </ul>
# <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
# <address class="address_nhn">
# <a class="logo nclicks(fot.naver)" href="https://www.navercorp.com/" target="_blank"><span class="blind">NAVER</span></a>
# <em>Copyright ©</em>
# <a class="nclicks(fot.navercorp)" href="https://www.navercorp.com/" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# <!-- -->
# </div>
# <script type="text/javascript">
#
#
#
#
#
#
#
# var index_tab = new news.index.TabController('index.press_category');
# index_tab.add(new news.index.Tab('index.press.btn','stit','index.press.area','/main/ajax/bottomIndex/press.naver'));
# index_tab.add(new news.index.Tab('index.category.btn','stit2','index.category.area','/main/ajax/bottomIndex/category.naver'));
# jindo.$Fn(index_tab.toggle, index_tab).attach(index_tab.tabs.keys(), 'click');
#
#
# (function() {
# 	news.right.RightSideFloatingManager.init();
# })();
#
#
#
#     (function() {
#         news.right.TopDownFloatingManager.init();
#     })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ;(function(){
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jindo.$Fn(function(){
#
#
# 	lcs_do();
#
#     }).attach(window, eventType);
# })();
#
#
#
#
#
#
#
#
# news.startup();
#
#
# jindo.$Fn(function(){
#     var welSkip = jindo.$Element("u_skip");
#     if (welSkip === null) {
#         return;
#     }
#     welSkip.delegate("click", "a", function(weEvent){
#         weEvent.stopDefault();
#         var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#         oWebAccessibilityUtil.moveFocus(elTarget);
#     });
# }).attach(window, "load");
#
#
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
# </body>
# </html>

# %%
target = soup.select_one('#main_content > div > div._persist > div:nth-child(1) > div:nth-child(1) > div.cluster_body > ul > li:nth-child(3) > div > a')
print(target)
print(target.text)
# Out:
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/014/0005004987?sid=102">4년제 대학 평균 등록금 679만원… 91% 동결·인하</a>
# 4년제 대학 평균 등록금 679만원… 91% 동결·인하

# %%
# select_one: 한 개 선택(동일한 태그가 여러 개 있을 경우엔 가장 첫 번째를 선택)
target = soup.select_one("#main_content > div > div._persist > div > div > div.cluster_body > ul > li > div.cluster_text > a")
print(target,'\n')
print(target.text,'\n')
print(target['class'],'\n')
print(target['href'])
# Out:
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/025/0003276844?sid=102">등록금 인상 17곳 중 8곳이 ‘교대’…정원 감축에 “더 오를수도”</a>
#
# 등록금 인상 17곳 중 8곳이 ‘교대’…정원 감축에 “더 오를수도”
#
# ['cluster_text_headline', 'nclicks(cls_nav.clsart)']
#
# https://n.news.naver.com/mnews/article/025/0003276844?sid=102

# %%
# select: 여러 개를 선택 (리스트 형태 - for문을 이용하여 출력)
target = soup.select("#main_content > div > div._persist > div > div > div.cluster_body > ul > li > div.cluster_text > a")
for element in target:
    print(element.text)
    print(element['href'])
# Out:
# 등록금 인상 17곳 중 8곳이 ‘교대’…정원 감축에 “더 오를수도”
# https://n.news.naver.com/mnews/article/025/0003276844?sid=102
# 전국 4년제 대학 17개교 등록금 인상…평균 680만원
# https://n.news.naver.com/mnews/article/119/0002708072?sid=102
# 4년제 대학 평균 등록금 679만원… 91% 동결·인하
# https://n.news.naver.com/mnews/article/014/0005004987?sid=102
# 4년제 대학 17곳 올해 등록금 인상…전문대 18곳도 인상
# https://n.news.naver.com/mnews/article/079/0003764975?sid=102
# 軍병원서 수술하다 죽은 군인…대법 “보훈대상자 아냐” 왜?
# https://n.news.naver.com/mnews/article/009/0005123843?sid=102
# 대법 "군 병원에서 수술받다 숨진 군인, 보훈 대상자 인정 안돼"
# https://n.news.naver.com/mnews/article/214/0001269764?sid=102
# 軍야유회 숙소 복귀하다 추락→수술 중 사망…대법 "보훈대상자 아냐"
# https://n.news.naver.com/mnews/article/003/0011832377?sid=102
# 귀가 중 추락해 치료 받다 숨진 군인…대법 "보훈보상대상 아냐"
# https://n.news.naver.com/mnews/article/421/0006778436?sid=102
# 민원 처리 안되자 공무원 앞서 분신시도한 사슴농장주 집유
# https://n.news.naver.com/mnews/article/003/0011832432?sid=102
# 민원처리 안되자 몸에 휘발유 붓고 공무원 위협한 60대 집행유예
# https://n.news.naver.com/mnews/article/655/0000009594?sid=102
# "공무원이 내 말 안 들어"…휘발유 끼얹고 '분신 시도'한 60대
# https://n.news.naver.com/mnews/article/015/0004839223?sid=102
# 공무원 민원 처리에 불만 품고 분신 시도한 60대 '집행유예 2년'
# https://n.news.naver.com/mnews/article/629/0000214525?sid=102
# 이태원참사 6개월…유족 "국회는 정쟁 멈추고 특별법 제정해야"
# https://n.news.naver.com/mnews/article/119/0002707991?sid=102
# 이태원 참사 유가족들, 빗속 1인 시위 "특별법 제정 촉구"
# https://n.news.naver.com/mnews/article/629/0000214445?sid=102
# 이태원 참사 유가족들, 빗속 1인 시위…"정쟁 멈추고 특별법 제정을"
# https://n.news.naver.com/mnews/article/003/0011831967?sid=102
# 이태원 참사 6개월, 책임지고 물러난 고위공직자는 없었다
# https://n.news.naver.com/mnews/article/032/0003220587?sid=102
# 돌봄종사자 만난 복지장관 "간호법은 최적 대안 아냐"
# https://n.news.naver.com/mnews/article/001/0013912186?sid=102
# '간호법 반발' 간호조무사 협회장, 단식 탈진…119 후송
# https://n.news.naver.com/mnews/article/003/0011832816?sid=102
# "숙소 제공" 가출 여학생 유혹…마약 덫 놓는 어른들 "최대 사형 구형"
# https://n.news.naver.com/mnews/article/008/0004881588?sid=102
# ※검찰 "청소년에게 마약 공급하면 최고 사형 구형"
# https://n.news.naver.com/mnews/article/057/0001739181?sid=102
# 아이돌 'B.A.P' 출신 힘찬, 강제추행 혐의로 실형 확정
# https://n.news.naver.com/mnews/article/003/0011832820?sid=102
# '강제추행' B.A.P 힘찬, 징역 10개월 확정
# https://n.news.naver.com/mnews/article/422/0000596395?sid=102
# 올해 1분기 러시아인 난민 신청 지난해 전체건수 넘어
# https://n.news.naver.com/mnews/article/003/0011832446?sid=102
# 러시아인 난민 신청 1분기 1,056건…1년치 넘어
# https://n.news.naver.com/mnews/article/422/0000596382?sid=102
# “직장 다니는게 지옥”...괴롭힘 신고해도 돌아오는건 괴롭힘뿐
# https://n.news.naver.com/mnews/article/009/0005123831?sid=102
# 직장갑질119 "제보자 61％ 직장 내 괴롭힘 호소"
# https://n.news.naver.com/mnews/article/422/0000596371?sid=102
# 이철우 경북지사, 故 서세원 아산병원 빈소 방문 “안타깝다”
# https://n.news.naver.com/mnews/article/018/0005475921?sid=102
# 故 서세원 국내 빈소 마련...코미디언협회장으로 엄수
# https://n.news.naver.com/mnews/article/052/0001879312?sid=102
# 검찰 "송영길 후원조직, 캠프 자금 조달·보관 의심"
# https://n.news.naver.com/mnews/article/052/0001879263?sid=102
# 돈봉투 의혹 송영길 압수수색‥당대표 일정·회계자료 확보
# https://n.news.naver.com/mnews/article/214/0001269686?sid=102
# 경남 개별주택 공시가격 평균 4% 내려…거제 5.4%↓
# https://n.news.naver.com/mnews/article/056/0011475530?sid=102
# 인천시, 개별주택 가격 공시…지난해보다 4.25% 하락
# https://n.news.naver.com/mnews/article/003/0011832398?sid=102
# 서울시 "월 20만원 `청년월세` 지원 받으세요"
# https://n.news.naver.com/mnews/article/029/0002797766?sid=102
# 서울시, 월 20만원 '청년월세' 2만5000명 모집
# https://n.news.naver.com/mnews/article/629/0000214503?sid=102
# '생후 40일 아들' 숨지게 한 친모 영장실질심사
# https://n.news.naver.com/mnews/article/214/0001269719?sid=102
# “심각한지 몰랐다” 40일 된 아들 숨지게 한 친모 영장
# https://n.news.naver.com/mnews/article/469/0000736839?sid=102
# 필수노동자들 임금 얼마 받나···성동구, 전국 최초로 ‘전수조사’[서울25]
# https://n.news.naver.com/mnews/article/032/0003220548?sid=102
# 성동구, 요양보호사 등 필수노동자 임금실태 전수조사
# https://n.news.naver.com/mnews/article/001/0013913147?sid=102
# 포항시 시정연구원 설립 추진
# https://n.news.naver.com/mnews/article/005/0001604923?sid=102
# 안산미래연구원 설립 본격화… 내년 상반기 개원 목표
# https://n.news.naver.com/mnews/article/016/0002137170?sid=102

# %%
from bs4 import BeautifulSoup
import requests

headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
url = "https://n.news.naver.com/mnews/article/032/0003161880?sid=101" # 네이버 기사 본문 페이지
req = requests.get(url, headers=headers)
soup = BeautifulSoup(req.content, "html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport">
# <meta content="‘7% 할인’ 서울광역상품권 또 풀린다···“출생연도 홀짝수로 구매시간 분리”" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://n.news.naver.com/mnews/article/032/0003161880?sid=101" property="og:url"/>
# <meta content="https://imgnews.pstatic.net/image/032/2022/07/24/0003161880_001_20220724112401144.jpg?type=w800" property="og:image"/>
# <meta content="서울 25개 자치구 어디에서나 쓸 수 있는 ‘서울사랑상품권(광역상품권)’이 오는 28일 추가 발행된다. 1차 발행 때처럼 동시접속자가 몰리는 것을 막기 위해 이번에는 출생연도를 기준으로 홀수는 오전 10시부터, 짝수" property="og:description"/>
# <meta content="경향신문 | 네이버" property="og:article:author"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="‘7% 할인’ 서울광역상품권 또 풀린다···“출생연도 홀짝수로 구매시간 분리”" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="경향신문" name="twitter:creator"/>
# <meta content="https://imgnews.pstatic.net/image/032/2022/07/24/0003161880_001_20220724112401144.jpg?type=w800" name="twitter:image"/>
# <meta content="서울 25개 자치구 어디에서나 쓸 수 있는 ‘서울사랑상품권(광역상품권)’이 오는 28일 추가 발행된다. 1차 발행 때처럼 동시접속자가 몰리는 것을 막기 위해 이번에는 출생연도를 기준으로 홀수는 오전 10시부터, 짝수" name="twitter:description"/>
# <meta content="gdid=8800006B_000000000000000003161880,service=news,collection=news,section=102" name="napp-site-analysis"/>
# <title>‘7% 할인’ 서울광역상품권 또 풀린다···“출생연도 홀짝수로 구매시간 분리”</title>
# <link href="https://static-nnews.pstatic.net/css/min/20230427/news.css" rel="stylesheet"/>
# <link href="https://mimgnews.pstatic.net/image/news/m/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon">
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" rel="apple-touch-icon-precomposed" size="72x72"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" rel="apple-touch-icon-precomposed" size="96x96"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" rel="apple-touch-icon-precomposed" size="144x144"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" rel="apple-touch-icon-precomposed" size="192x192"/>
# <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script>
# <script>
# 			var g_ssc = nsc = "Mnews.v2";
# 			var g_default_area = "art";
#
# 			var svr = "one-service-r-20230427-230427-143655-596967dd69-zn8rw";
# 			var nelo = {
# 				sampleNumber : 100,
# 				maxCount : 100,
# 				maxSendMessage : "로그 전송 최대치 도달"
# 			};
# 			var isGreendot = document.cookie.indexOf("MM_NEW=1") > -1;
# 			var isNewGreendot = document.cookie.indexOf("MM_NEW=2") > -1;
# 			var domain = "https://n.news.naver.com";
# 			var ajaxDomain = "";
# 			var newsDomain = "https://news.naver.com";
# 			var isAvailableDarkMode = false;
#
# 			var article = {
# 				isSubscribe: false,
# 				officeId: "032",
# 				articleId: "0003161880",
# 				sectionId : "102",
# 				gdid: "8800006B_000000000000000003161880",
# 				type: "1",
# 				sectionInfo: {
# 					firstSection: "102",
# 					secondSection: "256",
# 					thirdSection: "000"
# 				},
# 				title: document.title
# 			};
#
#
#
# 			var office = {
# 				isChannel: true,
# 				isPressHome: true,
# 				name : "경향신문",
# 				category : "종합지"
# 			};
#
# 			var refererType = "UNKNOWN";
#
# 			var searchQuery = (function() {
# 				var referrerLink = document.createElement("a");
# 				var emptySearch = "";
#
# 				referrerLink.href = document.referrer || "";
#
# 				if (referrerLink.host.indexOf("search.naver.com") === -1) {
# 					return emptySearch;
# 				}
#
# 				return decodeURIComponent(
# 					(
# 						referrerLink.search.match(/(?:\?|&)query\=([^&]+)/) || [ null, emptySearch ]
# 					)[1].replace(/\+/g, " ")
# 				);
# 			})();
#
# 			var divIds = [];
# 			var syncDivIds = [];
# 			var syncDivIdsForNonArticle = [];
#
# 			var unitIds = [];
# 			var syncUnitIds = [];
# 			var syncUnitIdsForNonArticle = [];
#
# 			window.gladsdk = window.gladsdk || { cmd: [] };
# 			gladsdk.cmd.push(function() {
# 				gladsdk.setAdDeduplication("article_body_dedup");
# 				gladsdk.setGlobalConfig({ enablePersistAd: true });
#
# 				var adInfoList = [];
#
# 				adInfoList.push({
# 					seq: 1,
# 					unitId: "p_news_newsend",
# 					sync: false,
# 					mobileOnly: false,
# 					article: false,
# 					directSalesPct: "0",
# 					calp: false
# 				});
# 				adInfoList.push({
# 					seq: 2,
# 					unitId: "p_news_sidebox",
# 					sync: false,
# 					mobileOnly: false,
# 					article: false,
# 					directSalesPct: "0",
# 					calp: false
# 				});
#
# 				var userAgent = navigator.userAgent.toLowerCase();
#
# 				for (var i = 0; i < adInfoList.length; i++) {
# 					var adInfo = adInfoList[i];
#
# 					var divId = "nmap_c_" + article.officeId + "_" + article.articleId + "_" + article.sectionId + "_" + adInfo.seq;
#
# 					var unitId = adInfo.unitId;
# 					var mobileOnly = adInfo.mobileOnly;
# 					var sync = adInfo.sync;
# 					var isArticle = adInfo.article;
# 					var directSalesPct = adInfo.directSalesPct;
# 					var calp = adInfo.calp;
#
# 					if (mobileOnly == true) {
# 						if (/iphone|android|ipod/.test(userAgent) == false) {
# 							continue;
# 						}
# 					}
#
# 					var customParam = {
# 						sid1: article.sectionId,
# 						oid: article.officeId,
# 						gdid: article.gdid,
# 						pk: searchQuery,
# 						directSalesPct: directSalesPct
# 					};
#
# 					if (calp == true) {
# 						customParam.calp = "";
# 					}
#
# 					var adUnit = {
# 						adUnitId: unitId,
# 						adSlotElementId: divId,
# 						customParam: customParam
# 					};
#
# 					if (sync == true) {
# 						syncUnitIds.push(unitId);
# 						syncDivIds.push(divId);
#
# 						if (isArticle == false) {
# 							syncUnitIdsForNonArticle.push(unitId);
# 							syncDivIdsForNonArticle.push(divId);
# 						}
# 					} else {
# 						unitIds.push(unitId);
# 						divIds.push(divId);
# 					}
#
# 					gladsdk.defineAdSlot(adUnit);
# 				}
#
# 			});
# 			window.__htExternalUrl = window.__htExternalUrl || {};
# 		</script>
# <script src="https://static-nnews.pstatic.net/js/min/20230427/common.min.js"></script>
# </link></meta></head>
# <body class="n_news_mnews fs2 as_mp_layout">
# <div class="end_container">
# <div class="u_skip"><a href="#ct">본문 바로가기</a></div>
# <header class="as_gnb_mnews" role="banner">
# <div class="header_inner">
# <div class="Ngnb">
# <div class="Ngnb_inner">
# <div class="Ngnb_both">
# <div class="Ngnb_left">
# <span class="Ngnb_logo"><a class="Nlogo_link _LINK" data-clk="gnb.naver" data-pc-url="https://www.naver.com/" data-url="https://m.naver.com/" href="https://m.naver.com/"><span class="Nicon_logo">NAVER</span></a></span>
# <div class="Ngnb_service">
# <h1 class="Nservice_item"><a class="_LINK" data-clk="gnb.news" data-pc-url="https://news.naver.com/" data-url="https://m.news.naver.com" href="https://m.news.naver.com"><span class="Nicon_service">뉴스</span></a></h1>
# <span class="Nservice_subitem">
# <a class="_LINK" data-clk="gnb.entertain" data-pc-url="https://entertain.naver.com/home" data-url="https://m.entertain.naver.com" href="https://m.entertain.naver.com">
# <span class="Nicon_family Nicon_entertain">연예</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a class="_LINK" data-clk="gnb.sports" data-pc-url="https://sports.news.naver.com/index" data-url="https://m.sports.naver.com" href="https://m.sports.naver.com">
# <span class="Nicon_family Nicon_sports">스포츠</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a data-clk="gnb.weather" href="https://weather.naver.com">
# <span class="Nicon_family Nicon_weather">날씨</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a data-clk="gnb.premium" href="https://contents.premium.naver.com">
# <span class="Nicon_family Nicon_premium">프리미엄</span>
# </a>
# </span>
# </div>
# </div>
# <div class="Ngnb_right">
# <div class="Ngnb_group">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="Ngnb_search _SEARCH_WRAP is_hidden"></div>
# <div class="Ngnb_tool">
# <a class="Ntool_button _SEARCH_CONTENT_TOGGLE_BUTTON" data-clk="gnb.scho" href="javascript:;"><span class="Nicon_search">검색</span></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="Nlnb" data-scroll-fixed="true" id="_LNB_PARENT_WRAP" style="z-index:3000;">
# <div class="Nlnb_menu Ntype_scroll" id="_LNB_WRAP" style="position: relative;">
# <div class="Nlnb_menu_inner" id="_LNB">
# <ul class="Nlnb_menu_list" role="tablist">
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.press" href="https://news.naver.com/"><span class="Nitem_link_menu">언론사별</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.pol" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="Nitem_link_menu">정치</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM is_active" role="tab">
# <a class="Nitem_link" data-clk="lnb.eco" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="Nitem_link_menu">경제</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.soc" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="Nitem_link_menu">사회</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.lif" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="Nitem_link_menu">생활/문화</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.it" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="Nitem_link_menu">IT/과학</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.wor" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="Nitem_link_menu">세계</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.rank" href="https://news.naver.com/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="Nitem_link_menu">랭킹</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.paper" href="https://news.naver.com/newspaper/home"><span class="Nitem_link_menu">신문보기</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.opi" href="https://news.naver.com/main/opinion/home.naver"><span class="Nitem_link_menu">오피니언</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.tv" href="https://news.naver.com/main/tv/index.naver?mid=tvh"><span class="Nitem_link_menu">TV</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.fact" href="https://news.naver.com/main/factcheck/main.naver"><span class="Nitem_link_menu">팩트체크</span></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </header>
# <hr/>
# <script>
# 	var svt = "20230430194823.285";
# 	var timestamp = svt.substr(0, 8);
# 	var isLogin = false;
# 	var uhv = "";
#
# 	var service = {
# 		news: false,
# 		entertain: false,
# 		sports: false,
# 		mnews: true,
# 		newsType: true
# 	};
# 	var serviceName = "mnews";
#
# 	var isProduction = true;
#
# 	var gnb_service = "news";
# 	var gnb_logout = encodeURIComponent(location.href);
# 	var gnb_template = "gnb_utf8";
# 	var gnb_brightness = 3;
# </script>
# <div class="ct_wrap" id="ct_wrap">
# <div class="ct_scroll_wrapper">
# <div class="newsct_wrapper _GRID_TEMPLATE_COLUMN _STICKY_CONTENT"><div class="newsct" id="ct" role="main">
# <div class="media_end_head go_trans">
# <div class="media_end_head_top">
# <a class="media_end_head_top_logo" href="http://www.khan.co.kr/">
# <img alt="경향신문" class="media_end_head_top_logo_img light_type" height="32" src="https://mimgnews.pstatic.net/image/upload/office_logo/032/2020/09/15/logo_032_6_20200915155035.png" title="경향신문" width=""/>
# <img alt="경향신문" class="media_end_head_top_logo_img dark_type" height="32" src="https://mimgnews.pstatic.net/image/upload/office_logo/032/2020/09/15/dark_logo_032_6_20200915155021.png" title="경향신문" width=""/>
# </a>
# <div class="media_end_head_top_channel _CHANNEL_BUTTON_WRAP" style="display:none;">
# <button class="media_end_head_top_channel_add _CHANNEL_BUTTON" data-clk-add="chmain032" data-clk-remove="chdelete032" data-delay="1000" data-notification="true" data-notification-clk="notru" data-text="구독">구독</button>
# <a class="media_end_head_top_channel_layer _LINK" data-clk="chlook" data-url-type="NAVERAPP_NEWS_CHANNEL" href="#" id="_CHANNEL_LAYER_032_0003161880" style="display: none;">
# <span class="media_end_head_top_channel_layer_text"><strong>경향신문</strong> 언론사 구독되었습니다. <br/>메인 뉴스판에서  주요뉴스를 <br/> 볼 수 있습니다.</span>
# <span class="media_end_head_top_channel_layer_link">보러가기</span>
# </a>
# <p class="media_end_head_top_channel_layer" id="_CHANNEL_REMOVE_LAYER_032_0003161880" style="display: none;">
# <span class="media_end_head_top_channel_layer_text"><strong>경향신문</strong> 언론사 구독 해지되었습니다.</span>
# </p>
# </div>
# </div>
# <div class="media_end_head_title">
# <h2 class="media_end_head_headline" id="title_area"><span>‘7% 할인’ 서울광역상품권 또 풀린다···“출생연도 홀짝수로 구매시간 분리”</span></h2>
# </div>
# <div class="media_end_head_info nv_notrans">
# <div class="media_end_head_info_datestamp">
# <div class="media_end_head_info_datestamp_bunch">
# <em class="media_end_head_info_datestamp_term">입력</em><span class="media_end_head_info_datestamp_time _ARTICLE_DATE_TIME" data-date-time="2022-07-24 11:16:01">2022.07.24. 오전 11:16</span>
# </div>
# <div class="media_end_head_info_datestamp_bunch">
# <em class="media_end_head_info_datestamp_term">수정</em><span class="media_end_head_info_datestamp_time _ARTICLE_MODIFY_DATE_TIME" data-modify-date-time="2022-07-24 11:24:01">2022.07.24. 오전 11:24</span>
# </div>
# <a class="media_end_head_origin_link" data-clk="are.ori" data-extra='{"lk":{"oid":"032","aid":"0d9de6d3c8ee8113"}}' data-gdid="032" href="https://www.khan.co.kr/national/national-general/article/202207241115001" target="_blank">기사원문</a>
# </div> <div class="media_end_head_journalist">
# <a class="media_end_head_journalist_box" data-clk="ummore" href="https://media.naver.com/journalist/032/56163">
# <div class="media_end_head_journalist_thumb">
# <img height="24" src="https://mimgnews.pstatic.net/image/upload/journalist/2019/02/18/%EC%9D%B4%EC%84%B1%ED%9D%AC.png?type=nf112_112" width="24"/>
# </div>
# <em class="media_end_head_journalist_name">이성희 기자</em>
# </a>
# <div class="media_end_head_journalist_layer _JOURNALIST_CARD" id="_JOURNALIST_LAYER" style="display: none;">
# <ul class="media_end_head_journalist_layer_list">
# <li class="media_end_head_journalist_layer_item _SUBSCRIBE_ELE" data-subscribe-type="JOURNALIST">
# <div class="media_end_head_journalist_layer_div _LIKE_HIDE _LAZY_LOADING_WRAP">
# <div class="media_end_head_journalist_layer_thumb _LAZY_LOADING_ERROR_HIDE">
# <img class="_LAZY_LOADING" data-src="https://mimgnews.pstatic.net/image/upload/journalist/2019/02/18/%EC%9D%B4%EC%84%B1%ED%9D%AC.png?type=nf112_112" height="38" width="38"/>
# </div>
# <div class="media_end_head_journalist_layer_text _reactionModule" data-ccounttype="period" data-cid="56163" data-sid="JOURNALIST" id="_cheer_56163_layer">
# <div class="media_end_head_journalist_layer_title">
# <em class="media_end_head_journalist_layer_name">이성희 기자</em>
# <div class="media_end_head_journalist_layer_btns _JOURNALIST_ID" data-journalistid="56163">
# <button class="media_end_head_journalist_btn_subscribe _SUBSCRIBE" data-channelkey="JOURNALIST_56163" data-clk="umsubs" type="button">구독</button>
# <button class="media_end_head_journalist_btn_subscribe is_on _UNSUBSCRIBE" data-channelkey="JOURNALIST_56163" data-clk="umunsubs" data-messagevalue="이성희" data-type="journalist" style="display:none;" type="button">구독중</button>
# </div>
# </div>
# <dl class="media_end_head_journalist_layer_subscriber _button" data-ishiddenlabelaszerocount="true" data-ishiddenzerocount="true" data-type="cheer">
# <div class="media_end_head_journalist_layer_definition_wrap _SUBSCRIBE_COUNT_TEXT_WRAP">
# <dt>구독자</dt>
# <dd class="_SUBSCRIBE_COUNT_TEXT" data-maxcount="99999">0</dd>
# </div>
# <div class="media_end_head_journalist_layer_definition_wrap">
# <dt class="_label">응원수</dt>
# <dd class="_count">0</dd>
# </div>
# </dl>
# </div>
# <a class="media_end_head_journalist_layer_link" data-clk="ummore" href="https://media.naver.com/journalist/032/56163">더보기</a>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="media_end_head_info_variety">
# <div class="media_end_head_info_variety_left" id="commentFontGroup">
# <div class="media_end_head_info_variety_likeit _LIKE_HIDE as_likeit_improve">
# <!-- 좋아요 -->
# <div class="_reactionModule u_likeit nv_notrans" data-cid="ne_032_0003161880" data-sid="NEWS">
# <a aria-haspopup="true" aria-pressed="false" class="u_likeit_button _face _LIKE_BUTTON" data-clk="RTL.face" data-label="recommend">
# <span class="u_likeit_icons _icons">
# <span class="u_likeit_icon __reaction__zeroface"></span>
# </span>
# <span class="u_likeit_text _count">추천</span>
# </a>
# <ul class="u_likeit_layer _faceLayer" role="menu">
# <li class="u_likeit_list useful" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTL.useful|RTL.unuseful" data-type="useful" href="#" role="button">
# <span class="u_likeit_list_name _label">쏠쏠정보</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list wow" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTL.wow|RTL.unwow" data-type="wow" href="#" role="button">
# <span class="u_likeit_list_name _label">흥미진진</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list touched" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTL.touched|RTL.untouched" data-type="touched" href="#" role="button">
# <span class="u_likeit_list_name _label">공감백배</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list analytical" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTL.analytical|RTL.unanalytical" data-type="analytical" href="#" role="button">
# <span class="u_likeit_list_name _label">분석탁월</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list recommend" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTL.recommend|RTL.unrecommend" data-type="recommend" href="#" role="button">
# <span class="u_likeit_list_name _label">후속강추</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# </ul> </div>
# <!-- 좋아요 -->
# </div>
# <div class="media_end_head_info_variety_cmtcount _COMMENT_HIDE">
# <a class="media_end_head_cmtcount_button _COMMENT_COUNT_VIEW" data-clk="rplt" data-max-limit="true" data-zero-allow="false" href="/mnews/article/comment/032/0003161880?sid=101" id="comment_count">댓글</a>
# </div>
# </div>
# <div class="media_end_head_info_variety_right">
# <!-- 요약봇 -->
# <div class="media_end_head_autosummary _auto_summary_wrapper _SUMMARY _LIKE_HIDE" data-articleid="0003161880" data-officeid="032" id="_SUMMARY_BUTTON">
# <a class="media_end_head_autosummary_button _toggle_btn _SUMMARY_BTN" data-clk="sum" href="javascript:;"><span class="blind">본문 요약봇</span></a>
# <div class="media_end_head_autosummary_layer_dimmed _SUMMARY_DIMMED" style="display: none;"></div>
# <div class="media_end_head_autosummary_layer _auto_summary_contents _SUMMARY_LAYER" style="display: none;">
# <div class="media_end_head_autosummary_layer_head">
# <strong class="media_end_head_autosummary_layer_head_tit">본문 요약봇<a class="media_end_head_autosummary_help" data-clk="help" href="https://help.naver.com/alias/news/news_022.naver">도움말</a></strong>
# <span class="media_end_head_autosummary_layer_head_txt">자동 추출 기술로 요약된 내용입니다. 요약 기술의 특성상 본문의 주요 내용이 제외될 수 있어, 전체 맥락을 이해하기 위해서는 기사 본문 전체보기를 권장합니다.</span>
# <a class="media_end_head_autosummary_layer_close _close_button _SUMMARY_CLOSE_BTN" data-clk="close" href="javascript:;"><span class="blind">닫기</span></a>
# </div>
# <div class="media_end_head_autosummary_layer_body">
# <div class="_contents_body _SUMMARY_CONTENT_BODY"></div>
# </div>
# </div>
# </div>
# <!-- TTS -->
# <div class="media_end_head_tts nv_notrans" id="tts_player_div_wrap">
# <button class="media_end_head_tts_run _TTS_SETTING_BTN" data-clk="wtts" title="텍스트 음성 변환 서비스" type="button"><span class="blind">텍스트 음성 변환 서비스 사용하기</span></button>
# <div class="media_end_head_tts_setlayer nv_notrans _TTS_SETTING_LAYER">
# <div class="media_end_head_tts_setlayer_select">
# <div class="media_end_head_tts_setlayer_select_bunch" id="ttsSelectGender">
# <em class="media_end_head_tts_option_tit">성별</em>
# <button class="media_end_head_tts_option" data-clk="ttsma" type="button" value="m">남성</button>
# <button class="media_end_head_tts_option" data-clk="ttsfe" type="button" value="f">여성</button>
# </div>
# <div class="media_end_head_tts_setlayer_select_bunch" id="ttsSelectSpeed">
# <em class="media_end_head_tts_option_tit">말하기 속도</em>
# <button class="media_end_head_tts_option" data-clk="ttssp" type="button" value="3">느림</button>
# <button class="media_end_head_tts_option" data-clk="ttssp" type="button" value="2">보통</button>
# <button class="media_end_head_tts_option" data-clk="ttssp" type="button" value="0">빠름</button>
# </div>
# <p class="media_end_head_tts_desc">이동 통신망을 이용하여 음성을 재생하면 별도의 데이터 통화료가 부과될 수 있습니다.</p>
# <button class="media_end_head_tts_apply _TTS_LISTEN_BTN" data-clk="ttsstart" type="button">본문듣기 시작</button>
# </div>
# <button class="media_end_head_tts_setlayer_close _TTS_SETTING_LAYER_CLOSE_BTN" data-clk="ttsclose" type="button"><span class="blind">닫기</span></button>
# </div>
# </div>
# <div id="tts_player_div"></div> <!-- 폰트 사이즈 -->
# <div class="media_end_head_fontsize _font_size_config_wrapper _FONT_WRAP">
# <a class="media_end_head_fontsize_set _font_size_config_toggle_btn _FONT_BUTTON" data-clk="fsz" href="#"><span class="blind">글자 크기 변경하기</span></a>
# <div class="media_end_head_fontsize_setlayer _FONT_LAYER">
# <ul class="media_end_head_fontsize_setlayer_select">
# <li class="media_end_head_fontsize_option1 _opt">
# <a class="media_end_head_fontsize_option_text _FONT_LAYER_BUTTON" data-clk="fsz1" data-value="1" href="#">가<em class="blind">1단계</em></a>
# <a class="media_end_head_fontsize_option_name _FONT_LAYER_BUTTON" data-clk="fsz1" data-value="1" href="#">작게</a>
# </li>
# <li class="media_end_head_fontsize_option2 _opt">
# <a class="media_end_head_fontsize_option_text _FONT_LAYER_BUTTON" data-clk="fsz2" data-value="2" href="#">가<em class="blind">2단계</em></a>
# <a class="media_end_head_fontsize_option_name _FONT_LAYER_BUTTON" data-clk="fsz2" data-value="2" href="#">보통</a>
# </li>
# <li class="media_end_head_fontsize_option3 _opt">
# <a class="media_end_head_fontsize_option_text _FONT_LAYER_BUTTON" data-clk="fsz3" data-value="3" href="#">가<em class="blind">3단계</em></a>
# <a class="media_end_head_fontsize_option_name _FONT_LAYER_BUTTON" data-clk="fsz3" data-value="3" href="#">크게</a>
# </li>
# <li class="media_end_head_fontsize_option4 _opt">
# <a class="media_end_head_fontsize_option_text _FONT_LAYER_BUTTON" data-clk="fsz4" data-value="4" href="#">가<em class="blind">4단계</em></a>
# <a class="media_end_head_fontsize_option_name _FONT_LAYER_BUTTON" data-clk="fsz4" data-value="4" href="#">아주크게</a>
# </li>
# <li class="media_end_head_fontsize_option5 _opt">
# <a class="media_end_head_fontsize_option_text _FONT_LAYER_BUTTON" data-clk="fsz5" data-value="5" href="#">가<em class="blind">5단계</em></a>
# <a class="media_end_head_fontsize_option_name _FONT_LAYER_BUTTON" data-clk="fsz5" data-value="5" href="#">최대크게</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="media_end_head_share nv_notrans">
# <a class="u_btn_sns_share naver-splugin spi_sns_share nv_notrans _SHARE_BUTTON" data-band-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=band" data-blog-blog-id="naver" data-blog-source-type="3" data-blog-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=blog" data-cafe-source-type="3" data-cafe-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=cafe" data-calendar-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=calendar" data-canonical-url="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=sec&amp;oid=032&amp;aid=0003161880&amp;sid1=001" data-clk="ushr" data-facebook-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=facebook" data-friend-display="on" data-friend-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=friend" data-kakaostory-display="off" data-kakaotalk-image-url="https://imgnews.pstatic.net/image/032/2022/07/24/0003161880_001_20220724112401144.jpg?type=nf300_200" data-kakaotalk-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=kakao" data-likecontentsid="ne_032_0003161880" data-likeserviceid="NEWS" data-line-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=line" data-mail-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=mail" data-memo-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=memo" data-mypeople-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=mypeople" data-style="type_a" data-title="‘7% 할인’ 서울광역상품권 또 풀린다···“출생연도 홀짝수로 구매시간 분리”" data-twitter-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=twitter" data-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101" href="#" id="spiButton" onclick="return false">
# <span class="naver-splugin-c send_caption"><span class="u_hc">SNS 보내기</span></span>
# </a>
# </div>
# <div class="media_end_head_print">
# <a class="media_end_print_link _PRINT_BUTTON" data-clk="print" data-print-url="/mnews/article/print/032/0003161880" href="#"><span class="blind">인쇄하기</span></a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="newsct_body" id="contents">
# <div class="newsct_article _article_body" id="newsct_article">
# <div class="go_trans _article_content" id="dic_area">
# <strong class="media_end_summary">1차는 6만4650명 구매···평균 39만원어치 팔려<br/>서울시 “서울페이플러스 회원 가입은 전날 미리”</strong><span class="end_photo_org"><div class="nbd_im_w _LAZY_LOADING_WRAP">
# <div class="nbd_a _LAZY_LOADING_ERROR_HIDE" id="img_a1">
# <img class="_LAZY_LOADING" data-src="https://imgnews.pstatic.net/image/032/2022/07/24/0003161880_001_20220724112401144.jpg?type=w647" id="img1">
# </img></div>
# </div><em class="img_desc">한 시민이 초복을 하루 앞둔 지난 15일 서울 시내 대형마트에서 장을 보고 있다. |성동훈 기자</em></span><br/><br/>서울 25개 자치구 어디에서나 쓸 수 있는 ‘서울사랑상품권(광역상품권)’이 오는 28일 추가 발행된다. 1차 발행 때처럼 동시접속자가 몰리는 것을 막기 위해 이번에는 출생연도를 기준으로 홀수는 오전 10시부터, 짝수는 오후 2시부터 각각 4시간씩 구매할 수 있다.<br/><br/>서울시는 7% 할인금액으로 구매할 수 있는 광역상품권을 28일 발행한다고 24일 밝혔다. 발행 규모는 1차(250억원) 때보다 2배 많은 총 500억원이다. 시민들의 장바구니 물가 부담을 덜고 소상공인 매출증대를 통한 지역경제 활성화를 위해 2차 발행 규모를 늘렸다고 서울시는 설명했다.<br/><br/>광역상품권은 서울 25개 자치구 내 가맹점 어디에서나 사용할 수 있는 상품권으로 1인당 월 40만원까지 구매할 수 있다. 보유는 총 100만원까지 가능하다. 지난 14일 1차 발행 상품권을 구매한 소비자는 총 6만4650명이었으며, 평균 구매 금액은 약 38만7000원이었다.<br/><br/>서울시는 2차 광역상품권 발행을 28일 오전과 오후로 나눠 진행한다. 지난 1차 발행 당시 구매접속 폭주로 한때 시스템이 먹통됐던 만큼 시스템 부하 등을 막기 위해서다. 1차는 발행 1시간여 만에 완판됐다.<br/><br/>이번에는 출생년도에 따라 홀수는 오전 10시부터 오후 2시까지, 짝수는 오후 2시부터 오후 6시까지 구입할 수 있다. 발행금액은 각 250억원씩 총 500억원이다. 오후 6시 이후에는 판매가능 금액이 남아있을 경우 홀짝수에 관계 없이 누구나 구매할 수 있다. 구매는 서울페이플러스 외에도 티머니페이, 신한SOL, 머니트리 등과 같은 결제 애플리케이션에서도 가능하다.<br/><br/>서울시는 시민들이 불편없이 광역상품권을 구매할 수 있도록 서울페이플러스 서버 용량을 1차 발행 대비 2배 이상 늘렸다. 이에 따라 동시 거래처리량은 초당 200건에서 1000건으로 5배 늘었다. 또 장시간 대기를 막기 위해 상품권 구매·결제단계에 ‘대기자 유량관리시스템’을 도입해 처리속도를 높였으며, 접속량 폭증 시 자동 튕겨나감을 막기 위해 로그아웃 시간을 자동 연장하도록 했다. 특히 편법 구매가 가능한 것으로 알려진 휴대전화 비행기 모드 전환시 후순위 대기순번으로 세팅되며 중복구매를 막기 위한 시스템도 탑재했다.<br/><br/>다만 시스템 과부하를 마기 위해 발행 당일 선물하기, 회원가입, 가맹점찾기 등 일부 서비스는 중단된다. 서울시는 광역상품권 구매를 원할 경우 발행 전날에는 미리 서울페이플러스에 회원가입을 해달라고 당부했다.<br/><br/>서울시는 자치구별로 발행해 해당 자치구 내 가맹점에서만 사용 가능한 10% 할인 서울사랑상품권도 추석 전인 9월 초 3670억원 규모로 발행할 계획이다.
# 		</div>
# </div>
# <div class="byline">
# <p class="byline_p">
# <span class="byline_s">이성희 기자 mong2@kyunghyang.com</span>
# </p>
# </div>
# <div class="newsct_journalist">
# <div class="newsct_journalist_inner">
# <h4 class="blind">기자 프로필</h4>
# <div class="media_journalistcard _JOURNALIST_CARD _MORE_WRAP">
# <div class="media_journalistcard_inner" id="JOURNALIST_CARD_LIST">
# <div class="media_journalistcard_item _SUBSCRIBE_ELE" data-subscribe-type="JOURNALIST">
# <div class="media_journalistcard_item_inner">
# <div class="media_journalistcard_intro">
# <div class="media_journalistcard_summary">
# <span class="media_journalistcard_summary_press">
# <img alt="경향신문" class="media_journalistcard_summary_press_img light_type" height="24" src="https://mimgnews.pstatic.net/image/upload/office_logo/032/2020/09/15/logo_032_6_20200915155035.png" title=""/>
# <img alt="경향신문" class="media_journalistcard_summary_press_img dark_type" height="24" src="https://mimgnews.pstatic.net/image/upload/office_logo/032/2020/09/15/dark_logo_032_6_20200915155021.png" title=""/>
# </span>
# <div class="media_journalistcard_summary_inner _LAZY_LOADING_WRAP">
# <div class="media_journalistcard_summary_info">
# <a class="media_journalistcard_summary_photo _LAZY_LOADING_ERROR_HIDE" data-clk="mmore" href="https://media.naver.com/journalist/032/56163">
# <div class="media_journalistcard_summary_photo_inner">
# <img alt="" class="media_journalistcard_summary_photo_inner_img _LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/upload/journalist/2019/02/18/%EC%9D%B4%EC%84%B1%ED%9D%AC.png?type=nf112_112" height="40" style="display:none;" width="40"/>
# </div>
# </a>
# <a class="media_journalistcard_summary_text" data-clk="mmore" href="https://media.naver.com/journalist/032/56163">
# <span class="media_journalistcard_summary_name">
# <span class="media_journalistcard_summary_name_inner">
# <em class="media_journalistcard_summary_name_text">이성희 기자</em>
# </span>
# </span>
# </a>
# </div>
# <div class="subscribe_wrap _JOURNALIST_ID" data-journalistid="56163">
# <a class="subscribe _SUBSCRIBE" data-channelkey="JOURNALIST_56163" data-clk="msubs" href="#">
# <span class="subscribe_ico"><span>구독</span></span>
# </a>
# <a class="subscribe on _UNSUBSCRIBE" data-channelkey="JOURNALIST_56163" data-clk="munsubs" data-messagevalue="이성희" data-type="journalist" href="#" style="display:none;">
# <span class="subscribe_ico"><span>구독중</span></span>
# </a>
# </div>
# </div>
# <span class="media_journalistcard_summary_subscribe">
# <span class="media_journalistcard_summary_subscribe_inner _SUBSCRIBE_COUNT_TEXT_WRAP">
# <i class="media_journalistcard_summary_subscribe_item">구독자</i> <em class="media_journalistcard_summary_subscribe_value _SUBSCRIBE_COUNT_TEXT">0</em>
# </span>
# <span class="media_journalistcard_summary_subscribe_inner _LIKE_HIDE">
# <div class="u_likeit_list_module _reactionModule" data-ccounttype="period" data-cid="56163" data-sid="JOURNALIST" id="_cheer_56163_layer">
# <span class="u_likeit_list_btn _button" data-ishiddenlabelaszerocount="true" data-ishiddenzerocount="true" data-type="cheer">
# <em class="u_txt _label">응원수</em>
# <em class="u_cnt _count">0</em>
# </span>
# </div>
# </span>
# </span>
# </div>
# </div>
# <div class="media_journalistcard_word">
# <p class="media_journalistcard_word_text">다르게, 바르게 쓰겠습니다.</p>
# </div>
# <div class="media_journalistcard_morenews">
# <ul class="media_journalistcard_morenews_list">
# <li class="media_journalistcard_morenews_item">
# <a class="media_journalistcard_morenews_item_inner" data-clk="bestart" href="/mnews/article/032/0003219657?type=journalists">압구정 재건축 ‘최고 70층’ 들어서나···1만가구 ‘미니 신도시’로 변신?</a>
# </li>
# <li class="media_journalistcard_morenews_item">
# <a class="media_journalistcard_morenews_item_inner" data-clk="bestart" href="/mnews/article/032/0003220549?type=journalists">서울 청년 2만5000명에 10개월간 ‘월세 20만원' 지원한다</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="media_journalistcard_recommend media_journalistcard_recommend_is_on" id="_RECOMMEND_JOURNALIST" style="display:none;">
# <div class="media_journalistcard_recommend_inner">
# <h4 class="media_journalistcard_recommend_title _RECOMMEND_JOURNALIST_WRAP">경향신문의 구독 많은 기자</h4>
# <script class="_RECOMMEND_JOURNALIST_TEMPLATE" type="x-tmpl-mustache">
# 							<ul class="media_journalistcard_recommend_list">
# 								{{#list}}
# 								<li class="media_journalistcard_recommend_item _SUBSCRIBE_ELE" data-subscribe-type="JOURNALIST">
# 									<div class="media_journalistcard_recommend_item_inner">
# 										<a href="{{reporterUrl}}" class="media_journalistcard_recommend_item_link" data-clk="bmmore">
# 											{{#imageUrl}}
# 											<span class="media_journalistcard_recommend_img_wrap"><img src="{{imageUrl}}" width="44" height="44" alt="" class="media_journalistcard_recommend_img"></span>
# 											{{/imageUrl}}
# 											<em class="media_journalistcard_recommend_name">{{reporterName}}</em>
# 										</a>
# 										{{#count}}
# 										<span class="media_journalistcard_recommend_subscribe">구독자 <em class="_SUBSCRIBE_COUNT_TEXT">{{count}}</em></span>
# 										{{/count}}
# 										<div class="subscribe_wrap">
# 											<a href="#" class="subscribe _SUBSCRIBE" data-channelKey="{{channelKey}}" data-clk="bmsubs">
# 												<span class="subscribe_ico"><span>구독</span></span>
# 											</a>
# 											<a href="#" class="subscribe on _UNSUBSCRIBE" data-channelKey="{{channelKey}}" data-type="journalist" data-messageValue="{{reporterName}}" data-clk="bmunsubs" style="display:none;">
# 												<span class="subscribe_ico"><span>구독중</span></span>
# 											</a>
# 										</div>
# 									</div>
# 								</li>
# 								{{/list}}
# 							</ul>
# 							</script>
# <div class="media_journalistcard_recommend_channel _JOURNALIST_CHANNEL_PROMOTION">
# <strong>경향신문</strong> 기사를 더 보고 싶다면?
# 								<button class="media_journalistcard_recommend_channel_add _JOURNALIST_CHANNEL_BANNER _CHANNEL_ADD" data-clk-add="chsub" data-clk-remove="chsubback" data-delay="1000" data-gdid="032" type="button">구독</button>
# <a class="media_journalistcard_recommend_channel_layer _LINK" data-url-type="NAVERAPP_NEWS_CHANNEL" href="#" id="_JOURNALIST_CHANNEL_LAYER_032_0003161880" style="display:none;">
# <span class="media_journalistcard_recommend_channel_layer_text"><strong>경향신문</strong> 언론사 구독되었습니다. <br/>메인 뉴스판에서 경향신문 주요뉴스를 <br/> 볼 수 있습니다.</span>
# <span class="media_journalistcard_recommend_channel_layer_link">보러가기</span>
# </a>
# <p class="media_journalistcard_recommend_channel_layer" id="_JOURNALIST_CHANNEL_REMOVE_LAYER_032_0003161880" style="display:none">
# <span class="media_journalistcard_recommend_channel_layer_text"><strong>경향신문</strong> 언론사 구독 해지되었습니다.</span>
# </p>
# </div>
# <a class="media_journalistcard_recommend_close _TOGGLE" data-clk="bmclose" data-target="_RECOMMEND_JOURNALIST" href="#">닫기</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="copyright">
# <div class="c_inner">
# <p class="c_text">Copyright ⓒ 경향신문. All rights reserved. 무단 전재 및 재배포 금지.</p>
# </div>
# </div> <div class="media_end_categorize">
# <a class="media_end_categorize_link _categorize_title _TOGGLE" data-target="_ARTICLE_SECTION_GUIDE_LAYER" href="#">이 기사는 언론사에서 <em class="media_end_categorize_item">사회</em> 섹션으로 분류했습니다.</a>
# <div class="media_end_categorize_ct" id="_ARTICLE_SECTION_GUIDE_LAYER">
# <em class="media_end_categorize_ct_title">기사 섹션 분류 안내</em>
# <p class="media_end_categorize_ct_p">기사의 섹션 정보는 해당 언론사의 분류를 따르고 있습니다. 언론사는 개별 기사를 2개 이상 섹션으로 중복 분류할 수 있습니다.</p>
# <a class="media_end_categorize_ct_close _CLOSE" data-target="_ARTICLE_SECTION_GUIDE_LAYER" href="#">닫기</a>
# </div>
# </div>
# <div id="channelBanner" style="display:none;">
# <div class="media_end_channel_banner _LAZY_LOADING_WRAP">
# <a class="media_end_channel_banner_link _CHANNEL_BANNER _CHANNEL_ADD" data-clk-add="chbanner032" data-clk-remove="chsee032" data-notification="true" data-notification-clk="notbb" href="#">
# <div class="media_end_channel_banner_head _LAZY_LOADING_ERROR_HIDE">
# <div class="media_end_channel_banner_img">
# <img alt="경향신문" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/032/2018/10/11/logo_032_57_20181011174011.png" height="40" style="display:none;" width="40"/>
# </div>
# </div>
# <div class="media_end_channel_banner_body _before _CHANNEL_BANNER_ADD">
# <p class="media_end_channel_banner_add">구독</p>
# <p class="media_end_channel_banner_txt"><span class="media_end_channel_banner_span"><strong>메인에서</strong> 바로 보는 언론사 편집 뉴스 지금 바로 구독해보세요!</span></p>
# </div>
# <div class="media_end_channel_banner_body _after _CHANNEL_BANNER_REMOVE is_hidden">
# <p class="media_end_channel_banner_add is_disabled">구독중</p>
# <p class="media_end_channel_banner_txt"><span class="media_end_channel_banner_span"><strong>메인에서</strong> 바로 보는 언론사 편집 뉴스 지금 바로 확인해보세요!</span> <em>보러가기</em></p>
# </div>
# </a>
# </div>
# </div>
# <div id="channelBannerRecommendList"></div>
# <script class="_CHANNEL_BANNER_RECOMMEND_LIST" type="x-tmpl-mustache">
# 	<div class="office_preference _CHANNEL_BANNER_RECOMMEND_LIST_WRAP">
# 	<div class="ofpr_recommend">
# 		<div class="ofpr_recommend_inner">
# 			<div class="ofpr_more_link">
# 				<h4 class="ofpr_tit">추가 구독해보세요</h4>
# 			</div>
# 			<ul class="ofpr_channel">
# 				{{#recommendList}}
# 				<li class="ofpr_item">
# 					<a href="#" class="ofpr_a _ALL_OFFICES_ITEM" data-officeId="{{officeId}}" data-officename="{{name}}" data-logo="{{logo}}" role="checkbox" aria-checked="false" data-clk-add="chwith" data-clk-remove="chwithno" data-target="_CHANNEL_BANNER_RECOMMEND_LIST_WRAP">
# 						<div class="ofpr_thumb"><img src="{{logo}}" class="ofpr_m" alt=""></div>
# 						<div class="ofpr_text">{{name}}</div>
# 						<span class="ofpr_badge">언론사 추가</span>
# 					</a>
# 				</li>
# 				{{/recommendList}}
# 			</ul>
# 			<div class="ofpr_btn_wrap">
# 				<button type="button" class="ofpr_btn_more _ALL_OFFICE_LIST" data-clk="chwithall">언론사 전체보기</button>
# 				<button type="button" class="ofpr_btn_confirm _ALL_OFFICES_COMPLETE disabled" data-clk-disabled="chwithsetall" data-clk-enabled="chwithchoice" data-target="_CHANNEL_BANNER_RECOMMEND_LIST_WRAP">언론사 전체 선택</button>
# 			</div>
# 			<button type="button" class="ofpr_recommend_close _TOGGLE" data-target="channelBannerRecommendList" data-clk="chclosing">닫기</button>
# 		</div>
# 	</div>
# 	</div>
# 	</script>
# <div class="promotion">
# <ul class="p_list">
# <li class="p_item">
# <a class="p_link" data-clk="promo" href="https://www.khan.co.kr/life/life-general/article/202106031627011">[뉴스레터]좋은 식습관을 만드는 맛있는 정보</a>
# </li>
# <li class="p_item">
# <a class="p_link" data-clk="promo" href="https://contents.premium.naver.com/khan/noon">‘눈에 띄는 경제’와 함께 경제 상식을 레벨 업 해보세요!</a>
# </li>
# </ul>
# </div> <div class="media_end_linked">
# <h3 class="media_end_linked_title">
# <a class="media_end_linked_title_inner" href="http://www.khan.co.kr/">
# <img alt="경향신문" class="media_end_linked_title_img light_type" height="26" src="https://mimgnews.pstatic.net/image/upload/office_logo/032/2020/09/15/logo_032_6_20200915155035.png" title="경향신문" width=""/>
# <img alt="경향신문" class="media_end_linked_title_img dark_type" height="26" src="https://mimgnews.pstatic.net/image/upload/office_logo/032/2020/09/15/dark_logo_032_6_20200915155021.png" title="경향신문" width=""/>
# </a>
# 			주요뉴스<span class="media_end_linked_title_desc">해당 언론사에서 선정하며 <em>언론사 페이지(아웃링크)</em>로 이동해 볼 수 있습니다.</span>
# </h3>
# <ul class="media_end_linked_list">
# <li class="media_end_linked_item"><a class="media_end_linked_item_inner" data-clk="are.link" data-extra='{"lk":{"oid":"032","aid":"3807563eb439f27e"}}' data-gdid="032" href="https://www.khan.co.kr/politics/politics-general/article/202207220714001/?utm_campaign=naver_news&amp;utm_source=naver&amp;utm_medium=related_news" target="_blank">윤 대통령 지지율 30.4%, 20%대 눈앞…부정평가는 67.2%</a></li>
# <li class="media_end_linked_item"><a class="media_end_linked_item_inner" data-clk="are.link" data-extra='{"lk":{"oid":"032","aid":"a815d6b924cec6b9"}}' data-gdid="032" href="https://www.khan.co.kr/national/national-general/article/202207181634021/?utm_campaign=naver_news&amp;utm_source=naver&amp;utm_medium=related_news" target="_blank">"대통령이 머드축제 갈 때냐"···시민들, 코로나 재유행 각자도생 맡긴 정부에 '분통'</a></li>
# <li class="media_end_linked_item"><a class="media_end_linked_item_inner" data-clk="are.link" data-extra='{"lk":{"oid":"032","aid":"628eaa0bed966f95"}}' data-gdid="032" href="http://sports.khan.co.kr/news/sk_index.html?art_id=202207241006003&amp;code=530101&amp;utm_campaign=naver_news&amp;utm_source=naver&amp;utm_medium=related_news" target="_blank">빙속 간판 김민석, 선수촌 내 음주운전···빙상에 또 먹구름</a></li>
# <li class="media_end_linked_item"><a class="media_end_linked_item_inner" data-clk="are.link" data-extra='{"lk":{"oid":"032","aid":"e131ca1ba7fd41c5"}}' data-gdid="032" href="https://www.khan.co.kr/politics/defense-diplomacy/article/202207221219011/?utm_campaign=naver_news&amp;utm_source=naver&amp;utm_medium=related_news" target="_blank">윤 대통령 "병사 봉급 200만원 인상 차질없이 추진"</a></li>
# <li class="media_end_linked_item"><a class="media_end_linked_item_inner" data-clk="are.link" data-extra='{"lk":{"oid":"032","aid":"ca18bea7f093c267"}}' data-gdid="032" href="https://www.khan.co.kr/politics/politics-general/article/202207221342011/?utm_campaign=naver_news&amp;utm_source=naver&amp;utm_medium=related_news" target="_blank">민주당 "윤석열, '과학방역' 큰소리치더니 '국민 각자도생 방역' 됐다"</a></li>
# </ul>
# </div>
# <div class="r_group_comp ad_box _da_banner is_border_none">
# <div class="ad_area _AD_WRAP _PERSIST_HEIGHT" data-article="false" data-mobileonly="false" data-persist="1_ad" data-sync="false" data-unitid="p_news_newsend" id="nmap_c_032_0003161880_102_1"></div>
# </div>
# <script>
# 	window.__htExternalUrl = window.__htExternalUrl || {};
# 	window.__htExternalUrl["like"] = "https://news.like.naver.com/js/reaction/dist/reaction.min.js";
# 	window.__htLikeOption = {
# 		type: "multi",
# 		cssId: "news",
# 		domain: "https://news.like.naver.com",
# 		isMobile: true,
# 		isHiddenLabel: false,
# 		isHiddenCount: false,
# 		isHiddenZeroCount: false,
# 		isUsedLabelAsZeroCount: false,
# 		isDebugMode: false,
# 		isDuplication: false,
# 		isHiddenLayerAfterSelection: true,
# 		clicklog: function(el, name) {
# 			nclkWrap.send({
# 				$this: $(el),
# 				sArea: name
# 			});
# 		}
# 	};
# 	window.__htLikeOption["isZeroFace"] = true;
# 	</script>
# <div class="ends_btn _PERSIST_HEIGHT _LIKE_HIDE as_likeit_improve" data-persist="0_faceLike">
# <div class="ends_btn_head">
# <strong class="ends_head_title">이 기사를 추천합니다</strong>
# <button class="ends_help_btn _TOGGLE" data-classvalue="is_hidden" data-clk="RTC.info" data-target="_LIKE_INFO_LAYER" type="button"></button>
# <div class="ends_help_layer is_hidden" id="_LIKE_INFO_LAYER">
# <p class="ends_help_desc">기사 추천은 24시간 내 50회까지 참여할 수 있습니다.</p>
# <button class="ends_help_close _TOGGLE" data-classvalue="is_hidden" data-clk="RTC.infoclose" data-target="_LIKE_INFO_LAYER"><span class="blind">닫기</span></button>
# </div>
# </div>
# <div class="_reactionModule u_likeit" data-cid="ne_032_0003161880" data-sid="NEWS" id="likeItCountViewDiv" style="visibility: visible;">
# <ul class="u_likeit_layer _faceLayer" role="menu">
# <li class="u_likeit_list useful" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTC.useful|RTC.unuseful" data-type="useful" href="#" role="button">
# <span class="u_likeit_list_name _label">쏠쏠정보</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list wow" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTC.wow|RTC.unwow" data-type="wow" href="#" role="button">
# <span class="u_likeit_list_name _label">흥미진진</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list touched" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTC.touched|RTC.untouched" data-type="touched" href="#" role="button">
# <span class="u_likeit_list_name _label">공감백배</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list analytical" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTC.analytical|RTC.unanalytical" data-type="analytical" href="#" role="button">
# <span class="u_likeit_list_name _label">분석탁월</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list recommend" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTC.recommend|RTC.unrecommend" data-type="recommend" href="#" role="button">
# <span class="u_likeit_list_name _label">후속강추</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# </ul> </div>
# <div class="u_likeit_module u_btn_likeit_on" id="likeItSTimeLineShareDiv" style="display:none"></div>
# <div class="u_likeit_module" id="likeItScrollDiv" style="display:none">
# <div class="u_likeit_friends" id="likeItFriendListDiv"></div>
# </div>
# </div> <div class="ends_addition" id="endAdditionContainer">
# <script>
# 			window.__htExternalUrl = window.__htExternalUrl || {};
# 			window.__htExternalUrl["share"] = "https://ssl.pstatic.net/spi/js/release/ko_KR/splugin.js";
# 			window.__htShareOption = {
# 				"scriptUrl": window.__htExternalUrl["share"],
# 				"evKey": "news",
# 				"dimmed": "fixed",
# 				"serviceName": "뉴스",
# 				"sourceName": "경향신문"
# 			};
# 			if (isAvailableDarkMode) {
# 				window.__htShareOption["darkMode"] = true;
# 			}
# 		</script>
# <div id="spiLayer" style="display:none;">
# <div class="spi_wrap layer_share_on">
# <div class="spi">
# <div class="spug">
# <a class="naver-splugin _spi_release spi_ico _btn_postbtn sns_share" data-band-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=band" data-blog-blog-id="naver" data-blog-source-type="3" data-blog-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=blog" data-button="postbtn" data-cafe-source-type="3" data-cafe-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=cafe" data-calendar-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=calendar" data-clk="dshr" data-facebook-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=facebook" data-friend-display="on" data-friend-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=friend" data-kakaostory-display="off" data-kakaotalk-image-url="https://imgnews.pstatic.net/image/032/2022/07/24/0003161880_001_20220724112401144.jpg?type=nf300_200" data-kakaotalk-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=kakao" data-likecontentsid="ne_032_0003161880" data-likeserviceid="NEWS" data-line-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=line" data-mail-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=mail" data-memo-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=memo" data-mypeople-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=mypeople" data-style="type_a" data-title="‘7% 할인’ 서울광역상품권 또 풀린다···“출생연도 홀짝수로 구매시간 분리”" data-twitter-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=twitter" data-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101" href="#"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="tomain_info _LIKE_HIDE" id="_TOMAIN_INFO" style="display: none;">
# <p class="tomain_info_layer">
# <strong class="tomain_info_head">모두에게 보여주고 싶은 기사라면<i>?</i><span class="tomain_info_betaicon">beta</span></strong>
# <span class="tomain_info_body">
# <strong class="tomain_info_point">이 기사를 추천합니다 </strong><span class="tomain_info_text">버튼을 눌러주세요. <br/> 집계 기간 동안 추천을 많이 받은 기사는 네이버 자동 기사배열 영역에 추천 요소로 활용됩니다.</span>
# </span>
# <a class="tomain_info_close _CLOSE" data-target="_TOMAIN_INFO" href="#">레이어 닫기</a>
# </p>
# </div>
# </div> <div class="_VALID_SERIES" data-component-id=""></div>
# <div class="media_end_linked_more">
# <div class="media_end_linked_more_inner">
# ...
# </div>
# <div class="rl_author_name">스마트 재테크</div>
# </div>
# </div>
# <div class="rl_img _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMzA0MjlfMjAy/MDAxNjgyNzY3OTE0MjM5.A6k8rs8EEQ61cNHzUHvArrZ1-sevUdiltnDGJ5z0zqQg.kTY--sUThesbjbITZT9DqP_S_gDZGvgQO2HsmJDzNMkg.JPEG/%EC%BD%94%EB%8D%B0%EC%A6%88%EC%BB%B4%EB%B0%94%EC%9D%B8%EC%A3%BC%EA%B0%80.jpg?type=nf190_130" height="65" width="95"/>
# </div>
# </div>
# </a>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="rl_link_end" data-clk="arp.ptextg" data-recommended-type="GLOBAL" data-score="0.8919763585026419" href="https://contents.premium.naver.com/ilab/insights/contents/230428091512694cw?from=news_arp_global">
# <div class="rl_content">
# <p class="rl_txt">
# 										4월 28일 today's insight_우리가 금융 공부를 해야만 하는 이유
# 									</p>
# <div class="rl_author">
# <div class="rl_author_thumb _LAZY_LOADING_ERROR_HIDE">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMjExMTlfMjA5/MDAxNjY4Nzk2Nzc4Mjgx.E8rZhid7dssWtYdmZHAuaUYFu7Z9FMClB5_6ODTUeN4g.6uuKV385C3I2n9nP3OTEAK1YP7UGuLnkp7PBYOZNpBMg.JPEG/image%7Cpremium%7Cchannel%7Cilab%7C2022%7C11%7C19%7C1668796778265.jpg?type=nfs200_200" height="18" width="18"/>
# </div>
# <div class="rl_author_name">인사이트 랩</div>
# </div>
# </div>
# <div class="rl_img _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMzA0MjhfMjY4/MDAxNjgyNjQwODQ2MzY0.R9lCL-nU3XbHvam20K0JmikWNGZ6vgxfVNUUtYjr4y4g.MnIxIhHzYygGz44_j39YkOzBpHy4Zx8GtTGwDcv1OCAg.PNG/%EA%B7%B8%EB%A6%BC2.png?type=nf190_130" height="65" width="95"/>
# </div>
# </div>
# </a>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="rl_link_end" data-clk="arp.ptextg" data-recommended-type="GLOBAL" data-score="1.1662375707119268" href="https://contents.premium.naver.com/invisiblecat/mukdolee/contents/230425181618288eb?from=news_arp_global">
# <div class="rl_content">
# <p class="rl_txt">
# 										9회말 2아웃에서 시작하는 단편
# 									</p>
# <div class="rl_author">
# <div class="rl_author_thumb _LAZY_LOADING_ERROR_HIDE">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMjA5MTJfODUg/MDAxNjYyOTc4ODM5OTUw.jWQ68xFlJxxeWgHC7MOz-nKEwY5B-ouItvxFGibdUmcg.JPOnbmaEduNqkP0U6ezuETUU9DXY4eVsKky7mmElr0Yg.JPEG/image%7Cpremium%7Cchannel%7Cinvisiblecat%7C2022%7C09%7C12%7C1662978839877.jpeg?type=nfs200_200" height="18" width="18"/>
# </div>
# <div class="rl_author_name">이묵돌</div>
# </div>
# </div>
# <div class="rl_img _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMzA0MjVfNzIg/MDAxNjgyNDE0NTk1ODc5.63RdlFLZujDmKClp-WAgIsSQTC9DEZ3vOjDhrjv7hFog.3ipXYr64_7JNlgdg3MYSEKyLEbsl3l5kLZCk34nEXrwg.PNG/image.png?type=nf190_130" height="65" width="95"/>
# </div>
# </div>
# </a>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="rl_link_end" data-clk="arp.ptextg" data-recommended-type="GLOBAL" data-score="0.9308779817293688" href="https://contents.premium.naver.com/moviesunwoo/moviesunwoo84/contents/230422144007535tk?from=news_arp_global">
# <div class="rl_content">
# <p class="rl_txt">
# 										군필자들의 악몽, &lt;D.P.&gt; 리뷰
# 									</p>
# <div class="rl_author">
# <div class="rl_author_thumb _LAZY_LOADING_ERROR_HIDE">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMjA3MTVfMjIz/MDAxNjU3ODYxNTk5MDgz._Dpr6J74CilT784Cy9p4Mtin1rIP2S79aJCZA_z_PJsg.YwfW3wD1pUvktXaEypBGaLCciu_jRYqo2zagTZ6Mo80g.PNG/image%7Cpremium%7Cchannel%7Cmoviesunwoo%7C2022%7C07%7C15%7C1657861599009.png?type=nfs200_200" height="18" width="18"/>
# </div>
# <div class="rl_author_name">영화선우</div>
# </div>
# </div>
# <div class="rl_img _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMzA0MjJfMTU4/MDAxNjgyMTQxNDc0MzEy.ZcfZjs1SdLC3tScnp1D9_tTXTqbHvKTMc_Gnd3QR3Vgg.gP5Ul67dK3ldc_ni2mjhXJYn8uSlz_IFUYU2HzAZyjcg.JPEG/%EB%8B%A4%EC%9A%B4%EB%A1%9C%EB%93%9C_(10).jpg/undefined?type=nf190_130" height="65" width="95"/>
# </div>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="pg ra_paginate">
# <div class="pg_num_area pg_num_area_v2">
# <button class="pg_btn_prev _FLICKING_PREV" data-clk="arp.bprv" type="button"><span class="blind">이전 콘텐츠들 보기</span></button>
# <div class="_FLICKING_INDICATOR" data-count="3"></div>
# <div class="pg_line"></div>
# <div class="pg_num pg_num">3</div>
# <button class="pg_btn_next _FLICKING_NEXT" data-clk="arp.bnxt" type="button"><span class="blind">다음 콘텐츠들 보기</span></button>
# </div>
# </div>
# <script class="_FLICKING_INDICATOR_TEMPLATE _PC" type="x-tmpl-mustache">
# 			{{#selected}}
# 			<div class="pg_num pg_num_cur">{{number}}</div>
# 			{{/selected}}
# 		</script>
# </div>
# </div>
# </div>
# <div class="outside_area _OUTSIDE_AREA">
# <div class="outside_area_inner _GRID_TEMPLATE_COLUMN_ASIDE _OUTSIDE_AREA_INNER"></div>
# </div>
# <aside class="main_aside _MAIN_ASIDE">
# <div class="main_aside_inner _MAIN_ASIDE_INNER">
# <h3 class="blind">구독</h3>
# <script class="_LAZY_LOADING_IFRAME" type="x-tmpl-mustache">
# 			<iframe class="_aside _GRID_TEMPLATE_ASIDE_IFRAME" src="https://news.naver.com/aside?oid=032" data-allow-domain="https://news.naver.com" style="visibility: hidden;" frameborder="no" scrolling="no" width="100%"></iframe>
# 			</script>
# </div>
# </aside>
# </div>
# </div>
# <div class="media_end_tts_ticker _FADE_LAYER" id="_media_end_tts_ticker" style="display: none;">
# <p class="media_end_tts_ticker_text" style="display: block;">본문 듣기를 <em class="media_end_tts_ticker_point">종료</em>하였습니다.</p>
# </div>
# <div class="tomain_ticker _TOMAIN_RECOMMAND_LAYER _FADE_LAYER" style="display: none;">이 기사를 <em class="tomain_ticker_point">추천</em>했습니다.
# </div>
# <div class="tomain_ticker _TOMAIN_CANCEL_LAYER _FADE_LAYER" style="display: none;">추천을 <em class="tomain_ticker_point">취소</em>했습니다.
# </div><hr/>
# <div class="u_ft _STICKY_FOOTER">
# <div class="u_ft_inner">
# <a class="r_pg_top show _MOVE_TOP" data-clk="fot.top" href="#" id="goTop" style="display:none;">맨위로</a>
# <footer role="contentinfo">
# <p class="u_ftlkw" id="u_ftlkw">
# <a class="u_ftlk _LINK" data-clk="fot.login" data-pc-url="https://nid.naver.com/nidlogin.login" data-url="https://nid.naver.com/nidlogin.login?svctype=262144" href="https://nid.naver.com/nidlogin.login?svctype=262144">로그인</a>
# <a class="u_ftlk _LINK" data-clk="fot.sitemap" data-pc-url="https://www.naver.com/more.html" data-url="https://m.naver.com/services.html?f=svc.news" href="https://m.naver.com/services.html?f=svc.news">전체서비스</a>
# </p>
# <p class="u_cr">
# <span class="u_ftm">
# <span class="u_cri u_cri_v1"><a class="u_cra _LINK" data-pc-url="https://news.naver.com/main/ombudsman/index.naver" data-url="https://m.news.naver.com/ombudsman/index" href="https://m.news.naver.com/ombudsman/index">서비스안내</a></span>
# <span class="u_cri u_cri_v1"><a class="u_cra" data-clk="fot.help" href="https://help.naver.com/alias/news/news_007.naver">뉴스도움말</a></span>
# <span class="u_cri u_cri_v1"><a class="u_cra" data-clk="fot.report" href="https://help.naver.com/alias/news/news_001.naver">오류신고</a></span>
# </span>
# <span class="u_copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며, 이를 무단<br/>이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</span>
# <span class="u_cri"><span class="copymark">ⓒ</span> <a class="u_cra_v1" data-clk="fot.navercorp" href="https://www.navercorp.com">NAVER Corp.</a></span>
# <span class="u_cri"><span class="copymark">ⓒ</span> <a class="u_cra_v1">경향신문</a></span>
# </p>
# </footer>
# </div>
# </div><div class="subscribe_dimmed is_hidden" id="_MY_FEED_CANCEL_MODAL" style="display:none;">
# <div class="subscribe_alert">
# <p class="subscribe_alert_p _message _MY_FFED_CANCEL_MODAL_MESSAGE">
# </p>
# <div class="subscribe_alert_btns">
# <a class="subscribe_alert_btn _CANCEL_YES_BTN _TOGGLE" data-classvalue="is_hidden" data-target="_MY_FEED_CANCEL_MODAL" href="#">예</a>
# <a class="subscribe_alert_btn _TOGGLE" data-classvalue="is_hidden" data-target="_MY_FEED_CANCEL_MODAL" href="#">아니오</a>
# </div>
# </div>
# </div>
# <script class="_MY_FEED_CANCEL_MODAL_TEMPLATE" type="x-tmpl-mustache">
# 			{{#series}}
# 			<span class="subscribe_alert_p_ellipsis">{{value}}</span><br>연재 구독을 취소하시겠습니까? <span class="subscribe_alert_p_dsc">해당 기사는 <em>구독</em>에서 제외됩니다.</span>
# 			{{/series}}
# 			{{#journalist}}
# 			{{value}} 기자의 기사<br> 구독을 취소하시겠습니까? <span class="subscribe_alert_p_dsc"><em>구독</em>에서 해당 기자의 기사가 제외됩니다.</span>
# 			{{/journalist}}
# </script>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION"></div>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION_ALL"></div>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="m_notification is_single">
# 	<strong class="mn_ok">구독완료</strong>
# 	{{#officeInfos}}
# 	<div class="mn_text">
# 		<h4 class="mn_h">{{officeName}} 뉴스를 <br> <span class="m_em">알림</span>으로 받아 보시겠습니까?</h4>
# 		<p class="mn_p">언론사의 주요 콘텐츠를 <br> 네이버에서 빠르게 확인할 수 있습니다.</p>
# 	</div>
# 	{{/officeInfos}}
# 	<div class="mn_btns">
# 		<button type="button" class="mn_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}no">닫기</button>
# 		<button type="button" class="mn_btn as_em _MODAL_LAYER_POSITIVE" data-clk="{{nclk}}yes">알림받기</button>
# 	</div>
# </div>
# </script>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION_ALL" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="m_notification">
# 	<strong class="mn_ok">구독완료</strong>
# 	<div class="mn_text">
# 		<h4 class="mn_h">언론사의 주요 뉴스를 <br> <span class="m_em">알림</span>으로 받아 보시겠습니까?</h4>
# 		<ul class="mn_list">
# 			{{#officeInfos}}
# 			<li class="mn_item">
# 				<div class="mn_head">
# 					<div class="mn_img">
# 						<img src="{{logo}}" alt="">
# 					</div>
# 					<div class="mn_name">{{officeName}}</div>
# 				</div>
# 				<div class="mn_body">
# 					<button type="button" class="mn_noti _ALL_OFFICES_NOTIFICATION_ITEM" data-oid="{{officeId}}" data-clk-add="notchnon" data-clk-remove="notchnoff">알림받기 사용함</button>
# 				</div>
# 			</li>
# 			{{/officeInfos}}
# 		</ul>
# 	</div>
# 	<div class="mn_btns">
# 		<button type="button" class="mn_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}no">닫기</button>
# 		<button type="button" class="mn_btn as_em _MODAL_LAYER_POSITIVE _CHANNEL_BANNER_ITEM_NOTICE_COMPLETE" data-clk="{{nclk}}yes">완료</button>
# 	</div>
# </div>
# </script>
# <div id="_MODAL_COMMENT_FOLLOW_TUTORIAL" style="display: none;"></div>
# <script class="_MODAL_COMMENT_FOLLOW_TUTORIAL_TEMPLATE" type="x-tmpl-mustache">
# <div class="comment_follow_tutorial" role="dialog" aria-modal="true">
# 	<div class="comment_follow_tutorial_layer">
# 		<div class="comment_follow_tutorial_layer_dimmed"></div>
# 		<div class="comment_follow_tutorial_layer_container">
# 			<div class="comment_follow_tutorial_layer_content">
# 				<div class="comment_follow_tutorial_layer_item">
# 					<p class="{{className}}">{{text}}</p>
# 					<i class="comment_follow_tutorial_layer_closeicon"></i>
# 					<button type="button" class="comment_follow_tutorial_layer_close _MODAL_COMMENT_FOLLOW_TUTORIAL_CLOSE" data-clk="{{nclkPrefix}}tutclose">닫기</button>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# </div>
# </script>
# <div class="ticker" id="_TICKER_LAYER_FOR_NOTIFICATION" style="display: none;"></div>
# <script class="_TICKER_LAYER_TEMPLATE_FOR_NOTIFICATION" type="x-tmpl-mustache">
# {{#officeInfos}}
# <p class="t_inner"><em class="t_point">{{officeName}}</em> 언론사 알림이 설정되었습니다.</p>
# {{/officeInfos}}
# </script>
# <script src="https://static-nnews.pstatic.net/js/min/20230427/library.min.js"></script>
# <script src="https://static-nnews.pstatic.net/js/min/20230427/read.min.js"></script>
# <script>
# 	window.ntm = window.ntm || [];
# 	var ntmOption = {};
#
# 	if (ntmOption) {
#
# 		var section = {"id":"102","name":"사회"};
# 		var redirectSection = {"id":"101","name":"경제"};
#
# 		ntmOption["channelId"] = article.officeId;
#
# 		// 기타 또는 주요 섹션 이름
# 		var nilSendSectionName = "기타";
# 		var nilSendSectionId = "";
# 		if (/100|101|102|103|104|105|106|107/.test(section.id)) {
# 			nilSendSectionName = section.name;
# 			nilSendSectionId = section.id;
# 		}
#
# 		// 기사 타입
# 		var htArticleTypeName = { "0": "text", "1": "photo", "2": "tv" };
# 		var articleTypeName = htArticleTypeName[article.type] || "";
#
# 		ntmOption["hitType"] = "cv";
# 		ntmOption["eventCategory"] = "post_view";
# 		ntmOption["uri"] = "http://news.naver.com/main/read.nhn?oid=032&aid=0003161880";
# 		ntmOption["gdid"] = article.gdid;
# 		ntmOption["dimension1"] = encodeURIComponent(nilSendSectionName);
# 		ntmOption["dimension4"] = articleTypeName;
# 		ntmOption["optional2"] = nilSendSectionId;
#
# 		var journalistIdList = [];
#
# 		// 기자 목록
# 		$("._JOURNALIST_CARD ._JOURNALIST_ID").each(function (index, object) {
# 			var $this = $(object);
# 			var journalistId = $this.attr("data-journalistId");
#
# 			if (journalistId && journalistIdList.indexOf(journalistId) === -1) {
# 				journalistIdList.push(journalistId);
# 			}
# 		});
#
# 		if (journalistIdList.length > 0) {
# 			ntmOption["dimension3"] = journalistIdList.join("___");
# 		}
#
# 		if (location.href.match(/ntype=RANKING/)) {
# 			ntmOption["dimension5"] = "y";
# 		}
#
# 		if (service.sports) {
# 			ntmOption["dimension2"] = article.sectionInfo.secondSection + "." + article.sectionInfo.thirdSection;
# 		}
#
# 		var seriesComponentId = $("._VALID_SERIES").attr("data-component-id");
# 		ntmOption["dimension6"] = seriesComponentId;
#
# 		if (/[?|&]type=breakingnews(&|$)/.test(location.href) === true) {
# 			if (/(m\.naver\.com)|(media\.naver\.com)|(news\.naver\.com\/?$)/.test(document.referrer) === true) {
# 				ntmOption["dimension7"] = "breaking";
# 			}
# 		}
#
# 		var ntmLeaveOption = $.extend({}, ntmOption);
# 		ntmLeaveOption["hitType"] = "event";
# 		ntmLeaveOption["eventCategory"] = "action";
# 		ntmLeaveOption["eventAction"] = "leave";
#
# 		if (/\/article\/comment\//.test(location.href) == false) {
# 			if (window.addEventListener) {
# 				window.addEventListener("load", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 				}, false);
# 				window.addEventListener("unload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 				}, false);
# 			} else if (window.attachEvent) {
# 				window.attachEvent("onload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 				});
# 				window.attachEvent("onunload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 				});
# 			} else {
# 				var fnOnUnload = window.onunload;
# 				window.onunload = function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 					if (fnOnUnload) {
# 						fnOnUnload();
# 					}
# 				};
#
# 				var fnOnload = window.onload;
# 				window.onload = function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 					if (fnOnload) {
# 						fnOnload();
# 					}
# 				};
# 			}
# 		}
# 	}
# </script>
# </div>
# <script>
# 			var eventType = "onpageshow" in window ? "pageshow" : "load";
# 			$(window).on(eventType, function() {
# 				lcs_do_gdid("8800006B_000000000000000003161880");
#
# 				// ma 로그 전송
# 				var data = {
# 					"service": "news",
# 					"baseInfo": {
# 						"category": (/\/article\/comment\//.test(location.href) == true) ? "댓글" : "본문",
# 					},
# 					"extraInfo": {
# 						"articleId": article.articleId,
# 						"sectionId": article.sectionId,
# 						"officeId": article.officeId,
# 						"articleType": article.type
# 					}
# 				};
#
# 				if (typeof ma !== "undefined") {
# 					ma.init({
# 						api: "https://ma.news.naver.com/l",
# 						data: data,
# 						contentBodyEl: document.querySelector("._article_content"),
# 						contentBodyVideoWrapperSelector: "._VIDEO_AREA"
# 					});
# 				}
#
# 				if (window.matchMedia("(prefers-color-scheme)").media === "not all") {
# 					$("html").removeClass("DARK_THEME");
# 				}
# 			});
# 		</script>
# </body>
# </html>

# %%
# 제목 추출 #title_area > span
target = soup.select_one("#title_area > span")
print(target)
print("-"*100)
target = target.text # tag를 떼고 추출
print(target)
# Out:
# <span>‘7% 할인’ 서울광역상품권 또 풀린다···“출생연도 홀짝수로 구매시간 분리”</span>
# ----------------------------------------------------------------------------------------------------
# ‘7% 할인’ 서울광역상품권 또 풀린다···“출생연도 홀짝수로 구매시간 분리”

# %%
# 본문 추출 : #dic_area
target = soup.select_one("#dic_area")
print(target)
print("-"*100)
target = target.text
print(target)
# Out:
# <div class="go_trans _article_content" id="dic_area">
# <strong class="media_end_summary">1차는 6만4650명 구매···평균 39만원어치 팔려<br/>서울시 “서울페이플러스 회원 가입은 전날 미리”</strong><span class="end_photo_org"><div class="nbd_im_w _LAZY_LOADING_WRAP">
# <div class="nbd_a _LAZY_LOADING_ERROR_HIDE" id="img_a1">
# <img class="_LAZY_LOADING" data-src="https://imgnews.pstatic.net/image/032/2022/07/24/0003161880_001_20220724112401144.jpg?type=w647" id="img1">
# </img></div>
# </div><em class="img_desc">한 시민이 초복을 하루 앞둔 지난 15일 서울 시내 대형마트에서 장을 보고 있다. |성동훈 기자</em></span><br/><br/>서울 25개 자치구 어디에서나 쓸 수 있는 ‘서울사랑상품권(광역상품권)’이 오는 28일 추가 발행된다. 1차 발행 때처럼 동시접속자가 몰리는 것을 막기 위해 이번에는 출생연도를 기준으로 홀수는 오전 10시부터, 짝수는 오후 2시부터 각각 4시간씩 구매할 수 있다.<br/><br/>서울시는 7% 할인금액으로 구매할 수 있는 광역상품권을 28일 발행한다고 24일 밝혔다. 발행 규모는 1차(250억원) 때보다 2배 많은 총 500억원이다. 시민들의 장바구니 물가 부담을 덜고 소상공인 매출증대를 통한 지역경제 활성화를 위해 2차 발행 규모를 늘렸다고 서울시는 설명했다.<br/><br/>광역상품권은 서울 25개 자치구 내 가맹점 어디에서나 사용할 수 있는 상품권으로 1인당 월 40만원까지 구매할 수 있다. 보유는 총 100만원까지 가능하다. 지난 14일 1차 발행 상품권을 구매한 소비자는 총 6만4650명이었으며, 평균 구매 금액은 약 38만7000원이었다.<br/><br/>서울시는 2차 광역상품권 발행을 28일 오전과 오후로 나눠 진행한다. 지난 1차 발행 당시 구매접속 폭주로 한때 시스템이 먹통됐던 만큼 시스템 부하 등을 막기 위해서다. 1차는 발행 1시간여 만에 완판됐다.<br/><br/>이번에는 출생년도에 따라 홀수는 오전 10시부터 오후 2시까지, 짝수는 오후 2시부터 오후 6시까지 구입할 수 있다. 발행금액은 각 250억원씩 총 500억원이다. 오후 6시 이후에는 판매가능 금액이 남아있을 경우 홀짝수에 관계 없이 누구나 구매할 수 있다. 구매는 서울페이플러스 외에도 티머니페이, 신한SOL, 머니트리 등과 같은 결제 애플리케이션에서도 가능하다.<br/><br/>서울시는 시민들이 불편없이 광역상품권을 구매할 수 있도록 서울페이플러스 서버 용량을 1차 발행 대비 2배 이상 늘렸다. 이에 따라 동시 거래처리량은 초당 200건에서 1000건으로 5배 늘었다. 또 장시간 대기를 막기 위해 상품권 구매·결제단계에 ‘대기자 유량관리시스템’을 도입해 처리속도를 높였으며, 접속량 폭증 시 자동 튕겨나감을 막기 위해 로그아웃 시간을 자동 연장하도록 했다. 특히 편법 구매가 가능한 것으로 알려진 휴대전화 비행기 모드 전환시 후순위 대기순번으로 세팅되며 중복구매를 막기 위한 시스템도 탑재했다.<br/><br/>다만 시스템 과부하를 마기 위해 발행 당일 선물하기, 회원가입, 가맹점찾기 등 일부 서비스는 중단된다. 서울시는 광역상품권 구매를 원할 경우 발행 전날에는 미리 서울페이플러스에 회원가입을 해달라고 당부했다.<br/><br/>서울시는 자치구별로 발행해 해당 자치구 내 가맹점에서만 사용 가능한 10% 할인 서울사랑상품권도 추석 전인 9월 초 3670억원 규모로 발행할 계획이다.
# 		</div>
# ----------------------------------------------------------------------------------------------------
#
# 1차는 6만4650명 구매···평균 39만원어치 팔려서울시 “서울페이플러스 회원 가입은 전날 미리”
#
#
#
# 한 시민이 초복을 하루 앞둔 지난 15일 서울 시내 대형마트에서 장을 보고 있다. |성동훈 기자서울 25개 자치구 어디에서나 쓸 수 있는 ‘서울사랑상품권(광역상품권)’이 오는 28일 추가 발행된다. 1차 발행 때처럼 동시접속자가 몰리는 것을 막기 위해 이번에는 출생연도를 기준으로 홀수는 오전 10시부터, 짝수는 오후 2시부터 각각 4시간씩 구매할 수 있다.서울시는 7% 할인금액으로 구매할 수 있는 광역상품권을 28일 발행한다고 24일 밝혔다. 발행 규모는 1차(250억원) 때보다 2배 많은 총 500억원이다. 시민들의 장바구니 물가 부담을 덜고 소상공인 매출증대를 통한 지역경제 활성화를 위해 2차 발행 규모를 늘렸다고 서울시는 설명했다.광역상품권은 서울 25개 자치구 내 가맹점 어디에서나 사용할 수 있는 상품권으로 1인당 월 40만원까지 구매할 수 있다. 보유는 총 100만원까지 가능하다. 지난 14일 1차 발행 상품권을 구매한 소비자는 총 6만4650명이었으며, 평균 구매 금액은 약 38만7000원이었다.서울시는 2차 광역상품권 발행을 28일 오전과 오후로 나눠 진행한다. 지난 1차 발행 당시 구매접속 폭주로 한때 시스템이 먹통됐던 만큼 시스템 부하 등을 막기 위해서다. 1차는 발행 1시간여 만에 완판됐다.이번에는 출생년도에 따라 홀수는 오전 10시부터 오후 2시까지, 짝수는 오후 2시부터 오후 6시까지 구입할 수 있다. 발행금액은 각 250억원씩 총 500억원이다. 오후 6시 이후에는 판매가능 금액이 남아있을 경우 홀짝수에 관계 없이 누구나 구매할 수 있다. 구매는 서울페이플러스 외에도 티머니페이, 신한SOL, 머니트리 등과 같은 결제 애플리케이션에서도 가능하다.서울시는 시민들이 불편없이 광역상품권을 구매할 수 있도록 서울페이플러스 서버 용량을 1차 발행 대비 2배 이상 늘렸다. 이에 따라 동시 거래처리량은 초당 200건에서 1000건으로 5배 늘었다. 또 장시간 대기를 막기 위해 상품권 구매·결제단계에 ‘대기자 유량관리시스템’을 도입해 처리속도를 높였으며, 접속량 폭증 시 자동 튕겨나감을 막기 위해 로그아웃 시간을 자동 연장하도록 했다. 특히 편법 구매가 가능한 것으로 알려진 휴대전화 비행기 모드 전환시 후순위 대기순번으로 세팅되며 중복구매를 막기 위한 시스템도 탑재했다.다만 시스템 과부하를 마기 위해 발행 당일 선물하기, 회원가입, 가맹점찾기 등 일부 서비스는 중단된다. 서울시는 광역상품권 구매를 원할 경우 발행 전날에는 미리 서울페이플러스에 회원가입을 해달라고 당부했다.서울시는 자치구별로 발행해 해당 자치구 내 가맹점에서만 사용 가능한 10% 할인 서울사랑상품권도 추석 전인 9월 초 3670억원 규모로 발행할 계획이다.

# %%
# 이미지 주소 추출 : #img1
target = soup.select_one("#img1")
print(target)
print("-"*100)
target = target["data-src"]
print(target)
# Out:
# <img class="_LAZY_LOADING" data-src="https://imgnews.pstatic.net/image/032/2022/07/24/0003161880_001_20220724112401144.jpg?type=w647" id="img1">
# </img>
# ----------------------------------------------------------------------------------------------------
# https://imgnews.pstatic.net/image/032/2022/07/24/0003161880_001_20220724112401144.jpg?type=w647

# %%
# 네이버 환율 가져오기 : #exchangeList > li.on > a.head.usd > div > span.value
from bs4 import BeautifulSoup
import urllib.request as req
# HTML 가져오기
url = "https://finance.naver.com/marketindex/"
res = req.urlopen(url)
# HTML 분석하기
soup = BeautifulSoup(res, "html.parser")
# 원하는 데이터 추출하기
price = soup.select_one("#exchangeList > li.on > a.head.usd > div > span.value").string
print("usd/krw =", price)
# Out:
# usd/krw = 1,341.00

# %% [markdown]
# #### Q. url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100' 사이트에서 뉴스기사를 출력하세요.

# %%
# A.
# select()
import requests as rq
from bs4 import BeautifulSoup
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}

url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100'
r = rq.get(url, headers=headers)
html = r.text
bs = BeautifulSoup(html,'lxml')
lines = bs.select('#main_content > div > div > div > div > div > ul > li > div > a')
body = '\n'.join([line.text for line in lines])
print(body)
# Out:
# 김기현, '음주운전 방지장치 의무화법' 발의…"음주운전, 커다란 해악"
# 두 차례 음주운전 30대 남성 또 음주운전... 법원, 집행유예
# 김기현, ‘음주운전 방지장치 의무화’ 대표발의…설치비용은 음주자 부담으로
# 김기현 ‘음주운전 방지 장치 의무화’ 도로교통법 개정안 발의
# 하버드 연단 선 尹, 중·러 겨냥…"힘에 의한 현상변경 안돼"
# 尹대통령 "자유 위협하는 세력은 공동체 안에도 있다"
# 윤 대통령 “자유 무시 결정판이 북한…용기와 연대로 민주주의 지켜야”
# 尹대통령 첫 하버드대 연설…"자유 무시, 결연한 연대 대응"
# 통일부, 北 김여정 비방에 “적반하장 억지 주장…좌절감 반영돼”
# 北 김여정, '워싱턴 선언' 맹비난…바이든에 "미래 없는 늙은이"
# 통일부, 북한 김여정 막말에 "허둥지둥 억지 주장…초조함 반영"
# 통일부, 北김여정 비방에 "저급한 수준…국제사회 웃음거리"
# MIT 석학들 만난 尹…디지털바이오 혁신 논의
# 윤 대통령, MIT 디지털바이오 석학들과 대담
# 尹, MIT 석학 만남…"韓 과학기술 인력, 보스턴에 보내 배울 것"(종합2보)
# MIT 석학 만난 尹 "한국 과학기술인력 많이 보낼 것"
# 5차례 대면한 양국 정상 ‘케미’ 빛났다
#  5번 만남에 끈끈해진 한미 정상…`어깨동무` 만찬 백미[국빈 방미 결산]
# 尹 "워싱턴 선언, 불가피한 선택… 정부 바뀐다고 바뀔 문제 아냐"(종합)
# 尹 "北 핵보유 인정하면 韓도 핵보유…마음 먹으면 1년內 핵무장"
# 민주당 “핵인지 감수성, 등장할 판” 워싱턴선언 비판
# 민주, 귀국 尹에 "이번 방미는 대국민 사기 외교…냉정한 평가 직시해야"
# 이재명 "박광온과 견고한 통합 이룰 것…우리 안 차이 안 커"
# 이재명 "박광온과 '담대한 변화·견고한 통합' 반드시 이룰 것"
# 간호법·특검법 여야 대치...尹 귀국 후 거부권 주목
# 巨野 강행 처리→尹 거부권 반복…눈살 찌푸리는 ‘파워게임’
# 윤 대통령, 국빈 방미 마무리하고 한국으로 출발
# 尹대통령, 5박7일 국빈 방미 마치고 귀국…김기현·윤재옥 공항서 환영
# 박지원 '바이든 듀엣설'에 대통령실 "사실무근, 반국가적 행태"
# 대통령실, 박지원 겨냥 "국익 훼손 반국가적 작태"
# '돈봉투' 여파에 기로 놓인 대의원제도…민주당의 선택은?
# 비명계 강력 반발속… 민주, `대의원제 축소` 밀어붙이나
# 박대출, 민주 향해 “무지·무모·무책임에 의료대란…돈봉투 시선 못돌려”
# 박대출 “갈등조장법으로 돈봉투 가릴 수 없어”… 간호법 저격
# 국민의힘, "송영길 '물극필반' 아닌 '사필귀정'"
# 국민의힘, “송영길 ‘물극필반’ 아닌 ‘사필귀정’”
# 박진 외교부 장관, 내달 1~2일 말레이 방문
# 박진 장관, 내일부터 말레이시아 방문…공급망·방산 등 실질협력 논의
# 尹 귀국에 여야 공방전…"대국민 사기 외교" vs "워싱턴선언, 승리 방정식"
# 與신원식 "워싱턴선언, 제2의 한미상호방위조약…핵파트너 도약"

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import ssl

context = ssl._create_unverified_context()
html = urlopen('http://www.pythonscraping.com/pages/page3.html')
bs = BeautifulSoup(html,'html.parser')
bs.find('table')
# Out:
# <table id="giftList">
# <tr><th>
# Item Title
# </th><th>
# Description
# </th><th>
# Cost
# </th><th>
# Image
# </th></tr>
# <tr class="gift" id="gift1"><td>
# Vegetable Basket
# </td><td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td><td>
# $15.00
# </td><td>
# <img src="../img/gifts/img1.jpg"/>
# </td></tr>
# <tr class="gift" id="gift2"><td>
# Russian Nesting Dolls
# </td><td>
# Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
# </td><td>
# $10,000.52
# </td><td>
# <img src="../img/gifts/img2.jpg"/>
# </td></tr>
# <tr class="gift" id="gift3"><td>
# Fish Painting
# </td><td>
# If something seems fishy about this painting, it's because it's a fish! <span class="excitingNote">Also hand-painted by trained monkeys!</span>
# </td><td>
# $10,005.00
# </td><td>
# <img src="../img/gifts/img3.jpg"/>
# </td></tr>
# <tr class="gift" id="gift4"><td>
# Dead Parrot
# </td><td>
# This is an ex-parrot! <span class="excitingNote">Or maybe he's only resting?</span>
# </td><td>
# $0.50
# </td><td>
# <img src="../img/gifts/img4.jpg"/>
# </td></tr>
# <tr class="gift" id="gift5"><td>
# Mystery Box
# </td><td>
# If you love suprises, this mystery box is for you! Do not place on light-colored surfaces. May cause oil staining. <span class="excitingNote">Keep your friends guessing!</span>
# </td><td>
# $1.50
# </td><td>
# <img src="../img/gifts/img6.jpg"/>
# </td></tr>
# </table>

# %%
for child in bs.find('table',{'id':'giftList'}).children:
    print(child)
# Out:
# <tr><th>
# Item Title
# </th><th>
# Description
# </th><th>
# Cost
# </th><th>
# Image
# </th></tr>
#
#
# <tr class="gift" id="gift1"><td>
# Vegetable Basket
# </td><td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td><td>
# $15.00
# </td><td>
# <img src="../img/gifts/img1.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift2"><td>
# Russian Nesting Dolls
# </td><td>
# Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
# </td><td>
# $10,000.52
# </td><td>
# <img src="../img/gifts/img2.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift3"><td>
# Fish Painting
# </td><td>
# If something seems fishy about this painting, it's because it's a fish! <span class="excitingNote">Also hand-painted by trained monkeys!</span>
# </td><td>
# $10,005.00
# </td><td>
# <img src="../img/gifts/img3.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift4"><td>
# Dead Parrot
# </td><td>
# This is an ex-parrot! <span class="excitingNote">Or maybe he's only resting?</span>
# </td><td>
# $0.50
# </td><td>
# <img src="../img/gifts/img4.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift5"><td>
# Mystery Box
# </td><td>
# If you love suprises, this mystery box is for you! Do not place on light-colored surfaces. May cause oil staining. <span class="excitingNote">Keep your friends guessing!</span>
# </td><td>
# $1.50
# </td><td>
# <img src="../img/gifts/img6.jpg"/>
# </td></tr>

# %%
print(bs.find('img',{'src':'../img/gifts/img1.jpg'}).parent.previous_sibling.get_text())
# Out:
# $15.00

# %%
for sibling in bs.find('table',{'id':'giftList'}).tr.next_siblings:
    print(sibling)
# Out:
# <tr class="gift" id="gift1"><td>
# Vegetable Basket
# </td><td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td><td>
# $15.00
# </td><td>
# <img src="../img/gifts/img1.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift2"><td>
# Russian Nesting Dolls
# </td><td>
# Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
# </td><td>
# $10,000.52
# </td><td>
# <img src="../img/gifts/img2.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift3"><td>
# Fish Painting
# </td><td>
# If something seems fishy about this painting, it's because it's a fish! <span class="excitingNote">Also hand-painted by trained monkeys!</span>
# </td><td>
# $10,005.00
# </td><td>
# <img src="../img/gifts/img3.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift4"><td>
# Dead Parrot
# </td><td>
# This is an ex-parrot! <span class="excitingNote">Or maybe he's only resting?</span>
# </td><td>
# $0.50
# </td><td>
# <img src="../img/gifts/img4.jpg"/>
# </td></tr>
#
#
# <tr class="gift" id="gift5"><td>
# Mystery Box
# </td><td>
# If you love suprises, this mystery box is for you! Do not place on light-colored surfaces. May cause oil staining. <span class="excitingNote">Keep your friends guessing!</span>
# </td><td>
# $1.50
# </td><td>
# <img src="../img/gifts/img6.jpg"/>
# </td></tr>

# %%
html="""
<head>
    <title>crawler</title>
</head>
<body>
    <p class="a" align="center"> text1</p>
    <p class="b" align="center"> text2</p>
    <p class="c" align="center"> text3</p>
    <div>
        <img src="/source" width="300" height="200">
    </div>
</body>
</html>
"""

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html, 'html.parser')
contents = soup.find('body')
for child in contents.children:
    print(child)
# Out:
# <p align="center" class="a"> text1</p>
#
#
# <p align="center" class="b"> text2</p>
#
#
# <p align="center" class="c"> text3</p>
#
#
# <div>
# <img height="200" src="/source" width="300"/>
# </div>

# %%
# body 의 자손은 p, div, img 등
for d in contents.descendants:
    print(d)
# Out:
# <p align="center" class="a"> text1</p>
#  text1
#
#
# <p align="center" class="b"> text2</p>
#  text2
#
#
# <p align="center" class="c"> text3</p>
#  text3
#
#
# <div>
# <img height="200" src="/source" width="300"/>
# </div>
#
#
# <img height="200" src="/source" width="300"/>

# %%
img_tag = contents.find('img')
print(img_tag)
print(img_tag.parent)
# Out:
# <img height="200" src="/source" width="300"/>
# <div>
# <img height="200" src="/source" width="300"/>
# </div>

# %%
print(list(img_tag.parents))
# Out:
# [<div>
# <img height="200" src="/source" width="300"/>
# </div>, <body>
# <p align="center" class="a"> text1</p>
# <p align="center" class="b"> text2</p>
# <p align="center" class="c"> text3</p>
# <div>
# <img height="200" src="/source" width="300"/>
# </div>
# </body>,
# <head>
# <title>crawler</title>
# </head>
# <body>
# <p align="center" class="a"> text1</p>
# <p align="center" class="b"> text2</p>
# <p align="center" class="c"> text3</p>
# <div>
# <img height="200" src="/source" width="300"/>
# </div>
# </body>
#
# ]

# %%
# 태그 객체
contents.div.img
# Out:
# <img height="200" src="/source" width="300"/>

# %%
print(contents,'\n')
print(img_tag.find_parent('body'),'\n')
print(img_tag.find_parent('div'))
# Out:
# <body>
# <p align="center" class="a"> text1</p>
# <p align="center" class="b"> text2</p>
# <p align="center" class="c"> text3</p>
# <div>
# <img height="200" src="/source" width="300"/>
# </div>
# </body>
#
# <body>
# <p align="center" class="a"> text1</p>
# <p align="center" class="b"> text2</p>
# <p align="center" class="c"> text3</p>
# <div>
# <img height="200" src="/source" width="300"/>
# </div>
# </body>
#
# <div>
# <img height="200" src="/source" width="300"/>
# </div>

# %%
print(contents,'\n')
print(img_tag.find_parent('body'),'\n')
print(img_tag.find_parent('div'))

# %%
p_tag = soup.find('p',class_='b')
print(p_tag)
# Out:
# <p align="center" class="b"> text2</p>

# %%
# find_previous_sibling() : 바로 이전 형제 노드를 검색
# find_previous_siblings() : 모든 형제 노드를 검색
print(p_tag.find_previous_sibling())
print(p_tag.find_previous_siblings())
# Out:
# <p align="center" class="a"> text1</p>
# [<p align="center" class="a"> text1</p>]

# %%
import urllib
from bs4 import BeautifulSoup
response = urllib.request.urlopen('https://naver.com')
byte_data = response.read()
html = byte_data.decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')
print(soup.find_all('a',{'class':'link_newsstand'}),'\n')
print(soup.find_all('a',{'class':'btn_sort'}))
# Out:
# [<a class="link_newsstand" data-clk="title" href="http://newsstand.naver.com/" target="_blank">뉴스스탠드</a>]
#
# [<a aria-controls="NM_NEWSSTAND_MY_LIST" aria-selected="false" class="btn_sort" data-clk="my" data-type="my" href="#" role="tab">구독한 언론사</a>, <a aria-controls="NM_NEWSSTAND_DEFAULT_THUMB" aria-selected="true" class="btn_sort" data-clk="all" data-type="all" href="#" role="tab">전체언론사</a>]

# %%
nlists = soup.findAll('a',{'class':{'link_newsstand','btn_sort'}})
for n in nlists:
#     print(n.text)
    print(n.get_text())
# Out:
# 뉴스스탠드
# 구독한 언론사
# 전체언론사

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen('https://naver.com')
bs = BeautifulSoup(html,'html.parser')

hlists = bs.findAll({'h1','h2','h3','h4','h5','h6'},limit=5)
for h in hlists:
    print(h, '\n')
# Out:
# <h1 class="logo_default">
# <a class="logo_naver" data-clk="top.logo" href="/"><span class="blind">네이버</span></a>
# </h1>
#
# <h2 class="blind">뉴스스탠드</h2>
#
# <h2 class="blind">주제별 캐스트</h2>
#
# <h2 class="blind">Sign in</h2>
#
# <h2 class="blind">타임스퀘어</h2>

# %%
hlists = bs.findAll({'h1','h2','h3','h4','h5','h6'}, text='뉴스스탠드')
print(hlists)
# Out:
# [<h2 class="blind">뉴스스탠드</h2>]

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')
bs.find('div', {'id':'bodyContent'}).find_all('a')
# Out:
# [<a href="/wiki/Wikipedia:Protection_policy#semi" title="This article is semi-protected to promote compliance with the policy on biographies of living persons"><img alt="Page semi-protected" data-file-height="512" data-file-width="512" decoding="async" height="20" src="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/30px-Semi-protection-shackle.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/40px-Semi-protection-shackle.svg.png 2x" width="20"/></a>,
#  <a class="mw-disambig" href="/wiki/Kevin_Bacon_(disambiguation)" title="Kevin Bacon (disambiguation)">Kevin Bacon (disambiguation)</a>,
#  <a class="image" href="/wiki/File:Kevin_Bacon_SDCC_2014.jpg"><img alt="Kevin Bacon SDCC 2014.jpg" data-file-height="2649" data-file-width="1907" decoding="async" height="306" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Kevin_Bacon_SDCC_2014.jpg/220px-Kevin_Bacon_SDCC_2014.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Kevin_Bacon_SDCC_2014.jpg/330px-Kevin_Bacon_SDCC_2014.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/d7/Kevin_Bacon_SDCC_2014.jpg/440px-Kevin_Bacon_SDCC_2014.jpg 2x" width="220"/></a>,
#  <a href="/wiki/Philadelphia" title="Philadelphia">Philadelphia</a>,
#  <a href="/wiki/Kevin_Bacon_filmography" title="Kevin Bacon filmography">Filmography</a>,
#  <a href="/wiki/Kyra_Sedgwick" title="Kyra Sedgwick">Kyra Sedgwick</a>,
#  <a href="/wiki/Sosie_Bacon" title="Sosie Bacon">Sosie Bacon</a>,
#  <a href="#cite_note-1">[1]</a>,
#  <a href="/wiki/Edmund_Bacon_(architect)" title="Edmund Bacon (architect)">Edmund Bacon</a>,
#  <a href="/wiki/Michael_Bacon_(musician)" title="Michael Bacon (musician)">Michael Bacon</a>,
#  <a href="/wiki/Holly_Near" title="Holly Near">Holly Near</a>,
#  <a href="/wiki/Wikipedia:Citation_needed" title="Wikipedia:Citation needed"><span title="This claim needs references to reliable sources. (October 2021)">citation needed</span></a>,
#  <a class="external text" href="http://baconbros.com/" rel="nofollow">baconbros<wbr/>.com</a>,
#  <a href="#cite_note-2">[2]</a>,
#  <a href="#cite_note-actor-3">[3]</a>,
#  <a class="mw-redirect" href="/wiki/Leading_man" title="Leading man">leading man</a>,
#  <a href="/wiki/Character_actor" title="Character actor">character roles</a>,
#  <a class="mw-redirect" href="/wiki/Golden_Globe_Award" title="Golden Globe Award">Golden Globe Award</a>,
#  <a class="mw-redirect" href="/wiki/Screen_Actors_Guild_Award" title="Screen Actors Guild Award">Screen Actors Guild Award</a>,
#  <a class="mw-redirect" href="/wiki/Primetime_Emmy_Award" title="Primetime Emmy Award">Primetime Emmy Award</a>,
#  <a href="/wiki/The_Guardian" title="The Guardian">The Guardian</a>,
#  <a class="mw-redirect" href="/wiki/Academy_Award" title="Academy Award">Academy Award</a>,
#  <a href="#cite_note-4">[4]</a>,
#  <a href="/wiki/Hollywood_Walk_of_Fame" title="Hollywood Walk of Fame">Hollywood Walk of Fame</a>,
#  <a href="#cite_note-5">[5]</a>,
#  <a class="mw-redirect" href="/wiki/National_Lampoon%27s_Animal_House" title="National Lampoon's Animal House">National Lampoon's Animal House</a>,
#  <a href="/wiki/Footloose_(1984_film)" title="Footloose (1984 film)">Footloose</a>,
#  <a href="/wiki/Diner_(1982_film)" title="Diner (1982 film)">Diner</a>,
#  <a href="/wiki/JFK_(film)" title="JFK (film)">JFK</a>,
#  <a href="/wiki/A_Few_Good_Men" title="A Few Good Men">A Few Good Men</a>,
#  <a href="/wiki/Apollo_13_(film)" title="Apollo 13 (film)">Apollo 13</a>,
#  <a href="/wiki/Mystic_River_(film)" title="Mystic River (film)">Mystic River</a>,
#  <a href="/wiki/Frost/Nixon_(film)" title="Frost/Nixon (film)">Frost/Nixon</a>,
#  <a href="/wiki/Friday_the_13th_(1980_film)" title="Friday the 13th (1980 film)">Friday the 13th</a>,
#  <a href="/wiki/The_River_Wild" title="The River Wild">The River Wild</a>,
#  <a href="/wiki/Sleepers_(film)" title="Sleepers (film)">Sleepers</a>,
#  <a href="/wiki/Wild_Things_(film)" title="Wild Things (film)">Wild Things</a>,
#  <a href="/wiki/The_Woodsman_(2004_film)" title="The Woodsman (2004 film)">The Woodsman</a>,
#  <a href="/wiki/Flatliners" title="Flatliners">Flatliners</a>,
#  <a href="/wiki/Crazy,_Stupid,_Love" title="Crazy, Stupid, Love">Crazy, Stupid, Love</a>,
#  <a href="/wiki/X-Men:_First_Class" title="X-Men: First Class">X-Men: First Class</a>,
#  <a href="/wiki/Black_Mass_(film)" title="Black Mass (film)">Black Mass</a>,
#  <a href="/wiki/Patriots_Day_(film)" title="Patriots Day (film)">Patriots Day</a>,
#  <a href="/wiki/Losing_Chase" title="Losing Chase">Losing Chase</a>,
#  <a href="/wiki/Loverboy_(2005_film)" title="Loverboy (2005 film)">Loverboy</a>,
#  <a href="/wiki/Fox_Broadcasting_Company" title="Fox Broadcasting Company">Fox</a>,
#  <a href="/wiki/The_Following" title="The Following">The Following</a>,
#  <a href="/wiki/Michael_Strobl" title="Michael Strobl">Lt. Col. Michael Strobl</a>,
#  <a href="/wiki/HBO" title="HBO">HBO</a>,
#  <a href="/wiki/Taking_Chance" title="Taking Chance">Taking Chance</a>,
#  <a href="/wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film" title="Golden Globe Award for Best Actor – Miniseries or Television Film">Golden Globe Award for Best Actor – Miniseries or Television Film</a>,
#  <a href="/wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie" title="Screen Actors Guild Award for Outstanding Performance by a Male Actor in a Miniseries or Television Movie">Screen Actors Guild Award for Outstanding Actor in a Miniseries or Television Movie</a>,
#  <a href="/wiki/Amazon_Prime_Video" title="Amazon Prime Video">Amazon Prime Video</a>,
#  <a href="/wiki/I_Love_Dick_(TV_series)" title="I Love Dick (TV series)">I Love Dick</a>,
#  <a href="/wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy" title="Golden Globe Award for Best Actor – Television Series Musical or Comedy">Golden Globe Award</a>,
#  <a href="/wiki/Showtime_(TV_network)" title="Showtime (TV network)">Showtime</a>,
#  <a href="/wiki/City_on_a_Hill_(TV_series)" title="City on a Hill (TV series)">City on a Hill</a>,
#  <a href="#cite_note-6">[6]</a>,
#  <a href="/wiki/Six_Degrees_of_Kevin_Bacon" title="Six Degrees of Kevin Bacon">Six Degrees of Kevin Bacon</a>,
#  <a href="/wiki/SixDegrees.org" title="SixDegrees.org">SixDegrees.org</a>,
#  <a href="#cite_note-walk-7">[7]</a>,
#  <a href="/wiki/EE_Limited" title="EE Limited">EE</a>,
#  <a href="#cite_note-8">[8]</a>,
#  <a href="/wiki/Philadelphia" title="Philadelphia">Philadelphia</a>,
#  <a href="#cite_note-actor-3">[3]</a>,
#  <a href="#cite_note-actor-3">[3]</a>,
#  <a href="/wiki/Edmund_Bacon_(architect)" title="Edmund Bacon (architect)">Edmund Bacon</a>,
#  <a href="/wiki/Urban_planning" title="Urban planning">urban planner</a>,
#  <a href="/wiki/Design_of_Cities" title="Design of Cities">Design of Cities</a>,
#  <a href="#cite_note-bacon-9">[9]</a>,
#  <a href="/wiki/Julia_R._Masterman_School" title="Julia R. Masterman School">Julia R. Masterman School</a>,
#  <a href="/wiki/Spring_Garden,_Philadelphia" title="Spring Garden, Philadelphia">Spring Garden</a>,
#  <a href="#cite_note-10">[10]</a>,
#  <a href="/wiki/Pennsylvania_Governor%27s_School_for_the_Arts" title="Pennsylvania Governor's School for the Arts">Pennsylvania Governor's School for the Arts</a>,
#  <a href="/wiki/Bucknell_University" title="Bucknell University">Bucknell University</a>,
#  <a href="/wiki/Lewisburg,_Pennsylvania" title="Lewisburg, Pennsylvania">Lewisburg, Pennsylvania</a>,
#  <a href="#cite_note-11">[11]</a>,
#  <a href="/wiki/Glory_Van_Scott" title="Glory Van Scott">Glory Van Scott</a>,
#  <a href="#cite_note-walk-7">[7]</a>,
#  <a href="#cite_note-bacon-9">[9]</a>,
#  <a href="/wiki/Kevin_Bacon_filmography" title="Kevin Bacon filmography">Kevin Bacon filmography</a>,
#  <a class="mw-redirect" href="/wiki/Circle_in_the_Square" title="Circle in the Square">Circle in the Square Theater School</a>,
#  <a class="mw-redirect" href="/wiki/Nancy_Mills" title="Nancy Mills">Nancy Mills</a>,
#  <a href="/wiki/Cosmopolitan_(magazine)" title="Cosmopolitan (magazine)">Cosmopolitan</a>,
#  <a href="#cite_note-cosmo91-12">[12]</a>,
#  <a href="/wiki/Fraternities_and_sororities" title="Fraternities and sororities">fraternity</a>,
#  <a href="/wiki/Animal_House" title="Animal House">National Lampoon's Animal House</a>,
#  <a href="#cite_note-bacon-9">[9]</a>,
#  <a href="/wiki/Search_for_Tomorrow" title="Search for Tomorrow">Search for Tomorrow</a>,
#  <a href="/wiki/Guiding_Light" title="Guiding Light">Guiding Light</a>,
#  <a href="/wiki/Friday_the_13th_(1980_film)" title="Friday the 13th (1980 film)"><i>Friday the 13th</i></a>,
#  <a href="#cite_note-13">[13]</a>,
#  <a href="/wiki/Getting_Out" title="Getting Out">Getting Out</a>,
#  <a href="/wiki/Phoenix_Theater" title="Phoenix Theater">Phoenix Theater</a>,
#  <a href="/wiki/Flux" title="Flux">Flux</a>,
#  <a class="mw-redirect" href="/wiki/Second_Stage_Theatre" title="Second Stage Theatre">Second Stage Theatre</a>,
#  <a href="#cite_note-bio-14">[14]</a>,
#  <a href="/wiki/Obie_Award" title="Obie Award">Obie Award</a>,
#  <a href="/wiki/Forty_Deuce" title="Forty Deuce">Forty Deuce</a>,
#  <a href="#cite_note-kevin-15">[15]</a>,
#  <a class="mw-redirect" href="/wiki/Slab_Boys" title="Slab Boys">Slab Boys</a>,
#  <a href="/wiki/Sean_Penn" title="Sean Penn">Sean Penn</a>,
#  <a href="/wiki/Val_Kilmer" title="Val Kilmer">Val Kilmer</a>,
#  <a href="/wiki/Barry_Levinson" title="Barry Levinson">Barry Levinson</a>,
#  <a href="/wiki/Diner_(1982_film)" title="Diner (1982 film)">Diner</a>,
#  <a href="/wiki/Steve_Guttenberg" title="Steve Guttenberg">Steve Guttenberg</a>,
#  <a href="/wiki/Daniel_Stern_(actor)" title="Daniel Stern (actor)">Daniel Stern</a>,
#  <a href="/wiki/Mickey_Rourke" title="Mickey Rourke">Mickey Rourke</a>,
#  <a href="/wiki/Tim_Daly" title="Tim Daly">Tim Daly</a>,
#  <a href="/wiki/Ellen_Barkin" title="Ellen Barkin">Ellen Barkin</a>,
#  <a href="#cite_note-16">[16]</a>,
#  <a href="/wiki/Footloose_(1984_film)" title="Footloose (1984 film)">Footloose</a>,
#  <a href="#cite_note-bio-14">[14]</a>,
#  <a href="/wiki/James_Dean" title="James Dean">James Dean</a>,
#  <a href="/wiki/Rebel_Without_a_Cause" title="Rebel Without a Cause">Rebel Without a Cause</a>,
#  <a href="/wiki/Mickey_Rooney" title="Mickey Rooney">Mickey Rooney</a>,
#  <a href="/wiki/Judy_Garland" title="Judy Garland">Judy Garland</a>,
#  <a href="#cite_note-time84-17">[17]</a>,
#  <a href="#cite_note-bacon-9">[9]</a>,
#  <a href="#cite_note-18">[18]</a>,
#  <a href="#cite_note-19">[19]</a>,
#  <a class="mw-redirect" href="/wiki/Typecasting_(acting)" title="Typecasting (acting)">typecasting</a>,
#  <a href="/wiki/John_Hughes_(filmmaker)" title="John Hughes (filmmaker)">John Hughes</a>,
#  <a href="/wiki/Planes,_Trains_and_Automobiles" title="Planes, Trains and Automobiles">Planes, Trains and Automobiles</a>,
#  <a href="#cite_note-20">[20]</a>,
#  <a href="/wiki/She%27s_Having_a_Baby" title="She's Having a Baby">She's Having a Baby</a>,
#  <a href="#cite_note-bio-14">[14]</a>,
#  <a href="/wiki/The_Big_Picture_(1989_film)" title="The Big Picture (1989 film)">The Big Picture</a>,
#  <a href="#cite_note-21">[21]</a>,
#  <a href="/wiki/Tremors_(1990_film)" title="Tremors (1990 film)">Tremors</a>,
#  <a href="#cite_note-22">[22]</a>,
#  <a href="/wiki/Joel_Schumacher" title="Joel Schumacher">Joel Schumacher</a>,
#  <a href="/wiki/Flatliners" title="Flatliners">Flatliners</a>,
#  <a href="#cite_note-bio-14">[14]</a>,
#  <a href="/wiki/Elizabeth_Perkins" title="Elizabeth Perkins">Elizabeth Perkins</a>,
#  <a href="/wiki/He_Said,_She_Said_(film)" title="He Said, She Said (film)">He Said, She Said</a>,
#  <a href="#cite_note-bio-14">[14]</a>,
#  <a href="/wiki/The_New_York_Times" title="The New York Times">The New York Times</a>,
#  <a href="#cite_note-nyt94-23">[23]</a>,
#  <a href="/wiki/Oliver_Stone" title="Oliver Stone">Oliver Stone</a>,
#  <a href="/wiki/JFK_(film)" title="JFK (film)">JFK</a>,
#  <a href="#cite_note-24">[24]</a>,
#  <a class="mw-redirect" href="/wiki/A_Few_Good_Men_(film)" title="A Few Good Men (film)">A Few Good Men</a>,
#  <a href="#cite_note-25">[25]</a>,
#  <a href="/wiki/Michael_Greif" title="Michael Greif">Michael Greif</a>,
#  <a href="#cite_note-bio-14">[14]</a>,
#  <a class="mw-redirect" href="/wiki/Golden_Globe_Award" title="Golden Globe Award">Golden Globe</a>,
#  <a href="/wiki/The_River_Wild" title="The River Wild">The River Wild</a>,
#  <a href="#cite_note-bio-14">[14]</a>,
#  <a href="/wiki/Meryl_Streep" title="Meryl Streep">Meryl Streep</a>,
#  <a href="/wiki/Murder_in_the_First_(film)" title="Murder in the First (film)">Murder in the First</a>,
#  <a href="#cite_note-bio-14">[14]</a>,
#  <a href="/wiki/Blockbuster_(entertainment)" title="Blockbuster (entertainment)">blockbuster</a>,
#  <a href="/wiki/Apollo_13_(film)" title="Apollo 13 (film)">Apollo 13</a>,
#  <a href="#cite_note-26">[26]</a>,
#  <a href="/wiki/Sleepers_(film)" title="Sleepers (film)">Sleepers</a>,
#  <a href="#cite_note-27">[27]</a>,
#  <a href="/wiki/Picture_Perfect_(1997_film)" title="Picture Perfect (1997 film)">Picture Perfect</a>,
#  <a href="#cite_note-bio-14">[14]</a>,
#  <a href="/wiki/Losing_Chase" title="Losing Chase">Losing Chase</a>,
#  <a href="#cite_note-austin-28">[28]</a>,
#  <a href="/wiki/Digging_to_China" title="Digging to China">Digging to China</a>,
#  <a href="#cite_note-bio-14">[14]</a>,
#  <a href="/wiki/Payola" title="Payola">payola</a>,
#  <a class="mw-redirect" href="/wiki/Telling_Lies_in_America_(film)" title="Telling Lies in America (film)">Telling Lies in America</a>,
#  <a href="#cite_note-bio-14">[14]</a>,
#  <a href="/wiki/Wild_Things_(film)" title="Wild Things (film)">Wild Things</a>,
#  <a href="/wiki/Stir_of_Echoes" title="Stir of Echoes">Stir of Echoes</a>,
#  <a href="/wiki/David_Koepp" title="David Koepp">David Koepp</a>,
#  <a href="#cite_note-29">[29]</a>,
#  <a class="image" href="/wiki/File:Kevin_Bacon_Cannes_2004.jpg"><img class="thumbimage" data-file-height="998" data-file-width="670" decoding="async" height="253" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/98/Kevin_Bacon_Cannes_2004.jpg/170px-Kevin_Bacon_Cannes_2004.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/98/Kevin_Bacon_Cannes_2004.jpg/255px-Kevin_Bacon_Cannes_2004.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/98/Kevin_Bacon_Cannes_2004.jpg/340px-Kevin_Bacon_Cannes_2004.jpg 2x" width="170"/></a>,
#  <a class="internal" href="/wiki/File:Kevin_Bacon_Cannes_2004.jpg" title="Enlarge"></a>,
#  <a href="/wiki/Cannes_Film_Festival" title="Cannes Film Festival">Cannes Film Festival</a>,
#  <a href="/wiki/Paul_Verhoeven" title="Paul Verhoeven">Paul Verhoeven</a>,
#  <a href="/wiki/Hollow_Man" title="Hollow Man">Hollow Man</a>,
#  <a href="#cite_note-30">[30]</a>,
#  <a href="/wiki/Colin_Firth" title="Colin Firth">Colin Firth</a>,
#  <a href="/wiki/Rachel_Blanchard" title="Rachel Blanchard">Rachel Blanchard</a>,
#  <a href="/wiki/M%C3%A9nage_%C3%A0_trois" title="Ménage à trois">ménage à trois</a>,
#  <a href="/wiki/Where_the_Truth_Lies" title="Where the Truth Lies">Where the Truth Lies</a>,
#  <a href="#cite_note-31">[31]</a>,
#  <a href="/wiki/Atom_Egoyan" title="Atom Egoyan">Atom Egoyan</a>,
#  <a class="mw-redirect" href="/wiki/MPAA" title="MPAA">MPAA</a>,
#  <a class="mw-redirect" href="/wiki/MPAA_film_rating_system" title="MPAA film rating system">NC-17</a>,
#  <a href="#cite_note-32">[32]</a>,
#  <a href="/wiki/Sean_Penn" title="Sean Penn">Sean Penn</a>,
#  <a href="/wiki/Tim_Robbins" title="Tim Robbins">Tim Robbins</a>,
#  <a href="/wiki/Clint_Eastwood" title="Clint Eastwood">Clint Eastwood</a>,
#  <a href="/wiki/Mystic_River_(film)" title="Mystic River (film)">Mystic River</a>,
#  <a href="/wiki/The_Woodsman_(2004_film)" title="The Woodsman (2004 film)">The Woodsman</a>,
#  <a href="#cite_note-33">[33]</a>,
#  <a href="/wiki/HBO_Films" title="HBO Films">HBO Films</a>,
#  <a href="/wiki/Taking_Chance" title="Taking Chance">Taking Chance</a>,
#  <a href="/wiki/Michael_Strobl" title="Michael Strobl">Michael Strobl</a>,
#  <a class="mw-redirect" href="/wiki/Desert_Storm" title="Desert Storm">Desert Storm</a>,
#  <a href="#cite_note-34">[34]</a>,
#  <a href="/wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie" title="Screen Actors Guild Award for Outstanding Performance by a Male Actor in a Miniseries or Television Movie">Screen Actors Guild Award for Outstanding Performance by a Male Actor in a Miniseries or Television Movie</a>,
#  <a class="image" href="/wiki/File:Black_Mass_PC_04_(21429102646).jpg"><img class="thumbimage" data-file-height="3056" data-file-width="2180" decoding="async" height="238" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b6/Black_Mass_PC_04_%2821429102646%29.jpg/170px-Black_Mass_PC_04_%2821429102646%29.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b6/Black_Mass_PC_04_%2821429102646%29.jpg/255px-Black_Mass_PC_04_%2821429102646%29.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b6/Black_Mass_PC_04_%2821429102646%29.jpg/340px-Black_Mass_PC_04_%2821429102646%29.jpg 2x" width="170"/></a>,
#  <a class="internal" href="/wiki/File:Black_Mass_PC_04_(21429102646).jpg" title="Enlarge"></a>,
#  <a class="mw-redirect" href="/wiki/Toronto_Film_Festival" title="Toronto Film Festival">Toronto Film Festival</a>,
#  <a href="/wiki/Matthew_Vaughn" title="Matthew Vaughn">Matthew Vaughn</a>,
#  <a href="/wiki/X-Men:_First_Class" title="X-Men: First Class">X-Men: First Class</a>,
#  <a class="mw-redirect" href="/wiki/Sebastian_Shaw_(comics)" title="Sebastian Shaw (comics)">Sebastian Shaw</a>,
#  <a href="#cite_note-35">[35]</a>,
#  <a href="#cite_note-36">[36]</a>,
#  <a href="/wiki/Dustin_Lance_Black" title="Dustin Lance Black">Dustin Lance Black</a>,
#  <a href="/wiki/8_(play)" title="8 (play)">8</a>,
#  <a class="mw-redirect" href="/wiki/Perry_v._Brown" title="Perry v. Brown">federal trial</a>,
#  <a class="mw-redirect" href="/wiki/Proposition_8" title="Proposition 8">Prop 8 ban</a>,
#  <a href="/wiki/Charles_J._Cooper" title="Charles J. Cooper">Charles J. Cooper</a>,
#  <a href="#cite_note-8_the_play-37">[37]</a>,
#  <a class="mw-redirect" href="/wiki/Wilshire_Ebell_Theatre" title="Wilshire Ebell Theatre">Wilshire Ebell Theatre</a>,
#  <a href="/wiki/American_Foundation_for_Equal_Rights" title="American Foundation for Equal Rights">American Foundation for Equal Rights</a>,
#  <a href="#cite_note-8_play_video-38">[38]</a>,
#  <a href="#cite_note-39">[39]</a>,
#  <a href="/wiki/The_Following" title="The Following">The Following</a>,
#  <a href="#cite_note-40">[40]</a>,
#  <a href="/wiki/Saturn_Award_for_Best_Actor_on_Television" title="Saturn Award for Best Actor on Television">Saturn Award for Best Actor on Television</a>,
#  <a href="#cite_note-41">[41]</a>,
#  <a class="mw-redirect" href="/wiki/Huffington_Post" title="Huffington Post">Huffington Post</a>,
#  <a href="/wiki/Tremors_(1990_film)" title="Tremors (1990 film)"><i>Tremors</i> franchise</a>,
#  <a href="#cite_note-42">[42]</a>,
#  <a class="mw-redirect" href="/wiki/Tremors_5:_Bloodline" title="Tremors 5: Bloodline">Tremors 5: Bloodline</a>,
#  <a class="mw-redirect" href="/wiki/EE_(telecommunications_company)" title="EE (telecommunications company)">EE mobile network</a>,
#  <a href="#cite_note-43">[43]</a>,
#  <a href="#cite_note-44">[44]</a>,
#  <a href="#cite_note-45">[45]</a>,
#  <a href="/wiki/Six_Degrees_of_Kevin_Bacon" title="Six Degrees of Kevin Bacon">Six Degrees of Kevin Bacon</a>,
#  <a href="/wiki/Trivia" title="Trivia">trivia</a>,
#  <a class="mw-redirect" href="/wiki/Big_screen" title="Big screen">screen</a>,
#  <a href="/wiki/Six_degrees_of_separation" title="Six degrees of separation">six degrees of separation</a>,
#  <a href="/wiki/Internet_meme" title="Internet meme">meme</a>,
#  <a href="/wiki/SixDegrees.org" title="SixDegrees.org">SixDegrees.org</a>,
#  <a href="/wiki/Social_networking_service" title="Social networking service">social networking service</a>,
#  <a href="#cite_note-46">[46]</a>,
#  <a href="/wiki/Six_Degrees_of_Kevin_Bacon" title="Six Degrees of Kevin Bacon">Bacon number</a>,
#  <a href="/wiki/IMDb" title="IMDb">Internet Movie Database</a>,
#  <a href="#cite_note-47">[47]</a>,
#  <a href="/wiki/Paul_Erd%C5%91s" title="Paul Erdős">Paul Erdős</a>,
#  <a href="/wiki/Erd%C5%91s_number" title="Erdős number">Erdős number</a>,
#  <a href="/wiki/Paul_Erd%C5%91s" title="Paul Erdős">Paul Erdős</a>,
#  <a href="/wiki/Erd%C5%91s_number" title="Erdős number">Erdős number</a>,
#  <a href="/wiki/Erd%C5%91s%E2%80%93Bacon_number" title="Erdős–Bacon number">Erdős–Bacon number</a>,
#  <a href="#cite_note-48">[48]</a>,
#  <a href="/wiki/The_Bacon_Brothers" title="The Bacon Brothers">The Bacon Brothers</a>,
#  <a href="/wiki/Michael_Bacon_(musician)" title="Michael Bacon (musician)">Michael</a>,
#  <a href="#cite_note-49">[49]</a>,
#  <a href="/wiki/Instagram" title="Instagram">Instagram</a>,
#  <a href="#cite_note-50">[50]</a>,
#  <a href="/wiki/Old_97%27s" title="Old 97's">Old 97's</a>,
#  <a href="/wiki/The_Guardians_of_the_Galaxy_Holiday_Special" title="The Guardians of the Galaxy Holiday Special">The Guardians of the Galaxy Holiday Special</a>,
#  <a href="#cite_note-51">[51]</a>,
#  <a href="/wiki/Kyra_Sedgwick" title="Kyra Sedgwick">Kyra Sedgwick</a>,
#  <a href="/wiki/PBS" title="PBS">PBS</a>,
#  <a href="/wiki/Lanford_Wilson" title="Lanford Wilson">Lanford Wilson</a>,
#  <a href="/wiki/Lemon_Sky" title="Lemon Sky">Lemon Sky</a>,
#  <a href="#cite_note-cosmo91-12">[12]</a>,
#  <a href="/wiki/Pyrates" title="Pyrates">Pyrates</a>,
#  <a href="/wiki/Murder_in_the_First_(film)" title="Murder in the First (film)">Murder in the First</a>,
#  <a href="/wiki/The_Woodsman_(2004_film)" title="The Woodsman (2004 film)">The Woodsman</a>,
#  <a href="/wiki/Loverboy_(2005_film)" title="Loverboy (2005 film)">Loverboy</a>,
#  <a href="/wiki/Sosie_Bacon" title="Sosie Bacon">Sosie Ruth</a>,
#  <a href="/wiki/Upper_West_Side" title="Upper West Side">Upper West Side</a>,
#  <a href="/wiki/Manhattan" title="Manhattan">Manhattan</a>,
#  <a href="#cite_note-52">[52]</a>,
#  <a href="/wiki/Tracy_Pollan" title="Tracy Pollan">Tracy Pollan</a>,
#  <a href="#cite_note-53">[53]</a>,
#  <a href="/wiki/Separation_of_church_and_state_in_the_United_States" title="Separation of church and state in the United States">separation of church and state</a>,
#  <a href="#cite_note-54">[54]</a>,
#  <a href="#cite_note-55">[55]</a>,
#  <a href="/wiki/The_Times" title="The Times">The Times</a>,
#  <a href="/wiki/Atheism" title="Atheism">did not "believe in God."</a>,
#  <a href="#cite_note-56">[56]</a>,
#  <a href="/wiki/Antireligion" title="Antireligion">anti-religion</a>,
#  <a href="#cite_note-57">[57]</a>,
#  <a href="/wiki/Will.i.am" title="Will.i.am">will.i.am</a>,
#  <a class="mw-redirect" href="/wiki/It%27s_a_New_Day_(Will.i.am_song)" title="It's a New Day (Will.i.am song)">"It's a New Day"</a>,
#  <a href="/wiki/Barack_Obama" title="Barack Obama">Barack Obama</a>,
#  <a href="/wiki/Ponzi_scheme" title="Ponzi scheme">Ponzi scheme</a>,
#  <a href="/wiki/Bernie_Madoff" title="Bernie Madoff">Bernie Madoff</a>,
#  <a href="#cite_note-financialpost-58">[58]</a>,
#  <a href="#cite_note-59">[59]</a>,
#  <a href="/wiki/Finding_Your_Roots" title="Finding Your Roots">Finding Your Roots</a>,
#  <a class="mw-redirect" href="/wiki/Henry_Louis_Gates" title="Henry Louis Gates">Henry Louis Gates</a>,
#  <a href="#cite_note-60">[60]</a>,
#  <a href="#cite_note-61">[61]</a>,
#  <a href="#cite_note-62">[62]</a>,
#  <a href="#cite_note-63">[63]</a>,
#  <a href="/wiki/Apollo_13_(film)" title="Apollo 13 (film)">Apollo 13</a>,
#  <a href="#cite_note-64">[64]</a>,
#  <a href="/wiki/Mystic_River_(film)" title="Mystic River (film)">Mystic River</a>,
#  <a href="/wiki/Blockbuster_Entertainment_Awards" title="Blockbuster Entertainment Awards">Blockbuster Entertainment Awards</a>,
#  <a href="/wiki/Blockbuster_Entertainment_Awards" title="Blockbuster Entertainment Awards">Favorite Actor – Science Fiction</a>,
#  <a href="#cite_note-65">[65]</a>,
#  <a href="/wiki/Hollow_Man" title="Hollow Man">Hollow Man</a>,
#  <a href="/wiki/Boston_Society_of_Film_Critics" title="Boston Society of Film Critics">Boston Society of Film Critics Awards</a>,
#  <a href="/wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast" title="Boston Society of Film Critics Award for Best Cast">Best Ensemble Cast</a>,
#  <a href="#cite_note-66">[66]</a>,
#  <a href="/wiki/Mystic_River_(film)" title="Mystic River (film)"><i>Mystic River</i></a>,
#  <a href="/wiki/Bravo_Otto" title="Bravo Otto">Bravo Otto Awards</a>,
#  <a href="/wiki/Bravo_Otto" title="Bravo Otto">Best Actor</a>,
#  <a href="/wiki/Footloose_(1984_film)" title="Footloose (1984 film)">Footloose</a>,
#  <a href="/wiki/CableACE_Award" title="CableACE Award">CableACE Awards</a>,
#  <a href="/wiki/CableACE_Award" title="CableACE Award">Directing a Movie or Miniseries</a>,
#  <a href="/wiki/Losing_Chase" title="Losing Chase">Losing Chase</a>,
#  <a class="mw-redirect" href="/wiki/Chlotrudis_Awards" title="Chlotrudis Awards">Chlotrudis Awards</a>,
#  <a href="/wiki/The_Woodsman_(2004_film)" title="The Woodsman (2004 film)">The Woodsman</a>,
#  <a href="/wiki/Critics%27_Choice_Movie_Awards" title="Critics' Choice Movie Awards">Critics' Choice Movie Awards</a>,
#  <a href="/wiki/Critics%27_Choice_Movie_Award_for_Best_Actor" title="Critics' Choice Movie Award for Best Actor">Best Actor</a>,
#  <a href="/wiki/Murder_in_the_First_(film)" title="Murder in the First (film)">Murder in the First</a>,
#  <a class="mw-redirect" href="/wiki/Ghent_International_Film_Festival" title="Ghent International Film Festival">Ghent International Film Festival</a>,
#  <a class="mw-redirect" href="/wiki/Ghent_International_Film_Festival" title="Ghent International Film Festival">Special Mention</a>,
#  <a href="/wiki/The_Woodsman_(2004_film)" title="The Woodsman (2004 film)">The Woodsman</a>,
#  <a href="/wiki/Giffoni_Film_Festival" title="Giffoni Film Festival">Giffoni Film Festival</a>,
#  <a href="/wiki/Giffoni_Film_Festival" title="Giffoni Film Festival">Best Actor</a>,
#  <a href="/wiki/Digging_to_China" title="Digging to China">Digging to China</a>,
#  <a href="/wiki/Mystic_River_(film)" title="Mystic River (film)"><i>Mystic River</i></a>,
#  <a class="mw-redirect" href="/wiki/Golden_Globe_Award" title="Golden Globe Award">Golden Globe Awards</a>,
#  <a href="/wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture" title="Golden Globe Award for Best Supporting Actor – Motion Picture">Best Supporting Actor in a Motion Picture</a>,
#  <a href="/wiki/The_River_Wild" title="The River Wild">The River Wild</a>,
#  <a href="/wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film" title="Golden Globe Award for Best Actor – Miniseries or Television Film">Best Actor in a Miniseries or Motion Picture Made for Television</a>,
#  <a href="/wiki/Taking_Chance" title="Taking Chance">Taking Chance</a>,
#  <a href="/wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy" title="Golden Globe Award for Best Actor – Television Series Musical or Comedy">Best Actor in a Television Series – Comedy or Musical</a>,
#  <a href="/wiki/I_Love_Dick_(TV_series)" title="I Love Dick (TV series)">I Love Dick</a>,
#  <a href="/wiki/Independent_Spirit_Awards" title="Independent Spirit Awards">Independent Spirit Awards</a>,
#  <a href="/wiki/Independent_Spirit_Award_for_Best_Male_Lead" title="Independent Spirit Award for Best Male Lead">Best Male Lead</a>,
#  <a href="/wiki/The_Woodsman_(2004_film)" title="The Woodsman (2004 film)">The Woodsman</a>,
#  <a href="/wiki/Mystic_River_(film)" title="Mystic River (film)"><i>Mystic River</i></a>,
#  <a href="/wiki/MTV_Movie_%26_TV_Awards" title="MTV Movie &amp; TV Awards">MTV Movie + TV Awards</a>,
#  <a href="/wiki/MTV_Movie_Award_for_Best_Villain" title="MTV Movie Award for Best Villain">Best Villain</a>,
#  <a href="/wiki/Hollow_Man" title="Hollow Man">Hollow Man</a>,
#  <a href="/wiki/Taking_Chance" title="Taking Chance">Taking Chance</a>,
#  <a href="/wiki/The_Following" title="The Following">The Following</a>,
#  <a class="mw-redirect" href="/wiki/E!_People%27s_Choice_Awards" title="E! People's Choice Awards">People's Choice Awards</a>,
#  <a class="mw-redirect" href="/wiki/E!_People%27s_Choice_Awards" title="E! People's Choice Awards">Favorite Dramatic Television Actor</a>,
#  <a href="/wiki/The_Following" title="The Following">The Following</a>,
#  <a class="mw-redirect" href="/wiki/E!_People%27s_Choice_Awards" title="E! People's Choice Awards">Favorite Crime Drama Television Actor</a>,
#  <a href="/wiki/The_Following" title="The Following">The Following</a>,
#  <a class="mw-redirect" href="/wiki/Primetime_Emmy_Award" title="Primetime Emmy Award">Primetime Emmy Awards</a>,
#  <a class="mw-redirect" href="/wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie" title="Primetime Emmy Award for Outstanding Lead Actor in a Limited Series or Movie">Outstanding Lead Actor in a Miniseries or a Movie</a>,
#  <a href="/wiki/Taking_Chance" title="Taking Chance">Taking Chance</a>,
#  <a href="/wiki/Satellite_Awards" title="Satellite Awards">Satellite Awards</a>,
#  <a href="/wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture" title="Satellite Award for Best Actor – Motion Picture">Best Actor in a Motion Picture – Drama</a>,
#  <a href="/wiki/The_Woodsman_(2004_film)" title="The Woodsman (2004 film)">The Woodsman</a>,
#  <a href="/wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film" title="Satellite Award for Best Actor – Miniseries or Television Film">Best Actor in a Miniseries or Motion Picture Made for Television</a>,
#  <a href="/wiki/Taking_Chance" title="Taking Chance">Taking Chance</a>,
#  <a class="mw-redirect" href="/wiki/Saturn_Award" title="Saturn Award">Saturn Awards</a>,
#  <a href="/wiki/Saturn_Award_for_Best_Actor_on_Television" title="Saturn Award for Best Actor on Television">Best Actor on Television</a>,
#  <a href="/wiki/The_Following" title="The Following">The Following</a>,
#  <a href="/wiki/Saturn_Award_for_Best_Actor_on_Television" title="Saturn Award for Best Actor on Television">Best Actor on Television</a>,
#  <a href="/wiki/The_Following" title="The Following">The Following</a>,
#  <a href="/wiki/Scream_Awards" title="Scream Awards">Scream Awards</a>,
#  <a href="/wiki/Scream_Awards" title="Scream Awards">Best Villain</a>,
#  <a href="/wiki/X-Men:_First_Class" title="X-Men: First Class">X-Men: First Class</a>,
#  <a class="mw-redirect" href="/wiki/Screen_Actors_Guild_Award" title="Screen Actors Guild Award">Screen Actors Guild Awards</a>,
#  <a href="/wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role" title="Screen Actors Guild Award for Outstanding Performance by a Male Actor in a Supporting Role">Outstanding Performance by a Male Actor in a Supporting Role</a>,
#  <a href="/wiki/Murder_in_the_First_(film)" title="Murder in the First (film)">Murder in the First</a>,
#  <a href="/wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture" title="Screen Actors Guild Award for Outstanding Performance by a Cast in a Motion Picture">Outstanding Performance by a Cast in a Motion Picture</a>,
#  <a href="/wiki/Apollo_13_(film)" title="Apollo 13 (film)">Apollo 13</a>,
#  <a href="/wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture" title="Screen Actors Guild Award for Outstanding Performance by a Cast in a Motion Picture">Outstanding Performance by a Cast in a Motion Picture</a>,
#  <a href="/wiki/Mystic_River_(film)" title="Mystic River (film)"><i>Mystic River</i></a>,
#  <a href="/wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture" title="Screen Actors Guild Award for Outstanding Performance by a Cast in a Motion Picture">Outstanding Performance by a Cast in a Motion Picture</a>,
#  <a href="/wiki/Frost/Nixon_(film)" title="Frost/Nixon (film)">Frost/Nixon</a>,
#  <a href="/wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie" title="Screen Actors Guild Award for Outstanding Performance by a Male Actor in a Miniseries or Television Movie">Outstanding Performance by a Male Actor in a Television Movie or Miniseries</a>,
#  <a href="/wiki/Taking_Chance" title="Taking Chance">Taking Chance</a>,
#  <a href="/wiki/Teen_Choice_Awards" title="Teen Choice Awards">Teen Choice Awards</a>,
#  <a href="/wiki/Teen_Choice_Award_for_Choice_Movie_Villain" title="Teen Choice Award for Choice Movie Villain">Choice Movie – Sleazbag</a>,
#  <a href="/wiki/Beauty_Shop" title="Beauty Shop">Beauty Shop</a>,
#  <a href="/wiki/Teen_Choice_Award_for_Choice_Movie_Villain" title="Teen Choice Award for Choice Movie Villain">Choice Movie – Villain</a>,
#  <a href="/wiki/X-Men:_First_Class" title="X-Men: First Class">X-Men: First Class</a>,
#  <a href="/wiki/TV_Guide_Award" title="TV Guide Award">TV Guide Awards</a>,
#  <a href="/wiki/TV_Guide_Award" title="TV Guide Award">Favorite Actor</a>,
#  <a href="/wiki/The_Following" title="The Following">The Following</a>,
#  <a class="image" href="/wiki/File:Kevin_Bacon%27s_Star_Walk_of_Fame.jpg"><img class="thumbimage" data-file-height="649" data-file-width="714" decoding="async" height="155" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/a5/Kevin_Bacon%27s_Star_Walk_of_Fame.jpg/170px-Kevin_Bacon%27s_Star_Walk_of_Fame.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/a5/Kevin_Bacon%27s_Star_Walk_of_Fame.jpg/255px-Kevin_Bacon%27s_Star_Walk_of_Fame.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/a5/Kevin_Bacon%27s_Star_Walk_of_Fame.jpg/340px-Kevin_Bacon%27s_Star_Walk_of_Fame.jpg 2x" width="170"/></a>,
#  <a class="internal" href="/wiki/File:Kevin_Bacon%27s_Star_Walk_of_Fame.jpg" title="Enlarge"></a>,
#  <a href="/wiki/Hollywood_Walk_of_Fame" title="Hollywood Walk of Fame">Hollywood Walk of Fame</a>,
#  <a href="/wiki/Hollywood_Walk_of_Fame" title="Hollywood Walk of Fame">Hollywood Walk of Fame</a>,
#  <a href="#cite_note-67">[67]</a>,
#  <a href="/wiki/Denver_Film_Festival" title="Denver Film Festival">Denver International Film Festival</a>,
#  <a href="#cite_note-68">[68]</a>,
#  <a href="/wiki/Phoenix_Film_Festival" title="Phoenix Film Festival">Phoenix Film Festival</a>,
#  <a href="#cite_note-69">[69]</a>,
#  <a href="/wiki/Santa_Barbara_International_Film_Festival" title="Santa Barbara International Film Festival">Santa Barbara International Film Festival</a>,
#  <a href="#cite_note-70">[70]</a>,
#  <a class="mw-redirect" href="/wiki/Broadcast_Film_Critics_Association" title="Broadcast Film Critics Association">Broadcast Film Critics Association</a>,
#  <a href="#cite_note-71">[71]</a>,
#  <a href="/wiki/Seattle_International_Film_Festival" title="Seattle International Film Festival">Seattle International Film Festival</a>,
#  <a href="#cite_note-72">[72]</a>,
#  <a href="/wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars" title="List of actors with Hollywood Walk of Fame motion picture stars">List of actors with Hollywood Walk of Fame motion picture stars</a>,
#  <a href="#cite_ref-1">^</a>,
#  <a class="external text" href="http://www.geneall.net/U/per_page.php?id=1014399" rel="nofollow">"Kyra Sedgwick"</a>,
#  <a href="#cite_ref-2">^</a>,
#  <a class="external text" href="https://web.archive.org/web/20090113222205/http://www.newenglandancestors.org/research/services/articles_gbr78.asp" rel="nofollow">"Ten Further Hollywood Figures (or Groups Thereof)"</a>,
#  <a class="external text" href="http://www.newenglandancestors.org/research/services/articles_gbr78.asp" rel="nofollow">the original</a>,
#  <a href="#cite_ref-actor_3-0"><sup><i><b>a</b></i></sup></a>,
#  <a href="#cite_ref-actor_3-1"><sup><i><b>b</b></i></sup></a>,
#  <a href="#cite_ref-actor_3-2"><sup><i><b>c</b></i></sup></a>,
#  <a class="external text" href="http://www.biography.com/people/kevin-bacon-9542173" rel="nofollow">"Kevin Bacon"</a>,
#  <a href="#cite_ref-4">^</a>,
#  <a class="external text" href="https://www.theguardian.com/film/filmblog/2009/feb/19/best-actors-never-nominated-for-oscars" rel="nofollow">"Oscars: the best actors never to have been nominated"</a>,
#  <a href="#cite_ref-5">^</a>,
#  <a class="external text" href="http://www.walkoffame.com/kevin-bacon" rel="nofollow">"Hollywood Walk of Fame - Kevin Bacon"</a>,
#  <a href="#cite_ref-6">^</a>,
#  <a class="external text" href="https://www.hollywoodreporter.com/tv/tv-news/showtime-cancels-city-on-a-hill-3-seasons-1235250089/" rel="nofollow">"<span class="cs1-kern-left"></span>'City on a Hill' Canceled After Three Seasons on Showtime"</a>,
#  <a href="/wiki/The_Hollywood_Reporter" title="The Hollywood Reporter">The Hollywood Reporter</a>,
#  <a href="#cite_ref-walk_7-0"><sup><i><b>a</b></i></sup></a>,
#  <a href="#cite_ref-walk_7-1"><sup><i><b>b</b></i></sup></a>,
#  <a class="external text" href="https://web.archive.org/web/20141016202657/http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html" rel="nofollow">"Kevin Bacon biography"</a>,
#  <a class="external text" href="http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html" rel="nofollow">the original</a>,
#  <a href="#cite_ref-8">^</a>,
#  <a class="external text" href="https://www.marketingweek.com/ee-unveils-six-degrees-of-bacon-launch-ads/" rel="nofollow">"EE unveils 'six degrees of Bacon' launch ads"</a>,
#  <a href="#cite_ref-bacon_9-0"><sup><i><b>a</b></i></sup></a>,
#  <a href="#cite_ref-bacon_9-1"><sup><i><b>b</b></i></sup></a>,
#  <a href="#cite_ref-bacon_9-2"><sup><i><b>c</b></i></sup></a>,
#  <a href="#cite_ref-bacon_9-3"><sup><i><b>d</b></i></sup></a>,
#  <a class="external text" href="https://web.archive.org/web/20190403203113/https://www.biography.com/news/kevin-bacon-biography-facts" rel="nofollow">"Kevin Bacon: 6 Things You Didn't Know"</a>,
#  <a class="external text" href="http://www.biography.com/news/kevin-bacon-biography-facts" rel="nofollow">the original</a>,
#  <a href="#cite_ref-10">^</a>,
#  <a class="external text" href="https://philadelphia.cbslocal.com/top-lists/stars-from-philly-to-hollywood/" rel="nofollow">"4 Stars From Philly To Hollywood"</a>,
#  <a href="#cite_ref-11">^</a>,
#  <a class="external text" href="https://movies.yahoo.com/person/kevin-bacon/biography.html" rel="nofollow">"ABOUT KEVIN BACON"</a>,
#  <a href="#cite_ref-cosmo91_12-0"><sup><i><b>a</b></i></sup></a>,
#  <a href="#cite_ref-cosmo91_12-1"><sup><i><b>b</b></i></sup></a>,
#  <a href="#cite_ref-13">^</a>,
#  <a class="external text" href="http://www.nydailynews.com/entertainment/happy-halloween-superstars-start-horror-flick-gallery-1.98345" rel="nofollow">"Happy Halloween: Stars who got their start in horror flicks"</a>,
#  <a href="#cite_ref-bio_14-0"><sup><i><b>a</b></i></sup></a>,
#  <a href="#cite_ref-bio_14-1"><sup><i><b>b</b></i></sup></a>,
#  <a href="#cite_ref-bio_14-2"><sup><i><b>c</b></i></sup></a>,
#  <a href="#cite_ref-bio_14-3"><sup><i><b>d</b></i></sup></a>,
#  <a href="#cite_ref-bio_14-4"><sup><i><b>e</b></i></sup></a>,
#  <a href="#cite_ref-bio_14-5"><sup><i><b>f</b></i></sup></a>,
#  <a href="#cite_ref-bio_14-6"><sup><i><b>g</b></i></sup></a>,
#  <a href="#cite_ref-bio_14-7"><sup><i><b>h</b></i></sup></a>,
#  <a href="#cite_ref-bio_14-8"><sup><i><b>i</b></i></sup></a>,
#  <a href="#cite_ref-bio_14-9"><sup><i><b>j</b></i></sup></a>,
#  <a href="#cite_ref-bio_14-10"><sup><i><b>k</b></i></sup></a>,
#  <a class="external text" href="https://web.archive.org/web/20160530033240/http://www.pbs.org/weta/finding-your-roots/profiles/kevin-bacon%c2%a0/" rel="nofollow">"Kevin Bacon"</a>,
#  <a class="external text" href="https://www.pbs.org/wnet/finding-your-roots/profiles/kevin-bacon%C2%A0/" rel="nofollow">the original</a>,
#  <a href="#cite_ref-kevin_15-0">^</a>,
#  <a class="external text" href="https://www.tvguide.com/celebrities/kevin-bacon/bio/160550" rel="nofollow">"Kevin Bacon biography"</a>,
#  <a href="#cite_ref-16">^</a>,
#  <a class="external text" href="https://web.archive.org/web/20141021030336/http://news.moviefone.com/2012/03/02/diner-30th-anniversary/" rel="nofollow">"Diner' 30th Anniversary: 25 Things You Didn't Know About The Guys-and-Fries Classic"</a>,
#  <a class="external text" href="http://news.moviefone.com/2012/03/02/diner-30th-anniversary/" rel="nofollow">the original</a>,
#  <a href="#cite_ref-time84_17-0">^</a>,
#  <a class="external text" href="https://web.archive.org/web/20080830035710/http://www.time.com/time/magazine/article/0,9171,950019,00.html" rel="nofollow">"Revel Without a Cause"</a>,
#  <a class="external text" href="http://www.time.com/time/magazine/article/0,9171,950019,00.html" rel="nofollow">the original</a>,
#  <a href="#cite_ref-18">^</a>,
#  <a class="external text" href="http://www.huffingtonpost.com/2014/08/25/kevin-bacon-footloose_n_5710413.html" rel="nofollow">"Kevin Bacon Got Bullied By High Schoolers While Prepping For 'Footloose'<span class="cs1-kern-right"></span>"</a>,
#  <a href="#cite_ref-19">^</a>,
#  <a class="external text" href="https://web.archive.org/web/20090109152125/http://www.thebiographychannel.co.uk/biography_story/522%3A492/1/Kevin_Bacon.htm" rel="nofollow">"Kevin Bacon"</a>,
#  <a class="external text" href="http://www.thebiographychannel.co.uk/biography_story/522:492/1/Kevin_Bacon.htm" rel="nofollow">the original</a>,
#  <a href="#cite_ref-20">^</a>,
#  <a class="external text" href="https://www.mentalfloss.com/article/71594/14-moving-facts-about-planes-trains-and-automobiles" rel="nofollow">"15 Moving Facts About 'Planes, Trains and Automobiles'<span class="cs1-kern-right"></span>"</a>,
#  <a href="#cite_ref-21">^</a>,
#  <a class="external text" href="https://www.nytimes.com/1994/09/25/movies/a-second-wind-is-blowing-for-kevin-bacon.html" rel="nofollow">"A Second Wind Is Blowing For Kevin Bacon"</a>,
#  <a href="#cite_ref-22">^</a>,
#  <a class="external text" href="https://www.nytimes.com/movie/review?res=9C0CE2DE1631F93AA25752C0A966958260" rel="nofollow">"Tremors Review"</a>,
#  <a href="#cite_ref-nyt94_23-0">^</a>,
#  <a class="external text" href="https://query.nytimes.com/gst/fullpage.html?res=9C07E6D91F3BF936A1575AC0A962958260" rel="nofollow">"A Second Wind Is Blowing For Kevin Bacon"</a>,
#  <a href="#cite_ref-24">^</a>,
#  <a class="external text" href="http://www.jfk-online.com/jfkbacon.html" rel="nofollow">"Kevin Bacon"</a>,
#  <a href="#cite_ref-25">^</a>,
#  <a class="external text" href="http://www.tcm.com/this-month/article/143158%7C0/A-Few-Good-Men.html" rel="nofollow">"A few good men"</a>,
#  <a href="#cite_ref-26">^</a>,
#  <a class="external text" href="http://collider.com/kevin-bacon-commercials-footloose/" rel="nofollow">"Kevin Bacon Reprises His Roles from FOOTLOOSE, A FEW GOOD MEN, APOLLO 13, and More in UK Commercials"</a>,
#  <a href="#cite_ref-27">^</a>,
#  <a class="external text" href="http://www.rogerebert.com/reviews/sleepers-1996" rel="nofollow">"Sleepers"</a>,
#  <a href="#cite_ref-austin_28-0">^</a>,
#  <a class="external text" href="http://www.austinchronicle.com/calendar/film/1997-02-07/283342/" rel="nofollow">"Losing Chase"</a>,
#  <a href="/wiki/The_Austin_Chronicle" title="The Austin Chronicle">The Austin Chronicle</a>,
#  <a href="#cite_ref-29">^</a>,
#  <a class="external text" href="http://www.criminalelement.com/blogs/2013/09/under-the-raderhorror-movies-you-may-have-missed-stir-of-echoes" rel="nofollow">"Under the Radar—Horror Movies You May Have Missed: Stir of Echoes"</a>,
#  <a href="#cite_ref-30">^</a>,
#  <a class="external text" href="http://www.rogerebert.com/reviews/hollow-man-2000" rel="nofollow">"The hollow man"</a>,
#  <a href="#cite_ref-31">^</a>,
#  <a class="external text" href="https://web.archive.org/web/20141017080013/http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm" rel="nofollow">"Kevin Bacon Talks About "Where the Truth Lies"<span class="cs1-kern-right"></span>"</a>,
#  <a class="external text" href="http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm" rel="nofollow">the original</a>,
#  <a href="#cite_ref-32">^</a>,
#  <a class="external text" href="https://archive.today/20120604150801/http://jam.canoe.ca/Movies/2005/09/14/1216527.html" rel="nofollow">"Kevin Bacon irked over movie rating"</a>,
#  <a class="external text" href="http://jam.canoe.ca/Movies/2005/09/14/1216527.html" rel="nofollow">the original</a>,
#  <a href="#cite_ref-33">^</a>,
#  <a class="external text" href="https://web.archive.org/web/20140802203026/http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html" rel="nofollow">"The Woodsman' (2004)"</a>,
#  <a class="external text" href="http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html" rel="nofollow">the original</a>,
#  <a href="#cite_ref-34">^</a>,
#  <a class="external text" href="http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-chance-body-fallen-marine-home-article-1.392226" rel="nofollow">"Kevin Bacon 'Taking Chance' body of fallen Marine home"</a>,
#  <a href="#cite_ref-35">^</a>,
#  <a class="external text" href="https://web.archive.org/web/20100722010545/http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html" rel="nofollow">"<span class="cs1-kern-left"></span>'Winter's Bone' star cast in 'X-Men: First Class' (exclusive)"</a>,
#  <a class="external text" href="http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html" rel="nofollow">the original</a>,
#  <a href="#cite_ref-36">^</a>,
#  <a class="external text" href="https://web.archive.org/web/20100720060214/http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html" rel="nofollow">"KEVIN BACON Playing SEBASTIAN SHAW in X-MEN: FIRST CLASS"</a>,
#  <a class="external text" href="http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html" rel="nofollow">the original</a>,
#  <a href="#cite_ref-8_the_play_37-0">^</a>,
#  <a class="external text" href="http://www.accesshollywood.com/jesse-tyler-ferguson/glee-stars-touched-by-brad-pitt-and-george-clooneys-support-of-8_article_61543" rel="nofollow">"<span class="cs1-kern-left"></span>'Glee' Stars 'Touched' By Pitt &amp; Clooney's Support Of '8'<span class="cs1-kern-right"></span>"</a>,
#  <a href="/wiki/Access_Hollywood" title="Access Hollywood">Access Hollywood</a>,
#  <a href="#cite_ref-8_play_video_38-0">^</a>,
#  <a class="external text" href="https://www.youtube.com/watch?v=qlUG8F9uVgM" rel="nofollow">"<span class="cs1-kern-left"></span>"8": A Play about the Fight for Marriage Equality"</a>,
#  <a class="external text" href="https://ghostarchive.org/varchive/youtube/20211211/qlUG8F9uVgM" rel="nofollow">Archived</a>,
#  <a href="#cite_ref-39">^</a>,
#  <a class="external text" href="http://www.pinknews.co.uk/2012/03/01/youtube-to-broadcast-proposition-8-play-live/" rel="nofollow">"YouTube to broadcast Proposition 8 play live"</a>,
#  <a href="#cite_ref-40">^</a>,
#  <a class="external text" href="http://www.fox.com/the-following/" rel="nofollow">"The Following"</a>,
#  <a href="#cite_ref-41">^</a>,
#  <a class="external text" href="https://news.yahoo.com/blogs/trending-now/kevin-bacon-gives-millennials-a-history-lesson-about-the--80s-162525915.html" rel="nofollow">"Kevin Bacon Gives Millennials a History Lesson About the '80s"</a>,
#  <a href="#cite_ref-42">^</a>,
#  <a class="external text" href="http://www.huffingtonpost.com.au/entry/kevin-bacon-tremors-tv-reboot_us_5655b651e4b072e9d1c13a11" rel="nofollow">"Kevin Bacon Returns To 'Tremors' For TV Reboot"</a>,
#  <a href="#cite_ref-43">^</a>,
#  <a class="external text" href="http://www.campaignlive.co.uk/news/1294856/" rel="nofollow">"Kevin Bacon rides UK's biggest rollercoaster in EE spot"</a>,
#  <a href="#cite_ref-44">^</a>,
#  <a class="external text" href="http://parade.condenast.com/269380/ashleighschmitz/kevin-bacon-reprises-his-most-iconic-film-roles-in-british-commercial/" rel="nofollow">"Kevin Bacon Reprises His Most Iconic Film Roles in British Commercial"</a>,
#  <a href="#cite_ref-45">^</a>,
#  <a class="external text" href="https://money.cnn.com/2015/03/13/media/kevin-bacon-eggs/index.html" rel="nofollow">"New egg ad comes with a side of Kevin Bacon"</a>,
# ...
#  <a class="mw-selflink selflink">Kevin Bacon</a>,
#  <a href="/wiki/Bryan_Cranston" title="Bryan Cranston">Bryan Cranston</a>,
#  <a href="/wiki/Mads_Mikkelsen" title="Mads Mikkelsen">Mads Mikkelsen</a>,
#  <a href="/wiki/Hugh_Dancy" title="Hugh Dancy">Hugh Dancy</a>,
#  <a href="/wiki/Andrew_Lincoln" title="Andrew Lincoln">Andrew Lincoln</a>,
#  <a href="/wiki/Bruce_Campbell" title="Bruce Campbell">Bruce Campbell</a>,
#  <a href="/wiki/Andrew_Lincoln" title="Andrew Lincoln">Andrew Lincoln</a>,
#  <a href="/wiki/Kyle_MacLachlan" title="Kyle MacLachlan">Kyle MacLachlan</a>,
#  <a href="/wiki/Patrick_Stewart" title="Patrick Stewart">Patrick Stewart</a>,
#  <a class="mw-redirect" href="/wiki/Saturn_Award_for_Best_Actor_in_a_Network_or_Cable_Television_Series" title="Saturn Award for Best Actor in a Network or Cable Television Series">Network/Cable</a>,
#  <a href="/wiki/Sam_Heughan" title="Sam Heughan">Sam Heughan</a>,
#  <a href="/wiki/Bob_Odenkirk" title="Bob Odenkirk">Bob Odenkirk</a>,
#  <a href="/wiki/Saturn_Award_for_Best_Actor_in_a_Streaming_Television_Series" title="Saturn Award for Best Actor in a Streaming Television Series">Streaming</a>,
#  <a href="/wiki/Henry_Thomas" title="Henry Thomas">Henry Thomas</a>,
#  <a href="/wiki/Oscar_Isaac" title="Oscar Isaac">Oscar Isaac</a>,
#  <a href="/wiki/Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie" title="Template:ScreenActorsGuildAward MaleTVMiniseriesMovie"><abbr style="background: #ABCDEF;;background:none transparent;border:none;box-shadow:none;padding:0;" title="View this template">v</abbr></a>,
#  <a href="/wiki/Template_talk:ScreenActorsGuildAward_MaleTVMiniseriesMovie" title="Template talk:ScreenActorsGuildAward MaleTVMiniseriesMovie"><abbr style="background: #ABCDEF;;background:none transparent;border:none;box-shadow:none;padding:0;" title="Discuss this template">t</abbr></a>,
#  <a class="external text" href="https://en.wikipedia.org/w/index.php?title=Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie&amp;action=edit"><abbr style="background: #ABCDEF;;background:none transparent;border:none;box-shadow:none;padding:0;" title="Edit this template">e</abbr></a>,
#  <a href="/wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie" title="Screen Actors Guild Award for Outstanding Performance by a Male Actor in a Miniseries or Television Movie">Screen Actors Guild Award for Outstanding Performance by a Male Actor in a Miniseries or Television Movie</a>,
#  <a href="/wiki/Raul_Julia" title="Raul Julia">Raul Julia</a>,
#  <a href="/wiki/Gary_Sinise" title="Gary Sinise">Gary Sinise</a>,
#  <a href="/wiki/Alan_Rickman" title="Alan Rickman">Alan Rickman</a>,
#  <a href="/wiki/Gary_Sinise" title="Gary Sinise">Gary Sinise</a>,
#  <a href="/wiki/Christopher_Reeve" title="Christopher Reeve">Christopher Reeve</a>,
#  <a href="/wiki/Jack_Lemmon" title="Jack Lemmon">Jack Lemmon</a>,
#  <a href="/wiki/Brian_Dennehy" title="Brian Dennehy">Brian Dennehy</a>,
#  <a href="/wiki/Ben_Kingsley" title="Ben Kingsley">Ben Kingsley</a>,
#  <a href="/wiki/William_H._Macy" title="William H. Macy">William H. Macy</a>,
#  <a href="/wiki/Al_Pacino" title="Al Pacino">Al Pacino</a>,
#  <a href="/wiki/Geoffrey_Rush" title="Geoffrey Rush">Geoffrey Rush</a>,
#  <a href="/wiki/Paul_Newman" title="Paul Newman">Paul Newman</a>,
#  <a href="/wiki/Jeremy_Irons" title="Jeremy Irons">Jeremy Irons</a>,
#  <a href="/wiki/Kevin_Kline" title="Kevin Kline">Kevin Kline</a>,
#  <a href="/wiki/Paul_Giamatti" title="Paul Giamatti">Paul Giamatti</a>,
#  <a class="mw-selflink selflink">Kevin Bacon</a>,
#  <a href="/wiki/Al_Pacino" title="Al Pacino">Al Pacino</a>,
#  <a href="/wiki/Paul_Giamatti" title="Paul Giamatti">Paul Giamatti</a>,
#  <a href="/wiki/Kevin_Costner" title="Kevin Costner">Kevin Costner</a>,
#  <a href="/wiki/Michael_Douglas" title="Michael Douglas">Michael Douglas</a>,
#  <a href="/wiki/Mark_Ruffalo" title="Mark Ruffalo">Mark Ruffalo</a>,
#  <a href="/wiki/Idris_Elba" title="Idris Elba">Idris Elba</a>,
#  <a href="/wiki/Bryan_Cranston" title="Bryan Cranston">Bryan Cranston</a>,
#  <a href="/wiki/Alexander_Skarsg%C3%A5rd" title="Alexander Skarsgård">Alexander Skarsgård</a>,
#  <a href="/wiki/Darren_Criss" title="Darren Criss">Darren Criss</a>,
#  <a href="/wiki/Sam_Rockwell" title="Sam Rockwell">Sam Rockwell</a>,
#  <a href="/wiki/Mark_Ruffalo" title="Mark Ruffalo">Mark Ruffalo</a>,
#  <a href="/wiki/Michael_Keaton" title="Michael Keaton">Michael Keaton</a>,
#  <a href="/wiki/Sam_Elliott" title="Sam Elliott">Sam Elliott</a>,
#  <a href="/wiki/Help:Authority_control" title="Help:Authority control">Authority control</a>,
#  <a href="https://www.wikidata.org/wiki/Q3454165#identifiers" title="Edit this at Wikidata"><img alt="Edit this at Wikidata" class="noprint" data-file-height="20" data-file-width="20" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/10px-OOjs_UI_icon_edit-ltr-progressive.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/15px-OOjs_UI_icon_edit-ltr-progressive.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/20px-OOjs_UI_icon_edit-ltr-progressive.svg.png 2x" style="vertical-align: text-top" width="10"/></a>,
#  <a class="external text" href="http://id.worldcat.org/fast/242183/" rel="nofollow">FAST</a>,
#  <a class="external text" href="https://isni.org/isni/0000000121291300" rel="nofollow">ISNI</a>,
#  <a class="external text" href="https://viaf.org/viaf/39570812" rel="nofollow">VIAF</a>,
#  <a class="external text" href="https://www.worldcat.org/identities/lccn-n88034930/" rel="nofollow">WorldCat</a>,
#  <a class="external text" href="https://authority.bibsys.no/authority/rest/authorities/html/98015093" rel="nofollow">Norway</a>,
#  <a class="external text" href="http://catalogo.bne.es/uhtbin/authoritybrowse.cgi?action=display&amp;authority_id=XX1298810" rel="nofollow">Spain</a>,
#  <a class="external text" href="https://catalogue.bnf.fr/ark:/12148/cb139817766" rel="nofollow">France</a>,
#  <a class="external text" href="https://data.bnf.fr/ark:/12148/cb139817766" rel="nofollow">BnF data</a>,
#  <a class="external text" href="https://d-nb.info/gnd/124109659" rel="nofollow">Germany</a>,
#  <a class="external text" href="http://uli.nli.org.il/F/?func=find-b&amp;local_base=NLX10&amp;find_code=UID&amp;request=987007454685905171" rel="nofollow">Israel</a>,
#  <a class="external text" href="https://id.loc.gov/authorities/n88034930" rel="nofollow">United States</a>,
#  <a class="external text" href="https://kopkatalogs.lv/F?func=direct&amp;local_base=lnc10&amp;doc_number=000249798&amp;P_CON_LNG=ENG" rel="nofollow">Latvia</a>,
#  <a class="external text" href="https://aleph.nkp.cz/F/?func=find-c&amp;local_base=aut&amp;ccl_term=ica=xx0025279&amp;CON_LNG=ENG" rel="nofollow">Czech Republic</a>,
#  <a class="external text" href="https://nla.gov.au/anbd.aut-an36021861" rel="nofollow">Australia</a>,
#  <a class="external text" href="https://lod.nl.go.kr/resource/KAC2020K8226" rel="nofollow">Korea</a>,
#  <a class="external text" href="http://data.bibliotheken.nl/id/thes/p147880998" rel="nofollow">Netherlands</a>,
#  <a class="external text" href="http://mak.bn.org.pl/cgi-bin/KHW/makwww.exe?BM=1&amp;NU=1&amp;IM=4&amp;WI=9810630778405606" rel="nofollow">Poland</a>,
#  <a class="external text" href="https://musicbrainz.org/artist/cc0dbdfc-9b2c-4e31-8448-808412388406" rel="nofollow">MusicBrainz</a>,
#  <a class="external text" href="https://trove.nla.gov.au/people/1189569" rel="nofollow">Trove</a>,
#  <a class="external text" href="https://snaccooperative.org/ark:/99166/w6w67gw2" rel="nofollow">SNAC</a>,
#  <a class="external text" href="https://www.idref.fr/067287832" rel="nofollow">IdRef</a>,
#  <a dir="ltr" href="https://en.wikipedia.org/w/index.php?title=Kevin_Bacon&amp;oldid=1151929172">https://en.wikipedia.org/w/index.php?title=Kevin_Bacon&amp;oldid=1151929172</a>,
#  <a href="/wiki/Help:Category" title="Help:Category">Categories</a>,
#  <a href="/wiki/Category:1958_births" title="Category:1958 births">1958 births</a>,
#  <a href="/wiki/Category:20th-century_American_male_actors" title="Category:20th-century American male actors">20th-century American male actors</a>,
#  <a href="/wiki/Category:21st-century_American_male_actors" title="Category:21st-century American male actors">21st-century American male actors</a>,
#  <a href="/wiki/Category:American_atheists" title="Category:American atheists">American atheists</a>,
#  <a href="/wiki/Category:American_male_film_actors" title="Category:American male film actors">American male film actors</a>,
#  <a href="/wiki/Category:American_male_soap_opera_actors" title="Category:American male soap opera actors">American male soap opera actors</a>,
#  <a href="/wiki/Category:American_male_television_actors" title="Category:American male television actors">American male television actors</a>,
#  <a href="/wiki/Category:American_male_voice_actors" title="Category:American male voice actors">American male voice actors</a>,
#  <a href="/wiki/Category:The_Bacon_Brothers_members" title="Category:The Bacon Brothers members">The Bacon Brothers members</a>,
#  <a href="/wiki/Category:Best_Miniseries_or_Television_Movie_Actor_Golden_Globe_winners" title="Category:Best Miniseries or Television Movie Actor Golden Globe winners">Best Miniseries or Television Movie Actor Golden Globe winners</a>,
#  <a href="/wiki/Category:Circle_in_the_Square_Theatre_School_alumni" title="Category:Circle in the Square Theatre School alumni">Circle in the Square Theatre School alumni</a>,
#  <a href="/wiki/Category:Living_people" title="Category:Living people">Living people</a>,
#  <a href="/wiki/Category:Male_actors_from_Philadelphia" title="Category:Male actors from Philadelphia">Male actors from Philadelphia</a>,
#  <a href="/wiki/Category:Obie_Award_recipients" title="Category:Obie Award recipients">Obie Award recipients</a>,
#  <a href="/wiki/Category:Outstanding_Performance_by_a_Cast_in_a_Motion_Picture_Screen_Actors_Guild_Award_winners" title="Category:Outstanding Performance by a Cast in a Motion Picture Screen Actors Guild Award winners">Outstanding Performance by a Cast in a Motion Picture Screen Actors Guild Award winners</a>,
#  <a href="/wiki/Category:Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie_Screen_Actors_Guild_Award_winners" title="Category:Outstanding Performance by a Male Actor in a Miniseries or Television Movie Screen Actors Guild Award winners">Outstanding Performance by a Male Actor in a Miniseries or Television Movie Screen Actors Guild Award winners</a>,
#  <a href="/wiki/Category:Sedgwick_family" title="Category:Sedgwick family">Sedgwick family</a>,
#  <a href="/wiki/Category:People_from_the_Upper_West_Side" title="Category:People from the Upper West Side">People from the Upper West Side</a>,
#  <a href="/wiki/Category:Use_American_English_from_April_2023" title="Category:Use American English from April 2023">Use American English from April 2023</a>,
#  <a href="/wiki/Category:All_Wikipedia_articles_written_in_American_English" title="Category:All Wikipedia articles written in American English">All Wikipedia articles written in American English</a>,
#  <a href="/wiki/Category:Articles_with_short_description" title="Category:Articles with short description">Articles with short description</a>,
#  <a href="/wiki/Category:Short_description_is_different_from_Wikidata" title="Category:Short description is different from Wikidata">Short description is different from Wikidata</a>,
#  <a href="/wiki/Category:Wikipedia_indefinitely_semi-protected_biographies_of_living_people" title="Category:Wikipedia indefinitely semi-protected biographies of living people">Wikipedia indefinitely semi-protected biographies of living people</a>,
#  <a href="/wiki/Category:Use_mdy_dates_from_April_2023" title="Category:Use mdy dates from April 2023">Use mdy dates from April 2023</a>,
#  <a href="/wiki/Category:All_articles_with_unsourced_statements" title="Category:All articles with unsourced statements">All articles with unsourced statements</a>,
#  <a href="/wiki/Category:Articles_with_unsourced_statements_from_October_2021" title="Category:Articles with unsourced statements from October 2021">Articles with unsourced statements from October 2021</a>,
#  <a href="/wiki/Category:Articles_with_hCards" title="Category:Articles with hCards">Articles with hCards</a>,
#  <a href="/wiki/Category:Commons_category_link_from_Wikidata" title="Category:Commons category link from Wikidata">Commons category link from Wikidata</a>,
#  <a href="/wiki/Category:IBDB_name_template_using_Wikidata" title="Category:IBDB name template using Wikidata">IBDB name template using Wikidata</a>,
#  <a href="/wiki/Category:Internet_Off-Broadway_Database_person_ID_same_as_Wikidata" title="Category:Internet Off-Broadway Database person ID same as Wikidata">Internet Off-Broadway Database person ID same as Wikidata</a>,
#  <a href="/wiki/Category:Articles_with_FAST_identifiers" title="Category:Articles with FAST identifiers">Articles with FAST identifiers</a>,
#  <a href="/wiki/Category:Articles_with_ISNI_identifiers" title="Category:Articles with ISNI identifiers">Articles with ISNI identifiers</a>,
#  <a href="/wiki/Category:Articles_with_VIAF_identifiers" title="Category:Articles with VIAF identifiers">Articles with VIAF identifiers</a>,
#  <a href="/wiki/Category:Articles_with_WorldCat_identifiers" title="Category:Articles with WorldCat identifiers">Articles with WorldCat identifiers</a>,
#  <a href="/wiki/Category:Articles_with_BIBSYS_identifiers" title="Category:Articles with BIBSYS identifiers">Articles with BIBSYS identifiers</a>,
#  <a href="/wiki/Category:Articles_with_BNE_identifiers" title="Category:Articles with BNE identifiers">Articles with BNE identifiers</a>,
#  <a href="/wiki/Category:Articles_with_BNF_identifiers" title="Category:Articles with BNF identifiers">Articles with BNF identifiers</a>,
#  <a href="/wiki/Category:Articles_with_BNFdata_identifiers" title="Category:Articles with BNFdata identifiers">Articles with BNFdata identifiers</a>,
#  <a href="/wiki/Category:Articles_with_GND_identifiers" title="Category:Articles with GND identifiers">Articles with GND identifiers</a>,
#  <a href="/wiki/Category:Articles_with_J9U_identifiers" title="Category:Articles with J9U identifiers">Articles with J9U identifiers</a>,
#  <a href="/wiki/Category:Articles_with_LCCN_identifiers" title="Category:Articles with LCCN identifiers">Articles with LCCN identifiers</a>,
#  <a href="/wiki/Category:Articles_with_LNB_identifiers" title="Category:Articles with LNB identifiers">Articles with LNB identifiers</a>,
#  <a href="/wiki/Category:Articles_with_NKC_identifiers" title="Category:Articles with NKC identifiers">Articles with NKC identifiers</a>,
#  <a href="/wiki/Category:Articles_with_NLA_identifiers" title="Category:Articles with NLA identifiers">Articles with NLA identifiers</a>,
#  <a href="/wiki/Category:Articles_with_NLK_identifiers" title="Category:Articles with NLK identifiers">Articles with NLK identifiers</a>,
#  <a href="/wiki/Category:Articles_with_NTA_identifiers" title="Category:Articles with NTA identifiers">Articles with NTA identifiers</a>,
#  <a href="/wiki/Category:Articles_with_PLWABN_identifiers" title="Category:Articles with PLWABN identifiers">Articles with PLWABN identifiers</a>,
#  <a href="/wiki/Category:Articles_with_MusicBrainz_identifiers" title="Category:Articles with MusicBrainz identifiers">Articles with MusicBrainz identifiers</a>,
#  <a href="/wiki/Category:Articles_with_Trove_identifiers" title="Category:Articles with Trove identifiers">Articles with Trove identifiers</a>,
#  <a href="/wiki/Category:Articles_with_SNAC-ID_identifiers" title="Category:Articles with SNAC-ID identifiers">Articles with SNAC-ID identifiers</a>,
#  <a href="/wiki/Category:Articles_with_SUDOC_identifiers" title="Category:Articles with SUDOC identifiers">Articles with SUDOC identifiers</a>]

# %% [markdown]
# re.compile('^(/wiki/)((?!:).)*$')의 의미
#
# - ^ : 문자열의 시작
# - $(/wiki/) : /wiki/로 시작하는 문자열$
# - $((?!:).)* :  :을 포함하지 않은 모든 문자열$
# - $(?!:) : :이 포함되지 않은 경우$
# - $. : 어떤 문자열이라도 일치$
# - $* : 0번 이상 반복$
# - $\$ : 문자열의 끝$
#
# 이 정규표현식은 /wiki/로 시작하면서 :이 포함되지 않은 모든 문자열과 일치합니다. 이러한 패턴을 가진 문자열은 위키피디아의 링크에 해당하는 문자열이기 때문에, 위키피디아에서 링크를 추출할 때 사용될 수 있습니다.

# %%
# /wiki/Wikipedia:Protection_policy#semi 형태를 제외
for link in bs.find('div', {'id':'bodyContent'}).find_all(
    'a', href=re.compile('^(/wiki/)((?!:).)*$')): # 부정형 전방탐색
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Philadelphia,_Pennsylvania
# /wiki/Kevin_Bacon_filmography
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Holly_Near
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Balto_(film)
# /wiki/Sleepers
# /wiki/The_Woodsman_(2004_film)
# /wiki/Animal_House
# /wiki/Diner_(1982_film)
# /wiki/Tremors_(1990_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Flatliners
# /wiki/The_River_Wild
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/Hollow_Man
# /wiki/Frost/Nixon_(film)
# /wiki/Black_Mass_(film)
# /wiki/Patriots_Day_(film)
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/Streaming_television
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/The_Guardian
# /wiki/Academy_Award
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/SixDegrees.org
# /wiki/EE_Limited
# /wiki/Philadelphia
# /wiki/Edmund_Bacon_(architect)
# /wiki/Julia_R._Masterman_High_School
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Glory_Van_Scott
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Getting_Out
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(1982_film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# /wiki/Footloose_(1984_film)
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/She%27s_Having_a_Baby
# /wiki/The_Big_Picture_(1989_film)
# /wiki/Tremors_(1990_film)
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# /wiki/The_New_York_Times
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men_(film)
# /wiki/Michael_Greif
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# /wiki/Sleepers_(film)
# /wiki/Picture_Perfect_(1997_film)
# /wiki/Losing_Chase
# /wiki/Digging_to_China
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# /wiki/Cannes_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Toronto_Film_Festival
# /wiki/Matthew_Vaughn
# /wiki/Sebastian_Shaw_(comics)
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Huffington_Post
# /wiki/Tremors_(1990_film)
# /wiki/EE_(telecommunications_company)
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Social_networking_service
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/IMDb
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# /wiki/Tracy_Pollan
# /wiki/Separation_of_church_and_state_in_the_United_States
# /wiki/The_Times
# /wiki/God
# /wiki/Antireligion
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Denver_Film_Festival
# /wiki/Phoenix_Film_Festival
# /wiki/Santa_Barbara_International_Film_Festival
# /wiki/Broadcast_Film_Critics_Association
# /wiki/Seattle_International_Film_Festival
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# /wiki/The_Austin_Chronicle
# /wiki/Access_Hollywood
# /wiki/IMDb
# /wiki/Internet_Broadway_Database
# /wiki/Internet_Off-Broadway_Database
# /wiki/AllMovie
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/The_Bacon_Brothers
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Will_Smith
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber_(actor)
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Sam_Heughan
# /wiki/Patrick_Stewart
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/ISNI_(identifier)
# /wiki/VIAF_(identifier)
# /wiki/MBA_(identifier)
# /wiki/RERO_(identifier)
# /wiki/SUDOC_(identifier)
# /wiki/Trove_(identifier)

# %%
# Q. 코스피 지수, 등락폭 및 등락율을 출력하세요.
import requests
from bs4 import BeautifulSoup

# 네이버 금융 국내증시 메인 사이트 주소
# url = "https://finance.naver.com/sise/"
url = 'https://finance.naver.com/sise/sise_index.naver?code=KOSPI'

# 웹사이트 정보 요청
html = requests.get(url).text

# html.parser로 html 형식 태그에서 데이터 추출 준비
soup = BeautifulSoup(html, 'html.parser')
print(soup.prettify())
# Out:
# <script type="text/javascript">
#  function mainSiseMove(code) {
# 	if (code=='KONEX') {
# 		document.location.href='/sise/konex.naver';
# 	} else if(code=='ETF') {
# 		document.location.href='/sise/etf.naver';
#     } else if(code=='ETN') {
#         document.location.href='/sise/etn.naver';
# 	} else {
# 		document.location.href='/sise/sise_index.naver?code='+code;
# 	}
# }
# </script>
# <!--  global include -->
# <html lang="ko">
#  <head>
#   <title>
#    코스피 : 네이버 증권
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="text/javascript" http-equiv="Content-Script-Type"/>
#   <meta content="text/css" http-equiv="Content-Style-Type"/>
#   <meta content="네이버 증권" name="apple-mobile-web-app-title">
#    <meta content="http://finance.naver.com/sise/sise_index.naver" property="og:url">
#     <meta content="코스피 : 네이버 증권" property="og:title"/>
#     <meta content="관심종목의 실시간 주가를 가장 빠르게 확인하는 곳" property="og:description"/>
#     <meta content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png" property="og:image"/>
#     <meta content="article" property="og:type"/>
#     <meta content="" property="og:article:thumbnailUrl"/>
#     <meta content="네이버 증권" property="og:article:author"/>
#     <meta content="http://FINANCE.NAVER.COM" property="og:article:author:url"/>
#     <link href="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/css/finance_header.css" rel="stylesheet" type="text/css"/>
#     <link href="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/css/newstock.css" rel="stylesheet" type="text/css"/>
#     <link href="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/css/common.css" rel="stylesheet" type="text/css"/>
#     <link href="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/css/layout.css" rel="stylesheet" type="text/css"/>
#     <link href="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/css/main.css" rel="stylesheet" type="text/css"/>
#     <link href="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/css/newstock2.css" rel="stylesheet" type="text/css"/>
#     <link href="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/css/newstock3.css" rel="stylesheet" type="text/css"/>
#     <link href="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/css/world.css" rel="stylesheet" type="text/css"/>
#     <script src="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/js/jindo.min.ns.1.5.3.euckr.js" type="text/javascript">
#     </script>
#     <script src="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/js/release/common.js" type="text/javascript">
#     </script>
#     <script src="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/js/jindoComponent/jindo.Component.1.0.3.js" type="text/javascript">
#     </script>
#     <script src="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/js/nhn.autocomplete.stock.js" type="text/javascript">
#     </script>
#     <link href="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/css/chartiq.css" rel="stylesheet" type="text/css"/>
#     <script src="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/js/thirdparty/html2canvas.min.js" type="text/javascript">
#     </script>
#     <script>
#      var ieVersion = (function () {
#         var version = -1;
#         if (
#           navigator.appName == 'Microsoft Internet Explorer' &&
#           navigator.userAgent.toLowerCase().indexOf('msie') != -1 &&
#           new RegExp('MSIE ([0-9]{1,}[\./0-9]{0,})').exec(navigator.userAgent) != null
#         ) {
#           version = parseInt(RegExp.$1);
#         }
#         return version;
#       })();
#     </script>
#     <link href="https://ssl.pstatic.net/imgstock/favi/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#     <script type="text/javascript">
#      (function(){
# 		document.write(
# 				[
# 					'<link rel="apple-touch-icon-precomposed" href="https://ssl.pstatic.net/imgstock/favi/favicon-96x96.png"/>',
# 					'<link rel="apple-touch-icon-precomposed" sizes="180x180" href="https://ssl.pstatic.net/imgstock/favi/favicon-180x180.png"/>',
# 					'<link rel="apple-touch-icon-precomposed" sizes="192x192" href="https://ssl.pstatic.net/imgstock/favi/favicon-192x192.png"/>',
# 					'<link rel="icon" type="image/png" sizes="16x16" href="https://ssl.pstatic.net/imgstock/favi/favicon-16x16.png"/>',
# 					'<link rel="icon" type="image/png" sizes="32x32" href="https://ssl.pstatic.net/imgstock/favi/favicon-32x32.png"/>',
# 					'<link rel="icon" type="image/png" sizes="96x96" href="https://ssl.pstatic.net/imgstock/favi/favicon-96x96.png"/>',
# 					'<link rel="icon" type="image/png" sizes="192x192" href="https://ssl.pstatic.net/imgstock/favi/favicon-192x192.png"/>'
# 				]
# 			.join('\n')
# 		);
#     })();
#     </script>
#    </meta>
#   </meta>
#  </head>
#  <body onload="getGNB();">
#   <script type="text/javascript">
#    var nclk_evt = 3;
# 	nclk_do();
#   </script>
#   <script type="text/javascript">
#    var nsc="finance.stock";
#
#
#
#
#
# var ccsrv="cc.naver.com";
#
#
#
#
# 	var gnb_service='finance';
#
#
#
# var gnb_logout=document.URL; //GNB에서 로그아웃 후 redirect 될 URL
# var gnb_searchbox='off'; //미니 검색창을 on 할지 off 할지. default는 off
# var gnb_shortnick='off'; //닉네임 말줄임(10자)을 on할지 off 할지. default는 off.
#
#
# var gnb_naverme_layer_open_callback = function(){
# 	   var naverLayerSize = gnbNaverMeLayer.getLayerSize();
#
# 		var me_layers = document.getElementById("me_layers");
# 		me_layers.width=naverLayerSize.width;
# 		me_layers.height=naverLayerSize.height;};
#
# var gnb_naverme_layer_close_callback = function(){
#
# 			var me_layers = document.getElementById("me_layers");
# 			me_layers.width="0";
# 			me_layers.height="0";};
#   </script>
#   <div id="u_skip">
#    <a href="#menu" tabindex="1">
#     <span>
#      메인 메뉴로 바로가기
#     </span>
#    </a>
#    <a href="#start" tabindex="2">
#     <span>
#      본문으로 바로가기
#     </span>
#    </a>
#   </div>
#   <div id="header">
#    <div class="snb_area">
#     <div class="snb_inner">
#      <div id="gnb_area">
#       <div id="gnb">
#        <script charset="EUC-KR" type="text/javascript">
#         var gnb_service = "gnbtest";
#                     var gnb_template = location.protocol == "http:" ? "gnb_quirks_euckr" : "gnb_utf8" ;
# 					var gnb_dark = false;
# 					var gnb_brightness = 1;
# 					var gnb_logout=encodeURIComponent(location.href);
# 					var gnb_one_naver = 1;
#        </script>
#        <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn?20230430" type="text/javascript">
#        </script>
#       </div>
#      </div>
#      <div class="sta">
#       <h1 class="logo">
#        <a class="logo_naver" href="https://www.naver.com/" onclick="clickcr(this, 'STA.naver', '', '', event);">
#         <span class="blind">
#          네이버
#         </span>
#        </a>
#        <a class="logo_service" href="/" onclick="clickcr(this, 'STA.finance', '', '', event);">
#         <span class="blind">
#          증권
#         </span>
#        </a>
#       </h1>
#       <form action="/search/search.naver" method="get" name="search" onsubmit="return delayed_submit(this)" style="margin:0; padding:0;">
#        <fieldset>
#         <legend>
#          검색
#         </legend>
#         <div class="snb_search_box">
#          <div class="snb_search_box_sub">
#           <input accesskey="s" autocomplete="off" class="snb_search_text snb_default" id="stock_items" name="query" title="검색" type="text" value="종목명·지수명 입력"/>
#           <a class="btn_arrow" href="#" id="nautocomplete" onclick="return false">
#            <span class="blind">
#             자동완성 펼치기
#            </span>
#           </a>
#          </div>
#          <div class="auto_area">
#           <h2 class="blind">
#            자동완성
#           </h2>
#           <div id="autoFrame" style="display: none;">
#            <div class="wrap" id="atcmp" style="display:none;">
#             <div class="wrap_in">
#              <div class="words">
#               <ul class="_resultBox">
#                <li>
#                 <a class="_au_real_list" href="#" onclick="clickcr(this, 'AUT.list', '', '', event); return false;">
#                  <span class="num _au_real_list">
#                   @code@
#                  </span>
#                  <span class="_au_real_list">
#                   @txt@
#                  </span>
#                  <span class="type _au_real_list">
#                   @market@
#                  </span>
#                 </a>
#                 <div class="_au_full" style="display:none">
#                  @full_txt@
#                 </div>
#                 <div class="_au_code" style="display:none">
#                  @in_code@
#                 </div>
#                 <div class="_au_name" style="display:none">
#                  @in_name@
#                 </div>
#                 <div class="_au_link" style="display:none">
#                  @in_link@
#                 </div>
#                 <div class="_au_market" style="display:none">
#                  @in_market@
#                 </div>
#                </li>
#               </ul>
#              </div>
#              <p class="func">
#               <span>
#                <a class="fire_event funoff" href="#" onclick="clickcr(this, 'AUT.x', '', '', event); smartSearch.unuse(); return false;">
#                 기능끄기
#                </a>
#               </span>
#              </p>
#             </div>
#            </div>
#            <!-- 현재 자동완성 기능을 사용하고 계십니다 -->
#            <div class="wrap" id="atcmpIng" style="display:none;">
#             <div class="wrap_in">
#              <div class="words">
#               <p class="msg">
#                현재 자동완성 기능을 사용하고 계십니다.
#               </p>
#              </div>
#              <p class="func">
#               <span>
#                <a class="fire_event funoff" href="#" onclick="clickcr(this, 'AUT.x', '', '', event); smartSearch.unuse(); return false;">
#                 기능끄기
#                </a>
#               </span>
#              </p>
#             </div>
#            </div>
#            <!--// 현재 자동완성 기능을 사용하고 계십니다 -->
#            <!-- 자동완성 기능이 활성화 -->
#            <div class="wrap" id="atcmpStart" style="display:none;">
#             <div class="wrap_in">
#              <div class="words">
#               <p class="msg">
#                자동완성 기능이 활성화되었습니다.
#               </p>
#              </div>
#              <p class="func">
#               <span>
#                <a class="fire_event funoff" href="#" onclick="clickcr(this, 'AUT.x', '', '', event); smartSearch.unuse(); return false;">
#                 기능끄기
#                </a>
#               </span>
#              </p>
#             </div>
#            </div>
#           </div>
#          </div>
#          <button alt="검색" class="snb_search_btn" onclick="clickcr(this, 'STA.search', '', '', event);" type="submit">
#           <span class="blind">
#            검색
#           </span>
#          </button>
#          <a class="snb_search_btn-total" href="#" onclick="itegrationSearch();clickcr(this, 'STA.nx', '', '', event);return false;" target="_blank">
#           통합검색
#          </a>
#         </div>
#        </fieldset>
#       </form>
#      </div>
#     </div>
#    </div>
#    <div class="lnb_area">
#     <div class="lnb_inner">
#      <div id="menu">
#       <ul class="menu">
#        <li class="m1 first">
#         <a href="/" onclick="clickcr(this, 'LNB.home', '', '', event);">
#          <span class="tx">
#           증권 홈
#          </span>
#         </a>
#        </li>
#        <li class="m2 on">
#         <a href="/sise/" onclick="clickcr(this, 'LNB.sise', '', '', event);">
#          <span class="tx">
#           국내증시
#          </span>
#         </a>
#        </li>
#        <li class="m3">
#         <a href="/world/" onclick="clickcr(this, 'LNB.world', '', '', event);">
#          <span class="tx">
#           해외증시
#          </span>
#         </a>
#        </li>
#        <li class="m4">
#         <a href="/marketindex/" onclick="clickcr(this, 'LNB.market', '', '', event);">
#          <span class="tx">
#           시장지표
#          </span>
#         </a>
#        </li>
#        <li class="m6">
#         <a href="/research/" onclick="clickcr(this, 'LNB.research', '', '', event);">
#          <span class="tx">
#           리서치
#          </span>
#         </a>
#        </li>
#        <li class="m7">
#         <a href="/news/">
#          <span class="tx">
#           뉴스
#          </span>
#         </a>
#        </li>
#        <li class="m8">
#         <a href="/mystock/" onclick="clickcr(this, 'LNB.mystock', '', '', event);">
#          <span class="tx">
#           MY
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </div>
#    <script type="text/JavaScript">
#     /* lcs 집계 */
#         ;(function(){
#             var eventType = "onpageshow" in window ? "pageshow" : "load";
#             jindo.$Fn(function(){
#                 lcs_do();
#             }).attach(window, eventType);
#         })();
#
# 		/* 검색 자동완성 [ 인자1 : 검색input의 ID, 인자2 : iframe 태그 ID ]   */
# 		// AutoComplete 생성
# 		var acDomain = "ac.finance.naver.com";
#         if (location.hostname.indexOf("staging-") > -1) {
#             acDomain = "staging-" + acDomain;
#         } else if (location.hostname.indexOf("dev-") > -1 || location.hostname.indexOf("localhost") > -1 || location.hostname.indexOf("local-") > -1) {
# 			acDomain = "dev-" + acDomain;
# 		}
#
#         var acUrl = "https://" + acDomain + "/ac";
#
# 		smartSearch = new nhn.Autocomplete(
# 			// InputManager 생성
# 			new nhn.AcInputManager(jindo.$("stock_items")),
# 			// DataManager 생성
# 			new nhn.AcDataManager(acUrl, "jsonp", "get", {
#                     st: "111",
#                     r_lt : "111",
#                     q_enc : "euc-kr",
#                     r_enc : "euc-kr",
#                     frm: "stock"}),
# 			// ViewManager 생성
# 			new nhn.AcStockViewManager(jindo.$("autoFrame"), jindo.$("nautocomplete"), {
#                                         strMax: 200,
#                                         listMax: [7, 2, 2],
#                                         aRedirectUrl : [
#                             			"https://finance.naver.com",
#                             			"https://finance.naver.com",
#                             			"https://finance.naver.com"]}),
# 			// Autocomplete Option
#             {formId:"search", cookieDomain:location.hostname, cookieName:"NaverCommonStock"});
#
# 			smartSearch.attach({
# 	            onFocus: function () {
# 	                var weInput = jindo.$Element('stock_items');
# 	                if (weInput && weInput.hasClass("snb_default")) {
# 	                        weInput.text("");
# 	                        weInput.removeClass('snb_default');
# 	                }
# 	            }
# 	        });
#
# 		/* 통합검색  start ----->  */
# 		//document.domain = 'naver.com';
# 		var sSearchHintText = '종목명·지수명·환율명·원자재명 입력';
# 		function itegrationSearch() {
# 			var query = jindo.$('stock_items').value;
#
# 			if ( query == ''  || encodeURIComponent(query) == encodeURIComponent(sSearchHintText))
# 			{
# 				alert ( '검색어를 입력해 주세요.' );
# 				return;
# 			}
#
#             var url = location.protocol + "//search.naver.com/search.naver?sm=sta_hty.finance&where=nexearch&ie=UTF8&query=" + encodeURIComponent(query);
#             window.open(url, "_blank");
#
# 			return false;
# 		}
#
# 		function delayed_submit(object) {
# 			if (navigator.userAgent.indexOf('MSIE') == -1) {
# 				window.setTimeout(function() {stock_search(object)}, 300);
# 			} else {
# 				stock_search(object);
# 			}
# 			return false;
# 		}
#
# 		function stock_search (object)
# 		{
# 			query = object.query.value.replace(/^\s*/,'').replace(/\s*$/,'');	// trim
# 			object.query.value=query;
#
# 			if ( query == '' || query == sSearchHintText.replace(/^\s*/,'').replace(/\s*$/,''))
# 			{
# 				alert ( '검색어를 입력해 주세요.' );
# 				return;
# 			}
# 			else {
# 				object.submit();
# 			}
# 		}
# 		/* <---------- 통합검색  end */
#
# 		function popup()
# 		{
# 			win = window.open('/template/group_limit_pop.jsp','finan_popup','width=569 height=278 scrollbars=no status=no');
# 			win.focus();
# 		}
#    </script>
#    <iframe frameborder="0" height="0" id="me_layers" name="test" scrolling="no" style="display:block;top: 22px; right: 209px; position: absolute; z-index: 15;" title="네이버미 영역" width="0">
#    </iframe>
#   </div>
#   <div id="wrap">
#    <!-- //  global include -->
#    <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/js/recent_code.js">
#    </script>
#    <div id="newarea">
#     <!-- leftmenu -->
#     <div class="snb snb2">
#      <h2 class="h_sise">
#       <a href="/sise/">
#        <span class="blind">
#         국내증시
#        </span>
#       </a>
#      </h2>
#      <ul class="nav1">
#       <li class="frst">
#        <strong class="lst_sise">
#         <span class="blind">
#          주요시세정보
#         </span>
#        </strong>
#        <ul class="sub">
#         <li class="type1 lst1_1">
#          <a class="on" href="/sise/sise_index.naver?code=KOSPI" onclick="clickcr(this,'siu.1','','',event);">
#           <span class="blind">
#            코스피
#           </span>
#          </a>
#         </li>
#         <li class="type1 lst1_2">
#          <a class="off" href="/sise/sise_index.naver?code=KOSDAQ" onclick="clickcr(this,'siu.2','','',event);">
#           <span class="blind">
#            코스닥
#           </span>
#          </a>
#         </li>
#         <li class="type1 lst1_3">
#          <a class="off" href="/sise/sise_index.naver?code=FUT" onclick="clickcr(this,'siu.3','','',event);">
#           <span class="blind">
#            선물
#           </span>
#          </a>
#         </li>
#         <li class="type1 lst1_26">
#          <a class="off" href="/sise/sise_index.naver?code=KPI200" onclick="clickcr(this,'siu.26','','',event);">
#           <span class="blind">
#            코스피200
#           </span>
#          </a>
#         </li>
#         <li class="type1 lst1_31">
#          <a class="off" href="/sise/konex.naver" onclick="clickcr(this,'siu.konex','','',event);">
#           <span class="blind">
#            코넥스
#           </span>
#          </a>
#         </li>
#         <li class="type1 lst1_16">
#          <a class="off" href="/sise/sise_market_sum.naver" onclick="clickcr(this,'siu.16','','',event);">
#           <span class="blind">
#            시가총액
#           </span>
#          </a>
#         </li>
#         <li class="type1 lst1_32">
#          <a class="off" href="/sise/dividend_list.naver" onclick="clickcr(this,'siu.dividend','','',event);">
#           <span class="blind">
#            배당
#           </span>
#          </a>
#         </li>
#         <li class="type1 lst1_4">
#          <a class="off" href="/sise/sise_group.naver?type=upjong" onclick="clickcr(this,'siu.4','','',event);">
#           <span class="blind">
#            업종
#           </span>
#          </a>
#         </li>
#         <li class="type1 lst1_5">
#          <a class="off" href="/sise/theme.naver" onclick="clickcr(this,'siu.5','','',event);">
#           <span class="blind">
#            테마
#           </span>
#          </a>
#         </li>
#         <li class="type1 lst1_30">
#          <a class="off" href="/sise/sise_group.naver?type=group" onclick="clickcr(this,'siu.30','','',event);">
#           <span class="blind">
#            그룹사
#           </span>
#          </a>
#         </li>
#         <li class="type1 lst1_27">
#          <a class="off" href="/sise/etf.naver" onclick="clickcr(this,'siu.27','','',event);">
#           <span class="blind">
#            ETF
#           </span>
#          </a>
#         </li>
#         <li class="type1 lst1_34">
#          <a class="off" href="/sise/etn.naver" onclick="clickcr(this,'siu.34','','',event);">
#           <span class="blind">
#            ETN
#           </span>
#          </a>
#         </li>
#         <li class="type1 lst1_8">
#          <a class="off" href="/sise/sise_rise.naver" onclick="clickcr(this,'siu.8','','',event);">
#           <span class="blind">
#            상승
#           </span>
#          </a>
#         </li>
#         <li class="type1 lst1_9">
#          <a class="off" href="/sise/sise_steady.naver" onclick="clickcr(this,'siu.9','','',event);">
#           <span class="blind">
#            보합
#           </span>
#          </a>
#         </li>
#         <li class="type1 lst1_10">
#          <a class="off" href="/sise/sise_fall.naver" onclick="clickcr(this,'siu.10','','',event);">
#           <span class="blind">
#            하락
#           </span>
#          </a>
#         </li>
#         <li class="type1 lst1_6">
#          <a class="off" href="/sise/sise_upper.naver" onclick="clickcr(this,'siu.6','','',event);">
#           <span class="blind">
#            상한가
#           </span>
#          </a>
#         </li>
#         <li class="type1 lst1_7">
#          <a class="off" href="/sise/sise_lower.naver" onclick="clickcr(this,'siu.7','','',event);">
#           <span class="blind">
#            하한가
#           </span>
#          </a>
#         </li>
#         <li class="type1 lst1_15">
#          <a class="off" href="/sise/sise_low_up.naver" onclick="clickcr(this,'siu.15','','',event);">
#           <span class="blind">
#            급등
#           </span>
#          </a>
#         </li>
#         <li class="type1 lst1_14">
#          <a class="off" href="/sise/sise_high_down.naver" onclick="clickcr(this,'siu.14','','',event);">
#           <span class="blind">
#            급락
#           </span>
#          </a>
#         </li>
#         <li class="type2 lst1_11">
#          <a class="off" href="/sise/sise_quant.naver" onclick="clickcr(this,'siu.11','','',event);">
#           <span class="blind">
#            거래상위
#           </span>
#          </a>
#         </li>
#         <li class="type1 lst1_12">
#          <a class="off" href="/sise/sise_quant_high.naver" onclick="clickcr(this,'siu.12','','',event);">
#           <span class="blind">
#            급증
#           </span>
#          </a>
#         </li>
#         <li class="type1 lst1_13">
#          <a class="off" href="/sise/sise_quant_low.naver" onclick="clickcr(this,'siu.13','','',event);">
#           <span class="blind">
#            급감
#           </span>
#          </a>
#         </li>
#         <li class="lst1_23">
#          <a class="off" href="/sise/sise_trans_style.naver" onclick="clickcr(this,'siu.23','','',event);">
#           <span class="blind">
#            투자자별매매동향
#           </span>
#          </a>
#         </li>
#         <li class="type1 lst1_17">
#          <a class="off" href="/sise/sise_deal_rank.naver" onclick="clickcr(this,'siu.17','','',event);">
#           <span class="blind">
#            외국인매매
#           </span>
#          </a>
#         </li>
#         <li class="type1 lst1_18">
#          <a class="off" href="/sise/sise_deal_rank.naver?investor_gubun=1000" onclick="clickcr(this,'siu.18','','',event);">
#           <span class="blind">
#            기관매매
#           </span>
#          </a>
#         </li>
#         <li class="lst1_19">
#          <a class="off" href="/sise/sise_program.naver" onclick="clickcr(this,'siu.19','','',event);">
#           <span class="blind">
#            프로그램매매동향
#           </span>
#          </a>
#         </li>
#         <li class="lst1_22">
#          <a class="off" href="/sise/sise_deposit.naver" onclick="clickcr(this,'siu.22','','',event);">
#           <span class="blind">
#            증시자금동향
#           </span>
#          </a>
#         </li>
#         <li class="lst1_21">
#          <a class="off" href="/sise/sise_new_stock.naver" onclick="clickcr(this,'siu.21','','',event);">
#           <span class="blind">
#            신규상장
#           </span>
#          </a>
#         </li>
#         <li class="lst1_24">
#          <a class="off" href="/sise/sise_foreign_hold.naver" onclick="clickcr(this,'siu.24','','',event);">
#           <span class="blind">
#            외국인보유
#           </span>
#          </a>
#         </li>
#         <li class="lst1_25">
#          <a class="off" href="/sise/market3news_list.naver" onclick="clickcr(this,'siu.25','','',event);">
#           <span class="blind">
#            장외시세
#           </span>
#          </a>
#         </li>
#         <li class="lst1_33">
#          <a class="off" href="/sise/ipo.naver" onclick="clickcr(this,'siu.33','','',event);">
#           <span class="blind">
#            IPO
#           </span>
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li>
#        <strong class="lst_prevent">
#         <span class="blind">
#          투자자보호
#         </span>
#        </strong>
#        <ul class="sub">
#         <li class="lst1_20">
#          <a class="off" href="/sise/management.naver" onclick="clickcr(this,'siu.20','','',event);">
#           <span class="blind">
#            관리종목
#           </span>
#          </a>
#         </li>
#         <li class="lst1_29">
#          <a class="off" href="/sise/trading_halt.naver" onclick="clickcr(this,'siu.29','','',event);">
#           <span class="blind">
#            거래정지종목
#           </span>
#          </a>
#         </li>
#         <li class="lst1_28">
#          <a class="off" href="/sise/investment_alert.naver?type=caution" onclick="clickcr(this,'siu.28','','',event);">
#           <span class="blind">
#            시장경보종목
#           </span>
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li>
#        <strong class="lst_search">
#         <span class="blind">
#          종목조건검색
#         </span>
#        </strong>
#        <ul class="sub">
#         <li class="type1 lst2_2">
#          <a class="off" href="/sise/item_gold.naver" onclick="clickcr(this,'sih.2','','',event);">
#           <span class="blind">
#            골든크로스
#           </span>
#          </a>
#         </li>
#         <li class="type1 lst2_1">
#          <a class="off" href="/sise/item_gap.naver" onclick="clickcr(this,'sih.1','','',event);">
#           <span class="blind">
#            갭상승
#           </span>
#          </a>
#         </li>
#         <li class="type1 lst2_3">
#          <a class="off" href="/sise/item_igyuk.naver" onclick="clickcr(this,'sih.3','','',event);">
#           <span class="blind">
#            이격도과열
#           </span>
#          </a>
#         </li>
#         <li class="type1 lst2_4">
#          <a class="off" href="/sise/item_overheating_1.naver" onclick="clickcr(this,'sih.4','','',event);">
#           <span class="blind">
#            투심과열
#           </span>
#          </a>
#         </li>
#         <li class="lst2_5">
#          <a class="off" href="/sise/item_overheating_2.naver" onclick="clickcr(this,'sih.5','','',event);">
#           <span class="blind">
#            상대강도과열
#           </span>
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li>
#        <a href="/sise/report.naver">
#         <strong class="lst_report">
#          <span class="blind">
#           기업 전자공시
#          </span>
#         </strong>
#        </a>
#       </li>
#       <li class="last">
#        <a href="/sise/short_trade.naver">
#         <strong class="lst_short">
#          <span class="blind">
#           공매도 종합 현황
#          </span>
#         </strong>
#        </a>
#       </li>
#      </ul>
#     </div>
#     <!-- //leftmenu -->
#     <div id="contentarea">
#      <!-- 컨텐츠 -->
#      <div id="contentarea_left">
#       <!-- 로케이터 -->
#       <form action="/sise/sise_index.naver" method="GET" name="sise_index">
#        <div class="sub_location tlt_bottom_line">
#         <a href="/">
#          증권홈
#         </a>
#         &gt;
#         <a href="/sise/">
#          국내증시
#         </a>
#         &gt;
#         <a href="#">
#          주요시세정보
#         </a>
#         &gt;
#         <select name="code" onchange="javascript:mainSiseMove(value);">
#          <option selected="" value="KOSPI">
#           코스피
#          </option>
#          <option value="KOSDAQ">
#           코스닥
#          </option>
#          <option value="FUT">
#           선물
#          </option>
#          <option value="KPI200">
#           코스피200
#          </option>
#          <option value="ETF">
#           ETF
#          </option>
#          <option value="ETN">
#           ETN
#          </option>
#          <option value="KONEX">
#           코넥스
#          </option>
#         </select>
#        </div>
#       </form>
#       <!-- //로케이터 -->
#       <div class="group_heading">
#        <h3 class="sub_tlt">
#         코스피
#        </h3>
#        <div class="ly_realtime">
#         <a class="btn_realtime" href="#">
#          <span class="blind">
#           실시간
#          </span>
#          <span class="ly_help">
#           실시간으로 지수
#           <br/>
#           데이터를 제공 중입니다.
#          </span>
#         </a>
#         <span id="time">
#          2023.04.28 장마감
#         </span>
#        </div>
#       </div>
#       <div class="box_top_sub" style="width:592px;_width:594px;height:296px">
#        <img alt="" class="rb" src="https://ssl.pstatic.net/imgstock/images5/blank.gif"/>
#        <img alt="" class="lb" src="https://ssl.pstatic.net/imgstock/images5/blank.gif"/>
#        <img alt="" class="rt" src="https://ssl.pstatic.net/imgstock/images5/blank.gif"/>
#        <img alt="" class="lt" src="https://ssl.pstatic.net/imgstock/images5/blank.gif"/>
#        <div class="inner_sub">
#         <div class="subtop_sise_graph">
#          <ul class="term">
#           <!-- 활성화 탭에는 on 클래스가 붙습니다 -->
#           <script language="javascript">
#            function select_chart(pst)
# {
# 	for(var i=0 ; i<4 ; i++)
# 	{
# 		if (i == pst)
# 			document.getElementById('chart_'+pst).className = 'on';
# 		else
# 			document.getElementById('chart_'+i).className = "";
# 	}
# }
#           </script>
#           <li class="on" id="chart_0">
#            <a href="javascript:select_chart(0)">
#             <strong>
#              1
#             </strong>
#             일
#            </a>
#            <div class="graph">
#             <img alt="그래프" height="140" onerror="(new jindo.$Ajax('https://finance.naver.com/onErrorImageUrlSave.naver', {type:'jsonp', method:'get'})).request({imageUrl:this.src + ' | finance'});" src="https://ssl.pstatic.net/imgstock/chart3/day/KOSPI.png?sidcode=1682856131435" width="201"/>
#            </div>
#           </li>
#           <li class="" id="chart_1">
#            <a href="javascript:select_chart(1)">
#             3개월
#            </a>
#            <div class="graph">
#             <img alt="그래프" height="140" src="https://ssl.pstatic.net/imgstock/chart3/day90/KOSPI.png?sidcode=1682856131435" width="201"/>
#            </div>
#           </li>
#           <li class="" id="chart_2">
#            <a href="javascript:select_chart(2)">
#             1년
#            </a>
#            <div class="graph">
#             <img alt="그래프" height="140" src="https://ssl.pstatic.net/imgstock/chart3/day365/KOSPI.png?sidcode=1682856131435" width="201"/>
#            </div>
#           </li>
#           <li class="" id="chart_3">
#            <a href="javascript:select_chart(3)">
#             3년
#            </a>
#            <div class="graph">
#             <img alt="그래프" height="140" src="https://ssl.pstatic.net/imgstock/chart3/day1095/KOSPI.png?sidcode=1682856131435" width="201"/>
#            </div>
#           </li>
#          </ul>
#         </div>
#         <div class="subtop_sise_detail">
#          <!-- [D] 상승장일때 up, 하락장일때 dn 클래스 추가 (보합시 추가 없음) -->
#          <div class="quotient up" id="quotient">
#           <em id="now_value">
#            2,501.53
#           </em>
#           <span class="fluc" id="change_value_and_rate">
#            <span>
#             5.72
#            </span>
#            +0.23%
#            <span class="blind">
#             상승
#            </span>
#           </span>
#          </div>
#          <table cellpadding="0" cellspacing="0" class="table_kos_index" summary="코스피 주요시세 정보에 관한 표입니다.">
#           <caption>
#            코스피 주요시세
#           </caption>
#           <tr>
#            <th class="th">
#             <span class="blind">
#              거래량(천주)
#             </span>
#            </th>
#            <td class="td" id="quant">
#             777,535
#            </td>
#            <th class="th2">
#             <span class="blind">
#              거래대금(백만)
#             </span>
#            </th>
#            <td class="td2" id="amount">
#             14,024,831
#            </td>
#           </tr>
#           <tr>
#            <th>
#             <span class="blind">
#              장중최고
#             </span>
#            </th>
#            <td class="td" id="high_value">
#             2,517.13
#            </td>
#            <th>
#             <span class="blind">
#              장중최저
#             </span>
#            </th>
#            <td class="td2" id="low_value">
#             2,489.58
#            </td>
#           </tr>
#           <tr>
#            <th>
#             <span class="blind">
#              52주최고
#             </span>
#            </th>
#            <td class="td">
#             2,702.10
#            </td>
#            <th>
#             <span class="blind">
#              52주최저
#             </span>
#            </th>
#            <td class="td2">
#             2,134.77
#            </td>
#           </tr>
#           <tr>
#            <th class="th">
#             <span class="blind">
#              등락/종목
#             </span>
#            </th>
#            <td class="td3" colspan="3">
#             <ul>
#              <li class="lst">
#               <span class="blind">
#                상한종목수
#               </span>
#               <a href="/sise/sise_upper.naver">
#                <span>
#                 0
#                </span>
#               </a>
#              </li>
#              <li class="lst2">
#               <span class="blind">
#                상승종목수
#               </span>
#               <a href="/sise/sise_rise.naver">
#                <span>
#                 424
#                </span>
#               </a>
#              </li>
#              <li class="lst3">
#               <span class="blind">
#                보합종목수
#               </span>
#               <a href="/sise/sise_steady.naver">
#                <span>
#                 54
#                </span>
#               </a>
#              </li>
#              <li class="lst4">
#               <span class="blind">
#                하락종목수
#               </span>
#               <a href="/sise/sise_fall.naver">
#                <span>
#                 452
#                </span>
#               </a>
#              </li>
#              <li class="lst5">
#               <span class="blind">
#                하한종목수
#               </span>
#               <a href="/sise/sise_lower.naver">
#                <span>
#                 0
#                </span>
#               </a>
#              </li>
#             </ul>
#            </td>
#           </tr>
#          </table>
#         </div>
#         <div class="c">
#         </div>
#         <dl class="lst_kos_info">
#          <dt>
#           <span class="blind">
#            투자자별 매매동향
#           </span>
#          </dt>
#          <dd class="dd">
#           개인
#           <br/>
#           <span class="up">
#            +1,360
#            <span>
#             억
#            </span>
#           </span>
#          </dd>
#          <dd class="dd">
#           외국인
#           <br/>
#           <span class="up">
#            +3,005
#            <span>
#             억
#            </span>
#           </span>
#          </dd>
#          <dd class="dd">
#           기관
#           <br/>
#           <span class="dn">
#            -3,551
#            <span>
#             억
#            </span>
#           </span>
#          </dd>
#          <dt class="last">
#           <span class="blind">
#            프로그램 매매동향
#           </span>
#          </dt>
#          <dd class="dd">
#           차익
#           <br/>
#           <span class="dn">
#            -449
#            <span>
#             억
#            </span>
#           </span>
#          </dd>
#          <dd class="dd">
#           비차익
#           <br/>
#           <span class="up">
#            +1,467
#            <span>
#             억
#            </span>
#           </span>
#          </dd>
#          <dd class="dd">
#           전체
#           <br/>
#           <span class="up">
#            +1,018
#            <span>
#             억
#            </span>
#           </span>
#          </dd>
#         </dl>
#        </div>
#       </div>
#       <div class="box_type_m">
#        <h4 class="top_tlt">
#         <em>
#          시황
#         </em>
#         뉴스
#         <span class="tlt_more" style="top:5px;">
#          <a href="/news/mainnews.naver">
#           주요뉴스 더보기
#          </a>
#         </span>
#        </h4>
#        <ul class="sise_report">
#         <li>
#          <span class="tit">
#           <a href="/news/news_read.naver?article_id=0004839185&amp;office_id=015&amp;mode=LSS3D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=401&amp;page=1">
#            코스피, 5월 FOMC에 주목…"인상폭보다 메시지에 집중해야"[주간전..
#           </a>
#          </span>
#          <p class="info">
#           <span class="paper">
#            한국경제
#           </span>
#           <span class="date">
#            2023-04-30 08:02
#           </span>
#          </p>
#         </li>
#         <li>
#          <span class="tit">
#           <a href="/news/news_read.naver?article_id=0004184759&amp;office_id=011&amp;mode=LSS3D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=401&amp;page=1">
#            외국인, 이달 삼성전자 2.8조 폭풍매수…코스피 2500선 회복
#           </a>
#          </span>
#          <p class="info">
#           <span class="paper">
#            서울경제
#           </span>
#           <span class="date">
#            2023-04-28 18:03
#           </span>
#          </p>
#         </li>
#         <li>
#          <span class="tit">
#           <a href="/news/news_read.naver?article_id=0005474987&amp;office_id=018&amp;mode=LSS3D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=401&amp;page=1">
#            [표]코스피 기관/외국인 매매동향(4/28 3시30분)
#           </a>
#          </span>
#          <p class="info">
#           <span class="paper">
#            이데일리
#           </span>
#           <span class="date">
#            2023-04-28 17:07
#           </span>
#          </p>
#         </li>
#         <li>
#          <span class="tit">
#           <a href="/news/news_read.naver?article_id=0005252484&amp;office_id=277&amp;mode=LSS3D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=401&amp;page=1">
#            코스피, 2500선에서 턱걸이 마감…주가조작의혹 종목들도 일제히 상..
#           </a>
#          </span>
#          <p class="info">
#           <span class="paper">
#            아시아경제
#           </span>
#           <span class="date">
#            2023-04-28 16:17
#           </span>
#          </p>
#         </li>
#         <li>
#          <span class="tit">
#           <a href="/news/news_read.naver?article_id=0013910927&amp;office_id=001&amp;mode=LSS3D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=401&amp;page=1">
#            코스피, 강보합세로 2,500선 턱걸이…2차전지·자동차 약세(종합)
#           </a>
#          </span>
#          <p class="info">
#           <span class="paper">
#            연합뉴스
#           </span>
#           <span class="date">
#            2023-04-28 16:03
#           </span>
#          </p>
#         </li>
#        </ul>
#       </div>
#       <div class="box_type_m">
#        <h4 class="top_tlt">
#         <em>
#          시황정보
#         </em>
#         리포트
#         <span class="tlt_more" style="top:5px;">
#          <a href="/research/market_info_list.naver">
#           더보기
#          </a>
#         </span>
#        </h4>
#        <ul class="sise_report">
#         <li>
#          <span class="tit">
#           <a href="/research/market_info_read.naver?nid=25072&amp;page=1">
#            지수가 반등하면 섹터는 어느 쪽?
#           </a>
#          </span>
#          <p class="info2">
#           <span class="paper">
#            하이투자증권
#           </span>
#           <span class="date">
#            2023-04-28
#           </span>
#          </p>
#         </li>
#         <li>
#          <span class="tit">
#           <a href="/research/market_info_read.naver?nid=25071&amp;page=1">
#            Global Daily (4월 28일)
#           </a>
#          </span>
#          <p class="info2">
#           <span class="paper">
#            신한투자증권
#           </span>
#           <span class="date">
#            2023-04-28
#           </span>
#          </p>
#         </li>
#         <li>
#          <span class="tit">
#           <a href="/research/market_info_read.naver?nid=25070&amp;page=1">
#            Finance Weekly
#           </a>
#          </span>
#          <p class="info2">
#           <span class="paper">
#            대신증권
#           </span>
#           <span class="date">
#            2023-04-28
#           </span>
#          </p>
#         </li>
#         <li>
#          <span class="tit">
#           <a href="/research/market_info_read.naver?nid=25069&amp;page=1">
#            Daily Morning Brief(2023.04.28)
#           </a>
#          </span>
#          <p class="info2">
#           <span class="paper">
#            다올투자증권
#           </span>
#           <span class="date">
#            2023-04-28
#           </span>
#          </p>
#         </li>
#         <li>
#          <span class="tit">
#           <a href="/research/market_info_read.naver?nid=25068&amp;page=1">
#            연이은 기업 실적 호조세 속 뉴욕증시 상승마감
#           </a>
#          </span>
#          <p class="info2">
#           <span class="paper">
#            하이투자증권
#           </span>
#           <span class="date">
#            2023-04-28
#           </span>
#          </p>
#         </li>
#        </ul>
#       </div>
#       <iframe bottommargin="0" frameborder="0" height="265" marginheight="0" name="time" scrolling="no" src="/sise/sise_index_time.naver?code=KOSPI&amp;thistime=20230428185900" title="시간별시세 영역" topmargin="0" width="100%">
#       </iframe>
#       <iframe bottommargin="0" frameborder="0" height="265" marginheight="0" name="day" scrolling="no" src="/sise/sise_index_day.naver?code=KOSPI" title="일별시세 영역" topmargin="0" width="100%">
#       </iframe>
#       <div class="c">
#       </div>
#       <!-- relative 추가 -->
#       <div class="wrap_chart_index">
#        <div class="cont_err cont_err_chart">
#         <p class="dsc_err">
#          현재 브라우저에서 차트를 지원하지 않습니다.
#         </p>
#         <p class="dsc_err2">
#          Internet Explorer 11 이상 사용시 차트 이용이 가능합니다.
#         </p>
#        </div>
#        <div class="alarm_layer_dimmed" style="display: none;">
#         <div class="alarm_layer">
#          <div class="inner_alarm">
#           <strong class="tit_alarm">
#            최대입력값을 초과했습니다.
#           </strong>
#           <p class="txt_alarm">
#            최대 150까지 입력할 수 있습니다.
#           </p>
#           <button class="btn_alarm" type="button">
#            확인
#           </button>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <!-- //컨텐츠 -->
#      <!--  right area -->
#      <div id="contentarea_right">
#       <script language="javascript">
#        function naver_login()
# 	{
# 		location.replace ('https://nid.naver.com/nidlogin.login?mode=form&url='+location.href);
# 	}
#       </script>
#       <iframe bottommargin="0" frameborder="0" height="305" marginheight="0" name="recent" scrolling="no" src="/template/right_item.naver?code=KOSPI&amp;width=200" title="최근조회 영역" topmargin="0" width="200">
#       </iframe>
#       <!-- 인기검색어 -->
#       <div class="box_type_r">
#        <div class="box_type_r_top">
#         <h2 class="r_subtlt tlt_bottom_line">
#          <img alt="인기검색어" height="11" src="https://ssl.pstatic.net/imgstock/images5/rtlt_best_keyword.gif" width="51"/>
#          <span class="tlt_more">
#           <a href="/sise/lastsearch2.naver" onclick="clickcr(this, 'rpk.keyword', '', '', event);">
#            더보기
#           </a>
#          </span>
#         </h2>
#         <table cellpadding="0" cellspacing="0" class="type_r1" summary="인기검색어 리스트">
#          <caption>
#           인기검색어
#          </caption>
#          <col width="11%"/>
#          <col width="*"/>
#          <col width="30%"/>
#          <col width="13%"/>
#          <tr>
#           <td align="right" class="tr">
#            <img alt="01" height="11" src="https://ssl.pstatic.net/imgstock/images5/ico_n01.gif" width="11"/>
#           </td>
#           <td>
#            <a class="company" href="/item/main.naver?code=004690" onclick="clickcr(this, 'rpk.list', '004690', '1', event);">
#             삼천리
#            </a>
#           </td>
#           <td class="number">
#            153,000
#           </td>
#           <td class="tc">
#            <img alt="up" class="updown" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" width="7"/>
#           </td>
#          </tr>
#          <tr>
#           <td align="right" class="tr">
#            <img alt="01" height="11" src="https://ssl.pstatic.net/imgstock/images5/ico_n02.gif" width="11"/>
#           </td>
#           <td>
#            <a class="company" href="/item/main.naver?code=032190" onclick="clickcr(this, 'rpk.list', '032190', '2', event);">
#             다우데이타
#            </a>
#           </td>
#           <td class="number">
#            17,370
#           </td>
#           <td class="tc">
#            <img alt="up" class="updown" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" width="7"/>
#           </td>
#          </tr>
#          <tr>
#           <td align="right" class="tr">
#            <img alt="01" height="11" src="https://ssl.pstatic.net/imgstock/images5/ico_n03.gif" width="11"/>
#           </td>
#           <td>
#            <a class="company" href="/item/main.naver?code=004360" onclick="clickcr(this, 'rpk.list', '004360', '3', event);">
#             세방
#            </a>
#           </td>
#           <td class="number">
#            18,060
#           </td>
#           <td class="tc">
#            <img alt="up" class="updown" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" width="7"/>
#           </td>
#          </tr>
#          <tr>
#           <td align="right" class="tr">
#            <img alt="01" height="11" src="https://ssl.pstatic.net/imgstock/images5/ico_n04.gif" width="11"/>
#           </td>
#           <td>
#            <a class="company" href="/item/main.naver?code=017390" onclick="clickcr(this, 'rpk.list', '017390', '4', event);">
#             서울가스
#            </a>
#           </td>
#           <td class="number">
#            127,900
#           </td>
#           <td class="tc">
#            <img alt="up" class="updown" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" width="7"/>
#           </td>
#          </tr>
#          <tr>
#           <td align="right" class="tr">
#            <img alt="01" height="11" src="https://ssl.pstatic.net/imgstock/images5/ico_n05.gif" width="11"/>
#           </td>
#           <td>
#            <a class="company" href="/item/main.naver?code=086520" onclick="clickcr(this, 'rpk.list', '086520', '5', event);">
#             에코프로
#            </a>
#           </td>
#           <td class="number">
#            730,000
#           </td>
#           <td class="tc">
#            <img alt="up" class="updown" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" width="7"/>
#           </td>
#          </tr>
#         </table>
#        </div>
#       </div>
#       <!-- //인기검색어 -->
#       <!-- 가장 많이 본 뉴스 -->
#       <div class="box_type_r">
#        <div class="box_type_r_top">
#         <h2 class="r_subtlt tlt_bottom_line">
#          <img alt="가장 많이 본 뉴스" height="11" src="https://ssl.pstatic.net/imgstock/images5/rtlt_best_news.gif" width="86"/>
#          <span class="tlt_more">
#           <a href="/news/news_list.naver?mode=RANK" onclick="clickcr(this, 'rnw.more', '', '', event)">
#            더보기
#           </a>
#          </span>
#         </h2>
#         <ul class="right_list_1_2">
#          <li>
#           <a href="/news/news_read.naver?article_id=0013904003&amp;office_id=001&amp;mode=RANK" onclick="clickcr(this, 'rnw.list', '0013904003', '1', event)" title="SG증권발 무더기 급락 부른 'CFD 거래' 뭐길래…&quot;공매도 효과&quot;">
#            SG증권발 무더기 급락 부른 'CFD 거래' 뭐길래…"공매도 효과"
#           </a>
#          </li>
#          <li>
#           <a href="/news/news_read.naver?article_id=0005121880&amp;office_id=009&amp;mode=RANK" onclick="clickcr(this, 'rnw.list', '0005121880', '2', event)" title="“1년치 상승분 다 사라졌다”...CFD 매물폭탄 가스주 사흘 연속  하한가">
#            “1년치 상승분 다 사라졌다”...CFD 매물폭탄 가스주 사흘 연속  하한가
#           </a>
#          </li>
#          <li>
#           <a href="/news/news_read.naver?article_id=0005250623&amp;office_id=277&amp;mode=RANK" onclick="clickcr(this, 'rnw.list', '0005250623', '3', event)" title="이차전지 쉬고 모터株 달려…개미, 희토류 무기화에 대비">
#            이차전지 쉬고 모터株 달려…개미, 희토류 무기화에 대비
#           </a>
#          </li>
#          <li>
#           <a href="/news/news_read.naver?article_id=0013902937&amp;office_id=001&amp;mode=RANK" onclick="clickcr(this, 'rnw.list', '0013902937', '4', event)" title="신용잔고율 10% 이상 종목, 올들어 곱절…곳곳 '빚투' 경고음">
#            신용잔고율 10% 이상 종목, 올들어 곱절…곳곳 '빚투' 경고음
#           </a>
#          </li>
#          <li>
#           <a href="/news/news_read.naver?article_id=0004879853&amp;office_id=008&amp;mode=RANK" onclick="clickcr(this, 'rnw.list', '0004879853', '5', event)" title="[Asia오전] 미국발 악재에 홍콩 제외 모두 하락…닛케이 0.53%↓">
#            [Asia오전] 미국발 악재에 홍콩 제외 모두 하락…닛케이 0.53%↓
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <!-- //가장 많이 본 뉴스 -->
#      </div>
#      <!--  right area -->
#      <div class="c">
#      </div>
#     </div>
#    </div>
#    <script type="text/javascript">
#     var pollingInterval = 2000;
# var pollingAjax = null;
# var timer = null;
#
# function changeNumberFormat(vNumber){
# 	var sUnderNumber = "";
# 	var sNumberString = vNumber || 0;
# 	sNumberString = (typeof sNumberString != "String") ? String(sNumberString) : sNumberString;
#
# 	if(sNumberString.indexOf(".") > -1){
# 		var aNumber = sNumberString.split(".");
# 		sNumberString = aNumber[0];
# 		sUnderNumber = "." + aNumber[1];
# 	}
#
# 	return sNumberString.replace(/(\d)(?=(\d{3})+$)/igm, "$1,") + sUnderNumber;
# }
#
# var startTimer = function() {
# 	clearTimer();
# 	timer = setInterval('doPolling()', pollingInterval);
# }
#
# var clearTimer = function() {
# 	if (pollingAjax) {
# 		pollingAjax.abort();
# 		pollingAjax = null;
# 	}
#
# 	timer = window.clearInterval(timer);
# }
#
# var doPolling = function() {
# 	clearTimer();
#
# 	var pollingApiUrl = 'https://polling.finance.naver.com/api/realtime?query=SERVICE_INDEX:KOSPI';
# 	pollingAjax = jindo.$Ajax(pollingApiUrl, {
# 		type : 'jsonp',
# 		jsonp_charset : "euc-kr",
# 		onload : function(response) {
# 			if(response != null && response.readyState() == 4) {
# 				refreshQuote(response.json());
# 				startTimer();
# 			}
# 		},
# 		timeout : 2,
# 		ontimeout : function() {
# 			startTimer();
# 		},
# 		async : true
# 	});
#
# 	pollingAjax.request();
# }
#
# function changeFontColor(changeValue, nowValue) {
# 	var result = "";
#
# 	if (changeValue > 0) {
# 		result = '<strong class="red01"';
# 	} else if (changeValue < 0) {
# 		result = '<strong class="nv01"';
# 	} else {
# 		result = '<strong';
# 	}
#
# 	result += '>' + changeNumberFormat(nowValue.toFixed(2)) + '</strong>';
#
# 	return result;
# }
#
# function changeVal(changeValue) {
# 	var result = "";
#
# 	if (changeValue > 0) {
# 		result = '<img src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" width="7" height="6" style="margin-right:4px;"><span class="tah p11 red02">' + changeNumberFormat(changeValue.toFixed(2)) + '</span>'
# 	} else if (changeValue < 0) {
# 		result = '<img src="https://ssl.pstatic.net/imgstock/images/images4/ico_down.gif" width="7" height="6" style="margin-right:4px;"><span class="tah p11 nv01">' + changeNumberFormat((changeValue * -1).toFixed(2)) + '</span>'
# 	} else {
# 		result = '<span class="tah p11 gray01">0</span>';
# 	}
#
# 	return result;
# }
#
# function changeRate(changeValue, changeRate) {
# 	var result = "";
#
# 	if (changeRate > 0) {
# 		result = '<strong class="tah red01">+' + changeNumberFormat(changeRate.toFixed(2)) + '%</strong>';
# 	} else if (changeRate < 0) {
# 		result = '<strong class="tah nv01">' + changeNumberFormat(changeRate.toFixed(2)) + '%</strong>';
# 	} else {
# 		if (changeValue > 0) {
# 			result = '<strong class="tah red01">+' + changeNumberFormat(changeRate.toFixed(2)) + '%</strong>';
# 		} else if (changeValue < 0) {
# 			result = '<strong class="tah nv01">' + changeNumberFormat(changeRate.toFixed(2)) + '%</strong>';
# 		} else {
# 			result = '<strong class="tah gray01">0.00%</strong>';
# 		}
# 	}
#
# 	return result;
# }
#
# function changeValAndRate(changeValue, changeRate) {
# 	var result = "";
#
# 	if (changeValue > 0) {
# 		result = '<span>' + changeNumberFormat(changeValue.toFixed(2)) + '</span>'
# 	} else if (changeValue < 0 ) {
# 		result = '<span>' + changeNumberFormat((changeValue * -1).toFixed(2)) + '</span>'
# 	} else {
# 		result = '<span>0.00</span>'
# 	}
#
# 	result += " ";
#
# 	if (changeRate > 0) {
# 		result += "+" + changeNumberFormat(changeRate.toFixed(2)) + '%<span class="blind>상승</span>"';
# 	} else if (changeRate < 0) {
# 		result += changeNumberFormat(changeRate.toFixed(2)) + '%<span class="blind>하락</span>"';
# 	} else {
# 		result += changeNumberFormat(changeRate.toFixed(2)) + '%<span class="blind>보합</span>"';
# 	}
#
# 	return result;
#
# }
#
# function displayTime(ms, aq, time) {
# 	var result;
#
# 	var utcDate = new Date(time);
# 	utcDate.setMinutes(utcDate.getMinutes() + utcDate.getTimezoneOffset());
# 	utcDate.setHours(utcDate.getHours() + 9);
#
# 	var oDate = jindo.$Date(utcDate);
#
# 	if (ms == "PREOPEN") {
# 		if (aq == "0") {
# 			closeDate = oDate.format('Y.m.d');
# 			result = oDate.format('Y.m.d') + "<span>개장전</span>";
# 		} else {
# 			closeDate = oDate.format('Y.m.d');
# 			result = oDate.format('Y.m.d') + "<span class='sub'>개장전</span> <span class='sub2'>예상지수</span>";
# 		}
# 	} else if (ms == "CLOSE") {
# 		result = closeDate + " 장마감";
# 	} else {
# 		closeDate = oDate.format('Y.m.d');
# 		result = oDate.format('Y.m.d H:i') + " 장중";
# 	}
#
# 	return result;
# }
#
# function refreshQuote(res) {
# 	if (res != null && res.resultCode == 'success') {
# 		pollingInterval = res.result.pollingInterval;
#
# 		for (index = 0 ; index < res.result.areas.length ; index++) {
# 			if (res.result.areas[index].name == "SERVICE_INDEX") {
# 				var ms = "NOT DEFINED";
# 				ms = res.result.areas[index].datas[0].ms;
# 				aq = res.result.areas[index].datas[0].aq;
# 				document.getElementById("time").innerHTML = displayTime(ms, aq, res.result.time);
#
# 				var itemData = res.result.areas[index].datas[0];
#
# 				var now_value = itemData.nv / 100;
# 				var change_value = itemData.cv / 100;
# 				var change_rate = itemData.cr;
#
# 				// 지수 , 전일대비, 등락률 상위 div 클래스 속성(up, dn) 변경
# 				var divEl = jindo.$Element(jindo.$$.getSingle("#quotient"));
#
# 				if (change_value > 0) {
# 					divEl.removeClass("dn");
# 					divEl.addClass("up");
# 				} else if (change_value < 0) {
# 					divEl.removeClass("up");
# 					divEl.addClass("dn");
# 				}
#
# 				// 장중최고
# 				var high_val = itemData.hv / 100;
# 				// 장중최저
# 				var low_val = itemData.lv / 100;
# 				// 거래량
# 				var quant = itemData.aq;
# 				// 거래대금
# 				var amount = itemData.aa;
#
# 				// 예상지수인 경우 0으로 초기화한다. 예상지수로는 산출할 수 없는 수치입니다. (서비스팀 스펙 협의 내용)
# 				if (ms == 'PREOPEN') {
# 					high_val = 0;
# 					low_val = 0;
# 					quant = 0;
# 					amount = 0;
# 				}
#
# 				// 지수
# 				document.getElementById('now_value').innerHTML = changeNumberFormat(now_value.toFixed(2));
# 				// 전일대비, 등락률
# 				document.getElementById('change_value_and_rate').innerHTML = changeValAndRate(change_value, change_rate);
#
# 				document.getElementById('high_value').innerHTML = changeNumberFormat(high_val.toFixed(2));
# 				document.getElementById('low_value').innerHTML = changeNumberFormat(low_val.toFixed(2));
# 				document.getElementById('quant').innerHTML = changeNumberFormat(quant.toFixed(0));
# 				document.getElementById('amount').innerHTML = changeNumberFormat(amount.toFixed(0));
# 			}
# 		}
# 	}
# }
# var dateTime = "20230428185900";
# var closeDate = dateTime.substring(0,4) + "." + dateTime.substring(4,6) + "." + dateTime.substring(6,8);
#
# if (true) {
# 	jindo.$Fn(doPolling).attach(document, "domready");
# }
#    </script>
#    <div id="footer">
#     <ul>
#      <li class="first">
#       <a href="https://new-m.pay.naver.com/member/terms-policy/naver-financial-service" onclick="clickcr(this, 'fot.service', '', '', event);" target="_blank">
#        이용약관
#       </a>
#      </li>
#      <li>
#       <a href="https://new-m.pay.naver.com/member/terms-policy/privacy" onclick="clickcr(this, 'fot.privacy', '', '', event);" target="_blank">
#        <strong>
#         개인정보처리방침
#        </strong>
#       </a>
#      </li>
#      <li>
#       <a href="/rules.naver" onclick="clickcr(this, 'fot.policy', '', '', event);" target="_blank">
#        게시판 운영원칙
#       </a>
#      </li>
#      <li>
#       <a href="https://help.naver.com/service/5617/category/bookmark?lang=ko" onclick="clickcr(this, 'fot.help', '', '', event);" target="_blank">
#        증권 고객센터
#       </a>
#      </li>
#     </ul>
#     <p class="desc">
#      네이버파이낸셜(주)이 제공하는 금융 정보는
#      <a class="desc_help" href="javascript:;" onclick="togglePanelFooter('footerPanel0');">
#       콘텐츠 제공업체
#      </a>
#      로부터 받는 투자 참고사항이며, 오류가 발생하거나 지연될 수 있습니다.
#      <br>
#       네이버파이낸셜(주)과 콘텐츠 제공업체는 제공된 정보에 의한 투자 결과에 법적인 책임을 지지 않습니다. 게시된 정보는 무단으로 배포할 수 없습니다.
#      </br>
#     </p>
#     <address>
#      <a class="logo" href="https://www.naverfincorp.com/" onclick="clickcr(this, 'fot.nhn', '', '', event);" target="_blank">
#       <img alt="NAVER FINANCIAL" height="12" src="https://ssl.pstatic.net/static/nfinance/img/logo_financial.png" width="160"/>
#      </a>
#     </address>
#     <div class="provider_layer" id="footerPanel0" onblur="hidePannel('footerPanel0')" style="display:none" tabindex="0">
#      <strong class="provider_layer__tit">
#       네이버파이낸셜에 콘텐츠 제공
#      </strong>
#      <div class="provider_layer__txt">
#       <strong>
#        에프앤가이드
#       </strong>
#       기업 및 재무정보
#       <br/>
#       <strong>
#        KG제로인
#       </strong>
#       해외 시세, 시장지표 정보
#       <br/>
#       <strong>
#        한국예탁결제원
#       </strong>
#       주주총회일, 전자투표 정보
#       <br/>
#       <strong>
#        인포스탁
#       </strong>
#       국내 테마 정보
#      </div>
#      <div class="provider_layer__info">
#       <strong class="provider_layer__tit">
#        네이버에 콘텐츠 제공
#       </strong>
#       <div class="provider_layer__txt">
#        <strong>
#         코스콤
#        </strong>
#        국내 시세 정보
#       </div>
#      </div>
#      <button class="button_close" onclick="hidePannel('footerPanel0')" type="button">
#       <img alt="닫기" height="20" src="https://ssl.pstatic.net/static/nfinance/2022/footer_close.png" width="20"/>
#      </button>
#     </div>
#    </div>
#    <script type="text/javascript">
#     function isVisible(obj) {
#     if (obj == document) return true
#
#     if (!obj) return false
#     if (!obj.parentNode) return false
#     if (obj.style) {
#         if (obj.style.display == 'none') return false
#         if (obj.style.visibility == 'hidden') return false
#     }
#
#     if (window.getComputedStyle) {
#         var style = window.getComputedStyle(obj, "")
#         if (style.display == 'none') return false
#         if (style.visibility == 'hidden') return false
#     }
#
#     var style = obj.currentStyle
#     if (style) {
#         if (style['display'] == 'none') return false
#         if (style['visibility'] == 'hidden') return false
#     }
#
#     return isVisible(obj.parentNode)
# }
#
# function isChildOf(myobj, containerObj) {
# 	while(myobj != undefined) {
# 		if (myobj == document.body) {
# 			break;
# 		}
# 		if (myobj == containerObj) {
# 			return true;
# 		}
# 		myobj = myobj.parentElement;
# 	}
# 	return false;
# }
#
# function gnbLayerClose(e){
# 	var target = e.target ? e.target : e.srcElement;
# 	if (isVisible(document.getElementById('gnb_service_lyr')) || isVisible(document.getElementById('gnb_notice_lyr')) ||isVisible(document.getElementById('gnb_my_lyr')) ) {
# 		if (!isChildOf(target, document.getElementById('gnb'))) {
# 			gnbAllLayerClose();
# 		}
# 	}
# }
#
# var isIE = (navigator.userAgent.toLowerCase().indexOf("msie")!=-1 && window.document.all) ? true:false;
# if (isIE) {
# 	document.attachEvent('onmousedown', gnbLayerClose);
# } else {
# 	window.addEventListener('mousedown', gnbLayerClose);
# }
#
# function showPannel(layerId){
#     var layer = jindo.$(layerId);
#     layer.style.display='block';
#
#     if (layerId == "summary_lyr") {
#         var layerHeight = jindo.$Element(layer).height();
#         jindo.$Element("summary_ifr").height(layerHeight);
#     }
# }
#
# function hidePannel(layerId){
#     var layer = jindo.$(layerId);
#     layer.style.display='none';
# }
#
# function togglePanelFooter(layerId) {
#     var elTargetLayer = jindo.$Element(jindo.$$.getSingle("#" + layerId));
#
#     if (elTargetLayer != null) {
#         if (elTargetLayer.visible()) {
#             hidePannel(layerId);
#         } else {
#             showPannel(layerId);
#         }
#     }
# }
#
# // add data-useragent
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
#    </script>
#   </div>
#  </body>
# </html>

# %%
# #now_value
soup.select_one('#now_value').string
# Out:
# '2,501.53'

# %%
import requests
from bs4 import BeautifulSoup
req = requests.get('https://naver.com')
html = req.text
soup = BeautifulSoup(html, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-dark="false" lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    NAVER
#   </title>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=1190" name="viewport"/>
#   <meta content="NAVER" name="apple-mobile-web-app-title">
#    <meta content="index,nofollow" name="robots">
#     <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description">
#      <meta content="네이버" property="og:title"/>
#      <meta content="https://www.naver.com/" property="og:url"/>
#      <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/>
#      <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description">
#       <meta content="summary" name="twitter:card"/>
#       <meta content="" name="twitter:title"/>
#       <meta content="https://www.naver.com/" name="twitter:url"/>
#       <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" name="twitter:image"/>
#       <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="twitter:description">
#        <link href="https://pm.pstatic.net/dist/css/nmain.20230302.css" rel="stylesheet"/>
#        <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_220526.css" rel="stylesheet"/>
#        <link href="/favicon.ico?1" rel="shortcut icon" type="image/x-icon">
#         <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png" rel="apple-touch-icon" sizes="114x114">
#          <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png" rel="apple-touch-icon"/>
#          <script>
#           window.nmain=window.nmain||{},window.nmain.supportFlicking=!1;var nsc="navertop.v4",ua=navigator.userAgent,useIeJSFlag="1";window.nmain.isIE="0"===useIeJSFlag,document.getElementsByTagName("html")[0].setAttribute("data-useragent",ua),window.nmain.isIE&&(Object.create=function(n){function e(){}return e.prototype=n,new e})
#          </script>
#          <script>
#           var darkmode= false;window.naver_corp_da=window.naver_corp_da||{main:{}},window.naver_corp_da.main=window.naver_corp_da.main||{},window.naver_corp_da.main.darkmode=darkmode,window.gladsdk=window.gladsdk||{cmd:[]},window.gladsdk.cmd.push((function(){window.gladsdk.setHostMeta("theme",darkmode?"dark":"light")})),window.ndpsdk=window.ndpsdk||{cmd:[],polyfill:{cmd:[]}},window.ndpsdk.cmd.push((function(){window.ndpsdk.setHostMeta("theme",darkmode?"dark":"light")}))
#          </script>
#          <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js">
#          </script>
#          <script async="" src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js">
#          </script>
#          <script>
#           window.nmain.gv = {  isLogin: false,
# useId: null,   daInfo: {"BEAUTY":{"menu":"BEAUTY","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000163","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_1","tb":"BEAUTY_1","unit":"SU10595","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000164","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_2","tb":"BEAUTY_1","unit":"SU10596","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVING":{"menu":"LIVING","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000183","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_1","tb":"LIVING_1","unit":"SU10597","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000184","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_2","tb":"LIVING_1","unit":"SU10606","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVINGHOME":{"menu":"LIVINGHOME","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000185","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_livinghome_1","tb":"LIVINGHOME_1","unit":"SU10571","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000186","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_livinghome_2","tb":"LIVINGHOME_1","unit":"SU10572","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]}},
# svt: 20230430211634,
# };
#          </script>
#          <script>
#           window.nmain.newsstand = {
# rcode: '09440127',
# newsCastSubsInfo: '',
# newsStandSubsInfo: ''
# };
# window.etc = {  };
# window.svr = "<!--cweb12-->";
#          </script>
#          <script defer="defer" src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js">
#          </script>
#          <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/external.2961eaa5.js?o=www" type="text/javascript">
#          </script>
#          <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/preload.5fe99fda.js?o=www" type="text/javascript">
#          </script>
#          <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/polyfill.f3c68d2d.js?o=www" type="text/javascript">
#          </script>
#          <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/vendors~more~nmain~notice~search~sidebar_notice.40da85e0.js?o=www" type="text/javascript">
#          </script>
#          <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/search.c0c3b1c5.js?o=www" type="text/javascript">
#          </script>
#          <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/vendors~more~nmain~sidebar_notice.7aad5e27.js?o=www" type="text/javascript">
#          </script>
#          <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/nmain.e31af4db.js?o=www" type="text/javascript">
#          </script>
#          <style>
#           :root{color-scheme:light}#_nx_kbd .setkorhelp a{display:none}
#          </style>
#         </link>
#        </link>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body>
#   <div id="u_skip">
#    <a href="#newsstand">
#     <span>
#      뉴스스탠드 바로가기
#     </span>
#    </a>
#    <a href="#themecast">
#     <span>
#      주제별캐스트 바로가기
#     </span>
#    </a>
#    <a href="#timesquare">
#     <span>
#      타임스퀘어 바로가기
#     </span>
#    </a>
#    <a href="#shopcast">
#     <span>
#      쇼핑캐스트 바로가기
#     </span>
#    </a>
#    <a href="#account">
#     <span>
#      로그인 바로가기
#     </span>
#    </a>
#   </div>
#   <div id="wrap">
#    <style>
#     ._1syGnXOL{padding-right:18px;font-size:14px;line-height:0;letter-spacing:-.25px;color:#000}._1syGnXOL span,._1syGnXOL strong{line-height:49px}._1syGnXOL:before{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20220527@2x.png);background-repeat:no-repeat;background-size:141px 112px;width:18px;height:18px;margin:16px 8px 0 0;background-position:-98px 0}[data-useragent*="MSIE 8"] ._1syGnXOL:before{background-image:url(https://static-whale.pstatic.net/main/sprite-20220527.png)}._1syGnXOL._3dsvmZg2:before{background-position:-47px -85px}._1syGnXOL._1NBFx1WK:before{width:20px;height:20px;margin:15px 8px 0 0;background-position:-21px -89px}._1syGnXOL._2mcQEKCd:before{width:22px;height:22px;margin:14px 7px 0 0;background-position:-47px -63px}._1syGnXOL._36slsKuJ:before{width:21px;height:49px;margin:0 14px 0 0;background-position:0 -63px}._1syGnXOL._3qlJVWzR:before{width:24px;height:49px;margin:0 10px 0 0;background-position:-117px 0}._1syGnXOL._3VkgqBXB:before{width:26px;height:49px;margin:0 10px 0 0;background-position:-116px -54px}._1syGnXOL._3di88A4c{padding-right:12px;font-size:17px}._1syGnXOL._3di88A4c:before{content:none}._1syGnXOL ._19K4X1CD{text-decoration:underline}._2aeXMlrb{display:inline-block;position:relative;font-size:12px;height:49px;width:78px;text-decoration:none;color:#fff;font-weight:700;letter-spacing:-.5px;vertical-align:top}._2aeXMlrb span{text-align:center;margin:9px 0;height:31px;display:block;line-height:31px;border-radius:15px}._2aeXMlrb span:before{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20220527@2x.png);background-repeat:no-repeat;background-size:141px 112px}[data-useragent*="MSIE 8"] ._2aeXMlrb span:before{background-image:url(https://static-whale.pstatic.net/main/sprite-20220527.png)}._2aeXMlrb.BMgpjddw{font-size:11px;width:94px}._2aeXMlrb.BMgpjddw span:before{margin:9px 3px 0 0;width:17px;height:13px;background-position:-89px -63px}._3h-N8T9V{position:absolute;top:0;left:0;right:0;bottom:0;background:rgba(0,0,0,0)}._1KncATpM{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20220527@2x.png);background-repeat:no-repeat;background-size:141px 112px;margin-top:14px;float:left;width:98px;height:21px;background-position:0 -21px}[data-useragent*="MSIE 8"] ._1KncATpM{background-image:url(https://static-whale.pstatic.net/main/sprite-20220527.png)}._1KncATpM._2v3uxv2x{background-position:0 0}._1KncATpM._1yl_Ow6o{background-position:0 -42px}._20PYt6lT{font-size:11px;height:49px;cursor:pointer;position:absolute;top:0;right:0;color:#666;opacity:.7}._20PYt6lT:after{width:15px;height:15px;margin-left:4px;background-position:-98px -33px;display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20220527@2x.png);background-repeat:no-repeat;background-size:141px 112px}[data-useragent*="MSIE 8"] ._20PYt6lT:after{background-image:url(https://static-whale.pstatic.net/main/sprite-20220527.png)}._20PYt6lT._39oMCV2N:after{background-position:-98px -18px}._20PYt6lT._3MOWOORv{color:#c3c2c2}._20PYt6lT._3MOWOORv:after{background-position:-80px -85px}._20PYt6lT._3wm5EzmJ{color:#fff}._20PYt6lT._3wm5EzmJ:after{background-position:-65px -85px}._1hiMWemA{height:49px}._1hiMWemA .tY_u8r23{position:relative;width:1130px;margin:0 auto}._1hiMWemA .tY_u8r23 a{text-decoration:none}._1hiMWemA._23U_6TM_{position:relative}._1hiMWemA._23U_6TM_:after{position:absolute;z-index:1;content:"";display:block;width:100%;height:1px;bottom:0;background-color:rgba(0,0,0,.050980392156862744)}
#    </style>
#    <div class="_1hiMWemA" data-clk-prefix="top" id="NM_TOP_BANNER" style="background-color: #fff7e1">
#     <div class="tY_u8r23">
#      <a class="_3h-N8T9V" data-clk="dropbanner1a" href="https://whale.naver.com/ko/details/security/&amp;wpid=RydDy7">
#      </a>
#      <span class="_1syGnXOL _3VkgqBXB" data-clk="dropbanner1a" style="padding-right: 20px; font-size: 17px; color: black">
#       <span>
#        매일 쓰는 브라우저 보안이 걱정된다면,
#       </span>
#       <strong>
#        안전하고 빠른 최신 브라우저 웨일로 업데이트 하세요.
#       </strong>
#      </span>
#      <a class="_2aeXMlrb BMgpjddw" data-clk="dropdownload1a" href="https://installer-whale.pstatic.net/downloads/banner/RydDy7/WhaleSetup.exe" id="NM_whale_download_btn">
#       <span style="background-color: #0436c7">
#        다운로드
#       </span>
#      </a>
#      <button class="_20PYt6lT _39oMCV2N" data-clk="dropclose1a" data-ui-cookie-exp-days="3" data-ui-cookie-key="NM_TOP_PROMOTION" data-ui-cookie-value="1" data-ui-hide-target="#NM_TOP_BANNER" type="button">
#       3일 동안 보지 않기
#      </button>
#     </div>
#    </div>
#    <div id="header" role="banner">
#     <div class="special_bg">
#      <div class="group_flex">
#       <div class="logo_area">
#        <h1 class="logo_default">
#         <a class="logo_naver" data-clk="top.logo" href="/">
#          <span class="blind">
#           네이버
#          </span>
#         </a>
#        </h1>
#       </div>
#       <div class="service_area">
#        <a class="link_set" data-clk="top.mkhome" href="https://help.naver.com/support/welcomePage/guide.help" id="NM_set_home_btn">
#         네이버를 시작페이지로
#        </a>
#        <i class="sa_bar">
#        </i>
#        <a class="link_jrnaver" data-clk="top.jrnaver" href="https://jr.naver.com">
#         <i class="ico_jrnaver">
#         </i>
#         <span class="blind">
#          쥬니어네이버
#         </span>
#        </a>
#        <a class="link_happybin" data-clk="top.happybean" href="https://happybean.naver.com">
#         <i class="ico_happybin">
#         </i>
#         <span class="blind">
#          해피빈
#         </span>
#        </a>
#       </div>
#       <div class="search_area" data-clk-prefix="sch" id="search">
#        <form action="https://search.naver.com/search.naver" id="sform" method="get" name="sform" role="search">
#         <fieldset>
#          <legend class="blind">
#           검색
#          </legend>
#          <input name="where" type="hidden" value="nexearch"/>
#          <input id="sm" name="sm" type="hidden" value="top_hty"/>
#          <input id="fbm" name="fbm" type="hidden" value="0"/>
#          <input disabled="disabled" id="acr" name="acr" type="hidden" value=""/>
#          <input disabled="disabled" id="acq" name="acq" type="hidden" value=""/>
#          <input disabled="disabled" id="qdt" name="qdt" type="hidden" value=""/>
#          <input id="ie" name="ie" type="hidden" value="utf8"/>
#          <input disabled="disabled" id="acir" name="acir" type="hidden" value=""/>
#          <input disabled="disabled" id="os" name="os" type="hidden" value=""/>
#          <input disabled="disabled" id="bid" name="bid" type="hidden" value=""/>
#          <input disabled="disabled" id="pkid" name="pkid" type="hidden" value=""/>
#          <input disabled="disabled" id="eid" name="eid" type="hidden" value=""/>
#          <input disabled="disabled" id="mra" name="mra" type="hidden" value=""/>
#          <div class="green_window" style="">
#           <!-- [AU] data-atcmp-element 에 해당하는 attribute를 추가해주세요. -->
#           <input accesskey="s" autocomplete="off" class="input_text" data-atcmp-element="" id="query" maxlength="255" name="query" onclick="document.getElementById('fbm').value=1;" placeholder="검색어를 입력해 주세요." style="ime-mode:active;" tabindex="1" title="검색어 입력" type="search" value=""/>
#          </div>
#          <button class="btn_submit" id="search_btn" onclick="window.nclick(this,'sch.action','','',event);" style="" tabindex="3" title="검색" type="submit">
#           <span class="blind">
#            검색
#           </span>
#           <span class="ico_search_submit">
#           </span>
#          </button>
#         </fieldset>
#        </form>
#        <!-- 한글입력기 -->
#        <a class="btn_keyboard" href="#" id="ke_kbd_btn" onclick="return false;" role="button">
#         <span class="blind">
#          한글 입력기
#         </span>
#         <span class="ico_keyboard">
#         </span>
#        </a>
#        <div id="_nx_kbd" style="display:none;">
#        </div>
#        <div class="autocomplete">
#         <!-- 자동완성 열린 경우 fold 클래스 추가, 딤드인 경우 dim 추가 -->
#         <a aria-pressed="false" class="btn_arw _btn_arw fold" data-atcmp-element="" href="#" id="nautocomplete" role="button" tabindex="2">
#          <span class="blind">
#           자동완성 레이어
#          </span>
#          <span class="ico_arr">
#          </span>
#         </a>
#        </div>
#        <!-- 자동완성레이어 -->
#        <div class="reatcmp" id="autoFrame" style="display: none;">
#         <!-- [AU] data-atcmp-element attribute를 추가해주세요. -->
#         <div class="ly_atcmp" data-atcmp-element="">
#          <div class="api_atcmp_wrap">
#           <!-- 최근검색어 -->
#           <!-- [AU] _recent_layer 클래스를 추가해주세요. -->
#           <div class="atcmp_fixer _recent_layer" style="display:none;">
#            <!-- [AU] _recent_header 클래스를 추가해주세요. -->
#            <div class="atcmp_header _recent_header">
#             <strong class="tit">
#              최근검색어
#             </strong>
#             <div class="option">
#              <!-- [AU] _delAll 클래스를 추가해주세요. -->
#              <a aria-pressed="false" class="item _delAll" href="#" role="button">
#               전체삭제
#              </a>
#             </div>
#            </div>
#            <div class="atcmp_container">
#             <!-- [AU] _recent 클래스를 추가해주세요. -->
#             <ul class="kwd_lst _recent">
#              <!-- 최근검색어 템플릿 -->
#              <!-- [AU] _item 클래스를 추가해주세요. -->
#              <!-- [AU] data-template-type="history" data-keyword="@in_txt@" attribute를 추가해주세요. -->
#              <li class="item _item" data-keyword="@in_txt@" data-rank="@rank@" data-template-type="history">
#               <a class="kwd" href="#">
#                <span class="fix">
#                 <span class="common_ico_kwd">
#                  <i class="imsc ico_search">
#                  </i>
#                 </span>
#                 <span>
#                  @txt@
#                 </span>
#                </span>
#               </a>
#               <span class="etc">
#                <em class="date">
#                 @date@.
#                </em>
#                <!-- [AU] _del 클래스를 추가해주세요. -->
#                <a aria-pressed="false" class="bt_item _del" href="#" role="button">
#                 <i class="imsc ico_del">
#                  삭제
#                 </i>
#                </a>
#               </span>
#              </li>
#             </ul>
#             <!-- [D] 검색어 저장 꺼진 경우 atcmp_fixer에 type_off 추가 -->
#             <!-- [AU] _offMsg 클래스를 추가해주세요. -->
#             <div class="kwd_info kwd_off _offMsg" style="display: none;">
#              검색어 저장 기능이 꺼져 있습니다.
#              <br/>
#              <span class="kwd_dsc">
#               설정이 초기화 된다면
#               <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/support/alias/search/word/word_29.naver" target="_blank">
#                도움말
#               </a>
#               을 확인해주세요.
#              </span>
#             </div>
#             <!-- [D] 검색어 내역 없는 경우 atcmp_fixer에 type_off 추가 -->
#             <!-- [AU] _recentNone 클래스를 추가해주세요. -->
#             <div class="kwd_info kwd_none _recentNone" style="display: none;">
#              최근 검색어 내역이 없습니다.
#              <br/>
#              <span class="kwd_dsc">
#               설정이 초기화 된다면
#               <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/support/alias/search/word/word_29.naver" target="_blank">
#                도움말
#               </a>
#               을 확인해주세요.
#              </span>
#             </div>
#            </div>
#            <div class="atcmp_footer">
#             <span class="side_opt_area">
#              <span class="opt_item">
#               <a data-clk="sly.help" href="https://help.naver.com/support/service/main.help?serviceNo=605&amp;categoryNo=1991" target="_blank">
#                도움말
#               </a>
#              </span>
#             </span>
#             <span class="rside_opt_area">
#              <span class="opt_item">
#               <!-- [AU] _keywordOnOff 클래스를 추가해주세요. -->
#               <a class="close _keywordOnOff" href="#">
#                자동저장 끄기
#               </a>
#              </span>
#             </span>
#            </div>
#           </div>
#           <!-- 자동완성 -->
#           <!-- [AU] _atcmp_layer 클래스를 추가해주세요. -->
#           <div class="atcmp_fixer _atcmp_layer" style="display:none;">
#            <!-- [AU] _words 클래스를 추가해주세요. -->
#            <div class="atcmp_container _words">
#             <!-- 정답형 템플릿 : 로또당첨번호 -->
#             <!-- [AU] _answer 클래스를 추가해주세요. -->
#             <!-- [AU] data-template-type="answer_3" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
#             <div class="atcmp_correct type_lotto _answer" data-code="@code@" data-keyword="@1@" data-template-type="answer_3">
#              <a class="link_item" href="#">
#               <span class="common_ico_kwd">
#                <i class="imsc ico_search">
#                </i>
#               </span>
#               <div class="dsc_area">
#                <span class="tit">
#                 @5@회 로또당첨번호
#                </span>
#                <span class="dsc">
#                 <span class="item">
#                  동행복권 제공
#                 </span>
#                </span>
#               </div>
#               <span class="etc_area">
#                <span class="etc lotto">
#                 <em class="n@6@">
#                  @6@
#                 </em>
#                 <em class="n@7@">
#                  @7@
#                 </em>
#                 <em class="n@8@">
#                  @8@
#                 </em>
#                 <em class="n@9@">
#                  @9@
#                 </em>
#                 <em class="n@10@">
#                  @10@
#                 </em>
#                 <em class="n@11@">
#                  @11@
#                 </em>
#                 <em class="imsc_bf bonus n@12@">
#                  @12@
#                 </em>
#                </span>
#               </span>
#              </a>
#             </div>
#             <!-- 정답형 템플릿 : 환율 -->
#             <!-- [AU] _answer 클래스를 추가해주세요. -->
#             <!-- [AU] data-template-type="answer_9" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
#             <div class="atcmp_correct type_exchange _answer" data-code="@code@" data-keyword="@1@" data-template-type="answer_9">
#              <!-- [D] 상승 up, 하락 down 추가 -->
#              <a class="link_item @11@" href="#">
#               <!-- [D] 국가별 class 가나다순
# ZAR 남아프리카 공화국
# NPR 네팔
# NOK 노르웨이
# NZD 뉴질랜드
# TWD 대만
# DKK 덴마크
# RUB 러시아
# MOP 마카오
# MYR 말레이시아
# MXN 멕시코
# MNT 몽골
# USD 미국
# BHD 바레인
# BDT 방글라데시
# VND 베트남
# BRL 브라질
# SAR 사우디아라비아
# SEK 스웨덴
# CHF 스위스
# SGD 싱가포르
# AED 아랍에미리트
# GBP 영국
# EUR 유럽연합
# ILS 이스라엘
# EGP 이집트
# INR 인도
# IDR 인도네시아
# JPY 일본
# CNY 중국
# CZK 체코
# CLP 칠레
# KZT 카자흐스탄
# QAR 카타르
# CAD 캐나다
# KWD 쿠웨이트
# THB 태국
# TRY 터키
# PKR 파키스탄
# PLN 폴란드
# PHP 필리핀
# HUF 헝가리
# AUD 호주
# HKD 홍콩
# -->
#               <span class="common_ico_kwd">
#                <i class="imsc ico @12@">
#                 @14@
#                </i>
#               </span>
#               <div class="dsc_area">
#                <span class="tit">
#                 @txt@
#                 <span class="sub">
#                  @currency@
#                 </span>
#                </span>
#                <span class="dsc">
#                 <span class="item">
#                  <i class="imsc ico_arr">
#                  </i>
#                  @8@(@9@%)
#                 </span>
#                </span>
#               </div>
#               <span class="etc_area">
#                <span class="etc">
#                 <em class="num">
#                  @6@
#                 </em>
#                 원
#                </span>
#               </span>
#              </a>
#             </div>
#             <!-- 정답형 템플릿 : 날씨(국내11, 해외12) -->
#             <!-- [AU] _answer 클래스를 추가해주세요. -->
#             <!-- [AU] data-template-type="answer_11" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
#             <div class="atcmp_correct type_weather _answer" data-code="@code@" data-keyword="@1@" data-template-type="answer_11">
#              <!-- [D] 상승 up, 하락 down 추가 -->
#              <a class="link_item @12@" href="#">
#               <span class="common_ico_kwd">
#                <i class="imsc ico_search">
#                </i>
#               </span>
#               <div class="dsc_area">
#                <span class="tit">
#                 @txt@
#                </span>
#                <span class="dsc">
#                 <span class="item">
#                  @7@, @message@
#                 </span>
#                </span>
#               </div>
#               <span class="etc_area">
#                <span class="etc">
#                 <!-- [D] 날씨별 class
# ico1 맑음(낮)
# ico2 맑음(밤)
# ico3 구름조금(낮)
# ico4 구름조금(밤)
# ico5 구름많음(낮)
# ico6 구름많음(밤)
# ico7 흐림
# ico8 약한비
# ico9 비
# ico10 강한비
# ico11 약한눈
# ico12 눈
# ico13 강한눈
# ico14 진눈깨비
# ico15 소나기
# ico16 안개
# ico17 소낙눈
# ico18 번개뇌우
# ico19 우박
# ico20 황사
# ico21 비또는눈
# ico22 가끔비
# ico23 가끔눈
# ico24 가끔비또는눈
# ico25 흐린후갬
# ico26 뇌우후갬
# ico27 비후갬
# ico28 눈후갬
# ico29 흐려져비
# ico30 흐려져눈
# -->
#                 <span class="ico_weather">
#                  <i class="imsc ico ico@iconNo@">
#                   @7@
#                  </i>
#                 </span>
#                 <em class="degree">
#                  @8@
#                  <sup class="celsius">
#                   °
#                  </sup>
#                 </em>
#                </span>
#               </span>
#              </a>
#             </div>
#             <!-- 정답형 템플릿 : 사이트 바로가기 -->
#             <!-- [AU] _answer 클래스를 추가해주세요. -->
#             <!-- [AU] data-template-type="answer_17" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
#             <div class="atcmp_correct type_site _answer" data-code="@code@" data-keyword="@1@" data-template-type="answer_17">
#              <a class="link_item" href="@5@" target="_blank">
#               <span class="common_ico_kwd">
#                <i class="imsc ico_url">
#                </i>
#               </span>
#               <div class="dsc_area">
#                <span class="tit">
#                 @txt@
#                </span>
#                <span class="dsc">
#                 <span class="item">
#                  @5@
#                 </span>
#                </span>
#               </div>
#               <span class="etc_area">
#                <span class="etc">
#                 바로가기
#                </span>
#               </span>
#              </a>
#             </div>
#             <!-- [AU] _kwd_list 클래스를 추가해주세요. -->
#             <ul class="kwd_lst _kwd_list">
#              <!-- [AU] 자동완성 검색어 템플릿 -->
#              <!-- [AU] _item 클래스를 추가해주세요. -->
#              <!-- [AU] data-rank="@rank@" data-template-type="suggestion" data-keyword="@in_txt@" attribute를 추가해주세요. -->
#              <li class="item _item" data-keyword="@in_txt@" data-rank="@rank@" data-template-type="suggestion">
#               <a class="kwd" href="#">
#                <span class="fix">
#                 <span class="common_ico_kwd">
#                  <i class="imsc ico_search">
#                  </i>
#                 </span>
#                 @txt@
#                </span>
#               </a>
#               <span class="etc">
#                <a aria-pressed="false" class="bt_item _add" href="#" role="button">
#                 <i class="imsc ico_insert">
#                  추가
#                 </i>
#                </a>
#               </span>
#              </li>
#              <!-- [AU] 최근검색어 템플릿 -->
#              <!-- [AU] _item 클래스를 추가해주세요. -->
#              <!-- [AU] data-rank="@rank@" data-template-type="history" data-keyword="@in_txt@" attribute를 추가해주세요. -->
#              <li class="item has_correct _item" data-keyword="@in_txt@" data-rank="@rank@" data-template-type="history">
#               <a class="kwd" href="#">
#                <span class="fix">
#                 <span class="common_ico_kwd">
#                  <i class="imsc ico_search">
#                  </i>
#                 </span>
#                 @txt@
#                </span>
#               </a>
#               <span class="etc">
#                <!-- 최근검색어 있으면 날짜 표시 -->
#                <em class="date">
#                 @date@.
#                </em>
#                <a aria-pressed="false" class="bt_item _add" href="#" role="button">
#                 <i class="imsc ico_insert">
#                  추가
#                 </i>
#                </a>
#               </span>
#              </li>
#             </ul>
#             <!-- [AU] 문맥검색 템플릿 -->
#             <!-- [AU] _item 클래스를 추가해주세요. -->
#             <!-- [AU] data-rank="@rank@" data-template-type="intend" data-keyword="@transQuery@" attribute를 추가해주세요. -->
#             <li class="item has_correct _item" data-intend-rank="@intendRank@" data-keyword="@transQuery@" data-rank="@rank@" data-template-type="intend">
#              <a class="kwd" href="#">
#               <span class="fix">
#                <span class="common_ico_kwd">
#                 <i class="imsc ico_search">
#                 </i>
#                </span>
#                @query@
#                <span class="context">
#                 @intend@
#                </span>
#               </span>
#              </a>
#              <span class="etc">
#               <a aria-pressed="false" class="bt_item _add" href="#" role="button">
#                <i class="imsc ico_insert">
#                 추가
#                </i>
#               </a>
#              </span>
#             </li>
#             <!-- [D] 선거안내문구 -->
#             <!-- [AU] _alert 클래스를 추가해주세요. -->
#             <div class="atcmp_alert _alert">
#              <div class="dsc_election">
#               <p class="dsc">
#                <i class="imsc ico_election">
#                </i>
#                <span class="_alert_passage">
#                </span>
#               </p>
#               <span class="dsc_inner">
#                <!-- [AU] _alert_passage2 클래스를 추가해주세요. -->
#                <span class="_alert_passage2">
#                </span>
#                <!-- [AU] _alert_link 클래스를 추가해주세요. -->
#                <a class="link _alert_link" href="#" target="_blank">
#                 자세히보기
#                </a>
#               </span>
#              </div>
#             </div>
#             <!-- [AU] _plus 클래스를 추가해주세요. -->
#             <div class="atcmp_plus _plus">
#              <div class="dsc_plus">
#               <a class="link_dsc" data-clk="sug.cxhelp" href="https://help.naver.com/support/alias/search/word/word_16.naver" target="_blank">
#                관심사를 반영한 컨텍스트 자동완성
#                <i class="imsc ico_help">
#                 도움말
#                </i>
#               </a>
#              </div>
#              <div class="switch">
#               <!-- [D] 선택시 aria-pressed="ture/false" -->
#               <!-- [AU] _plus_btn 클래스를 추가해주세요. -->
#               <a aria-pressed="false" class="bt_switch active _plus_btn" href="#" role="button">
#                <i class="imsc ico_option">
#                 컨텍스트 자동완성
#                </i>
#               </a>
#              </div>
#              <!-- [AU] _plus_layer 클래스를 추가해주세요. -->
#              <div class="layer_plus _plus_layer">
#               <strong class="tit">
#                컨텍스트 자동완성
#               </strong>
#               <!-- [AU] _plus_layer_isloggedin 클래스를 추가해주세요. -->
#               <!-- [AU] style="display:none" 추가해주세요. -->
#               <div class="_plus_layer_isloggedin" style="display:none">
#                <p class="dsc">
#                 ON/OFF 설정은
#                 <br/>
#                 해당기기(브라우저)에 저장됩니다.
#                </p>
#                <div class="btn_area">
#                 <a class="btn btn_view" data-clk="sug.cxlink" href="https://help.naver.com/support/alias/search/word/word_16.naver" target="_blank">
#                  자세히
#                 </a>
#                </div>
#               </div>
#               <!-- [AU] _plus_layer_isnotloggedin 클래스를 추가해주세요. -->
#               <!-- [AU] style="display:none" 추가해주세요. -->
#               <div class="_plus_layer_isnotloggedin" style="display:none">
#                <p class="dsc">
#                 <em class="txt">
#                  동일한 시간대/연령/남녀별
#                 </em>
#                 사용자 그룹의
#                 <br/>
#                 관심사에 맞춰 자동완성을 제공합니다.
#                </p>
#                <div class="btn_area">
#                 <a class="btn btn_login" data-clk="sug.cxlogin" href="https://nid.naver.com/nidlogin.login">
#                  로그인
#                 </a>
#                 <a class="btn btn_view" data-clk="sug.cxlink" href="https://help.naver.com/support/alias/search/word/word_16.naver" target="_blank">
#                  자세히
#                 </a>
#                </div>
#               </div>
#               <!-- [AU] _plus_layer_close 클래스를 추가해주세요. -->
#               <a class="btn_close _plus_layer_close" href="#" role="button">
#                <i class="imsc ico_close">
#                 컨텍스트 자동완성 레이어 닫기
#                </i>
#               </a>
#              </div>
#             </div>
#            </div>
#            <div class="atcmp_footer">
#             <span class="side_opt_area">
#              <span class="opt_item">
#               <a data-clk="sug.help" href="https://help.naver.com/alias/search/word/word_17.naver" target="_blank">
#                도움말
#               </a>
#              </span>
#              <span class="opt_item">
#               <a class="report" data-clk="sug.report" href="https://help.naver.com/support/contents/contents.help?serviceNo=605&amp;categoryNo=18215" target="_blank">
#                신고
#               </a>
#              </span>
#             </span>
#             <span class="rside_opt_area">
#              <span class="opt_item">
#               <!-- [AU] _suggestOnOff 클래스를 추가해주세요. -->
#               <a class="close _suggestOnOff" href="#">
#                자동완성 끄기
#               </a>
#              </span>
#             </span>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <!--EMPTY-->
#     <div id="gnb" role="navigation">
#      <div class="gnb_inner" id="NM_FAVORITE">
#       <div class="group_nav">
#        <ul class="list_nav type_fix">
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.mail" href="https://mail.naver.com/">
#           <i class="ico_mail">
#           </i>
#           메일
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.cafe" href="https://section.cafe.naver.com/">
#           카페
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.blog" href="https://section.blog.naver.com/">
#           블로그
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.kin" href="https://kin.naver.com/">
#           지식iN
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav shop" data-clk="svc.shopping" href="https://shopping.naver.com/">
#           <span class="blind">
#            쇼핑
#           </span>
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav shoplive" data-clk="svc.shoppinglive" href="https://shoppinglive.naver.com/home">
#           <span class="blind">
#            쇼핑LIVE
#           </span>
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.pay" href="https://order.pay.naver.com/home">
#           Pay
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.tvcast" href="https://tv.naver.com/">
#           <i class="ico_tv">
#           </i>
#           TV
#          </a>
#         </li>
#        </ul>
#        <ul class="list_nav NM_FAVORITE_LIST">
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.dic" href="https://dict.naver.com/">
#           사전
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.news" href="https://news.naver.com/">
#           뉴스
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.stock" href="https://finance.naver.com/">
#           증권
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.land" href="https://land.naver.com/">
#           부동산
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.map" href="https://map.naver.com/">
#           지도
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.vibe" href="https://vibe.naver.com/?from=naver_main&amp;utm_source=naver_main&amp;utm_medium=naver_main_pcweb&amp;utm_campaign=naver_main_redirect">
#           VIBE
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.book" href="https://search.shopping.naver.com/book/home">
#           도서
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.webtoon" href="https://comic.naver.com/">
#           웹툰
#          </a>
#         </li>
#        </ul>
#        <ul class="list_nav type_empty" style="display: none;">
#        </ul>
#        <a class="btn_more" data-clk="svc.more" href="#" role="button">
#         더보기
#        </a>
#        <div class="ly_btn_area">
#         <a class="btn NM_FAVORITE_ALL" data-clk="map.svcmore" href="more.html">
#          서비스 전체보기
#         </a>
#         <a class="btn btn_set" data-clk="map.edit" href="#" role="button">
#          메뉴설정
#         </a>
#         <a class="btn btn_reset" data-clk="edt.reset" href="#" role="button">
#          초기화
#         </a>
#         <a class="btn btn_save" data-clk="edt.save" href="#" role="button">
#          저장
#         </a>
#        </div>
#       </div>
#       <div class="group_weather" id="NM_WEATHER">
#        <div>
#         <a class="weather_area ico_w07" data-clk="squ.weat" href="https://weather.naver.com/today/09440127?cpName=KMA">
#          <div class="current_box">
#           <strong aria-label="현재기온" class="current">
#            13.1°
#           </strong>
#           <strong class="state">
#            흐림
#           </strong>
#          </div>
#          <div class="degree_box">
#           <span aria-label="최저기온" class="min">
#            8.0°
#           </span>
#           <span aria-label="최고기온" class="max">
#            18.0°
#           </span>
#          </div>
#          <span class="location">
#           상암동
#          </span>
#         </a>
#        </div>
#        <div>
#         <a class="air_area" data-clk="squ.dust" href="https://weather.naver.com/today/09440127?cpName=KMA">
#          <ul class="list_air">
#           <li class="air_item">
#            미세
#            <strong class="state state_normal">
#             보통
#            </strong>
#           </li>
#           <li class="air_item">
#            초미세
#            <strong class="state state_good">
#             좋음
#            </strong>
#           </li>
#          </ul>
#          <span class="location">
#           상암동
#          </span>
#         </a>
#        </div>
#       </div>
#      </div>
#      <div class="ly_service">
#       <div class="group_service NM_FAVORITE_ALL_LY">
#       </div>
#       <div class="group_service NM_FAVORITE_EDIT_LY" style="display: none;">
#       </div>
#      </div>
#     </div>
#    </div>
#    <div id="container" role="main">
#     <div style="position:relative;width:1130px;margin:0 auto;z-index:11">
#      <div id="da_top">
#      </div>
#      <div id="da_expwide">
#      </div>
#     </div>
#     <div class="column_left" id="NM_INT_LEFT">
#      <div id="veta_top">
#       <div id="veta_top_inner" style="height:135px">
#       </div>
#       <span class="veta_bd_t">
#       </span>
#       <span class="veta_bd_b">
#       </span>
#       <span class="veta_bd_l">
#       </span>
#       <span class="veta_bd_r">
#       </span>
#      </div>
#      <div class="sc_newscast" id="newsstand">
#       <h2 class="blind">
#        뉴스스탠드
#       </h2>
#       <div class="group_issue" data-clk-prefix="ncy" id="NM_NEWSSTAND_HEADER">
#        <div class="issue_area">
#         <a class="link_media" data-clk="newsflash" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y">
#          연합뉴스
#         </a>
#         <div class="list_issue" data-nm-ui="rolling" id="NM_ONELINE_ROLLING">
#          <div>
#           <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013913044">
#            尹대통령, 5박7일 국빈 방미 마치고 귀국
#           </a>
#          </div>
#          <div>
#           <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013913300">
#            대통령실, 박지원에 "반국가적 작태"…'아메리칸 파이'후문 일축
#           </a>
#          </div>
#          <div>
#           <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013913375">
#            전세피해자 기존 전세대출 20년 분할상환…연체정보 삭제
#           </a>
#          </div>
#          <div>
#           <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013913353">
#            의사·간호조무사 "총파업 강행" 예고…의료대란 현실화할까
#           </a>
#          </div>
#          <div>
#           <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013913317">
#            검찰, '돈봉투' 압수물 분석…송영길·먹사연 연결점 추적
#           </a>
#          </div>
#          <div>
#           <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013913163">
#            '한계채무자 만나고 지옥철 타고'…현장 부쩍 자주 찾는 이재명
#           </a>
#          </div>
#          <div>
#           <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013913385">
#            지진 발생 옥천 주민 "갑자기 '쿵'…평생 이런 지진동 처음"
#           </a>
#          </div>
#          <div>
#           <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013913389">
#            9호선 등촌역 화재로 2시간 무정차
#           </a>
#          </div>
#          <div>
#           <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013913364">
#            생후 40일 아들 떨어뜨리고 방치해 사망…친모 구속
#           </a>
#          </div>
#          <div>
#           <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013913369">
#            故 서세원 빈소 추모 행렬…이철우·주호영 조문
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="direct_area">
#         <a class="link_news" data-clk="newshome" href="http://news.naver.com/">
#          뉴스홈
#         </a>
#         <a class="link_direct" data-clk="entertainment" href="http://entertain.naver.com/home">
#          연예
#         </a>
#         <a class="link_direct" data-clk="sports" href="http://sports.news.naver.com/">
#          스포츠
#         </a>
#         <a class="link_direct" data-clk="economy" href="http://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101">
#          경제
#         </a>
#        </div>
#       </div>
#       <div class="group_title" data-clk-prefix="nsd" id="NM_NEWSSTAND_TITLE">
#        <a class="link_newsstand" data-clk="title" href="http://newsstand.naver.com/" target="_blank">
#         뉴스스탠드
#        </a>
#        <div class="sort_area" id="NM_NEWSSTAND_data_buttons" role="tablist">
#         <a aria-controls="NM_NEWSSTAND_MY_LIST" aria-selected="false" class="btn_sort" data-clk="my" data-type="my" href="#" role="tab">
#          구독한 언론사
#         </a>
#         <a aria-controls="NM_NEWSSTAND_DEFAULT_THUMB" aria-selected="true" class="btn_sort" data-clk="all" data-type="all" href="#" role="tab">
#          전체언론사
#         </a>
#        </div>
#        <div class="set_area" id="NM_NEWSSTAND_view_buttons" role="tablist">
#         <a aria-controls="NM_NEWSSTAND_DEFAULT_LIST" aria-selected="false" class="btn_set" data-clk="articleview" data-type="list" href="#" role="tab">
#          <i class="ico_list">
#           <span class="blind">
#            리스트형
#           </span>
#          </i>
#         </a>
#         <a aria-controls="NM_NEWSSTAND_DEFAULT_THUMB" aria-selected="true" class="btn_set" data-clk="pressview" data-type="thumb" href="#" role="tab">
#          <i class="ico_tile">
#           <span class="blind">
#            썸네일형
#           </span>
#          </i>
#         </a>
#         <a class="btn_set" data-clk="set" href="http://newsstand.naver.com/config.html" target="_blank">
#          <i class="ico_set">
#           <span class="blind">
#            설정
#           </span>
#          </i>
#         </a>
#        </div>
#       </div>
#       <div id="NM_NEWSSTAND_VIEW_CONTAINER" style="position:relative">
#        <div class="group_news" data-clk-prefix="nsd_all" id="NM_NEWSSTAND_DEFAULT_LIST" role="tabpanel" style="display:none">
#         <a class="pm_btn_prev_l _NM_NEWSSTAND_LIST_prev_btn" data-clk-custom="prev" href="#" role="button">
#          <i class="ico_btn">
#           <span class="blind">
#            이전
#           </span>
#          </i>
#         </a>
#         <a class="pm_btn_next_l _NM_NEWSSTAND_LIST_next_btn" data-clk-custom="next" href="#" role="button">
#          <i class="ico_btn">
#           <span class="blind">
#            다음
#           </span>
#          </i>
#         </a>
#         <div class="list_view">
#          <div class="option_area">
#           <div class="list_option_wrap">
#            <ul class="list_option">
#             <li class="option_item" data-cateid="ct2">
#              <a class="option" data-clk="daei" href="#">
#               종합/경제
#              </a>
#             </li>
#             <li class="option_item" data-cateid="ct3">
#              <a class="option" data-clk="dtvcom" href="#">
#               방송/통신
#              </a>
#             </li>
#             <li class="option_item" data-cateid="ct4">
#              <a class="option" data-clk="dit" href="#">
#               IT
#              </a>
#             </li>
#             <li class="option_item" data-cateid="ct5">
#              <a class="option" data-clk="deng" href="#">
#               영자지
#              </a>
#             </li>
#             <li class="option_item" data-cateid="ct6">
#              <a class="option" data-clk="dsporent" href="#">
#               스포츠/연예
#              </a>
#             </li>
#             <li class="option_item" data-cateid="ct7">
#              <a class="option" data-clk="dmagtec" href="#">
#               매거진/전문지
#              </a>
#             </li>
#             <li class="option_item" data-cateid="ct8">
#              <a class="option" data-clk="dloc" href="#">
#               지역
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#          <div class="_NM_NEWSSTAND_ARTICLE_CONTAINER" data-clk-sub="*a">
#          </div>
#         </div>
#         <div class="ly_popup NM_NEWSSTAND_POPUP NM_NEWSSTAND_invalid" data-clk-sub="*a" style="display:none">
#          <a class="btn_close NM_NEWSSTAND_POPUP_CLOSE" href="#" role="button">
#           <i class="ico_close">
#           </i>
#           <span class="blind">
#            닫기
#           </span>
#          </a>
#          <p class="popup_msg">
#           해당 언론사 사정으로 접근이 제한됩니다.
#          </p>
#          <div class="popup_btn">
#           <a class="btn_confirm NM_NEWSSTAND_POPUP_CLOSE" href="#" role="button">
#            확인
#           </a>
#          </div>
#         </div>
#         <div class="ly_popup NM_NEWSSTAND_POPUP NM_NEWSSTAND_undescribe_confirm" data-clk-sub="*a" style="display:none">
#          <a class="btn_close NM_NEWSSTAND_POPUP_CLOSE" data-clk="usclose" href="#" role="button">
#           <i class="ico_close">
#           </i>
#           <span class="blind">
#            닫기
#           </span>
#          </a>
#          <p class="popup_msg">
#           <strong class="NM_NEWSSTAND_POPUP_PNAME">
#           </strong>
#           을(를)
#           <br/>
#           구독해지 하시겠습니까?
#          </p>
#          <div class="popup_btn">
#           <a class="btn_confirm NM_NEWSSTAND_POPUP_CONFIRM" data-clk="usdone" href="#" role="button">
#            확인
#           </a>
#           <a class="btn_confirm NM_NEWSSTAND_POPUP_CLOSE" data-clk="uscancel" href="#" role="button">
#            취소
#           </a>
#          </div>
#         </div>
#         <div class="ly_toast NM_NEWSSTAND_TOAST" style="display:none">
#          <p class="toast_msg">
#           구독한 언론사에 추가되었습니다.
#          </p>
#         </div>
#        </div>
#        <div class="group_news" data-clk-prefix="nsd_all" id="NM_NEWSSTAND_DEFAULT_THUMB" role="tabpanel" style="display:block">
#         <a class="pm_btn_prev_l _NM_UI_PAGE_PREV" data-clk-custom="prev" href="#" role="button">
#          <i class="ico_btn">
#           <span class="blind">
#            이전
#           </span>
#          </i>
#         </a>
#         <a class="pm_btn_next_l _NM_UI_PAGE_NEXT" data-clk-custom="next" href="#" role="button">
#          <i class="ico_btn">
#           <span class="blind">
#            다음
#           </span>
#          </i>
#         </a>
#         <div class="_NM_UI_PAGE_CONTAINER" data-clk-sub="*p" style="height:100%;overflow:hidden">
#          <div style="width: 750px; float: left;">
#           <div class="tile_view">
#            <div class="frame_area">
#             <i class="line to_right1">
#             </i>
#             <i class="line to_right2">
#             </i>
#             <i class="line to_right3">
#             </i>
#             <i class="line to_bottom1">
# ...
#              <img alt="폭스바겐, 주행거리 늘어난 ‘2023년형 ID.4’ 출시 예정" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20230427_1095%2Fupload_1682560658457VGIp2.jpg%22&amp;type=nf340_228" height="114" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" width="170"/>
#              <span class="thumb_bd">
#              </span>
#             </a>
#             <a class="theme_info" data-clk="tcc_aut.list12cont2" href="https://post.naver.com/viewer/postView.naver?volumeNo=35821935&amp;memberNo=35797058&amp;searchRank=65" target="_blank">
#              <em class="theme_category">
#               자동차
#              </em>
#              <strong class="title elss">
#               폭스바겐, 주행거리 늘어난 ‘2023년형 ID.4’ 출시 예정
#              </strong>
#              <p class="desc">
#               &lt;카매거진=최정필 기자 choiditor@carmgz.kr&gt;폭스바겐코리아가 주행가능거리를 늘리고 에너지 효율을 향상시켜 상품성을 대폭 강화한 ‘2023년형 ID.4’를 오는 6월초 공식 출시하고 고객 인도를 개시한다고 밝혔다. 지난해 9월 출시된 폭스바겐코리아의 첫 번째 전기차 ID.4는 폭스바겐 전기차 전용 MEB 플랫폼을
#              </p>
#              <div class="source_box">
#               <span class="date">
#                1주일 전
#               </span>
#               <span class="source">
#                <span class="source_inner">
#                 카매거진
#                </span>
#               </span>
#              </div>
#             </a>
#            </li>
#            <li class="theme_item" data-da-position="true" data-gdid="CAS_0be1a064-e3c2-11ed-9177-6d3287c2e036">
#             <a class="theme_thumb" data-clk="tcc_aut.list12cont3" href="https://post.naver.com/viewer/postView.naver?volumeNo=35842528&amp;memberNo=32025603" target="_blank">
#              <img alt="아우디, 후속 A8 '700마력 육박 슈퍼 전기차'로 내놓는다" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20230426_1095%2Fupload_1682465848669P8Gp7.jpg%22&amp;type=nf340_228" height="114" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" width="170"/>
#              <span class="thumb_bd">
#              </span>
#             </a>
#             <a class="theme_info" data-clk="tcc_aut.list12cont3" href="https://post.naver.com/viewer/postView.naver?volumeNo=35842528&amp;memberNo=32025603" target="_blank">
#              <em class="theme_category">
#               자동차
#              </em>
#              <strong class="title elss">
#               아우디, 후속 A8 '700마력 육박 슈퍼 전기차'로 내놓는다
#              </strong>
#              <p class="desc">
#               아우디가 완전히 새로운 ‘A8’ 대체 모델을 내년에 선보인다. 해외자동차매체 오토카에 따르면 해당 모델은 아우디가 지금까지 선보인 전기차 중 가장 강력한 차량이 될 예정이다. 현재 가장 강력한 전기차는 ‘RS E-트론 GT’로 한 쌍의 전기 모터로 637마력의 성능을 발휘한다. 내연기관의 경우 4.0리터 V8 트윈
#              </p>
#              <div class="source_box">
#               <span class="date">
#                4일 전
#               </span>
#               <span class="source">
#                <span class="source_inner">
#                 지피코리아
#                </span>
#               </span>
#              </div>
#             </a>
#            </li>
#            <li class="theme_item" data-da-position="true" data-gdid="CAS_e88688c2-e49e-11ed-8495-073ac29e4585">
#             <a class="theme_thumb" data-clk="tcc_aut.list12cont4" href="https://post.naver.com/viewer/postView.naver?volumeNo=35849885&amp;memberNo=11643111" target="_blank">
#              <img alt="애스턴마틴, DBX707의 6가지 매력 공개…궁극의 럭셔리 SUV란 평 받는 이유는?" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20230427_1095%2Fupload_1682560662361YvQwI.jpg%22&amp;type=nf340_228" height="114" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" width="170"/>
#              <span class="thumb_bd">
#              </span>
#             </a>
#             <a class="theme_info" data-clk="tcc_aut.list12cont4" href="https://post.naver.com/viewer/postView.naver?volumeNo=35849885&amp;memberNo=11643111" target="_blank">
#              <em class="theme_category">
#               자동차
#              </em>
#              <strong class="title elss">
#               애스턴마틴, DBX707의 6가지 매력 공개…궁극의 럭셔리 SUV란 평 받는 이유는?
#              </strong>
#              <p class="desc">
#               GQ, 탑 기어 등 각종 매체 어워드 수상…영국 윌리엄 왕세자도 시승한 것으로도 알려져애스턴마틴이 스포츠카 DNA를 담아낸 럭셔리 SUV DBX707의 6가지 매력을 선정해 발표했다. 애스턴마틴 DBX707은 강력한 퍼포먼스, 럭셔리한 디자인과 편안한 주행 경험을 선사해 궁극의 럭셔리 SUV란 평을 받고 있다. 이에 애스턴마틴은 DBX707의
#              </p>
#              <div class="source_box">
#               <span class="date">
#                3일 전
#               </span>
#               <span class="source">
#                <span class="source_inner">
#                 모터매거진
#                </span>
#               </span>
#              </div>
#             </a>
#            </li>
#            <li class="theme_item" data-da-position="true" data-gdid="CAS_613b7bcb-e1bd-11ed-9177-fff60e241361">
#             <a class="theme_thumb" data-clk="tcc_aut.list12cont5" href="https://post.naver.com/viewer/postView.naver?volumeNo=35820552&amp;memberNo=16056627" target="_blank">
#              <img alt="애플 전기차, 도대체 언제 어떻게 나오는 걸까?" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20230423_1095%2Fupload_1682243917152frLjK.jpg%22&amp;type=nf340_228" height="114" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" width="170"/>
#              <span class="thumb_bd">
#              </span>
#             </a>
#             <a class="theme_info" data-clk="tcc_aut.list12cont5" href="https://post.naver.com/viewer/postView.naver?volumeNo=35820552&amp;memberNo=16056627" target="_blank">
#              <em class="theme_category">
#               자동차
#              </em>
#              <strong class="title elss">
#               애플 전기차, 도대체 언제 어떻게 나오는 걸까?
#              </strong>
#              <p class="desc">
#               애플 전기차, 도대체 언제 어떻게 나오는 걸까?애플은 수년 동안 전기 자동차를 개발 중이라는 소문이 돌았지만 여전히 공식적인 발표는 하지 않고 있습니다. 그럼에도 불구하고 애플이 전기차 시장 진출을 진지하게 고려하고 있다고 믿을 만한 이유는 여러 가지가 있는데요. 애플이 전기차를 만들 것이라고 보는 이유와 향후 애플만의 차별화 요소로는 무엇이 있을지 ABC
#              </p>
#              <div class="source_box">
#               <span class="date">
#                1주일 전
#               </span>
#               <span class="source">
#                <span class="source_inner">
#                 ABC타이어
#                </span>
#               </span>
#              </div>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="btn_more_wrap">
#          <button class="btn_more" data-clk-custom="tcc_aut.more" data-next-page="2" type="button">
#           <i class="ico_more">
#           </i>
#           새로운 글 더보기
#          </button>
#         </div>
#         <div class="NM_THEME_META" data-panel-code="CARGAME" data-parent-code="" style="display: none">
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="column_right" id="NM_INT_RIGHT">
#      <div class="column_fix_wrap">
#       <div id="da_brand">
#       </div>
#       <div class="sc_login" id="account">
#        <h2 class="blind">
#         Sign in
#        </h2>
#        <p class="login_msg">
#         Connect with people
#        </p>
#        <a class="link_login" data-clk="log_off.login" href="https://nid.naver.com/nidlogin.login?mode=form&amp;url=https%3A%2F%2Fwww.naver.com">
#         <i class="ico_naver">
#          <span class="blind">
#           NAVER
#          </span>
#         </i>
#         Sign in
#        </a>
#        <div class="sub_area">
#         <div class="look_box">
#          <a class="link_look" data-clk="log_off.searchid" href="https://nid.naver.com/user/help.nhn?todo=idinquiry">
#           Forgot Username
#          </a>
#          <a class="link_look" data-clk="log_off.searchpass" href="https://nid.naver.com/nidreminder.form">
#           Password
#          </a>
#         </div>
#         <a class="link_join" data-clk="log_off.registration" href="https://nid.naver.com/nidregister.form?url=https%3A%2F%2Fwww.naver.com">
#          Sign up
#         </a>
#        </div>
#       </div>
#       <div class="sc_timesquare" id="timesquare">
#        <h2 class="blind">
#         타임스퀘어
#        </h2>
#        <div class="card_wrap">
#         <div class="card_nav">
#          <a class="btn_nav btn_prev" data-clk="squ.pre" href="#" role="button">
#           <span class="blind">
#            이전
#           </span>
#          </a>
#          <a class="btn_nav btn_next" data-clk="squ.next" href="#" role="button">
#           <span class="blind">
#            다음
#           </span>
#          </a>
#         </div>
#         <div id="NM_TS_ROLLING_WRAP" style="height: 100%;">
#          <div>
#           <a class="card_news" data-clk="squ.line1" href="https://news.naver.com/main/tv/index.naver?mid=tvh">
#            <i class="news_badge type_live">
#             LIVE
#            </i>
#            <span class="news">
#             저녁방송 메인뉴스 보기
#            </span>
#           </a>
#          </div>
#          <div>
#           <a class="card_news" data-clk="squ.line3" href="https://search.naver.com/search.naver?sm=top_hty&amp;fbm=0&amp;ie=utf8&amp;query=%EC%BD%94%EB%A1%9C%EB%82%9819">
#            <i class="news_badge">
#             이슈
#            </i>
#            <span class="news">
#             코로나바이러스감염증-19 현황
#            </span>
#           </a>
#          </div>
#         </div>
#        </div>
#        <!-- EMPTY -->
#       </div>
#       <div id="veta_branding">
#        <span class="blind">
#         <script id="veta_service_check">
#         </script>
#        </span>
#        <div id="veta_branding_inner" style="width:350px;height:200px">
#        </div>
#        <span class="veta_bd_t">
#        </span>
#        <span class="veta_bd_b">
#        </span>
#        <span class="veta_bd_l">
#        </span>
#        <span class="veta_bd_r">
#        </span>
#       </div>
#       <div class="sc_shopcast" id="shopcast">
#        <iframe data-iframe-src="/shoppingbox/shoppingboxnew/main.nhn?mode=plusdeal&amp;domain=N" frameborder="0" height="1809" id="shopcast_iframe" marginheight="0" marginwidth="0" scrolling="no" title="쇼핑캐스트" width="350">
#        </iframe>
#       </div>
#      </div>
#     </div>
#     <a class="content_top" href="#wrap" id="NM_scroll_top_btn">
#      <span class="blind">
#       TOP
#      </span>
#     </a>
#     <button aria-pressed="false" class="btn_theme" id="NM_darkmode_btn" role="button" type="button">
#      <span class="blind">
#       라이트 모드로 보기
#      </span>
#     </button>
#    </div>
#    <div id="footer" role="contentinfo">
#     <div class="footer_inner">
#      <div class="banner_area" id="NM-FOOTER-AD">
#       <div class="da_box_wrap">
#        <div id="da_public_left">
#        </div>
#        <div id="da_public_right">
#        </div>
#        <div id="veta_time2">
#        </div>
#       </div>
#      </div>
#      <div class="notice_area" data-clk-prefix="ntc">
#       <div class="notice_box">
#        <h3 class="title">
#         <a href="https://www.naver.com/NOTICE">
#          공지사항
#         </a>
#        </h3>
#        <!-- EMPTY -->
#       </div>
#       <a class="link_all" data-clk="svcmap" href="more.html">
#        서비스 전체보기
#       </a>
#      </div>
#      <div class="aside_area">
#       <div class="partner_box_wrap">
#        <div class="partner_box" data-clk-prefix="crt">
#         <h3 class="title">
#          Creators
#         </h3>
#         <a class="link_partner" data-clk="creator" href="https://www.navercorp.com/service/creators">
#          크리에이터
#         </a>
#         <a class="link_partner" data-clk="smbusiness" href="https://www.navercorp.com/service/business">
#          스몰비즈니스
#         </a>
#        </div>
#        <div class="partner_box" data-clk-prefix="crt">
#         <h3 class="title">
#          Partners
#         </h3>
#         <a class="link_partner" data-clk="sme" href="https://campaign.naver.com/smefullcare/online/">
#          SME 풀케어 시스템
#         </a>
#         <a class="link_partner" data-clk="service" href="https://business.naver.com/service.html">
#          비즈니스 · 광고
#         </a>
#         <a class="link_partner" data-clk="store" href="https://sell.storefarm.naver.com/#/home/about">
#          스토어 개설
#         </a>
#         <a class="link_partner" data-clk="place" href="https://smartplace.naver.com">
#          지역업체 등록
#         </a>
#         <a class="link_partner" data-clk="expert" href="https://expert.naver.com/expert/introduction?tab=guide#join">
#          엑스퍼트 등록
#         </a>
#        </div>
#        <div class="partner_box" data-clk-prefix="crt">
#         <h3 class="title">
#          Developers
#         </h3>
#         <a class="link_partner" data-clk="center" href="https://developers.naver.com">
#          네이버 개발자 센터
#         </a>
#         <a class="link_partner" data-clk="openapi" href="https://developers.naver.com/docs/common/openapiguide/#/apilist.md">
#          오픈 API
#         </a>
#         <a class="link_partner" data-clk="opensource" href="https://naver.github.io">
#          오픈소스
#         </a>
#         <a class="link_partner" data-clk="d2" href="https://d2.naver.com">
#          네이버 D2
#         </a>
#         <a class="link_partner" data-clk="naverD2SF" href="http://d2startup.com">
#          네이버 D2SF
#         </a>
#         <a class="link_partner" data-clk="labs" href="https://www.naverlabs.com">
#          네이버 랩스
#         </a>
#        </div>
#       </div>
#       <div class="service_box_wrap">
#        <div class="service_box" data-clk-prefix="wbd">
#         <a class="service_logo" data-clk="bt" href="http://whale.naver.com/">
#          <img alt="웨일" height="48" src="data:image/png;base64,..." width="48"/>
#         </a>
#         <div class="service_info">
#          <strong class="title">
#           웨일 브라우저
#          </strong>
#          <a class="dsc" data-clk="bt" href="http://whale.naver.com/">
#           다운받기
#          </a>
#         </div>
#        </div>
#        <div class="service_box" data-clk-prefix="prj">
#         <a class="service_logo" data-clk="link" href="https://search.naver.com/search.naver?where=nexearch&amp;sm=top_hty&amp;fbm=1&amp;ie=utf8&amp;query=%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%EA%BD%83">
#          <img alt="꽃" height="50" src="data:image/png;base64,..." width="47"/>
#         </a>
#         <div class="service_info">
#          <strong class="title">
#           프로젝트 꽃
#          </strong>
#          <a class="dsc" data-clk="link" href="https://search.naver.com/search.naver?where=nexearch&amp;sm=top_hty&amp;fbm=1&amp;ie=utf8&amp;query=%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%EA%BD%83">
#           바로가기
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="corp_area" data-clk-prefix="plc">
#       <h3 class="blind">
#        네이버 정책 및 약관
#       </h3>
#       <ul class="list_corp">
#        <li class="corp_item">
#         <a data-clk="intronhn" href="https://www.navercorp.com">
#          회사소개
#         </a>
#        </li>
#        <li class="corp_item">
#         <a data-clk="recruit" href="https://recruit.navercorp.com/">
#          인재채용
#         </a>
#        </li>
#        <li class="corp_item">
#         <a data-clk="contact" href="https://www.navercorp.com/naver/proposalGuide">
#          제휴제안
#         </a>
#        </li>
#        <li class="corp_item">
#         <a data-clk="service" href="/policy/service.html">
#          이용약관
#         </a>
#        </li>
#        <li class="corp_item">
#         <a data-clk="privacy" href="/policy/privacy.html">
#          <strong>
#           개인정보처리방침
#          </strong>
#         </a>
#        </li>
#        <li class="corp_item">
#         <a data-clk="youth" href="/policy/youthpolicy.html">
#          청소년보호정책
#         </a>
#        </li>
#        <li class="corp_item">
#         <a data-clk="policy" href="https://policy.naver.com/policy/service_group.html">
#          네이버 정책
#         </a>
#        </li>
#        <li class="corp_item">
#         <a data-clk="helpcenter" href="https://help.naver.com/">
#          고객센터
#         </a>
#        </li>
#       </ul>
#       <address class="addr">
#        <a data-clk="nhn" href="https://www.navercorp.com" target="_blank">
#         ⓒ NAVER Corp.
#        </a>
#       </address>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div id="adscript" style="display:none">
#   </div>
#  </body>
# </html>

# %%
soup.select_one('body a')
# Out:
# <a href="#newsstand"><span>뉴스스탠드 바로가기</span></a>

# %%
soup.select('body a')
# Out:
# [<a href="#newsstand"><span>뉴스스탠드 바로가기</span></a>,
#  <a href="#themecast"><span>주제별캐스트 바로가기</span></a>,
#  <a href="#timesquare"><span>타임스퀘어 바로가기</span></a>,
#  <a href="#shopcast"><span>쇼핑캐스트 바로가기</span></a>,
#  <a href="#account"><span>로그인 바로가기</span></a>,
#  <a class="_3h-N8T9V" data-clk="dropbanner1b" href="https://whale.naver.com/banner/details/security/?=main&amp;wpid=RydDy7"></a>,
#  <a class="_2aeXMlrb BMgpjddw" data-clk="dropdownload1b" href="https://installer-whale.pstatic.net/downloads/banner/RydDy7/WhaleSetup.exe" id="NM_whale_download_btn"><span style="background-color: #0436c7">다운로드</span></a>,
#  <a class="special_logo_link" data-clk="top.spe" href="https://campaign.naver.com/collect_v2/?pcode=naver_speciallogo&amp;event_id=anniversary_summer&amp;target=https%253A%252F%252Fcampaign.naver.com%252Fissue%252Fanniversary%252Fsummer%252F" title="더위 정복! 중복">
#  <img alt="더위 정복! 중복" class="special_img_fold" height="60" src="https://s.pstatic.net/static/www/mobile/edit/20220725/mobile_164142249888.png" width="58"/>
#  </a>,
#  <a class="link_set" data-clk="top.mkhome" href="https://help.naver.com/support/welcomePage/guide.help" id="NM_set_home_btn">네이버를 시작페이지로</a>,
#  <a class="link_jrnaver" data-clk="top.jrnaver" href="https://jr.naver.com"><i class="ico_jrnaver"></i><span class="blind">쥬니어네이버</span></a>,
#  <a class="link_happybin" data-clk="top.happybean" href="https://happybean.naver.com"><i class="ico_happybin"></i><span class="blind">해피빈</span></a>,
#  <a class="btn_keyboard" href="#" id="ke_kbd_btn" onclick="return false;" role="button"><span class="blind">한글 입력기</span><span class="ico_keyboard"></span></a>,
#  <a aria-pressed="false" class="btn_arw _btn_arw fold" data-atcmp-element="" href="#" id="nautocomplete" role="button" tabindex="2"><span class="blind">자동완성 레이어</span><span class="ico_arr"></span></a>,
#  <a aria-pressed="false" class="item _delAll" href="#" role="button">전체삭제</a>,
#  <a class="kwd" href="#">
#  <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span><span>@txt@</span></span>
#  </a>,
#  <a aria-pressed="false" class="bt_item _del" href="#" role="button"><i class="imsc ico_del">삭제</i></a>,
#  <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/support/alias/search/word/word_29.naver" target="_blank">도움말</a>,
#  <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/support/alias/search/word/word_29.naver" target="_blank">도움말</a>,
#  <a data-clk="sly.help" href="https://help.naver.com/support/service/main.help?serviceNo=605&amp;categoryNo=1991" target="_blank">도움말</a>,
#  <a class="close _keywordOnOff" href="#">자동저장 끄기</a>,
#  <a class="link_item" href="#">
#  <span class="common_ico_kwd"><i class="imsc ico_search"></i></span>
#  <div class="dsc_area">
#  <span class="tit">@5@회차 당첨번호</span>
#  <span class="dsc">
#  <span class="item">추첨 @13@.</span><span class="item">지급기한 1년</span>
#  </span>
#  </div>
#  <span class="etc_area">
#  <span class="etc lotto">
#  <em class="n@6@">@6@</em><em class="n@7@">@7@</em><em class="n@8@">@8@</em><em class="n@9@">@9@</em><em class="n@10@">@10@</em><em class="n@11@">@11@</em><em class="imsc_bf bonus n@12@">@12@</em>
#  </span>
#  </span>
#  </a>,
#  <a class="link_item @11@" href="#">
#  <!-- [D] 국가별 class 가나다순
#  ZAR 남아프리카 공화국
#  NPR 네팔
#  NOK 노르웨이
#  NZD 뉴질랜드
#  TWD 대만
#  DKK 덴마크
#  RUB 러시아
#  MOP 마카오
#  MYR 말레이시아
#  MXN 멕시코
#  MNT 몽골
#  USD 미국
#  BHD 바레인
#  BDT 방글라데시
#  VND 베트남
#  BRL 브라질
#  SAR 사우디아라비아
#  SEK 스웨덴
#  CHF 스위스
#  SGD 싱가포르
#  AED 아랍에미리트
#  GBP 영국
#  EUR 유럽연합
#  ILS 이스라엘
#  EGP 이집트
#  INR 인도
#  IDR 인도네시아
#  JPY 일본
#  CNY 중국
#  CZK 체코
#  CLP 칠레
#  KZT 카자흐스탄
#  QAR 카타르
#  CAD 캐나다
#  KWD 쿠웨이트
#  THB 태국
#  TRY 터키
#  PKR 파키스탄
#  PLN 폴란드
#  PHP 필리핀
#  HUF 헝가리
#  AUD 호주
#  HKD 홍콩
#  -->
#  <span class="common_ico_kwd"><i class="imsc ico @12@">@14@</i></span>
#  <div class="dsc_area">
#  <span class="tit">@txt@<span class="sub">@currency@</span></span>
#  <span class="dsc">
#  <span class="item"><i class="imsc ico_arr"></i>@8@(@9@%)</span>
#  </span>
#  </div>
#  <span class="etc_area">
#  <span class="etc"><em class="num">@6@</em>원</span>
#  </span>
#  </a>,
#  <a class="link_item @12@" href="#">
#  <span class="common_ico_kwd"><i class="imsc ico_search"></i></span>
#  <div class="dsc_area">
#  <span class="tit">@txt@</span>
#  <span class="dsc">
#  <span class="item">@7@, @message@</span>
#  </span>
#  </div>
#  <span class="etc_area">
#  <span class="etc">
#  <!-- [D] 날씨별 class
#  ico1 맑음(낮)
#  ico2 맑음(밤)
#  ico3 구름조금(낮)
#  ico4 구름조금(밤)
#  ico5 구름많음(낮)
#  ico6 구름많음(밤)
#  ico7 흐림
#  ico8 약한비
#  ico9 비
#  ico10 강한비
#  ico11 약한눈
#  ico12 눈
#  ico13 강한눈
#  ico14 진눈깨비
#  ico15 소나기
#  ico16 안개
#  ico17 소낙눈
#  ico18 번개뇌우
#  ico19 우박
#  ico20 황사
#  ico21 비또는눈
#  ico22 가끔비
#  ico23 가끔눈
#  ico24 가끔비또는눈
#  ico25 흐린후갬
#  ico26 뇌우후갬
#  ico27 비후갬
#  ico28 눈후갬
#  ico29 흐려져비
#  ico30 흐려져눈
#  -->
#  <span class="ico_weather"><i class="imsc ico ico@iconNo@">@7@</i></span>
#  <em class="degree">@8@<sup class="celsius">°</sup></em>
#  </span>
#  </span>
#  </a>,
#  <a class="link_item" href="@5@" target="_blank">
#  <span class="common_ico_kwd"><i class="imsc ico_url"></i></span>
#  <div class="dsc_area">
#  <span class="tit">@txt@</span>
#  <span class="dsc">
#  <span class="item">@5@</span>
#  </span>
#  </div>
#  <span class="etc_area">
#  <span class="etc">바로가기</span>
#  </span>
#  </a>,
#  <a class="kwd" href="#">
#  <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span>@txt@</span>
#  </a>,
#  <a aria-pressed="false" class="bt_item _add" href="#" role="button"><i class="imsc ico_insert">추가</i></a>,
#  <a class="kwd" href="#">
#  <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span>@txt@</span>
#  </a>,
#  <a aria-pressed="false" class="bt_item _add" href="#" role="button"><i class="imsc ico_insert">추가</i></a>,
#  <a class="kwd" href="#">
#  <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span>@query@ <span class="context">@intend@</span></span>
#  </a>,
#  <a aria-pressed="false" class="bt_item _add" href="#" role="button"><i class="imsc ico_insert">추가</i></a>,
#  <a class="link _alert_link" href="#" target="_blank">자세히보기</a>,
#  <a class="link_dsc" data-clk="sug.cxhelp" href="https://help.naver.com/support/alias/search/word/word_16.naver" target="_blank">관심사를 반영한 컨텍스트 자동완성<i class="imsc ico_help">도움말</i></a>,
#  <a aria-pressed="false" class="bt_switch active _plus_btn" href="#" role="button"><i class="imsc ico_option">컨텍스트 자동완성</i></a>,
#  <a class="btn btn_view" data-clk="sug.cxlink" href="https://help.naver.com/support/alias/search/word/word_16.naver" target="_blank">자세히</a>,
#  <a class="btn btn_login" data-clk="sug.cxlogin" href="https://nid.naver.com/nidlogin.login">로그인</a>,
#  <a class="btn btn_view" data-clk="sug.cxlink" href="https://help.naver.com/support/alias/search/word/word_16.naver" target="_blank">자세히</a>,
#  <a class="btn_close _plus_layer_close" href="#" role="button"><i class="imsc ico_close">컨텍스트 자동완성 레이어 닫기</i></a>,
#  <a data-clk="sug.help" href="https://help.naver.com/support/service/main.help?serviceNo=605&amp;categoryNo=1987" target="_blank">도움말</a>,
#  <a class="report" data-clk="sug.report" href="https://help.naver.com/support/contents/contents.help?serviceNo=605&amp;categoryNo=18215" target="_blank">신고</a>,
#  <a class="close _suggestOnOff" href="#">자동완성 끄기</a>,
#  <a class="nav" data-clk="svc.mail" href="https://mail.naver.com/"><i class="ico_mail"></i>메일</a>,
#  <a class="nav" data-clk="svc.cafe" href="https://section.cafe.naver.com/">카페</a>,
#  <a class="nav" data-clk="svc.blog" href="https://section.blog.naver.com/">블로그</a>,
#  <a class="nav" data-clk="svc.kin" href="https://kin.naver.com/">지식iN</a>,
#  <a class="nav shop" data-clk="svc.shopping" href="https://shopping.naver.com/"><span class="blind">쇼핑</span></a>,
#  <a class="nav shoplive" data-clk="svc.shoppinglive" href="https://shoppinglive.naver.com/home"><span class="blind">쇼핑LIVE</span></a>,
#  <a class="nav" data-clk="svc.pay" href="https://order.pay.naver.com/home">Pay</a>,
#  <a class="nav" data-clk="svc.tvcast" href="https://tv.naver.com/"><i class="ico_tv"></i>TV</a>,
#  <a class="nav" data-clk="svc.dic" href="https://dict.naver.com/">사전</a>,
#  <a class="nav" data-clk="svc.news" href="https://news.naver.com/">뉴스</a>,
#  <a class="nav" data-clk="svc.stock" href="https://finance.naver.com/">증권</a>,
#  <a class="nav" data-clk="svc.land" href="https://land.naver.com/">부동산</a>,
#  <a class="nav" data-clk="svc.map" href="https://map.naver.com/">지도</a>,
#  <a class="nav" data-clk="svc.vibe" href="https://vibe.naver.com/">VIBE</a>,
#  <a class="nav" data-clk="svc.book" href="https://search.shopping.naver.com/book/home">도서</a>,
#  <a class="nav" data-clk="svc.webtoon" href="https://comic.naver.com/">웹툰</a>,
#  <a class="btn_more" data-clk="svc.more" href="#" role="button">더보기</a>,
#  <a class="btn NM_FAVORITE_ALL" data-clk="map.svcmore" href="more.html">서비스 전체보기</a>,
#  <a class="btn btn_set" data-clk="map.edit" href="#" role="button">메뉴설정</a>,
#  <a class="btn btn_reset" data-clk="edt.reset" href="#" role="button">초기화</a>,
#  <a class="btn btn_save" data-clk="edt.save" href="#" role="button">저장</a>,
#  <a class="weather_area ico_w05" data-clk="squ.weat" href="https://weather.naver.com/today/09170130">
#  <div class="current_box">
#  <strong aria-label="현재기온" class="current">32.5°</strong><strong class="state">구름많음</strong>
#  </div>
#  <div class="degree_box">
#  <span aria-label="최저기온" class="min">24.0°</span><span aria-label="최고기온" class="max">33.0°</span>
#  </div>
#  <span class="location">이태원동</span>
#  </a>,
#  <a class="air_area" data-clk="squ.dust" href="https://weather.naver.com/today/09170130">
#  <ul class="list_air">
#  <li class="air_item">미세<strong class="state state_good">좋음</strong></li>
#  <li class="air_item">초미세<strong class="state state_good">좋음</strong></li>
#  </ul>
#  <span class="location">이태원동</span>
#  </a>,
#  <a class="link_media" data-clk="newsflash" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y">연합뉴스</a>,
#  <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013334288">'행안부 경찰국 신설안' 국무회의 통과…내달 2일 공포</a>,
#  <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013334689">한동훈 "사면, 대통령 고유권한…기준·방향 말하는건 부적절"</a>,
#  <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013334556">尹, 한동훈에 "부정부패 엄정대응…기업위축 과도한 형벌 개선"</a>,
#  <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013335408">한총리 "흥청망청 재정, 타이트한 재정으로…건전성 회복 목표"</a>,
#  <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013334533">국방부 "유엔사, 판문점 통과 허용한 것…북송 승인 의미 아냐"</a>,
#  <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013335089">BA.5 사실상 우세종…국내감염 검출률 49.1%, 해외 합치면 56.3%</a>,
#  <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013334570">"금리 1%p 더 오르면 대출자 97만명, 2금융권서도 밀려나"</a>,
#  <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013334595">한국인 기대수명 83.5세로 증가…외래진료 1년에 14.7번 간다</a>,
#  <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013334642">용산정비창, 초고층 복합업무지구로 탈바꿈…"롯데타워급 가능"</a>,
#  <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013335458">대우조선 경영진 "책임 통감…위기 극복하고 거취 포함 책임질 것"</a>,
#  <a class="link_news" data-clk="newshome" href="http://news.naver.com/">뉴스홈</a>,
#  <a class="link_direct" data-clk="entertainment" href="http://entertain.naver.com/home">연예</a>,
#  <a class="link_direct" data-clk="sports" href="http://sports.news.naver.com/">스포츠</a>,
#  <a class="link_direct" data-clk="economy" href="http://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101">경제</a>,
#  <a class="link_newsstand" data-clk="title" href="http://newsstand.naver.com/" target="_blank">뉴스스탠드</a>,
#  <a aria-controls="NM_NEWSSTAND_MY_LIST" aria-selected="false" class="btn_sort" data-clk="my" data-type="my" href="#" role="tab">구독한 언론사</a>,
#  <a aria-controls="NM_NEWSSTAND_DEFAULT_THUMB" aria-selected="true" class="btn_sort" data-clk="all" data-type="all" href="#" role="tab">전체언론사</a>,
#  <a aria-controls="NM_NEWSSTAND_DEFAULT_LIST" aria-selected="false" class="btn_set" data-clk="articleview" data-type="list" href="#" role="tab"> <i class="ico_list"><span class="blind">리스트형</span></i></a>,
#  <a aria-controls="NM_NEWSSTAND_DEFAULT_THUMB" aria-selected="true" class="btn_set" data-clk="pressview" data-type="thumb" href="#" role="tab"> <i class="ico_tile"><span class="blind">썸네일형</span></i></a>,
#  <a class="btn_set" data-clk="set" href="http://newsstand.naver.com/config.html" target="_blank"> <i class="ico_set"><span class="blind">설정</span></i></a>,
#  <a class="pm_btn_prev_l _NM_NEWSSTAND_LIST_prev_btn" data-clk-custom="prev" href="#" role="button"><i class="ico_btn"><span class="blind">이전</span></i></a>,
#  <a class="pm_btn_next_l _NM_NEWSSTAND_LIST_next_btn" data-clk-custom="next" href="#" role="button"><i class="ico_btn"><span class="blind">다음</span></i></a>,
#  <a class="option" data-clk="daei" href="#">종합/경제</a>,
#  <a class="option" data-clk="dtvcom" href="#">방송/통신</a>,
#  <a class="option" data-clk="dit" href="#">IT</a>,
#  <a class="option" data-clk="deng" href="#">영자지</a>,
#  <a class="option" data-clk="dsporent" href="#">스포츠/연예</a>,
#  <a class="option" data-clk="dmagtec" href="#">매거진/전문지</a>,
#  <a class="option" data-clk="dloc" href="#">지역</a>,
#  <a class="btn_close NM_NEWSSTAND_POPUP_CLOSE" href="#" role="button"><i class="ico_close"></i><span class="blind">닫기</span></a>,
#  <a class="btn_confirm NM_NEWSSTAND_POPUP_CLOSE" href="#" role="button">확인</a>,
#  <a class="btn_close NM_NEWSSTAND_POPUP_CLOSE" data-clk="usclose" href="#" role="button"><i class="ico_close"></i><span class="blind">닫기</span></a>,
#  <a class="btn_confirm NM_NEWSSTAND_POPUP_CONFIRM" data-clk="usdone" href="#" role="button">확인</a>,
#  <a class="btn_confirm NM_NEWSSTAND_POPUP_CLOSE" data-clk="uscancel" href="#" role="button">취소</a>,
#  <a class="pm_btn_prev_l _NM_UI_PAGE_PREV" data-clk-custom="prev" href="#" role="button"><i class="ico_btn"><span class="blind">이전</span></i></a>,
#  <a class="pm_btn_next_l _NM_UI_PAGE_NEXT" data-clk-custom="next" href="#" role="button"><i class="ico_btn"><span class="blind">다음</span></i></a>,
#  <a class="thumb" href="#">
#  <img alt="스포츠동아" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/314.png"/>
#  <span class="thumb_dim"></span></a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="314" href="#" role="button">구독</a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="314" href="#" role="button">해지</a>,
#  <a class="btn_popup" data-clk="logo" data-pid="314" href="http://newsstand.naver.com/?list=&amp;pcode=314" target="_blank">기사보기</a>,
#  <a class="thumb" href="#">
#  <img alt="스포탈코리아" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/139.png"/>
#  <span class="thumb_dim"></span></a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="139" href="#" role="button">구독</a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="139" href="#" role="button">해지</a>,
#  <a class="btn_popup" data-clk="logo" data-pid="139" href="http://newsstand.naver.com/?list=&amp;pcode=139" target="_blank">기사보기</a>,
#  <a class="thumb" href="#">
#  <img alt="스포츠조선" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/076.png"/>
#  <span class="thumb_dim"></span></a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="076" href="#" role="button">구독</a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="076" href="#" role="button">해지</a>,
#  <a class="btn_popup" data-clk="logo" data-pid="076" href="http://newsstand.naver.com/?list=&amp;pcode=076" target="_blank">기사보기</a>,
#  <a class="thumb" href="#">
#  <img alt="아이뉴스24" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/031.png"/>
#  <span class="thumb_dim"></span></a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="031" href="#" role="button">구독</a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="031" href="#" role="button">해지</a>,
#  <a class="btn_popup" data-clk="logo" data-pid="031" href="http://newsstand.naver.com/?list=&amp;pcode=031" target="_blank">기사보기</a>,
#  <a class="thumb" href="#">
#  <img alt="한국경제TV" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/215.png"/>
#  <span class="thumb_dim"></span></a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="215" href="#" role="button">구독</a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="215" href="#" role="button">해지</a>,
#  <a class="btn_popup" data-clk="logo" data-pid="215" href="http://newsstand.naver.com/?list=&amp;pcode=215" target="_blank">기사보기</a>,
#  <a class="thumb" href="#">
#  <img alt="마이데일리" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/117.png"/>
#  <span class="thumb_dim"></span></a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="117" href="#" role="button">구독</a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="117" href="#" role="button">해지</a>,
#  <a class="btn_popup" data-clk="logo" data-pid="117" href="http://newsstand.naver.com/?list=&amp;pcode=117" target="_blank">기사보기</a>,
#  <a aria-disabled="true" class="thumb" href="#">
#  <img alt="지지통신" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/376.png"/>
#  <span class="thumb_dim"></span>
#  </a>,
#  <a class="thumb" href="#">
#  <img alt="이데일리" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/018.png"/>
#  <span class="thumb_dim"></span></a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="018" href="#" role="button">구독</a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="018" href="#" role="button">해지</a>,
#  <a class="btn_popup" data-clk="logo" data-pid="018" href="http://newsstand.naver.com/?list=&amp;pcode=018" target="_blank">기사보기</a>,
#  <a class="thumb" href="#">
#  <img alt="헤럴드경제" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/016.png"/>
#  <span class="thumb_dim"></span></a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="016" href="#" role="button">구독</a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="016" href="#" role="button">해지</a>,
#  <a class="btn_popup" data-clk="logo" data-pid="016" href="http://newsstand.naver.com/?list=&amp;pcode=016" target="_blank">기사보기</a>,
#  <a class="thumb" href="#">
#  <img alt="데일리안" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/368.png"/>
#  <span class="thumb_dim"></span></a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="368" href="#" role="button">구독</a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="368" href="#" role="button">해지</a>,
#  <a class="btn_popup" data-clk="logo" data-pid="368" href="http://newsstand.naver.com/?list=&amp;pcode=368" target="_blank">기사보기</a>,
#  <a class="thumb" href="#">
#  <img alt="노컷뉴스" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/079.png"/>
#  <span class="thumb_dim"></span></a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="079" href="#" role="button">구독</a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="079" href="#" role="button">해지</a>,
#  <a class="btn_popup" data-clk="logo" data-pid="079" href="http://newsstand.naver.com/?list=&amp;pcode=079" target="_blank">기사보기</a>,
#  <a class="thumb" href="#">
#  <img alt="JTBC" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/904.png"/>
#  <span class="thumb_dim"></span></a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="904" href="#" role="button">구독</a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="904" href="#" role="button">해지</a>,
#  <a class="btn_popup" data-clk="logo" data-pid="904" href="http://newsstand.naver.com/?list=&amp;pcode=904" target="_blank">기사보기</a>,
#  <a class="thumb" href="#">
#  <img alt="블로터" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/293.png"/>
#  <span class="thumb_dim"></span></a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="293" href="#" role="button">구독</a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="293" href="#" role="button">해지</a>,
#  <a class="btn_popup" data-clk="logo" data-pid="293" href="http://newsstand.naver.com/?list=&amp;pcode=293" target="_blank">기사보기</a>,
#  <a class="thumb" href="#">
#  <img alt="뉴시스" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/003.png"/>
#  <span class="thumb_dim"></span></a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="003" href="#" role="button">구독</a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="003" href="#" role="button">해지</a>,
#  <a class="btn_popup" data-clk="logo" data-pid="003" href="http://newsstand.naver.com/?list=&amp;pcode=003" target="_blank">기사보기</a>,
#  <a class="thumb" href="#">
#  <img alt="오마이뉴스" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/047.png"/>
#  <span class="thumb_dim"></span></a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="047" href="#" role="button">구독</a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="047" href="#" role="button">해지</a>,
#  <a class="btn_popup" data-clk="logo" data-pid="047" href="http://newsstand.naver.com/?list=&amp;pcode=047" target="_blank">기사보기</a>,
#  <a class="thumb" href="#">
#  <img alt="머니투데이방송" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/up/2021/0420/nsd105139164.png"/>
#  <span class="thumb_dim"></span></a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="916" href="#" role="button">구독</a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="916" href="#" role="button">해지</a>,
#  <a class="btn_popup" data-clk="logo" data-pid="916" href="http://newsstand.naver.com/?list=&amp;pcode=916" target="_blank">기사보기</a>,
#  <a class="thumb" href="#">
#  <img alt="르몽드 디플로마티크" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/915.png"/>
#  <span class="thumb_dim"></span></a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="915" href="#" role="button">구독</a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="915" href="#" role="button">해지</a>,
#  <a class="btn_popup" data-clk="logo" data-pid="915" href="http://newsstand.naver.com/?list=&amp;pcode=915" target="_blank">기사보기</a>,
#  <a class="thumb" href="#">
#  <img alt="조이뉴스24" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/947.png"/>
#  <span class="thumb_dim"></span></a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="947" href="#" role="button">구독</a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="947" href="#" role="button">해지</a>,
#  <a class="btn_popup" data-clk="logo" data-pid="947" href="http://newsstand.naver.com/?list=&amp;pcode=947" target="_blank">기사보기</a>,
#  <a class="thumb" href="#">
#  <img alt="EBS" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/up/2020/0803/nsd20247547.png"/>
#  <span class="thumb_dim"></span></a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="344" href="#" role="button">구독</a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="344" href="#" role="button">해지</a>,
#  <a class="btn_popup" data-clk="logo" data-pid="344" href="http://newsstand.naver.com/?list=&amp;pcode=344" target="_blank">기사보기</a>,
#  <a class="thumb" href="#">
#  <img alt="미디어펜" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/809.png"/>
#  <span class="thumb_dim"></span></a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="809" href="#" role="button">구독</a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="809" href="#" role="button">해지</a>,
#  <a class="btn_popup" data-clk="logo" data-pid="809" href="http://newsstand.naver.com/?list=&amp;pcode=809" target="_blank">기사보기</a>,
#  <a class="thumb" href="#">
#  <img alt="베리타스알파" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/958.png"/>
#  <span class="thumb_dim"></span></a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="958" href="#" role="button">구독</a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="958" href="#" role="button">해지</a>,
#  <a class="btn_popup" data-clk="logo" data-pid="958" href="http://newsstand.naver.com/?list=&amp;pcode=958" target="_blank">기사보기</a>,
#  <a class="thumb" href="#">
#  <img alt="PC사랑" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/364.png"/>
#  <span class="thumb_dim"></span></a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="364" href="#" role="button">구독</a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="364" href="#" role="button">해지</a>,
#  <a class="btn_popup" data-clk="logo" data-pid="364" href="http://newsstand.naver.com/?list=&amp;pcode=364" target="_blank">기사보기</a>,
#  <a class="thumb" href="#">
#  <img alt="미디어스" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/up/2021/0211/nsd01153196.png"/>
#  <span class="thumb_dim"></span></a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="829" href="#" role="button">구독</a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="829" href="#" role="button">해지</a>,
#  <a class="btn_popup" data-clk="logo" data-pid="829" href="http://newsstand.naver.com/?list=&amp;pcode=829" target="_blank">기사보기</a>,
#  <a class="thumb" href="#">
#  <img alt="에너지경제" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/963.png"/>
#  <span class="thumb_dim"></span></a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="963" href="#" role="button">구독</a>,
#  <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="963" href="#" role="button">해지</a>,
#  <a class="btn_popup" data-clk="logo" data-pid="963" href="http://newsstand.naver.com/?list=&amp;pcode=963" target="_blank">기사보기</a>,
#  <a class="btn_close NM_NEWSSTAND_POPUP_CLOSE" href="#" role="button"><i class="ico_close"></i><span class="blind">닫기</span></a>,
#  <a class="btn_confirm NM_NEWSSTAND_POPUP_CLOSE" href="#" role="button">확인</a>,
#  <a class="btn_close NM_NEWSSTAND_POPUP_CLOSE" data-clk="usclose" href="#" role="button"><i class="ico_close"></i><span class="blind">닫기</span></a>,
#  <a class="btn_confirm NM_NEWSSTAND_POPUP_CONFIRM" data-clk="usdone" href="#" role="button">확인</a>,
#  <a class="btn_confirm NM_NEWSSTAND_POPUP_CLOSE" data-clk="uscancel" href="#" role="button">취소</a>,
#  <a class="pm_btn_prev_l _NM_NEWSSTAND_LIST_prev_btn" data-clk-custom="prev" href="#" role="button"><i class="ico_btn"></i><span class="blind">이전</span></a>,
#  <a class="pm_btn_next_l _NM_NEWSSTAND_LIST_next_btn" data-clk-custom="next" href="#" role="button"><i class="ico_btn"></i><span class="blind">다음</span><span class="blind">다음</span></a>,
#  <a class="btn_close NM_NEWSSTAND_POPUP_CLOSE" href="#" role="button"><i class="ico_close"></i><span class="blind">닫기</span></a>,
#  <a class="btn_confirm NM_NEWSSTAND_POPUP_CLOSE" href="#" role="button">확인</a>,
#  <a class="btn_close NM_NEWSSTAND_POPUP_CLOSE" data-clk="usclose" href="#" role="button"><i class="ico_close"></i><span class="blind">닫기</span></a>,
#  <a class="btn_confirm NM_NEWSSTAND_POPUP_CONFIRM" data-clk="usdone" href="#" role="button">확인</a>,
#  <a class="btn_confirm NM_NEWSSTAND_POPUP_CLOSE" data-clk="uscancel" href="#" role="button">취소</a>,
#  <a class="pm_btn_prev_l _NM_UI_PAGE_PREV" data-clk-custom="prev" href="#" role="button"><i class="ico_btn"><span class="blind">이전</span></i></a>,
#  <a class="pm_btn_next_l _NM_UI_PAGE_NEXT" data-clk-custom="next" href="#" role="button"><i class="ico_btn"><span class="blind">다음</span></i></a>,
#  <a class="btn_close NM_NEWSSTAND_POPUP_CLOSE" href="#" role="button"><i class="ico_close"></i><span class="blind">닫기</span></a>,
#  <a class="btn_confirm NM_NEWSSTAND_POPUP_CLOSE" href="#" role="button">확인</a>,
#  <a class="btn_close NM_NEWSSTAND_POPUP_CLOSE" data-clk="usclose" href="#" role="button"><i class="ico_close"></i><span class="blind">닫기</span></a>,
#  <a class="btn_confirm NM_NEWSSTAND_POPUP_CONFIRM" data-clk="usdone" href="#" role="button">확인</a>,
#  <a class="btn_confirm NM_NEWSSTAND_POPUP_CLOSE" data-clk="uscancel" href="#" role="button">취소</a>,
#  <a class="link_redirect" href="http://newsstand.naver.com/config.html" target="_blank">언론사 구독 설정하기</a>,
#  <a class="btn_set" data-clk="tca.like" href="#" id="NM_THEME_EDIT_SET" role="button">관심주제 설정</a>,
#  <a class="pm_btn_prev NM_THEME_PREV" data-clk="tct.prev" href="#" role="button" style="display: none;">
#  <i class="ico_btn"><span class="blind">이전</span></i>
#  </a>,
#  <a class="pm_btn_next NM_THEME_NEXT" data-clk="tct.next" href="#" role="button" style="display: none;">
#  <i class="ico_btn"><span class="blind">다음</span></i>
#  </a>,
#  <a aria-controls="NM_THEME_CONTAINER" aria-selected="false" class="_NM_THEME_CATE tab id_enter" data-clk="tct.tvc" data-panel-code="ENTER" href="#" role="tab">엔터</a>,
#  <a aria-controls="NM_THEME_CONTAINER" aria-selected="false" class="_NM_THEME_CATE tab id_sports" data-clk="tct.spo" data-panel-code="SPORTS" href="#" role="tab">스포츠</a>,
#  <a aria-controls="NM_THEME_CONTAINER" aria-selected="false" class="_NM_THEME_CATE tab id_cargame" data-clk="tct.aut" data-panel-code="CARGAME" href="#" role="tab">자동차</a>,
#  <a aria-controls="NM_THEME_CONTAINER" aria-selected="false" class="_NM_THEME_CATE tab id_bboom" data-clk="tct.web" data-panel-code="BBOOM" href="#" role="tab">웹툰</a>,
#  <a aria-controls="NM_THEME_CONTAINER" aria-selected="false" class="_NM_THEME_CATE tab id_finance" data-clk="tct.fin" data-panel-code="FINANCE" href="#" role="tab">경제</a>,
#  <a aria-controls="NM_THEME_CONTAINER" aria-selected="false" class="_NM_THEME_CATE tab id_myfeed" data-clk="tct.sub" data-panel-code="MYFEED" href="#" role="tab">추천<span class="ico_middot"></span>구독</a>,
#  <a aria-controls="NM_THEME_CONTAINER" aria-selected="true" class="_NM_THEME_CATE tab id_living" data-clk="tct.fod" data-panel-code="LIVING" href="#" role="tab">레시피</a>,
#  <a aria-controls="NM_THEME_CONTAINER" aria-selected="false" class="_NM_THEME_CATE tab id_livinghome" data-clk="tct.lif" data-panel-code="LIVINGHOME" href="#" role="tab">리빙</a>,
#  <a aria-controls="NM_THEME_CONTAINER" aria-selected="false" class="_NM_THEME_CATE tab id_culture" data-clk="tct.bok" data-panel-code="CULTURE" href="#" role="tab">책방</a>,
#  <a aria-controls="NM_THEME_CONTAINER" aria-selected="false" class="_NM_THEME_CATE tab id_beauty" data-clk="tct.bty" data-panel-code="BEAUTY" href="#" role="tab">패션뷰티</a>,
#  <a class="topstory_thumb" data-clk="tcc_fod.navertv" href="https://tv.naver.com/v/27989423" target="_blank">
#  <img alt="은근 쉽게 만들 수 있는 소떡소떡 떡 강정" data-src="https://s.pstatic.net/static/www/mobile/edit/20220725/cropImg_728x360_100674068162448960.jpeg" height="180" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" src="https://s.pstatic.net/static/www/mobile/edit/20220725/cropImg_728x360_100674068162448960.jpeg" width="364"/>
#  <span class="thumb_dim"></span>
#  <span class="thumb_bd"></span>
#  <i class="pm_ico_play"><span class="blind">재생</span></i>
#  <span class="theme_runtime">
#  <span class="runtime_bg">재생시간</span>
#  <em class="time">1:53</em>
#  </span>
#  </a>,
#  <a class="topstory_info" data-clk="tcc_fod.navertvtitle" href="https://tv.naver.com/v/27989423" target="_blank">
#  <em class="theme_category">[오늘의 푸드TV] 냠냠간단요리	</em>
#  <strong class="title">은근 쉽게 만들 수 있는 소떡소떡 떡 강정</strong>
#  <p class="desc">바삭하게 구워도 말랑하게 구워도 OK <br/>입에 착 붙는 양념장만 있으면 꿀맛</p>
#  <div class="source_area">
#  <span class="source"><span class="source_inner">#비엔나소시지 #간단요리</span></span>
#  </div>
#  </a>,
#  <a class="topstory_thumb" data-clk="tcc_fod.navertv" href="https://tv.naver.com/v/27958347" target="_blank">
#  <img alt="전복 삼계탕 먹고 1시간 내로 힘이 불끈! " data-src="https://s.pstatic.net/static/www/mobile/edit/20220722/cropImg_728x360_100405849459930880.jpeg" height="180" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" src="https://s.pstatic.net/static/www/mobile/edit/20220722/cropImg_728x360_100405849459930880.jpeg" width="364"/>
#  <span class="thumb_dim"></span>
#  <span class="thumb_bd"></span>
#  <i class="pm_ico_play"><span class="blind">재생</span></i>
#  <span class="theme_runtime">
#  <span class="runtime_bg">재생시간</span>
#  <em class="time">4:06</em>
#  </span>
#  </a>,
#  <a class="topstory_info" data-clk="tcc_fod.navertvtitle" href="https://tv.naver.com/v/27958347" target="_blank">
#  <em class="theme_category">[오늘의 푸드TV] 윤이련 50년 요리비결	</em>
#  <strong class="title">전복 삼계탕 먹고 1시간 내로 힘이 불끈! </strong>
#  <p class="desc">마늘과 대파로 풍미까지 살리기  <br/>닭은 너무 오래 익히면 쫄깃함이 떨어져요</p>
#  <div class="source_area">
#  <span class="source"><span class="source_inner">#보양식 #중복요리</span></span>
#  </div>
#  </a>,
#  <a class="theme_thumb" data-clk="tcc_fod.list1cont1" href="https://blog.naver.com/ostwee/222792136786" target="_blank">
#  <img alt="작은 크기의 전복 더 키우지 않고 파는 이유" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20220721_1095%2Fupload_1658395129768zIYkm.jpg%22&amp;type=nf340_228" height="114" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20220721_1095%2Fupload_1658395129768zIYkm.jpg%22&amp;type=nf340_228" width="170"/>
#  <span class="thumb_bd"></span>
#  </a>,
#  <a class="theme_info" data-clk="tcc_fod.list1cont1" href="https://blog.naver.com/ostwee/222792136786" target="_blank">
#  <em class="theme_category"> 레시피</em>
#  <strong class="title elss">작은 크기의 전복 더 키우지 않고 파는 이유</strong>
#  <p class="desc">최근 저희가 양식장에 많이 남아있는 특정 크기의 전복을 저렴하게 판매했는데요, 그 이유에 대해 많은 분이 관심 어린 질문을 해주셨습니다. 전복은 클수록 비싼데 왜 키워서 파는 게 더 손해일까요? 이유를 설명해 드리기 이전에 전복이 어떻게 키워지고 판매되는지부터 아셔야 합니다. 전복의 유통은 크게 3단계인데요, 양식장에서 전복을 키우고 산지 유통사가 그 전복</p>
#  <div class="source_box">
#  <span class="date">3주일 전</span>
#  <span class="source">
#  <span class="source_inner">인어교주해적단</span>
#  </span>
#  </div>
#  </a>,
#  <a class="theme_thumb" data-clk="tcc_fod.list1cont2" href="https://blog.naver.com/bsy615/222744901607" target="_blank">
#  <img alt="아롱사태 수육 만들기 소스 소고기 사태 수육 요리 압력솥 수육 삶기 손님초대요리" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20220720_1095%2Fupload_1658307440518OlwCB.JPEG%22&amp;type=nf340_228" height="114" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20220720_1095%2Fupload_1658307440518OlwCB.JPEG%22&amp;type=nf340_228" width="170"/>
#  <span class="thumb_bd"></span>
#  </a>,
#  <a class="theme_info" data-clk="tcc_fod.list1cont2" href="https://blog.naver.com/bsy615/222744901607" target="_blank">
#  <em class="theme_category"> 레시피</em>
#  <strong class="title elss">아롱사태 수육 만들기 소스 소고기 사태 수육 요리 압력솥 수육 삶기 손님초대요리</strong>
#  <p class="desc">지난번에 #아롱사태수육 만든 걸 큰언니가 보고 계속 먹고 싶다고 했었어요. 이마트에 갔다가 눈에 들어오길래 사 들고 왔답니다. 제주도 온 김에 만들어주고 가야지요. #압력밥솥수육삶기 로 조금 더 쉽고 간단하게 만들 수 있고요. 시간도 얼마 걸리지 않고 반응이 너무들 좋아서 괜히 어깨가 쓱 올라가는 요리랍니다. 손님 초대요리로 너무 좋고 생색내기도 좋아요. </p>
#  <div class="source_box">
#  <span class="date">2개월 전</span>
#  <span class="source">
#  <span class="source_inner">졸리</span>
#  </span>
#  </div>
#  </a>,
#  <a class="theme_thumb" data-clk="tcc_fod.list1cont3" href="https://blog.naver.com/baby0817/222798277697" target="_blank">
#  <img alt="소갈비탕끓이는법 박수받은 갈비탕 끓이는법 여름 보양식 오늘 저녁메뉴 추천" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20220725_1095%2Fupload_1658740418123hU5pm.JPEG%22&amp;type=nf340_228" height="114" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20220725_1095%2Fupload_1658740418123hU5pm.JPEG%22&amp;type=nf340_228" width="170"/>
#  <span class="thumb_bd"></span>
#  </a>,
#  <a class="theme_info" data-clk="tcc_fod.list1cont3" href="https://blog.naver.com/baby0817/222798277697" target="_blank">
#  <em class="theme_category"> 레시피</em>
#  <strong class="title elss">소갈비탕끓이는법 박수받은 갈비탕 끓이는법 여름 보양식 오늘 저녁메뉴 추천</strong>
#  <p class="desc">소갈비탕끓이는법 박수받은 츄츄표 갈비탕 끓이는법 오늘 저녁메뉴 추천 여름 보양식 더운 여름에 이열치열 또 에너지를 팍 내기 위해서는 주말에 맛있는 여름 보양식을 챙겨드셔야 하는데요. 오랜만에 가족들 여름보양식으로 소갈비탕끓이는법 올려볼게요. 아침에 아주 개운하게 한그릇씩 먹었답니다. 어찌나 다들 잘먹는지요. 숌이도 국물에 밥을 말아서 먹였다죠 :) 크~ 이</p>
#  <div class="source_box">
#  <span class="date">3주일 전</span>
#  <span class="source">
#  <span class="source_inner">꼬마츄츄</span>
#  </span>
#  </div>
#  </a>,
#  <a class="theme_thumb" data-clk="tcc_fod.list1cont4" href="https://blog.naver.com/lalacucina/222759721621" target="_blank">
#  <img alt="묵은지 감자탕 끓이는법 레시피 뼈해장국 뼈다귀 해장국 만들기" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20220725_1095%2Fupload_1658740463251VA1MZ.jpg%22&amp;type=nf340_228" height="114" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20220725_1095%2Fupload_1658740463251VA1MZ.jpg%22&amp;type=nf340_228" width="170"/>
#  <span class="thumb_bd"></span>
#  </a>,
#  <a class="theme_info" data-clk="tcc_fod.list1cont4" href="https://blog.naver.com/lalacucina/222759721621" target="_blank">
#  <em class="theme_category"> 레시피</em>
#  <strong class="title elss">묵은지 감자탕 끓이는법 레시피 뼈해장국 뼈다귀 해장국 만들기</strong>
#  <p class="desc">묵은지 감자탕끓이는법 감자탕 뼈해장국 감자탕레시피 묵은지감자탕 뼈다귀해장국 만들기 안녕하세요 즐거운 주말 보내고 계신가요? 날씨가 엄청 더워졌어요 그럼에도 불구하고 ㅎ 저는 냉동실에 있던 돼지등뼈를 정리할 겸 감자탕 끓여보았어요 겨울에도 먹지만 여름에도 보양식 같은 느낌으로 만들어 먹으면 푸짐해서 종종 만들게 됩니다 무엇보다 가격도 저렴하고 부드럽게 쏙..</p>
#  <div class="source_box">
#  <span class="date">1개월 전</span>
#  <span class="source">
#  <span class="source_inner">레지나</span>
#  </span>
#  </div>
#  </a>,
#  <a class="media_area" data-clk="tcc_fod.video1cont1" data-gdid="CAS_9a4abbfc-08e7-11ed-afb7-73c4099a557d" href="https://tv.naver.com/v/27693830" target="_blank">
#  <div class="media_thumb">
#  <img alt="" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20220721_1095%2Fupload_1658402718674uQY9Y.JPEG%22&amp;type=nf464_260" height="130" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20220721_1095%2Fupload_1658402718674uQY9Y.JPEG%22&amp;type=nf464_260" width="232"/>
#  <span class="thumb_dim"></span>
#  <span class="thumb_bd"></span>
#  <i class="pm_ico_play"><span class="blind">재생</span></i>
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">02:00</em></span>
#  </div>
#  <div class="media_info">
#  <div class="info_box">
#  <strong class="title">누가 만들어도 실패 없는 대파 토스트</strong>
#  <div class="source_wrap">
#  <span class="date">3주일 전</span>
#  <span class="source">
#  <span class="source_inner">냠냠간단요리</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </a>,
#  <a class="media_area" data-clk="tcc_fod.video1cont2" data-gdid="CAS_3b35b077-065e-11ed-84df-9742a3d64f94" href="https://tv.naver.com/v/15350532" target="_blank">
#  <div class="media_thumb">
#  <img alt="" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20220718_1095%2Fupload_1658124537724nTL1m.JPEG%22&amp;type=nf464_260" height="130" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20220718_1095%2Fupload_1658124537724nTL1m.JPEG%22&amp;type=nf464_260" width="232"/>
#  <span class="thumb_dim"></span>
#  <span class="thumb_bd"></span>
#  <i class="pm_ico_play"><span class="blind">재생</span></i>
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">07:11</em></span>
#  </div>
#  <div class="media_info">
#  <div class="info_box">
#  <strong class="title">유통기한은 숫자일 뿐! 버터의 모든 것</strong>
#  <div class="source_wrap">
#  <span class="date">1년 전</span>
#  <span class="source">
#  <span class="source_inner">백년밥상TV</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </a>,
#  <a class="media_area" data-clk="tcc_fod.video1cont3" data-gdid="CAS_3b35b076-065e-11ed-84df-5188f5b1299e" href="https://m.tv.naver.com/v/24526478" target="_blank">
#  <div class="media_thumb">
#  <img alt="" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20220718_1095%2Fupload_1658124908696ofStz.JPEG%22&amp;type=nf464_260" height="130" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20220718_1095%2Fupload_1658124908696ofStz.JPEG%22&amp;type=nf464_260" width="232"/>
#  <span class="thumb_dim"></span>
#  <span class="thumb_bd"></span>
#  <i class="pm_ico_play"><span class="blind">재생</span></i>
#  <span class="theme_runtime"><span class="runtime_bg">재생시간</span><em class="time">10:13</em></span>
#  </div>
#  <div class="media_info">
#  <div class="info_box">
#  <strong class="title">건강한 닭 요리를 위해 꼭 알아 두세요</strong>
#  <div class="source_wrap">
#  <span class="date">6개월 전</span>
#  <span class="source">
#  <span class="source_inner">백년밥상TV</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </a>,
#  <a class="theme_thumb" data-clk="tcc_fod.list2cont1" href="https://blog.naver.com/dasomammy/222827639555" target="_blank">
#  <img alt="해천탕 레시피, 중복맞이 해신탕 만드는 법" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20220725_1095%2Fupload_1658732396633C5fAV.JPEG%22&amp;type=nf340_228" height="114" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20220725_1095%2Fupload_1658732396633C5fAV.JPEG%22&amp;type=nf340_228" width="170"/>
#  <span class="thumb_bd"></span>
#  </a>,
#  <a class="theme_info" data-clk="tcc_fod.list2cont1" href="https://blog.naver.com/dasomammy/222827639555" target="_blank">
#  <em class="theme_category"> 레시피</em>
#  <strong class="title elss">해천탕 레시피, 중복맞이 해신탕 만드는 법</strong>
#  <p class="desc">지난 초복에 만들어 먹은 요리를 중복에 맞춰 소개하는 나름 의도적이고 계획적인 포스팅 ㅋㅋㅋ 복날이 아니라도 무더위에 지치기 쉬울때 보양해주시는 음식 한번 먹음 또 기운이 나고 그러잖아요. 끓이느라 좀 덥긴 하지만 또 잘 먹고 나면 기운 팔팔 나는 그런 요리. 이번 중복엔 그냥 삼계탕 말고 귀한 해물 듬뿍 넣은 해천탕 만들어 드세요^^ 해물이라고 새우. 전</p>
#  <div class="source_box">
#  <span class="date">어제</span>
#  <span class="source">
#  <span class="source_inner">다소마미</span>
#  </span>
#  </div>
#  </a>,
#  <a class="theme_thumb" data-clk="tcc_fod.list2cont2" href="https://blog.naver.com/xxoung75/222826723483" target="_blank">
#  <img alt="백종원 닭볶음탕 레시피 닭요리 쉽게 해요." data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20220725_1095%2Fupload_16587401628558khlr.jpg%22&amp;type=nf340_228" height="114" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20220725_1095%2Fupload_16587401628558khlr.jpg%22&amp;type=nf340_228" width="170"/>
#  <span class="thumb_bd"></span>
#  </a>,
#  <a class="theme_info" data-clk="tcc_fod.list2cont2" href="https://blog.naver.com/xxoung75/222826723483" target="_blank">
#  <em class="theme_category"> 레시피</em>
#  <strong class="title elss">백종원 닭볶음탕 레시피 닭요리 쉽게 해요.</strong>
#  <p class="desc">화요일이 중복이네요. 올해는 삼계탕보다 닭볶음탕이 먹고 싶다고 주문하는 우리집 아가씨들.. 그래서 이번에 닭 넉넉하게 준비했습니다. 2팩을 사서 한냄비 푸짐하게 끓였습니다. 신랑 좋아하는 감자 듬뿍 넣고요. 떡도 좀 넣어서 끓여줬더니 가족모두 잘먹네요. 주말에 가족 모두 다함께 먹으려고 준비해서 만들어 먹었습니다 ^^ 제가 좋아하는 백종원 레시피로 만들었습</p>
#  <div class="source_box">
#  <span class="date">2일 전</span>
#  <span class="source">
#  <span class="source_inner">철든철부지</span>
#  </span>
#  </div>
#  </a>,
#  <a class="theme_thumb" data-clk="tcc_fod.list2cont3" href="https://blog.naver.com/chyung1505/222799302052" target="_blank">
#  <img alt="빨간삼계탕 압력솥에~ 얼큰 시원한 이찬원 여름보양식 레시피" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20220725_1095%2Fupload_1658740325406JVX77.jpg%22&amp;type=nf340_228" height="114" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20220725_1095%2Fupload_1658740325406JVX77.jpg%22&amp;type=nf340_228" width="170"/>
#  <span class="thumb_bd"></span>
#  </a>,
#  <a class="theme_info" data-clk="tcc_fod.list2cont3" href="https://blog.naver.com/chyung1505/222799302052" target="_blank">
#  <em class="theme_category"> 레시피</em>
#  <strong class="title elss">빨간삼계탕 압력솥에~ 얼큰 시원한 이찬원 여름보양식 레시피</strong>
#  <p class="desc">으.... 더워요! 더워... +.+ 더위를 참 잘 견디는 1인이었는데~ 어느 순간부터 왜이리 힘든 것인지! 심지어 요즘 장마철이라 습도까지 높으니 정말 불쾌지수가 대에박~입니다. 뭔가 자꾸 기운이 빠지는 느낌이라 여름보양식 제대로 챙겨봐야겠다 싶더라고요. 지난 번 편스토랑에서 이찬원 찬또레시피로 빨간삼계탕이 나왔는데 그 때 보면서 이건 무조건이다 싶었거든</p>
#  <div class="source_box">
#  <span class="date">3주일 전</span>
#  <span class="source">
#  <span class="source_inner">줌마파워</span>
#  </span>
#  </div>
#  </a>,
# ...
#  <span class="thumb_bd"></span>
#  </a>,
#  <a class="theme_info" data-clk="tcc_fod.list11cont1" href="https://blog.naver.com/wdjkahn/222799300563" target="_blank">
#  <em class="theme_category"> 레시피</em>
#  <strong class="title elss">초계국수 만드는법 간단 육수 시원한 여름별미 보양식 만들기.</strong>
#  <p class="desc">초계국수 만드는법 간단 육수 시원한 여름별미 여름 보양식 만들기. 무더운 더위가 계속되고 있는 한여름이예요. 입맛도 없고 기운도 없고요, 하루 종일 커피만 마시는 것 같아요. 이러다가 지쳐 쓰러지지 않을까??^^;; 힝. 집 나간 여름 입맛을 다시 델꼬 들어오려면 별미식이 꼭 필요해요. 맨날맨날 먹는 쌀밥에 입맛이 집을 나간거라, 밥 대신 새콤달콤 입맛 살</p>
#  <div class="source_box">
#  <span class="date">3주일 전</span>
#  <span class="source">
#  <span class="source_inner">세가지꿈</span>
#  </span>
#  </div>
#  </a>,
#  <a class="theme_thumb" data-clk="tcc_fod.list11cont2" href="https://post.naver.com/viewer/postView.naver?volumeNo=34117405&amp;memberNo=15460571" target="_blank">
#  <img alt="편의점에서 만나는 특이한 아이스크림" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20220721_1095%2Fupload_1658399839259Lc135.JPEG%22&amp;type=nf340_228" height="114" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" width="170"/>
#  <span class="thumb_bd"></span>
#  </a>,
#  <a class="theme_info" data-clk="tcc_fod.list11cont2" href="https://post.naver.com/viewer/postView.naver?volumeNo=34117405&amp;memberNo=15460571" target="_blank">
#  <em class="theme_category"> 레시피</em>
#  <strong class="title elss">편의점에서 만나는 특이한 아이스크림</strong>
#  <p class="desc">특이한 아이스크림 아이스크림 성수기인 여름철을 맞아, 다양한 빙과류 제품이 쏟아지고 있다. 워낙 경쟁이 치열하다 보니, 빙과류 시장에서도 다른 제품과는 다른 특징을 내세우기 위해 다양한 시도가 이어지는 상황이다. 특이한 콘셉트를 통해 소비자의 눈길을 잡고, 흉내 낼 수 없는 독특한 맛으로 충격을 주는 제품들이 늘어나고 있는 것이다. 지금부터는 편의점에서 만</p>
#  <div class="source_box">
#  <span class="date">1주일 전</span>
#  <span class="source">
#  <span class="source_inner">데일리</span>
#  </span>
#  </div>
#  </a>,
#  <a class="theme_thumb" data-clk="tcc_fod.list11cont3" href="https://blog.naver.com/yel_1004/222766550036" target="_blank">
#  <img alt="팽이버섯 베이컨 말이 만들기 새우까지 돌돌 말아봤어요" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20220721_1095%2Fupload_1658399045143Loa9b.jpg%22&amp;type=nf340_228" height="114" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" width="170"/>
#  <span class="thumb_bd"></span>
#  </a>,
#  <a class="theme_info" data-clk="tcc_fod.list11cont3" href="https://blog.naver.com/yel_1004/222766550036" target="_blank">
#  <em class="theme_category"> 레시피</em>
#  <strong class="title elss">팽이버섯 베이컨 말이 만들기 새우까지 돌돌 말아봤어요</strong>
#  <p class="desc">안녕하세요~~ 오늘 저녁에 아니, ㅎㅎ 밤에 소개할 레시피는 술안주로 좋은 팽이버섯 베이컨 말이입니다. 오전에 급 번개로 나가서 맛난 음식도 먹고 카페까지 다녀왔더니~~ 저도 모르게 피곤했나 봐요. 저녁 이후부터 지금까지 침대 위에서 뒹굴뒹굴하다가 이제야 일어났어요 ㅎㅎㅎ 암튼 며칠 전에 만들어 먹은 팽이버섯 베이컨 말이는 짭조름하면서도 고소하고 쫄깃한 식</p>
#  <div class="source_box">
#  <span class="date">1개월 전</span>
#  <span class="source">
#  <span class="source_inner">소국</span>
#  </span>
#  </div>
#  </a>,
#  <a class="theme_thumb" data-clk="tcc_fod.list11cont4" href="https://blog.naver.com/jinsung0009/222767556192" target="_blank">
#  <img alt="닭꼬치 만들기 닭다리살로 대파만 있으면 OK!" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20220721_1095%2Fupload_1658399084568etbfy.jpg%22&amp;type=nf340_228" height="114" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" width="170"/>
#  <span class="thumb_bd"></span>
#  </a>,
#  <a class="theme_info" data-clk="tcc_fod.list11cont4" href="https://blog.naver.com/jinsung0009/222767556192" target="_blank">
#  <em class="theme_category"> 레시피</em>
#  <strong class="title elss">닭꼬치 만들기 닭다리살로 대파만 있으면 OK!</strong>
#  <p class="desc">나름 바쁘고 알차게 보낸 하루. 잠시 커피 한 잔의 여유가 필요한 시간입니다. 사실 커피 한 잔보다는 낮잠 자기에 딱 적당한 시간이긴 한데 말이죵. ㅎ 낮잠은 잘만한 상황이 안되니 커피로 만족해야겠어요. 나름 힐링의 시간. 내일이 주말이라는 것만으로도 맘이 편해집니다. 오늘은 닭꼬치 만들기를 올려봅니다. 집에서 종종 만들기는 하는데 주로 소스는 시판 데리야</p>
#  <div class="source_box">
#  <span class="date">1개월 전</span>
#  <span class="source">
#  <span class="source_inner">꿈꾸는지니</span>
#  </span>
#  </div>
#  </a>,
#  <a class="theme_thumb" data-clk="tcc_fod.list11cont5" href="https://blog.naver.com/beluga11/222785542674" target="_blank">
#  <img alt="소고기육전만드는법 육전 부위 및 소스 막걸리 안주" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20220721_1095%2Fupload_1658399147802dTm0t.jpg%22&amp;type=nf340_228" height="114" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" width="170"/>
#  <span class="thumb_bd"></span>
#  </a>,
#  <a class="theme_info" data-clk="tcc_fod.list11cont5" href="https://blog.naver.com/beluga11/222785542674" target="_blank">
#  <em class="theme_category"> 레시피</em>
#  <strong class="title elss">소고기육전만드는법 육전 부위 및 소스 막걸리 안주</strong>
#  <p class="desc">이번엔 제가 자주 만들어 먹는 막걸리 안주 소고기육전만드는법 소개입니다 만들기 간단하고 맛도 좋은데다 식단조절이 필요할 때 딱 맞는 요리라 파채와 함께 곁들여 먹는 걸 좋아하지만 요즘 날씨가 더워져서 그런지 파채까지 만드는 건 조금 귀찮기도 해서 간단하게 소스를 만들어 곁들였답니다 파채와 궁합이 참 좋은 메뉴이긴 하지만 간장 양념에 같이 먹어도 넘 맛나더라</p>
#  <div class="source_box">
#  <span class="date">1개월 전</span>
#  <span class="source">
#  <span class="source_inner">벨루가</span>
#  </span>
#  </div>
#  </a>,
#  <a class="theme_thumb" data-clk="tcc_fod.list12cont1" href="https://blog.naver.com/hsk0328/222796491738" target="_blank">
#  <img alt="비빔만두 만들기 양념장 버무린 냉동만두 요리! 집에서 맥주안주 추천 양념만두" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20220721_1095%2Fupload_1658399071794uLWW8.jpg%22&amp;type=nf340_228" height="114" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" width="170"/>
#  <span class="thumb_bd"></span>
#  </a>,
#  <a class="theme_info" data-clk="tcc_fod.list12cont1" href="https://blog.naver.com/hsk0328/222796491738" target="_blank">
#  <em class="theme_category"> 레시피</em>
#  <strong class="title elss">비빔만두 만들기 양념장 버무린 냉동만두 요리! 집에서 맥주안주 추천 양념만두</strong>
#  <p class="desc">비빔만두 만들기 양념장 버무린 냉동만두 요리! 집에서 맥주안주 추천 양념만두 레시피 남편이 스무 살 초반 시절에 새벽에 친구들과 분식집에서 만나 비빔만두 혹은 정식을 종종 먹었었다고 해요. 새콤달콤한 비빔만두 양념장 맛과 아삭아삭한 오이, 양배추 식감이 생각날 때면 언제든 먹으러 갔다 하더라고요. 남편의 추억의 요리라 자주 만들어 주고 있어요. 자주 만들어</p>
#  <div class="source_box">
#  <span class="date">3주일 전</span>
#  <span class="source">
#  <span class="source_inner">미소순이</span>
#  </span>
#  </div>
#  </a>,
#  <a class="theme_thumb" data-clk="tcc_fod.list12cont2" href="https://blog.naver.com/dhdmsdo79/222743564925" target="_blank">
#  <img alt="콘치즈만드는법 양파가 신의 한수 콘치즈 레시피" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20220721_1095%2Fupload_1658399618853jSLhD.jpg%22&amp;type=nf340_228" height="114" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" width="170"/>
#  <span class="thumb_bd"></span>
#  </a>,
#  <a class="theme_info" data-clk="tcc_fod.list12cont2" href="https://blog.naver.com/dhdmsdo79/222743564925" target="_blank">
#  <em class="theme_category"> 레시피</em>
#  <strong class="title elss">콘치즈만드는법 양파가 신의 한수 콘치즈 레시피</strong>
#  <p class="desc">안녕하세요. 제시예요. 우리 집 비상식량 중 하나가 통조림옥수수랍니다. 신랑이 좋아해서 요건 떨어지지 않고 식량창고에 한두 개는 꼭 채워놓고 있는 식재료 중 하나에요. 종종 콘 샐러드도 만들어주고 콘치즈피자도 만들어주고 가장 많이 만들어주는 건 콘치즈랍니다. 간단하면서~ 맛도 좋아 저도 주말 간식으로 자주 만들어 주곤 해요. 자주 만들어주다 보니 이렇게도 </p>
#  <div class="source_box">
#  <span class="date">1개월 전</span>
#  <span class="source">
#  <span class="source_inner">제시</span>
#  </span>
#  </div>
#  </a>,
#  <a class="theme_thumb" data-clk="tcc_fod.list12cont3" href="https://blog.naver.com/jasmin7141/222760199577" target="_blank">
#  <img alt="삼겹살배추찜 만들기 화이트와인 대패삼겹 배추술찜 w. 간장 소스" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20220721_1095%2Fupload_16583995667769bcPq.JPEG%22&amp;type=nf340_228" height="114" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" width="170"/>
#  <span class="thumb_bd"></span>
#  </a>,
#  <a class="theme_info" data-clk="tcc_fod.list12cont3" href="https://blog.naver.com/jasmin7141/222760199577" target="_blank">
#  <em class="theme_category"> 레시피</em>
#  <strong class="title elss">삼겹살배추찜 만들기 화이트와인 대패삼겹 배추술찜 w. 간장 소스</strong>
#  <p class="desc">삼겹살배추찜 만들기 화이트와인 대패삼겹 배추술찜 w. 간장 소스 달달한 알배추와 대패삼겹살, 화이트와인으로 만드는 간단한 삼겹살 배추술찜 이에요. 예전에 정재형님이 방송에서 만들었던 레시피가 마음에 들어서 먹고 싶을 때 가끔 먹고 있어요. ㅎㅎ 만드는법도 너무 간단하고 풍미도 좋고 야채와 고기를 듬뿍 먹을 수 있어서 좋아해요. 화이트와인의 풍미가 베여서 고</p>
#  <div class="source_box">
#  <span class="date">1개월 전</span>
#  <span class="source">
#  <span class="source_inner">낭랑주부</span>
#  </span>
#  </div>
#  </a>,
#  <a class="theme_thumb" data-clk="tcc_fod.list12cont4" href="https://blog.naver.com/cooklhj/222791660556" target="_blank">
#  <img alt="두부김치 만드는법 돼지고기 김치볶음" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20220721_1095%2Fupload_1658399139710t1q6U.jpg%22&amp;type=nf340_228" height="114" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" width="170"/>
#  <span class="thumb_bd"></span>
#  </a>,
#  <a class="theme_info" data-clk="tcc_fod.list12cont4" href="https://blog.naver.com/cooklhj/222791660556" target="_blank">
#  <em class="theme_category"> 레시피</em>
#  <strong class="title elss">두부김치 만드는법 돼지고기 김치볶음</strong>
#  <p class="desc">두부김치 만드는법 돼지고기 김치볶음 냉장고에 두부가 있는걸 보고 두부조림할까 하다가~ 간장불고기 만들어 먹고 남은 돼지고기가 조금 있어서 두부김치로 메뉴변경~ 소싯적 술안주로 즐겨먹던 두부김치와 돼지고기김치볶음 맛나게 만들었습니다. 김치가 짠데, 돼지고기에 양념까지 해서 볶으면 간이 너무 세질거에요. 김치의 염도에 따라 돼지고기의 양념이 달라지니 이점 참.</p>
#  <div class="source_box">
#  <span class="date">4주일 전</span>
#  <span class="source">
#  <span class="source_inner">잠꾸러기</span>
#  </span>
#  </div>
#  </a>,
#  <a class="theme_thumb" data-clk="tcc_fod.list12cont5" href="https://blog.naver.com/pookybebe/222792741784" target="_blank">
#  <img alt="여름별미요리 초당옥수수 치즈 김치전 만드는 법 김치부침개 레시피" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20220721_1095%2Fupload_1658399161332aySgP.jpg%22&amp;type=nf340_228" height="114" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" width="170"/>
#  <span class="thumb_bd"></span>
#  </a>,
#  <a class="theme_info" data-clk="tcc_fod.list12cont5" href="https://blog.naver.com/pookybebe/222792741784" target="_blank">
#  <em class="theme_category"> 레시피</em>
#  <strong class="title elss">여름별미요리 초당옥수수 치즈 김치전 만드는 법 김치부침개 레시피</strong>
#  <p class="desc">여름별미 제철 초당옥수수 치즈 김치의 조합 초당옥수수 치즈김치전 만드는 법 (김치부침개 레시피) 글 사진 영상 푸키베베 #초당옥수수치즈김치전 #치즈김치전 #김치부침개레시피 #여름별미 #초당옥수수요리 #전요리 #김치요리 #치즈요리 초당옥수수 치즈 김치전 김치전 recipe 왔습니다~ 왔어요. 제가 이맘때 꼭 주문해서 먹는 #초당옥수수 의 계절이 왔어요. 초당</p>
#  <div class="source_box">
#  <span class="date">3주일 전</span>
#  <span class="source">
#  <span class="source_inner">푸키베베</span>
#  </span>
#  </div>
#  </a>,
#  <a class="link_login" data-clk="log_off.login" href="https://nid.naver.com/nidlogin.login?mode=form&amp;url=https%3A%2F%2Fwww.naver.com"><i class="ico_naver"><span class="blind">NAVER</span></i>Sign in</a>,
#  <a class="link_look" data-clk="log_off.searchid" href="https://nid.naver.com/user/help.nhn?todo=idinquiry">Forgot Username</a>,
#  <a class="link_look" data-clk="log_off.searchpass" href="https://nid.naver.com/nidreminder.form">Password</a>,
#  <a class="link_join" data-clk="log_off.registration" href="https://nid.naver.com/nidregister.form?url=https%3A%2F%2Fwww.naver.com">Sign up</a>,
#  <a class="btn_nav btn_prev" data-clk="squ.pre" href="#" role="button"><span class="blind">이전</span></a>,
#  <a class="btn_nav btn_next" data-clk="squ.next" href="#" role="button"><span class="blind">다음</span></a>,
#  <a class="card_news" data-clk="squ.line3" href="https://search.naver.com/search.naver?sm=top_hty&amp;fbm=0&amp;ie=utf8&amp;query=%EC%BD%94%EB%A1%9C%EB%82%9819"><i class="news_badge">이슈</i><span class="news">코로나바이러스감염증-19 현황</span></a>,
#  <a class="card_stock" data-clk="squ.kospi" href="https://finance.naver.com/sise/sise_index.nhn?code=KOSPI">
#  <strong class="stock_title">증시</strong>
#  <div class="stock_box">
#  <em class="name">코스피</em>
#  <strong class="current">2,412.96</strong>
#  <span class="rate rate_up"><span class="blind">상승</span>9.27 +0.39%</span>
#  </div>
#  </a>,
#  <a class="card_stock" data-clk="squ.kosdaq" href="https://finance.naver.com/sise/sise_index.nhn?code=KOSDAQ">
#  <strong class="stock_title">증시</strong>
#  <div class="stock_box">
#  <em class="name">코스닥</em>
#  <strong class="current">789.93</strong>
#  <span class="rate rate_up"><span class="blind">상승</span>0.24 +0.03%</span>
#  </div>
#  </a>,
#  <a class="card_stock type_exchange" data-clk="squ.usd" href="https://finance.naver.com/marketindex/exchangeDetail.nhn?marketindexCd=FX_USDKRW">
#  <strong class="stock_title">환율</strong>
#  <div class="stock_box">
#  <em class="name">USD</em>
#  <strong class="current">1,308.00</strong>
#  <span class="rate rate_down"><span class="blind">하락</span>4.00 -0.30%</span>
#  </div>
#  </a>,
#  <a class="content_top" href="#wrap" id="NM_scroll_top_btn"><span class="blind">TOP</span></a>,
#  <a href="https://www.naver.com/NOTICE">공지사항</a>,
#  <a class="link_all" data-clk="svcmap" href="more.html">서비스 전체보기</a>,
#  <a class="link_partner" data-clk="creator" href="https://www.navercorp.com/service/creators">크리에이터</a>,
#  <a class="link_partner" data-clk="smbusiness" href="https://www.navercorp.com/service/business">스몰비즈니스</a>,
#  <a class="link_partner" data-clk="sme" href="https://campaign.naver.com/smefullcare/online/">SME 풀케어 시스템</a>,
#  <a class="link_partner" data-clk="service" href="https://business.naver.com/service.html">비즈니스 · 광고</a>,
#  <a class="link_partner" data-clk="store" href="https://sell.storefarm.naver.com/#/home/about">스토어 개설</a>,
#  <a class="link_partner" data-clk="place" href="https://smartplace.naver.com">지역업체 등록</a>,
#  <a class="link_partner" data-clk="expert" href="https://expert.naver.com/expert/introduction?tab=guide#join">엑스퍼트 등록</a>,
#  <a class="link_partner" data-clk="center" href="https://developers.naver.com">네이버 개발자 센터</a>,
#  <a class="link_partner" data-clk="openapi" href="https://developers.naver.com/docs/common/openapiguide/#/apilist.md">오픈 API</a>,
#  <a class="link_partner" data-clk="opensource" href="https://naver.github.io">오픈소스</a>,
#  <a class="link_partner" data-clk="d2" href="https://d2.naver.com">네이버 D2</a>,
#  <a class="link_partner" data-clk="naverD2SF" href="http://d2startup.com">네이버 D2SF</a>,
#  <a class="link_partner" data-clk="labs" href="https://www.naverlabs.com">네이버 랩스</a>,
#  <a class="service_logo" data-clk="bt" href="http://whale.naver.com/"> <img alt="웨일" height="48" src="data:image/png;base64,..." width="48"/> </a>,
#  <a class="dsc" data-clk="bt" href="http://whale.naver.com/">다운받기</a>,
#  <a class="service_logo" data-clk="link" href="https://search.naver.com/search.naver?where=nexearch&amp;sm=top_hty&amp;fbm=1&amp;ie=utf8&amp;query=%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%EA%BD%83"> <img alt="꽃" height="50" src="data:image/png;base64,..." width="47"/> </a>,
#  <a class="dsc" data-clk="link" href="https://search.naver.com/search.naver?where=nexearch&amp;sm=top_hty&amp;fbm=1&amp;ie=utf8&amp;query=%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%EA%BD%83">바로가기</a>,
#  <a data-clk="intronhn" href="https://www.navercorp.com">회사소개</a>,
#  <a data-clk="recruit" href="https://recruit.navercorp.com/">인재채용</a>,
#  <a data-clk="contact" href="https://www.navercorp.com/naver/proposalGuide">제휴제안</a>,
#  <a data-clk="service" href="/policy/service.html">이용약관</a>,
#  <a data-clk="privacy" href="/policy/privacy.html"><strong>개인정보처리방침</strong></a>,
#  <a data-clk="youth" href="/policy/youthpolicy.html">청소년보호정책</a>,
#  <a data-clk="policy" href="/policy/spamcheck.html">네이버 정책</a>,
#  <a data-clk="helpcenter" href="https://help.naver.com/">고객센터</a>,
#  <a data-clk="nhn" href="https://www.navercorp.com" target="_blank">ⓒ NAVER Corp.</a>]

# %%
soup.select_one('div > a')
# Out:
# <a href="#newsstand"><span>뉴스스탠드 바로가기</span></a>

# %% [markdown]
# https://yongku.tistory.com/entry/Python-%ED%81%AC%EB%A1%A4%EB%A7%81-%EB%84%A4%EC%9D%B4%EB%B2%84-%EB%89%B4%EC%8A%A4-%ED%81%AC%EB%A1%A4%EB%A7%81%ED%95%98%EA%B8%B0-with-Python<br>
# https://everyday-tech.tistory.com/entry/%EC%89%BD%EA%B2%8C-%EB%94%B0%EB%9D%BC%ED%95%98%EB%8A%94-%EB%84%A4%EC%9D%B4%EB%B2%84-%EB%89%B4%EC%8A%A4-%ED%81%AC%EB%A1%A4%EB%A7%81python-2%ED%83%84

# %%
from datetime import datetime

date = str(datetime.now())
print(date)
date = date[:date.rfind(':')].replace(' ', '_') # date 문자열에서 마지막 : 문자의 인덱스를 반환
print(date)
date = date.replace(':','시') + '분'
print(date)
# Out:
# 2023-04-30 21:22:34.857364
# 2023-04-30_21:22
# 2023-04-30_21시22분

# %% [markdown]
# query = query.replace(' ', '+') 를 사용하는 이유
# - 검색어에서 공백을 + 문자로 대체하는 코드로 HTTP GET 요청에서 검색어를 전달할 때 사용하는 일반적인 방법
# - HTTP GET 요청에서는 URL의 일부분으로 검색어를 전달해야 하는데, 이때 공백은 URL에서 특별한 의미를 가지는 문자이기 때문에, 검색어에서 공백을 + 문자로 대체하여 URL에 포함시켜야 함
# - python web scraping은 python+web+scraping으로 나타낸다.

# %%
import requests
from pandas import DataFrame
from bs4 import BeautifulSoup
import re
from datetime import datetime
import os

date = str(datetime.now())
date = date[:date.rfind(':')].replace(' ', '_')
date = date.replace(':','시') + '분'

query = input('검색 키워드를 입력하세요 : ')
news_num = int(input('총 필요한 뉴스기사 수를 입력해주세요(숫자만 입력) : '))
print(query)
query = query.replace(' ', '+')
print(query)

news_url = 'https://search.naver.com/search.naver?where=news&sm=tab_jum&query={}'

req = requests.get(news_url.format(query)) #
print(req)
# soup = BeautifulSoup(req.text, 'html.parser'
# Out:
# 검색 키워드를 입력하세요 : 대한민국
# 총 필요한 뉴스기사 수를 입력해주세요(숫자만 입력) : 10
# 대한민국
# 대한민국
# <Response [200]>

# %%
html ='''
<ul class="list_news"> <li class="bx" id="sp_nws1"> <div class="news_wrap api_ani_send"> <div class="news_area"> <div class="news_info"> <div class="api_save_group _keep_wrap"> <a href="#" role="button" class="btn_save _keep_trigger" data-url="http://www.kihoilbo.co.kr/news/articleView.html?idxno=1028448" onclick="tCR('a=nws*b.kep&amp;r=1&amp;i=8811BF05_000000000000000000460335&amp;u=javascript'); return false;" aria-pressed="false"><i class="spnew ico_save">문서 저장하기</i></a> <div class="api_ly_save _keep_save_layer"> <a href="#" role="button" class="spnew_af item item_save _keep_save" data-cr-on="a=nws*b.kepon&amp;r=1&amp;i=8811BF05_000000000000000000460335&amp;u=javascript" data-cr-off="a=nws*b.kepoff&amp;r=1&amp;i=8811BF05_000000000000000000460335&amp;u=javascript">Keep에 저장</a> <a href="https://keep.naver.com/" class="spnew_af item item_quick" target="_blank" onclick="return goOtherCR(this,'a=nws*b.kephome&amp;r=1&amp;i=8811BF05_000000000000000000460335&amp;u='+urlencode(this.href));">Keep 바로가기</a> </div></div><div class="info_group"> <a href="http://www.kihoilbo.co.kr/" class="info press" target="_blank" onclick="return goOtherCR(this, 'a=nws*b.prof&amp;r=1&amp;i=8811BF05_000000000000000000460335&amp;g=5154.0000460335&amp;u='+urlencode(this.href));"><span class="thumb_box"><img src="https://search.pstatic.net/common/?src=http%3A%2F%2Fwww.kihoilbo.co.kr%2Fimage%2Flogo%2Ffavicon_20190807115910.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" alt="" width="20" height="20" class="thumb" onerror="this.src='...';this.className='thumb bg_default_press'"></span>기호일보</a><span class="info">8시간 전</span> </div></div><a href="http://www.kihoilbo.co.kr/news/articleView.html?idxno=1028448" class="news_tit" target="_blank" onclick="return goOtherCR(this, 'a=nws*b.tit&amp;r=1&amp;i=8811BF05_000000000000000000460335&amp;g=5154.0000460335&amp;u='+urlencode(this.href));" title="화성시, ChatGPT 활용연구 TF 출범">화성시, ChatGPT 활용연구 TF 출범</a> <div class="news_dsc"> <div class="dsc_wrap"> <a href="http://www.kihoilbo.co.kr/news/articleView.html?idxno=1028448" class="api_txt_lines dsc_txt_wrap" target="_blank" onclick="return goOtherCR(this, 'a=nws*b.body&amp;r=1&amp;i=8811BF05_000000000000000000460335&amp;g=5154.0000460335&amp;u='+urlencode(this.href));">기호일보 - 아침을 여는 신문, KIHOILBO 화성시가 ChatGPT를 활용한 스마트 행정 추진을 위해 전담팀(TF)을 구성하고 지난 28일 근로자복지회관에서 'ChatGPT 활용연구 TF 출범식'을 개최했다. TF팀은 기획조정실장을...</a> </div></div></div><a href="http://www.kihoilbo.co.kr/news/articleView.html?idxno=1028448" class="dsc_thumb " target="_blank" onclick="return goOtherCR(this, 'a=nws*b.img&amp;r=1&amp;i=8811BF05_000000000000000000460335&amp;g=5154.0000460335&amp;u='+urlencode(this.href));"><img src="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F5154%2F2023%2F04%2F30%2F460335.jpg&amp;type=ff264_180&amp;expire=2&amp;refresh=true" width="132" height="90" alt="화성시, ChatGPT 활용" class="thumb api_get" onerror="this.parentNode.style.display='none';"></a> </div><div class="news_cluster"> <ul class="list_cluster"> <li class="sub_bx"> <span class="sub_wrap"> <span class="sub_area"> <cite class="sub_txt press" title="뉴데일리">뉴데일리</cite><span class="sub_txt">7시간 전</span> </span><a href="https://tk.newdaily.co.kr/site/data/html/2023/04/30/2023043000026.html" class="elss sub_tit" target="_blank" onclick="return goOtherCR(this, 'a=nws*d.tit&amp;r=2&amp;i=88000391_000000000000000000739242&amp;g=5005.0000739242&amp;u='+urlencode(this.href));" title="동구청, ChatGPT 활용 행정혁신 강연">동구청, ChatGPT 활용 행정혁신 강연</a> </span></li> <li class="sub_bx"> <span class="sub_wrap"> <span class="sub_area"> <cite class="sub_txt press" title="인천일보">인천일보</cite><span class="sub_txt">11시간 전</span> </span><a href="http://www.incheonilbo.com/news/articleView.html?idxno=1191926" class="elss sub_tit" target="_blank" onclick="return goOtherCR(this, 'a=nws*d.tit&amp;r=3&amp;i=88123FBD_000000000000000000507093&amp;g=5193.0000507093&amp;u='+urlencode(this.href));" title="화성 chat GPT 활용연구 TF 팀 출범">화성 <mark>chat</mark> <mark>GPT</mark> 활용연구 TF 팀 출범</a> </span></li> <li class="sub_bx"> <span class="sub_wrap"> <span class="sub_area"> <cite class="sub_txt press" title="중도일보">중도일보</cite><span class="sub_txt">6시간 전</span> </span><a href="http://www.joongdo.co.kr/web/view.php?key=20230430010009098" class="elss sub_tit" target="_blank" onclick="return goOtherCR(this, 'a=nws*d.tit&amp;r=4&amp;i=88121F5C_000000000000000000851390&amp;g=5340.0000851390&amp;u='+urlencode(this.href));" title="화성시, 스마트 행정 'ChatGPT' 활용연구 출범">화성시, 스마트 행정 'ChatGPT' 활용연구 출범</a> </span></li> </ul></div></li> <li class="bx" id="sp_nws5"> <div class="news_wrap api_ani_send"> <div class="news_area"> <div class="news_info"> <div class="api_save_group _keep_wrap"> <a href="#" role="button" class="btn_save _keep_trigger" data-url="http://www.newspim.com/news/view/20230430000069" onclick="tCR('a=nws*b.kep&amp;r=5&amp;i=88000394_000000000000000002333192&amp;u=javascript'); return false;" aria-pressed="false"><i class="spnew ico_save">문서 저장하기</i></a> <div class="api_ly_save _keep_save_layer"> <a href="#" role="button" class="spnew_af item item_save _keep_save" data-cr-on="a=nws*b.kepon&amp;r=5&amp;i=88000394_000000000000000002333192&amp;u=javascript" data-cr-off="a=nws*b.kepoff&amp;r=5&amp;i=88000394_000000000000000002333192&amp;u=javascript">Keep에 저장</a> <a href="https://keep.naver.com/" class="spnew_af item item_quick" target="_blank" onclick="return goOtherCR(this,'a=nws*b.kephome&amp;r=5&amp;i=88000394_000000000000000002333192&amp;u='+urlencode(this.href));">Keep 바로가기</a> </div></div><div class="info_group"> <a href="http://www.newspim.com" class="info press" target="_blank" onclick="return goOtherCR(this, 'a=nws*b.prof&amp;r=5&amp;i=88000394_000000000000000002333192&amp;g=5002.0002333192&amp;u='+urlencode(this.href));"><span class="thumb_box"><img src="https://search.pstatic.net/common/?src=http%3A%2F%2Fimg.newspim.com%2Fm%2Fmweb%2Ffavicon_144X144V2.png&amp;type=f54_54&amp;expire=24&amp;refresh=true" alt="" width="20" height="20" class="thumb" onerror="this.src='...';this.className='thumb bg_default_press'"></span>뉴스핌</a><span class="info">5시간 전</span> </div></div><a href="http://www.newspim.com/news/view/20230430000069" class="news_tit" target="_blank" onclick="return goOtherCR(this, 'a=nws*b.tit&amp;r=5&amp;i=88000394_000000000000000002333192&amp;g=5002.0002333192&amp;u='+urlencode(this.href));" title="경기도의회 'ChatGPT의 현재와 미래' 특강 실시">경기도의회 'ChatGPT의 현재와 미래' 특강 실시</a> <div class="news_dsc"> <div class="dsc_wrap"> <a href="http://www.newspim.com/news/view/20230430000069" class="api_txt_lines dsc_txt_wrap" target="_blank" onclick="return goOtherCR(this, 'a=nws*b.body&amp;r=5&amp;i=88000394_000000000000000002333192&amp;g=5002.0002333192&amp;u='+urlencode(this.href));">경기도의회는 지난 28일 도의원 및 사무처 직원을 대상으로 자체교육(5차)을 진행했다고 30일 밝혔다. 경기도의회는 지난 28일 도의원 및 사무처 직원을 대상으로 자체교육(5차)을 진행했다고 30일 밝혔다. [사진...</a> </div></div></div><a href="http://www.newspim.com/news/view/20230430000069" class="dsc_thumb " target="_blank" onclick="return goOtherCR(this, 'a=nws*b.img&amp;r=5&amp;i=88000394_000000000000000002333192&amp;g=5002.0002333192&amp;u='+urlencode(this.href));"><img src="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F5002%2F2023%2F04%2F30%2F2333192.jpg&amp;type=ff264_180&amp;expire=2&amp;refresh=true" width="132" height="90" alt="경기도의회 ‘ChatGPT의" class="thumb api_get" onerror="this.parentNode.style.display='none';"></a> </div><div class="news_cluster"> <ul class="list_cluster"> <li class="sub_bx"> <span class="sub_wrap"> <span class="sub_area"> <cite class="sub_txt press" title="에너지경제">에너지경제</cite><span class="sub_txt">7시간 전</span> </span><a href="https://www.ekn.kr/web/view.php?key=20230430010007764" class="elss sub_tit" target="_blank" onclick="return goOtherCR(this, 'a=nws*d.tit&amp;r=6&amp;i=88102504_000000000000000000578788&amp;g=5133.0000578788&amp;u='+urlencode(this.href));" title="경기도의회, 도의원과 사무처 직원 대상으로 ChatGPT 특강 진행">경기도의회, 도의원과 사무처 직원 대상으로 ChatGPT 특강 진행</a> </span></li> <li class="sub_bx"> <span class="sub_wrap"> <span class="sub_area"> <cite class="sub_txt press" title="열린뉴스통신">열린뉴스통신</cite><span class="sub_txt">38분 전</span> </span><a href="https://www.onews.tv/news/articleView.html?idxno=164071" class="elss sub_tit" target="_blank" onclick="return goOtherCR(this, 'a=nws*d.tit&amp;r=7&amp;i=88202ra6_000000000000000000121835&amp;g=5818.0000121835&amp;u='+urlencode(this.href));" title="경기도의회, 'ChatGPT의 현재와 미래' 5차 자체교육">경기도의회, 'ChatGPT의 현재와 미래' 5차 자체교육</a> </span></li> </ul></div></li> <li class="bx" id="sp_nws8"> <div class="news_wrap api_ani_send"> <div class="news_area"> <div class="news_info"> <div class="api_save_group _keep_wrap"> <a href="#" role="button" class="btn_save _keep_trigger" data-url="https://www.idaegu.co.kr/news/articleView.html?idxno=418679" onclick="tCR('a=nws*f.kep&amp;r=8&amp;i=88155e7b_000000000000000000256731&amp;u=javascript'); return false;" aria-pressed="false"><i class="spnew ico_save">문서 저장하기</i></a> <div class="api_ly_save _keep_save_layer"> <a href="#" role="button" class="spnew_af item item_save _keep_save" data-cr-on="a=nws*f.kepon&amp;r=8&amp;i=88155e7b_000000000000000000256731&amp;u=javascript" data-cr-off="a=nws*f.kepoff&amp;r=8&amp;i=88155e7b_000000000000000000256731&amp;u=javascript">Keep에 저장</a> <a href="https://keep.naver.com/" class="spnew_af item item_quick" target="_blank" onclick="return goOtherCR(this,'a=nws*f.kephome&amp;r=8&amp;i=88155e7b_000000000000000000256731&amp;u='+urlencode(this.href));">Keep 바로가기</a> </div></div><div class="info_group"> <a href="http://www.idaegu.co.kr" class="info press" target="_blank" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=8&amp;i=88155e7b_000000000000000000256731&amp;g=5341.0000256731&amp;u='+urlencode(this.href));"><span class="thumb_box"><img src="https://search.pstatic.net/common/?src=https%3A%2F%2Fwww.idaegu.co.kr%2Fimage%2Flogo%2Ffavicon_20180618095934.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" alt="" width="20" height="20" class="thumb" onerror="this.src='...';this.className='thumb bg_default_press'"></span>대구신문</a><span class="info">3시간 전</span> </div></div><a href="https://www.idaegu.co.kr/news/articleView.html?idxno=418679" class="news_tit" target="_blank" onclick="return goOtherCR(this, 'a=nws*f.tit&amp;r=8&amp;i=88155e7b_000000000000000000256731&amp;g=5341.0000256731&amp;u='+urlencode(this.href));" title="대구 동구청&amp;중구청, 챗(Chat) GPT를 활용한 행정혁신 강연 개최">대구 동구청&amp;중구청, 챗(<mark>Chat</mark>) <mark>GPT</mark>를 활용한 행정혁신 강연 개최</a> <div class="news_dsc"> <div class="dsc_wrap"> <a href="https://www.idaegu.co.kr/news/articleView.html?idxno=418679" class="api_txt_lines dsc_txt_wrap" target="_blank" onclick="return goOtherCR(this, 'a=nws*f.body&amp;r=8&amp;i=88155e7b_000000000000000000256731&amp;g=5341.0000256731&amp;u='+urlencode(this.href));">중구청 제공 대구 동구청과 중구청은 지난 달 27일과 28일 양일간 전 직원을 대상으로 챗(<mark>Chat</mark>) <mark>GPT</mark>를 활용한 행정혁신 강연을 개최했다. 챗 <mark>GPT</mark>는 지난해 11월 미국 오픈에이아이(OpenAI)사가 개발한 대화형 인공지능...</a> </div></div></div><a href="https://www.idaegu.co.kr/news/articleView.html?idxno=418679" class="dsc_thumb " target="_blank" onclick="return goOtherCR(this, 'a=nws*f.img&amp;r=8&amp;i=88155e7b_000000000000000000256731&amp;g=5341.0000256731&amp;u='+urlencode(this.href));"><img src="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F5341%2F2023%2F04%2F30%2F256731.jpg&amp;type=ofullfill264_180_gray&amp;expire=2&amp;refresh=true" width="132" height="90" alt="대구 동구청&amp;중구청, " class="thumb api_get" onerror="this.parentNode.style.display='none';"></a> </div></li> <li class="bx" id="sp_nws9"> <div class="news_wrap api_ani_send"> <div class="news_area"> <div class="news_info"> <div class="api_save_group _keep_wrap"> <a href="#" role="button" class="btn_save _keep_trigger" data-url="http://www.mediatoday.co.kr/news/articleView.html?idxno=309816" onclick="tCR('a=nws*j.kep&amp;r=9&amp;i=880000C5_000000000000000000117871&amp;u=javascript'); return false;" aria-pressed="false"><i class="spnew ico_save">문서 저장하기</i></a> <div class="api_ly_save _keep_save_layer"> <a href="#" role="button" class="spnew_af item item_save _keep_save" data-cr-on="a=nws*j.kepon&amp;r=9&amp;i=880000C5_000000000000000000117871&amp;u=javascript" data-cr-off="a=nws*j.kepoff&amp;r=9&amp;i=880000C5_000000000000000000117871&amp;u=javascript">Keep에 저장</a> <a href="https://keep.naver.com/" class="spnew_af item item_quick" target="_blank" onclick="return goOtherCR(this,'a=nws*j.kephome&amp;r=9&amp;i=880000C5_000000000000000000117871&amp;u='+urlencode(this.href));">Keep 바로가기</a> </div></div><div class="info_group"> <a href="http://www.mediatoday.co.kr/" class="info press" target="_blank" onclick="return goOtherCR(this, 'a=nws*j.prof&amp;r=9&amp;i=880000C5_000000000000000000117871&amp;g=006.0000117871&amp;u='+urlencode(this.href));"><span class="thumb_box"><img src="https://search.pstatic.net/common/?src=https%3A%2F%2Fmimgnews.pstatic.net%2Fimage%2Fupload%2Foffice_logo%2F006%2F2017%2F01%2F05%2Flogo_006_18_20170105111205.png&amp;type=f54_54&amp;expire=24&amp;refresh=true" alt="" width="20" height="20" class="thumb" onerror="this.src='...';this.className='thumb bg_default_press'"></span>미디어오늘<i class="spnew ico_pick">언론사 선정</i></a><span class="info">1일 전</span><a href="https://n.news.naver.com/mnews/article/006/0000117871?sid=101" class="info" target="_blank" onclick="return goOtherCR(this, 'a=nws*j.nav&amp;r=9&amp;i=880000C5_000000000000000000117871&amp;u='+urlencode(this.href));">네이버뉴스</a> </div></div><a href="http://www.mediatoday.co.kr/news/articleView.html?idxno=309816" class="news_tit" target="_blank" onclick="return goOtherCR(this, 'a=nws*j.tit&amp;r=9&amp;i=880000C5_000000000000000000117871&amp;g=006.0000117871&amp;u='+urlencode(this.href));" title="챗GPT와 함께 소설 쓰기 과정은 이랬다">챗<mark>GPT</mark>와 함께 소설 쓰기 과정은 이랬다</a> <div class="news_dsc"> <div class="dsc_wrap"> <a href="http://www.mediatoday.co.kr/news/articleView.html?idxno=309816" class="api_txt_lines dsc_txt_wrap" target="_blank" onclick="return goOtherCR(this, 'a=nws*j.body&amp;r=9&amp;i=880000C5_000000000000000000117871&amp;g=006.0000117871&amp;u='+urlencode(this.href));">이 책은 챗<mark>GPT</mark>와 인간 작가가 공동 집필한 국내 첫 소설집이다. 책은 작가별 단편 소설이 나온 다음 챗<mark>GPT</mark>와 어떻게 협업했는지 과정을 '협업일지'와 '협업후기' 형식으로 담았다. 책을 기획한 자음과모음 출판사의 박진혜...</a> </div></div></div><a href="http://www.mediatoday.co.kr/news/articleView.html?idxno=309816" class="dsc_thumb " target="_blank" onclick="return goOtherCR(this, 'a=nws*j.img&amp;r=9&amp;i=880000C5_000000000000000000117871&amp;g=006.0000117871&amp;u='+urlencode(this.href));"><img src="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F006%2F2023%2F04%2F29%2F117871.jpg&amp;type=ff264_180&amp;expire=2&amp;refresh=true" width="132" height="90" alt="챗GPT와 함께 소설 쓰" class="thumb api_get" onerror="this.parentNode.style.display='none';"></a> </div></li> <li class="bx" id="sp_nws10"> <div class="news_wrap api_ani_send"> <div class="news_area"> <div class="news_info"> <div class="api_save_group _keep_wrap"> <a href="#" role="button" class="btn_save _keep_trigger" data-url="https://www.dailian.co.kr/news/view/1228765/?sc=Naver" onclick="tCR('a=nws*a.kep&amp;r=10&amp;i=8812A0A8_000000000000000002707906&amp;u=javascript'); return false;" aria-pressed="false"><i class="spnew ico_save">문서 저장하기</i></a> <div class="api_ly_save _keep_save_layer"> <a href="#" role="button" class="spnew_af item item_save _keep_save" data-cr-on="a=nws*a.kepon&amp;r=10&amp;i=8812A0A8_000000000000000002707906&amp;u=javascript" data-cr-off="a=nws*a.kepoff&amp;r=10&amp;i=8812A0A8_000000000000000002707906&amp;u=javascript">Keep에 저장</a> <a href="https://keep.naver.com/" class="spnew_af item item_quick" target="_blank" onclick="return goOtherCR(this,'a=nws*a.kephome&amp;r=10&amp;i=8812A0A8_000000000000000002707906&amp;u='+urlencode(this.href));">Keep 바로가기</a> </div></div><div class="info_group"> <a href="http://www.dailian.co.kr/" class="info press" target="_blank" onclick="return goOtherCR(this, 'a=nws*a.prof&amp;r=10&amp;i=8812A0A8_000000000000000002707906&amp;g=119.0002707906&amp;u='+urlencode(this.href));"><span class="thumb_box"><img src="https://search.pstatic.net/common/?src=https%3A%2F%2Fmimgnews.pstatic.net%2Fimage%2Fupload%2Foffice_logo%2F119%2F2023%2F03%2F17%2Flogo_119_18_20230317161152.jpg&amp;type=f54_54&amp;expire=24&amp;refresh=true" alt="" width="20" height="20" class="thumb" onerror="this.src='...';this.className='thumb bg_default_press'"></span>데일리안</a><span class="info">2일 전</span><a href="https://n.news.naver.com/mnews/article/119/0002707906?sid=004" class="info" target="_blank" onclick="return goOtherCR(this, 'a=nws*a.nav&amp;r=10&amp;i=8812A0A8_000000000000000002707906&amp;u='+urlencode(this.href));">네이버뉴스</a> </div></div><a href="https://www.dailian.co.kr/news/view/1228765/?sc=Naver" class="news_tit" target="_blank" onclick="return goOtherCR(this, 'a=nws*a.tit&amp;r=10&amp;i=8812A0A8_000000000000000002707906&amp;g=119.0002707906&amp;u='+urlencode(this.href));" title="화성시, ChatGPT 활용연구 TF팀 출범">화성시, ChatGPT 활용연구 TF팀 출범</a> <div class="news_dsc"> <div class="dsc_wrap"> <a href="https://www.dailian.co.kr/news/view/1228765/?sc=Naver" class="api_txt_lines dsc_txt_wrap" target="_blank" onclick="return goOtherCR(this, 'a=nws*a.body&amp;r=10&amp;i=8812A0A8_000000000000000002707906&amp;g=119.0002707906&amp;u='+urlencode(this.href));">경기 화성시가 ChatGPT를 활용한 스마트 행정 추진을 위해 전담팀(TF)을 구성하고 28일, 근로자복지회관에서 ChatGPT 활용연구 TF 출범식을 개최했다. TF팀은 기획조정실장을 단장, 스마트도시과장을 부단장으로...</a> </div></div></div><a href="https://www.dailian.co.kr/news/view/1228765/?sc=Naver" class="dsc_thumb " target="_blank" onclick="return goOtherCR(this, 'a=nws*a.img&amp;r=10&amp;i=8812A0A8_000000000000000002707906&amp;g=119.0002707906&amp;u='+urlencode(this.href));"><img src="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F119%2F2023%2F04%2F28%2F2707906.jpg&amp;type=ofullfill264_180_gray&amp;expire=2&amp;refresh=true" width="132" height="90" alt="화성시, ChatGPT 활용" class="thumb api_get" onerror="this.parentNode.style.display='none';"></a> </div><div class="news_cluster"> <ul class="list_cluster"> <li class="sub_bx"> <span class="sub_wrap"> <span class="sub_area"> <cite class="sub_txt press" title="대한경제">대한경제</cite><span class="sub_txt">2일 전</span> </span><a href="https://www.dnews.co.kr/uhtml/view.jsp?idxno=202304281737548950693" class="elss sub_tit" target="_blank" onclick="return goOtherCR(this, 'a=nws*d.tit&amp;r=11&amp;i=88105698_000000000000000000451347&amp;g=5138.0000451347&amp;u='+urlencode(this.href));" title="화성시, 스마트 행정은 ChatGPT로">화성시, 스마트 행정은 ChatGPT로</a> </span></li> <li class="sub_bx"> <span class="sub_wrap"> <span class="sub_area"> <cite class="sub_txt press" title="에너지경제">에너지경제</cite><span class="sub_txt">2일 전</span> </span><a href="https://www.ekn.kr/web/view.php?key=20230428010007594" class="elss sub_tit" target="_blank" onclick="return goOtherCR(this, 'a=nws*d.tit&amp;r=12&amp;i=88102504_000000000000000000578618&amp;g=5133.0000578618&amp;u='+urlencode(this.href));" title="화성시, Chat GPT 활용연구 TF팀 출범식 개최">화성시, <mark>Chat</mark> <mark>GPT</mark> 활용연구 TF팀 출범식 개최</a> </span></li> <li class="sub_bx"> <span class="sub_wrap"> <span class="sub_area"> <cite class="sub_txt press" title="위클리오늘">위클리오늘</cite><span class="sub_txt">2일 전</span> </span><a href="http://www.weeklytoday.com/news/articleView.html?idxno=567824" class="elss sub_tit" target="_blank" onclick="return goOtherCR(this, 'a=nws*d.tit&amp;r=13&amp;i=8813C2D2_000000000000000000281685&amp;g=5294.0000281685&amp;u='+urlencode(this.href));" title="화성시, ChatGPT 활용연구 TF 출범식 개최">화성시, ChatGPT 활용연구 TF 출범식 개최</a> </span></li> <li class="sub_bx"> <span class="sub_wrap"> <span class="sub_area"> <cite class="sub_txt press" title="NSP통신">NSP통신</cite><span class="sub_txt">2일 전</span> </span><a href="https://www.nspna.com/news/?mode=view&amp;newsid=634625" class="elss sub_tit" target="_blank" onclick="return goOtherCR(this, 'a=nws*d.tit&amp;r=14&amp;i=880003F1_000000000000000000606368&amp;g=5025.0000606368&amp;u='+urlencode(this.href));" title="화성시, 행정에 부는 챗GPT 바람…활용연구TF출범">화성시, 행정에 부는 챗<mark>GPT</mark> 바람…활용연구TF출범</a> </span></li> </ul></div></li> <li class="bx" id="sp_nws15"> <div class="news_wrap api_ani_send"> <div class="news_area"> <div class="news_info"> <div class="api_save_group _keep_wrap"> <a href="#" role="button" class="btn_save _keep_trigger" data-url="http://www.newsis.com/view/?id=NISX20230427_0002282419&amp;cID=10811&amp;pID=10800" onclick="tCR('a=nws*a.kep&amp;r=15&amp;i=88000127_000000000000000011826825&amp;u=javascript'); return false;" aria-pressed="false"><i class="spnew ico_save">문서 저장하기</i></a> <div class="api_ly_save _keep_save_layer"> <a href="#" role="button" class="spnew_af item item_save _keep_save" data-cr-on="a=nws*a.kepon&amp;r=15&amp;i=88000127_000000000000000011826825&amp;u=javascript" data-cr-off="a=nws*a.kepoff&amp;r=15&amp;i=88000127_000000000000000011826825&amp;u=javascript">Keep에 저장</a> <a href="https://keep.naver.com/" class="spnew_af item item_quick" target="_blank" onclick="return goOtherCR(this,'a=nws*a.kephome&amp;r=15&amp;i=88000127_000000000000000011826825&amp;u='+urlencode(this.href));">Keep 바로가기</a> </div></div><div class="info_group"> <a href="http://www.newsis.com" class="info press" target="_blank" onclick="return goOtherCR(this, 'a=nws*a.prof&amp;r=15&amp;i=88000127_000000000000000011826825&amp;g=003.0011826825&amp;u='+urlencode(this.href));"><span class="thumb_box"><img src="..." data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fmimgnews.pstatic.net%2Fimage%2Fupload%2Foffice_logo%2F003%2F2019%2F02%2F19%2Flogo_003_18_20190219111719.jpg&amp;type=f54_54&amp;expire=24&amp;refresh=true" alt="" width="20" height="20" class="thumb" onerror="this.src='...';this.className='thumb bg_default_press'" data-obstatus="ob-once"></span>뉴시스</a><span class="info">3일 전</span><a href="https://n.news.naver.com/mnews/article/003/0011826825?sid=102" class="info" target="_blank" onclick="return goOtherCR(this, 'a=nws*a.nav&amp;r=15&amp;i=88000127_000000000000000011826825&amp;u='+urlencode(this.href));">네이버뉴스</a> </div></div><a href="http://www.newsis.com/view/?id=NISX20230427_0002282419&amp;cID=10811&amp;pID=10800" class="news_tit" target="_blank" onclick="return goOtherCR(this, 'a=nws*a.tit&amp;r=15&amp;i=88000127_000000000000000011826825&amp;g=003.0011826825&amp;u='+urlencode(this.href));" title="DX포럼, ‘ChatGPT 활용 사례로 보는 인공지능과 데이터의 미래’">DX포럼, ‘ChatGPT 활용 사례로 보는 인공지능과 데이터의 미래’</a> <div class="news_dsc"> <div class="dsc_wrap"> <a href="http://www.newsis.com/view/?id=NISX20230427_0002282419&amp;cID=10811&amp;pID=10800" class="api_txt_lines dsc_txt_wrap" target="_blank" onclick="return goOtherCR(this, 'a=nws*a.body&amp;r=15&amp;i=88000127_000000000000000011826825&amp;g=003.0011826825&amp;u='+urlencode(this.href));">기사내용 요약 27일 오후 6시 부산빅데이터혁신센터 ‘제7회 디지털 전환 포럼(DX포럼)‘이 27일 오후 6시 해운대 부산빅데이터혁신센터에서 ‘ChatGPT 활용 사례로 보는 인공지능과 데이터의 미래’를 주제로 열린다....</a> </div></div></div><a href="http://www.newsis.com/view/?id=NISX20230427_0002282419&amp;cID=10811&amp;pID=10800" class="dsc_thumb " target="_blank" onclick="return goOtherCR(this, 'a=nws*a.img&amp;r=15&amp;i=88000127_000000000000000011826825&amp;g=003.0011826825&amp;u='+urlencode(this.href));"><img src="..." data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F003%2F2023%2F04%2F27%2F11826825.jpg&amp;type=ff264_180&amp;expire=2&amp;refresh=true" width="132" height="90" alt="DX포럼, ‘ChatGPT 활" class="thumb api_get" onerror="this.parentNode.style.display='none';" data-obstatus="ob-once"></a> </div><div class="news_cluster"> <ul class="list_cluster"> <li class="sub_bx"> <span class="sub_wrap"> <span class="sub_area"> <cite class="sub_txt press" title="뉴스1">뉴스1</cite><span class="sub_txt">3일 전</span><a href="https://n.news.naver.com/mnews/article/421/0006772755?sid=102" class="sub_txt" target="_blank" onclick="return goOtherCR(this, 'a=nws*c.nav&amp;r=16&amp;i=08138263_000000000000000006772755&amp;u='+urlencode(this.href));">네이버뉴스</a> </span><a href="https://www.news1.kr/articles/5029003" class="elss sub_tit" target="_blank" onclick="return goOtherCR(this, 'a=nws*c.tit&amp;r=16&amp;i=08138263_000000000000000006772755&amp;g=421.0006772755&amp;u='+urlencode(this.href));" title="부산빅데이터혁신센터, 27일 디지털 전환 포럼 개최">부산빅데이터혁신센터, 27일 디지털 전환 포럼 개최</a> </span></li> </ul></div></li> <li class="bx" id="sp_nws17"> <div class="news_wrap api_ani_send"> <div class="news_area"> <div class="news_info"> <div class="api_save_group _keep_wrap"> <a href="#" role="button" class="btn_save _keep_trigger" data-url="https://n.news.naver.com/mnews/article/077/0005927161?sid=104" onclick="tCR('a=nws*e.kep&amp;r=17&amp;i=880000DD_000000000000000005927161&amp;u=javascript'); return false;" aria-pressed="false"><i class="spnew ico_save">문서 저장하기</i></a> <div class="api_ly_save _keep_save_layer"> <a href="#" role="button" class="spnew_af item item_save _keep_save" data-cr-on="a=nws*e.kepon&amp;r=17&amp;i=880000DD_000000000000000005927161&amp;u=javascript" data-cr-off="a=nws*e.kepoff&amp;r=17&amp;i=880000DD_000000000000000005927161&amp;u=javascript">Keep에 저장</a> <a href="https://keep.naver.com/" class="spnew_af item item_quick" target="_blank" onclick="return goOtherCR(this,'a=nws*e.kephome&amp;r=17&amp;i=880000DD_000000000000000005927161&amp;u='+urlencode(this.href));">Keep 바로가기</a> </div></div><div class="info_group"> <a href="https://en.yna.co.kr/image/index" class="info press" target="_blank" onclick="return goOtherCR(this, 'a=nws*e.prof&amp;r=17&amp;i=880000DD_000000000000000005927161&amp;g=&amp;u='+urlencode(this.href));"><span class="thumb_box"><img src="..." data-lazysrc="..." alt="" width="20" height="20" class="thumb bg_default_press" onerror="this.src='...';this.className='thumb bg_default_press'" data-obstatus="ob-once"></span>AP연합뉴스</a><span class="info">1일 전</span><a href="https://n.news.naver.com/mnews/article/077/0005927161?sid=104" class="info" target="_blank" onclick="return goOtherCR(this, 'a=nws*e.nav&amp;r=17&amp;i=880000DD_000000000000000005927161&amp;u='+urlencode(this.href));">네이버뉴스</a> </div></div><a href="https://n.news.naver.com/mnews/article/077/0005927161?sid=104" class="news_tit" target="_blank" onclick="return goOtherCR(this, 'a=nws*e.tit&amp;r=17&amp;i=880000DD_000000000000000005927161&amp;g=&amp;u='+urlencode(this.href));" title="Italy ChatGPT">Italy ChatGPT</a> <div class="news_dsc"> <div class="dsc_wrap"> <a href="https://n.news.naver.com/mnews/article/077/0005927161?sid=104" class="api_txt_lines dsc_txt_wrap" target="_blank" onclick="return goOtherCR(this, 'a=nws*e.body&amp;r=17&amp;i=880000DD_000000000000000005927161&amp;g=&amp;u='+urlencode(this.href));">FILE - The OpenAI logo is seen on a mobile phone in front of a computer screen which displays the ChatGPT home Screen, on March 17, 2023, in Boston. ChatGPT's maker said Friday April 28, 2023...</a> </div></div></div><a href="https://n.news.naver.com/mnews/article/077/0005927161?sid=104" class="dsc_thumb " target="_blank" onclick="return goOtherCR(this, 'a=nws*e.img&amp;r=17&amp;i=880000DD_000000000000000005927161&amp;g=&amp;u='+urlencode(this.href));"><img src="..." data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F077%2F2023%2F04%2F29%2F5927161.jpg&amp;type=ff264_180&amp;expire=2&amp;refresh=true" width="132" height="90" alt="Italy ChatGPT" class="thumb api_get" onerror="this.parentNode.style.display='none';" data-obstatus="ob-once"></a> </div></li> <li class="bx" id="sp_nws18"> <div class="news_wrap api_ani_send"> <div class="news_area"> <div class="news_info"> <div class="api_save_group _keep_wrap"> <a href="#" role="button" class="btn_save _keep_trigger" data-url="https://www.news1.kr/articles/5029548" onclick="tCR('a=nws*a.kep&amp;r=18&amp;i=08138263_000000000000000006773571&amp;u=javascript'); return false;" aria-pressed="false"><i class="spnew ico_save">문서 저장하기</i></a> <div class="api_ly_save _keep_save_layer"> <a href="#" role="button" class="spnew_af item item_save _keep_save" data-cr-on="a=nws*a.kepon&amp;r=18&amp;i=08138263_000000000000000006773571&amp;u=javascript" data-cr-off="a=nws*a.kepoff&amp;r=18&amp;i=08138263_000000000000000006773571&amp;u=javascript">Keep에 저장</a> <a href="https://keep.naver.com/" class="spnew_af item item_quick" target="_blank" onclick="return goOtherCR(this,'a=nws*a.kephome&amp;r=18&amp;i=08138263_000000000000000006773571&amp;u='+urlencode(this.href));">Keep 바로가기</a> </div></div><div class="info_group"> <a href="http://news1.kr/" class="info press" target="_blank" onclick="return goOtherCR(this, 'a=nws*a.prof&amp;r=18&amp;i=08138263_000000000000000006773571&amp;g=421.0006773571&amp;u='+urlencode(this.href));"><span class="thumb_box"><img src="..." data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fmimgnews.pstatic.net%2Fimage%2Fupload%2Foffice_logo%2F421%2F2017%2F01%2F05%2Flogo_421_18_20170105111205.png&amp;type=f54_54&amp;expire=24&amp;refresh=true" alt="" width="20" height="20" class="thumb" onerror="this.src='...';this.className='thumb bg_default_press'" data-obstatus="ob-once"></span>뉴스1</a><span class="info">3일 전</span><a href="https://n.news.naver.com/mnews/article/421/0006773571?sid=105" class="info" target="_blank" onclick="return goOtherCR(this, 'a=nws*a.nav&amp;r=18&amp;i=08138263_000000000000000006773571&amp;u='+urlencode(this.href));">네이버뉴스</a> </div></div><a href="https://www.news1.kr/articles/5029548" class="news_tit" target="_blank" onclick="return goOtherCR(this, 'a=nws*a.tit&amp;r=18&amp;i=08138263_000000000000000006773571&amp;g=421.0006773571&amp;u='+urlencode(this.href));" title="카톡 챗GPT '아숙업' 만든 업스테이지, 활용 비법 알려준다">카톡 챗<mark>GPT</mark> '아숙업' 만든 업스테이지, 활용 비법 알려준다</a> <div class="news_dsc"> <div class="dsc_wrap"> <a href="https://www.news1.kr/articles/5029548" class="api_txt_lines dsc_txt_wrap" target="_blank" onclick="return goOtherCR(this, 'a=nws*a.body&amp;r=18&amp;i=08138263_000000000000000006773571&amp;g=421.0006773571&amp;u='+urlencode(this.href));">채팅형 인공지능(AI) 아숙업(AskUp) 제작사 업스테이지가 챗<mark>GPT</mark> 활용 비법과 이를 활용해 직접 서비스를 만드는 교육을 선보인다. AI 스타트업 업스테이지는 챗<mark>GPT</mark> 활용 서비스 기획과 활용 비법을 알려주는 온라인...</a> </div></div></div><a href="https://www.news1.kr/articles/5029548" class="dsc_thumb " target="_blank" onclick="return goOtherCR(this, 'a=nws*a.img&amp;r=18&amp;i=08138263_000000000000000006773571&amp;g=421.0006773571&amp;u='+urlencode(this.href));"><img src="..." data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F421%2F2023%2F04%2F27%2F6773571.jpg&amp;type=ff264_180&amp;expire=2&amp;refresh=true" width="132" height="90" alt="카톡 챗GPT ‘아숙업‘ " class="thumb api_get" onerror="this.parentNode.style.display='none';" data-obstatus="ob-once"></a> </div><div class="news_cluster"> <ul class="list_cluster"> <li class="sub_bx"> <span class="sub_wrap"> <span class="sub_area"> <cite class="sub_txt press" title="뉴시스">뉴시스</cite><span class="sub_txt">3일 전</span><a href="https://n.news.naver.com/mnews/article/003/0011826923?sid=105" class="sub_txt" target="_blank" onclick="return goOtherCR(this, 'a=nws*c.nav&amp;r=19&amp;i=88000127_000000000000000011826923&amp;u='+urlencode(this.href));">네이버뉴스</a> </span><a href="http://www.newsis.com/view/?id=NISX20230427_0002282520&amp;cID=10406&amp;pID=13100" class="elss sub_tit" target="_blank" onclick="return goOtherCR(this, 'a=nws*c.tit&amp;r=19&amp;i=88000127_000000000000000011826923&amp;g=003.0011826923&amp;u='+urlencode(this.href));" title="&quot;챗GPT 활용비법 알려준다&quot; 아숙업 만든 업스테이지">"챗<mark>GPT</mark> 활용비법 알려준다" 아숙업 만든 업스테이지</a> </span></li> <li class="sub_bx"> <span class="sub_wrap"> <span class="sub_area"> <cite class="sub_txt press" title="데일리안">데일리안</cite><span class="sub_txt">3일 전</span><a href="https://n.news.naver.com/mnews/article/119/0002707019?sid=105" class="sub_txt" target="_blank" onclick="return goOtherCR(this, 'a=nws*c.nav&amp;r=20&amp;i=8812A0A8_000000000000000002707019&amp;u='+urlencode(this.href));">네이버뉴스</a> </span><a href="https://www.dailian.co.kr/news/view/1227756/?sc=Naver" class="elss sub_tit" target="_blank" onclick="return goOtherCR(this, 'a=nws*c.tit&amp;r=20&amp;i=8812A0A8_000000000000000002707019&amp;g=119.0002707019&amp;u='+urlencode(this.href));" title="업스테이지, 챗GPT 활용 비법 알린다…‘ChatGPT UP’ 강의 개설">업스테이지, 챗<mark>GPT</mark> 활용 비법 알린다…‘ChatGPT UP’ 강의 개설</a> </span></li> <li class="sub_bx"> <span class="sub_wrap"> <span class="sub_area"> <cite class="sub_txt press" title="뉴스핌">뉴스핌</cite><span class="sub_txt">3일 전</span> </span><a href="http://www.newspim.com/news/view/20230427000143" class="elss sub_tit" target="_blank" onclick="return goOtherCR(this, 'a=nws*d.tit&amp;r=21&amp;i=88000394_000000000000000002330946&amp;g=5002.0002330946&amp;u='+urlencode(this.href));" title="업스테이지, 챗GPT 활용비법 알려주는 'ChatGPT UP' 강의 개설">업스테이지, 챗<mark>GPT</mark> 활용비법 알려주는 'ChatGPT UP' 강의 개설</a> </span></li> <li class="sub_bx"> <span class="sub_wrap"> <span class="sub_area"> <cite class="sub_txt press" title="문화일보">문화일보</cite><span class="sub_txt">3일 전</span><a href="https://n.news.naver.com/mnews/article/021/0002568885?sid=101" class="sub_txt" target="_blank" onclick="return goOtherCR(this, 'a=nws*c.nav&amp;r=22&amp;i=880000C4_000000000000000002568885&amp;u='+urlencode(this.href));">네이버뉴스</a> </span><a href="https://www.munhwa.com/news/view.html?no=2023042701039907275002" class="elss sub_tit" target="_blank" onclick="return goOtherCR(this, 'a=nws*c.tit&amp;r=22&amp;i=880000C4_000000000000000002568885&amp;g=021.0002568885&amp;u='+urlencode(this.href));" title="업스테이지, 챗GPT로 앱 만드는 법 강의한다">업스테이지, 챗<mark>GPT</mark>로 앱 만드는 법 강의한다</a> </span></li> </ul></div><a href="?where=news&amp;sm=tab_tnw&amp;query=%7Bchatgpt%7D&amp;sort=0&amp;photo=0&amp;field=0&amp;pd=0&amp;ds=&amp;de=&amp;mynews=0&amp;office_type=0&amp;office_section_code=0&amp;news_office_checked=&amp;related=1&amp;docid=4210006773571&amp;nso=so:r,p:all,a:all" class="news_more" onclick="return goOtherCR(this, 'a=nws*r.more&amp;u='+urlencode(urlexpand(this.href)));">관련뉴스 10건 전체보기<i class="spnew ico_arrow"></i></a> </li> <li class="bx" id="sp_nws23"> <div class="news_wrap api_ani_send"> <div class="news_area"> <div class="news_info"> <div class="api_save_group _keep_wrap"> <a href="#" role="button" class="btn_save _keep_trigger" data-url="https://www.donga.com/news/Economy/article/all/20230426/119007018/1" onclick="tCR('a=nws*j.kep&amp;r=23&amp;i=880000A9_000000000000000003493687&amp;u=javascript'); return false;" aria-pressed="false"><i class="spnew ico_save">문서 저장하기</i></a> <div class="api_ly_save _keep_save_layer"> <a href="#" role="button" class="spnew_af item item_save _keep_save" data-cr-on="a=nws*j.kepon&amp;r=23&amp;i=880000A9_000000000000000003493687&amp;u=javascript" data-cr-off="a=nws*j.kepoff&amp;r=23&amp;i=880000A9_000000000000000003493687&amp;u=javascript">Keep에 저장</a> <a href="https://keep.naver.com/" class="spnew_af item item_quick" target="_blank" onclick="return goOtherCR(this,'a=nws*j.kephome&amp;r=23&amp;i=880000A9_000000000000000003493687&amp;u='+urlencode(this.href));">Keep 바로가기</a> </div></div><div class="info_group"> <a href="http://www.donga.com/" class="info press" target="_blank" onclick="return goOtherCR(this, 'a=nws*j.prof&amp;r=23&amp;i=880000A9_000000000000000003493687&amp;g=020.0003493687&amp;u='+urlencode(this.href));"><span class="thumb_box"><img src="..." data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fmimgnews.pstatic.net%2Fimage%2Fupload%2Foffice_logo%2F020%2F2017%2F01%2F05%2Flogo_020_18_20170105111205.png&amp;type=f54_54&amp;expire=24&amp;refresh=true" alt="" width="20" height="20" class="thumb" onerror="this.src='...';this.className='thumb bg_default_press'" data-obstatus="ob-once"></span>동아일보<i class="spnew ico_pick">언론사 선정</i></a><span class="info"><i class="spnew ico_paper"></i>A12면 1단</span><span class="info">4일 전</span><a href="https://n.news.naver.com/mnews/article/020/0003493687?sid=101" class="info" target="_blank" onclick="return goOtherCR(this, 'a=nws*j.nav&amp;r=23&amp;i=880000A9_000000000000000003493687&amp;u='+urlencode(this.href));">네이버뉴스</a> </div></div><a href="https://www.donga.com/news/Economy/article/all/20230426/119007018/1" class="news_tit" target="_blank" onclick="return goOtherCR(this, 'a=nws*j.tit&amp;r=23&amp;i=880000A9_000000000000000003493687&amp;g=020.0003493687&amp;u='+urlencode(this.href));" title="‘○○GPT’ 명칭 함부로 못쓴다… 개발사, 상표권 출원">‘○○<mark>GPT</mark>’ 명칭 함부로 못쓴다… 개발사, 상표권 출원</a> <div class="news_dsc"> <div class="dsc_wrap"> <a href="https://www.donga.com/news/Economy/article/all/20230426/119007018/1" class="api_txt_lines dsc_txt_wrap" target="_blank" onclick="return goOtherCR(this, 'a=nws*j.body&amp;r=23&amp;i=880000A9_000000000000000003493687&amp;g=020.0003493687&amp;u='+urlencode(this.href));">앞으로 ‘<mark>GPT</mark>’를 붙인 인공지능(AI) 서비스명을 사용하기 어려워질 것으로 전망된다. 챗<mark>GPT</mark>를 개발한 오픈AI가 상표권을 내세워 챗<mark>GPT</mark>의 API를 사용한 서비스 명칭 가이드라인을 제시했기 때문이다. 오픈AI는...</a> </div></div></div><a href="https://www.donga.com/news/Economy/article/all/20230426/119007018/1" class="dsc_thumb " target="_blank" onclick="return goOtherCR(this, 'a=nws*j.img&amp;r=23&amp;i=880000A9_000000000000000003493687&amp;g=020.0003493687&amp;u='+urlencode(this.href));"><img src="..." data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F020%2F2023%2F04%2F26%2F3493687.jpg&amp;type=ff264_180&amp;expire=2&amp;refresh=true" width="132" height="90" alt="‘○○GPT’ 명칭 함부" class="thumb api_get" onerror="this.parentNode.style.display='none';" data-obstatus="ob-once"></a> </div></li> <li class="bx" id="sp_nws24"> <div class="news_wrap api_ani_send"> <div class="news_area"> <div class="news_info"> <div class="api_save_group _keep_wrap"> <a href="#" role="button" class="btn_save _keep_trigger" data-url="http://www.kbsm.net/news/view.php?idx=389951" onclick="tCR('a=nws*f.kep&amp;r=24&amp;i=8817ca6c_000000000000000000209563&amp;u=javascript'); return false;" aria-pressed="false"><i class="spnew ico_save">문서 저장하기</i></a> <div class="api_ly_save _keep_save_layer"> <a href="#" role="button" class="spnew_af item item_save _keep_save" data-cr-on="a=nws*f.kepon&amp;r=24&amp;i=8817ca6c_000000000000000000209563&amp;u=javascript" data-cr-off="a=nws*f.kepoff&amp;r=24&amp;i=8817ca6c_000000000000000000209563&amp;u=javascript">Keep에 저장</a> <a href="https://keep.naver.com/" class="spnew_af item item_quick" target="_blank" onclick="return goOtherCR(this,'a=nws*f.kephome&amp;r=24&amp;i=8817ca6c_000000000000000000209563&amp;u='+urlencode(this.href));">Keep 바로가기</a> </div></div><div class="info_group"> <a href="http://www.kbsm.net" class="info press" target="_blank" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=24&amp;i=8817ca6c_000000000000000000209563&amp;g=5533.0000209563&amp;u='+urlencode(this.href));"><span class="thumb_box"><img src="..." data-lazysrc="https://search.pstatic.net/common/?src=http%3A%2F%2Fwww.kbsm.net%2Ffavicon.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" alt="" width="20" height="20" class="thumb" onerror="this.src='...';this.className='thumb bg_default_press'" data-obstatus="ob-once"></span>경북신문</a><span class="info">8시간 전</span> </div></div><a href="http://www.kbsm.net/news/view.php?idx=389951" class="news_tit" target="_blank" onclick="return goOtherCR(this, 'a=nws*f.tit&amp;r=24&amp;i=8817ca6c_000000000000000000209563&amp;g=5533.0000209563&amp;u='+urlencode(this.href));" title="대구 동구, 챗GPT 활용 행정혁신 추진">대구 동구, 챗<mark>GPT</mark> 활용 행정혁신 추진</a> <div class="news_dsc"> <div class="dsc_wrap"> <a href="http://www.kbsm.net/news/view.php?idx=389951" class="api_txt_lines dsc_txt_wrap" target="_blank" onclick="return goOtherCR(this, 'a=nws*f.body&amp;r=24&amp;i=8817ca6c_000000000000000000209563&amp;g=5533.0000209563&amp;u='+urlencode(this.href));">대구 동구가 지난 27일 전 직원을 대상으로 챗지피티(ChatGPT)를 이해하고 활용할 수 있는 강연을 열었다. 챗지피티는 오픈AI에서 개발한 대화형 인공지능 언어 모델이다. 이를 활용하면 문서 작성, 정보 검색, 민원 처리...</a> </div></div></div><a href="http://www.kbsm.net/news/view.php?idx=389951" class="dsc_thumb " target="_blank" onclick="return goOtherCR(this, 'a=nws*f.img&amp;r=24&amp;i=8817ca6c_000000000000000000209563&amp;g=5533.0000209563&amp;u='+urlencode(this.href));"><img src="..." data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F5533%2F2023%2F04%2F30%2F209563.jpg&amp;type=ofullfill264_180_gray&amp;expire=2&amp;refresh=true" width="132" height="90" alt="대구 동구, 챗GPT 활용" class="thumb api_get" onerror="this.parentNode.style.display='none';" data-obstatus="ob-once"></a> </div></li> </ul>
'''
bs = BeautifulSoup(html,'html.parser')
print(bs.prettify())
# Out:
# <ul class="list_news">
#  <li class="bx" id="sp_nws1">
#   <div class="news_wrap api_ani_send">
#    <div class="news_area">
#     <div class="news_info">
#      <div class="api_save_group _keep_wrap">
#       <a aria-pressed="false" class="btn_save _keep_trigger" data-url="http://www.kihoilbo.co.kr/news/articleView.html?idxno=1028448" href="#" onclick="tCR('a=nws*b.kep&amp;r=1&amp;i=8811BF05_000000000000000000460335&amp;u=javascript'); return false;" role="button">
#        <i class="spnew ico_save">
#         문서 저장하기
#        </i>
#       </a>
#       <div class="api_ly_save _keep_save_layer">
#        <a class="spnew_af item item_save _keep_save" data-cr-off="a=nws*b.kepoff&amp;r=1&amp;i=8811BF05_000000000000000000460335&amp;u=javascript" data-cr-on="a=nws*b.kepon&amp;r=1&amp;i=8811BF05_000000000000000000460335&amp;u=javascript" href="#" role="button">
#         Keep에 저장
#        </a>
#        <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick="return goOtherCR(this,'a=nws*b.kephome&amp;r=1&amp;i=8811BF05_000000000000000000460335&amp;u='+urlencode(this.href));" target="_blank">
#         Keep 바로가기
#        </a>
#       </div>
#      </div>
#      <div class="info_group">
#       <a class="info press" href="http://www.kihoilbo.co.kr/" onclick="return goOtherCR(this, 'a=nws*b.prof&amp;r=1&amp;i=8811BF05_000000000000000000460335&amp;g=5154.0000460335&amp;u='+urlencode(this.href));" target="_blank">
#        <span class="thumb_box">
#         <img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Fwww.kihoilbo.co.kr%2Fimage%2Flogo%2Ffavicon_20190807115910.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/>
#        </span>
#        기호일보
#       </a>
#       <span class="info">
#        8시간 전
#       </span>
#      </div>
#     </div>
#     <a class="news_tit" href="http://www.kihoilbo.co.kr/news/articleView.html?idxno=1028448" onclick="return goOtherCR(this, 'a=nws*b.tit&amp;r=1&amp;i=8811BF05_000000000000000000460335&amp;g=5154.0000460335&amp;u='+urlencode(this.href));" target="_blank" title="화성시, ChatGPT 활용연구 TF 출범">
#      화성시, ChatGPT 활용연구 TF 출범
#     </a>
#     <div class="news_dsc">
#      <div class="dsc_wrap">
#       <a class="api_txt_lines dsc_txt_wrap" href="http://www.kihoilbo.co.kr/news/articleView.html?idxno=1028448" onclick="return goOtherCR(this, 'a=nws*b.body&amp;r=1&amp;i=8811BF05_000000000000000000460335&amp;g=5154.0000460335&amp;u='+urlencode(this.href));" target="_blank">
#        기호일보 - 아침을 여는 신문, KIHOILBO 화성시가 ChatGPT를 활용한 스마트 행정 추진을 위해 전담팀(TF)을 구성하고 지난 28일 근로자복지회관에서 'ChatGPT 활용연구 TF 출범식'을 개최했다. TF팀은 기획조정실장을...
#       </a>
#      </div>
#     </div>
#    </div>
#    <a class="dsc_thumb" href="http://www.kihoilbo.co.kr/news/articleView.html?idxno=1028448" onclick="return goOtherCR(this, 'a=nws*b.img&amp;r=1&amp;i=8811BF05_000000000000000000460335&amp;g=5154.0000460335&amp;u='+urlencode(this.href));" target="_blank">
#     <img alt="화성시, ChatGPT 활용" class="thumb api_get" height="90" onerror="this.parentNode.style.display='none';" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F5154%2F2023%2F04%2F30%2F460335.jpg&amp;type=ff264_180&amp;expire=2&amp;refresh=true" width="132"/>
#    </a>
#   </div>
#   <div class="news_cluster">
#    <ul class="list_cluster">
#     <li class="sub_bx">
#      <span class="sub_wrap">
#       <span class="sub_area">
#        <cite class="sub_txt press" title="뉴데일리">
#         뉴데일리
#        </cite>
#        <span class="sub_txt">
#         7시간 전
#        </span>
#       </span>
#       <a class="elss sub_tit" href="https://tk.newdaily.co.kr/site/data/html/2023/04/30/2023043000026.html" onclick="return goOtherCR(this, 'a=nws*d.tit&amp;r=2&amp;i=88000391_000000000000000000739242&amp;g=5005.0000739242&amp;u='+urlencode(this.href));" target="_blank" title="동구청, ChatGPT 활용 행정혁신 강연">
#        동구청, ChatGPT 활용 행정혁신 강연
#       </a>
#      </span>
#     </li>
#     <li class="sub_bx">
#      <span class="sub_wrap">
#       <span class="sub_area">
#        <cite class="sub_txt press" title="인천일보">
#         인천일보
#        </cite>
#        <span class="sub_txt">
#         11시간 전
#        </span>
#       </span>
#       <a class="elss sub_tit" href="http://www.incheonilbo.com/news/articleView.html?idxno=1191926" onclick="return goOtherCR(this, 'a=nws*d.tit&amp;r=3&amp;i=88123FBD_000000000000000000507093&amp;g=5193.0000507093&amp;u='+urlencode(this.href));" target="_blank" title="화성 chat GPT 활용연구 TF 팀 출범">
#        화성
#        <mark>
#         chat
#        </mark>
#        <mark>
#         GPT
#        </mark>
#        활용연구 TF 팀 출범
#       </a>
#      </span>
#     </li>
#     <li class="sub_bx">
#      <span class="sub_wrap">
#       <span class="sub_area">
#        <cite class="sub_txt press" title="중도일보">
#         중도일보
#        </cite>
#        <span class="sub_txt">
#         6시간 전
#        </span>
#       </span>
#       <a class="elss sub_tit" href="http://www.joongdo.co.kr/web/view.php?key=20230430010009098" onclick="return goOtherCR(this, 'a=nws*d.tit&amp;r=4&amp;i=88121F5C_000000000000000000851390&amp;g=5340.0000851390&amp;u='+urlencode(this.href));" target="_blank" title="화성시, 스마트 행정 'ChatGPT' 활용연구 출범">
#        화성시, 스마트 행정 'ChatGPT' 활용연구 출범
#       </a>
#      </span>
#     </li>
#    </ul>
#   </div>
#  </li>
#  <li class="bx" id="sp_nws5">
#   <div class="news_wrap api_ani_send">
#    <div class="news_area">
#     <div class="news_info">
#      <div class="api_save_group _keep_wrap">
#       <a aria-pressed="false" class="btn_save _keep_trigger" data-url="http://www.newspim.com/news/view/20230430000069" href="#" onclick="tCR('a=nws*b.kep&amp;r=5&amp;i=88000394_000000000000000002333192&amp;u=javascript'); return false;" role="button">
#        <i class="spnew ico_save">
#         문서 저장하기
#        </i>
#       </a>
#       <div class="api_ly_save _keep_save_layer">
#        <a class="spnew_af item item_save _keep_save" data-cr-off="a=nws*b.kepoff&amp;r=5&amp;i=88000394_000000000000000002333192&amp;u=javascript" data-cr-on="a=nws*b.kepon&amp;r=5&amp;i=88000394_000000000000000002333192&amp;u=javascript" href="#" role="button">
#         Keep에 저장
#        </a>
#        <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick="return goOtherCR(this,'a=nws*b.kephome&amp;r=5&amp;i=88000394_000000000000000002333192&amp;u='+urlencode(this.href));" target="_blank">
#         Keep 바로가기
#        </a>
#       </div>
#      </div>
#      <div class="info_group">
#       <a class="info press" href="http://www.newspim.com" onclick="return goOtherCR(this, 'a=nws*b.prof&amp;r=5&amp;i=88000394_000000000000000002333192&amp;g=5002.0002333192&amp;u='+urlencode(this.href));" target="_blank">
#        <span class="thumb_box">
#         <img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=http%3A%2F%2Fimg.newspim.com%2Fm%2Fmweb%2Ffavicon_144X144V2.png&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/>
#        </span>
#        뉴스핌
#       </a>
#       <span class="info">
#        5시간 전
#       </span>
#      </div>
#     </div>
#     <a class="news_tit" href="http://www.newspim.com/news/view/20230430000069" onclick="return goOtherCR(this, 'a=nws*b.tit&amp;r=5&amp;i=88000394_000000000000000002333192&amp;g=5002.0002333192&amp;u='+urlencode(this.href));" target="_blank" title="경기도의회 'ChatGPT의 현재와 미래' 특강 실시">
#      경기도의회 'ChatGPT의 현재와 미래' 특강 실시
#     </a>
#     <div class="news_dsc">
#      <div class="dsc_wrap">
#       <a class="api_txt_lines dsc_txt_wrap" href="http://www.newspim.com/news/view/20230430000069" onclick="return goOtherCR(this, 'a=nws*b.body&amp;r=5&amp;i=88000394_000000000000000002333192&amp;g=5002.0002333192&amp;u='+urlencode(this.href));" target="_blank">
#        경기도의회는 지난 28일 도의원 및 사무처 직원을 대상으로 자체교육(5차)을 진행했다고 30일 밝혔다. 경기도의회는 지난 28일 도의원 및 사무처 직원을 대상으로 자체교육(5차)을 진행했다고 30일 밝혔다. [사진...
#       </a>
#      </div>
#     </div>
#    </div>
#    <a class="dsc_thumb" href="http://www.newspim.com/news/view/20230430000069" onclick="return goOtherCR(this, 'a=nws*b.img&amp;r=5&amp;i=88000394_000000000000000002333192&amp;g=5002.0002333192&amp;u='+urlencode(this.href));" target="_blank">
#     <img alt="경기도의회 ‘ChatGPT의" class="thumb api_get" height="90" onerror="this.parentNode.style.display='none';" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F5002%2F2023%2F04%2F30%2F2333192.jpg&amp;type=ff264_180&amp;expire=2&amp;refresh=true" width="132"/>
#    </a>
#   </div>
#   <div class="news_cluster">
#    <ul class="list_cluster">
#     <li class="sub_bx">
#      <span class="sub_wrap">
#       <span class="sub_area">
#        <cite class="sub_txt press" title="에너지경제">
#         에너지경제
#        </cite>
#        <span class="sub_txt">
#         7시간 전
#        </span>
#       </span>
#       <a class="elss sub_tit" href="https://www.ekn.kr/web/view.php?key=20230430010007764" onclick="return goOtherCR(this, 'a=nws*d.tit&amp;r=6&amp;i=88102504_000000000000000000578788&amp;g=5133.0000578788&amp;u='+urlencode(this.href));" target="_blank" title="경기도의회, 도의원과 사무처 직원 대상으로 ChatGPT 특강 진행">
#        경기도의회, 도의원과 사무처 직원 대상으로 ChatGPT 특강 진행
#       </a>
#      </span>
#     </li>
#     <li class="sub_bx">
#      <span class="sub_wrap">
#       <span class="sub_area">
#        <cite class="sub_txt press" title="열린뉴스통신">
#         열린뉴스통신
#        </cite>
#        <span class="sub_txt">
#         38분 전
#        </span>
#       </span>
#       <a class="elss sub_tit" href="https://www.onews.tv/news/articleView.html?idxno=164071" onclick="return goOtherCR(this, 'a=nws*d.tit&amp;r=7&amp;i=88202ra6_000000000000000000121835&amp;g=5818.0000121835&amp;u='+urlencode(this.href));" target="_blank" title="경기도의회, 'ChatGPT의 현재와 미래' 5차 자체교육">
#        경기도의회, 'ChatGPT의 현재와 미래' 5차 자체교육
#       </a>
#      </span>
#     </li>
#    </ul>
#   </div>
#  </li>
#  <li class="bx" id="sp_nws8">
#   <div class="news_wrap api_ani_send">
#    <div class="news_area">
#     <div class="news_info">
#      <div class="api_save_group _keep_wrap">
#       <a aria-pressed="false" class="btn_save _keep_trigger" data-url="https://www.idaegu.co.kr/news/articleView.html?idxno=418679" href="#" onclick="tCR('a=nws*f.kep&amp;r=8&amp;i=88155e7b_000000000000000000256731&amp;u=javascript'); return false;" role="button">
#        <i class="spnew ico_save">
#         문서 저장하기
#        </i>
#       </a>
#       <div class="api_ly_save _keep_save_layer">
#        <a class="spnew_af item item_save _keep_save" data-cr-off="a=nws*f.kepoff&amp;r=8&amp;i=88155e7b_000000000000000000256731&amp;u=javascript" data-cr-on="a=nws*f.kepon&amp;r=8&amp;i=88155e7b_000000000000000000256731&amp;u=javascript" href="#" role="button">
#         Keep에 저장
#        </a>
#        <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick="return goOtherCR(this,'a=nws*f.kephome&amp;r=8&amp;i=88155e7b_000000000000000000256731&amp;u='+urlencode(this.href));" target="_blank">
#         Keep 바로가기
#        </a>
#       </div>
#      </div>
#      <div class="info_group">
#       <a class="info press" href="http://www.idaegu.co.kr" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=8&amp;i=88155e7b_000000000000000000256731&amp;g=5341.0000256731&amp;u='+urlencode(this.href));" target="_blank">
#        <span class="thumb_box">
#         <img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fwww.idaegu.co.kr%2Fimage%2Flogo%2Ffavicon_20180618095934.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/>
#        </span>
#        대구신문
#       </a>
#       <span class="info">
#        3시간 전
#       </span>
#      </div>
#     </div>
#     <a class="news_tit" href="https://www.idaegu.co.kr/news/articleView.html?idxno=418679" onclick="return goOtherCR(this, 'a=nws*f.tit&amp;r=8&amp;i=88155e7b_000000000000000000256731&amp;g=5341.0000256731&amp;u='+urlencode(this.href));" target="_blank" title="대구 동구청&amp;중구청, 챗(Chat) GPT를 활용한 행정혁신 강연 개최">
#      대구 동구청&amp;중구청, 챗(
#      <mark>
#       Chat
#      </mark>
#      )
#      <mark>
#       GPT
#      </mark>
#      를 활용한 행정혁신 강연 개최
#     </a>
#     <div class="news_dsc">
#      <div class="dsc_wrap">
#       <a class="api_txt_lines dsc_txt_wrap" href="https://www.idaegu.co.kr/news/articleView.html?idxno=418679" onclick="return goOtherCR(this, 'a=nws*f.body&amp;r=8&amp;i=88155e7b_000000000000000000256731&amp;g=5341.0000256731&amp;u='+urlencode(this.href));" target="_blank">
#        중구청 제공 대구 동구청과 중구청은 지난 달 27일과 28일 양일간 전 직원을 대상으로 챗(
#        <mark>
#         Chat
#        </mark>
#        )
#        <mark>
#         GPT
#        </mark>
#        를 활용한 행정혁신 강연을 개최했다. 챗
#        <mark>
#         GPT
#        </mark>
#        는 지난해 11월 미국 오픈에이아이(OpenAI)사가 개발한 대화형 인공지능...
#       </a>
#      </div>
#     </div>
#    </div>
#    <a class="dsc_thumb" href="https://www.idaegu.co.kr/news/articleView.html?idxno=418679" onclick="return goOtherCR(this, 'a=nws*f.img&amp;r=8&amp;i=88155e7b_000000000000000000256731&amp;g=5341.0000256731&amp;u='+urlencode(this.href));" target="_blank">
#     <img alt="대구 동구청&amp;중구청, " class="thumb api_get" height="90" onerror="this.parentNode.style.display='none';" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F5341%2F2023%2F04%2F30%2F256731.jpg&amp;type=ofullfill264_180_gray&amp;expire=2&amp;refresh=true" width="132"/>
#    </a>
#   </div>
#  </li>
#  <li class="bx" id="sp_nws9">
#   <div class="news_wrap api_ani_send">
#    <div class="news_area">
#     <div class="news_info">
#      <div class="api_save_group _keep_wrap">
#       <a aria-pressed="false" class="btn_save _keep_trigger" data-url="http://www.mediatoday.co.kr/news/articleView.html?idxno=309816" href="#" onclick="tCR('a=nws*j.kep&amp;r=9&amp;i=880000C5_000000000000000000117871&amp;u=javascript'); return false;" role="button">
#        <i class="spnew ico_save">
#         문서 저장하기
#        </i>
#       </a>
#       <div class="api_ly_save _keep_save_layer">
#        <a class="spnew_af item item_save _keep_save" data-cr-off="a=nws*j.kepoff&amp;r=9&amp;i=880000C5_000000000000000000117871&amp;u=javascript" data-cr-on="a=nws*j.kepon&amp;r=9&amp;i=880000C5_000000000000000000117871&amp;u=javascript" href="#" role="button">
#         Keep에 저장
#        </a>
#        <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick="return goOtherCR(this,'a=nws*j.kephome&amp;r=9&amp;i=880000C5_000000000000000000117871&amp;u='+urlencode(this.href));" target="_blank">
#         Keep 바로가기
#        </a>
#       </div>
#      </div>
#      <div class="info_group">
#       <a class="info press" href="http://www.mediatoday.co.kr/" onclick="return goOtherCR(this, 'a=nws*j.prof&amp;r=9&amp;i=880000C5_000000000000000000117871&amp;g=006.0000117871&amp;u='+urlencode(this.href));" target="_blank">
#        <span class="thumb_box">
#         <img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fmimgnews.pstatic.net%2Fimage%2Fupload%2Foffice_logo%2F006%2F2017%2F01%2F05%2Flogo_006_18_20170105111205.png&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/>
#        </span>
#        미디어오늘
#        <i class="spnew ico_pick">
#         언론사 선정
#        </i>
#       </a>
#       <span class="info">
#        1일 전
#       </span>
#       <a class="info" href="https://n.news.naver.com/mnews/article/006/0000117871?sid=101" onclick="return goOtherCR(this, 'a=nws*j.nav&amp;r=9&amp;i=880000C5_000000000000000000117871&amp;u='+urlencode(this.href));" target="_blank">
#        네이버뉴스
#       </a>
#      </div>
#     </div>
#     <a class="news_tit" href="http://www.mediatoday.co.kr/news/articleView.html?idxno=309816" onclick="return goOtherCR(this, 'a=nws*j.tit&amp;r=9&amp;i=880000C5_000000000000000000117871&amp;g=006.0000117871&amp;u='+urlencode(this.href));" target="_blank" title="챗GPT와 함께 소설 쓰기 과정은 이랬다">
#      챗
#      <mark>
#       GPT
#      </mark>
#      와 함께 소설 쓰기 과정은 이랬다
#     </a>
#     <div class="news_dsc">
#      <div class="dsc_wrap">
#       <a class="api_txt_lines dsc_txt_wrap" href="http://www.mediatoday.co.kr/news/articleView.html?idxno=309816" onclick="return goOtherCR(this, 'a=nws*j.body&amp;r=9&amp;i=880000C5_000000000000000000117871&amp;g=006.0000117871&amp;u='+urlencode(this.href));" target="_blank">
#        이 책은 챗
#        <mark>
#         GPT
#        </mark>
#        와 인간 작가가 공동 집필한 국내 첫 소설집이다. 책은 작가별 단편 소설이 나온 다음 챗
#        <mark>
#         GPT
#        </mark>
#        와 어떻게 협업했는지 과정을 '협업일지'와 '협업후기' 형식으로 담았다. 책을 기획한 자음과모음 출판사의 박진혜...
#       </a>
#      </div>
#     </div>
#    </div>
#    <a class="dsc_thumb" href="http://www.mediatoday.co.kr/news/articleView.html?idxno=309816" onclick="return goOtherCR(this, 'a=nws*j.img&amp;r=9&amp;i=880000C5_000000000000000000117871&amp;g=006.0000117871&amp;u='+urlencode(this.href));" target="_blank">
#     <img alt="챗GPT와 함께 소설 쓰" class="thumb api_get" height="90" onerror="this.parentNode.style.display='none';" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F006%2F2023%2F04%2F29%2F117871.jpg&amp;type=ff264_180&amp;expire=2&amp;refresh=true" width="132"/>
#    </a>
#   </div>
#  </li>
#  <li class="bx" id="sp_nws10">
#   <div class="news_wrap api_ani_send">
#    <div class="news_area">
#     <div class="news_info">
#      <div class="api_save_group _keep_wrap">
#       <a aria-pressed="false" class="btn_save _keep_trigger" data-url="https://www.dailian.co.kr/news/view/1228765/?sc=Naver" href="#" onclick="tCR('a=nws*a.kep&amp;r=10&amp;i=8812A0A8_000000000000000002707906&amp;u=javascript'); return false;" role="button">
#        <i class="spnew ico_save">
#         문서 저장하기
#        </i>
#       </a>
#       <div class="api_ly_save _keep_save_layer">
#        <a class="spnew_af item item_save _keep_save" data-cr-off="a=nws*a.kepoff&amp;r=10&amp;i=8812A0A8_000000000000000002707906&amp;u=javascript" data-cr-on="a=nws*a.kepon&amp;r=10&amp;i=8812A0A8_000000000000000002707906&amp;u=javascript" href="#" role="button">
#         Keep에 저장
#        </a>
#        <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick="return goOtherCR(this,'a=nws*a.kephome&amp;r=10&amp;i=8812A0A8_000000000000000002707906&amp;u='+urlencode(this.href));" target="_blank">
#         Keep 바로가기
#        </a>
#       </div>
#      </div>
#      <div class="info_group">
#       <a class="info press" href="http://www.dailian.co.kr/" onclick="return goOtherCR(this, 'a=nws*a.prof&amp;r=10&amp;i=8812A0A8_000000000000000002707906&amp;g=119.0002707906&amp;u='+urlencode(this.href));" target="_blank">
#        <span class="thumb_box">
#         <img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fmimgnews.pstatic.net%2Fimage%2Fupload%2Foffice_logo%2F119%2F2023%2F03%2F17%2Flogo_119_18_20230317161152.jpg&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/>
#        </span>
#        데일리안
#       </a>
#       <span class="info">
#        2일 전
#       </span>
#       <a class="info" href="https://n.news.naver.com/mnews/article/119/0002707906?sid=004" onclick="return goOtherCR(this, 'a=nws*a.nav&amp;r=10&amp;i=8812A0A8_000000000000000002707906&amp;u='+urlencode(this.href));" target="_blank">
#        네이버뉴스
#       </a>
#      </div>
#     </div>
#     <a class="news_tit" href="https://www.dailian.co.kr/news/view/1228765/?sc=Naver" onclick="return goOtherCR(this, 'a=nws*a.tit&amp;r=10&amp;i=8812A0A8_000000000000000002707906&amp;g=119.0002707906&amp;u='+urlencode(this.href));" target="_blank" title="화성시, ChatGPT 활용연구 TF팀 출범">
#      화성시, ChatGPT 활용연구 TF팀 출범
#     </a>
#     <div class="news_dsc">
#      <div class="dsc_wrap">
#       <a class="api_txt_lines dsc_txt_wrap" href="https://www.dailian.co.kr/news/view/1228765/?sc=Naver" onclick="return goOtherCR(this, 'a=nws*a.body&amp;r=10&amp;i=8812A0A8_000000000000000002707906&amp;g=119.0002707906&amp;u='+urlencode(this.href));" target="_blank">
#        경기 화성시가 ChatGPT를 활용한 스마트 행정 추진을 위해 전담팀(TF)을 구성하고 28일, 근로자복지회관에서 ChatGPT 활용연구 TF 출범식을 개최했다. TF팀은 기획조정실장을 단장, 스마트도시과장을 부단장으로...
#       </a>
#      </div>
#     </div>
#    </div>
#    <a class="dsc_thumb" href="https://www.dailian.co.kr/news/view/1228765/?sc=Naver" onclick="return goOtherCR(this, 'a=nws*a.img&amp;r=10&amp;i=8812A0A8_000000000000000002707906&amp;g=119.0002707906&amp;u='+urlencode(this.href));" target="_blank">
#     <img alt="화성시, ChatGPT 활용" class="thumb api_get" height="90" onerror="this.parentNode.style.display='none';" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F119%2F2023%2F04%2F28%2F2707906.jpg&amp;type=ofullfill264_180_gray&amp;expire=2&amp;refresh=true" width="132"/>
#    </a>
#   </div>
#   <div class="news_cluster">
#    <ul class="list_cluster">
#     <li class="sub_bx">
#      <span class="sub_wrap">
#       <span class="sub_area">
#        <cite class="sub_txt press" title="대한경제">
#         대한경제
#        </cite>
#        <span class="sub_txt">
#         2일 전
#        </span>
#       </span>
#       <a class="elss sub_tit" href="https://www.dnews.co.kr/uhtml/view.jsp?idxno=202304281737548950693" onclick="return goOtherCR(this, 'a=nws*d.tit&amp;r=11&amp;i=88105698_000000000000000000451347&amp;g=5138.0000451347&amp;u='+urlencode(this.href));" target="_blank" title="화성시, 스마트 행정은 ChatGPT로">
#        화성시, 스마트 행정은 ChatGPT로
#       </a>
#      </span>
#     </li>
#     <li class="sub_bx">
#      <span class="sub_wrap">
#       <span class="sub_area">
#        <cite class="sub_txt press" title="에너지경제">
#         에너지경제
#        </cite>
#        <span class="sub_txt">
#         2일 전
#        </span>
#       </span>
#       <a class="elss sub_tit" href="https://www.ekn.kr/web/view.php?key=20230428010007594" onclick="return goOtherCR(this, 'a=nws*d.tit&amp;r=12&amp;i=88102504_000000000000000000578618&amp;g=5133.0000578618&amp;u='+urlencode(this.href));" target="_blank" title="화성시, Chat GPT 활용연구 TF팀 출범식 개최">
#        화성시,
#        <mark>
#         Chat
#        </mark>
#        <mark>
#         GPT
#        </mark>
#        활용연구 TF팀 출범식 개최
#       </a>
#      </span>
#     </li>
#     <li class="sub_bx">
#      <span class="sub_wrap">
#       <span class="sub_area">
#        <cite class="sub_txt press" title="위클리오늘">
#         위클리오늘
#        </cite>
#        <span class="sub_txt">
#         2일 전
#        </span>
#       </span>
#       <a class="elss sub_tit" href="http://www.weeklytoday.com/news/articleView.html?idxno=567824" onclick="return goOtherCR(this, 'a=nws*d.tit&amp;r=13&amp;i=8813C2D2_000000000000000000281685&amp;g=5294.0000281685&amp;u='+urlencode(this.href));" target="_blank" title="화성시, ChatGPT 활용연구 TF 출범식 개최">
#        화성시, ChatGPT 활용연구 TF 출범식 개최
#       </a>
#      </span>
#     </li>
#     <li class="sub_bx">
#      <span class="sub_wrap">
#       <span class="sub_area">
#        <cite class="sub_txt press" title="NSP통신">
#         NSP통신
#        </cite>
#        <span class="sub_txt">
#         2일 전
#        </span>
#       </span>
#       <a class="elss sub_tit" href="https://www.nspna.com/news/?mode=view&amp;newsid=634625" onclick="return goOtherCR(this, 'a=nws*d.tit&amp;r=14&amp;i=880003F1_000000000000000000606368&amp;g=5025.0000606368&amp;u='+urlencode(this.href));" target="_blank" title="화성시, 행정에 부는 챗GPT 바람…활용연구TF출범">
#        화성시, 행정에 부는 챗
#        <mark>
#         GPT
#        </mark>
#        바람…활용연구TF출범
#       </a>
#      </span>
#     </li>
#    </ul>
#   </div>
#  </li>
#  <li class="bx" id="sp_nws15">
#   <div class="news_wrap api_ani_send">
#    <div class="news_area">
#     <div class="news_info">
#      <div class="api_save_group _keep_wrap">
#       <a aria-pressed="false" class="btn_save _keep_trigger" data-url="http://www.newsis.com/view/?id=NISX20230427_0002282419&amp;cID=10811&amp;pID=10800" href="#" onclick="tCR('a=nws*a.kep&amp;r=15&amp;i=88000127_000000000000000011826825&amp;u=javascript'); return false;" role="button">
#        <i class="spnew ico_save">
#         문서 저장하기
#        </i>
#       </a>
#       <div class="api_ly_save _keep_save_layer">
#        <a class="spnew_af item item_save _keep_save" data-cr-off="a=nws*a.kepoff&amp;r=15&amp;i=88000127_000000000000000011826825&amp;u=javascript" data-cr-on="a=nws*a.kepon&amp;r=15&amp;i=88000127_000000000000000011826825&amp;u=javascript" href="#" role="button">
#         Keep에 저장
#        </a>
#        <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick="return goOtherCR(this,'a=nws*a.kephome&amp;r=15&amp;i=88000127_000000000000000011826825&amp;u='+urlencode(this.href));" target="_blank">
#         Keep 바로가기
#        </a>
#       </div>
#      </div>
#      <div class="info_group">
#       <a class="info press" href="http://www.newsis.com" onclick="return goOtherCR(this, 'a=nws*a.prof&amp;r=15&amp;i=88000127_000000000000000011826825&amp;g=003.0011826825&amp;u='+urlencode(this.href));" target="_blank">
#        <span class="thumb_box">
#         <img alt="" class="thumb" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fmimgnews.pstatic.net%2Fimage%2Fupload%2Foffice_logo%2F003%2F2019%2F02%2F19%2Flogo_003_18_20190219111719.jpg&amp;type=f54_54&amp;expire=24&amp;refresh=true" data-obstatus="ob-once" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="..." width="20"/>
#        </span>
#        뉴시스
#       </a>
#       <span class="info">
#        3일 전
#       </span>
#       <a class="info" href="https://n.news.naver.com/mnews/article/003/0011826825?sid=102" onclick="return goOtherCR(this, 'a=nws*a.nav&amp;r=15&amp;i=88000127_000000000000000011826825&amp;u='+urlencode(this.href));" target="_blank">
#        네이버뉴스
#       </a>
#      </div>
#     </div>
#     <a class="news_tit" href="http://www.newsis.com/view/?id=NISX20230427_0002282419&amp;cID=10811&amp;pID=10800" onclick="return goOtherCR(this, 'a=nws*a.tit&amp;r=15&amp;i=88000127_000000000000000011826825&amp;g=003.0011826825&amp;u='+urlencode(this.href));" target="_blank" title="DX포럼, ‘ChatGPT 활용 사례로 보는 인공지능과 데이터의 미래’">
#      DX포럼, ‘ChatGPT 활용 사례로 보는 인공지능과 데이터의 미래’
#     </a>
#     <div class="news_dsc">
#      <div class="dsc_wrap">
#       <a class="api_txt_lines dsc_txt_wrap" href="http://www.newsis.com/view/?id=NISX20230427_0002282419&amp;cID=10811&amp;pID=10800" onclick="return goOtherCR(this, 'a=nws*a.body&amp;r=15&amp;i=88000127_000000000000000011826825&amp;g=003.0011826825&amp;u='+urlencode(this.href));" target="_blank">
#        기사내용 요약 27일 오후 6시 부산빅데이터혁신센터 ‘제7회 디지털 전환 포럼(DX포럼)‘이 27일 오후 6시 해운대 부산빅데이터혁신센터에서 ‘ChatGPT 활용 사례로 보는 인공지능과 데이터의 미래’를 주제로 열린다....
#       </a>
#      </div>
#     </div>
#    </div>
#    <a class="dsc_thumb" href="http://www.newsis.com/view/?id=NISX20230427_0002282419&amp;cID=10811&amp;pID=10800" onclick="return goOtherCR(this, 'a=nws*a.img&amp;r=15&amp;i=88000127_000000000000000011826825&amp;g=003.0011826825&amp;u='+urlencode(this.href));" target="_blank">
#     <img alt="DX포럼, ‘ChatGPT 활" class="thumb api_get" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F003%2F2023%2F04%2F27%2F11826825.jpg&amp;type=ff264_180&amp;expire=2&amp;refresh=true" data-obstatus="ob-once" height="90" onerror="this.parentNode.style.display='none';" src="..." width="132"/>
#    </a>
#   </div>
#   <div class="news_cluster">
#    <ul class="list_cluster">
#     <li class="sub_bx">
#      <span class="sub_wrap">
#       <span class="sub_area">
#        <cite class="sub_txt press" title="뉴스1">
#         뉴스1
#        </cite>
#        <span class="sub_txt">
#         3일 전
#        </span>
#        <a class="sub_txt" href="https://n.news.naver.com/mnews/article/421/0006772755?sid=102" onclick="return goOtherCR(this, 'a=nws*c.nav&amp;r=16&amp;i=08138263_000000000000000006772755&amp;u='+urlencode(this.href));" target="_blank">
#         네이버뉴스
#        </a>
#       </span>
#       <a class="elss sub_tit" href="https://www.news1.kr/articles/5029003" onclick="return goOtherCR(this, 'a=nws*c.tit&amp;r=16&amp;i=08138263_000000000000000006772755&amp;g=421.0006772755&amp;u='+urlencode(this.href));" target="_blank" title="부산빅데이터혁신센터, 27일 디지털 전환 포럼 개최">
#        부산빅데이터혁신센터, 27일 디지털 전환 포럼 개최
#       </a>
#      </span>
#     </li>
#    </ul>
#   </div>
#  </li>
#  <li class="bx" id="sp_nws17">
#   <div class="news_wrap api_ani_send">
#    <div class="news_area">
#     <div class="news_info">
#      <div class="api_save_group _keep_wrap">
#       <a aria-pressed="false" class="btn_save _keep_trigger" data-url="https://n.news.naver.com/mnews/article/077/0005927161?sid=104" href="#" onclick="tCR('a=nws*e.kep&amp;r=17&amp;i=880000DD_000000000000000005927161&amp;u=javascript'); return false;" role="button">
#        <i class="spnew ico_save">
#         문서 저장하기
#        </i>
#       </a>
#       <div class="api_ly_save _keep_save_layer">
#        <a class="spnew_af item item_save _keep_save" data-cr-off="a=nws*e.kepoff&amp;r=17&amp;i=880000DD_000000000000000005927161&amp;u=javascript" data-cr-on="a=nws*e.kepon&amp;r=17&amp;i=880000DD_000000000000000005927161&amp;u=javascript" href="#" role="button">
#         Keep에 저장
#        </a>
#        <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick="return goOtherCR(this,'a=nws*e.kephome&amp;r=17&amp;i=880000DD_000000000000000005927161&amp;u='+urlencode(this.href));" target="_blank">
#         Keep 바로가기
#        </a>
#       </div>
#      </div>
#      <div class="info_group">
#       <a class="info press" href="https://en.yna.co.kr/image/index" onclick="return goOtherCR(this, 'a=nws*e.prof&amp;r=17&amp;i=880000DD_000000000000000005927161&amp;g=&amp;u='+urlencode(this.href));" target="_blank">
#        <span class="thumb_box">
#         <img alt="" class="thumb bg_default_press" data-lazysrc="..." data-obstatus="ob-once" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="..." width="20"/>
#        </span>
#        AP연합뉴스
#       </a>
#       <span class="info">
#        1일 전
#       </span>
#       <a class="info" href="https://n.news.naver.com/mnews/article/077/0005927161?sid=104" onclick="return goOtherCR(this, 'a=nws*e.nav&amp;r=17&amp;i=880000DD_000000000000000005927161&amp;u='+urlencode(this.href));" target="_blank">
#        네이버뉴스
#       </a>
#      </div>
#     </div>
#     <a class="news_tit" href="https://n.news.naver.com/mnews/article/077/0005927161?sid=104" onclick="return goOtherCR(this, 'a=nws*e.tit&amp;r=17&amp;i=880000DD_000000000000000005927161&amp;g=&amp;u='+urlencode(this.href));" target="_blank" title="Italy ChatGPT">
#      Italy ChatGPT
#     </a>
#     <div class="news_dsc">
#      <div class="dsc_wrap">
#       <a class="api_txt_lines dsc_txt_wrap" href="https://n.news.naver.com/mnews/article/077/0005927161?sid=104" onclick="return goOtherCR(this, 'a=nws*e.body&amp;r=17&amp;i=880000DD_000000000000000005927161&amp;g=&amp;u='+urlencode(this.href));" target="_blank">
#        FILE - The OpenAI logo is seen on a mobile phone in front of a computer screen which displays the ChatGPT home Screen, on March 17, 2023, in Boston. ChatGPT's maker said Friday April 28, 2023...
#       </a>
#      </div>
#     </div>
#    </div>
#    <a class="dsc_thumb" href="https://n.news.naver.com/mnews/article/077/0005927161?sid=104" onclick="return goOtherCR(this, 'a=nws*e.img&amp;r=17&amp;i=880000DD_000000000000000005927161&amp;g=&amp;u='+urlencode(this.href));" target="_blank">
#     <img alt="Italy ChatGPT" class="thumb api_get" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F077%2F2023%2F04%2F29%2F5927161.jpg&amp;type=ff264_180&amp;expire=2&amp;refresh=true" data-obstatus="ob-once" height="90" onerror="this.parentNode.style.display='none';" src="..." width="132"/>
#    </a>
#   </div>
#  </li>
#  <li class="bx" id="sp_nws18">
#   <div class="news_wrap api_ani_send">
#    <div class="news_area">
#     <div class="news_info">
#      <div class="api_save_group _keep_wrap">
#       <a aria-pressed="false" class="btn_save _keep_trigger" data-url="https://www.news1.kr/articles/5029548" href="#" onclick="tCR('a=nws*a.kep&amp;r=18&amp;i=08138263_000000000000000006773571&amp;u=javascript'); return false;" role="button">
#        <i class="spnew ico_save">
#         문서 저장하기
#        </i>
#       </a>
#       <div class="api_ly_save _keep_save_layer">
#        <a class="spnew_af item item_save _keep_save" data-cr-off="a=nws*a.kepoff&amp;r=18&amp;i=08138263_000000000000000006773571&amp;u=javascript" data-cr-on="a=nws*a.kepon&amp;r=18&amp;i=08138263_000000000000000006773571&amp;u=javascript" href="#" role="button">
#         Keep에 저장
#        </a>
#        <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick="return goOtherCR(this,'a=nws*a.kephome&amp;r=18&amp;i=08138263_000000000000000006773571&amp;u='+urlencode(this.href));" target="_blank">
#         Keep 바로가기
#        </a>
#       </div>
#      </div>
#      <div class="info_group">
#       <a class="info press" href="http://news1.kr/" onclick="return goOtherCR(this, 'a=nws*a.prof&amp;r=18&amp;i=08138263_000000000000000006773571&amp;g=421.0006773571&amp;u='+urlencode(this.href));" target="_blank">
#        <span class="thumb_box">
#         <img alt="" class="thumb" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fmimgnews.pstatic.net%2Fimage%2Fupload%2Foffice_logo%2F421%2F2017%2F01%2F05%2Flogo_421_18_20170105111205.png&amp;type=f54_54&amp;expire=24&amp;refresh=true" data-obstatus="ob-once" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="..." width="20"/>
#        </span>
#        뉴스1
#       </a>
#       <span class="info">
#        3일 전
#       </span>
#       <a class="info" href="https://n.news.naver.com/mnews/article/421/0006773571?sid=105" onclick="return goOtherCR(this, 'a=nws*a.nav&amp;r=18&amp;i=08138263_000000000000000006773571&amp;u='+urlencode(this.href));" target="_blank">
#        네이버뉴스
#       </a>
#      </div>
#     </div>
#     <a class="news_tit" href="https://www.news1.kr/articles/5029548" onclick="return goOtherCR(this, 'a=nws*a.tit&amp;r=18&amp;i=08138263_000000000000000006773571&amp;g=421.0006773571&amp;u='+urlencode(this.href));" target="_blank" title="카톡 챗GPT '아숙업' 만든 업스테이지, 활용 비법 알려준다">
#      카톡 챗
#      <mark>
#       GPT
#      </mark>
#      '아숙업' 만든 업스테이지, 활용 비법 알려준다
#     </a>
#     <div class="news_dsc">
#      <div class="dsc_wrap">
#       <a class="api_txt_lines dsc_txt_wrap" href="https://www.news1.kr/articles/5029548" onclick="return goOtherCR(this, 'a=nws*a.body&amp;r=18&amp;i=08138263_000000000000000006773571&amp;g=421.0006773571&amp;u='+urlencode(this.href));" target="_blank">
#        채팅형 인공지능(AI) 아숙업(AskUp) 제작사 업스테이지가 챗
#        <mark>
#         GPT
#        </mark>
#        활용 비법과 이를 활용해 직접 서비스를 만드는 교육을 선보인다. AI 스타트업 업스테이지는 챗
#        <mark>
#         GPT
#        </mark>
#        활용 서비스 기획과 활용 비법을 알려주는 온라인...
#       </a>
#      </div>
#     </div>
#    </div>
#    <a class="dsc_thumb" href="https://www.news1.kr/articles/5029548" onclick="return goOtherCR(this, 'a=nws*a.img&amp;r=18&amp;i=08138263_000000000000000006773571&amp;g=421.0006773571&amp;u='+urlencode(this.href));" target="_blank">
#     <img alt="카톡 챗GPT ‘아숙업‘ " class="thumb api_get" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F421%2F2023%2F04%2F27%2F6773571.jpg&amp;type=ff264_180&amp;expire=2&amp;refresh=true" data-obstatus="ob-once" height="90" onerror="this.parentNode.style.display='none';" src="..." width="132"/>
#    </a>
#   </div>
#   <div class="news_cluster">
#    <ul class="list_cluster">
#     <li class="sub_bx">
#      <span class="sub_wrap">
#       <span class="sub_area">
#        <cite class="sub_txt press" title="뉴시스">
#         뉴시스
#        </cite>
#        <span class="sub_txt">
#         3일 전
#        </span>
#        <a class="sub_txt" href="https://n.news.naver.com/mnews/article/003/0011826923?sid=105" onclick="return goOtherCR(this, 'a=nws*c.nav&amp;r=19&amp;i=88000127_000000000000000011826923&amp;u='+urlencode(this.href));" target="_blank">
#         네이버뉴스
#        </a>
#       </span>
#       <a class="elss sub_tit" href="http://www.newsis.com/view/?id=NISX20230427_0002282520&amp;cID=10406&amp;pID=13100" onclick="return goOtherCR(this, 'a=nws*c.tit&amp;r=19&amp;i=88000127_000000000000000011826923&amp;g=003.0011826923&amp;u='+urlencode(this.href));" target="_blank" title='"챗GPT 활용비법 알려준다" 아숙업 만든 업스테이지'>
#        "챗
#        <mark>
#         GPT
#        </mark>
#        활용비법 알려준다" 아숙업 만든 업스테이지
#       </a>
#      </span>
#     </li>
#     <li class="sub_bx">
#      <span class="sub_wrap">
#       <span class="sub_area">
#        <cite class="sub_txt press" title="데일리안">
#         데일리안
#        </cite>
#        <span class="sub_txt">
#         3일 전
#        </span>
#        <a class="sub_txt" href="https://n.news.naver.com/mnews/article/119/0002707019?sid=105" onclick="return goOtherCR(this, 'a=nws*c.nav&amp;r=20&amp;i=8812A0A8_000000000000000002707019&amp;u='+urlencode(this.href));" target="_blank">
#         네이버뉴스
#        </a>
#       </span>
#       <a class="elss sub_tit" href="https://www.dailian.co.kr/news/view/1227756/?sc=Naver" onclick="return goOtherCR(this, 'a=nws*c.tit&amp;r=20&amp;i=8812A0A8_000000000000000002707019&amp;g=119.0002707019&amp;u='+urlencode(this.href));" target="_blank" title="업스테이지, 챗GPT 활용 비법 알린다…‘ChatGPT UP’ 강의 개설">
#        업스테이지, 챗
#        <mark>
#         GPT
#        </mark>
#        활용 비법 알린다…‘ChatGPT UP’ 강의 개설
#       </a>
#      </span>
#     </li>
#     <li class="sub_bx">
#      <span class="sub_wrap">
#       <span class="sub_area">
#        <cite class="sub_txt press" title="뉴스핌">
#         뉴스핌
#        </cite>
#        <span class="sub_txt">
#         3일 전
#        </span>
#       </span>
#       <a class="elss sub_tit" href="http://www.newspim.com/news/view/20230427000143" onclick="return goOtherCR(this, 'a=nws*d.tit&amp;r=21&amp;i=88000394_000000000000000002330946&amp;g=5002.0002330946&amp;u='+urlencode(this.href));" target="_blank" title="업스테이지, 챗GPT 활용비법 알려주는 'ChatGPT UP' 강의 개설">
#        업스테이지, 챗
#        <mark>
#         GPT
#        </mark>
#        활용비법 알려주는 'ChatGPT UP' 강의 개설
#       </a>
#      </span>
#     </li>
#     <li class="sub_bx">
#      <span class="sub_wrap">
#       <span class="sub_area">
#        <cite class="sub_txt press" title="문화일보">
#         문화일보
#        </cite>
#        <span class="sub_txt">
#         3일 전
#        </span>
#        <a class="sub_txt" href="https://n.news.naver.com/mnews/article/021/0002568885?sid=101" onclick="return goOtherCR(this, 'a=nws*c.nav&amp;r=22&amp;i=880000C4_000000000000000002568885&amp;u='+urlencode(this.href));" target="_blank">
#         네이버뉴스
#        </a>
#       </span>
#       <a class="elss sub_tit" href="https://www.munhwa.com/news/view.html?no=2023042701039907275002" onclick="return goOtherCR(this, 'a=nws*c.tit&amp;r=22&amp;i=880000C4_000000000000000002568885&amp;g=021.0002568885&amp;u='+urlencode(this.href));" target="_blank" title="업스테이지, 챗GPT로 앱 만드는 법 강의한다">
#        업스테이지, 챗
#        <mark>
#         GPT
#        </mark>
#        로 앱 만드는 법 강의한다
#       </a>
#      </span>
#     </li>
#    </ul>
#   </div>
#   <a class="news_more" href="?where=news&amp;sm=tab_tnw&amp;query=%7Bchatgpt%7D&amp;sort=0&amp;photo=0&amp;field=0&amp;pd=0&amp;ds=&amp;de=&amp;mynews=0&amp;office_type=0&amp;office_section_code=0&amp;news_office_checked=&amp;related=1&amp;docid=4210006773571&amp;nso=so:r,p:all,a:all" onclick="return goOtherCR(this, 'a=nws*r.more&amp;u='+urlencode(urlexpand(this.href)));">
#    관련뉴스 10건 전체보기
#    <i class="spnew ico_arrow">
#    </i>
#   </a>
#  </li>
#  <li class="bx" id="sp_nws23">
#   <div class="news_wrap api_ani_send">
#    <div class="news_area">
#     <div class="news_info">
#      <div class="api_save_group _keep_wrap">
#       <a aria-pressed="false" class="btn_save _keep_trigger" data-url="https://www.donga.com/news/Economy/article/all/20230426/119007018/1" href="#" onclick="tCR('a=nws*j.kep&amp;r=23&amp;i=880000A9_000000000000000003493687&amp;u=javascript'); return false;" role="button">
#        <i class="spnew ico_save">
#         문서 저장하기
#        </i>
#       </a>
#       <div class="api_ly_save _keep_save_layer">
#        <a class="spnew_af item item_save _keep_save" data-cr-off="a=nws*j.kepoff&amp;r=23&amp;i=880000A9_000000000000000003493687&amp;u=javascript" data-cr-on="a=nws*j.kepon&amp;r=23&amp;i=880000A9_000000000000000003493687&amp;u=javascript" href="#" role="button">
#         Keep에 저장
#        </a>
#        <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick="return goOtherCR(this,'a=nws*j.kephome&amp;r=23&amp;i=880000A9_000000000000000003493687&amp;u='+urlencode(this.href));" target="_blank">
#         Keep 바로가기
#        </a>
#       </div>
#      </div>
#      <div class="info_group">
#       <a class="info press" href="http://www.donga.com/" onclick="return goOtherCR(this, 'a=nws*j.prof&amp;r=23&amp;i=880000A9_000000000000000003493687&amp;g=020.0003493687&amp;u='+urlencode(this.href));" target="_blank">
#        <span class="thumb_box">
#         <img alt="" class="thumb" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fmimgnews.pstatic.net%2Fimage%2Fupload%2Foffice_logo%2F020%2F2017%2F01%2F05%2Flogo_020_18_20170105111205.png&amp;type=f54_54&amp;expire=24&amp;refresh=true" data-obstatus="ob-once" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="..." width="20"/>
#        </span>
#        동아일보
#        <i class="spnew ico_pick">
#         언론사 선정
#        </i>
#       </a>
#       <span class="info">
#        <i class="spnew ico_paper">
#        </i>
#        A12면 1단
#       </span>
#       <span class="info">
#        4일 전
#       </span>
#       <a class="info" href="https://n.news.naver.com/mnews/article/020/0003493687?sid=101" onclick="return goOtherCR(this, 'a=nws*j.nav&amp;r=23&amp;i=880000A9_000000000000000003493687&amp;u='+urlencode(this.href));" target="_blank">
#        네이버뉴스
#       </a>
#      </div>
#     </div>
#     <a class="news_tit" href="https://www.donga.com/news/Economy/article/all/20230426/119007018/1" onclick="return goOtherCR(this, 'a=nws*j.tit&amp;r=23&amp;i=880000A9_000000000000000003493687&amp;g=020.0003493687&amp;u='+urlencode(this.href));" target="_blank" title="‘○○GPT’ 명칭 함부로 못쓴다… 개발사, 상표권 출원">
#      ‘○○
#      <mark>
#       GPT
#      </mark>
#      ’ 명칭 함부로 못쓴다… 개발사, 상표권 출원
#     </a>
#     <div class="news_dsc">
#      <div class="dsc_wrap">
#       <a class="api_txt_lines dsc_txt_wrap" href="https://www.donga.com/news/Economy/article/all/20230426/119007018/1" onclick="return goOtherCR(this, 'a=nws*j.body&amp;r=23&amp;i=880000A9_000000000000000003493687&amp;g=020.0003493687&amp;u='+urlencode(this.href));" target="_blank">
#        앞으로 ‘
#        <mark>
#         GPT
#        </mark>
#        ’를 붙인 인공지능(AI) 서비스명을 사용하기 어려워질 것으로 전망된다. 챗
#        <mark>
#         GPT
#        </mark>
#        를 개발한 오픈AI가 상표권을 내세워 챗
#        <mark>
#         GPT
#        </mark>
#        의 API를 사용한 서비스 명칭 가이드라인을 제시했기 때문이다. 오픈AI는...
#       </a>
#      </div>
#     </div>
#    </div>
#    <a class="dsc_thumb" href="https://www.donga.com/news/Economy/article/all/20230426/119007018/1" onclick="return goOtherCR(this, 'a=nws*j.img&amp;r=23&amp;i=880000A9_000000000000000003493687&amp;g=020.0003493687&amp;u='+urlencode(this.href));" target="_blank">
#     <img alt="‘○○GPT’ 명칭 함부" class="thumb api_get" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F020%2F2023%2F04%2F26%2F3493687.jpg&amp;type=ff264_180&amp;expire=2&amp;refresh=true" data-obstatus="ob-once" height="90" onerror="this.parentNode.style.display='none';" src="..." width="132"/>
#    </a>
#   </div>
#  </li>
#  <li class="bx" id="sp_nws24">
#   <div class="news_wrap api_ani_send">
#    <div class="news_area">
#     <div class="news_info">
#      <div class="api_save_group _keep_wrap">
#       <a aria-pressed="false" class="btn_save _keep_trigger" data-url="http://www.kbsm.net/news/view.php?idx=389951" href="#" onclick="tCR('a=nws*f.kep&amp;r=24&amp;i=8817ca6c_000000000000000000209563&amp;u=javascript'); return false;" role="button">
#        <i class="spnew ico_save">
#         문서 저장하기
#        </i>
#       </a>
#       <div class="api_ly_save _keep_save_layer">
#        <a class="spnew_af item item_save _keep_save" data-cr-off="a=nws*f.kepoff&amp;r=24&amp;i=8817ca6c_000000000000000000209563&amp;u=javascript" data-cr-on="a=nws*f.kepon&amp;r=24&amp;i=8817ca6c_000000000000000000209563&amp;u=javascript" href="#" role="button">
#         Keep에 저장
#        </a>
#        <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick="return goOtherCR(this,'a=nws*f.kephome&amp;r=24&amp;i=8817ca6c_000000000000000000209563&amp;u='+urlencode(this.href));" target="_blank">
#         Keep 바로가기
#        </a>
#       </div>
#      </div>
#      <div class="info_group">
#       <a class="info press" href="http://www.kbsm.net" onclick="return goOtherCR(this, 'a=nws*f.prof&amp;r=24&amp;i=8817ca6c_000000000000000000209563&amp;g=5533.0000209563&amp;u='+urlencode(this.href));" target="_blank">
#        <span class="thumb_box">
#         <img alt="" class="thumb" data-lazysrc="https://search.pstatic.net/common/?src=http%3A%2F%2Fwww.kbsm.net%2Ffavicon.ico&amp;type=f54_54&amp;expire=24&amp;refresh=true" data-obstatus="ob-once" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="..." width="20"/>
#        </span>
#        경북신문
#       </a>
#       <span class="info">
#        8시간 전
#       </span>
#      </div>
#     </div>
#     <a class="news_tit" href="http://www.kbsm.net/news/view.php?idx=389951" onclick="return goOtherCR(this, 'a=nws*f.tit&amp;r=24&amp;i=8817ca6c_000000000000000000209563&amp;g=5533.0000209563&amp;u='+urlencode(this.href));" target="_blank" title="대구 동구, 챗GPT 활용 행정혁신 추진">
#      대구 동구, 챗
#      <mark>
#       GPT
#      </mark>
#      활용 행정혁신 추진
#     </a>
#     <div class="news_dsc">
#      <div class="dsc_wrap">
#       <a class="api_txt_lines dsc_txt_wrap" href="http://www.kbsm.net/news/view.php?idx=389951" onclick="return goOtherCR(this, 'a=nws*f.body&amp;r=24&amp;i=8817ca6c_000000000000000000209563&amp;g=5533.0000209563&amp;u='+urlencode(this.href));" target="_blank">
#        대구 동구가 지난 27일 전 직원을 대상으로 챗지피티(ChatGPT)를 이해하고 활용할 수 있는 강연을 열었다. 챗지피티는 오픈AI에서 개발한 대화형 인공지능 언어 모델이다. 이를 활용하면 문서 작성, 정보 검색, 민원 처리...
#       </a>
#      </div>
#     </div>
#    </div>
#    <a class="dsc_thumb" href="http://www.kbsm.net/news/view.php?idx=389951" onclick="return goOtherCR(this, 'a=nws*f.img&amp;r=24&amp;i=8817ca6c_000000000000000000209563&amp;g=5533.0000209563&amp;u='+urlencode(this.href));" target="_blank">
#     <img alt="대구 동구, 챗GPT 활용" class="thumb api_get" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F5533%2F2023%2F04%2F30%2F209563.jpg&amp;type=ofullfill264_180_gray&amp;expire=2&amp;refresh=true" data-obstatus="ob-once" height="90" onerror="this.parentNode.style.display='none';" src="..." width="132"/>
#    </a>
#   </div>
#  </li>
# </ul>

# %%
import requests
from pandas import DataFrame
from bs4 import BeautifulSoup
import re
from datetime import datetime
import os

date = str(datetime.now())
date = date[:date.rfind(':')].replace(' ', '_')
date = date.replace(':','시') + '분'

query = input('검색 키워드를 입력하세요 : ')
news_num = int(input('총 필요한 뉴스기사 수를 입력해주세요(숫자만 입력) : '))
query = query.replace(' ', '+') # 검색 키워드 공백 처리

news_url = 'https://search.naver.com/search.naver?where=news&sm=tab_jum&query={}'

req = requests.get(news_url.format(query)) # format() 메서드를 사용하여 {} 부분을 query 변수로 대체
soup = BeautifulSoup(req.text, 'html.parser')


news_dict = {}
idx = 0
cur_page = 1

print()
print('크롤링 중...')

while idx < news_num:
### 네이버 뉴스 웹페이지 구성이 바뀌어 태그명, class 속성 값 등을 수정###

    table = soup.find('ul',{'class' : 'list_news'})
    li_list = table.find_all('li', {'id': re.compile('sp_nws.*')})
    area_list = [li.find('div', {'class' : 'news_area'}) for li in li_list]
    a_list = [area.find('a', {'class' : 'news_tit'}) for area in area_list]

    for n in a_list[:min(len(a_list), news_num-idx)]:
        news_dict[idx] = {'title' : n.get('title'),
                          'url' : n.get('href') }
        idx += 1

    cur_page += 1

pages = soup.find('div', {'class' : 'sc_page_inner'})
next_page_url = [p for p in pages.find_all('a') if p.text == str(cur_page)][0].get('href')

req = requests.get('https://search.naver.com/search.naver' + next_page_url)
soup = BeautifulSoup(req.text, 'html.parser')

print('크롤링 완료')

print('데이터프레임 변환')
news_df = DataFrame(news_dict).T

news_df
# folder_path = os.getcwd()
# xlsx_file_name = '네이버뉴스_{}_{}.xlsx'.format(query, date)

# news_df.to_excel(xlsx_file_name)

# print('엑셀 저장 완료 | 경로 : {}\\{}'.format(folder_path, xlsx_file_name))
# os.startfile(folder_path)
# Out:
# 검색 키워드를 입력하세요 : chatgpt
# 총 필요한 뉴스기사 수를 입력해주세요(숫자만 입력) : 10
#
# 크롤링 중...
# 크롤링 완료
# 데이터프레임 변환
#                                      title  \
# 0                  화성시, ChatGPT 활용연구 TF 출범
# 1            경기도의회 'ChatGPT의 현재와 미래' 특강 실시
# 2  대구 동구청&중구청, 챗(Chat) GPT를 활용한 행정혁신 강연 개최
# 3                   챗GPT와 함께 소설 쓰기 과정은 이랬다
# 4                 화성시, ChatGPT 활용연구 TF팀 출범
# 5  DX포럼, ‘ChatGPT 활용 사례로 보는 인공지능과 데이터의 미래’
# 6                            Italy ChatGPT
# 7       카톡 챗GPT '아숙업' 만든 업스테이지, 활용 비법 알려준다
# 8          ‘○○GPT’ 명칭 함부로 못쓴다… 개발사, 상표권 출원
# 9                   대구 동구, 챗GPT 활용 행정혁신 추진
#
#                                                  url
# 0  http://www.kihoilbo.co.kr/news/articleView.htm...
# 1    http://www.newspim.com/news/view/20230430000069
# 2  https://www.idaegu.co.kr/news/articleView.html...
# 3  http://www.mediatoday.co.kr/news/articleView.h...
# 4  https://www.dailian.co.kr/news/view/1228765/?s...
# 5  http://www.newsis.com/view/?id=NISX20230427_00...
# 6  https://n.news.naver.com/mnews/article/077/000...
# 7              https://www.news1.kr/articles/5029548
# 8  https://www.donga.com/news/Economy/article/all...
# 9       http://www.kbsm.net/news/view.php?idx=389951
