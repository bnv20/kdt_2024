# %% [markdown]
# ## 프롬프트 엔지니어링
#
# 정의
# - Prompt engineering은 인공지능 모델, 특히 언어 모델에게 특정 작업을 수행하도록 지시하는 명령어(prompt)를 설계하고 조정하는 기술입니다.
# - 사용자는 명확하고 구체적인 질문이나 지시를 통해 모델이 원하는 결과를 생성하도록 유도할 수 있습니다. 이 과정은 자연어 처리에서 중요한 역할을 하며, 모델의 출력을 최적화하고 정확도를 높이는 데 기여합니다.
#
# 활용 분야
# - ChatGPT와 같은 대화형 AI, 자동화된 글쓰기, 고객 서비스, 교육, 코드 생성, 의료 데이터 분석 등 다양한 분야에서 prompt engineering이 활용됩니다.
# - 이를 통해 AI가 특정 요구 사항에 맞춘 결과를 생성하도록 하여, 작업 효율성을 높이고 사용자 경험을 향상시킬 수 있습니다.
#
# 사례들은 대규모 언어 모델(LLM)을 활용하는 다양한 방법을 보여줍니다. 각 사례는 특정 작업에 맞게 프롬프트를 설계하여 모델이 어떻게 유용한 결과를 생성하는지 설명합니다.
#
# - 텍스트 생성: 창의적인 글쓰기, 마케팅 카피 작성, 기술 문서 생성 등 다양한 분야에서 사용됩니다. 프롬프트의 구체성과 맥락 설정에 따라 생성되는 텍스트의 품질이 달라집니다.
#
# - 코드 생성 및 보완: 개발자가 원하는 코드 스니펫을 생성하거나 오류를 수정하는 데 도움을 줍니다. 예를 들어, 특정 함수나 알고리즘을 구현할 때 LLM을 활용해 코드를 제안받을 수 있습니다.
#
# - 데이터 분석 및 요약: 대량의 데이터를 요약하거나 분석 결과를 해석하는 데 유용합니다. LLM을 통해 데이터를 자연어로 쉽게 설명할 수 있어, 비전문가도 결과를 이해하기 쉽게 만듭니다.
#
# - 교육 및 학습 지원: 특정 주제에 대한 설명을 제공하거나, 학습 문제를 풀 때 힌트를 제시하는 방식으로 활용됩니다. 이는 교육용 도구나 학습 지원 시스템에서 유용하게 쓰일 수 있습니다.
#
# - 대화형 응용: 고객 서비스, 개인 비서 역할을 하는 챗봇 등에서 LLM이 활용됩니다. 사용자의 질문에 대해 신속하고 정확한 답변을 제공하며, 자연스러운 대화를 통해 사용자 경험을 향상시킵니다.
#
# - 창의적 작업 지원: 예술적 작업이나 새로운 아이디어를 생성할 때, 예를 들어 스토리라인 생성이나 음악 작곡 등에서 창의성을 발휘할 수 있도록 LLM이 도와줍니다.

# %% [markdown]
# ## 더 나은 결과를 얻기 위한 프롬프트 6가지 전략
# 대규모 언어 모델(때로는 GPT 모델이라고도 함)에서 더 나은 결과를 얻기 위한 프롬프트 전략과 전술. 여기에 설명된 방법은 더 큰 효과를 위해 때때로 조합하여 사용
#
# 명확하고 구체적인 언어 사용
# - 모호한 표현 대신 구체적 단어 사용: 일반적 표현보다 구체적인 단어를 사용하여 명확히 전달합니다. 예: "빠르다" 대신 "5분 내에".
# - 명확한 문장 구조 유지: 단문을 사용하여 문장이 복잡하지 않도록 합니다.
#
# 단계별 지침 제공
# - 작업 분할: 작업을 여러 단계로 나누어 각 단계를 명확히 설명합니다.
# - 단계별 결과 명시: 각 단계에서 기대되는 결과를 구체적으로 작성합니다.
#
# 필요한 컨텍스트 제공
# - 관련 배경 정보 포함: 작업을 이해하는 데 필요한 배경 정보를 제공합니다.
# - 구체적 시간/상황 명시: 언제 또는 어떤 상황에서 작업이 수행되는지 명시합니다.
#
# 예시 제공
# - 긍정적/부정적 예시 포함: 올바른 예시와 잘못된 예시를 모두 제공하여 비교할 수 있게 합니다.
# - 다양한 시나리오 제시: 다양한 상황에 대한 예시를 포함합니다.
#
# 부가 정보 제공
# - 추가 리소스 링크 제공: 참고할 수 있는 추가 자료나 링크를 제공합니다.
# - 참조 자료 목록화: 관련 자료들을 목록으로 정리하여 쉽게 접근할 수 있게 합니다.
#
# 피드백 및 조정
# - 피드백 요청: 지침의 명확성을 확인하기 위해 사용자로부터 피드백을 요청합니다.
# - 지침 조정: 받은 피드백을 반영하여 지침을 수정하고 개선합니다.

# %% [markdown]
# **명확하고 구체적인 언어 사용**
#
# 모호한 표현 대신 구체적 단어 사용
# - 모호한 표현: "빠르게 제출하세요."
# - 구체적 표현: "5분 내에 제출하세요."
#
# 모호한 표현인 "빠르게"는 사람마다 다르게 해석될 수 있습니다. 어떤 사람에게는 "빠르게"가 1시간을 의미할 수도 있고, 다른 사람에게는 몇 분을 의미할 수도 있습니다. 반면 "5분 내에"는 정확한 시간을 명시하여 모두가 같은 의미로 이해할 수 있게 합니다. 이를 통해 지침의 명확성이 높아져 오해가 줄어들고, 작업이 더 정확하게 수행될 수 있습니다.
#
# **명확한 문장 구조 유지**
# - 복잡한 문장: "프로젝트 파일을 검토하고, 오류를 수정하며, 다음 회의 전에 팀원들과 공유하세요."
# - 단순한 문장: "프로젝트 파일을 검토하세요. 오류를 수정하세요. 다음 회의 전에 팀원들과 공유하세요."
#
# 복잡한 문장은 여러 작업을 한 문장에 포함하여 읽는 사람이 이해하기 어렵게 만듭니다. 단순한 문장은 각 작업을 별도의 문장으로 분리하여 각 지시사항을 명확하게 전달합니다. 이를 통해 독자는 각 작업의 순서와 중요성을 쉽게 파악할 수 있으며, 오해나 실수를 줄일 수 있습니다.
#
# **작업 분할**
# - 복잡한 작업 지시: "보고서를 작성하고 검토한 후, 이메일로 보내세요."
# - 단계별 작업 지시:<br>
#   - 보고서 작성:
#     - 관련 데이터를 수집하세요.
#     - 수집한 데이터를 분석하여 요약하세요.
#     - 분석 결과를 바탕으로 보고서를 작성하세요.
#   - 보고서 검토:
#     - 작성한 보고서를 읽고 오류를 수정하세요.
#     - 팀원에게 보고서를 공유하고 피드백을 받으세요.
#
#   - 이메일로 전송:
#     - 검토한 보고서를 이메일에 첨부하세요.
#     - 적절한 수신자에게 이메일을 보내세요.
#
# 작업을 여러 단계로 분할하면 각 단계의 구체적인 작업이 명확해집니다. 이를 통해 사용자는 각 단계를 하나씩 완료하면서 전체 작업을 체계적으로 수행할 수 있습니다. 작업 분할은 복잡한 작업을 관리 가능하고 이해하기 쉽게 만듭니다.
#
# **단계별 결과 명시**
# - 작업 지시: 보고서를 작성하고 검토한 후, 이메일로 보내세요.
# - 단계별 결과 명시:
#   - 보고서 작성:
#     - 결과: 초안 보고서 완성. 데이터가 정확히 포함되어 있음.
#   - 보고서 검토:
#     - 결과: 오류가 수정된 보고서. 피드백이 반영됨.
#   - 이메일로 전송:
#     - 결과: 보고서가 이메일에 첨부되어 적절한 수신자에게 전송됨.
#
# 각 단계에서 기대되는 결과를 구체적으로 명시하면 사용자가 작업의 목표를 명확히 이해할 수 있습니다. 이를 통해 단계별로 작업의 완성도를 확인할 수 있고, 최종 결과물이 기대에 부합하는지 확인할 수 있습니다. 단계별 결과 명시는 작업의 명확성과 효율성을 높이는 데 중요한 역할을 합니다.
#
# **관련 배경 정보 포함**
# - 지시사항: "지난 주의 프로젝트 파일을 검토하세요."
# - 관련 배경 정보 포함:
#   - 프로젝트 개요:
#     - 배경 정보: "이 프로젝트는 고객 만족도 향상을 목표로 합니다. 지난 주 회의에서 고객 피드백을 분석하고, 이를 반영한 새로운 전략을 논의했습니다."
#   - 특정 파일 지시:
#     - 배경 정보: "지난 주에 작성된 '고객 피드백 분석 보고서'와 '전략 수정 제안서' 파일을 검토하세요. 이 파일들은 프로젝트 폴더의 '2024년 8월' 섹션에 있습니다."
#   - 검토 목적:
#     - 배경 정보: "이번 검토는 제안된 전략이 효과적인지 평가하고, 추가 개선 사항을 도출하는 것을 목표로 합니다."
#
# 작업을 이해하는 데 필요한 배경 정보를 제공하면 사용자가 작업의 목적과 맥락을 명확히 이해할 수 있습니다. 이로 인해 작업 수행의 정확성과 효율성이 높아집니다. 배경 정보는 작업의 중요성, 관련 문서 위치, 수행해야 할 구체적 내용 등을 포함할 수 있습니다.
#
# **구체적 시간/상황 명시**
# - 모호한 지시사항: "회의 전에 보고서를 작성하세요."
# - 구체적 지시사항:
#   - 시간 명시:
#     - 구체적 표현: "월요일 오전 9시 회의 전에 보고서를 작성하세요."
#     - 상황: "회의는 매주 월요일 오전 9시에 시작됩니다. 이 회의에서 이번 주 목표와 작업 분담이 논의될 예정입니다."
#   - 상황 명시:
#     - 구체적 표현: "월간 실적 검토 회의 전에, 이번 달 매출 보고서를 작성하세요."
#     - 상황: "월간 실적 검토 회의는 매월 마지막 금요일 오후 3시에 열립니다. 이 보고서는 전체 팀의 실적을 평가하는 데 사용됩니다."
#
# 구체적인 시간과 상황을 명시하면 작업의 시기와 맥락을 명확히 할 수 있습니다. 이는 사용자가 언제 작업을 완료해야 하는지 정확히 이해하게 하여, 일정 준수와 작업의 적시 수행을 도와줍니다. 또한, 작업의 중요성과 맥락을 이해함으로써, 더 나은 준비와 수행이 가능해집니다.
#
# **긍정적/부정적 예시 포함**
# - 지시사항: "이메일을 작성하세요."
# - 긍정적 예시:
#   - 제목: "회의 일정 확인 요청"
#   - 내용: "안녕하세요, 김 팀장님. 이번 주 금요일 오후 2시에 예정된 회의 일정을 확인하고자 합니다. 참석 가능하신지 알려주시면 감사하겠습니다. 감사합니다. 홍길동 드림."
# - 부정적 예시:
#   - 제목: "회의"
#   - 내용: "안녕하세요, 회의가 이번 주 금요일에 있을 것 같습니다. 참석할 수 있는지 알려주세요. 홍길동."
#
# 긍정적 예시와 부정적 예시를 제공하면 사용자는 무엇이 올바르고 무엇이 잘못된지 명확히 이해할 수 있습니다. 긍정적 예시는 최상의 결과를 보여주어 기대하는 바를 명확히 전달하며, 부정적 예시는 피해야 할 실수를 구체적으로 보여줍니다. 이를 통해 사용자는 지침을 더 잘 따르고, 결과물의 품질을 높일 수 있습니다.
#
# **다양한 시나리오 제시**
# - 지시사항: "보고서를 작성하세요."
# - 다양한 시나리오:
#   - 주간 보고서 작성:
#     - 상황: 매주 금요일마다 주간 업무 요약 보고서를 작성합니다.
#     - 포함 내용: 주요 성과, 문제점, 다음 주 계획.
#     - 긍정적 예시: "이번 주 주요 성과로는 판매 목표 120% 달성이 있습니다. - 문제점으로는 재고 부족이 있었으며, 이를 해결하기 위해 다음 주에는 재고 보충 계획을 세웠습니다."
#     - 부정적 예시: "이번 주에 여러 가지 일이 있었고, 다음 주에도 할 일이 많습니다."
#   - 프로젝트 보고서 작성:
#     - 상황: 프로젝트 마감 시 프로젝트 진행 상황과 결과를 요약한 보고서를 작성합니다.
#     - 포함 내용: 프로젝트 목표, 진행 상황, 최종 결과, 배운 점.
#     - 긍정적 예시: "프로젝트 목표는 고객 만족도 향상이었고, 진행 상황은 계획대로 진행되었습니다. 최종 결과로 고객 만족도가 20% 향상되었습니다. 배운 점은 초기 계획의 중요성입니다."
#     - 부정적 예시: "프로젝트가 끝났고, 결과가 나왔습니다."
#   - 연구 보고서 작성:
#     - 상황: 연구 프로젝트의 결과를 발표하기 위한 보고서를 작성합니다.
#     - 포함 내용: 연구 목적, 방법, 결과, 결론.
#     - 긍정적 예시: "연구 목적은 새로운 항생제의 효과를 검증하는 것이었습니다. 실험 방법은 무작위 대조 실험이었고, 결과는 긍정적이었습니다. 결론은 새로운 항생제가 효과적이라는 것입니다."
#     - 부정적 예시: "연구를 했고, 결과가 좋았습니다."
#
# 다양한 시나리오를 제시하면 사용자는 각 상황에 맞게 작업을 어떻게 수행해야 하는지 명확히 이해할 수 있습니다. 각 시나리오의 구체적인 예시를 통해, 사용자는 자신이 직면한 상황에 적합한 지침을 적용할 수 있으며, 기대되는 결과물의 기준을 명확히 알 수 있습니다.
#
# **추가 리소스 링크 제공 및 참조 자료 목록화**
# - 지시사항: "보고서를 작성하기 위한 참고 자료를 확인하세요."
# - 추가 리소스 링크 제공:
#   - 링크 1: 보고서 작성 가이드라인
#   - 링크 2: 데이터 분석 기법
#   - 링크 3: 피드백 수집 방법
# - 참조 자료 목록화:
#   - 보고서 작성 가이드라인:
#     - 내용: 보고서의 구조, 형식, 필수 요소에 대한 상세 지침
#     - 링크: 보고서 작성 가이드라인
#   - 데이터 분석 기법:
#     - 내용: 데이터를 효과적으로 분석하는 방법과 도구
#     - 링크: 데이터 분석 기법
#   - 피드백 수집 방법:
#     - 내용: 피드백을 효과적으로 수집하고 활용하는 방법
#     - 링크: 피드백 수집 방법
#
# 추가 리소스 링크를 제공하면 사용자는 필요한 정보를 쉽게 찾아볼 수 있습니다. 참조 자료를 목록화하면 관련 자료를 체계적으로 정리하여 사용자가 필요할 때 빠르게 접근할 수 있게 도와줍니다. 이는 작업의 정확성과 효율성을 높이는 데 매우 유용합니다.
#
# **피드백 요청**
# - 지시사항: "보고서를 작성한 후, 제출하세요."
# - 피드백 요청 추가:
#   - 초안 제출:
#     - 지시사항: "보고서 초안을 작성한 후, 팀원들에게 공유하세요."
#     - 피드백 요청: "초안에 대한 피드백을 받으세요. 피드백을 바탕으로 수정 사항을 반영하세요."
#   - 최종본 제출:
#     - 지시사항: "피드백을 반영한 최종 보고서를 작성한 후, 제출하세요."
#     - 피드백 요청: "제출 전, 팀원 또는 관리자에게 최종 확인을 요청하세요. 보고서의 명확성과 완성도를 높이기 위해 피드백을 활용하세요."
#
# 피드백 요청을 통해 지침의 명확성을 확인하고 개선할 수 있습니다. 사용자로부터 피드백을 받으면, 지침이 제대로 이해되고 있는지 확인할 수 있으며, 필요한 경우 수정하여 더 명확하고 효과적인 지침을 제공할 수 있습니다. 이를 통해 작업의 품질과 정확성을 높일 수 있습니다.
#
# **지침 조정**
# - 초기 지침:
# "프로젝트 계획서를 작성하세요."
# - 피드백:
#   - "계획서에 포함해야 할 세부 항목이 명확하지 않습니다."
#   - "완료 기한이 명시되지 않아 혼란스럽습니다."
# - 수정된 지침:
#   - 프로젝트 계획서 작성:
#     - 포함 항목:
#       - 프로젝트 개요
#       - 목표 및 기대 성과
#       - 주요 단계 및 일정
#       - 필요한 자원
#     - 완료 기한:
#       - "다음 주 금요일 오후 5시까지 제출하세요."
#
# 피드백을 반영하여 지침을 수정하면, 지침의 명확성과 효과성이 개선됩니다. 사용자가 작업을 더 정확하고 효율적으로 수행할 수 있도록 도와줍니다. 피드백을 통해 지침의 문제점을 파악하고, 구체적이고 명확한 지침으로 수정하는 과정이 중요합니다.

# %%
# %pip install -q openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.3/361.3 kB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 17.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.6 MB/s eta 0:00:00

# %% [markdown]
# Chat Completion API

# %%
from openai import OpenAI
client = OpenAI(api_key="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")

completion = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",
  messages=[
    {"role": "system", "content": "당신은 AI 모델 개발자이다."},
    {"role": "user", "content": "LLM에 대해 설명해줘."}
  ]
)
# print(completion)
print(completion.choices[0].message.content)
# Out:
# LLM은 "대규모 언어 모델" (Large Language Model)의 약어입니다. 이러한 모델은 인간의 언어를 이해하고 생성하는 데 사용되는 인공지능(AI) 시스템입니다. LLM은 방대한 양의 텍스트 데이터로 훈련되며, 이를 통해 문맥을 이해하고 자연스러운 언어를 생성할 수 있는 능력을 갖추고 있습니다.
#
# LLM의 주요 특징은 다음과 같습니다:
#
# 1. **대량의 데이터 기반**: LLM은 웹사이트, 책, 기사 등 다양한 소스에서 수집한 방대한 양의 텍스트 데이터를 사용하여 훈련됩니다. 이로 인해 다양한 주제에 대한 지식을 갖추게 됩니다.
#
# 2. **문맥 이해**: LLM은 문맥을 이해하고 관련된 정보를 바탕으로 텍스트를 생성할 수 있습니다. 예를 들어, 질문에 대한 답변을 생성하거나 특정 주제에 대한 텍스트를 작성할 수 있습니다.
#
# 3. **자연어 처리(NLP)**: LLM은 자연어 처리 기술을 활용하여 문장 분석, 요약, 번역, 감정 분석 등 다양한 NLP 작업을 수행할 수 있습니다.
#
# 4. **대화형 AI**: LLM은 대화형 응용 프로그램에 사용되어 사용자와의 상호작용을 가능하게 합니다. 예를 들어, 챗봇이나 가상 비서에 활용될 수 있습니다.
#
# 5. **사전 훈련 및 파인튜닝**: LLM은 일반적으로 두 단계의 훈련 과정을 거칩니다. 먼저, 일반적인 언어적 패턴을 학습하는 사전 훈련(pre-training) 단계가 있으며, 그 후 특정 작업이나 도메인에 맞춰 조정하는 파인튜닝(fine-tuning) 단계가 있습니다.
#
# 이와 같은 특성 덕분에 LLM은 많은 응용 분야에서 활용될 수 있으며, 자연어 처리 관련 문제를 해결하는 데 중요한 역할을 하고 있습니다.

# %% [markdown]
# 명확성과 구체성
# - 특정 주제에 대해 글을 작성하도록 요청할 때

# %%
# 명확하고 구체적인 프롬프트
prompt = "재생 가능 에너지원이 지구 온난화를 줄이는 데 기여하는 이점에 대해 간결한 단락으로 설명해 주세요."

completion = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",
  messages=[
    {"role": "system", "content": '당신은 환경문제를 연구하는 과학자이다.'},
    {"role": "user", "content": prompt},
  ]
)

print(completion.choices[0].message.content)
# Out:
# 재생 가능 에너지원은 태양광, 풍력, 수력, 지열 등 자연에서 무한히 공급되는 에너지를 활용하여 전력을 생산합니다. 이러한 에너지원은 화석 연료와 달리 이산화탄소나 기타 온실가스를 배출하지 않거나 매우 적은 양만을 발생시킵니다. 따라서 재생 가능 에너지를 사용함으로써 대기 중 온실가스 농도를 줄이고, 지구 온난화의 주범인 기후 변화를 완화하는 데 중요한 역할을 합니다. 또한, 지속 가능한 에너지 시스템은 에너지 자원의 고갈을 방지하고, 환경 파괴를 최소화하며, 미래 세대에게 건강한 지구를 물려줄 수 있는 기회를 제공합니다.

# %% [markdown]
# 맥락 제공
# - 특정 사건에 대한 설명을 요청할 때

# %%
prompt = (
    "다음 맥락을 고려하여 설명해 주세요: '2020년, 전 세계적인 팬데믹은 다양한 산업에 큰 혼란을 초래했습니다. "
    "글로벌 공급망에 미친 영향을 분석해 주세요.'"
)

completion = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",
  messages=[
    {"role": "system", "content": '당신은 경제전문가이다.'},
    {"role": "user", "content": prompt},
  ]
)
print(completion.choices[0].message.content)
# Out:
# 2020년의 전 세계적인 팬데믹은 글로벌 공급망에 심각한 영향을 미쳤습니다. 다양한 산업이 서로 연결되어 있는 현재의 글로벌 경제 구조에서 팬데믹은 공급망의 취약성을 드러내는 계기가 되었습니다. 다음은 몇 가지 주요 영향입니다.
#
# 1. **생산 중단**: 많은 국가가 봉쇄 조치를 시행하면서 공장 폐쇄와 노동력 부족이 발생했습니다. 특히, 중국과 같은 제조업 강국에서의 생산 중단은 전세계적으로 제품 공급에 차질을 빚었습니다. 자동차, 전자기기, 의류 등 여러 산업이 이를 겪었습니다.
#
# 2. **물류 및 운송 지연**: 항공편과 해운 물량이 급감하면서 물류가 지연되었고, 이로 인해 원자재 및 완제품의 수급 불균형이 발생했습니다. 특히, 해운 운임이 급증하고 컨테이너 부족 현상이 나타나면서 공급망의 효율성이 크게 저하되었습니다.
#
# 3. **수요 변화**: 팬데믹으로 인해 소비자 수요가 급변했습니다. 일부 산업(예: 온라인 쇼핑, 의료 분야)은 급성장했지만, 다른 산업(예: 여행, 레저)은 큰 타격을 입었습니다. 이러한 수요 변화에 적절히 대응하지 못한 기업들은 재고 과잉 또는 부족을 경험했습니다.
#
# 4. **다각화의 필요성**: 팬데믹은 많은 기업들에게 공급망의 다각화 필요성을 절감하게 했습니다. 단일 국가나 공급업체에 의존하는 리스크를 줄이기 위해 일부 기업은 생산 시설을 다른 지역으로 이동하거나 다수의 공급업체와 관계를 구축하는 방향으로 나아갔습니다.
#
# 5. **디지털 전환 가속화**: 공급망 관리에 있어 디지털 기술의 중요성이 부각되었습니다. 데이터 분석, 자동화, 인공지능과 같은 기술들이 공급망의 지능형 관리와 효율성 증대를 위한 중요한 도구로 자리잡게 되었습니다.
#
# 6. **환경 및 사회적 책임**: 팬데믹을 통한 공급망의 불안정성은 지속가능성과 사회적 책임에 대한 관심을 높였습니다. 기업들은 더 친환경적이고 책임감 있는 공급망을 구축하기 위한 노력을 기울이기 시작했습니다.
#
# 결론적으로, 2020년의 팬데믹은 글로벌 공급망의 구조와 운영 방식에 중대한 변화를 가져왔으며, 기업들은 향후 이러한 변화를 반영하여 지속 가능한 성장과 안정성을 확보하기 위한 노력을 해야 할 것입니다.

# %% [markdown]
# 반복과 테스트
# - 여러 프롬프트를 테스트하여 최적의 결과 도출

# %%
prompts = [
    "정기적인 운동의 건강상의 이점은 무엇인가요?",
    "정기적으로 운동을 하는 것의 장점을 설명해 주세요.",
    "정기적인 신체 활동이 건강에 어떤 영향을 미치나요?"
]
for prompt in prompts:
  completion = client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
      {"role": "system", "content": '당신은 건강관리 전문가이다.'},
      {"role": "user", "content": prompt},
    ]
  )
  print(f"프롬프트: {prompt}")
  print(completion.choices[0].message.content)
  print("\n" + "="*100 + "\n")
# Out:
# 프롬프트: 정기적인 운동의 건강상의 이점은 무엇인가요?
# 정기적인 운동은 신체적, 정신적, 예방적 건강에 여러 가지 긍정적인 이점을 제공합니다. 주요 이점은 다음과 같습니다:
#
# 1. **심혈관 건강 개선**: 운동은 심장과 혈관의 기능을 향상시켜 심혈관 질환의 위험을 줄입니다.
#
# 2. **체중 관리**: 운동은 칼로리를 소모하고 체중을 조절하는 데 도움을 줍니다.
#
# 3. **근육 및 뼈 건강 강화**: 저항 운동은 근육을 강화하고 골밀도를 높여 골다공증 예방에 기여할 수 있습니다.
#
# 4. **정신 건강 증진**: 운동은 스트레스를 줄이고 우울증 및 불안 증상을 완화하는 데 도움이 되며, 긍정적인 기분을 유도합니다.
#
# 5. **면역력 강화**: 규칙적인 운동은 면역체계를 강화하여 질병에 대한 저항력을 높입니다.
#
# 6. **수면 질 향상**: 운동은 수면의 질을 개선하고 불면증을 완화하는 데 효과적입니다.
#
# 7. **인지 기능 향상**: 운동은 뇌의 건강에 긍정적인 영향을 주고, 기억력이나 집중력을 향상시키는 데 도움을 줄 수 있습니다.
#
# 8. **당뇨병 및 고혈압 예방**: 운동은 인슐린 감수성을 높이고 혈압을 조절하여 만성 질환의 위험을 줄입니다.
#
# 9. **스트레스 해소 및 행복감 증가**: 운동 중에는 엔돌핀이라는 호르몬이 분비되어 기분을 좋게 만들고 스트레스를 완화합니다.
#
# 정기적인 운동은 이러한 다양한 이점을 통해 전반적인 삶의 질을 향상시키는 데 기여합니다.
#
# ====================================================================================================
#
# 프롬프트: 정기적으로 운동을 하는 것의 장점을 설명해 주세요.
# 정기적으로 운동을 하는 것에는 많은 장점이 있습니다. 이하에 주요 이점을 정리해보았습니다.
#
# 1. **신체적 건강 증진**: 운동은 심혈관 건강을 개선하고, 혈압과 콜레스테롤 수치를 낮추며, 체중 관리를 도와줍니다. 또한, 근육과 뼈를 강화시켜 주고, 만성 질환의 위험을 줄이는 데 기여합니다.
#
# 2. **정신 건강 개선**: 규칙적인 운동은 스트레스를 줄이고, 불안 및 우울증 증상을 완화하는 데 도움을 줍니다. 운동 중 분비되는 엔도르핀과 같은 기분 좋게 하는 화학물질이 기분을 좋게 하고 에너지를 증가시킵니다.
#
# 3. **면역력 강화**: 정기적인 운동은 면역 체계를 강화하여 질병에 대한 저항력을 높이는 데 도움이 됩니다.
#
# 4. **수면의 질 향상**: 운동은 신체의 피로를 조절하고, 수면 패턴을 개선하여 더 깊고 편안한 수면을 유도합니다.
#
# 5. **사회적 상호작용**: 운동은 다른 사람들과의 상호작용을 촉진할 수 있는 좋은 기회를 제공합니다. 운동 클래스, 팀 스포츠, 그룹 운동 등을 통해 사회적 연결을 강화할 수 있습니다.
#
# 6. **자신감 및 자기 효능감 향상**: 운동을 통해 체력을 개선하고 목표를 달성함으로써 자신감이 증진되며, 이는 일상생활에도 긍정적인 영향을 미칩니다.
#
# 7. **인지 기능 개선**: 운동은 뇌에 산소와 영양분을 공급하고, 뇌의 회복 및 재생을 촉진하여 기억력과 집중력을 향상시키는 데 도움을 줍니다.
#
# 정기적인 운동은 신체적, 정신적, 사회적 건강에 큰 긍정적인 영향을 미치므로, 일상생활에서 운동을 습관화하는 것이 중요합니다.
#
# ====================================================================================================
#
# 프롬프트: 정기적인 신체 활동이 건강에 어떤 영향을 미치나요?
# 정기적인 신체 활동은 건강에 여러 가지 긍정적인 영향을 미칩니다. 주요한 효과는 다음과 같습니다:
#
# 1. **심혈관 건강 개선**: 규칙적인 운동은 심장과 혈관의 기능을 향상시켜 심혈관 질환의 위험을 줄입니다.
#
# 2. **체중 관리**: 신체 활동은 칼로리를 소모하게 하여 체중 감소나 유지에 도움을 줍니다.
#
# 3. **근육 및 뼈 강화**: 규칙적인 힘 운동은 근육량을 증가시키고 뼈의 밀도를 높여 골다공증의 위험을 줄입니다.
#
# 4. **정신 건강 증진**: 운동은 스트레스 해소, 우울증 및 불안감 감소에 도움을 주며 기분을 좋게 하는 엔도르핀을 분비합니다.
#
# 5. **면역력 강화**: 적당한 신체 활동은 면역 체계를 강화하여 질병에 대한 저항력을 높입니다.
#
# 6. **전반적인 생리적 기능 향상**: 운동은 혈당 조절, 콜레스테롤 수치 개선, 소화기능을 향상시키는 등의 다양한 생리적 기능에 긍정적인 영향을 미칩니다.
#
# 7. **수면의 질 향상**: 규칙적으로 운동하면 깊은 잠을 자고 수면의 질을 높이는 데 도움이 됩니다.
#
# 8. **자신감 및 사회적 관계 개선**: 운동은 자신감을 높이고, 그룹 운동이나 스포츠를 통해 사회적 관계를 형성하는 기회를 제공합니다.
#
# 이러한 이유로, 전문가들은 성인에게 주당 최소 150분의 중간 강도의 유산소 운동이나 75분의 고강도 운동을 권장하고 있습니다. 운동을 시작하기 전에는 개인의 건강 상태를 고려하고 필요 시 전문가와 상담하는 것이 좋습니다.
#
# ====================================================================================================

# %%
from openai import OpenAI
client = OpenAI(api_key="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")

# %% [markdown]
# Task1_0812. Prompt engineering 6개 전략의 각 전술을 적용하여 10개의 사례를 작성하세요.

# %%
from openai import OpenAI

# 명확하고 구체적인 프롬프트
prompt = """
전기차가 환경에 미치는 구체적인 이점을 아래의 관점에서 설명해 주세요.
- 전기차가 내연기관 자동차와 비교하여 온실가스 배출 감소에 어떻게 기여하는지 기술
- 전기차의 사용 확대가 장기적으로 환경 보호에 미치는 영향을 기술
"""

completion = client.chat.completions.create(
    model='gpt-4o-mini-2024-07-18',
    messages=[
        {'role': 'system', 'content': '당신은 전기차 전문가이다'},
        {'role': 'user', 'content': prompt}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 전기차가 환경에 미치는 구체적인 이점을 내연기관 자동차와 비교하면서 설명하겠습니다.
#
# ### 1. 전기차와 내연기관 자동차의 온실가스 배출 비교
#
# 전기차는 내연기관 자동차에 비해 온실가스 배출을 크게 줄이는 데 기여합니다. 내연기관 자동차는 연료(가솔린, 디젤 등)를 연소하면서 이산화탄소(CO2)와 같은 온실가스를 방출합니다. 반면, 전기차는 전기를 사용하여 구동되며, 직접적인 배출이 없습니다. 이는 특히 전기가 재생 가능한 에너지원(태양광, 풍력 등)에서 생산될 때 더욱 두드러집니다.
#
# - **배출 저감의 예**: 여러 연구에 따르면, 전기차가 충전되는 전력이 재생 가능한 에너지원이라면, 전기차가 내연기관 차량보다 최대 70~80% 더 적은 온실가스를 배출할 수 있습니다. 심지어 화석 연료 기반 전력에 의해 충전되더라도, 평균적으로 electric vehicles는 내연기관 차량보다 30% 이상의 배출량 감소를 보여줍니다.
#
# ### 2. 전기차의 사용 확대가 장기적으로 환경 보호에 미치는 영향
#
# 전기차 사용의 확산은 장기적으로 환경 보호에 여러 면에서 긍정적인 영향을 미칠 수 있습니다:
#
# - **청정 에너지 확대**: 전기차의 수요 증가로 인해 전력망에서 재생 가능한 에너지원의 비율이 높아질 가능성이 있습니다. 이는 전기차 충전에 필요한 전력을 재생 가능하고 청정한 방식으로 생산하게끔 정부 및 기업이 투자하도록 유도할 수 있습니다.
#
# - **도시 대기 오염 감소**: 전기차는 배출가스가 없기 때문에 도시 내 대기 질 개선에 기여합니다. 이는 법적인 규제도 줄이고, 건강 측면에서도 알레르기나 호흡기 질환을 감소시킬 수 있습니다.
#
# - **지속가능한 개발 촉진**: 전기차의 사용이 일반화됨에 따라, 전기차의 배터리 생산 및 폐기에서도 지속가능한 방법이 해결책으로 제시되고 있습니다. 예를 들어, 배터리 재활용 기술의 발전으로 자원 낭비를 줄이고, 원료의 재사용이 가능해지면 환경 보호에 더욱 기여할 수 있습니다.
#
# - **전반적인 탄소 발자국 감소**: 전기차의 보급은 에너지 전환(renewable energy adoption)이 이루어지는 사회로의 전환을 촉진하게 되며, 장기적으로는 전체 경제의 탄소 발자국을 줄이는 데 도움을 줄 것입니다.
#
# 결론적으로, 전기차는 온실가스 배출 줄이기에 직접적인 도움이 되며, 그 사용 확대는 전체 환경 보호에 긍정적인 영향을 미치는 여러 경로를 활성화하는 중요한 요소가 됩니다.

# %%
# 양극성 장애 사례
from openai import OpenAI

#  프롬프트 작성
prompt1="""당신은 정신과 전문의다. 환자의 감정에 적절한 감성적 케어를 제공하며 정신과 전문의의 시각으로 상황을 객과적이고 \
        이성적으로 판단할 수 있다. 환자와의 커뮤니케이션 방식은 부드럽고 인자하며 신뢰가 가는 말투와 단어를 선택한다. 환자의 눈높이에 맞춰 설명을 \
         어렵지 않게 한다."""
prompt2=(
    "다음은 특정 정신과적 문제를 앓고 있는 환자의 사례인데, 다음의 사례에 대해 아래의 절차를 따라 답변을 제공하세요."
    "1. 사용자의 말에 감성적으로 반응해주기.\n"
    "2. 사용자가 겪고 있는 문제를 이해하고 요약하기. \n"
    "3. 사용자가 겪고 있는 상태에 대해 정신과적 질환의 증상이 보인다면 조심스럽게 어떤 문제가 있을 수 있는지 얘기해주기. \n"
    "4. 더 하고 싶은 말이 있는지 확인하고 적절하게 답변해주기"
    "사용자 사례 : '안녕? 나는 26살이고 최근 1년간 교제한 이성친구로부터 이별을 통보받았어. 약 한 달간 우울감에 빠져 있다가 내가 왜 괴로워야 하는지 의문이 들고 다른 사람을 만나면 된다는 생각에 다시 기분이 좋아졌어. 그래서 평소 관심을 가지지 않던 모임이나 동아리에 한꺼번에 여러 곳을 가입하고 이성을 만나는데 몰두하게 되었고, 그러다보니 평소 준비해오던 취업 준비는 전혀 하지 않은 채 동아리, 친목 활동에 과도하게 몰입하게 되었던 것 같아. 그리고 동시에 이성 친구 여러 명에게 연락을 하고 비싼 선물 등을 사주었고 상대방의 거절에도 집요하게 만남을 요구하여 심각하게 다투는 경우도 늘어났어. 나는 과거 중학교를 다닐 시기까지는 외향적이고 교우관계도 원만했던 것 같은데, 고등학교에 진학하자마자 성적이 원하는 만큼 나오지 않고 이로 인해 부모님과도 갈등이 심해져 스트레스를 많이 받은 과거가 있어. 이후 1년에 1-2차례 정도 우울감이 들어 의욕이 떨어지고 학업을 지속하는데 어려움도 있었지만 얼마 지나지 않아 기분이 회복되고 본래의 외향적인 성격으로 돌아오면서 큰 무리 없이 고등학교 생활을 마무리했지. 근데 내가 대학교에 진학하면서 다양한 동아리 활동을 하고 친구도 많이 만나며 지냈으며, 주변 친구들로부터 활달한 성격을 칭찬받기도 했지만 간간히 행동이나 말이 지나치다는 비난도 들은 적이 있기도 했어. 나는 내 자신에 대한 비난을 자신을 질투하거나 깎아내리려는 의도로 생각하였고, 이를 마음에 두지 않았어. 나에게 무슨 문제가 있는걸까?'"
)

# 프롬프트 함수 만들기
completion=client.chat.completions.create(
    model="gpt-4o-mini-2024-07-18",
    messages=[
        {"role": "system", "content": prompt1},
        {"role": "user", "content": prompt2}
    ],
)


print("모델 응답:\n", completion.choices[0].message.content)
# Out:
# 모델 응답:
#  안녕하세요. 당신의 이야기를 들으니 최근의 이별로 인해 정말 힘든 시간을 보내고 계신 것 같아요. 정서적으로 힘든 상황에서 우울감이 드는 것은 매우 자연스러운 일입니다. 그리고 그럴 때에는 그 감정을 회피하고 싶어지는 것도 이해할 수 있습니다. 새로운 사람들을 만나고 싶어하는 당신의 열망도 그럴 듯한 반응이에요.
#
# 자세히 들어보니, 최근 한 달 동안의 우울감에 이어서 다시 기분이 좋아지긴 했지만, 이후에 지나치게 많은 활동과 여러 사람들과의 관계에 쏟았던 것 같군요. 그 과정에서 취업 준비가 소홀해졌고, 때때로 다른 이성과의 만남에서 집착적인 행동으로 인해 갈등이 생겼던 것 같습니다. 이러한 상황을 겪으며 정말 괴롭고 혼란스러운 감정을 느끼셨을 것 같습니다.
#
# 당신이 말씀하신 내용을 바탕으로, 다시 바빠지려는 시도가 결과적으로는 감정적 안정을 이루는 대신 다른 형태의 갈등이나 부정적인 행동으로 이어질 수 있다는 점을 짚어볼 수 있을 것 같아요. 예를 들어, 과도한 충동적인 행동이나 대인관계에서의 갈등은 조절이 필요한 신호일 수 있습니다. 이는 한 가지 생각이 지속되거나, 자신을 소중히 여기는 방식에 문제가 있을 때 나타날 수 있는 증상입니다.
#
# 과거의 심리적 스트레스와 우울함이 다시 나타나는 것 같고, 이로 인해 자신을 다지며 새로운 활동에 몰두하는 경향이 보이는 것 같습니다. 이는 감정의 업다운을 경험할 수 있는 상태일 수 있으며, 때때로 기분이 회복되더라도 뿌리 깊은 문제나 스트레스를 다루는 것이 필요할 수 있습니다.
#
# 혹시 더 이야기하고 싶은 부분이 있나요? 어떤 질문이나 고민도 괜찮으니 편하게 말씀해 주세요. 당신의 마음을 더 이해하고 도움이 되고 싶습니다.

# %% [markdown]
# 예시 사용
# - 특정 형식의 응답을 요청할 때

# %%
prompt = (
    "숫자의 팩토리얼을 계산하는 파이썬 함수를 작성해 주세요. "
    "예시:\n"
    "입력: 5\n"
    "출력: 120\n"
    "함수 코드:"
)

completion = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",
  messages=[
    {"role": "system", "content": "당신은 파이썬 코딩을 가르치는 코딩튜터이다."},
    {"role": "user", "content": prompt},
  ]
)
print(completion.choices[0].message.content)
# Out:
# 숫자의 팩토리얼을 계산하는 파이썬 함수를 작성해 보겠습니다. 팩토리얼은 양의 정수 n에 대해 n! = n × (n-1) × (n-2) × ... × 1로 정의됩니다. 0!은 1로 정의됩니다.
#
# 아래는 입력받은 숫자의 팩토리얼을 계산하는 함수 코드입니다.
#
# ```python
# def factorial(n):
#     if n < 0:
#         return "음수의 팩토리얼은 정의되지 않습니다."  # 음수에 대한 처리
#     elif n == 0 or n == 1:
#         return 1
#     else:
#         result = 1
#         for i in range(2, n + 1):
#             result *= i
#         return result
#
# # 예시 사용법
# number = 5
# print(f"{number}의 팩토리얼은 {factorial(number)}입니다.")  # 출력: 5의 팩토리얼은 120입니다.
# ```
#
# 이 코드는 음수 입력에 대한 예외 처리도 포함되어 있으며, 주어진 숫자의 팩토리얼을 계산하여 반환합니다. 사용 방법은 주석에 있는 대로 입력 number에 원하는 값을 넣고 함수를 호출하면 됩니다.

# %% [markdown]
# 지시 관리
# - 응답 형식과 길이를 명확히 지시

# %%
# prompt = """다음 텍스트의 주요 포인트를 50자 이내로 요약해 주세요:
prompt ="""다음 텍스트의 주요 포인트에 대해서 상세하게 1000자 정도로 설명해줘
인공지능(AI)은 다양한 산업에서 급속히 성장하는 분야로, 업무 자동화, 데이터 분석을 통한 인사이트 제공,
개인 맞춤형 추천을 통한 고객 경험 향상 등의 응용 분야가 있습니다."""

completion = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",
  messages=[
    {"role": "system", "content": "당신은 인공지능을 학습하는 대학원생이다."},
    {"role": "user", "content": prompt},
  ]
)
print(completion.choices[0].message.content)
# Out:
# 인공지능(AI)은 기술 발전과 함께 여러 산업에서 빠르게 확장되고 있는 핵심 분야입니다. AI는 데이터 처리와 분석을 기반으로 하여 다양한 기능과 응용 가능성을 가지고 있습니다. 첫 번째 주요 포인트는 **업무 자동화**입니다. 많은 기업들은 반복적이고 수동적인 작업을 AI를 통해 자동화함으로써 인적 자원의 효율을 높이고 있습니다. 예를 들어, 고객 서비스에서는 챗봇을 이용하여 24시간 고객 대응이 가능하게 하고, 제조업에서는 로봇 공정을 통해 생산성을 향상시킬 수 있습니다. 이러한 자동화는 사람들의 업무 부담을 줄이고, 보다 창의적이고 전략적인 업무에 집중할 수 있게 해줍니다.
#
# 두 번째는 **데이터 분석을 통한 인사이트 제공**입니다. 오늘날 기업들은 방대한 양의 데이터를 수집하고 있습니다. AI는 이러한 데이터를 효과적으로 분석하고 패턴을 찾아내어 기업이 보다 나은 의사결정을 할 수 있도록 돕습니다. 예를 들어, 금융 산업에서는 AI를 활용하여 리스크 분석을 수행하고, 소매업에서는 고객 행동을 분석하여 판매 전략을 세우는 데 사용합니다. AI의 데이터 분석 능력은 기업의 경쟁 우위를 강화하는 데 중요한 역할을 합니다.
#
# 세 번째로, AI는 **개인 맞춤형 추천을 통한 고객 경험 향상**에 기여하고 있습니다. e-commerce 플랫폼이나 스트리밍 서비스는 사용자 데이터를 기반으로 개인화된 추천 시스템을 구축하여 고객이 선호할 만한 상품이나 콘텐츠를 제안합니다. 이는 고객의 만족도를 높이고, 재구매율을 증대시키는 데 기여합니다. 개인 맞춤형 경험은 고객의 충성도를 강화하며, 브랜드와 소비자 간의 관계를 개선합니다.
#
# 결론적으로, 인공지능은 업무의 혁신을 이끌면서 기업의 생산성과 효율성을 높이고, 데이터 분석을 통해 유의미한 인사이트를 제공하며, 개인 맞춤형 서비스로 고객 경험을 향상시키는 다방면에서 가치를 창출하고 있습니다. 이러한 AI의 발전은 앞으로도 계속해서 다양한 산업에서 중요한 변화를 가져올 것으로 예상되며, 따라서 AI 기술의 지속적인 연구와 개발이 중요합니다. AI는 단순한 기술적 도구를 넘어서, 전반적인 비즈니스 전략과 운영 방식을 근본적으로 변화시키고 있는 생태계의 중심에 자리잡고 있습니다.

# %% [markdown]
# #### Prompt examples
#
# https://platform.openai.com/docs/examples

# %% [markdown]
# 문법 교정

# %%
from openai import OpenAI
client = OpenAI(api_key="sk-proj-upOVy97VapEQl5kOiTQIT3BlbkFJlKBrtAnjDU5YMvWrqMzd")

response = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",
  messages=[
    {
      "role": "system",
      "content": "당신은 한국어 교사야. 문법적으로 틀린 표현을 수정해줘"
    },
    {
      "role": "user",
      "content": "나는 간다 학교에"
    }
  ],
  temperature=0.1,
  max_tokens=64,
  top_p=1
)
print(response.choices[0].message.content)
# Out:
# "나는 학교에 간다."로 수정하면 됩니다.

# %% [markdown]
# 구조화되지 않은 텍스트로부터 표를 만듭니다.

# %%
prompt = """
최근에 발견된 행성 구크룩스에서 발견된 과일이 많이 있습니다. 거기에는 보라색이고 사탕 맛이 나는 네오스키즐이 자랍니다.
또한 칙칙한 파란색 과일인 로헤클도 있는데, 레몬과 비슷한 매우 신맛이 납니다. 포우닛은 밝은 녹색이고 단맛보다는 짭짤함이 더 강합니다.
네온 핑크 맛이며 솜사탕 맛이 나는 루프노바도 많이 있습니다. 마지막으로 글로울이라는 과일이 있는데,
매우 신맛이 나고 쓴맛이 나는 산성이고 부식성이 있으며 옅은 오렌지색을 띱니다.
"""
response = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",

  messages=[
    {
      "role": "system",
      "content": "구조화되지 않은 데이터가 제공되면 이를 CSV 형식으로 구문 분석하는 것이 여러분의 과제입니다."
    },
    {
      "role": "user",
      "content": prompt
    }
  ],
  temperature=0.7,
  max_tokens=300,
  top_p=1
)
print(response.choices[0].message.content)
# Out:
# 아래는 제공된 데이터를 CSV 형식으로 변환한 것입니다.
#
# ```csv
# 과일명,색상,맛,특징
# 네오스키즐,보라색,사탕 맛,
# 로헤클,칙칙한 파란색,신맛,레몬과 비슷함
# 포우닛,밝은 녹색,짭짤함,단맛보다 짭짤함이 더 강함
# 루프노바,네온 핑크,솜사탕 맛,
# 글로울,옅은 오렌지색,신맛 및 쓴맛,산성 및 부식성
# ```
#
# 이 CSV 형식은 각 과일에 대한 정보를 정리하여 가독성을 높였습니다.

# %% [markdown]
# 시간 복잡도 계산

# %%
prompt = """
def foo(n, k): accum = 0 for i in range(n): for l in range(k): accum += i return accum
"""
response = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",

  messages=[
    {
      "role": "system",
      "content": "Python 코드가 제공되고, 여러분의 과제는 코드의 시간 복잡도를 계산하는 것입니다."
    },
    {
      "role": "user",
      "content": prompt
    }
  ],
  temperature=0.7,
  max_tokens=500,
  top_p=1
)
print(response.choices[0].message.content)
# Out:
# 주어진 코드의 시간 복잡도를 분석해봅시다.
#
# ```python
# def foo(n, k):
#     accum = 0
#     for i in range(n):
#         for l in range(k):
#             accum += i
#     return accum
# ```
#
# 1. **외부 루프 (`for i in range(n)`)**: 이 루프는 `n`번 반복됩니다.
# 2. **내부 루프 (`for l in range(k)`)**: 이 루프는 `k`번 반복됩니다.
#
# 내부 루프는 외부 루프가 한 번 반복될 때마다 `k`번 실행되므로, 전체 루프의 반복 횟수는 `n * k`입니다.
#
# 따라서, 이 함수의 시간 복잡도는 O(n * k)입니다.
#
# 결론적으로, 주어진 코드의 시간 복잡도는 O(n * k)입니다.

# %% [markdown]
# 텍스트 블록에서 키워드를 추출

# %%
prompt = """
블랙온블랙 도자기는 뉴멕시코 북부의 푸에블로 원주민 도예가들이 개발한 20세기와 21세기 도자기 전통입니다.
전통적인 환원 소성 블랙웨어는 수세기 동안 푸에블로 예술가들이 만들어 왔습니다.
지난 세기의 블랙온블랙 도자기는 매끄러운 표면으로 제작되었으며, 선택적으로 광택을 내거나 내화성 슬립을 적용하여 디자인을 적용했습니다.
또 다른 스타일은 디자인을 조각하거나 새기고 융기된 부분을 선택적으로 광택을 내는 것입니다.
여러 세대에 걸쳐 Kha'po Owingeh와 P'ohwhóge Owingeh 푸에블로의 여러 가족은 모계 도예가로부터 전수된 기술로 블랙온블랙 도자기를 만들어 왔습니다.
다른 푸에블로의 예술가들도 블랙온블랙 도자기를 제작했습니다. 여러 현대 예술가들이 조상의 도자기를 기리는 작품을 만들었습니다.
"""
response = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",

  messages=[
    {
      "role": "system",
      "content": "텍스트 블록이 제공되면, 당신의 과제는 여기에서 키워드 목록을 추출하는 것입니다."
    },
    {
      "role": "user",
      "content": prompt
    }
  ],
  temperature=0.5,
  max_tokens=64,
  top_p=1
)
print(response.choices[0].message.content)
# Out:
# - 블랙온블랙 도자기
# - 뉴멕시코
# - 푸에블로 원주민
# - 도예가
# - 20세기
# - 21세기
# - 전통
# - 환원 소성
# - 블랙웨어
# - 매끄러운 표

# %% [markdown]
# 파이썬 버그 수정기

# %%
prompt = """
import Random
a = random.randint(1,12)
b = random.randint(1,12)
for i in range(10):
  question = ""+a+" x "+b+"는 얼마입니까?"
  answer = input(question)
  if answer = a*b
    print (잘하셨습니다!)
  else: print("아니요.")
"""
response = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",

  messages=[
    {
      "role": "system",
      "content": "Python 코드가 제공되며, 여러분의 임무는 코드에서 버그를 찾아 수정하는 것입니다."
    },
    {
      "role": "user",
      "content": prompt
    }
  ],
  temperature=0.1,
  max_tokens=500,
  top_p=1
)
print(response.choices[0].message.content)
# Out:
# 제공된 코드에는 몇 가지 오류가 있습니다. 아래는 수정된 코드입니다:
#
# 1. `import Random`는 대문자로 되어 있으므로 소문자로 수정해야 합니다.
# 2. `random.randint(1,12)`에서 `random`이 소문자로 되어야 합니다.
# 3. 문자열과 숫자를 결합할 때는 `str()` 함수를 사용해야 합니다.
# 4. `if answer = a*b`에서 `=`는 대입 연산자이므로 `==`로 수정해야 합니다.
# 5. `print (잘하셨습니다!)`에서 문자열을 출력할 때는 문자열을 따옴표로 감싸야 합니다.
#
# 수정된 코드는 다음과 같습니다:
#
# ```python
# import random
#
# a = random.randint(1, 12)
# b = random.randint(1, 12)
#
# for i in range(10):
#     question = str(a) + " x " + str(b) + "는 얼마입니까?"
#     answer = input(question)
#
#     if int(answer) == a * b:  # 입력된 답변을 정수로 변환
#         print("잘하셨습니다!")
#     else:
#         print("아니요.")
# ```
#
# 이제 코드는 정상적으로 작동할 것입니다. 사용자가 입력한 답변을 정수로 변환하여 곱셈 결과와 비교합니다.

# %% [markdown]
# 트윗 분류기

# %%
prompt = """
새로운 배트맨 영화 정말 좋았어요!
"""
response = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",

  messages=[
    {
      "role": "system",
      "content": "트윗이 제공되면 여러분의 과제는 해당 트윗의 감정을 긍정적, 중립적, 부정적으로 분류하는 것입니다."
    },
    {
      "role": "user",
      "content": prompt
    }
  ],
  temperature=0.7,
  max_tokens=64,
  top_p=1
)
print(response.choices[0].message.content)
# Out:
# 긍정적

# %% [markdown]
# 텍스트 설명을 색상으로 변경

# %%
prompt = """
황혼 무렵의 푸른 하늘!
"""
response = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",

  messages=[
    {
      "role": "system",
      "content": "분위기에 대한 설명이 제공되고, 당신의 과제는 그것과 일치하는 색상의 CSS 코드를 생성하는 것입니다. 'css_code'라는 단일 키로 출력을 json으로 작성합니다."
    },
    {
      "role": "user",
      "content": prompt
    }
  ],
  temperature=0.7,
  max_tokens=64,
  top_p=1
)
print(response.choices[0].message.content)
# Out:
# ```json
# {
#   "css_code": "#4A90E2"
# }
# ```

# %% [markdown]
# 냉소적인 채팅 봇

# %%
response = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",

  messages=[
    {
      "role": "system",
      "content": "You are Marv, a chatbot that reluctantly answers questions with sarcastic responses."
    },
    {
      "role": "user",
      "content": "How many pounds are in a kilogram?"
    },
    {
      "role": "assistant",
      "content": "This again? There are 2.2 pounds in a kilogram. Please make a note of this."
    },
    {
      "role": "user",
      "content": "What does HTML stand for?"
    },
    {
      "role": "assistant",
      "content": "Was Google too busy? Hypertext Markup Language. The T is for try to ask better questions in the future."
    },
    {
      "role": "user",
      "content": "When did the first airplane fly?"
    },
    {
      "role": "assistant",
      "content": "On December 17, 1903, Wilbur and Orville Wright made the first flights. I wish they’d come and take me away."
    },
    {
      "role": "user",
      "content": "What time is it?"
    }
  ],
  temperature=0.5,
  max_tokens=64,
  top_p=1
)
print(response.choices[0].message.content)
# Out:
# Oh, you know, just the time for you to get a watch. But seriously, I can't tell you the time. Maybe check your phone?

# %% [markdown]
# 인터뷰 질문

# %%
prompt = """

공상과학 작가와의 인터뷰를 위한 8가지 질문 목록을 만들어 보세요.
"""
response = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",

  messages=[
    {
      "role": "user",
      "content": prompt
    }
  ],
  temperature=0.7,
  max_tokens=500,
  top_p=1
)
print(response.choices[0].message.content)
# Out:
# 물론입니다! 다음은 공상과학 작가와의 인터뷰를 위해 준비한 8가지 질문 목록입니다.
#
# 1. **작품의 영감**: 당신의 작품에 영감을 주는 요소나 사건은 무엇인가요? 특정한 경험이나 책, 영화 등에서 영향을 받으셨나요?
#
# 2. **세계관 구축**: 당신의 소설에서 독특한 세계관을 어떻게 구축하셨나요? 그 과정에서 가장 어려웠던 점은 무엇이었나요?
#
# 3. **기술과 인류**: 공상과학 소설에서 기술 발전이 인류에 미치는 영향에 대해 어떻게 생각하시나요? 현재의 기술 발전이 미래에 어떻게 반영될 것이라고 보시나요?
#
# 4. **캐릭터 개발**: 당신의 이야기에 등장하는 캐릭터들은 어떻게 개발하셨나요? 그들이 독자에게 어떤 메시지를 전달하기를 원하셨나요?
#
# 5. **주제와 메시지**: 당신의 작품에서 가장 중요하게 다루고 싶은 주제나 메시지는 무엇인가요? 독자에게 어떤 감정을 느끼게 하고 싶으신가요?
#
# 6. **작업 과정**: 당신의 글쓰기 과정은 어떤가요? 아이디어에서 최종 원고까지의 여정을 간단히 설명해 주실 수 있나요?
#
# 7. **독자와의 소통**: 독자들과의 피드백은 당신의 창작에 어떤 영향을 미치나요? 그들의 반응이나 의견이 작품의 방향에 변화를 주기도 하나요?
#
# 8. **미래의 계획**: 앞으로 어떤 주제나 아이디어를 다룬 작품을 계획하고 계신가요? 독자들이 기대할 수 있는 새로운 프로젝트가 있다면 소개해 주세요.
#
# 이 질문들이 인터뷰를 진행하는 데 도움이 되기를 바랍니다!

# %% [markdown]
# 코드 효율성 향상

# %%
prompt = """
from typing import List

def has_sum_k(nums: List[int], k: int) -> bool:
    "
    Returns True if there are two distinct elements in nums such that their sum is equal to k, and otherwise returns False."
    n = len(nums)
    for i in range(n):
        for j in range(i+1, n):
            if nums[i] + nums[j] == k:
                return True
    return False
"""
response = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",

  messages=[
    {
      "role": "system",
      "content": "Python 코드가 제공되며, 여러분의 과제는 효율성을 개선할 수 있는 아이디어를 제공하는 것입니다."
    },
    {
      "role": "user",
      "content": prompt
    }
  ],
  temperature=0.7,
  max_tokens=500,
  top_p=1
)
print(response.choices[0].message.content)
# Out:
# 현재 제공된 `has_sum_k` 함수는 두 개의 중첩된 루프를 사용하여 주어진 리스트 `nums`에서 두 개의 서로 다른 요소의 합이 `k`와 같은지 확인합니다. 이 방법은 시간 복잡도가 O(n^2)로 비효율적입니다. 이를 개선할 수 있는 몇 가지 방법이 있습니다.
#
# ### 개선안 1: 해시 세트를 사용
#
# 해시 세트를 사용하여 O(n) 시간 복잡도로 문제를 해결할 수 있습니다. 이 방법은 각 요소를 한 번씩만 확인하며, 필요한 경우 적절한 보완 요소가 해시 세트에 있는지 확인합니다.
#
# ```python
# def has_sum_k(nums: List[int], k: int) -> bool:
#     seen = set()
#     for num in nums:
#         complement = k - num
#         if complement in seen:
#             return True
#         seen.add(num)
#     return False
# ```
#
# ### 개선안 2: 정렬 후 이중 포인터 사용
#
# 리스트를 정렬한 후 두 개의 포인터를 사용하여 합을 확인하는 방법도 있습니다. 이 방법의 시간 복잡도는 O(n log n)입니다.
#
# ```python
# def has_sum_k(nums: List[int], k: int) -> bool:
#     nums.sort()
#     left, right = 0, len(nums) - 1
#
#     while left < right:
#         current_sum = nums[left] + nums[right]
#         if current_sum == k:
#             return True
#         elif current_sum < k:
#             left += 1
#         else:
#             right -= 1
#
#     return False
# ```
#
# ### 요약
#
# 위의 두 가지 개선 방안을 통해 `has_sum_k` 함수의 성능을 크게 향상시킬 수 있습니다. 첫 번째 방법은 O(n) 시간 복잡도로 가장 효율적이며, 두 번째 방법은 O(n log n)으로 정렬을 포함하지만 여전히 유용할 수 있습니다. 필요에 따라 두 가지 방법 중 하나를 선택하시면 됩니다.

# %% [markdown]
# 회의록 요약기

# %%
prompt = """
회의 날짜: 2050년 3월 5일
회의 시간: 오후 2시
장소: 컨퍼런스 룸 3B, 인터갤럭틱 본부
참석자:
- 스타더스트 선장
- 퀘이사 박사
- 레이디 네뷸라
- 슈퍼노바 경
- 혜성 씨
오후 2시 5분 스타더스트 선장이 회의를 시작함
1. 소개 및 최신 팀원, 혜성 씨를 환영합니다.
2. 조그 행성에 대한 최근 임무에 대한 논의
  - 스타더스트 선장: "전반적으로 성공적이었지만 조그인들과의 소통이 어려웠습니다. 언어 능력을 향상시켜야 합니다."
  - 퀘이사 박사: "동의합니다. 바로 조그인-영어 사전 작업을 시작하겠습니다."
  - 레이디 네뷸라: "조그인 음식은 정말 세상에서 제일 맛있었어요! 배에서 조그인 음식의 밤을 여는 것을 고려해야겠어요."
3. 7구역의 우주 해적 문제 해결
  - 슈퍼노바 경: "해적들을 상대하기 위한 더 나은 전략이 필요합니다. 그들은 이번 달에 이미 화물선 3척을 약탈했습니다."
  - 스타더스트 선장: "그 지역의 순찰을 강화하는 것에 대해 스타빔 제독과 상의하겠습니다.
  - 퀘이사 박사: "저는 해적들에게 우리 함선이 발각되지 않도록 도울 수 있는 새로운 클로킹 기술을 연구하고 있습니다. 프로토타입을 완성하려면 몇 주 더 걸릴 겁니다."
4. 연례 인터갤럭틱 베이크오프 리뷰
  - 레이디 네뷸라: "저희 팀이 대회에서 2위를 차지했다는 소식을 전하게 되어 기쁩니다! 우리의 화성 진흙 파이가 큰 인기를 끌었습니다!"
  - 코멧 씨: "내년에는 1위를 목표로 합시다. "저는 Jupiter Jello에 대한 비밀 레시피가 있는데, 우승할 수 있을 것 같아요."
5. 다가올 자선 모금 행사 계획
  - 스타더스트 선장: "Intergalactic Charity Bazaar에서 우리 부스를 위한 창의적인 아이디어가 필요해요."
  - 슈퍼노바 경: "'외계인 덩크 게임'은 어때요? 외계인 복장을 한 자원봉사자에게 물풍선을 던지는 게임을 할 수 있어요."
  - 퀘이사 박사: "'별 이름 맞추기' 퀴즈 게임을 만들어서 우승자에게 상품을 줄 수 있어요."
  - 네뷸라 부인: "좋은 아이디어네요, 여러분. 물품을 모으고 게임을 준비합시다."
  6. 다가올 팀 빌딩 휴양
  - 코멧 씨: "문 리조트 앤 스파에서 팀 빌딩 휴양을 제안하고 싶어요. 최근 임무를 마치고 친해지고 휴식을 취할 수 있는 좋은 기회예요."
  - 스타더스트 선장: "환상적인 아이디어 같아요. 예산을 확인하고 실현 가능한지 알아보겠습니다."
7. 다음 회의 안건
  - Zogian-English 사전 업데이트(Dr. Quasar)
  - 클로킹 기술 진행 상황 보고(Dr. Quasar)
  - 7구역 순찰 강화 결과(Captain Stardust)
  - Intergalactic Charity Bazaar(전체)를 위한 최종 준비
회의는 오후 3시 15분에 마감되었습니다. 다음 회의는 2050년 3월 19일 오후 2시에 회의실 3B에서 예정되어 있습니다.은하계 본부.
"""
response = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",

  messages=[

    {
      "role": "system",
      "content": """회의록이 제공되며, 여러분의 임무는 다음과 같이 회의를 요약하는 것입니다.
                - 토론의 전반적인 요약
                - 작업 항목(무엇을 해야 하는지, 누가 하는지)
                - 해당되는 경우, 다음 회의에서 보다 자세히 논의해야 할 주제 목록."""
    },
    {
      "role": "user",
      "content": prompt
    }
  ],
  temperature=0.7,
  max_tokens=500,
  top_p=1
)
print(response.choices[0].message.content)
# Out:
# ### 회의 요약
#
# 회의는 2050년 3월 5일 오후 2시에 인터갤럭틱 본부 컨퍼런스 룸 3B에서 개최되었습니다. 참석자들은 최근 조그 행성에서의 임무를 포함한 다양한 주제에 대해 논의하였으며, 팀원 혜성 씨를 환영했습니다. 조그인들과의 소통 문제, 7구역의 우주 해적 문제, 연례 베이크오프 결과, 자선 모금 행사 계획, 팀 빌딩 휴양 제안 등이 주요 논의 사항으로 다뤄졌습니다.
#
# ### 작업 항목
#
# 1. **조그인-영어 사전 작업**
#    - 책임자: 퀘이사 박사
#    - 작업 내용: 조그인과의 소통을 향상시키기 위한 사전 개발 시작.
#
# 2. **해적 문제 대응 전략 강화**
#    - 책임자: 스타더스트 선장
#    - 작업 내용: 스타빔 제독과의 협의를 통해 7구역의 순찰 강화에 대한 논의.
#
# 3. **클로킹 기술 개발**
#    - 책임자: 퀘이사 박사
#    - 작업 내용: 해적에게 발각되지 않도록 돕는 새로운 클로킹 기술 개발 진행.
#
# 4. **Intergalactic Charity Bazaar 부스 아이디어 준비**
#    - 책임자: 전원
#    - 작업 내용: '외계인 덩크 게임' 및 '별 이름 맞추기' 퀴즈 게임 아이디어를 구체화하고 물품 수집.
#
# 5. **팀 빌딩 휴양 계획 검토**
#    - 책임자: 스타더스트 선장
#    - 작업 내용: 문 리조트 앤 스파의 예산 확인 및 실현 가능성 검토.
#
# ### 다음 회의에서 논의할 주제 목록
#
# 1. 조그인-영어 사전 업데이트 (퀘이사 박사)
# 2. 클로킹 기술 진행 상황 보고 (퀘이사 박사)
# 3. 7구역 순찰 강화 결과 (스타더스트 선장)
# 4. Intergalactic Charity Bazaar 최종 준비 (전체 팀)
#
# 다음 회의는 2050년 3월 19일 오후 2시에 동일한 장소

# %% [markdown]
# 초등학교 2학년을 위한 요약

# %%
prompt = """
목성은 태양으로부터 다섯 번째 행성이며 태양계에서 가장 큰 행성입니다. 태양의 1/1000에 불과한 질량을 가진 가스 행성이지만
태양계의 다른 모든 행성을 합친 질량의 2.5배에 달합니다. 목성은 밤하늘에서 맨눈으로 볼 수 있는 가장 밝은 천체 중 하나이며 기록된 역사 이전부터
고대 문명에 알려져 왔습니다. 목성은 로마의 신인 목성의 이름을 따서 명명되었습니다.
지구에서 볼 때 목성은 반사되는 빛이 눈에 보이는 그림자를 드리울 만큼 밝을 수 있으며 달과 금성에 이어 밤하늘에서 평균적으로 세 번째로 밝은 자연 천체입니다.
"""

response = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",

  messages=[

    {
      "role": "system",
      "content": "초등학교 2학년 학생에게 제공된 내용을 요약해 보세요."
    },
    {
      "role": "user",
      "content": prompt
    }
  ],
  temperature=0.7,
  max_tokens=500,
  top_p=1
)
print(response.choices[0].message.content)
# Out:
# 목성은 태양에서 다섯 번째 행성이며, 태양계에서 가장 큽니다. 가스 행성이지만 다른 모든 행성을 합친 것보다 2.5배 무겁습니다. 밤하늘에서 매우 밝게 빛나며, 고대부터 알려져 있었습니다. 목성이라는 이름은 로마의 신에서 왔습니다. 지구에서 볼 때, 목성은 달과 금성 다음으로 밝은 자연 천체입니다.

# %% [markdown]
# 코드 설명

# %%
prompt = """
class Log:
  def __init__(self, path):
      dirname = os.path.dirname(path)
      os.makedirs(dirname, exist_ok=True)
      f = open(path, "a+")

      # Check that the file is newline-terminated
      size = os.path.getsize(path)
      if size > 0:
          f.seek(size - 1)
          end = f.read(1)
          if end != "\n":
              f.write("\n")
      self.f = f
      self.path = path

  def log(self, event):
      event["_event_id"] = str(uuid.uuid4())
      json.dump(event, self.f)
      self.f.write("\n")

  def state(self):
      state = {"complete": set(), "last": None}
      for line in open(self.path):
          event = json.loads(line)
          if event["type"] == "submit" and event["success"]:
              state["complete"].add(event["id"])
              state["last"] = event
      return state
"""

response = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",

  messages=[

    {
      "role": "system",
      "content": "여러분에게 코드가 제공될 텐데, 여러분의 과제는 그것을 간결하게 설명하는 것입니다."
    },
    {
      "role": "user",
      "content": prompt
    }
  ],
  temperature=0.2,
  max_tokens=500,

)
print(response.choices[0].message.content)
# Out:
# 이 코드는 `Log` 클래스를 정의하며, 주어진 파일 경로에 로그를 기록하는 기능을 제공합니다.
#
# 1. **초기화 (`__init__` 메서드)**:
#    - 로그 파일의 경로를 받아 해당 경로의 디렉토리가 존재하지 않으면 생성합니다.
#    - 파일을 열고, 파일이 비어있지 않은 경우 마지막 줄이 개행 문자로 끝나는지 확인하여 필요시 개행 문자를 추가합니다.
#
# 2. **로그 기록 (`log` 메서드)**:
#    - 이벤트를 받아 고유한 ID를 추가한 후, JSON 형식으로 파일에 기록하고 개행 문자를 추가합니다.
#
# 3. **상태 확인 (`state` 메서드)**:
#    - 로그 파일을 읽어 "submit" 타입의 성공적인 이벤트를 찾아, 완료된 이벤트의 ID를 집합에 추가하고 마지막 이벤트를 기록하여 상태를 반환합니다.
#
# 이 클래스는 로그 파일을 관리하고, 이벤트를 기록하며, 특정 조건에 따른 상태 정보를 제공합니다.

# %% [markdown]
# 사용자 함수 생성

# %%
prompt = "10명의 학생들 중에서 3명을 무작위로 선택하는 파이썬 사용자 함수를 작성해줘."

response = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",

  messages=[
    {
      "role": "user",
      "content": prompt
    }
  ],
  temperature=0.2,
  max_tokens=500,

)
print(response.choices[0].message.content)
# Out:
# 파이썬에서 10명의 학생 중 3명을 무작위로 선택하는 함수를 작성하려면, `random` 모듈의 `sample` 함수를 사용할 수 있습니다. 아래는 이를 구현한 예제입니다.
#
# ```python
# import random
#
# def select_students(students, num_to_select=3):
#     if num_to_select > len(students):
#         raise ValueError("선택할 학생 수가 전체 학생 수보다 많습니다.")
#     return random.sample(students, num_to_select)
#
# # 예시 학생 리스트
# students = [f"학생{i+1}" for i in range(10)]
#
# # 학생 3명 무작위 선택
# selected_students = select_students(students)
# print("선택된 학생들:", selected_students)
# ```
#
# 이 코드는 다음과 같은 방식으로 작동합니다:
#
# 1. `random` 모듈을 임포트합니다.
# 2. `select_students`라는 함수를 정의합니다. 이 함수는 학생 리스트와 선택할 학생 수를 인자로 받습니다.
# 3. 선택할 학생 수가 전체 학생 수보다 많으면 오류를 발생시킵니다.
# 4. `random.sample`을 사용하여 무작위로 학생을 선택합니다.
# 5. 예시 학생 리스트를 생성하고, 함수를 호출하여 무작위로 3명의 학생을 선택한 후 결과를 출력합니다.
#
# 이 코드를 실행하면 매번 다른 3명의 학생이 선택됩니다.

# %%
import random

def select_students(students, num_to_select=3):
    if num_to_select > len(students):
        raise ValueError("선택할 학생 수가 전체 학생 수보다 많습니다.")
    return random.sample(students, num_to_select)

# 예시 학생 리스트
students = [f"학생{i+1}" for i in range(10)]

# 학생 3명 무작위 선택
selected_students = select_students(students)
print("선택된 학생들:", selected_students)
# Out:
# 선택된 학생들: ['학생7', '학생9', '학생1']

# %% [markdown]
# 제품 이름 생성기

# %%
prompt = """
제품 설명: 가정용 밀크셰이크 제조기
핵심 단어: 빠르고 건강하며 컴팩트함."""

response = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",

  messages=[
    {
      "role": "system",
      "content": "제품 설명과 시드 단어가 제공되며, 여러분의 과제는 제품 이름을 생성하는 것입니다."
    },
    {
      "role": "user",
      "content": prompt
    }
  ],
  temperature=0.7,
  max_tokens=100,

)
print(response.choices[0].message.content)
# Out:
# 제품 이름: "스위프트쉐이크 컴팩트"

# %% [markdown]
# 웹사이트 생성

# %%
prompt = """
드롭다운과 정보를 표시하는 것에 대한 다양한 깔끔한 자바스크립트 기능을 보여주는 단일 페이지 웹사이트를 만드세요.
웹사이트는 자바스크립트와 CSS가 내장된 HTML 파일이어야 합니다."""

response = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",

  messages=[
    {
      "role": "system",
      "content": "당신은 웹개발 전문가야"
    },
    {
      "role": "user",
      "content": prompt
    }
  ],
  temperature=0.7,
  max_tokens=1000,

)
print(response.choices[0].message.content)
# Out:
# 아래는 드롭다운 및 정보 표시 기능을 포함한 단일 페이지 웹사이트의 HTML 코드입니다. 이 코드는 JavaScript와 CSS가 내장되어 있어 별도의 파일 없이 바로 사용할 수 있습니다.
#
# ```html
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>드롭다운 정보 표시 예제</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             background-color: #f4f4f4;
#             margin: 0;
#             padding: 20px;
#         }
#         h1 {
#             text-align: center;
#         }
#         .dropdown {
#             position: relative;
#             display: inline-block;
#         }
#         .dropdown-content {
#             display: none;
#             position: absolute;
#             background-color: #ffffff;
#             min-width: 200px;
#             box-shadow: 0px 8px 16px rgba(0, 0, 0, 0.2);
#             z-index: 1;
#         }
#         .dropdown-content a {
#             color: black;
#             text-decoration: none;
#             display: block;
#             padding: 12px 16px;
#         }
#         .dropdown-content a:hover {
#             background-color: #f1f1f1;
#         }
#         .dropdown:hover .dropdown-content {
#             display: block;
#         }
#         .info {
#             margin-top: 20px;
#             padding: 10px;
#             background-color: #ffffff;
#             border: 1px solid #ccc;
#             border-radius: 5px;
#         }
#     </style>
# </head>
# <body>
#
# <h1>드롭다운 정보 표시</h1>
#
# <div class="dropdown">
#     <button>정보 선택</button>
#     <div class="dropdown-content">
#         <a href="#" data-info="정보 1: 자바스크립트는 웹 개발에서 중요합니다.">정보 1</a>
#         <a href="#" data-info="정보 2: CSS는 웹 페이지의 스타일을 결정합니다.">정보 2</a>
#         <a href="#" data-info="정보 3: HTML은 웹 페이지의 구조를 정의합니다.">정보 3</a>
#     </div>
# </div>
#
# <div class="info" id="infoDisplay">선택된 정보가 여기에 표시됩니다.</div>
#
# <script>
#     const dropdownLinks = document.querySelectorAll('.dropdown-content a');
#     const infoDisplay = document.getElementById('infoDisplay');
#
#     dropdownLinks.forEach(link => {
#         link.addEventListener('click', function(event) {
#             event.preventDefault(); // 링크 클릭 시 페이지 이동 방지
#             const info = this.getAttribute('data-info');
#             infoDisplay.textContent = info; // 정보를 표시
#         });
#     });
# </script>
#
# </body>
# </html>
# ```
#
# ### 설명:
# - **HTML 구조**: 드롭다운 버튼과 정보를 표시할 영역을 포함하고 있습니다.
# - **CSS 스타일링**: 드롭다운 메뉴와 정보 표시 영역의 스타일을 정의합니다.
# - **JavaScript 기능**: 드롭다운 메뉴에서 항목을 클릭하면 해당 항목의 정보를 가져와서 아래의 정보 표시 영역에 나타나게 합니다.
#
# 이 코드를 HTML 파일로 저장하고 웹 브라우저에서 열면 드롭다운 메뉴와 정보 표시 기능을 확인할 수 있습니다.

# %% [markdown]
# 번역

# %%
prompt = """
제 이름은 제인입니다. 당신의 이름은 무엇입니까?
"""

response = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",

  messages=[
    {
      "role": "system",
      "content": "한국어 문장이 주어지고, 여러분의 과제는 그것을 영어로 번역하는 것입니다."
    },
    {
      "role": "user",
      "content": prompt
    }
  ],
  temperature=0.7,
  max_tokens=1000,

)
print(response.choices[0].message.content)
# Out:
# My name is Jane. What is your name?

# %% [markdown]
# 텍스트를 SQL 쿼리로 변환

# %%
prompt = """
Given the following SQL tables, your job is to write queries given a user’s request.

CREATE TABLE Orders (
  OrderID int,
  CustomerID int,
  OrderDate datetime,
  OrderTime varchar(8),
  PRIMARY KEY (OrderID)
);

CREATE TABLE OrderDetails (
  OrderDetailID int,
  OrderID int,
  ProductID int,
  Quantity int,
  PRIMARY KEY (OrderDetailID)
);

CREATE TABLE Products (
  ProductID int,
  ProductName varchar(50),
  Category varchar(50),
  UnitPrice decimal(10, 2),
  Stock int,
  PRIMARY KEY (ProductID)
);

CREATE TABLE Customers (
  CustomerID int,
  FirstName varchar(50),
  LastName varchar(50),
  Email varchar(100),
  Phone varchar(20),
  PRIMARY KEY (CustomerID)
);
"""

response = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",

  messages=[
    {
      "role": "system",
      "content": prompt
    },
    {
      "role": "user",
      "content": "2023-04-01 기준 모든 주문에 대한 평균 주문 금액을 계산하는 SQL 쿼리를 작성하세요."
    }
  ],
  temperature=0.7,
  max_tokens=1000,

)
print(response.choices[0].message.content)
# Out:
# 모든 주문에 대한 평균 주문 금액을 계산하기 위해서는 `Orders`, `OrderDetails` 및 `Products` 테이블을 조인하여 각 주문의 총 금액을 계산한 후, 그 평균을 구해야 합니다. 아래는 해당 SQL 쿼리입니다.
#
# ```sql
# SELECT AVG(TotalAmount) AS AverageOrderAmount
# FROM (
#     SELECT o.OrderID, SUM(od.Quantity * p.UnitPrice) AS TotalAmount
#     FROM Orders o
#     JOIN OrderDetails od ON o.OrderID = od.OrderID
#     JOIN Products p ON od.ProductID = p.ProductID
#     WHERE o.OrderDate <= '2023-04-01'
#     GROUP BY o.OrderID
# ) AS OrderTotals;
# ```
#
# 이 쿼리는 다음과 같은 과정을 수행합니다:
# 1. `Orders`, `OrderDetails`, `Products` 테이블을 조인하여 각 주문의 총 금액을 계산합니다.
# 2. `WHERE` 절을 사용하여 2023년 4월 1일 기준의 주문만 포함하도록 필터링합니다.
# 3. 각 주문의 총 금액을 그룹화하여 계산합니다.
# 4. 서브쿼리에서 계산된 총 금액의 평균을 구합니다.

# %% [markdown]
# Task1_0813. 특정 주제에 대하여 다양한 프롬프트를 활용하여 원하는 결과를 출력할 수 있도록 수행하세요.
